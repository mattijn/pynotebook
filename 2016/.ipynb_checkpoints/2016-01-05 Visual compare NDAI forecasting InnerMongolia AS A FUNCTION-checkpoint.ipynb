# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.io.shapereader import Reader
from cartopy.feature import ShapelyFeature
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LATITUDE_FORMATTER, LONGITUDE_FORMATTER
import matplotlib.ticker as mticker
import cartopy.feature as cfeature
# %matplotlib inline
import os
from osgeo import gdal
import numpy as np
fname = 'D:\Data\ChinaShapefile//PilotAreas.shp'

# %%
import numpy as np
import matplotlib.colors as mcolors
def make_colormap(seq):
    """Return a LinearSegmentedColormap
    seq: a sequence of floats and RGB-tuples. The floats should be increasing
    and in the interval (0,1).
    """
    seq = [(None,) * 3, 0.0] + list(seq) + [1.0, (None,) * 3]
    cdict = {'red': [], 'green': [], 'blue': []}
    for i, item in enumerate(seq):
        if isinstance(item, float):
            r1, g1, b1 = seq[i - 1]
            r2, g2, b2 = seq[i + 1]
            cdict['red'].append([item, r1, r2])
            cdict['green'].append([item, g1, g2])
            cdict['blue'].append([item, b1, b2])
    return mcolors.LinearSegmentedColormap('CustomMap', cdict)
c = mcolors.ColorConverter().to_rgb

def cmap_discretize(cmap, N):
    """Return a discrete colormap from the continuous colormap cmap.
    
        cmap: colormap instance, eg. cm.jet. 
        N: number of colors.
    
    Example
        x = resize(arange(100), (5,100))
        djet = cmap_discretize(cm.jet, 5)
        imshow(x, cmap=djet)
    """

    if type(cmap) == str:
        cmap = get_cmap(cmap)
    colors_i = np.concatenate((np.linspace(0, 1., N), (0.,0.,0.,0.)))
    colors_rgba = cmap(colors_i)
    indices = np.linspace(0, 1., N+1)
    cdict = {}
    for ki,key in enumerate(('red','green','blue')):
        cdict[key] = [ (indices[i], colors_rgba[i-1,ki], colors_rgba[i,ki]) for i in xrange(N+1) ]
    # Return colormap object.
    return mcolors.LinearSegmentedColormap(cmap.name + "_%d"%N, cdict, 1024)

# %%
cb_NDAI = make_colormap([c('#993406'), c('#D95E0E'),0.1, c('#D95E0E'), c('#FE9829'),0.2, 
                         c('#FE9829'), c('#FFD98E'),0.3, c('#FFD98E'), c('#FEFFD3'),0.4, 
                         c('#FEFFD3'), c('#C4DC73'),0.5, c('#C4DC73'), c('#93C83D'),0.6,
                         c('#93C83D'), c('#69BD45'),0.7, c('#69BD45'), c('#6ECCDD'),0.8,
                         c('#6ECCDD'), c('#3553A4'),0.9, c('#3553A4')])

# %%
# ticks of classes
#bounds = [0.,82.875,95.625,108.375,127.5,146.625,159.375,172.125,255.]
bounds = [-1,-0.35,-0.25,-0.15,0,0.15,0.25,0.35,1]
# ticklabels plus colorbar
ticks = ['-1','-0.35','-0.25','-0.15','+0','+.15','+.25','+.35','+1']
cmap = cmap_discretize(cb_NDAI,8)
norm = mcolors.BoundaryNorm(bounds, cmap.N)

# %%
def listall(RootFolder, wildcard='', extension='.tif'):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if wildcard in name
                     if name.endswith(extension)]
    return lists

# %%
def index_containing_substring(the_list, substring):
    for i, s in enumerate(the_list):
        if substring in s:
              return i
    return -1

# %%
ndai_w7h1 = listall(r'D:\tmp\ndai_out\NDAI\window7horizon1')
ndai_w14h7 = listall(r'D:\tmp\ndai_out\NDAI\window14horizon7')
ndai_w28h14 = listall(r'D:\tmp\ndai_out\NDAI\window28horizon14')
ndai_obs = listall(r'D:\Data\LS_DATA\NDAI-1day_IM_bbox_warp')

print ndai_obs[0][-25:-17]
# Out:
# 2003_001

# %%
ndai_obs[2699]
# Out:
# 'D:\\Data\\LS_DATA\\NDAI-1day_IM_bbox_warp\\NDAI_2010_145_IM_bbox_wrap.tif'

# %%
for ndai in ndai_obs[2699:]:
    try:
        frc_w7h1 = ndai_w7h1[[i for i, s in enumerate(ndai_w7h1) if ndai[-25:-17] in s][0]]
        frc_w14h7 = ndai_w14h7[[i for i, s in enumerate(ndai_w14h7) if ndai[-25:-17] in s][0]]
        frc_w28h14 = ndai_w28h14[[i for i, s in enumerate(ndai_w28h14) if ndai[-25:-17] in s][0]]
        #print frc_w7h1, frc_w14h7, frc_w28h14
    except:
        #print ndai[-25:-17]
        continue
        
    # files are same doy and year DO WORK
    print ndai[-25:-17]
    year = str(ndai[-25:-21])
    doy = str(ndai[-20:-17])

    ds_obs = gdal.Open(ndai)
    print 'geotransform', ds_obs.GetGeoTransform()
    print 'raster X size', ds_obs.RasterXSize
    print 'raster Y size', ds_obs.RasterYSize

    data_obs = ds_obs.ReadAsArray()
    data_ma_obs = np.ma.masked_equal(data_obs,-9999)
    data_ma_obs = np.ma.masked_invalid(data_ma_obs)
    gt = ds_obs.GetGeoTransform()
    proj = ds_obs.GetProjection()

    xres = gt[1]
    yres = gt[5]

    # get the edge coordinates and add half the resolution 
    # to go to center coordinates
    xmin = gt[0] + xres * 0.5
    xmax = gt[0] + (xres * ds_obs.RasterXSize) - xres * 0.5
    ymin = gt[3] + (yres * ds_obs.RasterYSize) + yres * 0.5
    ymax = gt[3] - yres * 0.5

    #ds = None
    gridlons = np.mgrid[xmin:xmax+xres:xres]
    gridlats = np.mgrid[ymax+yres:ymin:yres]            

    data_w7h1 = gdal.Open(frc_w7h1).ReadAsArray()
    data_ma_w7h1 = np.ma.masked_equal(data_w7h1,-9999)
    data_ma_w7h1 = np.ma.masked_invalid(data_ma_w7h1)

    data_w14h7 = gdal.Open(frc_w14h7).ReadAsArray()
    data_ma_w14h7 = np.ma.masked_equal(data_w14h7,-9999)
    data_ma_w14h7 = np.ma.masked_invalid(data_ma_w14h7)

    data_w28h14 = gdal.Open(frc_w28h14).ReadAsArray()
    data_ma_w28h14 = np.ma.masked_equal(data_w28h14,-9999)
    data_ma_w28h14 = np.ma.masked_invalid(data_ma_w28h14)


    print 'data loaded start preparing plot'
    ## PLOT @@@@@@@@@@@@@@@ 1 @@@@@@@@@@@@@
    #plt.figure(figsize=(41.53683777162, 18))
    plt.figure(figsize=(13.84561259054,12))
    ax = plt.subplot(221,projection=ccrs.PlateCarree())
    #ax.background_patch.set_facecolor('none')
    ax.set_extent([111.5,124.3,40.3,49.8])
    ax.outline_patch.set_edgecolor('gray')
    ax.outline_patch.set_linewidth(1)
    ax.outline_patch.set_linestyle(':')

    coastline = cfeature.COASTLINE.scale='10m'
    borders = cfeature.BORDERS.scale='10m'
    land = cfeature.LAND.scale='10m'
    ocean = cfeature.OCEAN.scale='10m'

    ax.add_feature(cfeature.OCEAN, facecolor='lightsteelblue') 
    ax.add_feature(cfeature.LAND, facecolor='gainsboro')  
    ax.add_feature(cfeature.COASTLINE,linewidth=0.5, edgecolor='black')
    ax.add_feature(cfeature.BORDERS, linewidth=0.5, edgecolor='black')  

    #ax.add_feature(cfeature.RIVERS, linewidth=0.2, edgecolor='blue') 
    gl = ax.gridlines(linewidth=1, color='gray', linestyle=':')
    #gl.xlocator = mticker.FixedLocator(range(-180,190,20))
    #gl.ylocator = mticker.FixedLocator(range(-60,90,10))
    #gl.xformatter = LONGITUDE_FORMATTER
    #gl.yformatter = LATITUDE_FORMATTER

    im = ax.pcolormesh(gridlons, gridlats, data_ma_obs, transform=ccrs.PlateCarree(), norm=norm, cmap=cmap, vmin=-1, vmax=1, zorder=2)
    #cb = plt.colorbar(im, fraction=0.0476, pad=0.04, ticks=bounds,norm=norm, orientation='horizontal')
    #cb.set_label('Normalized Drought Anomaly Index')
    #cb.set_ticklabels(ticks)

    shape_feature = ShapelyFeature(Reader(fname).geometries(),
                                    ccrs.PlateCarree(), facecolor='none')
    ax.add_feature(shape_feature, zorder=3, linewidth=0.5)
    ax.set_title('OBSERVED '+'year: '+year+' doy: '+doy)


    ## !@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+
    ## PLOT @@@@@@@@@@@@@@@ 2 @@@@@@@@@@@@@
    ## !@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+


    ax = plt.subplot(222,projection=ccrs.PlateCarree())
    #ax.background_patch.set_facecolor('none')
    ax.set_extent([111.5,124.3,40.3,49.8])
    ax.outline_patch.set_edgecolor('gray')
    ax.outline_patch.set_linewidth(1)
    ax.outline_patch.set_linestyle(':')

    coastline = cfeature.COASTLINE.scale='10m'
    borders = cfeature.BORDERS.scale='10m'
    ocean = cfeature.OCEAN.scale='10m'
    land = cfeature.LAND.scale='10m'

    ax.add_feature(cfeature.LAND, facecolor='gainsboro')  
    ax.add_feature(cfeature.OCEAN, facecolor='lightsteelblue')  
    ax.add_feature(cfeature.COASTLINE,linewidth=0.5, edgecolor='black')
    ax.add_feature(cfeature.BORDERS, linewidth=0.5, edgecolor='black')  

    #ax.add_feature(cfeature.RIVERS, linewidth=0.2, edgecolor='blue') 
    gl = ax.gridlines(linewidth=1, color='gray', linestyle=':')
    #gl.xlocator = mticker.FixedLocator(range(-180,190,20))
    #gl.ylocator = mticker.FixedLocator(range(-60,90,10))
    #gl.xformatter = LONGITUDE_FORMATTER
    #gl.yformatter = LATITUDE_FORMATTER
    im = ax.pcolormesh(gridlons, gridlats, data_ma_w7h1, transform=ccrs.PlateCarree(), norm=norm, cmap=cmap, vmin=-1, vmax=1, zorder=2)
    #cb = plt.colorbar(im, fraction=0.0476, pad=0.04, ticks=bounds,norm=norm, orientation='horizontal')
    #cb.set_label('Normalized Drought Anomaly Index')
    #cb.set_ticklabels(ticks)

    shape_feature = ShapelyFeature(Reader(fname).geometries(),
                                    ccrs.PlateCarree(), facecolor='none')
    ax.add_feature(shape_feature, zorder=3, linewidth=0.5)
    ax.set_title('FORECAST WINDOW 7 HORIZON 1: '+'year: '+year+' doy: '+doy)


    ## !@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+
    ## PLOT @@@@@@@@@@@@@@@ 2 @@@@@@@@@@@@@
    ## !@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+


    ax = plt.subplot(223,projection=ccrs.PlateCarree())
    #ax.background_patch.set_facecolor('none')
    ax.set_extent([111.5,124.3,40.3,49.8])
    ax.outline_patch.set_edgecolor('gray')
    ax.outline_patch.set_linewidth(1)
    ax.outline_patch.set_linestyle(':')

    coastline = cfeature.COASTLINE.scale='10m'
    borders = cfeature.BORDERS.scale='10m'
    ocean = cfeature.OCEAN.scale='10m'
    land = cfeature.LAND.scale='10m'

    ax.add_feature(cfeature.LAND, facecolor='gainsboro')  
    ax.add_feature(cfeature.OCEAN, facecolor='lightsteelblue')  
    ax.add_feature(cfeature.COASTLINE,linewidth=0.5, edgecolor='black')
    ax.add_feature(cfeature.BORDERS, linewidth=0.5, edgecolor='black')  

    #ax.add_feature(cfeature.RIVERS, linewidth=0.2, edgecolor='blue') 
    gl = ax.gridlines(linewidth=1, color='gray', linestyle=':')
    #gl.xlocator = mticker.FixedLocator(range(-180,190,20))
    #gl.ylocator = mticker.FixedLocator(range(-60,90,10))
    #gl.xformatter = LONGITUDE_FORMATTER
    #gl.yformatter = LATITUDE_FORMATTER
    im = ax.pcolormesh(gridlons, gridlats, data_ma_w14h7, transform=ccrs.PlateCarree(), norm=norm, cmap=cmap, vmin=-1, vmax=1, zorder=2)
    cb = plt.colorbar(im, fraction=0.0476, pad=0.04, ticks=bounds,norm=norm, orientation='horizontal')
    cb.set_label('Normalized Drought Anomaly Index')
    cb.set_ticklabels(ticks)

    shape_feature = ShapelyFeature(Reader(fname).geometries(),
                                    ccrs.PlateCarree(), facecolor='none')
    ax.add_feature(shape_feature, zorder=3, linewidth=0.5)
    ax.set_title('FORECAST WINDOW 14 HORIZON 7: '+'year: '+year+' doy: '+doy)

    ## !@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+
    ## PLOT @@@@@@@@@@@@@@@ 4 @@@@@@@@@@@@@
    ## !@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+!@#$%^&*()-+


    ax = plt.subplot(224,projection=ccrs.PlateCarree())
    #ax.background_patch.set_facecolor('none')
    ax.set_extent([111.5,124.3,40.3,49.8])
    ax.outline_patch.set_edgecolor('gray')
    ax.outline_patch.set_linewidth(1)
    ax.outline_patch.set_linestyle(':')

    coastline = cfeature.COASTLINE.scale='10m'
    borders = cfeature.BORDERS.scale='10m'
    ocean = cfeature.OCEAN.scale='10m'
    land = cfeature.LAND.scale='10m'

    ax.add_feature(cfeature.LAND, facecolor='gainsboro')  
    ax.add_feature(cfeature.OCEAN, facecolor='lightsteelblue')  
    ax.add_feature(cfeature.COASTLINE,linewidth=0.5, edgecolor='black')
    ax.add_feature(cfeature.BORDERS, linewidth=0.5, edgecolor='black')  

    #ax.add_feature(cfeature.RIVERS, linewidth=0.2, edgecolor='blue') 
    gl = ax.gridlines(linewidth=1, color='gray', linestyle=':')
    #gl.xlocator = mticker.FixedLocator(range(-180,190,20))
    #gl.ylocator = mticker.FixedLocator(range(-60,90,10))
    #gl.xformatter = LONGITUDE_FORMATTER
    #gl.yformatter = LATITUDE_FORMATTER
    
    im = ax.pcolormesh(gridlons, gridlats, data_ma_w28h14, transform=ccrs.PlateCarree(), norm=norm, cmap=cmap, vmin=-1, vmax=1, zorder=2)
    cb = plt.colorbar(im, fraction=0.0476, pad=0.04, ticks=bounds,norm=norm, orientation='horizontal')
    cb.set_label('Normalized Drought Anomaly Index')
    cb.set_ticklabels(ticks)

    shape_feature = ShapelyFeature(Reader(fname).geometries(),
                                    ccrs.PlateCarree(), facecolor='none')
    ax.add_feature(shape_feature, zorder=3, linewidth=0.5)
    ax.set_title('FORECAST WINDOW 28 HORIZON 14: '+'year: '+year+' doy: '+doy)                    
    plt.tight_layout()
    plt.savefig(r'D:\tmp\ndai_out\PNG//OBS_FRC_'+year+'_'+doy+'.png', dpi=100,bbox_inches='tight')
    plt.clf()
    plt.close()
# Out:
# 2010_145
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_146
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_147
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_148
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_149
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_150
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_151
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_152
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_153
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_154
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_155
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_156
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_157
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_158
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_159
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_160
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_161
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_162
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_163
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_164
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_165
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_166
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_167
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_168
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_169
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_170
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_171
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_172
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_173
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_174
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_175
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_176
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_177
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_178
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_179
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_180
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_181
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_182
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_183
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_184
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_185
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_186
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_187
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_188
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_189
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_190
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_191
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_192
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_193
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_194
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_195
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_196
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_197
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_198
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_199
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_200
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_201
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_202
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_203
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_204
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_205
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_206
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_207
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_208
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_209
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_210
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_211
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_212
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_213
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_214
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_215
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_216
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_217
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_218
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_219
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_220
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_221
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_222
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_223
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_224
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_225
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_226
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_227
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_228
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_229
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_230
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_231
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_232
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_233
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_234
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_235
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_236
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_237
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_238
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_239
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_240
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_241
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_242
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_243
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_244
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_245
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_246
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_247
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_248
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_249
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_250
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_251
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_252
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_253
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_254
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_255
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_256
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_257
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_258
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_259
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_260
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_261
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_262
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_263
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_264
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_265
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_266
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_267
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_268
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_269
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_270
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_271
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_272
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_273
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_274
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_275
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_276
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_277
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_278
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_279
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_280
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_281
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_282
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_283
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_284
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_285
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_286
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_287
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_288
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_289
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_290
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_291
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_292
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_293
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_294
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_295
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_296
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_297
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_298
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_299
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_300
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_301
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_302
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_303
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_304
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_305
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_306
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_307
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_308
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_309
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_310
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_311
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_312
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_313
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_314
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_315
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_316
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_317
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_318
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_319
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_320
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_321
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_322
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_323
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_324
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_325
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_326
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_327
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_328
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_329
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_330
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_331
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_332
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_333
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_334
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_335
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_336
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_337
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_338
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_339
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_340
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_341
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_342
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_343
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_344
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_345
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_346
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_347
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_348
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_349
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_350
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_351
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_352
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_353
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_354
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_355
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_356
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_357
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_358
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_359
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_360
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_361
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_362
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_363
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_364
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2010_365
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_001
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_002
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_003
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_004
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_005
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_006
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_007
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_008
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_009
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_010
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_011
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_012
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_013
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_014
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_015
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_016
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_017
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_018
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_019
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_020
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_021
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_022
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_023
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_024
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_025
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_026
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_027
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_028
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_029
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_030
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_031
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_032
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# 2011_033
# geotransform (111.92970000000011, 0.00999852305113156, 0.0, 49.42357600000006, 0.0, -0.00999928310502274)
# raster X size 1193
# raster Y size 876
# data loaded start preparing plot
# D:\Python27x64\lib\site-packages\matplotlib\artist.py:221: MatplotlibDeprecationWarning: This has been deprecated in mpl 1.5, please use the
# axes property.  A removal date has not been set.
#   warnings.warn(_get_axes_msg, mplDeprecation, stacklevel=1)
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-10-0ee06bced701> in <module>()
#      58     ax = plt.subplot(221,projection=ccrs.PlateCarree())
#      59     #ax.background_patch.set_facecolor('none')
# ---> 60     ax.set_extent([111.5,124.3,40.3,49.8])
#      61     ax.outline_patch.set_edgecolor('gray')
#      62     ax.outline_patch.set_linewidth(1)
#
# D:\Python27x64\lib\site-packages\cartopy\mpl\geoaxes.pyc in set_extent(self, extents, crs)
#     585
#     586         if projected is None:
# --> 587             projected = self.projection.project_geometry(domain_in_crs, crs)
#     588         x1, y1, x2, y2 = projected.bounds
#     589         self.set_xlim([x1, x2])
#
# D:\Python27x64\lib\site-packages\cartopy\crs.pyc in project_geometry(self, geometry, src_crs)
#     170             raise ValueError('Unsupported geometry '
#     171                              'type {!r}'.format(geom_type))
# --> 172         return getattr(self, method_name)(geometry, src_crs)
#     173
#     174     def _project_point(self, point, src_crs):
#
# D:\Python27x64\lib\site-packages\cartopy\crs.pyc in _project_line_string(self, geometry, src_crs)
#     176
#     177     def _project_line_string(self, geometry, src_crs):
# --> 178         return cartopy.trace.project_linear(geometry, src_crs, self)
#     179
#     180     def _project_linear_ring(self, linear_ring, src_crs):
#
# lib\cartopy\trace.pyx in cartopy.trace.project_linear (lib/cartopy\trace.cpp:1135)()
#
# lib\cartopy\trace.pyx in cartopy.trace.geos_from_shapely (lib/cartopy\trace.cpp:838)()
#
# OverflowError: Python int too large to convert to C long

# %%
1

# %%
from osgeo import gdal
import numpy as np
tif_forecast = r'D:\tmp\ndai_out\NDAI\window14horizon7//NDAI_W14H07_2009_021.tif'
ds_frc = gdal.Open(tif_forecast)
print 'geotransform', ds_frc.GetGeoTransform()
print 'raster X size', ds_frc.RasterXSize
print 'raster Y size', ds_frc.RasterYSize

data_frc = ds_frc.ReadAsArray()
data_ma_frc = np.ma.masked_equal(data_frc,-9999)
data_ma_frc = np.ma.masked_invalid(data_ma_frc)
gt = ds_frc.GetGeoTransform()
proj = ds_frc.GetProjection()

xres = gt[1]
yres = gt[5]

# get the edge coordinates and add half the resolution 
# to go to center coordinates
xmin = gt[0] + xres * 0.5
xmax = gt[0] + (xres * ds_frc.RasterXSize) - xres * 0.5
ymin = gt[3] + (yres * ds_frc.RasterYSize) + yres * 0.5
ymax = gt[3] - yres * 0.5

#ds = None
gridlons = np.mgrid[xmin:xmax+xres:xres]
gridlats = np.mgrid[ymax+yres:ymin:yres]

# plt.imshow(data_ma, cmap='viridis')
# plt.show()

# %%
tif_observed = r'D:\Data\LS_DATA\NDAI-1day_IM_bbox_warp//NDAI_2009_021_IM_bbox_wrap.tif'
ds_obs = gdal.Open(tif_observed)
print 'geotransform', ds_obs.GetGeoTransform()
print 'raster X size', ds_obs.RasterXSize
print 'raster Y size', ds_obs.RasterYSize

data_obs = ds_obs.ReadAsArray()
data_ma_obs = np.ma.masked_equal(data_obs,-9999)
data_ma_obs = np.ma.masked_invalid(data_ma_obs)
plt.imshow(data_ma_obs, cmap='viridis')
plt.show()
