# %%
from __future__ import division

# %%
from osgeo import gdal, ogr, gdalconst
import os
import subprocess as sp
from datetime import datetime, timedelta
import numpy as np
import pandas as pd

# %%
def saveRaster(path, array, dsSource, datatype=3, formatraster="GTiff", nan=None): 
    """
    Datatypes:
    unknown = 0
    byte = 1
    unsigned int16 = 2
    signed int16 = 3
    unsigned int32 = 4
    signed int32 = 5
    float32 = 6
    float64 = 7
    complex int16 = 8
    complex int32 = 9
    complex float32 = 10
    complex float64 = 11
    float32 = 6, 
    signed int = 3
    
    Formatraster:
    GeoTIFF = GTiff
    Erdas = HFA (output = .img)
    OGC web map service = WMS
    png = PNG
    """
    # Set Driver
    format_ = formatraster #save as format
    driver = gdal.GetDriverByName( format_ )
    driver.Register()
    
    # Set Metadata for Raster output
    cols = dsSource.RasterXSize
    rows = dsSource.RasterYSize
    bands = dsSource.RasterCount
    datatype = datatype#band.DataType
    
    # Set Projection for Raster
    outDataset = driver.Create(path, cols, rows, bands, datatype)
    geoTransform = dsSource.GetGeoTransform()
    outDataset.SetGeoTransform(geoTransform)
    proj = dsSource.GetProjection()
    outDataset.SetProjection(proj)
    
    # Write output to band 1 of new Raster and write NaN value
    outBand = outDataset.GetRasterBand(1)
    if nan != None:
        outBand.SetNoDataValue(nan)
    outBand.WriteArray(array) #save input array
    #outBand.WriteArray(dem)
    
    # Close and finalise newly created Raster
    #F_M01 = None
    outBand = None
    proj = None
    geoTransform = None
    outDataset = None
    driver = None
    datatype = None
    bands = None
    rows = None
    cols = None
    driver = None
    array = None

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
def listall(RootFolder, varname='',extension='.png'):
    lists = [os.path.join(root, name)
             for root, dirs, files in os.walk(RootFolder)
             for name in files
             if varname in name
             if name.endswith(extension)]
    return lists

# %%
# get index from tif files
files_LST  = listall(r'J:\LST_recon', extension='.tif')
files_NDVI = listall(r'J:\NDVI_recon', extension='.tif')
#max_LST = r'J:\MAX_MIN_NDVI_recon_LST_recon//LST_recon_max_int.tif'
#min_LST = r'J:\MAX_MIN_NDVI_recon_LST_recon//LST_recon_min_int.tif'
max_NDVI = r'J:\MAX_MIN_NDVI_recon_LST_recon//NDVI_recon_max_int.tif'
min_NDVI = r'J:\MAX_MIN_NDVI_recon_LST_recon//NDVI_recon_min_int.tif'
alpha = 0.5

# %%
files_LST = files_LST[1095:-730]
files_NDVI = files_NDVI[1095:-730]

# %%
LST_dates = []
LST_doy_list = []
for LST in files_LST:
    #print LST
    LST_year = int(LST[-22:-18])
    LST_doy = int(LST[-7:-4])
    LST_date = datetime(LST_year, 1, 1) + timedelta(LST_doy - 1)
    LST_string = str(LST_date.year).zfill(2)+'-'+str(LST_date.month).zfill(2)+'-'+str(LST_date.day).zfill(2)
    #LST_date = np.datetime64(LST_date)
    #LST_date = pd.Timestamp(np.datetime_as_string(LST_date))    
    LST_dates.append(LST_date)
    LST_yday = LST_date.timetuple().tm_yday
    LST_doy_list.append(LST_yday)    

NDVI_dates = []
NDVI_doy_list = []
for NDVI in files_NDVI:
    #print NDVI
    NDVI_year = int(NDVI[-23:-19])
    NDVI_doy = int(NDVI[-7:-4])
    NDVI_date = datetime(NDVI_year, 1, 1) + timedelta(NDVI_doy - 1)
    NDVI_string = str(NDVI_date.year).zfill(2)+'-'+str(NDVI_date.month).zfill(2)+'-'+str(NDVI_date.day).zfill(2)    
    #NDVI_date = np.datetime64(NDVI_date)
    #NDVI_date = pd.Timestamp(np.datetime_as_string(NDVI_date))
    NDVI_dates.append(NDVI_date)
    NDVI_yday = NDVI_date.timetuple().tm_yday
    NDVI_doy_list.append(NDVI_yday)

# %%
for idx, date in enumerate(LST_dates[2:365]):
    print date
    print 'LST'
    LST_in = LST_dates[idx]
    LST_single_doy_all_year = np.array(LST_dates)[np.array(LST_doy_list) == date.timetuple().tm_yday]
    
    # calculate maximum and minimum based on selection
    base_file = files_LST[LST_dates.index(LST_single_doy_all_year[0])]
    base_max = gdal.Open(base_file, gdalconst.GA_ReadOnly).ReadAsArray()
    base_min = gdal.Open(base_file, gdalconst.GA_ReadOnly).ReadAsArray()    
    for jdx, doy in enumerate(LST_single_doy_all_year):
        #print files_LST[LST_dates.index(doy)]
        ds = gdal.Open(files_LST[LST_dates.index(doy)], gdalconst.GA_ReadOnly).ReadAsArray()
        base_max = np.maximum.reduce([ds, base_max])
        base_min = np.minimum.reduce([ds, base_min])        
    # save max and min LST
    ds_base = gdal.Open(files_LST[LST_dates.index(doy)], gdalconst.GA_ReadOnly)
    date_of_year = str(date.timetuple().tm_yday).zfill(3)
    saveRaster(r'J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST//LST_MAX_'+date_of_year+'.tif', 
               base_max, ds_base)
    saveRaster(r'J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST//LST_MIN_'+date_of_year+'.tif', 
               base_min, ds_base)    
    
    print 'NDVI'    
    NDVI_in = NDVI_dates.index(date)
    NDVI_single_doy_all_year = np.array(NDVI_dates)[np.array(NDVI_doy_list) == date.timetuple().tm_yday]
    
    # calculate maximum and minimum based on selection
    base_file = files_NDVI[NDVI_dates.index(NDVI_single_doy_all_year[0])]
    base_max = gdal.Open(base_file, gdalconst.GA_ReadOnly).ReadAsArray()
    base_min = gdal.Open(base_file, gdalconst.GA_ReadOnly).ReadAsArray()    
    for jdx, doy in enumerate(NDVI_single_doy_all_year):
        #print files_NDVI[NDVI_dates.index(doy)]
        ds = gdal.Open(files_NDVI[NDVI_dates.index(doy)], gdalconst.GA_ReadOnly).ReadAsArray()
        base_max = np.maximum.reduce([ds, base_max])
        base_min = np.minimum.reduce([ds, base_min])         
    # save max and min LST
    ds_base = gdal.Open(files_NDVI[NDVI_dates.index(doy)], gdalconst.GA_ReadOnly)
    date_of_year = str(date.timetuple().tm_yday).zfill(3)
    saveRaster(r'J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI//NDVI_MAX_'+date_of_year+'.tif', 
               base_max, ds_base)
    saveRaster(r'J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI//NDVI_MIN_'+date_of_year+'.tif', 
               base_min, ds_base)

# %%
for idx, date in enumerate(LST_dates):
    print date
    print 'LST'
    LST_in = LST_dates[idx]
    LST_single_doy_all_year = np.array(LST_dates)[np.array(LST_doy_list) == date.timetuple().tm_yday]
    
    # calculate maximum and minimum based on selection
    base_file = files_LST[LST_dates.index(LST_single_doy_all_year[0])]
    base_mean = gdal.Open(base_file, gdalconst.GA_ReadOnly).ReadAsArray().astype(np.float64)
    base_mean = np.ma.masked_equal(base_mean,0)
    #print base_mean.max(), base_mean.min()
    #base_mean[np.ma.where( base_mean <= 0 )] = 0    
    base_mean -= base_mean
    for jdx, doy in enumerate(LST_single_doy_all_year):
        #print files_LST[LST_dates.index(doy)]
        ds = gdal.Open(files_LST[LST_dates.index(doy)], gdalconst.GA_ReadOnly).ReadAsArray().astype(np.float64)
        ds = np.ma.masked_equal(ds,0)
        #print ds.max(), ds.min()
        #ds[np.ma.where( ds <= 0 )] = 0
        base_mean += ds
        #print base_mean.max(), base_mean.min()        
        #base_max = np.maximum.reduce([ds, base_max])
        #base_min = np.minimum.reduce([ds, base_min])        
    # save max and min LST
    base_mean /= len(LST_single_doy_all_year)
    base_mean.fill_value = 0
    #base_mean *= 1000
    base_mean = np.rint(base_mean).astype(int)
    ds_base = gdal.Open(files_LST[LST_dates.index(doy)], gdalconst.GA_ReadOnly)
    date_of_year = str(date.timetuple().tm_yday).zfill(3)
    saveRaster(r'J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST//LST_MEAN_'+date_of_year+'.tif', 
               base_mean, ds_base)
    #saveRaster(r'J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST//LST_MIN_'+date_of_year+'.tif', 
    #           base_min, ds_base)    
    
    print 'NDVI'    
    NDVI_in = NDVI_dates.index(date)
    NDVI_single_doy_all_year = np.array(NDVI_dates)[np.array(NDVI_doy_list) == date.timetuple().tm_yday]
    
    # calculate maximum and minimum based on selection
    base_file = files_NDVI[NDVI_dates.index(NDVI_single_doy_all_year[0])]
    base_mean = gdal.Open(base_file, gdalconst.GA_ReadOnly).ReadAsArray().astype(np.float64)
    base_mean = np.ma.masked_equal(base_mean,-3000)
    base_mean[np.ma.where( base_mean <= 0 )] = 0
    base_mean -= base_mean   
    #base_mean = None
    for jdx, doy in enumerate(NDVI_single_doy_all_year):
        #print files_NDVI[NDVI_dates.index(doy)]
        ds = gdal.Open(files_NDVI[NDVI_dates.index(doy)], gdalconst.GA_ReadOnly).ReadAsArray().astype(np.float64)
        ds = np.ma.masked_equal(ds,-3000)
        ds[np.ma.where( ds <= 0 )] = 0
        base_mean += ds
        #base_max = np.maximum.reduce([ds, base_max])
        #base_min = np.minimum.reduce([ds, base_min])         
    # save max and min LST
    ds_base = gdal.Open(files_NDVI[NDVI_dates.index(doy)], gdalconst.GA_ReadOnly)
    base_mean /= len(NDVI_single_doy_all_year)
    base_mean.fill_value = 0 
    base_mean = np.rint(base_mean).astype(int)    
    date_of_year = str(date.timetuple().tm_yday).zfill(3)
    #print r'J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI//NDVI_MEAN_'+date_of_year+'.tif'
    saveRaster(r'J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI//NDVI_MEAN_'+date_of_year+'.tif', 
               base_mean, ds_base)
    #saveRaster(r'J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI//NDVI_MIN_'+date_of_year+'.tif', 
    #           base_min, ds_base)

# %%
LST_doy_min = np.array(listall(r'J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST', varname='MIN', extension='.tif'))
LST_doy_max = np.array(listall(r'J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST', varname='MAX', extension='.tif'))
LST_doy_mean = np.array(listall(r'J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST', varname='MEAN', extension='.tif'))
NDVI_doy_min = np.array(listall(r'J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI', varname='MIN', extension='.tif'))
NDVI_doy_max = np.array(listall(r'J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI', varname='MAX', extension='.tif'))
NDVI_doy_mean = np.array(listall(r'J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI', varname='MEAN', extension='.tif'))

# %%
# RECALCULATE VCI, TCI, VHI, NVAI, NTAI

# %%
for idx, LST_file in enumerate(files_LST): #files_LST
    
    #idx = files_01_03_15.index(LST_file)
    #LST_in = LST_dates_01_03_15[idx]
    LST_in = LST_dates[idx]
    print 'LST'
    
    ds_base = gdal.Open(LST_file, gdalconst.GA_ReadOnly)
    LST = gdal.Open(LST_file, gdalconst.GA_ReadOnly).ReadAsArray()
    LST_mean = gdal.Open(LST_doy_mean[LST_in.timetuple().tm_yday - 1], gdalconst.GA_ReadOnly).ReadAsArray()
    LST_max = gdal.Open(LST_doy_max[LST_in.timetuple().tm_yday - 1], gdalconst.GA_ReadOnly).ReadAsArray()
    LST_min = gdal.Open(LST_doy_min[LST_in.timetuple().tm_yday - 1], gdalconst.GA_ReadOnly).ReadAsArray()
    print LST_in, LST_doy_mean[LST_in.timetuple().tm_yday - 1]

    print 'NDVI'    
    NDVI_index = NDVI_dates.index(LST_in)
    NDVI_in = NDVI_dates[NDVI_index]
    NDVI = gdal.Open(files_NDVI[NDVI_index], gdalconst.GA_ReadOnly).ReadAsArray().astype(np.float64)
    #print NDVI_doy_mean[NDVI_in.timetuple().tm_yday - 1]
    NDVI_mean = gdal.Open(NDVI_doy_mean[NDVI_in.timetuple().tm_yday - 1], gdalconst.GA_ReadOnly).ReadAsArray()
    NDVI_max = gdal.Open(NDVI_doy_max[NDVI_in.timetuple().tm_yday - 1], gdalconst.GA_ReadOnly).ReadAsArray()
    NDVI_min = gdal.Open(NDVI_doy_min[NDVI_in.timetuple().tm_yday - 1], gdalconst.GA_ReadOnly).ReadAsArray()
    #print NDVI, NDVI_mean, NDVI_max, NDVI_min
    print files_NDVI[NDVI_index], NDVI_doy_mean[NDVI_in.timetuple().tm_yday - 1]
    
    print 'DI'
    VCI = (NDVI - NDVI_min) / (NDVI_max - NDVI_min)
    TCI = (LST_max - LST) / (LST_max - LST_min)
    VHI = (alpha * VCI) + (( 1 - alpha) * TCI)
    
    NVAI = (NDVI - NDVI_mean) / (NDVI_max - NDVI_min)
    NTAI = (LST - LST_mean) / (LST_max - LST_min)
    #NDAI = (alpha * NVAI - ( 1- alpha) * NTAI)
    
    fl_VCI = r'D:\Data\VCI_2003_2013//VCI_'+str(LST_in.year)+'_'+str(LST_in.timetuple().tm_yday).zfill(3)+'.tif'
    fl_TCI = r'D:\Data\TCI_2003_2013//TCI_'+str(LST_in.year)+'_'+str(LST_in.timetuple().tm_yday).zfill(3)+'.tif'
    fl_VHI = r'J:\VHI_2003_2013//VHI_'+str(LST_in.year)+'_'+str(LST_in.timetuple().tm_yday).zfill(3)+'.tif'
    fl_NVAI = r'D:\Data\NVAI_2003_2013//NVAI_'+str(LST_in.year)+'_'+str(LST_in.timetuple().tm_yday).zfill(3)+'.tif'
    fl_NTAI = r'D:\Data\NTAI_2003_2013//NTAI_'+str(LST_in.year)+'_'+str(LST_in.timetuple().tm_yday).zfill(3)+'.tif'
#     fl_NDAI = r'J:\NDAI_2003-2014//NDAI_'+str(LST_in.year)+'_'+str(LST_in.timetuple().tm_yday).zfill(3)+'.tif'
    print 'SAVING'
    saveRaster(fl_VCI, np.rint(VCI*1000), ds_base, 2)
    saveRaster(fl_TCI, np.rint(TCI*1000), ds_base, 2)
    saveRaster(fl_VHI, np.rint(VHI*1000), ds_base, 2)
    saveRaster(fl_NVAI, np.rint((NVAI+1)*1000), ds_base, 2)
    saveRaster(fl_NTAI, np.rint((NTAI+1)*1000), ds_base, 2)
#    saveRaster(fl_NDAI, np.rint((NDAI+1)*1000), ds_base, 2)
    #LST_single_doy_all_year = np.array(LST_dates)[np.array(LST_doy_list) == date.timetuple().tm_yday]
    #print LST_single_doy_all_year
    # calculate maximum and minimum based on selection
    #base_file = files_LST[LST_dates.index(LST_single_doy_all_year[0])]
    #print base_file
    #base_mean = gdal.Open(base_file, gdalconst.GA_ReadOnly).ReadAsArray()
# Out:
# LST
# 2003-01-01 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_001.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.001.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_001.tif
# DI
# SAVING
# LST
# 2003-01-02 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_002.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.002.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_002.tif
# DI
# SAVING
# LST
# 2003-01-03 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_003.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.003.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_003.tif
# DI
# SAVING
# LST
# 2003-01-04 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_004.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.004.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_004.tif
# DI
# SAVING
# LST
# 2003-01-05 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_005.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.005.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_005.tif
# DI
# SAVING
# LST
# 2003-01-06 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_006.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.006.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_006.tif
# DI
# SAVING
# LST
# 2003-01-07 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_007.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.007.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_007.tif
# DI
# SAVING
# LST
# 2003-01-08 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_008.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.008.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_008.tif
# DI
# SAVING
# LST
# 2003-01-09 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_009.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.009.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_009.tif
# DI
# SAVING
# LST
# 2003-01-10 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_010.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.010.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_010.tif
# DI
# SAVING
# LST
# 2003-01-11 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_011.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.011.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_011.tif
# DI
# SAVING
# LST
# 2003-01-12 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_012.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.012.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_012.tif
# DI
# SAVING
# LST
# 2003-01-13 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_013.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.013.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_013.tif
# DI
# SAVING
# LST
# 2003-01-14 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_014.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.014.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_014.tif
# DI
# SAVING
# LST
# 2003-01-15 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_015.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.015.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_015.tif
# DI
# SAVING
# LST
# 2003-01-16 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_016.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.016.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_016.tif
# DI
# SAVING
# LST
# 2003-01-17 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_017.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.017.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_017.tif
# DI
# SAVING
# LST
# 2003-01-18 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_018.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.018.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_018.tif
# DI
# SAVING
# LST
# 2003-01-19 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_019.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.019.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_019.tif
# DI
# SAVING
# LST
# 2003-01-20 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_020.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.020.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_020.tif
# DI
# SAVING
# LST
# 2003-01-21 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_021.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.021.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_021.tif
# DI
# SAVING
# LST
# 2003-01-22 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_022.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.022.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_022.tif
# DI
# SAVING
# LST
# 2003-01-23 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_023.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.023.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_023.tif
# DI
# SAVING
# LST
# 2003-01-24 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_024.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.024.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_024.tif
# DI
# SAVING
# LST
# 2003-01-25 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_025.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.025.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_025.tif
# DI
# SAVING
# LST
# 2003-01-26 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_026.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.026.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_026.tif
# DI
# SAVING
# LST
# 2003-01-27 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_027.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.027.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_027.tif
# DI
# SAVING
# LST
# 2003-01-28 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_028.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.028.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_028.tif
# DI
# SAVING
# LST
# 2003-01-29 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_029.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.029.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_029.tif
# DI
# SAVING
# LST
# 2003-01-30 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_030.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.030.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_030.tif
# DI
# SAVING
# LST
# 2003-01-31 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_031.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.031.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_031.tif
# DI
# SAVING
# LST
# 2003-02-01 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_032.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.032.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_032.tif
# DI
# SAVING
# LST
# 2003-02-02 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_033.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.033.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_033.tif
# DI
# SAVING
# LST
# 2003-02-03 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_034.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.034.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_034.tif
# DI
# SAVING
# LST
# 2003-02-04 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_035.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.035.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_035.tif
# DI
# SAVING
# LST
# 2003-02-05 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_036.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.036.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_036.tif
# DI
# SAVING
# LST
# 2003-02-06 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_037.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.037.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_037.tif
# DI
# SAVING
# LST
# 2003-02-07 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_038.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.038.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_038.tif
# DI
# SAVING
# LST
# 2003-02-08 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_039.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.039.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_039.tif
# DI
# SAVING
# LST
# 2003-02-09 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_040.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.040.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_040.tif
# DI
# SAVING
# LST
# 2003-02-10 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_041.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.041.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_041.tif
# DI
# SAVING
# LST
# 2003-02-11 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_042.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.042.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_042.tif
# DI
# SAVING
# LST
# 2003-02-12 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_043.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.043.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_043.tif
# DI
# SAVING
# LST
# 2003-02-13 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_044.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.044.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_044.tif
# DI
# SAVING
# LST
# 2003-02-14 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_045.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.045.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_045.tif
# DI
# SAVING
# LST
# 2003-02-15 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_046.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.046.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_046.tif
# DI
# SAVING
# LST
# 2003-02-16 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_047.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.047.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_047.tif
# DI
# SAVING
# LST
# 2003-02-17 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_048.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.048.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_048.tif
# DI
# SAVING
# LST
# 2003-02-18 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_049.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.049.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_049.tif
# DI
# SAVING
# LST
# 2003-02-19 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_050.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.050.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_050.tif
# DI
# SAVING
# LST
# 2003-02-20 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_051.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.051.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_051.tif
# DI
# SAVING
# LST
# 2003-02-21 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_052.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.052.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_052.tif
# DI
# SAVING
# LST
# 2003-02-22 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_053.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.053.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_053.tif
# DI
# SAVING
# LST
# 2003-02-23 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_054.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.054.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_054.tif
# DI
# SAVING
# LST
# 2003-02-24 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_055.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.055.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_055.tif
# DI
# SAVING
# LST
# 2003-02-25 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_056.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.056.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_056.tif
# DI
# SAVING
# LST
# 2003-02-26 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_057.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.057.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_057.tif
# DI
# SAVING
# LST
# 2003-02-27 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_058.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.058.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_058.tif
# DI
# SAVING
# LST
# 2003-02-28 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_059.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.059.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_059.tif
# DI
# SAVING
# LST
# 2003-03-01 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_060.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.060.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_060.tif
# DI
# SAVING
# LST
# 2003-03-02 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_061.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.061.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_061.tif
# DI
# SAVING
# LST
# 2003-03-03 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_062.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.062.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_062.tif
# DI
# SAVING
# LST
# 2003-03-04 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_063.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.063.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_063.tif
# DI
# SAVING
# LST
# 2003-03-05 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_064.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.064.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_064.tif
# DI
# SAVING
# LST
# 2003-03-06 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_065.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.065.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_065.tif
# DI
# SAVING
# LST
# 2003-03-07 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_066.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.066.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_066.tif
# DI
# SAVING
# LST
# 2003-03-08 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_067.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.067.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_067.tif
# DI
# SAVING
# LST
# 2003-03-09 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_068.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.068.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_068.tif
# DI
# SAVING
# LST
# 2003-03-10 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_069.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.069.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_069.tif
# DI
# SAVING
# LST
# 2003-03-11 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_070.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.070.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_070.tif
# DI
# SAVING
# LST
# 2003-03-12 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_071.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.071.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_071.tif
# DI
# SAVING
# LST
# 2003-03-13 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_072.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.072.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_072.tif
# DI
# SAVING
# LST
# 2003-03-14 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_073.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.073.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_073.tif
# DI
# SAVING
# LST
# 2003-03-15 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_074.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.074.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_074.tif
# DI
# SAVING
# LST
# 2003-03-16 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_075.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.075.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_075.tif
# DI
# SAVING
# LST
# 2003-03-17 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_076.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.076.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_076.tif
# DI
# SAVING
# LST
# 2003-03-18 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_077.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.077.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_077.tif
# DI
# SAVING
# LST
# 2003-03-19 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_078.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.078.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_078.tif
# DI
# SAVING
# LST
# 2003-03-20 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_079.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.079.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_079.tif
# DI
# SAVING
# LST
# 2003-03-21 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_080.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.080.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_080.tif
# DI
# SAVING
# LST
# 2003-03-22 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_081.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.081.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_081.tif
# DI
# SAVING
# LST
# 2003-03-23 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_082.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.082.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_082.tif
# DI
# SAVING
# LST
# 2003-03-24 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_083.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.083.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_083.tif
# DI
# SAVING
# LST
# 2003-03-25 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_084.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.084.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_084.tif
# DI
# SAVING
# LST
# 2003-03-26 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_085.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.085.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_085.tif
# DI
# SAVING
# LST
# 2003-03-27 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_086.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.086.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_086.tif
# DI
# SAVING
# LST
# 2003-03-28 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_087.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.087.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_087.tif
# DI
# SAVING
# LST
# 2003-03-29 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_088.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.088.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_088.tif
# DI
# SAVING
# LST
# 2003-03-30 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_089.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.089.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_089.tif
# DI
# SAVING
# LST
# 2003-03-31 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_090.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.090.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_090.tif
# DI
# SAVING
# LST
# 2003-04-01 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_091.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.091.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_091.tif
# DI
# SAVING
# LST
# 2003-04-02 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_092.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.092.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_092.tif
# DI
# SAVING
# LST
# 2003-04-03 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_093.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.093.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_093.tif
# DI
# SAVING
# LST
# 2003-04-04 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_094.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.094.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_094.tif
# DI
# SAVING
# LST
# 2003-04-05 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_095.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.095.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_095.tif
# DI
# SAVING
# LST
# 2003-04-06 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_096.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.096.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_096.tif
# DI
# SAVING
# LST
# 2003-04-07 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_097.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.097.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_097.tif
# DI
# SAVING
# LST
# 2003-04-08 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_098.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.098.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_098.tif
# DI
# SAVING
# LST
# 2003-04-09 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_099.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.099.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_099.tif
# DI
# SAVING
# LST
# 2003-04-10 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_100.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.100.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_100.tif
# DI
# SAVING
# LST
# 2003-04-11 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_101.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.101.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_101.tif
# DI
# SAVING
# LST
# 2003-04-12 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_102.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.102.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_102.tif
# DI
# SAVING
# LST
# 2003-04-13 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_103.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.103.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_103.tif
# DI
# SAVING
# LST
# 2003-04-14 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_104.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.104.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_104.tif
# DI
# SAVING
# LST
# 2003-04-15 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_105.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.105.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_105.tif
# DI
# SAVING
# LST
# 2003-04-16 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_106.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.106.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_106.tif
# DI
# SAVING
# LST
# 2003-04-17 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_107.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.107.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_107.tif
# DI
# SAVING
# LST
# 2003-04-18 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_108.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.108.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_108.tif
# DI
# SAVING
# LST
# 2003-04-19 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_109.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.109.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_109.tif
# DI
# SAVING
# LST
# 2003-04-20 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_110.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.110.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_110.tif
# DI
# SAVING
# LST
# 2003-04-21 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_111.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.111.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_111.tif
# DI
# SAVING
# LST
# 2003-04-22 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_112.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.112.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_112.tif
# DI
# SAVING
# LST
# 2003-04-23 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_113.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.113.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_113.tif
# DI
# SAVING
# LST
# 2003-04-24 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_114.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.114.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_114.tif
# DI
# SAVING
# LST
# 2003-04-25 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_115.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.115.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_115.tif
# DI
# SAVING
# LST
# 2003-04-26 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_116.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.116.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_116.tif
# DI
# SAVING
# LST
# 2003-04-27 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_117.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.117.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_117.tif
# DI
# SAVING
# LST
# 2003-04-28 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_118.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.118.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_118.tif
# DI
# SAVING
# LST
# 2003-04-29 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_119.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.119.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_119.tif
# DI
# SAVING
# LST
# 2003-04-30 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_120.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.120.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_120.tif
# DI
# SAVING
# LST
# 2003-05-01 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_121.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.121.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_121.tif
# DI
# SAVING
# LST
# 2003-05-02 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_122.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.122.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_122.tif
# DI
# SAVING
# LST
# 2003-05-03 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_123.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.123.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_123.tif
# DI
# SAVING
# LST
# 2003-05-04 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_124.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.124.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_124.tif
# DI
# SAVING
# LST
# 2003-05-05 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_125.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.125.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_125.tif
# DI
# SAVING
# LST
# 2003-05-06 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_126.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.126.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_126.tif
# DI
# SAVING
# LST
# 2003-05-07 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_127.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.127.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_127.tif
# DI
# SAVING
# LST
# 2003-05-08 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_128.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.128.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_128.tif
# DI
# SAVING
# LST
# 2003-05-09 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_129.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.129.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_129.tif
# DI
# SAVING
# LST
# 2003-05-10 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_130.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.130.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_130.tif
# DI
# SAVING
# LST
# 2003-05-11 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_131.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.131.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_131.tif
# DI
# SAVING
# LST
# 2003-05-12 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_132.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.132.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_132.tif
# DI
# SAVING
# LST
# 2003-05-13 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_133.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.133.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_133.tif
# DI
# SAVING
# LST
# 2003-05-14 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_134.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.134.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_134.tif
# DI
# SAVING
# LST
# 2003-05-15 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_135.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.135.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_135.tif
# DI
# SAVING
# LST
# 2003-05-16 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_136.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.136.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_136.tif
# DI
# SAVING
# LST
# 2003-05-17 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_137.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.137.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_137.tif
# DI
# SAVING
# LST
# 2003-05-18 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_138.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.138.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_138.tif
# DI
# SAVING
# LST
# 2003-05-19 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_139.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.139.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_139.tif
# DI
# SAVING
# LST
# 2003-05-20 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_140.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.140.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_140.tif
# DI
# SAVING
# LST
# 2003-05-21 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_141.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.141.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_141.tif
# DI
# SAVING
# LST
# 2003-05-22 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_142.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.142.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_142.tif
# DI
# SAVING
# LST
# 2003-05-23 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_143.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.143.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_143.tif
# DI
# SAVING
# LST
# 2003-05-24 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_144.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.144.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_144.tif
# DI
# SAVING
# LST
# 2003-05-25 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_145.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.145.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_145.tif
# DI
# SAVING
# LST
# 2003-05-26 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_146.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.146.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_146.tif
# DI
# SAVING
# LST
# 2003-05-27 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_147.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.147.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_147.tif
# DI
# SAVING
# LST
# 2003-05-28 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_148.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.148.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_148.tif
# DI
# SAVING
# LST
# 2003-05-29 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_149.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.149.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_149.tif
# DI
# SAVING
# LST
# 2003-05-30 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_150.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.150.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_150.tif
# DI
# SAVING
# LST
# 2003-05-31 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_151.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.151.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_151.tif
# DI
# SAVING
# LST
# 2003-06-01 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_152.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.152.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_152.tif
# DI
# SAVING
# LST
# 2003-06-02 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_153.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.153.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_153.tif
# DI
# SAVING
# LST
# 2003-06-03 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_154.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.154.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_154.tif
# DI
# SAVING
# LST
# 2003-06-04 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_155.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.155.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_155.tif
# DI
# SAVING
# LST
# 2003-06-05 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_156.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.156.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_156.tif
# DI
# SAVING
# LST
# 2003-06-06 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_157.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.157.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_157.tif
# DI
# SAVING
# LST
# 2003-06-07 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_158.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.158.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_158.tif
# DI
# SAVING
# LST
# 2003-06-08 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_159.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.159.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_159.tif
# DI
# SAVING
# LST
# 2003-06-09 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_160.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.160.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_160.tif
# DI
# SAVING
# LST
# 2003-06-10 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_161.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.161.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_161.tif
# DI
# SAVING
# LST
# 2003-06-11 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_162.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.162.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_162.tif
# DI
# SAVING
# LST
# 2003-06-12 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_163.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.163.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_163.tif
# DI
# SAVING
# LST
# 2003-06-13 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_164.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.164.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_164.tif
# DI
# SAVING
# LST
# 2003-06-14 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_165.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.165.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_165.tif
# DI
# SAVING
# LST
# 2003-06-15 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_166.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.166.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_166.tif
# DI
# SAVING
# LST
# 2003-06-16 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_167.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.167.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_167.tif
# DI
# SAVING
# LST
# 2003-06-17 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_168.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.168.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_168.tif
# DI
# SAVING
# LST
# 2003-06-18 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_169.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.169.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_169.tif
# DI
# SAVING
# LST
# 2003-06-19 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_170.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.170.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_170.tif
# DI
# SAVING
# LST
# 2003-06-20 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_171.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.171.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_171.tif
# DI
# SAVING
# LST
# 2003-06-21 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_172.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.172.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_172.tif
# DI
# SAVING
# LST
# 2003-06-22 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_173.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.173.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_173.tif
# DI
# SAVING
# LST
# 2003-06-23 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_174.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.174.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_174.tif
# DI
# SAVING
# LST
# 2003-06-24 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_175.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.175.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_175.tif
# DI
# SAVING
# LST
# 2003-06-25 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_176.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.176.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_176.tif
# DI
# SAVING
# LST
# 2003-06-26 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_177.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.177.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_177.tif
# DI
# SAVING
# LST
# 2003-06-27 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_178.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.178.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_178.tif
# DI
# SAVING
# LST
# 2003-06-28 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_179.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.179.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_179.tif
# DI
# SAVING
# LST
# 2003-06-29 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_180.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.180.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_180.tif
# DI
# SAVING
# LST
# 2003-06-30 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_181.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.181.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_181.tif
# DI
# SAVING
# LST
# 2003-07-01 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_182.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.182.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_182.tif
# DI
# SAVING
# LST
# 2003-07-02 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_183.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.183.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_183.tif
# DI
# SAVING
# LST
# 2003-07-03 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_184.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.184.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_184.tif
# DI
# SAVING
# LST
# 2003-07-04 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_185.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.185.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_185.tif
# DI
# SAVING
# LST
# 2003-07-05 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_186.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.186.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_186.tif
# DI
# SAVING
# LST
# 2003-07-06 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_187.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.187.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_187.tif
# DI
# SAVING
# LST
# 2003-07-07 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_188.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.188.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_188.tif
# DI
# SAVING
# LST
# 2003-07-08 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_189.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.189.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_189.tif
# DI
# SAVING
# LST
# 2003-07-09 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_190.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.190.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_190.tif
# DI
# SAVING
# LST
# 2003-07-10 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_191.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.191.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_191.tif
# DI
# SAVING
# LST
# 2003-07-11 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_192.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.192.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_192.tif
# DI
# SAVING
# LST
# 2003-07-12 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_193.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.193.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_193.tif
# DI
# SAVING
# LST
# 2003-07-13 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_194.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.194.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_194.tif
# DI
# SAVING
# LST
# 2003-07-14 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_195.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.195.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_195.tif
# DI
# SAVING
# LST
# 2003-07-15 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_196.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.196.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_196.tif
# DI
# SAVING
# LST
# 2003-07-16 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_197.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.197.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_197.tif
# DI
# SAVING
# LST
# 2003-07-17 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_198.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.198.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_198.tif
# DI
# SAVING
# LST
# 2003-07-18 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_199.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.199.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_199.tif
# DI
# SAVING
# LST
# 2003-07-19 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_200.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.200.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_200.tif
# DI
# SAVING
# LST
# 2003-07-20 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_201.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.201.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_201.tif
# DI
# SAVING
# LST
# 2003-07-21 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_202.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.202.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_202.tif
# DI
# SAVING
# LST
# 2003-07-22 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_203.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.203.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_203.tif
# DI
# SAVING
# LST
# 2003-07-23 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_204.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.204.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_204.tif
# DI
# SAVING
# LST
# 2003-07-24 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_205.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.205.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_205.tif
# DI
# SAVING
# LST
# 2003-07-25 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_206.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.206.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_206.tif
# DI
# SAVING
# LST
# 2003-07-26 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_207.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.207.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_207.tif
# DI
# SAVING
# LST
# 2003-07-27 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_208.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.208.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_208.tif
# DI
# SAVING
# LST
# 2003-07-28 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_209.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.209.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_209.tif
# DI
# SAVING
# LST
# 2003-07-29 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_210.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.210.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_210.tif
# DI
# SAVING
# LST
# 2003-07-30 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_211.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.211.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_211.tif
# DI
# SAVING
# LST
# 2003-07-31 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_212.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.212.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_212.tif
# DI
# SAVING
# LST
# 2003-08-01 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_213.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.213.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_213.tif
# DI
# SAVING
# LST
# 2003-08-02 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_214.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.214.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_214.tif
# DI
# SAVING
# LST
# 2003-08-03 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_215.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.215.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_215.tif
# DI
# SAVING
# LST
# 2003-08-04 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_216.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.216.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_216.tif
# DI
# SAVING
# LST
# 2003-08-05 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_217.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.217.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_217.tif
# DI
# SAVING
# LST
# 2003-08-06 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_218.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.218.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_218.tif
# DI
# SAVING
# LST
# 2003-08-07 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_219.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.219.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_219.tif
# DI
# SAVING
# LST
# 2003-08-08 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_220.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.220.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_220.tif
# DI
# SAVING
# LST
# 2003-08-09 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_221.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.221.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_221.tif
# DI
# SAVING
# LST
# 2003-08-10 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_222.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.222.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_222.tif
# DI
# SAVING
# LST
# 2003-08-11 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_223.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.223.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_223.tif
# DI
# SAVING
# LST
# 2003-08-12 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_224.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.224.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_224.tif
# DI
# SAVING
# LST
# 2003-08-13 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_225.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.225.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_225.tif
# DI
# SAVING
# LST
# 2003-08-14 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_226.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.226.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_226.tif
# DI
# SAVING
# LST
# 2003-08-15 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_227.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.227.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_227.tif
# DI
# SAVING
# LST
# 2003-08-16 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_228.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.228.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_228.tif
# DI
# SAVING
# LST
# 2003-08-17 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_229.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.229.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_229.tif
# DI
# SAVING
# LST
# 2003-08-18 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_230.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.230.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_230.tif
# DI
# SAVING
# LST
# 2003-08-19 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_231.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.231.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_231.tif
# DI
# SAVING
# LST
# 2003-08-20 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_232.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.232.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_232.tif
# DI
# SAVING
# LST
# 2003-08-21 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_233.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.233.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_233.tif
# DI
# SAVING
# LST
# 2003-08-22 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_234.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.234.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_234.tif
# DI
# SAVING
# LST
# 2003-08-23 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_235.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.235.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_235.tif
# DI
# SAVING
# LST
# 2003-08-24 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_236.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.236.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_236.tif
# DI
# SAVING
# LST
# 2003-08-25 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_237.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.237.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_237.tif
# DI
# SAVING
# LST
# 2003-08-26 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_238.tif
# NDVI
# J:\NDVI_recon\2003\CN_2003_NDVI_recon.238.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_238.tif
# DI
# SAVING
# LST
# 2003-08-27 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_239.tif
# NDVI
# ...
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.286.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_286.tif
# DI
# SAVING
# LST
# 2013-10-14 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_287.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.287.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_287.tif
# DI
# SAVING
# LST
# 2013-10-15 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_288.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.288.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_288.tif
# DI
# SAVING
# LST
# 2013-10-16 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_289.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.289.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_289.tif
# DI
# SAVING
# LST
# 2013-10-17 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_290.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.290.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_290.tif
# DI
# SAVING
# LST
# 2013-10-18 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_291.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.291.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_291.tif
# DI
# SAVING
# LST
# 2013-10-19 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_292.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.292.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_292.tif
# DI
# SAVING
# LST
# 2013-10-20 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_293.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.293.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_293.tif
# DI
# SAVING
# LST
# 2013-10-21 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_294.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.294.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_294.tif
# DI
# SAVING
# LST
# 2013-10-22 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_295.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.295.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_295.tif
# DI
# SAVING
# LST
# 2013-10-23 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_296.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.296.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_296.tif
# DI
# SAVING
# LST
# 2013-10-24 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_297.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.297.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_297.tif
# DI
# SAVING
# LST
# 2013-10-25 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_298.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.298.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_298.tif
# DI
# SAVING
# LST
# 2013-10-26 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_299.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.299.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_299.tif
# DI
# SAVING
# LST
# 2013-10-27 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_300.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.300.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_300.tif
# DI
# SAVING
# LST
# 2013-10-28 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_301.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.301.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_301.tif
# DI
# SAVING
# LST
# 2013-10-29 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_302.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.302.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_302.tif
# DI
# SAVING
# LST
# 2013-10-30 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_303.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.303.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_303.tif
# DI
# SAVING
# LST
# 2013-10-31 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_304.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.304.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_304.tif
# DI
# SAVING
# LST
# 2013-11-01 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_305.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.305.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_305.tif
# DI
# SAVING
# LST
# 2013-11-02 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_306.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.306.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_306.tif
# DI
# SAVING
# LST
# 2013-11-03 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_307.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.307.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_307.tif
# DI
# SAVING
# LST
# 2013-11-04 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_308.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.308.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_308.tif
# DI
# SAVING
# LST
# 2013-11-05 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_309.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.309.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_309.tif
# DI
# SAVING
# LST
# 2013-11-06 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_310.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.310.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_310.tif
# DI
# SAVING
# LST
# 2013-11-07 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_311.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.311.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_311.tif
# DI
# SAVING
# LST
# 2013-11-08 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_312.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.312.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_312.tif
# DI
# SAVING
# LST
# 2013-11-09 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_313.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.313.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_313.tif
# DI
# SAVING
# LST
# 2013-11-10 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_314.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.314.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_314.tif
# DI
# SAVING
# LST
# 2013-11-11 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_315.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.315.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_315.tif
# DI
# SAVING
# LST
# 2013-11-12 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_316.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.316.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_316.tif
# DI
# SAVING
# LST
# 2013-11-13 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_317.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.317.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_317.tif
# DI
# SAVING
# LST
# 2013-11-14 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_318.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.318.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_318.tif
# DI
# SAVING
# LST
# 2013-11-15 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_319.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.319.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_319.tif
# DI
# SAVING
# LST
# 2013-11-16 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_320.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.320.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_320.tif
# DI
# SAVING
# LST
# 2013-11-17 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_321.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.321.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_321.tif
# DI
# SAVING
# LST
# 2013-11-18 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_322.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.322.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_322.tif
# DI
# SAVING
# LST
# 2013-11-19 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_323.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.323.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_323.tif
# DI
# SAVING
# LST
# 2013-11-20 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_324.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.324.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_324.tif
# DI
# SAVING
# LST
# 2013-11-21 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_325.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.325.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_325.tif
# DI
# SAVING
# LST
# 2013-11-22 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_326.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.326.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_326.tif
# DI
# SAVING
# LST
# 2013-11-23 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_327.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.327.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_327.tif
# DI
# SAVING
# LST
# 2013-11-24 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_328.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.328.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_328.tif
# DI
# SAVING
# LST
# 2013-11-25 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_329.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.329.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_329.tif
# DI
# SAVING
# LST
# 2013-11-26 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_330.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.330.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_330.tif
# DI
# SAVING
# LST
# 2013-11-27 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_331.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.331.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_331.tif
# DI
# SAVING
# LST
# 2013-11-28 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_332.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.332.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_332.tif
# DI
# SAVING
# LST
# 2013-11-29 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_333.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.333.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_333.tif
# DI
# SAVING
# LST
# 2013-11-30 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_334.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.334.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_334.tif
# DI
# SAVING
# LST
# 2013-12-01 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_335.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.335.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_335.tif
# DI
# SAVING
# LST
# 2013-12-02 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_336.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.336.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_336.tif
# DI
# SAVING
# LST
# 2013-12-03 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_337.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.337.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_337.tif
# DI
# SAVING
# LST
# 2013-12-04 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_338.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.338.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_338.tif
# DI
# SAVING
# LST
# 2013-12-05 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_339.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.339.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_339.tif
# DI
# SAVING
# LST
# 2013-12-06 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_340.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.340.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_340.tif
# DI
# SAVING
# LST
# 2013-12-07 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_341.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.341.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_341.tif
# DI
# SAVING
# LST
# 2013-12-08 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_342.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.342.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_342.tif
# DI
# SAVING
# LST
# 2013-12-09 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_343.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.343.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_343.tif
# DI
# SAVING
# LST
# 2013-12-10 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_344.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.344.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_344.tif
# DI
# SAVING
# LST
# 2013-12-11 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_345.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.345.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_345.tif
# DI
# SAVING
# LST
# 2013-12-12 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_346.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.346.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_346.tif
# DI
# SAVING
# LST
# 2013-12-13 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_347.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.347.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_347.tif
# DI
# SAVING
# LST
# 2013-12-14 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_348.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.348.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_348.tif
# DI
# SAVING
# LST
# 2013-12-15 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_349.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.349.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_349.tif
# DI
# SAVING
# LST
# 2013-12-16 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_350.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.350.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_350.tif
# DI
# SAVING
# LST
# 2013-12-17 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_351.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.351.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_351.tif
# DI
# SAVING
# LST
# 2013-12-18 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_352.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.352.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_352.tif
# DI
# SAVING
# LST
# 2013-12-19 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_353.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.353.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_353.tif
# DI
# SAVING
# LST
# 2013-12-20 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_354.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.354.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_354.tif
# DI
# SAVING
# LST
# 2013-12-21 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_355.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.355.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_355.tif
# DI
# SAVING
# LST
# 2013-12-22 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_356.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.356.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_356.tif
# DI
# SAVING
# LST
# 2013-12-23 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_357.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.357.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_357.tif
# DI
# SAVING
# LST
# 2013-12-24 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_358.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.358.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_358.tif
# DI
# SAVING
# LST
# 2013-12-25 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_359.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.359.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_359.tif
# DI
# SAVING
# LST
# 2013-12-26 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_360.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.360.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_360.tif
# DI
# SAVING
# LST
# 2013-12-27 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_361.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.361.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_361.tif
# DI
# SAVING
# LST
# 2013-12-28 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_362.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.362.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_362.tif
# DI
# SAVING
# LST
# 2013-12-29 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_363.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.363.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_363.tif
# DI
# SAVING
# LST
# 2013-12-30 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_364.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.364.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_364.tif
# DI
# SAVING
# LST
# 2013-12-31 00:00:00 J:\MAX_MIN_NDVI_recon_LST_recon\doy_LST\LST_MEAN_365.tif
# NDVI
# J:\NDVI_recon\2013\CN_2013_NDVI_recon.365.tif J:\MAX_MIN_NDVI_recon_LST_recon\doy_NDVI\NDVI_MEAN_365.tif
# DI
# SAVING

# %%
im = plt.imshow(VCI)
plt.colorbar(im)

# %%
alpha
# Out:
# 0.5

# %%
# CALCULATE NDAI 2000 - 2003 & 2015

# %%
for idx, LST_file in enumerate(files_01_03_15): #files_LST
    
    idx = files_01_03_15.index(LST_file)
    LST_in = LST_dates_01_03_15[idx]
    #LST_in = LST_dates[idx]
    print 'LST'
    
    ds_base = gdal.Open(LST_file, gdalconst.GA_ReadOnly)
    LST = gdal.Open(LST_file, gdalconst.GA_ReadOnly).ReadAsArray()
    LST_mean = gdal.Open(LST_doy_mean[LST_in.timetuple().tm_yday - 1], gdalconst.GA_ReadOnly).ReadAsArray()
    LST_max = gdal.Open(LST_doy_max[LST_in.timetuple().tm_yday - 1], gdalconst.GA_ReadOnly).ReadAsArray()
    LST_min = gdal.Open(LST_doy_min[LST_in.timetuple().tm_yday - 1], gdalconst.GA_ReadOnly).ReadAsArray()
    print LST_in#, LST_doy_mean[LST_in.timetuple().tm_yday - 1]

    print 'NDVI'    
    NDVI_index = NDVI_dates.index(LST_in)
    NDVI_in = NDVI_dates[NDVI_index]
    NDVI = gdal.Open(files_NDVI[NDVI_index], gdalconst.GA_ReadOnly).ReadAsArray()
    #print NDVI_doy_mean[NDVI_in.timetuple().tm_yday - 1]
    NDVI_mean = gdal.Open(NDVI_doy_mean[NDVI_in.timetuple().tm_yday - 1], gdalconst.GA_ReadOnly).ReadAsArray()
    NDVI_max = gdal.Open(NDVI_doy_max[NDVI_in.timetuple().tm_yday - 1], gdalconst.GA_ReadOnly).ReadAsArray()
    NDVI_min = gdal.Open(NDVI_doy_min[NDVI_in.timetuple().tm_yday - 1], gdalconst.GA_ReadOnly).ReadAsArray() 
    #print NDVI, NDVI_mean, NDVI_max, NDVI_min
    #print files_NDVI[NDVI_index], NDVI_doy_mean[NDVI_in.timetuple().tm_yday - 1]
    
    print 'DI'
#     VCI = (NDVI - NDVI_min) / (NDVI_max - NDVI_min)
#     TCI = (LST_max - LST) / (LST_max - LST_min)
#     VHI = (alpha * VCI + ( 1 - alpha) * TCI)
    
    NVAI = (NDVI - NDVI_mean) / (NDVI_max - NDVI_min)
    NTAI = (LST - LST_mean) / (LST_max - LST_min)
    NDAI = (alpha * NVAI - ( 1- alpha) * NTAI)
    
#     fl_VCI = r'D:\Data\VCI_2000_2015//VCI_'+str(LST_in.year)+'_'+str(LST_in.timetuple().tm_yday).zfill(3)+'.tif'
#     fl_TCI = r'D:\Data\TCI_2000_2015//TCI_'+str(LST_in.year)+'_'+str(LST_in.timetuple().tm_yday).zfill(3)+'.tif'
#     fl_VHI = r'J:\VHI_2000_2015//VHI_'+str(LST_in.year)+'_'+str(LST_in.timetuple().tm_yday).zfill(3)+'.tif'
#     fl_NVAI = r'D:\Data\NVAI_2000_2015//NVAI_'+str(LST_in.year)+'_'+str(LST_in.timetuple().tm_yday).zfill(3)+'.tif'
#     fl_NTAI = r'D:\Data\NTAI_2000_2015//NTAI_'+str(LST_in.year)+'_'+str(LST_in.timetuple().tm_yday).zfill(3)+'.tif'
    fl_NDAI = r'J:\NDAI_2003-2014//NDAI_'+str(LST_in.year)+'_'+str(LST_in.timetuple().tm_yday).zfill(3)+'.tif'
#     print 'SAVING'
#     saveRaster(fl_VCI, VCI, ds_base, 3)
#     saveRaster(fl_TCI, TCI, ds_base, 3)
#     saveRaster(fl_VHI, VHI, ds_base, 3)
#     saveRaster(fl_NVAI, NVAI, ds_base, 3)
#     saveRaster(fl_NTAI, NTAI, ds_base, 3)
    saveRaster(fl_NDAI, np.rint((NDAI+1)*1000), ds_base, 2)
    #LST_single_doy_all_year = np.array(LST_dates)[np.array(LST_doy_list) == date.timetuple().tm_yday]
    #print LST_single_doy_all_year
    # calculate maximum and minimum based on selection
    #base_file = files_LST[LST_dates.index(LST_single_doy_all_year[0])]
    #print base_file
    #base_mean = gdal.Open(base_file, gdalconst.GA_ReadOnly).ReadAsArray()

# %%
im = plt.imshow(np.rint((NDAI+1)*1000), vmin=0, vmax=2000)
plt.colorbar(im)

# %%
second = (NDVI_max-NDVI_min)

# %%
im = plt.imshow(first)
plt.colorbar(im)

# %%
5 - 6
