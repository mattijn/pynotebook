# %%
import numpy as np
from osgeo import gdal
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = r'D:\Downloads\srtm30_plus//e020n40.nc'
ds = gdal.Open(path)

# %%
array = ds.ReadAsArray()

# %%
im = plt.imshow(array)
plt.colorbar(im)

# %%
path = r'D:\Downloads\mod44w//MOD44W_Water_2000_FE1718.tif'
ds = gdal.Open(path)
array = ds.ReadAsArray()
im = plt.imshow(array)
plt.colorbar(im)
