# %%
from osgeo import gdal, ogr, gdalconst
import os
from glob import glob
import subprocess as sp
from datetime import datetime, timedelta
import numpy as np
import pandas as pd

# %%
def saveRaster(path, array, dsSource, datatype=6, formatraster="GTiff", nan=None): 
    """
    Datatypes:
    unknown = 0
    byte = 1
    unsigned int16 = 2
    signed int16 = 3
    unsigned int32 = 4
    signed int32 = 5
    float32 = 6
    float64 = 7
    complex int16 = 8
    complex int32 = 9
    complex float32 = 10
    complex float64 = 11
    float32 = 6, 
    signed int = 3
    
    Formatraster:
    GeoTIFF = GTiff
    Erdas = HFA (output = .img)
    OGC web map service = WMS
    png = PNG
    """
    # Set Driver
    format_ = formatraster #save as format
    driver = gdal.GetDriverByName( format_ )
    driver.Register()
    
    # Set Metadata for Raster output
    cols = dsSource.RasterXSize
    rows = dsSource.RasterYSize
    bands = dsSource.RasterCount
    datatype = datatype#band.DataType
    
    # Set Projection for Raster
    outDataset = driver.Create(path, cols, rows, bands, datatype)
    geoTransform = dsSource.GetGeoTransform()
    outDataset.SetGeoTransform(geoTransform)
    proj = dsSource.GetProjection()
    outDataset.SetProjection(proj)
    
    # Write output to band 1 of new Raster and write NaN value
    outBand = outDataset.GetRasterBand(1)
    if nan != None:
        outBand.SetNoDataValue(nan)
    outBand.WriteArray(array) #save input array
    #outBand.WriteArray(dem)
    
    # Close and finalise newly created Raster
    #F_M01 = None
    outBand = None
    proj = None
    geoTransform = None
    outDataset = None
    driver = None
    datatype = None
    bands = None
    rows = None
    cols = None
    driver = None
    array = None

# %%
def compute_nattevoeten_getroffenen(inw_grid, wdp_grid, nattevoeten_out, getroffenen_out):
    ds_inw = gdal.Open(inw_grid)
    band_inw = ds_inw.GetRasterBand(1)
    nan_inw = band_inw.GetNoDataValue()
    array_inw = band_inw.ReadAsArray()
    array_inw = array_inw.astype(float)
    #extra_nan = 31075
    array_inw_msk = np.ma.masked_where(array_inw == nan_inw, array_inw)
    #array_inw_msk = np.ma.masked_where(array_inw_msk == extra_nan, array_inw_msk)

    ds_wdp = gdal.Open(wdp_grid)
    band_wdp = ds_wdp.GetRasterBand(1)
    nan_wdp = band_wdp.GetNoDataValue()
    array_wdp = band_wdp.ReadAsArray()
    array_wdp = array_wdp.astype(float)
    array_wdp_msk = np.ma.masked_where(array_wdp == nan_wdp, array_wdp)    
    
    array_wdp_msk[array_wdp_msk > 0] = 1    
        
    # export nattevoeten grid
    saveRaster(nattevoeten_out, array_wdp_msk.data, ds_wdp, datatype=6, formatraster="GTiff", nan=nan_wdp)    

    array_gtf_msk = array_inw_msk * array_wdp_msk
    array_gtf_msk.data[array_gtf_msk.mask] = nan_wdp
    
    # export getroffenen grid
    saveRaster(getroffenen_out, array_gtf_msk, ds_wdp, datatype=6, formatraster="GTiff", nan=nan_wdp)

# %%
wdp_grids_list = glob(r"D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\*waterdiepte*.tif")
inw_grid = r"D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Inwoners\grave_inwoners_grid.tif"

# %%
ds_inw = gdal.Open(inw_grid)
band_inw = ds_inw.GetRasterBand(1)
nan_inw = band_inw.GetNoDataValue()
array_inw = band_inw.ReadAsArray()
array_inw = array_inw.astype(float)
#extra_nan = 31075
array_inw_msk = np.ma.masked_where(array_inw == nan_inw, array_inw)
#array_inw_msk = np.ma.masked_where(array_inw_msk == extra_nan, array_inw_msk)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(array_inw_msk)

# %%
for wdp_grid in wdp_grids_list:
    print(wdp_grid)
    nattevoeten_out = wdp_grid.replace('waterdiepte', 'nattevoeten') 
    getroffenen_out = wdp_grid.replace('waterdiepte', 'getroffenen')    
    compute_nattevoeten_getroffenen(inw_grid, wdp_grid, nattevoeten_out, getroffenen_out)
# Out:
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_keent__maximaal_scenario__tp-1d__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_keent__maximaal_scenario__tpplus1d__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_keent__maximaal_scenario__tp__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__beugen__fm__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__beugen__tp-1d__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__beugen__tp__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__dieden__fm__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__dieden__tp-1d__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__dieden__tp__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__katwijk__fm__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__katwijk__tp-1d__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__katwijk__tp__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__keent__fm__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__keent__tp-1d__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__keent__tp__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__kraaijenbergse_plassen__fm__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__kraaijenbergse_plassen__tp-1d__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__kraaijenbergse_plassen__tp__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__ooijen__fm__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__ooijen__tp-1d__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_heusden_de_maaskant__ooijen__tp__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_maas_en_waal__alphen__tp-1d__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_maas_en_waal__alphen__tpplus1d__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_maas_en_waal__alphen__tp__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_maas_en_waal__appeltern__tp-1d__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_maas_en_waal__appeltern__tpplus1d__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_maas_en_waal__appeltern__tp__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_maas_en_waal__heumen__tp-1d__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_maas_en_waal__heumen__tpplus1d__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_maas_en_waal__heumen__tp__waterdiepte.tif
# D:\Projects\Pr\3730.15\Werkfolder\ci\grave\tif\Overstromingsscenarios (floodscenarios)\geo_land_van_maas_en_waal__sluisheumen__tp__waterdiepte.tif
