# %%
import os
import subprocess as sp
from pathlib import Path
import itertools
from osgeo import gdal, ogr
import numpy as np
from datetime import datetime

# %%
def cmd(command, parse_directly=False):
    
    if parse_directly==True:
        #print(command)
        norm = sp.Popen(command,stdout=sp.PIPE, shell=True)
    else:
        #print(sp.list2cmdline(command))
        norm = sp.Popen(sp.list2cmdline(command),stdout=sp.PIPE, shell=True)            
             
    out_cmd = norm.communicate()
    return out_cmd

# %%
def get_WD_folder(base, workdir):
    base_list = base.split('_')[1]
    if 'A' in base_list:
        coef = 'ruweData_A'        

    if 'B' in base_list:
        coef = 'ruweData_B'
    
    wd_dir = 'WD_{}_{}'.format(base_list[6].zfill(3), 
                                   base_list[7].zfill(3))    
    
    workdir_WD = os.path.join(workdir, coef, wd_dir)   
    return workdir_WD

# %%
def iter_incrementing_file_names(path):
    """
    Iterate incrementing file names. Start with path and add " (n)" before the
    extension, where n starts at 1 and increases.

    :param path: Some path
    :return: An iterator.
    """
    yield path
    prefix, ext = os.path.splitext(path)
    for i in itertools.count(start=1, step=1):
        no = str(i).zfill(2)
        # yield prefix + '_{0}'.format(i) + ext
        yield prefix + '_' + no + ext

# %%
def get_unique_filename(file_in):
    for filename in iter_incrementing_file_names(file_in):
        new_fn = Path(filename)
        if new_fn.is_file():
            pass
        else:
            return filename

# %%
def get_features(shape):
    driver = ogr.GetDriverByName('ESRI Shapefile')

    dataSource = driver.Open(shape, 0)  # 0 means read-only. 1 means writeable.

    # Check to see if shapefile is found.
    if dataSource is None:
        print('Could not open %s' % (shape))
        return
    else:
        print('Opened %s' % (shape))
        layer = dataSource.GetLayer()
        shape_features = layer.GetFeatureCount()
        print('Name of layer: %s' % layer.GetDescription())
        print("Number of features in %s: %d" % (os.path.basename(shape), shape_features))

        features_shape = []
        for i in range(shape_features):
            feat = layer.GetFeature(i)            
            obID = feat.GetField('OBJECTID')
            
            geom = feat.GetGeometryRef()
            extent = geom.GetEnvelope()
            #print(extent)
            
            features_shape.append({'obID':obID, 'extent':list(set(extent))})
        #features_shape = list(set(features_shape))
        return dataSource, layer, features_shape

# %%
rootDir = r'D:\FEWSProjecten\OmsWaddenzee\trunk\fews'
configDir = r'D:\FEWSProjecten\OmsWaddenzee\trunk\fews\Config'

sourceRoot = os.path.join(rootDir, r'Import\hkv\coefficienten\bronShp')
tmpRoot = os.path.join(rootDir, r'ImportInterim\hkv\coefficienten\tmpData')
backupRoot = os.path.join(rootDir, r'ImportBackup\hkv\coefficienten\ruweDataBackup')
asciiRoot = os.path.join(rootDir, r'Import\hkv\coefficienten\asciiData')

y = os.path.join(configDir, r'MapLayerFiles\Achtergrond_polygonen//Achtergrond_polygonen.shp')

# %%
rootOgrGdal = r'C:\Python35\Lib\site-packages\osgeo'
python_exe = r'C:\Python35\python.exe'
ogr2ogr = os.path.join(rootOgrGdal, 'ogr2ogr.exe')
gdalwarp = os.path.join(rootOgrGdal, 'gdalwarp.exe')
gdal_fillnodata = os.path.join(rootOgrGdal, 'scripts','gdal_fillnodata.py')
gdal_rasterize = os.path.join(rootOgrGdal, 'gdal_rasterize.exe')
gdal_translate = os.path.join(rootOgrGdal, 'gdal_translate.exe')
gdalbuildvrt = os.path.join(rootOgrGdal, 'gdalbuildvrt.exe')
gdalinfo = os.path.join(rootOgrGdal, 'gdalinfo.exe')
ogrinfo = os.path.join(rootOgrGdal, 'ogrinfo.exe')

# %%
# get id and extents of all features in achtergrond_polygonen shapefile
try:
    ds, layer, z_features = get_features(y)
    l = layer.GetDescription()    
except Exception as ex:
    print(ex)
    # continue
# Out:
# Opened D:\FEWSProjecten\OmsWaddenzee\trunk\fews\Config\MapLayerFiles\Achtergrond_polygonen//Achtergrond_polygonen.shp
# Name of layer: Achtergrond_polygonen
# Number of features in Achtergrond_polygonen.shp: 481

# %%
#today date
dt = datetime.today().strftime('%Y%m%d')+'000000'

# %%
for root, dirs, files in os.walk(sourceRoot):
    for file in files:
        if file.endswith('.shp') and 'test' not in file:            
            
            init_file = os.path.join(os.path.abspath(root), file)
            base, extension = os.path.splitext(init_file)
            #folders            
            coef = base.split('\\')[-3]
            wd = base.split('\\')[-2]
            fl = base.split('\\')[-1]
            
            
            
            sourcedir = os.path.join(sourceRoot, coef, wd)
            workdir = os.path.join(tmpRoot, coef, wd)
            backupdir = os.path.join(backupRoot, coef, wd)
            asciiDataDir = os.path.join(asciiRoot, coef, wd)
            
            tile = fl.split('_')[1]
            
            # get feature 
            obID = int(tile) - 1
            feature = z_features[obID]
            x = [str(e) for e in np.sort(np.round(feature['extent'], 1))]
            #print(x)
            t = tile.zfill(3)
            a = init_file
            
            # 0 convert point SHP to RASTER
            b = os.path.join(workdir, 'step0_{}.tif'.format(t))
            command = [gdal_rasterize, '-a', 'Z', '-a_nodata', '-9999', '-a_srs', 'EPSG:28992',
                       '-tr', '1.0', '1.0', '-te', x[0], x[2], x[1], x[3], '-l', fl, a, b]
            norm = cmd(command)
            #print(norm[0])

            # 1 since grids contain scattered data, interpolate and fill the nodata values to 100m edge 
            c = os.path.join(workdir, 'step1_{}.tif'.format(t))
            command = [python_exe, gdal_fillnodata, '-q', '-md', '100', b, c]
            norm = cmd(command)
            #print(norm[0])

            # 2 merge tif to ascii-grid
            f_out = 'grid{}_{}.asc'.format(t, dt)
            d = os.path.join(asciiDataDir, f_out)
            command = [gdal_translate, '-of', 'AAIGrid', '-a_nodata', '-9999', c, d]
            norm = cmd(command)               
            #print(norm[0])
            print(coef, wd, fl, f_out)
# Out:
# ruweData_A WD_000_090 clip_1 grid001_20181113000000.asc
# ruweData_A WD_000_090 clip_10 grid010_20181113000000.asc
# ruweData_A WD_000_090 clip_100 grid100_20181113000000.asc
# ruweData_A WD_000_090 clip_101 grid101_20181113000000.asc
# ruweData_A WD_000_090 clip_102 grid102_20181113000000.asc
# ruweData_A WD_000_090 clip_103 grid103_20181113000000.asc
# ruweData_A WD_000_090 clip_104 grid104_20181113000000.asc
# ruweData_A WD_000_090 clip_105 grid105_20181113000000.asc
# ruweData_A WD_000_090 clip_106 grid106_20181113000000.asc
# ruweData_A WD_000_090 clip_107 grid107_20181113000000.asc
# ruweData_A WD_000_090 clip_108 grid108_20181113000000.asc
# ruweData_A WD_000_090 clip_109 grid109_20181113000000.asc
# ruweData_A WD_000_090 clip_11 grid011_20181113000000.asc
# ruweData_A WD_000_090 clip_110 grid110_20181113000000.asc
# ruweData_A WD_000_090 clip_111 grid111_20181113000000.asc
# ruweData_A WD_000_090 clip_112 grid112_20181113000000.asc
# ruweData_A WD_000_090 clip_113 grid113_20181113000000.asc
# ruweData_A WD_000_090 clip_114 grid114_20181113000000.asc
# ruweData_A WD_000_090 clip_115 grid115_20181113000000.asc
# ruweData_A WD_000_090 clip_116 grid116_20181113000000.asc
# ruweData_A WD_000_090 clip_117 grid117_20181113000000.asc
# ruweData_A WD_000_090 clip_118 grid118_20181113000000.asc
# ruweData_A WD_000_090 clip_119 grid119_20181113000000.asc
# ruweData_A WD_000_090 clip_12 grid012_20181113000000.asc
# ruweData_A WD_000_090 clip_120 grid120_20181113000000.asc
# ruweData_A WD_000_090 clip_121 grid121_20181113000000.asc
# ruweData_A WD_000_090 clip_122 grid122_20181113000000.asc
# ruweData_A WD_000_090 clip_123 grid123_20181113000000.asc
# ruweData_A WD_000_090 clip_124 grid124_20181113000000.asc
# ruweData_A WD_000_090 clip_125 grid125_20181113000000.asc
# ruweData_A WD_000_090 clip_126 grid126_20181113000000.asc
# ruweData_A WD_000_090 clip_127 grid127_20181113000000.asc
# ruweData_A WD_000_090 clip_128 grid128_20181113000000.asc
# ruweData_A WD_000_090 clip_129 grid129_20181113000000.asc
# ruweData_A WD_000_090 clip_13 grid013_20181113000000.asc
# ruweData_A WD_000_090 clip_130 grid130_20181113000000.asc
# ruweData_A WD_000_090 clip_131 grid131_20181113000000.asc
# ruweData_A WD_000_090 clip_132 grid132_20181113000000.asc
# ruweData_A WD_000_090 clip_133 grid133_20181113000000.asc
# ruweData_A WD_000_090 clip_134 grid134_20181113000000.asc
# ruweData_A WD_000_090 clip_135 grid135_20181113000000.asc
# ruweData_A WD_000_090 clip_136 grid136_20181113000000.asc
# ruweData_A WD_000_090 clip_137 grid137_20181113000000.asc
# ruweData_A WD_000_090 clip_138 grid138_20181113000000.asc
# ruweData_A WD_000_090 clip_139 grid139_20181113000000.asc
# ruweData_A WD_000_090 clip_14 grid014_20181113000000.asc
# ruweData_A WD_000_090 clip_140 grid140_20181113000000.asc
# ruweData_A WD_000_090 clip_141 grid141_20181113000000.asc
# ruweData_A WD_000_090 clip_142 grid142_20181113000000.asc
# ruweData_A WD_000_090 clip_143 grid143_20181113000000.asc
# ruweData_A WD_000_090 clip_144 grid144_20181113000000.asc
# ruweData_A WD_000_090 clip_145 grid145_20181113000000.asc
# ruweData_A WD_000_090 clip_146 grid146_20181113000000.asc
# ruweData_A WD_000_090 clip_147 grid147_20181113000000.asc
# ruweData_A WD_000_090 clip_148 grid148_20181113000000.asc
# ruweData_A WD_000_090 clip_149 grid149_20181113000000.asc
# ruweData_A WD_000_090 clip_15 grid015_20181113000000.asc
# ruweData_A WD_000_090 clip_150 grid150_20181113000000.asc
# ruweData_A WD_000_090 clip_151 grid151_20181113000000.asc
# ruweData_A WD_000_090 clip_152 grid152_20181113000000.asc
# ruweData_A WD_000_090 clip_153 grid153_20181113000000.asc
# ruweData_A WD_000_090 clip_154 grid154_20181113000000.asc
# ruweData_A WD_000_090 clip_155 grid155_20181113000000.asc
# ruweData_A WD_000_090 clip_156 grid156_20181113000000.asc
# ruweData_A WD_000_090 clip_157 grid157_20181113000000.asc
# ruweData_A WD_000_090 clip_158 grid158_20181113000000.asc
# ruweData_A WD_000_090 clip_159 grid159_20181113000000.asc
# ruweData_A WD_000_090 clip_16 grid016_20181113000000.asc
# ruweData_A WD_000_090 clip_160 grid160_20181113000000.asc
# ruweData_A WD_000_090 clip_161 grid161_20181113000000.asc
# ruweData_A WD_000_090 clip_162 grid162_20181113000000.asc
# ruweData_A WD_000_090 clip_163 grid163_20181113000000.asc
# ruweData_A WD_000_090 clip_164 grid164_20181113000000.asc
# ruweData_A WD_000_090 clip_165 grid165_20181113000000.asc
# ruweData_A WD_000_090 clip_166 grid166_20181113000000.asc
# ruweData_A WD_000_090 clip_167 grid167_20181113000000.asc
# ruweData_A WD_000_090 clip_168 grid168_20181113000000.asc
# ruweData_A WD_000_090 clip_169 grid169_20181113000000.asc
# ruweData_A WD_000_090 clip_17 grid017_20181113000000.asc
# ruweData_A WD_000_090 clip_170 grid170_20181113000000.asc
# ruweData_A WD_000_090 clip_171 grid171_20181113000000.asc
# ruweData_A WD_000_090 clip_172 grid172_20181113000000.asc
# ruweData_A WD_000_090 clip_173 grid173_20181113000000.asc
# ruweData_A WD_000_090 clip_174 grid174_20181113000000.asc
# ruweData_A WD_000_090 clip_175 grid175_20181113000000.asc
# ruweData_A WD_000_090 clip_176 grid176_20181113000000.asc
# ruweData_A WD_000_090 clip_177 grid177_20181113000000.asc
# ruweData_A WD_000_090 clip_178 grid178_20181113000000.asc
# ruweData_A WD_000_090 clip_179 grid179_20181113000000.asc
# ruweData_A WD_000_090 clip_18 grid018_20181113000000.asc
# ruweData_A WD_000_090 clip_180 grid180_20181113000000.asc
# ruweData_A WD_000_090 clip_181 grid181_20181113000000.asc
# ruweData_A WD_000_090 clip_182 grid182_20181113000000.asc
# ruweData_A WD_000_090 clip_183 grid183_20181113000000.asc
# ruweData_A WD_000_090 clip_184 grid184_20181113000000.asc
# ruweData_A WD_000_090 clip_185 grid185_20181113000000.asc
# ruweData_A WD_000_090 clip_186 grid186_20181113000000.asc
# ruweData_A WD_000_090 clip_187 grid187_20181113000000.asc
# ruweData_A WD_000_090 clip_188 grid188_20181113000000.asc
# ruweData_A WD_000_090 clip_189 grid189_20181113000000.asc
# ruweData_A WD_000_090 clip_19 grid019_20181113000000.asc
# ruweData_A WD_000_090 clip_190 grid190_20181113000000.asc
# ruweData_A WD_000_090 clip_191 grid191_20181113000000.asc
# ruweData_A WD_000_090 clip_192 grid192_20181113000000.asc
# ruweData_A WD_000_090 clip_193 grid193_20181113000000.asc
# ruweData_A WD_000_090 clip_194 grid194_20181113000000.asc
# ruweData_A WD_000_090 clip_195 grid195_20181113000000.asc
# ruweData_A WD_000_090 clip_196 grid196_20181113000000.asc
# ruweData_A WD_000_090 clip_197 grid197_20181113000000.asc
# ruweData_A WD_000_090 clip_198 grid198_20181113000000.asc
# ruweData_A WD_000_090 clip_199 grid199_20181113000000.asc
# ruweData_A WD_000_090 clip_2 grid002_20181113000000.asc
# ruweData_A WD_000_090 clip_20 grid020_20181113000000.asc
# ruweData_A WD_000_090 clip_200 grid200_20181113000000.asc
# ruweData_A WD_000_090 clip_201 grid201_20181113000000.asc
# ruweData_A WD_000_090 clip_202 grid202_20181113000000.asc
# ruweData_A WD_000_090 clip_203 grid203_20181113000000.asc
# ruweData_A WD_000_090 clip_204 grid204_20181113000000.asc
# ruweData_A WD_000_090 clip_205 grid205_20181113000000.asc
# ruweData_A WD_000_090 clip_206 grid206_20181113000000.asc
# ruweData_A WD_000_090 clip_207 grid207_20181113000000.asc
# ruweData_A WD_000_090 clip_208 grid208_20181113000000.asc
# ruweData_A WD_000_090 clip_209 grid209_20181113000000.asc
# ruweData_A WD_000_090 clip_21 grid021_20181113000000.asc
# ruweData_A WD_000_090 clip_210 grid210_20181113000000.asc
# ruweData_A WD_000_090 clip_211 grid211_20181113000000.asc
# ruweData_A WD_000_090 clip_212 grid212_20181113000000.asc
# ruweData_A WD_000_090 clip_213 grid213_20181113000000.asc
# ruweData_A WD_000_090 clip_214 grid214_20181113000000.asc
# ruweData_A WD_000_090 clip_215 grid215_20181113000000.asc
# ruweData_A WD_000_090 clip_216 grid216_20181113000000.asc
# ruweData_A WD_000_090 clip_217 grid217_20181113000000.asc
# ruweData_A WD_000_090 clip_218 grid218_20181113000000.asc
# ruweData_A WD_000_090 clip_219 grid219_20181113000000.asc
# ruweData_A WD_000_090 clip_22 grid022_20181113000000.asc
# ruweData_A WD_000_090 clip_220 grid220_20181113000000.asc
# ruweData_A WD_000_090 clip_221 grid221_20181113000000.asc
# ruweData_A WD_000_090 clip_222 grid222_20181113000000.asc
# ruweData_A WD_000_090 clip_223 grid223_20181113000000.asc
# ruweData_A WD_000_090 clip_224 grid224_20181113000000.asc
# ruweData_A WD_000_090 clip_225 grid225_20181113000000.asc
# ruweData_A WD_000_090 clip_226 grid226_20181113000000.asc
# ruweData_A WD_000_090 clip_227 grid227_20181113000000.asc
# ruweData_A WD_000_090 clip_228 grid228_20181113000000.asc
# ruweData_A WD_000_090 clip_229 grid229_20181113000000.asc
# ruweData_A WD_000_090 clip_23 grid023_20181113000000.asc
# ruweData_A WD_000_090 clip_230 grid230_20181113000000.asc
# ruweData_A WD_000_090 clip_231 grid231_20181113000000.asc
# ruweData_A WD_000_090 clip_232 grid232_20181113000000.asc
# ruweData_A WD_000_090 clip_233 grid233_20181113000000.asc
# ruweData_A WD_000_090 clip_234 grid234_20181113000000.asc
# ruweData_A WD_000_090 clip_235 grid235_20181113000000.asc
# ruweData_A WD_000_090 clip_236 grid236_20181113000000.asc
# ruweData_A WD_000_090 clip_237 grid237_20181113000000.asc
# ruweData_A WD_000_090 clip_238 grid238_20181113000000.asc
# ruweData_A WD_000_090 clip_239 grid239_20181113000000.asc
# ruweData_A WD_000_090 clip_24 grid024_20181113000000.asc
# ruweData_A WD_000_090 clip_240 grid240_20181113000000.asc
# ruweData_A WD_000_090 clip_241 grid241_20181113000000.asc
# ruweData_A WD_000_090 clip_242 grid242_20181113000000.asc
# ruweData_A WD_000_090 clip_243 grid243_20181113000000.asc
# ruweData_A WD_000_090 clip_244 grid244_20181113000000.asc
# ruweData_A WD_000_090 clip_245 grid245_20181113000000.asc
# ruweData_A WD_000_090 clip_246 grid246_20181113000000.asc
# ruweData_A WD_000_090 clip_247 grid247_20181113000000.asc
# ruweData_A WD_000_090 clip_248 grid248_20181113000000.asc
# ruweData_A WD_000_090 clip_249 grid249_20181113000000.asc
# ruweData_A WD_000_090 clip_25 grid025_20181113000000.asc
# ruweData_A WD_000_090 clip_250 grid250_20181113000000.asc
# ruweData_A WD_000_090 clip_251 grid251_20181113000000.asc
# ruweData_A WD_000_090 clip_252 grid252_20181113000000.asc
# ruweData_A WD_000_090 clip_253 grid253_20181113000000.asc
# ruweData_A WD_000_090 clip_254 grid254_20181113000000.asc
# ruweData_A WD_000_090 clip_255 grid255_20181113000000.asc
# ruweData_A WD_000_090 clip_256 grid256_20181113000000.asc
# ruweData_A WD_000_090 clip_257 grid257_20181113000000.asc
# ruweData_A WD_000_090 clip_258 grid258_20181113000000.asc
# ruweData_A WD_000_090 clip_259 grid259_20181113000000.asc
# ruweData_A WD_000_090 clip_26 grid026_20181113000000.asc
# ruweData_A WD_000_090 clip_260 grid260_20181113000000.asc
# ruweData_A WD_000_090 clip_261 grid261_20181113000000.asc
# ruweData_A WD_000_090 clip_262 grid262_20181113000000.asc
# ruweData_A WD_000_090 clip_263 grid263_20181113000000.asc
# ruweData_A WD_000_090 clip_264 grid264_20181113000000.asc
# ruweData_A WD_000_090 clip_265 grid265_20181113000000.asc
# ruweData_A WD_000_090 clip_266 grid266_20181113000000.asc
# ruweData_A WD_000_090 clip_267 grid267_20181113000000.asc
# ruweData_A WD_000_090 clip_268 grid268_20181113000000.asc
# ruweData_A WD_000_090 clip_269 grid269_20181113000000.asc
# ruweData_A WD_000_090 clip_27 grid027_20181113000000.asc
# ruweData_A WD_000_090 clip_270 grid270_20181113000000.asc
# ruweData_A WD_000_090 clip_271 grid271_20181113000000.asc
# ruweData_A WD_000_090 clip_272 grid272_20181113000000.asc
# ruweData_A WD_000_090 clip_273 grid273_20181113000000.asc
# ruweData_A WD_000_090 clip_274 grid274_20181113000000.asc
# ruweData_A WD_000_090 clip_275 grid275_20181113000000.asc
# ruweData_A WD_000_090 clip_276 grid276_20181113000000.asc
# ruweData_A WD_000_090 clip_277 grid277_20181113000000.asc
# ruweData_A WD_000_090 clip_278 grid278_20181113000000.asc
# ruweData_A WD_000_090 clip_279 grid279_20181113000000.asc
# ruweData_A WD_000_090 clip_28 grid028_20181113000000.asc
# ruweData_A WD_000_090 clip_280 grid280_20181113000000.asc
# ruweData_A WD_000_090 clip_281 grid281_20181113000000.asc
# ruweData_A WD_000_090 clip_282 grid282_20181113000000.asc
# ruweData_A WD_000_090 clip_283 grid283_20181113000000.asc
# ruweData_A WD_000_090 clip_284 grid284_20181113000000.asc
# ruweData_A WD_000_090 clip_285 grid285_20181113000000.asc
# ruweData_A WD_000_090 clip_286 grid286_20181113000000.asc
# ruweData_A WD_000_090 clip_287 grid287_20181113000000.asc
# ruweData_A WD_000_090 clip_288 grid288_20181113000000.asc
# ruweData_A WD_000_090 clip_289 grid289_20181113000000.asc
# ruweData_A WD_000_090 clip_29 grid029_20181113000000.asc
# ruweData_A WD_000_090 clip_290 grid290_20181113000000.asc
# ruweData_A WD_000_090 clip_291 grid291_20181113000000.asc
# ruweData_A WD_000_090 clip_292 grid292_20181113000000.asc
# ruweData_A WD_000_090 clip_293 grid293_20181113000000.asc
# ruweData_A WD_000_090 clip_294 grid294_20181113000000.asc
# ruweData_A WD_000_090 clip_295 grid295_20181113000000.asc
# ruweData_A WD_000_090 clip_296 grid296_20181113000000.asc
# ruweData_A WD_000_090 clip_297 grid297_20181113000000.asc
# ruweData_A WD_000_090 clip_298 grid298_20181113000000.asc
# ruweData_A WD_000_090 clip_299 grid299_20181113000000.asc
# ruweData_A WD_000_090 clip_3 grid003_20181113000000.asc
# ruweData_A WD_000_090 clip_30 grid030_20181113000000.asc
# ruweData_A WD_000_090 clip_300 grid300_20181113000000.asc
# ruweData_A WD_000_090 clip_301 grid301_20181113000000.asc
# ruweData_A WD_000_090 clip_302 grid302_20181113000000.asc
# ruweData_A WD_000_090 clip_303 grid303_20181113000000.asc
# ruweData_A WD_000_090 clip_304 grid304_20181113000000.asc
# ruweData_A WD_000_090 clip_305 grid305_20181113000000.asc
# ruweData_A WD_000_090 clip_306 grid306_20181113000000.asc
# ruweData_A WD_000_090 clip_307 grid307_20181113000000.asc
# ruweData_A WD_000_090 clip_308 grid308_20181113000000.asc
# ruweData_A WD_000_090 clip_309 grid309_20181113000000.asc
# ruweData_A WD_000_090 clip_31 grid031_20181113000000.asc
# ruweData_A WD_000_090 clip_310 grid310_20181113000000.asc
# ruweData_A WD_000_090 clip_311 grid311_20181113000000.asc
# ruweData_A WD_000_090 clip_312 grid312_20181113000000.asc
# ruweData_A WD_000_090 clip_313 grid313_20181113000000.asc
# ruweData_A WD_000_090 clip_314 grid314_20181113000000.asc
# ruweData_A WD_000_090 clip_315 grid315_20181113000000.asc
# ruweData_A WD_000_090 clip_316 grid316_20181113000000.asc
# ruweData_A WD_000_090 clip_317 grid317_20181113000000.asc
# ruweData_A WD_000_090 clip_318 grid318_20181113000000.asc
# ruweData_A WD_000_090 clip_319 grid319_20181113000000.asc
# ruweData_A WD_000_090 clip_32 grid032_20181113000000.asc
# ruweData_A WD_000_090 clip_320 grid320_20181113000000.asc
# ruweData_A WD_000_090 clip_321 grid321_20181113000000.asc
# ruweData_A WD_000_090 clip_322 grid322_20181113000000.asc
# ruweData_A WD_000_090 clip_323 grid323_20181113000000.asc
# ruweData_A WD_000_090 clip_324 grid324_20181113000000.asc
# ruweData_A WD_000_090 clip_325 grid325_20181113000000.asc
# ruweData_A WD_000_090 clip_326 grid326_20181113000000.asc
# ruweData_A WD_000_090 clip_327 grid327_20181113000000.asc
# ruweData_A WD_000_090 clip_328 grid328_20181113000000.asc
# ruweData_A WD_000_090 clip_329 grid329_20181113000000.asc
# ruweData_A WD_000_090 clip_33 grid033_20181113000000.asc
# ruweData_A WD_000_090 clip_330 grid330_20181113000000.asc
# ruweData_A WD_000_090 clip_331 grid331_20181113000000.asc
# ruweData_A WD_000_090 clip_332 grid332_20181113000000.asc
# ruweData_A WD_000_090 clip_333 grid333_20181113000000.asc
# ruweData_A WD_000_090 clip_334 grid334_20181113000000.asc
# ruweData_A WD_000_090 clip_335 grid335_20181113000000.asc
# ruweData_A WD_000_090 clip_336 grid336_20181113000000.asc
# ruweData_A WD_000_090 clip_337 grid337_20181113000000.asc
# ruweData_A WD_000_090 clip_338 grid338_20181113000000.asc
# ruweData_A WD_000_090 clip_339 grid339_20181113000000.asc
# ruweData_A WD_000_090 clip_34 grid034_20181113000000.asc
# ruweData_A WD_000_090 clip_340 grid340_20181113000000.asc
# ruweData_A WD_000_090 clip_341 grid341_20181113000000.asc
# ruweData_A WD_000_090 clip_342 grid342_20181113000000.asc
# ruweData_A WD_000_090 clip_343 grid343_20181113000000.asc
# ruweData_A WD_000_090 clip_344 grid344_20181113000000.asc
# ruweData_A WD_000_090 clip_345 grid345_20181113000000.asc
# ruweData_A WD_000_090 clip_346 grid346_20181113000000.asc
# ruweData_A WD_000_090 clip_347 grid347_20181113000000.asc
# ruweData_A WD_000_090 clip_348 grid348_20181113000000.asc
# ruweData_A WD_000_090 clip_349 grid349_20181113000000.asc
# ruweData_A WD_000_090 clip_35 grid035_20181113000000.asc
# ruweData_A WD_000_090 clip_350 grid350_20181113000000.asc
# ruweData_A WD_000_090 clip_351 grid351_20181113000000.asc
# ruweData_A WD_000_090 clip_352 grid352_20181113000000.asc
# ruweData_A WD_000_090 clip_353 grid353_20181113000000.asc
# ruweData_A WD_000_090 clip_354 grid354_20181113000000.asc
# ruweData_A WD_000_090 clip_355 grid355_20181113000000.asc
# ruweData_A WD_000_090 clip_356 grid356_20181113000000.asc
# ruweData_A WD_000_090 clip_357 grid357_20181113000000.asc
# ruweData_A WD_000_090 clip_358 grid358_20181113000000.asc
# ruweData_A WD_000_090 clip_359 grid359_20181113000000.asc
# ruweData_A WD_000_090 clip_36 grid036_20181113000000.asc
# ruweData_A WD_000_090 clip_360 grid360_20181113000000.asc
# ruweData_A WD_000_090 clip_361 grid361_20181113000000.asc
# ruweData_A WD_000_090 clip_362 grid362_20181113000000.asc
# ruweData_A WD_000_090 clip_363 grid363_20181113000000.asc
# ruweData_A WD_000_090 clip_364 grid364_20181113000000.asc
# ruweData_A WD_000_090 clip_365 grid365_20181113000000.asc
# ruweData_A WD_000_090 clip_366 grid366_20181113000000.asc
# ruweData_A WD_000_090 clip_367 grid367_20181113000000.asc
# ruweData_A WD_000_090 clip_368 grid368_20181113000000.asc
# ruweData_A WD_000_090 clip_369 grid369_20181113000000.asc
# ruweData_A WD_000_090 clip_37 grid037_20181113000000.asc
# ruweData_A WD_000_090 clip_370 grid370_20181113000000.asc
# ruweData_A WD_000_090 clip_371 grid371_20181113000000.asc
# ruweData_A WD_000_090 clip_372 grid372_20181113000000.asc
# ruweData_A WD_000_090 clip_373 grid373_20181113000000.asc
# ruweData_A WD_000_090 clip_374 grid374_20181113000000.asc
# ruweData_A WD_000_090 clip_375 grid375_20181113000000.asc
# ruweData_A WD_000_090 clip_376 grid376_20181113000000.asc
# ruweData_A WD_000_090 clip_377 grid377_20181113000000.asc
# ruweData_A WD_000_090 clip_378 grid378_20181113000000.asc
# ruweData_A WD_000_090 clip_379 grid379_20181113000000.asc
# ruweData_A WD_000_090 clip_38 grid038_20181113000000.asc
# ruweData_A WD_000_090 clip_380 grid380_20181113000000.asc
# ruweData_A WD_000_090 clip_381 grid381_20181113000000.asc
# ruweData_A WD_000_090 clip_382 grid382_20181113000000.asc
# ruweData_A WD_000_090 clip_383 grid383_20181113000000.asc
# ruweData_A WD_000_090 clip_384 grid384_20181113000000.asc
# ruweData_A WD_000_090 clip_385 grid385_20181113000000.asc
# ruweData_A WD_000_090 clip_386 grid386_20181113000000.asc
# ruweData_A WD_000_090 clip_387 grid387_20181113000000.asc
# ruweData_A WD_000_090 clip_388 grid388_20181113000000.asc
# ruweData_A WD_000_090 clip_389 grid389_20181113000000.asc
# ruweData_A WD_000_090 clip_39 grid039_20181113000000.asc
# ruweData_A WD_000_090 clip_390 grid390_20181113000000.asc
# ruweData_A WD_000_090 clip_391 grid391_20181113000000.asc
# ruweData_A WD_000_090 clip_392 grid392_20181113000000.asc
# ruweData_A WD_000_090 clip_393 grid393_20181113000000.asc
# ruweData_A WD_000_090 clip_394 grid394_20181113000000.asc
# ruweData_A WD_000_090 clip_395 grid395_20181113000000.asc
# ruweData_A WD_000_090 clip_396 grid396_20181113000000.asc
# ruweData_A WD_000_090 clip_397 grid397_20181113000000.asc
# ruweData_A WD_000_090 clip_398 grid398_20181113000000.asc
# ruweData_A WD_000_090 clip_399 grid399_20181113000000.asc
# ruweData_A WD_000_090 clip_4 grid004_20181113000000.asc
# ruweData_A WD_000_090 clip_40 grid040_20181113000000.asc
# ruweData_A WD_000_090 clip_400 grid400_20181113000000.asc
# ruweData_A WD_000_090 clip_401 grid401_20181113000000.asc
# ruweData_A WD_000_090 clip_402 grid402_20181113000000.asc
# ruweData_A WD_000_090 clip_403 grid403_20181113000000.asc
# ruweData_A WD_000_090 clip_404 grid404_20181113000000.asc
# ruweData_A WD_000_090 clip_405 grid405_20181113000000.asc
# ruweData_A WD_000_090 clip_406 grid406_20181113000000.asc
# ruweData_A WD_000_090 clip_407 grid407_20181113000000.asc
# ruweData_A WD_000_090 clip_408 grid408_20181113000000.asc
# ruweData_A WD_000_090 clip_409 grid409_20181113000000.asc
# ruweData_A WD_000_090 clip_41 grid041_20181113000000.asc
# ruweData_A WD_000_090 clip_410 grid410_20181113000000.asc
# ruweData_A WD_000_090 clip_411 grid411_20181113000000.asc
# ruweData_A WD_000_090 clip_412 grid412_20181113000000.asc
# ruweData_A WD_000_090 clip_413 grid413_20181113000000.asc
# ruweData_A WD_000_090 clip_414 grid414_20181113000000.asc
# ruweData_A WD_000_090 clip_415 grid415_20181113000000.asc
# ruweData_A WD_000_090 clip_416 grid416_20181113000000.asc
# ruweData_A WD_000_090 clip_417 grid417_20181113000000.asc
# ruweData_A WD_000_090 clip_418 grid418_20181113000000.asc
# ruweData_A WD_000_090 clip_419 grid419_20181113000000.asc
# ruweData_A WD_000_090 clip_42 grid042_20181113000000.asc
# ruweData_A WD_000_090 clip_420 grid420_20181113000000.asc
# ruweData_A WD_000_090 clip_421 grid421_20181113000000.asc
# ruweData_A WD_000_090 clip_422 grid422_20181113000000.asc
# ruweData_A WD_000_090 clip_423 grid423_20181113000000.asc
# ruweData_A WD_000_090 clip_424 grid424_20181113000000.asc
# ruweData_A WD_000_090 clip_425 grid425_20181113000000.asc
# ruweData_A WD_000_090 clip_426 grid426_20181113000000.asc
# ruweData_A WD_000_090 clip_427 grid427_20181113000000.asc
# ruweData_A WD_000_090 clip_428 grid428_20181113000000.asc
# ruweData_A WD_000_090 clip_429 grid429_20181113000000.asc
# ruweData_A WD_000_090 clip_43 grid043_20181113000000.asc
# ruweData_A WD_000_090 clip_430 grid430_20181113000000.asc
# ruweData_A WD_000_090 clip_431 grid431_20181113000000.asc
# ruweData_A WD_000_090 clip_432 grid432_20181113000000.asc
# ruweData_A WD_000_090 clip_433 grid433_20181113000000.asc
# ruweData_A WD_000_090 clip_434 grid434_20181113000000.asc
# ruweData_A WD_000_090 clip_435 grid435_20181113000000.asc
# ruweData_A WD_000_090 clip_436 grid436_20181113000000.asc
# ruweData_A WD_000_090 clip_437 grid437_20181113000000.asc
# ruweData_A WD_000_090 clip_438 grid438_20181113000000.asc
# ruweData_A WD_000_090 clip_439 grid439_20181113000000.asc
# ruweData_A WD_000_090 clip_44 grid044_20181113000000.asc
# ruweData_A WD_000_090 clip_440 grid440_20181113000000.asc
# ruweData_A WD_000_090 clip_441 grid441_20181113000000.asc
# ruweData_A WD_000_090 clip_442 grid442_20181113000000.asc
# ruweData_A WD_000_090 clip_443 grid443_20181113000000.asc
# ruweData_A WD_000_090 clip_444 grid444_20181113000000.asc
# ruweData_A WD_000_090 clip_445 grid445_20181113000000.asc
# ruweData_A WD_000_090 clip_446 grid446_20181113000000.asc
# ruweData_A WD_000_090 clip_447 grid447_20181113000000.asc
# ruweData_A WD_000_090 clip_448 grid448_20181113000000.asc
# ruweData_A WD_000_090 clip_449 grid449_20181113000000.asc
# ruweData_A WD_000_090 clip_45 grid045_20181113000000.asc
# ruweData_A WD_000_090 clip_450 grid450_20181113000000.asc
# ruweData_A WD_000_090 clip_451 grid451_20181113000000.asc
# ruweData_A WD_000_090 clip_452 grid452_20181113000000.asc
# ruweData_A WD_000_090 clip_453 grid453_20181113000000.asc
# ruweData_A WD_000_090 clip_454 grid454_20181113000000.asc
# ruweData_A WD_000_090 clip_455 grid455_20181113000000.asc
# ruweData_A WD_000_090 clip_456 grid456_20181113000000.asc
# ruweData_A WD_000_090 clip_457 grid457_20181113000000.asc
# ruweData_A WD_000_090 clip_458 grid458_20181113000000.asc
# ruweData_A WD_000_090 clip_459 grid459_20181113000000.asc
# ruweData_A WD_000_090 clip_46 grid046_20181113000000.asc
# ruweData_A WD_000_090 clip_460 grid460_20181113000000.asc
# ruweData_A WD_000_090 clip_461 grid461_20181113000000.asc
# ruweData_A WD_000_090 clip_462 grid462_20181113000000.asc
# ruweData_A WD_000_090 clip_463 grid463_20181113000000.asc
# ruweData_A WD_000_090 clip_464 grid464_20181113000000.asc
# ruweData_A WD_000_090 clip_465 grid465_20181113000000.asc
# ruweData_A WD_000_090 clip_466 grid466_20181113000000.asc
# ruweData_A WD_000_090 clip_467 grid467_20181113000000.asc
# ruweData_A WD_000_090 clip_468 grid468_20181113000000.asc
# ruweData_A WD_000_090 clip_469 grid469_20181113000000.asc
# ruweData_A WD_000_090 clip_47 grid047_20181113000000.asc
# ruweData_A WD_000_090 clip_470 grid470_20181113000000.asc
# ruweData_A WD_000_090 clip_471 grid471_20181113000000.asc
# ruweData_A WD_000_090 clip_472 grid472_20181113000000.asc
# ruweData_A WD_000_090 clip_473 grid473_20181113000000.asc
# ruweData_A WD_000_090 clip_474 grid474_20181113000000.asc
# ruweData_A WD_000_090 clip_475 grid475_20181113000000.asc
# ruweData_A WD_000_090 clip_476 grid476_20181113000000.asc
# ruweData_A WD_000_090 clip_477 grid477_20181113000000.asc
# ruweData_A WD_000_090 clip_478 grid478_20181113000000.asc
# ruweData_A WD_000_090 clip_479 grid479_20181113000000.asc
# ruweData_A WD_000_090 clip_48 grid048_20181113000000.asc
# ruweData_A WD_000_090 clip_480 grid480_20181113000000.asc
# ruweData_A WD_000_090 clip_481 grid481_20181113000000.asc
# ruweData_A WD_000_090 clip_49 grid049_20181113000000.asc
# ruweData_A WD_000_090 clip_5 grid005_20181113000000.asc
# ruweData_A WD_000_090 clip_50 grid050_20181113000000.asc
# ruweData_A WD_000_090 clip_51 grid051_20181113000000.asc
# ruweData_A WD_000_090 clip_52 grid052_20181113000000.asc
# ruweData_A WD_000_090 clip_53 grid053_20181113000000.asc
# ruweData_A WD_000_090 clip_54 grid054_20181113000000.asc
# ruweData_A WD_000_090 clip_55 grid055_20181113000000.asc
# ruweData_A WD_000_090 clip_56 grid056_20181113000000.asc
# ruweData_A WD_000_090 clip_57 grid057_20181113000000.asc
# ruweData_A WD_000_090 clip_58 grid058_20181113000000.asc
# ruweData_A WD_000_090 clip_59 grid059_20181113000000.asc
# ruweData_A WD_000_090 clip_6 grid006_20181113000000.asc
# ruweData_A WD_000_090 clip_60 grid060_20181113000000.asc
# ruweData_A WD_000_090 clip_61 grid061_20181113000000.asc
# ruweData_A WD_000_090 clip_62 grid062_20181113000000.asc
# ruweData_A WD_000_090 clip_63 grid063_20181113000000.asc
# ruweData_A WD_000_090 clip_64 grid064_20181113000000.asc
# ruweData_A WD_000_090 clip_65 grid065_20181113000000.asc
# ruweData_A WD_000_090 clip_66 grid066_20181113000000.asc
# ruweData_A WD_000_090 clip_67 grid067_20181113000000.asc
# ruweData_A WD_000_090 clip_68 grid068_20181113000000.asc
# ruweData_A WD_000_090 clip_69 grid069_20181113000000.asc
# ruweData_A WD_000_090 clip_7 grid007_20181113000000.asc
# ruweData_A WD_000_090 clip_70 grid070_20181113000000.asc
# ruweData_A WD_000_090 clip_71 grid071_20181113000000.asc
# ruweData_A WD_000_090 clip_72 grid072_20181113000000.asc
# ruweData_A WD_000_090 clip_73 grid073_20181113000000.asc
# ruweData_A WD_000_090 clip_74 grid074_20181113000000.asc
# ruweData_A WD_000_090 clip_75 grid075_20181113000000.asc
# ruweData_A WD_000_090 clip_76 grid076_20181113000000.asc
# ruweData_A WD_000_090 clip_77 grid077_20181113000000.asc
# ruweData_A WD_000_090 clip_78 grid078_20181113000000.asc
# ruweData_A WD_000_090 clip_79 grid079_20181113000000.asc
# ruweData_A WD_000_090 clip_8 grid008_20181113000000.asc
# ruweData_A WD_000_090 clip_80 grid080_20181113000000.asc
# ruweData_A WD_000_090 clip_81 grid081_20181113000000.asc
# ruweData_A WD_000_090 clip_82 grid082_20181113000000.asc
# ruweData_A WD_000_090 clip_83 grid083_20181113000000.asc
# ruweData_A WD_000_090 clip_84 grid084_20181113000000.asc
# ruweData_A WD_000_090 clip_85 grid085_20181113000000.asc
# ruweData_A WD_000_090 clip_86 grid086_20181113000000.asc
# ruweData_A WD_000_090 clip_87 grid087_20181113000000.asc
# ruweData_A WD_000_090 clip_88 grid088_20181113000000.asc
# ruweData_A WD_000_090 clip_89 grid089_20181113000000.asc
# ruweData_A WD_000_090 clip_9 grid009_20181113000000.asc
# ruweData_A WD_000_090 clip_90 grid090_20181113000000.asc
# ruweData_A WD_000_090 clip_91 grid091_20181113000000.asc
# ruweData_A WD_000_090 clip_92 grid092_20181113000000.asc
# ruweData_A WD_000_090 clip_93 grid093_20181113000000.asc
# ruweData_A WD_000_090 clip_94 grid094_20181113000000.asc
# ruweData_A WD_000_090 clip_95 grid095_20181113000000.asc
# ruweData_A WD_000_090 clip_96 grid096_20181113000000.asc
# ruweData_A WD_000_090 clip_97 grid097_20181113000000.asc
# ruweData_A WD_000_090 clip_98 grid098_20181113000000.asc
# ruweData_A WD_000_090 clip_99 grid099_20181113000000.asc

# %%
# purge redundant xml and prj files 
xmlFiles = []
prjFiles = []
for root, dirs, files in os.walk(asciiDataDir):
    for file in files:
        if file.endswith(".xml"):
             xmlFiles.append(os.path.join(root, file))
        if file.endswith(".prj"):
             prjFiles.append(os.path.join(root, file))               

for xmlFile in xmlFiles:
    os.remove(xmlFile)

for prjFile in prjFiles:
    os.remove(prjFile)
