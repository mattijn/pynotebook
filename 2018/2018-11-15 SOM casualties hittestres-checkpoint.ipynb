# %%
import numpy as np
import pandas as pd
import geopandas as gpd

import sompy
from sompy.visualization.mapview import View2D
import altair as alt

# %matplotlib inline
# Out:
# backend module://ipykernel.pylab.backend_inline version unknown
# backend module://ipykernel.pylab.backend_inline version unknown
# backend module://ipykernel.pylab.backend_inline version unknown

# %%
# load csv
file_name = r"D:\jupyter notebooks\0001.00 Markt\2018-11-15 casualties hittestres.csv"

# %%
# read all sheets from excel and parse as single dataframe
df = pd.read_csv(file_name, index_col=0)
df.head()
# Out:
#              delta_UN  delta_UG  delta_UX  delta_TN  delta_TG  delta_TX  \
# 1995-01-01 -14.135714 -0.700000  2.664286 -0.048571 -0.882857 -1.474286
# 1995-01-08  -1.136905  2.339286  1.607143 -5.081548 -4.770833 -4.656548
# 1995-01-15   3.386905  4.077381  3.071429 -0.252381  0.152381  0.314881
# 1995-01-22  -8.434524 -5.452381 -2.910714  2.634524  2.722619  3.062500
# 1995-01-29   2.547619  1.619048  2.476190  3.391667  3.432143  3.376786
#
#             delta_UN_SG9  delta_UG_SG9  delta_UX_SG9  delta_TN_SG9  \
# 1995-01-01    -10.022962      0.020550      2.056846     -2.965223
# 1995-01-08     -6.393306      0.272016      1.693983     -1.225375
# 1995-01-15     -3.356450      0.596529      1.429973      0.047345
# 1995-01-22     -0.761062      0.871014      1.241102      1.384977
# 1995-01-29      0.918831      0.882421      0.999072      2.235841
#
#             delta_TG_SG9  delta_TX_SG9  delta_casualties
# 1995-01-01     -3.409982     -3.738823               NaN
# 1995-01-08     -1.336648     -1.429390               NaN
# 1995-01-15      0.198730      0.289678       -227.291667
# 1995-01-22      1.640616      1.796185       -365.500000
# 1995-01-29      2.472333      2.581496       -298.333333

# %%
# drop rows containing a NaN value
df.dropna(axis=0, how='any', inplace=True) 

# make sure to only have quantitative data and get the numpy array
df = df.astype(np.float32)
X = df.values

# %%
# parameters of dataframe
df.columns
# Out:
# Index(['delta_UN', 'delta_UG', 'delta_UX', 'delta_TN', 'delta_TG', 'delta_TX',
#        'delta_UN_SG9', 'delta_UG_SG9', 'delta_UX_SG9', 'delta_TN_SG9',
#        'delta_TG_SG9', 'delta_TX_SG9', 'delta_casualties'],
#       dtype='object')

# %% [markdown]
# #### documentation
# - Tutorial regarding AirFlights (2018-10-14!) at https://github.com/sevamoo/SOMPY/blob/master/sompy/examples/AirFlights_hexagonal_grid.ipynb
# - Detailed information regarding parameter settings in the docstring: https://github.com/sevamoo/SOMPY/blob/master/sompy/sompy.py#L55:L85

# %%
# train a kohonen network
mapsize = [50, 60]
som = sompy.SOMFactory.build(X, mapsize, mask=None, mapshape='planar', lattice='rect',
                             normalization='var', initialization='pca', neighborhood='gaussian',
                             training='batch', component_names=df.columns, name='sompy')

# verbose='debug' will print detailed information
som.train(n_job=1, verbose='debug')
# Out:
#  Training...
# --------------------------------------------------------------
#  details:
#       > data len is 1261 and data dimension is 13
#       > map size is 50,60
#       > array size in log10 scale is 7.691779693599581
#       > number of jobs in parallel: 1
#  -------------------------------------------------------------
#
#  pca_linear_initialization took: 0.085000 seconds
#  Rough training...
#  radius_ini: 8.000000 , radius_final: 2.000000, trainlen: 72
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 1 ---> elapsed time:  0.276000, quantization error: 1.841804
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 2 ---> elapsed time:  0.312000, quantization error: 1.856882
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 3 ---> elapsed time:  0.283000, quantization error: 1.883175
#
#  find_bmu took: 0.186000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 4 ---> elapsed time:  0.363000, quantization error: 1.893108
#
#  find_bmu took: 0.200000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 5 ---> elapsed time:  0.365000, quantization error: 1.891755
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.031000 seconds
#  epoch: 6 ---> elapsed time:  0.380000, quantization error: 1.886683
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 7 ---> elapsed time:  0.357000, quantization error: 1.879333
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 8 ---> elapsed time:  0.266000, quantization error: 1.870647
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 9 ---> elapsed time:  0.281000, quantization error: 1.861625
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 10 ---> elapsed time:  0.298000, quantization error: 1.852112
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.014000 seconds
#  epoch: 11 ---> elapsed time:  0.382000, quantization error: 1.842111
#
#  find_bmu took: 0.233000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 12 ---> elapsed time:  0.378000, quantization error: 1.831220
#
#  find_bmu took: 0.095000 seconds
#  update_codebook_voronoi took: 0.002000 seconds
#  epoch: 13 ---> elapsed time:  0.230000, quantization error: 1.820887
#
#  find_bmu took: 0.137000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 14 ---> elapsed time:  0.316000, quantization error: 1.811552
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 15 ---> elapsed time:  0.275000, quantization error: 1.802618
#
#  find_bmu took: 0.180000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 16 ---> elapsed time:  0.382000, quantization error: 1.794091
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 17 ---> elapsed time:  0.373000, quantization error: 1.786265
#
#  find_bmu took: 0.200000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 18 ---> elapsed time:  0.371000, quantization error: 1.778603
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 19 ---> elapsed time:  0.273000, quantization error: 1.771445
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 20 ---> elapsed time:  0.285000, quantization error: 1.764020
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 21 ---> elapsed time:  0.278000, quantization error: 1.756785
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 22 ---> elapsed time:  0.284000, quantization error: 1.750117
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.036000 seconds
#  epoch: 23 ---> elapsed time:  0.394000, quantization error: 1.742907
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 24 ---> elapsed time:  0.256000, quantization error: 1.735976
#
#  find_bmu took: 0.231000 seconds
#  update_codebook_voronoi took: 0.011000 seconds
#  epoch: 25 ---> elapsed time:  0.404000, quantization error: 1.728756
#
#  find_bmu took: 0.131000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 26 ---> elapsed time:  0.302000, quantization error: 1.720990
#
#  find_bmu took: 0.200000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 27 ---> elapsed time:  0.384000, quantization error: 1.713829
#
#  find_bmu took: 0.234000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 28 ---> elapsed time:  0.382000, quantization error: 1.706340
#
#  find_bmu took: 0.212000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 29 ---> elapsed time:  0.378000, quantization error: 1.698945
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 30 ---> elapsed time:  0.263000, quantization error: 1.691565
#
#  find_bmu took: 0.200000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 31 ---> elapsed time:  0.384000, quantization error: 1.684119
#
#  find_bmu took: 0.101000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 32 ---> elapsed time:  0.280000, quantization error: 1.676240
#
#  find_bmu took: 0.172000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 33 ---> elapsed time:  0.365000, quantization error: 1.668898
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.018000 seconds
#  epoch: 34 ---> elapsed time:  0.381000, quantization error: 1.661749
#
#  find_bmu took: 0.238000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 35 ---> elapsed time:  0.394000, quantization error: 1.653738
#
#  find_bmu took: 0.218000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 36 ---> elapsed time:  0.454000, quantization error: 1.645499
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 37 ---> elapsed time:  0.381000, quantization error: 1.637684
#
#  find_bmu took: 0.240000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 38 ---> elapsed time:  0.411000, quantization error: 1.629906
#
#  find_bmu took: 0.114000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 39 ---> elapsed time:  0.267000, quantization error: 1.621998
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 40 ---> elapsed time:  0.379000, quantization error: 1.613901
#
#  find_bmu took: 0.145000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 41 ---> elapsed time:  0.285000, quantization error: 1.606029
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 42 ---> elapsed time:  0.380000, quantization error: 1.597243
#
#  find_bmu took: 0.187000 seconds
#  update_codebook_voronoi took: 0.013000 seconds
#  epoch: 43 ---> elapsed time:  0.356000, quantization error: 1.588058
#
#  find_bmu took: 0.204000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 44 ---> elapsed time:  0.399000, quantization error: 1.579127
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 45 ---> elapsed time:  0.371000, quantization error: 1.569651
#
#  find_bmu took: 0.137000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 46 ---> elapsed time:  0.288000, quantization error: 1.560130
#
#  find_bmu took: 0.115000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 47 ---> elapsed time:  0.285000, quantization error: 1.549941
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 48 ---> elapsed time:  0.292000, quantization error: 1.539619
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 49 ---> elapsed time:  0.283000, quantization error: 1.529443
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 50 ---> elapsed time:  0.373000, quantization error: 1.519137
#
#  find_bmu took: 0.182000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 51 ---> elapsed time:  0.357000, quantization error: 1.508542
#
#  find_bmu took: 0.232000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 52 ---> elapsed time:  0.412000, quantization error: 1.497954
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 53 ---> elapsed time:  0.366000, quantization error: 1.487017
#
#  find_bmu took: 0.135000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 54 ---> elapsed time:  0.294000, quantization error: 1.475951
#
#  find_bmu took: 0.172000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 55 ---> elapsed time:  0.357000, quantization error: 1.464548
#
#  find_bmu took: 0.145000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 56 ---> elapsed time:  0.293000, quantization error: 1.452137
#
#  find_bmu took: 0.102000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 57 ---> elapsed time:  0.284000, quantization error: 1.439468
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 58 ---> elapsed time:  0.291000, quantization error: 1.426751
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 59 ---> elapsed time:  0.284000, quantization error: 1.413316
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 60 ---> elapsed time:  0.268000, quantization error: 1.399537
#
#  find_bmu took: 0.088000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 61 ---> elapsed time:  0.263000, quantization error: 1.386071
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 62 ---> elapsed time:  0.301000, quantization error: 1.372177
#
#  find_bmu took: 0.237000 seconds
#  update_codebook_voronoi took: 0.002000 seconds
#  epoch: 63 ---> elapsed time:  0.395000, quantization error: 1.358181
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 64 ---> elapsed time:  0.363000, quantization error: 1.342887
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 65 ---> elapsed time:  0.375000, quantization error: 1.327740
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 66 ---> elapsed time:  0.373000, quantization error: 1.312153
#
#  find_bmu took: 0.140000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 67 ---> elapsed time:  0.281000, quantization error: 1.295951
#
#  find_bmu took: 0.238000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 68 ---> elapsed time:  0.396000, quantization error: 1.279681
#
#  find_bmu took: 0.172000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 69 ---> elapsed time:  0.326000, quantization error: 1.262020
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 70 ---> elapsed time:  0.374000, quantization error: 1.242812
#
#  find_bmu took: 0.200000 seconds
#  update_codebook_voronoi took: 0.037000 seconds
#  epoch: 71 ---> elapsed time:  0.399000, quantization error: 1.223146
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 72 ---> elapsed time:  0.377000, quantization error: 1.202945
#
#  Finetune training...
#  radius_ini: 2.000000 , radius_final: 1.000000, trainlen: 96
#
#  find_bmu took: 0.141000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 1 ---> elapsed time:  0.297000, quantization error: 1.182539
#
#  find_bmu took: 0.128000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 2 ---> elapsed time:  0.283000, quantization error: 1.180301
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 3 ---> elapsed time:  0.278000, quantization error: 1.176817
#
#  find_bmu took: 0.135000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 4 ---> elapsed time:  0.293000, quantization error: 1.173146
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.031000 seconds
#  epoch: 5 ---> elapsed time:  0.383000, quantization error: 1.169747
#
#  find_bmu took: 0.142000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 6 ---> elapsed time:  0.292000, quantization error: 1.166666
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 7 ---> elapsed time:  0.283000, quantization error: 1.164070
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 8 ---> elapsed time:  0.294000, quantization error: 1.161433
#
#  find_bmu took: 0.218000 seconds
#  update_codebook_voronoi took: 0.004000 seconds
#  epoch: 9 ---> elapsed time:  0.397000, quantization error: 1.158804
#
#  find_bmu took: 0.182000 seconds
#  update_codebook_voronoi took: 0.014000 seconds
#  epoch: 10 ---> elapsed time:  0.341000, quantization error: 1.156045
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 11 ---> elapsed time:  0.373000, quantization error: 1.153057
#
#  find_bmu took: 0.200000 seconds
#  update_codebook_voronoi took: 0.012000 seconds
#  epoch: 12 ---> elapsed time:  0.379000, quantization error: 1.149979
#
#  find_bmu took: 0.237000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 13 ---> elapsed time:  0.385000, quantization error: 1.147020
#
#  find_bmu took: 0.172000 seconds
#  update_codebook_voronoi took: 0.014000 seconds
#  epoch: 14 ---> elapsed time:  0.334000, quantization error: 1.144099
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 15 ---> elapsed time:  0.286000, quantization error: 1.141251
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 16 ---> elapsed time:  0.378000, quantization error: 1.138401
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 17 ---> elapsed time:  0.376000, quantization error: 1.135197
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 18 ---> elapsed time:  0.375000, quantization error: 1.131968
#
#  find_bmu took: 0.130000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 19 ---> elapsed time:  0.278000, quantization error: 1.128633
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.014000 seconds
#  epoch: 20 ---> elapsed time:  0.389000, quantization error: 1.125356
#
#  find_bmu took: 0.135000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 21 ---> elapsed time:  0.288000, quantization error: 1.121856
#
#  find_bmu took: 0.212000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 22 ---> elapsed time:  0.366000, quantization error: 1.118691
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 23 ---> elapsed time:  0.262000, quantization error: 1.115613
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 24 ---> elapsed time:  0.298000, quantization error: 1.112548
#
#  find_bmu took: 0.218000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 25 ---> elapsed time:  0.397000, quantization error: 1.109511
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 26 ---> elapsed time:  0.254000, quantization error: 1.106575
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 27 ---> elapsed time:  0.281000, quantization error: 1.103482
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 28 ---> elapsed time:  0.283000, quantization error: 1.100353
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 29 ---> elapsed time:  0.375000, quantization error: 1.096811
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 30 ---> elapsed time:  0.380000, quantization error: 1.093492
#
#  find_bmu took: 0.102000 seconds
#  update_codebook_voronoi took: 0.014000 seconds
#  epoch: 31 ---> elapsed time:  0.297000, quantization error: 1.090014
#
#  find_bmu took: 0.207000 seconds
#  update_codebook_voronoi took: 0.043000 seconds
#  epoch: 32 ---> elapsed time:  0.413000, quantization error: 1.086525
#
#  find_bmu took: 0.100000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 33 ---> elapsed time:  0.258000, quantization error: 1.083043
#
#  find_bmu took: 0.086000 seconds
#  update_codebook_voronoi took: 0.000000 seconds
#  epoch: 34 ---> elapsed time:  0.280000, quantization error: 1.079881
#
#  find_bmu took: 0.100000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 35 ---> elapsed time:  0.283000, quantization error: 1.076471
#
#  find_bmu took: 0.085000 seconds
#  update_codebook_voronoi took: 0.014000 seconds
#  epoch: 36 ---> elapsed time:  0.297000, quantization error: 1.072919
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 37 ---> elapsed time:  0.306000, quantization error: 1.069342
#
#  find_bmu took: 0.226000 seconds
#  update_codebook_voronoi took: 0.003000 seconds
#  epoch: 38 ---> elapsed time:  0.387000, quantization error: 1.065552
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 39 ---> elapsed time:  0.293000, quantization error: 1.061850
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 40 ---> elapsed time:  0.365000, quantization error: 1.058371
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 41 ---> elapsed time:  0.387000, quantization error: 1.054846
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 42 ---> elapsed time:  0.390000, quantization error: 1.051361
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.014000 seconds
#  epoch: 43 ---> elapsed time:  0.388000, quantization error: 1.047649
#
#  find_bmu took: 0.101000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 44 ---> elapsed time:  0.293000, quantization error: 1.044130
#
#  find_bmu took: 0.203000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 45 ---> elapsed time:  0.404000, quantization error: 1.040064
#
#  find_bmu took: 0.101000 seconds
#  update_codebook_voronoi took: 0.018000 seconds
#  epoch: 46 ---> elapsed time:  0.285000, quantization error: 1.036353
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.037000 seconds
#  epoch: 47 ---> elapsed time:  0.420000, quantization error: 1.032456
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 48 ---> elapsed time:  0.277000, quantization error: 1.028494
#
#  find_bmu took: 0.144000 seconds
#  update_codebook_voronoi took: 0.006000 seconds
#  epoch: 49 ---> elapsed time:  0.314000, quantization error: 1.024314
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 50 ---> elapsed time:  0.302000, quantization error: 1.020176
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 51 ---> elapsed time:  0.403000, quantization error: 1.016267
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 52 ---> elapsed time:  0.392000, quantization error: 1.012124
#
#  find_bmu took: 0.095000 seconds
#  update_codebook_voronoi took: 0.003000 seconds
#  epoch: 53 ---> elapsed time:  0.274000, quantization error: 1.007933
#
#  find_bmu took: 0.141000 seconds
#  update_codebook_voronoi took: 0.008000 seconds
#  epoch: 54 ---> elapsed time:  0.340000, quantization error: 1.003372
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 55 ---> elapsed time:  0.403000, quantization error: 0.999031
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 56 ---> elapsed time:  0.297000, quantization error: 0.994531
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.009000 seconds
#  epoch: 57 ---> elapsed time:  0.328000, quantization error: 0.990037
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 58 ---> elapsed time:  0.405000, quantization error: 0.985754
#
#  find_bmu took: 0.134000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 59 ---> elapsed time:  0.304000, quantization error: 0.981249
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 60 ---> elapsed time:  0.405000, quantization error: 0.975922
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.044000 seconds
#  epoch: 61 ---> elapsed time:  0.420000, quantization error: 0.971106
#
#  find_bmu took: 0.200000 seconds
#  update_codebook_voronoi took: 0.031000 seconds
#  epoch: 62 ---> elapsed time:  0.393000, quantization error: 0.966004
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.035000 seconds
#  epoch: 63 ---> elapsed time:  0.419000, quantization error: 0.960950
#
#  find_bmu took: 0.210000 seconds
#  update_codebook_voronoi took: 0.012000 seconds
#  epoch: 64 ---> elapsed time:  0.397000, quantization error: 0.956401
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 65 ---> elapsed time:  0.286000, quantization error: 0.951892
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 66 ---> elapsed time:  0.314000, quantization error: 0.947459
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 67 ---> elapsed time:  0.301000, quantization error: 0.942920
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 68 ---> elapsed time:  0.315000, quantization error: 0.937918
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 69 ---> elapsed time:  0.316000, quantization error: 0.932697
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 70 ---> elapsed time:  0.316000, quantization error: 0.927798
#
#  find_bmu took: 0.172000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 71 ---> elapsed time:  0.399000, quantization error: 0.922744
#
#  find_bmu took: 0.102000 seconds
#  update_codebook_voronoi took: 0.018000 seconds
#  epoch: 72 ---> elapsed time:  0.326000, quantization error: 0.917467
#
#  find_bmu took: 0.203000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 73 ---> elapsed time:  0.429000, quantization error: 0.912367
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.032000 seconds
#  epoch: 74 ---> elapsed time:  0.432000, quantization error: 0.907072
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 75 ---> elapsed time:  0.435000, quantization error: 0.901687
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 76 ---> elapsed time:  0.420000, quantization error: 0.896390
#
#  find_bmu took: 0.227000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 77 ---> elapsed time:  0.454000, quantization error: 0.891101
#
#  find_bmu took: 0.102000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 78 ---> elapsed time:  0.325000, quantization error: 0.885774
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.040000 seconds
#  epoch: 79 ---> elapsed time:  0.461000, quantization error: 0.880531
#
#  find_bmu took: 0.202000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 80 ---> elapsed time:  0.420000, quantization error: 0.875054
#
#  find_bmu took: 0.171000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 81 ---> elapsed time:  0.402000, quantization error: 0.869720
#
#  find_bmu took: 0.102000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 82 ---> elapsed time:  0.323000, quantization error: 0.863677
#
#  find_bmu took: 0.110000 seconds
#  update_codebook_voronoi took: 0.035000 seconds
#  epoch: 83 ---> elapsed time:  0.372000, quantization error: 0.858252
#
#  find_bmu took: 0.129000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 84 ---> elapsed time:  0.345000, quantization error: 0.851995
#
#  find_bmu took: 0.186000 seconds
#  update_codebook_voronoi took: 0.012000 seconds
#  epoch: 85 ---> elapsed time:  0.434000, quantization error: 0.846235
#
#  find_bmu took: 0.138000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 86 ---> elapsed time:  0.348000, quantization error: 0.839943
#
#  find_bmu took: 0.173000 seconds
#  update_codebook_voronoi took: 0.050000 seconds
#  epoch: 87 ---> elapsed time:  0.472000, quantization error: 0.833323
#
#  find_bmu took: 0.245000 seconds
#  update_codebook_voronoi took: 0.008000 seconds
#  epoch: 88 ---> elapsed time:  0.480000, quantization error: 0.826761
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 89 ---> elapsed time:  0.341000, quantization error: 0.820447
#
#  find_bmu took: 0.113000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 90 ---> elapsed time:  0.373000, quantization error: 0.814128
#
#  find_bmu took: 0.231000 seconds
#  update_codebook_voronoi took: 0.013000 seconds
#  epoch: 91 ---> elapsed time:  0.478000, quantization error: 0.807860
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 92 ---> elapsed time:  0.362000, quantization error: 0.800198
#
#  find_bmu took: 0.201000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 93 ---> elapsed time:  0.478000, quantization error: 0.793692
#
#  find_bmu took: 0.106000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 94 ---> elapsed time:  0.347000, quantization error: 0.786702
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 95 ---> elapsed time:  0.367000, quantization error: 0.780060
#
#  find_bmu took: 0.109000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 96 ---> elapsed time:  0.368000, quantization error: 0.773399
#
#  --------------------------------------------------------------
#  Final quantization error: 0.773399
#  train took: 58.367000 seconds

# %%
# show and save the planes
view2D = View2D(25, 25, "rand data", text_size=10)
view2D.show(som, col_sz=5, which_dim="all", denormalize=True)
view2D.save(r'D:\jupyter notebooks\0001.00 Markt/som_codebook.png')
# Out:
# findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0 to DejaVu Sans ('c:\\python35\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf') with score of 0.050000
# findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('c:\\python35\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf') with score of 0.050000

# %%
# compute the umatrix
u = sompy.umatrix.UMatrixView(
    50, 50, 'umatrix', show_axis=True, text_size=8, show_text=True)

# and its values
UMAT = u.build_u_matrix(som, distance=1, row_normalized=False)
UMAT2 = u.show(som, distance2=1, row_normalized=False,
               show_data=True, contooor=False, blob=False)#,
               #filename=r'D:\Projects\Pr\3537.30\2018-09-11 output//u_matrix_all_parameters.png')

# %%
# get the coordinates from the derived network (codebook)
codebook = som._normalizer.denormalize_by(som.data_raw, som.codebook.matrix)
msz = som.codebook.mapsize
cents = som.bmu_ind_to_xy(np.arange(0, msz[0] * msz[1]))

yv = cents[:, 0].astype(int)
xv = cents[:, 1].astype(int)
xyv = cents[:, 2].astype(int)  # coordinates

# %%
# combine the results from the kohonen network with the original data
df_cb = pd.DataFrame(
    data=codebook, columns=df.columns.str.replace('_', ' '))  # keywords)
df_cb['U-matrix'] = UMAT.flatten('C')
df_cb['X'] = xv
df_cb['Y'] = yv
df_cb['XY'] = xyv

# %%
df_cb.head()
# Out:
#     delta UN   delta UG  delta UX  delta TN  delta TG  delta TX  delta UN SG9  \
# 0   6.512618   8.197519  4.735575 -2.935579 -3.239156 -3.041687      6.069999
# 1   7.885153   9.211828  4.592352 -2.620379 -3.177906 -3.164154      6.427242
# 2   9.986617  10.255237  4.173998 -2.099198 -3.086734 -3.480783      6.525632
# 3  12.478279  10.879786  3.674786 -1.624637 -3.241739 -4.216087      6.556555
# 4  14.521505  10.505555  3.372613 -1.305869 -3.303337 -4.776384      7.652915
#
#    delta UG SG9  delta UX SG9  delta TN SG9  delta TG SG9  delta TX SG9  \
# 0      6.491259      4.224931     -0.258946     -0.354012     -0.363858
# 1      6.465421      3.807009     -0.204120     -0.481717     -0.555320
# 2      6.579908      3.529701     -0.343439     -0.881466     -1.047899
# 3      6.604190      3.262813     -0.473633     -1.280095     -1.633320
# 4      6.132996      2.467181     -0.317313     -1.284880     -1.933616
#
#    delta casualties  U-matrix  X  Y  XY
# 0         20.718385  0.365331  0  0   0
# 1        -57.581171  0.427690  1  0   1
# 2       -132.383923  0.438538  2  0   2
# 3       -166.013079  0.455516  3  0   3
# 4       -138.131832  0.466067  4  0   4

# %%
# combine computed key (node location in grid) to the original events
df['som_key'] = som._bmu[0].astype(int)

# %%
df.tail()
# Out:
#              delta_UN   delta_UG  delta_UX  delta_TN  delta_TG  delta_TX  \
# 2018-09-30 -20.482143  -9.202381  0.517857 -5.900000 -2.725000 -0.145833
# 2018-10-07 -12.571428  -5.761905 -1.398810 -0.927976  0.045833  1.289881
# 2018-10-14 -18.988094 -10.565476 -3.559524  2.838691  4.472024  6.855357
# 2018-10-21 -11.505953  -3.589286  2.416667 -0.339881  1.600000  4.097024
# 2018-10-28  -5.761905  -4.291667 -3.470238 -0.291071 -0.151786 -0.848214
#
#             delta_UN_SG9  delta_UG_SG9  delta_UX_SG9  delta_TN_SG9  \
# 2018-09-30    -12.800015     -7.394068     -2.034864     -0.474516
# 2018-10-07    -13.546975     -7.523781     -1.970656     -0.340566
# 2018-10-14    -13.491961     -7.115705     -1.819120     -0.308526
# 2018-10-21    -12.423624     -6.189579     -1.606102     -0.221770
# 2018-10-28     -9.604463     -4.621717     -1.321295      0.305231
#
#             delta_TG_SG9  delta_TX_SG9  delta_casualties  som_key
# 2018-09-30      0.943592      2.404375        194.750000     2631
# 2018-10-07      1.138161      2.713468        263.500000     2632
# 2018-10-14      1.114716      2.631392        192.041672     2993
# 2018-10-21      1.024960      2.320056        157.875000     2570
# 2018-10-28      1.196673      1.933981         42.333332     2623

# %%
# use absolute values of relative humidity and temperature regarding timeseries
df_U_T = pd.read_csv(r"D:\jupyter notebooks\0001.00 Markt\2018-11-16 temp humid.csv", index_col=0)
df_U_T = df_U_T[['UG','TG']]

# %%
# merge with df to get the som_key
df_U_T_key = pd.merge(df, df_U_T, left_index=True, right_index=True)[['UG', 'TG', 'som_key']]
df_U_T_key.columns = ['relative humidity (%)', 'temperature (C)', 'som_key']

# %%
df_U_T_key.head()
# Out:
#             relative humidity (%)  temperature (C)  som_key
# 1995-01-15              91.714286         4.514286     1156
# 1995-01-22              82.714286         6.114286     2713
# 1995-01-29              85.714286         6.442857     2102
# 1995-02-05              87.428571         5.985714     2103
# 1995-02-12              88.285714         6.242857     2043

# %%
# from the codebook only use the delta casualtues (mortality anomaly is a better word, rephrase)
df_MA_key = df_cb[['delta casualties', 'X', 'Y', 'XY']]
df_MA_key.columns = ['mortality_anomaly', 'X','Y','XY']

# %%
df_MA_key.head()
# Out:
#    mortality_anomaly  X  Y  XY
# 0          20.718385  0  0   0
# 1         -57.581171  1  0   1
# 2        -132.383923  2  0   2
# 3        -166.013079  3  0   3
# 4        -138.131832  4  0   4

# %%
# need custom values for legend min/max, figure out whats good
df_U_T_key['temperature (C)'].min()
# Out:
# -7.428571428571429

# %%
df_U_T_key['rh_low'] = 45
df_U_T_key['rh_high'] = 100
df_U_T_key['temp_low'] = -10
df_U_T_key['temp_high'] = 25

# %%
# use json as data_transformers in altair
# info: https://altair-viz.github.io/user_guide/data_transformers.html
#alt.data_transformers.enable('json')
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
# combined super chart
brush = alt.selection(type='interval')

# prepare matrix chart
matrix = alt.Chart(df_MA_key).mark_rect().encode(
    x = alt.X('X:O', scale=alt.Scale(rangeStep=8, paddingInner=0.02)),
    y = alt.Y('Y:O', scale=alt.Scale(rangeStep=8, paddingInner=0.02)),
    opacity = alt.condition(brush, alt.value(1),  alt.value(0.2)),
    color = alt.Color('mortality_anomaly:Q', sort= "descending",
                      scale=alt.Scale(scheme="spectral", domain=[-150,150]), 
                      legend=alt.Legend(title='Mortality Anomaly'))                    
).add_selection(
    brush
)

# prepare base time-series chart (RH and T series)
ts_base = alt.Chart(df_U_T_key.reset_index()).mark_line().encode(
    x='index:T',
    color=alt.value('#000000')
).interactive(bind_y=False).properties(
    width=500,
    height=174
)

# prepare dynamic vertical rules, originate from matrix selection
ts_dynamic = alt.Chart(df_U_T_key.reset_index()).mark_rule().encode(
    x = 'index:T',
    color = alt.Color('MA:Q', sort= "descending",
                    scale=alt.Scale(scheme="spectral", domain=[-150,150])),
    size = alt.value(5)    
).transform_lookup(
    lookup = 'som_key',
    from_ = alt.LookupData(df_MA_key, 'XY'),
    as_ = 't_series'
).transform_calculate(
    "X", "datum.t_series.X"
).transform_calculate(
    "Y", "datum.t_series.Y"
).transform_calculate(
    "MA", "datum.t_series.mortality_anomaly"
).transform_filter(
    brush 
).interactive(bind_y=False).properties(
    width=500,
    height=174
)

# combine prepared charts
chart = matrix | (
    (   ts_dynamic.encode(y=alt.Y('rh_low'), y2='rh_high') +
        ts_base.encode(y=alt.Y('relative humidity (%):Q', 
                               title='relative humidity (%)', 
                               scale=alt.Scale(zero=False)))
        
    ) & 
    (   ts_dynamic.encode(y='temp_low', y2='temp_high') +
        ts_base.encode(y=alt.Y('temperature (C):Q', 
                               title='temperature (C)'))
    )     
)

# %%
chart
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
database = 'demo'
uid = '236ebLIeCDdnKbfGe956IvZetIv1'
#some_url = r"http://localhost/mangrove.ws/entry.asmx/Call?"
url = 'https://tsws.hkvservices.nl/mangrove.ws/'

# %%
import hkvportal

# %%
dp = hkvportal.Service(url, uid)
# Out:
# Init schema document for None
# register_type('{http://www.w3.org/2001/XMLSchema}string', <zeep.xsd.types.builtins.String object at 0x0000000015D64DD8>)
# register_type('{http://www.w3.org/2001/XMLSchema}boolean', <zeep.xsd.types.builtins.Boolean object at 0x0000000016601DA0>)
# register_type('{http://www.w3.org/2001/XMLSchema}decimal', <zeep.xsd.types.builtins.Decimal object at 0x0000000016601C50>)
# register_type('{http://www.w3.org/2001/XMLSchema}float', <zeep.xsd.types.builtins.Float object at 0x0000000017A615F8>)
# register_type('{http://www.w3.org/2001/XMLSchema}double', <zeep.xsd.types.builtins.Double object at 0x0000000015A437B8>)
# register_type('{http://www.w3.org/2001/XMLSchema}duration', <zeep.xsd.types.builtins.Duration object at 0x0000000017A616A0>)
# register_type('{http://www.w3.org/2001/XMLSchema}dateTime', <zeep.xsd.types.builtins.DateTime object at 0x0000000017A615C0>)
# register_type('{http://www.w3.org/2001/XMLSchema}time', <zeep.xsd.types.builtins.Time object at 0x0000000017A61748>)
# register_type('{http://www.w3.org/2001/XMLSchema}date', <zeep.xsd.types.builtins.Date object at 0x0000000017A61668>)
# register_type('{http://www.w3.org/2001/XMLSchema}gYearMonth', <zeep.xsd.types.builtins.gYearMonth object at 0x0000000017A616D8>)
# register_type('{http://www.w3.org/2001/XMLSchema}gYear', <zeep.xsd.types.builtins.gYear object at 0x0000000017A61898>)
# register_type('{http://www.w3.org/2001/XMLSchema}gMonthDay', <zeep.xsd.types.builtins.gMonthDay object at 0x0000000017A61860>)
# register_type('{http://www.w3.org/2001/XMLSchema}gDay', <zeep.xsd.types.builtins.gDay object at 0x0000000017A61908>)
# register_type('{http://www.w3.org/2001/XMLSchema}gMonth', <zeep.xsd.types.builtins.gMonth object at 0x0000000017A61780>)
# register_type('{http://www.w3.org/2001/XMLSchema}hexBinary', <zeep.xsd.types.builtins.HexBinary object at 0x0000000017A61940>)
# register_type('{http://www.w3.org/2001/XMLSchema}base64Binary', <zeep.xsd.types.builtins.Base64Binary object at 0x0000000017A619E8>)
# register_type('{http://www.w3.org/2001/XMLSchema}anyURI', <zeep.xsd.types.builtins.AnyURI object at 0x0000000017A61A20>)
# register_type('{http://www.w3.org/2001/XMLSchema}QName', <zeep.xsd.types.builtins.QName object at 0x0000000017A61A58>)
# register_type('{http://www.w3.org/2001/XMLSchema}NOTATION', <zeep.xsd.types.builtins.Notation object at 0x0000000017A619B0>)
# register_type('{http://www.w3.org/2001/XMLSchema}normalizedString', <zeep.xsd.types.builtins.NormalizedString object at 0x0000000017A61BA8>)
# register_type('{http://www.w3.org/2001/XMLSchema}token', <zeep.xsd.types.builtins.Token object at 0x0000000017A61B38>)
# register_type('{http://www.w3.org/2001/XMLSchema}language', <zeep.xsd.types.builtins.Language object at 0x0000000017A61B70>)
# register_type('{http://www.w3.org/2001/XMLSchema}NMTOKEN', <zeep.xsd.types.builtins.NmToken object at 0x0000000017A61BE0>)
# register_type('{http://www.w3.org/2001/XMLSchema}NMTOKENS', <zeep.xsd.types.builtins.NmTokens object at 0x0000000017A61C18>)
# register_type('{http://www.w3.org/2001/XMLSchema}Name', <zeep.xsd.types.builtins.Name object at 0x0000000017A61C50>)
# register_type('{http://www.w3.org/2001/XMLSchema}NCName', <zeep.xsd.types.builtins.NCName object at 0x0000000017A61C88>)
# register_type('{http://www.w3.org/2001/XMLSchema}ID', <zeep.xsd.types.builtins.ID object at 0x0000000017A61DA0>)
# register_type('{http://www.w3.org/2001/XMLSchema}IDREF', <zeep.xsd.types.builtins.IDREF object at 0x0000000017A61D68>)
# register_type('{http://www.w3.org/2001/XMLSchema}IDREFS', <zeep.xsd.types.builtins.IDREFS object at 0x0000000017A61DD8>)
# register_type('{http://www.w3.org/2001/XMLSchema}ENTITY', <zeep.xsd.types.builtins.Entity object at 0x0000000017A61E80>)
# register_type('{http://www.w3.org/2001/XMLSchema}ENTITIES', <zeep.xsd.types.builtins.Entities object at 0x0000000017A617F0>)
# register_type('{http://www.w3.org/2001/XMLSchema}integer', <zeep.xsd.types.builtins.Integer object at 0x0000000017A61F60>)
# register_type('{http://www.w3.org/2001/XMLSchema}nonPositiveInteger', <zeep.xsd.types.builtins.NonPositiveInteger object at 0x0000000017A61EB8>)
# register_type('{http://www.w3.org/2001/XMLSchema}negativeInteger', <zeep.xsd.types.builtins.NegativeInteger object at 0x00000000182CC0B8>)
# register_type('{http://www.w3.org/2001/XMLSchema}long', <zeep.xsd.types.builtins.Long object at 0x00000000182CC048>)
# register_type('{http://www.w3.org/2001/XMLSchema}int', <zeep.xsd.types.builtins.Int object at 0x00000000182CC080>)
# register_type('{http://www.w3.org/2001/XMLSchema}short', <zeep.xsd.types.builtins.Short object at 0x00000000182CC128>)
# register_type('{http://www.w3.org/2001/XMLSchema}byte', <zeep.xsd.types.builtins.Byte object at 0x00000000182CC208>)
# register_type('{http://www.w3.org/2001/XMLSchema}nonNegativeInteger', <zeep.xsd.types.builtins.NonNegativeInteger object at 0x00000000182CC198>)
# register_type('{http://www.w3.org/2001/XMLSchema}unsignedByte', <zeep.xsd.types.builtins.UnsignedByte object at 0x00000000182CC278>)
# register_type('{http://www.w3.org/2001/XMLSchema}unsignedInt', <zeep.xsd.types.builtins.UnsignedInt object at 0x00000000182CC320>)
# register_type('{http://www.w3.org/2001/XMLSchema}unsignedLong', <zeep.xsd.types.builtins.UnsignedLong object at 0x00000000182CC390>)
# register_type('{http://www.w3.org/2001/XMLSchema}unsignedShort', <zeep.xsd.types.builtins.UnsignedShort object at 0x0000000017A61F98>)
# register_type('{http://www.w3.org/2001/XMLSchema}positiveInteger', <zeep.xsd.types.builtins.PositiveInteger object at 0x00000000182CC358>)
# register_type('{http://www.w3.org/2001/XMLSchema}anyType', <zeep.xsd.types.any.AnyType object at 0x00000000182CC1D0>)
# register_type('{http://www.w3.org/2001/XMLSchema}anySimpleType', <zeep.xsd.types.simple.AnySimpleType object at 0x00000000182CC470>)
# register_element('{http://www.w3.org/2001/XMLSchema}schema', <zeep.xsd.elements.builtins.Schema object at 0x00000000182CC438>)
# Add document with tns http://www.w3.org/2001/XMLSchema to schema 366366504
# Loading remote data from: https://tsws.hkvservices.nl/mangrove.ws/entry.asmx?WSDL
# Starting new HTTPS connection (1): tsws.hkvservices.nl
# https://tsws.hkvservices.nl:443 "GET /mangrove.ws/entry.asmx?WSDL HTTP/1.1" 200 2216
# Creating definition for https://tsws.hkvservices.nl/mangrove.ws/entry.asmx?WSDL
# Init schema document for 'https://tsws.hkvservices.nl/mangrove.ws/entry.asmx?WSDL'
# Add document with tns http://tempuri.org/ to schema 366366504
# register_element('{http://tempuri.org/}Call', <Element(name='Call', type=<zeep.xsd.dynamic_types.Call object at 0x00000000182CCDA0>)>)
# register_element('{http://tempuri.org/}CallResponse', <Element(name='CallResponse', type=<zeep.xsd.dynamic_types.CallResponse object at 0x00000000182D1278>)>)
# register_element('{http://tempuri.org/}Execute', <Element(name='Execute', type=<zeep.xsd.dynamic_types.Execute object at 0x00000000182D1438>)>)
# register_element('{http://tempuri.org/}ExecuteResponse', <Element(name='ExecuteResponse', type=<zeep.xsd.dynamic_types.ExecuteResponse object at 0x00000000182D16D8>)>)
# register_element('{http://tempuri.org/}CallBytes', <Element(name='CallBytes', type=<zeep.xsd.dynamic_types.CallBytes object at 0x00000000182D1780>)>)
# register_element('{http://tempuri.org/}CallBytesResponse', <Element(name='CallBytesResponse', type=<zeep.xsd.dynamic_types.CallBytesResponse object at 0x00000000182D1898>)>)
# register_element('{http://tempuri.org/}ExecuteBytes', <Element(name='ExecuteBytes', type=<zeep.xsd.dynamic_types.ExecuteBytes object at 0x00000000182D1B70>)>)
# register_element('{http://tempuri.org/}ExecuteBytesResponse', <Element(name='ExecuteBytesResponse', type=<zeep.xsd.dynamic_types.ExecuteBytesResponse object at 0x00000000182D1EB8>)>)
# Init schema document for 'https://tsws.hkvservices.nl/mangrove.ws/entry.asmx?WSDL'
# Add document with tns http://tempuri.org/AbstractTypes to schema 366366504
# Ignoring import statement for namespace 'http://schemas.xmlsoap.org/soap/encoding/' (missing schemaLocation)
# Auto importing missing known schema: http://schemas.xmlsoap.org/soap/encoding/
# Loading remote data from: http://schemas.xmlsoap.org/soap/encoding/
# Starting new HTTP connection (1): schemas.xmlsoap.org
# http://schemas.xmlsoap.org:80 "GET /soap/encoding/ HTTP/1.1" 200 3382
# Init schema document for 'http://schemas.xmlsoap.org/soap/encoding/'
# Add document with tns http://schemas.xmlsoap.org/soap/encoding/ to schema 366366504
# register_attribute('{http://schemas.xmlsoap.org/soap/encoding/}root', <Attribute(name='root', type=<UnresolvedCustomType(qname='{http://schemas.xmlsoap.org/soap/encoding/}root', base_type=<UnresolvedType(qname='{http://www.w3.org/2001/XMLSchema}boolean')>)>)>)
# register_attribute_group('{http://schemas.xmlsoap.org/soap/encoding/}commonAttributes', <zeep.xsd.elements.attribute.AttributeGroup object at 0x00000000182DE940>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}arrayCoordinate', <UnresolvedCustomType(qname='{http://schemas.xmlsoap.org/soap/encoding/}arrayCoordinate', base_type=<UnresolvedType(qname='{http://www.w3.org/2001/XMLSchema}string')>)>)
# register_attribute('{http://schemas.xmlsoap.org/soap/encoding/}arrayType', <Attribute(name='arrayType', type=<UnresolvedType(qname='{http://www.w3.org/2001/XMLSchema}string')>)>)
# Auto importing missing known schema: http://schemas.xmlsoap.org/soap/encoding/
# Returning existing schema: 'http://schemas.xmlsoap.org/soap/encoding/'
# register_attribute('{http://schemas.xmlsoap.org/soap/encoding/}offset', <Attribute(name='offset', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}arrayCoordinate')>)>)
# register_attribute_group('{http://schemas.xmlsoap.org/soap/encoding/}arrayAttributes', <zeep.xsd.elements.attribute.AttributeGroup object at 0x00000000182DEEB8>)
# register_attribute('{http://schemas.xmlsoap.org/soap/encoding/}position', <Attribute(name='position', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}arrayCoordinate')>)>)
# register_attribute_group('{http://schemas.xmlsoap.org/soap/encoding/}arrayMemberAttributes', <zeep.xsd.elements.attribute.AttributeGroup object at 0x00000000182DEF28>)
# register_group('{http://schemas.xmlsoap.org/soap/encoding/}Array', <Group(<zeep.xsd.elements.indicators.Group object at 0x00000000182DEE10>)>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}Array', <Element(name='Array', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}Array')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}Array', <zeep.xsd.dynamic_types.Array object at 0x00000000182E82E8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}Struct', <Element(name='Struct', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}Struct')>)>)
# register_group('{http://schemas.xmlsoap.org/soap/encoding/}Struct', <Group(<zeep.xsd.elements.indicators.Group object at 0x00000000182E8518>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}Struct', <zeep.xsd.dynamic_types.Struct object at 0x00000000182E8630>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}base64', <UnresolvedCustomType(qname='{http://schemas.xmlsoap.org/soap/encoding/}base64', base_type=<UnresolvedType(qname='{http://www.w3.org/2001/XMLSchema}base64Binary')>)>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}duration', <Element(name='duration', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}duration')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}duration', <zeep.xsd.dynamic_types.duration object at 0x00000000182E8898>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}dateTime', <Element(name='dateTime', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}dateTime')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}dateTime', <zeep.xsd.dynamic_types.dateTime object at 0x00000000182E89E8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}NOTATION', <Element(name='NOTATION', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}NOTATION')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}NOTATION', <zeep.xsd.dynamic_types.NOTATION object at 0x00000000182E8AC8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}time', <Element(name='time', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}time')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}time', <zeep.xsd.dynamic_types.time object at 0x00000000182E8CF8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}date', <Element(name='date', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}date')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}date', <zeep.xsd.dynamic_types.date object at 0x00000000182E8F28>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}gYearMonth', <Element(name='gYearMonth', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}gYearMonth')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}gYearMonth', <zeep.xsd.dynamic_types.gYearMonth object at 0x00000000182ED048>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}gYear', <Element(name='gYear', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}gYear')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}gYear', <zeep.xsd.dynamic_types.gYear object at 0x00000000182ED278>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}gMonthDay', <Element(name='gMonthDay', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}gMonthDay')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}gMonthDay', <zeep.xsd.dynamic_types.gMonthDay object at 0x00000000182ED3C8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}gDay', <Element(name='gDay', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}gDay')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}gDay', <zeep.xsd.dynamic_types.gDay object at 0x00000000182ED5F8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}gMonth', <Element(name='gMonth', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}gMonth')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}gMonth', <zeep.xsd.dynamic_types.gMonth object at 0x00000000182ED7F0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}boolean', <Element(name='boolean', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}boolean')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}boolean', <zeep.xsd.dynamic_types.boolean object at 0x00000000182EDA58>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}base64Binary', <Element(name='base64Binary', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}base64Binary')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}base64Binary', <zeep.xsd.dynamic_types.base64Binary object at 0x00000000182EDAC8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}hexBinary', <Element(name='hexBinary', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}hexBinary')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}hexBinary', <zeep.xsd.dynamic_types.hexBinary object at 0x00000000182EDCC0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}float', <Element(name='float', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}float')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}float', <zeep.xsd.dynamic_types.float object at 0x00000000182EDE80>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}double', <Element(name='double', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}double')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}double', <zeep.xsd.dynamic_types.double object at 0x00000000182F70B8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}anyURI', <Element(name='anyURI', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}anyURI')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}anyURI', <zeep.xsd.dynamic_types.anyURI object at 0x00000000182F7320>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}QName', <Element(name='QName', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}QName')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}QName', <zeep.xsd.dynamic_types.QName object at 0x00000000182F7550>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}string', <Element(name='string', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}string')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}string', <zeep.xsd.dynamic_types.string object at 0x00000000182F7780>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}normalizedString', <Element(name='normalizedString', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}normalizedString')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}normalizedString', <zeep.xsd.dynamic_types.normalizedString object at 0x00000000182F7978>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}token', <Element(name='token', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}token')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}token', <zeep.xsd.dynamic_types.token object at 0x00000000182F7B70>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}language', <Element(name='language', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}language')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}language', <zeep.xsd.dynamic_types.language object at 0x00000000182F7E10>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}Name', <Element(name='Name', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}Name')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}Name', <zeep.xsd.dynamic_types.Name object at 0x00000000182FE160>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}NMTOKEN', <Element(name='NMTOKEN', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}NMTOKEN')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}NMTOKEN', <zeep.xsd.dynamic_types.NMTOKEN object at 0x00000000182FE320>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}NCName', <Element(name='NCName', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}NCName')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}NCName', <zeep.xsd.dynamic_types.NCName object at 0x00000000182FE5F8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}NMTOKENS', <Element(name='NMTOKENS', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}NMTOKENS')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}NMTOKENS', <zeep.xsd.dynamic_types.NMTOKENS object at 0x00000000182FE898>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}ID', <Element(name='ID', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}ID')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}ID', <zeep.xsd.dynamic_types.ID object at 0x00000000182FEB70>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}IDREF', <Element(name='IDREF', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}IDREF')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}IDREF', <zeep.xsd.dynamic_types.IDREF object at 0x00000000182FEC50>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}ENTITY', <Element(name='ENTITY', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}ENTITY')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}ENTITY', <zeep.xsd.dynamic_types.ENTITY object at 0x0000000018304080>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}IDREFS', <Element(name='IDREFS', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}IDREFS')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}IDREFS', <zeep.xsd.dynamic_types.IDREFS object at 0x0000000018304208>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}ENTITIES', <Element(name='ENTITIES', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}ENTITIES')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}ENTITIES', <zeep.xsd.dynamic_types.ENTITIES object at 0x00000000183044A8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}decimal', <Element(name='decimal', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}decimal')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}decimal', <zeep.xsd.dynamic_types.decimal object at 0x0000000018304860>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}integer', <Element(name='integer', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}integer')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}integer', <zeep.xsd.dynamic_types.integer object at 0x0000000018304B00>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}nonPositiveInteger', <Element(name='nonPositiveInteger', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}nonPositiveInteger')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}nonPositiveInteger', <zeep.xsd.dynamic_types.nonPositiveInteger object at 0x0000000018304D68>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}negativeInteger', <Element(name='negativeInteger', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}negativeInteger')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}negativeInteger', <zeep.xsd.dynamic_types.negativeInteger object at 0x0000000018304EF0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}long', <Element(name='long', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}long')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}long', <zeep.xsd.dynamic_types.long object at 0x000000001830D128>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}int', <Element(name='int', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}int')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}int', <zeep.xsd.dynamic_types.int object at 0x000000001830D550>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}short', <Element(name='short', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}short')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}short', <zeep.xsd.dynamic_types.short object at 0x000000001830D780>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}byte', <Element(name='byte', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}byte')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}byte', <zeep.xsd.dynamic_types.byte object at 0x000000001830DB38>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}nonNegativeInteger', <Element(name='nonNegativeInteger', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}nonNegativeInteger')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}nonNegativeInteger', <zeep.xsd.dynamic_types.nonNegativeInteger object at 0x000000001830DC88>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}unsignedLong', <Element(name='unsignedLong', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}unsignedLong')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}unsignedLong', <zeep.xsd.dynamic_types.unsignedLong object at 0x000000001830DE10>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}unsignedInt', <Element(name='unsignedInt', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}unsignedInt')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}unsignedInt', <zeep.xsd.dynamic_types.unsignedInt object at 0x000000001830DFD0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}unsignedShort', <Element(name='unsignedShort', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}unsignedShort')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}unsignedShort', <zeep.xsd.dynamic_types.unsignedShort object at 0x0000000018311128>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}unsignedByte', <Element(name='unsignedByte', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}unsignedByte')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}unsignedByte', <zeep.xsd.dynamic_types.unsignedByte object at 0x0000000018311320>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}positiveInteger', <Element(name='positiveInteger', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}positiveInteger')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}positiveInteger', <zeep.xsd.dynamic_types.positiveInteger object at 0x00000000183114A8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}anyType', <Element(name='anyType', type=<zeep.xsd.types.any.AnyType object at 0x0000000018311588>)>)
# register_type('{http://tempuri.org/AbstractTypes}StringArray', <zeep.xsd.dynamic_types.StringArray object at 0x00000000182DE320>)
# Resolving in schema <SchemaDocument(location='https://tsws.hkvservices.nl/mangrove.ws/entry.asmx?WSDL', tns='http://tempuri.org/', is_empty=False)>
# Resolving in schema <SchemaDocument(location='https://tsws.hkvservices.nl/mangrove.ws/entry.asmx?WSDL', tns='http://tempuri.org/AbstractTypes', is_empty=False)>
# Resolving in schema <SchemaDocument(location='http://schemas.xmlsoap.org/soap/encoding/', tns='http://schemas.xmlsoap.org/soap/encoding/', is_empty=False)>
# Resolving in schema <SchemaDocument(location='http://schemas.xmlsoap.org/soap/encoding/', tns='http://schemas.xmlsoap.org/soap/encoding/', is_empty=False)>
# Adding message: {http://tempuri.org/}CallSoapIn
# Adding message: {http://tempuri.org/}CallSoapOut
# Adding message: {http://tempuri.org/}ExecuteSoapIn
# Adding message: {http://tempuri.org/}ExecuteSoapOut
# Adding message: {http://tempuri.org/}CallBytesSoapIn
# Adding message: {http://tempuri.org/}CallBytesSoapOut
# Adding message: {http://tempuri.org/}ExecuteBytesSoapIn
# Adding message: {http://tempuri.org/}ExecuteBytesSoapOut
# Adding message: {http://tempuri.org/}CallHttpGetIn
# Adding message: {http://tempuri.org/}CallHttpGetOut
# Adding message: {http://tempuri.org/}ExecuteHttpGetIn
# Adding message: {http://tempuri.org/}ExecuteHttpGetOut
# Adding message: {http://tempuri.org/}CallBytesHttpGetIn
# Adding message: {http://tempuri.org/}CallBytesHttpGetOut
# Adding message: {http://tempuri.org/}ExecuteBytesHttpGetIn
# Adding message: {http://tempuri.org/}ExecuteBytesHttpGetOut
# Adding message: {http://tempuri.org/}CallHttpPostIn
# Adding message: {http://tempuri.org/}CallHttpPostOut
# Adding message: {http://tempuri.org/}ExecuteHttpPostIn
# Adding message: {http://tempuri.org/}ExecuteHttpPostOut
# Adding message: {http://tempuri.org/}CallBytesHttpPostIn
# Adding message: {http://tempuri.org/}CallBytesHttpPostOut
# Adding message: {http://tempuri.org/}ExecuteBytesHttpPostIn
# Adding message: {http://tempuri.org/}ExecuteBytesHttpPostOut
# Adding port: {http://tempuri.org/}entrySoap
# Adding port: {http://tempuri.org/}entryHttpGet
# Adding port: {http://tempuri.org/}entryHttpPost
# Adding binding: {http://tempuri.org/}entrySoap
# Adding binding: {http://tempuri.org/}entrySoap12
# Adding binding: {http://tempuri.org/}entryHttpGet
# Adding binding: {http://tempuri.org/}entryHttpPost
# Adding service: entry
# Dataservice is recognized. https://tsws.hkvservices.nl/mangrove.ws/entry.asmx?WSDL will be used as portal

# %%
dp.new_entry(
    database='hoek',
    key='som_casualties_hittestress',
    data=chart.to_html(),
    description='SOM Casualties Hittestress'
)
# Out:
# HTTP Post to https://tsws.hkvservices.nl/mangrove.ws/entry.asmx:
# <?xml version='1.0' encoding='utf-8'?>
# <soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/"><soap-env:Body><ns0:CallBytes xmlns:ns0="http://tempuri.org/"><ns0:function>dataportal.db.createentry</ns0:function><ns0:parameters>{"uid": "236ebLIeCDdnKbfGe956IvZetIv1", "database": "hoek", "key": "som_casualties_hittestress", "description": "SOM Casualties Hittestress"}</ns0:parameters><ns0:bytes>...</ns0:bytes></ns0:CallBytes></soap-env:Body></soap-env:Envelope>
# https://tsws.hkvservices.nl:443 "POST /mangrove.ws/entry.asmx HTTP/1.1" 200 114
# HTTP Response from https://tsws.hkvservices.nl/mangrove.ws/entry.asmx (status: 200):
# {"id": "222f28f7-4f58-490b-891e-7275cac0c6df", "key": "som_casualties_hittestress", "date": "2019-11-19 11:09:59"}
# entry available at:
# https://tsws.hkvservices.nl/mangrove.ws/data.ashx?function=dataportal.db.getdata&parameters={database:'hoek',key:'som_casualties_hittestress'}&contentType=SET_BY_USER

# %%
ht = chart.to_html()

# %%
ht[0:100]
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n  <style>\n    .vega-actions a {\n        margin-right: 12px;\n        co'

# %%
# original visualisation was in >1000 lines of code in Vega
# can be reduced to ~200 lines of code in Vega-Lite
# and now reduced to 57 lines of code in Altair
