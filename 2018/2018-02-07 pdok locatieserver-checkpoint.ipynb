# %%
import pandas as pd
import requests
from xml.dom import minidom
from shapely.geometry import Point
import re
import time

# %%
# get SUGGEST id from PDOK locatieserver 
def request_pdok_suggest(address_key):
    """
    Get the suggested address id
    """
    url = 'https://geodata.nationaalgeoregister.nl/locatieserver/v3/suggest?wt=xml&q={}'.format(address_key)
    response = requests.get(url)
    # parse xml
    xmldoc = minidom.parseString(response.content)
    str_list = xmldoc.getElementsByTagName('str')
    # get str containing id
    str_tag = str_list[2]
    # get value of id
    id_suggest = str_tag.childNodes[0].nodeValue
    return id_suggest

# %%
def request_pdok_lookup(id_suggest):
    """
    Get the lookup location using the suggeseted address id
    """
    url = 'https://geodata.nationaalgeoregister.nl/locatieserver/v3/lookup?wt=xml&id={}'.format(id_suggest)
    response = requests.get(url)
    xmldoc = minidom.parseString(response.content)
    str_list = xmldoc.getElementsByTagName('str')
    for str_tag in str_list:        
        try:
            str_attr = str_tag.attributes['name'].value
        except: 
            c= 1            
        if str_attr == 'centroide_ll':                
            centroid_id = str_tag.childNodes[0].nodeValue
            centroid_split = re.split('[() ]', centroid_id)
            centroid_point = Point(float(centroid_split[1]), float(centroid_split[1]))
        else:
            continue
        return centroid_point

# %%
path_to_csv = r'D:\Projects\RO\basisonderwijs.csv'
df = pd.read_csv(path_to_csv, encoding='latin-1')

# %%
list_centroids = []
list_address_key = []
for idx, val in df.iterrows():    
    address_key = val['SLEUTEL_CSV']
    print (idx, address_key)
    id_suggest = request_pdok_suggest(address_key)
    centroid_point = request_pdok_lookup(id_suggest)
    
    list_centroids.append(centroid_point)
    list_address_key.append(address_key)
    time.sleep(2)
# Out:
# 0 Oosterstraat 58 7822HG EMMEN
# 1 Bargermeerweg 113 7811LD EMMEN
# 2 Buiskoolstraat 1 7814RC EMMEN
# 3 Middenhaag 4 7815LB EMMEN
# 4 Smedingeslag 1 7824HK EMMEN
# 5 Houtweg 403 7823PS EMMEN
# 6 Barnar 5 A 7826EP EMMEN
# 7 Rolderbrink 128 130 7812PK EMMEN
# 8 Wilhelmsweg 85 A 7814VG EMMEN
# 9 Mantingerbrink 203 7812MD EMMEN
# 10 Eerste Koppelveenweg 2 7881EG EMMER-COMPASCUUM
# 11 Westerdiep OZ 96 7881HG EMMER-COMPASCUUM
# 12 Runde ZZ 84 7881HP EMMER-COMPASCUUM
# 13 Kanaal A NZ 102 7881KL EMMER-COMPASCUUM
# 14 Semsstraat 2 7887AD ERICA
# 15 Horizon 76 7891CV KLAZIENAVEEN
# 16 Voeghoutenstraat 23 7891LA KLAZIENAVEEN
# 17 Derksweg 22 7891PK KLAZIENAVEEN
# 18 Sportlaan 85 7833CH NIEUW-AMSTERDAM
# 19 Walevest 10 7885AK NIEUW-DORDRECHT
# 20 Gedempte Achterdiep 9 7831CJ NIEUW-WEERDINGE
# 21 Roswinkelerstraat 131 7895AR ROSWINKEL
# 22 De Blokken 22 7894CL ZWARTEMEER
# 23 Spanjaardspad 86 7761BR SCHOONEBEEK
# 24 Giervalk 20 7827HX EMMEN
# 195 Bonnerveen 7 A 9511PM GIETERVEEN
# 196 Molenakkers 30 9468BM ANNEN
# 197 't Witzand 22 9463PA EEXT
# 198 Dorpsstraat 54 9658PC EEXTERVEEN
# 199 Molenstraat 3 B 9531CH BORGER
# 200 Schoolstraat 4 9536PN EES
# 201 Schoolstraat 12 9533PL DROUWEN
# 202 Zuiderdiep 3 9521AA NIEUW-BUINEN
# 203 Noorderdiep 129 9521BC NIEUW-BUINEN
# 204 Wilhelminalaan 4 7876HA VALTHERMOND
# 205 Schoolstraat 27 9571CB 2E EXLOERMOND
# 206 Linderakkers 3 7872PM VALTHE
# 207 De Goorns 28 7873AM ODOORN
# 208 Hoofdstraat 62 7875AD EXLOO
# 209 Cavaljeweg 29 7934PJ STUIFZAND
# 210 Stoekeplein 1 7902HM HOOGEVEEN
# 211 Boekenberghstraat 12 7906GA HOOGEVEEN
# 212 De Vink 6 7905HN HOOGEVEEN
# 213 van Leeuwenhoekstraat 85 7908BJ HOOGEVEEN
# 214 Oostering 4 7933PX PESSE
# 215 Booyenverlaat 7 7908EE HOOGEVEEN
# 216 Grote Beer 36 7904LW HOOGEVEEN
# 217 Kerkenkavel 40 7913AT HOLLANDSCHEVELD
# 218
# 219
# 220 De Spil 5 7918AX NIEUWLANDE
# 221 Tilber 9 7908PB HOOGEVEEN
# 222 Floralaan 3 9301KE RODEN
# 223 Witterhoofdweg 1 B 9405HX ASSEN
# 224 Amstelstraat 14 A 9406TH ASSEN
# 225 Prinses Irenestraat 6 9401HH ASSEN
# 226 Bremstraat 14 9404GD ASSEN
# 227 Sluisstraat 139 9406AX ASSEN
# 228 Obrechtlaan 43103 9402TB ASSEN
# 229 Schepersmaat 4 9405TA ASSEN
# 230 Veenwalweg 43227 9407AM ASSEN
# 231 Kleuvenstee 1 9403LT ASSEN
# 232 Tarwehullen 1 9403WD ASSEN
# 233 Schoolstraat 31 9408MB ASSEN
# 234 De Boomgaard 5 9408JA ASSEN
# 235 Splitting 145 7826CT EMMEN
# 236 Zwarte Dijkje 31 7914PB NOORDSCHESCHUT
# 237 Harm Tiesingstraat 2 7815JJ EMMEN
# 238 Kerklaan 26 9564PA ZANDBERG DR
# 239 De Blokken 16 7894CL ZWARTEMEER
# 240 Postweg 131 7884PJ BARGER-COMPASCUUM
# 241 Hoofdkanaal OZ 86 7881CN EMMER-COMPASCUUM
# 242 Tuinstraat 5 E 9404KK ASSEN
# 243 Groote Veen 89 9761DG EELDE
# 244 Omhaal 33 7887CD ERICA
# 245 Echtenstraat 1 9402JA ASSEN
# 246 Geuzingerbrink 74 7812NX EMMEN
# 247 Jhr M W C de Jongestraat 26 7891KN KLAZIENAVEEN
# 248 Houtweg 402 7823PS EMMEN
# 249 Meridiaan 154 7891EK KLAZIENAVEEN
# 250 Boskraai 76 7827JV EMMEN
# 251 Zuiderlaan 197 C 7944EE MEPPEL
# 252 K.P.-laan 20 7943CV MEPPEL
# 253 De Vissersingel 1 7942EA MEPPEL
# 254 Engelgaarde 31 7943LD MEPPEL
# 494 Methardusstraat 43 9853PD MUNNEKEZIJL
# 495 Bernhardlaan 42 9291HP KOLLUM
# 496 Tsjerk Hiddesstraat 4 9291AX KOLLUM
# 497 Skoallestrjitte 14 9298PT KOLLUMERZWAAG
# 498 Raarderwei 8 9156AC BORNWIRD
# 499 Elbasterwei 13 9151KN HOLWERD
# 500 Roptawei 7 9123JA METSLAWIER
# 501 De Skulp 24 9138SJ NIAWIER
# 502 Fennewei 2 9144CX HANTUMHUIZEN
# 503 Kokentun 14 9136PS PAESENS
# 504 Herweystrjitte 49 9145SK TERNAARD
# 505 Langgrousterwei 21 9137RL OOSTERNIJKERK
# 506 De Skeperij 35 9131LE EE
# 507 Mearsloatswal 2 9101DR DOKKUM
# 508 Van Kleffensstraat 5 9101CL DOKKUM
# 509 Kapellaan 5 9101WB DOKKUM
# 510 Kweekschoolstraat 2 9101AC DOKKUM
# 511 Zwaluwstraat 49 9101HE DOKKUM
# 512 De Kampen 39 9132LV ENGWIERUM
# 513 Jannumerwei 4 9175GH REITSUM
# 514 Offingaweg 32 9074AK HALLUM
# 515 Farrewei 16 A 9171LM BLIJE
# 516 De Streek 4 9172NJ FERWERT
# 517 Schoolstraat 10 9111HH BURDAARD
# 518 Ringweg 26 9073HH MARRUM
# 519 Pastoor Schuttestraat 30 8395TN STEGGERDA
# 520 Ljouwertertrekwei 4 9035ED DRONRYP
# 521 Dekamastrjitte 2 B 9011WE JIRNSUM
# 522 Siemen de Jongstrjitte 4 8561DP BALK
# 523 Schritsen 52 8861CV HARLINGEN
# 524 Sanleansterdyk 20 8736JB REAHUS
# 525 Ds. L Touwenlaan 3 8754BP MAKKUM FR
# 526 Pier Panderstraat 3 9203SG DRACHTEN
# 527 Lycklamaweg 14 8471JX WOLVEGA
# 528 De Pit 2 8521PD SINT NICOLAASGA
# 529 Weverswei 4 A 8711GP WORKUM
# 530 Markerstraat 9 8531KM LEMMER
# 531 Tuinen 28 8801VW FRANEKER
# 532 Bramerduinenpad 10 9163KG NES AMELAND
# 533 Uilke Boonstralaan 32 8501EC JOURE
# 534 Van Dekemalaan 2 8442BC HEERENVEEN
# 535 Kapellaan 3 9101WB DOKKUM
# 536 Ageommeleane 14 8574TN BAKHUIZEN
# 537 Dwarswyk 346 9202CA DRACHTEN
# 538 Louw Doniastraat 1 8607AT SNEEK
# 539 Wilhelminastraat 18 8471PK WOLVEGA
# 540 Leeuwarderweg 30 8605AH SNEEK
# 541 Idzerdastins 63 8925AG LEEUWARDEN
# 542
# 543 Van der Looswei 4 8615LV BLAUWHUIS
# 544 Julianalaan 40 8932AB LEEUWARDEN
# 545 De Jister 19 8621DR HEEG
# 546 Melchior Clantstrjitte 18 8551NL WOUDSEND
# 547 Averkampstraat 10 8916EL LEEUWARDEN
# 548 Tjissema 6 9089BG WYTGAARD
# 549 Plein 1455 1 8701EW BOLSWARD
# 550 Dollard 19 9204CK DRACHTEN
# 551 Johan de Walestraat 1 8921XB LEEUWARDEN
# 552 Ds. van Velzenstrjitte 17 9289JB DROGEHAM
# 553 Piterpolle 29 9286EM TWIJZEL
# 554 Goudtsjeblom-strjitte 22 9288AM KOOTSTERTILLE
# 555 Lustenburg 15 9283TJ SURHUIZUM
# 556 W Barteles vd Kooiwei 2 9284TJ AUGUSTINUSGA
# 557 Sarabos 9 A 9873TH GERKESKLOOSTER
# 558 Skoalstrjitte 1 9287LV TWIJZELERHEIDE
# 559 Ikeloane 10 9281RB HARKEMA
# 560 Johan Frisostraat 2 9285TS BUITENPOST
# 561 Badlaan 39 9231AZ SURHUISTERVEEN
# 562 De Merel 43448 9231JJ SURHUISTERVEEN
# 563 Foarwei 23 9113PA WALTERSWALD
# 564 Tjaerdawei 42 A 9105KG RINSUMAGEAST
# 565 Kavelwei 13 A 9108MC BROEKSTERWALD
# 566 Sportloane 2 A 9271VN DE WESTEREEN
# 567 Wyger Martensstrjitte 22 9104JM DAMWALD
# 568 Foarwei 54 9104BX DAMWALD
# 569 De Wylgen 1 9269SN FEANWALDEN
# 570 Paulus Potterstraat 13 B 8471VM WOLVEGA
# 571 Ds Veenweg 10 B 8456HR DE KNIPE
# 572 Laweijstraat 10 8433KG HAULERWIJK
# 573 Aengwirderweg 284 8458BJ TJALLEBERD
# 574 Steegde 29 8426BZ APPELSCHA
# 575 Willem Kroezestraat 6 B 8434NN WASKEMEER
# 576 Heerenveenseweg 36 8471BG WOLVEGA
# 577 Herenweg 108 8435WX DONKERBROEK
# 578 Schoterlandseweg 19 8413NM OUDEHORNE
# 579 Boekhorsterweg 15 8431CW OOSTERWOLDE FR
# 580 Rijweg 59 8431KH OOSTERWOLDE FR

# %%
address_key

# %%
id_ = request_pdok_suggest(address_key)

# %%
response.content

# %%
centroid_id

# %%
point = Point(0.0, 0.0)

# %%
point

# %%
url = 'https://geodata.nationaalgeoregister.nl/locatieserver/v3/suggest?wt=xml&q={}'.format(address_key)
response = requests.get(url)
xmldoc = minidom.parseString(response.content)
str_list = xmldoc.getElementsByTagName('str')
str_tag = str_list[2]
#str_attr = str_tag.attributes['name'].value
id_suggest = str_tag.childNodes[0].nodeValue
# for str_tag in str_list:
#     try:
#         str_attr = str_tag.attributes['name'].value
#     except:
#         next
#     print(str_attr)
#     if str_attr == 'id':                
#         id_suggest = str_tag.childNodes[0].nodeValue
#         print(id_suggest)
#     else:
#         continue

# %%
id_suggest

# %%
#xmldoc = minidom.parse('items.xml')
#itemlist = xmldoc.getElementsByTagName('item')

# %%
print(response.content)

# %%
for atype in tree.findall('id'):
    print(atype)

# %%
for atype in e.findall('type'):
    print(atype.get('foobar'))

# %%
# get SUGGEST id from PDOK locatieserver 
def request_pdok_suggest(address_key):
    url = 'https://geodata.nationaalgeoregister.nl/locatieserver/v3/suggest?wt=xml&q={}'.format(address_key)
    response = requests.get(url)
    tree = ElementTree.fromstring(response.content)    
    return tree

# %%
tree_suggest = request_pdok_suggest(address_key)

# %%
tree_suggest.keys()

# %%
for child in tree_suggest:
    print(child.tag, child.attrib)

# %%
response = requests.get(url)

tree = ElementTree.fromstring(response.content)
