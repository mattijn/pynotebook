# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import sompy
from sompy.visualization.mapview import View2D
import matplotlib.pyplot as plt
from hkvportal.io.services import dataportal
import json
import pandas as pd
from io import StringIO
import glob
import os
# %matplotlib inline

# %%
# And store as well in the HKV DATAPORTAL
dp = dataportal()

# %%
dp.setDataservice(dataservice='https://data.hkvservices.nl/dataservices/')
dp.createDatabase(database='PR2877_20')
# Out:
# Init schema document for None
# register_type('{http://www.w3.org/2001/XMLSchema}string', <zeep.xsd.types.builtins.String object at 0x00000000040CB240>)
# register_type('{http://www.w3.org/2001/XMLSchema}boolean', <zeep.xsd.types.builtins.Boolean object at 0x000000000872F5F8>)
# register_type('{http://www.w3.org/2001/XMLSchema}decimal', <zeep.xsd.types.builtins.Decimal object at 0x000000001C759CF8>)
# register_type('{http://www.w3.org/2001/XMLSchema}float', <zeep.xsd.types.builtins.Float object at 0x000000001C759B70>)
# register_type('{http://www.w3.org/2001/XMLSchema}double', <zeep.xsd.types.builtins.Double object at 0x000000001C759DA0>)
# register_type('{http://www.w3.org/2001/XMLSchema}duration', <zeep.xsd.types.builtins.Duration object at 0x000000001C759D30>)
# register_type('{http://www.w3.org/2001/XMLSchema}dateTime', <zeep.xsd.types.builtins.DateTime object at 0x000000001C759EB8>)
# register_type('{http://www.w3.org/2001/XMLSchema}time', <zeep.xsd.types.builtins.Time object at 0x000000001C759E80>)
# register_type('{http://www.w3.org/2001/XMLSchema}date', <zeep.xsd.types.builtins.Date object at 0x000000001C759E10>)
# register_type('{http://www.w3.org/2001/XMLSchema}gYearMonth', <zeep.xsd.types.builtins.gYearMonth object at 0x000000001C759EF0>)
# register_type('{http://www.w3.org/2001/XMLSchema}gYear', <zeep.xsd.types.builtins.gYear object at 0x000000001C759F60>)
# register_type('{http://www.w3.org/2001/XMLSchema}gMonthDay', <zeep.xsd.types.builtins.gMonthDay object at 0x000000001C770080>)
# register_type('{http://www.w3.org/2001/XMLSchema}gDay', <zeep.xsd.types.builtins.gDay object at 0x000000001C770048>)
# register_type('{http://www.w3.org/2001/XMLSchema}gMonth', <zeep.xsd.types.builtins.gMonth object at 0x000000001C7700B8>)
# register_type('{http://www.w3.org/2001/XMLSchema}hexBinary', <zeep.xsd.types.builtins.HexBinary object at 0x000000001C7700F0>)
# register_type('{http://www.w3.org/2001/XMLSchema}base64Binary', <zeep.xsd.types.builtins.Base64Binary object at 0x000000001C770240>)
# register_type('{http://www.w3.org/2001/XMLSchema}anyURI', <zeep.xsd.types.builtins.AnyURI object at 0x000000001C7701D0>)
# register_type('{http://www.w3.org/2001/XMLSchema}QName', <zeep.xsd.types.builtins.QName object at 0x000000001C770160>)
# register_type('{http://www.w3.org/2001/XMLSchema}NOTATION', <zeep.xsd.types.builtins.Notation object at 0x000000001C7702B0>)
# register_type('{http://www.w3.org/2001/XMLSchema}normalizedString', <zeep.xsd.types.builtins.NormalizedString object at 0x000000001C770358>)
# register_type('{http://www.w3.org/2001/XMLSchema}token', <zeep.xsd.types.builtins.Token object at 0x000000001C7703C8>)
# register_type('{http://www.w3.org/2001/XMLSchema}language', <zeep.xsd.types.builtins.Language object at 0x000000001C770208>)
# register_type('{http://www.w3.org/2001/XMLSchema}NMTOKEN', <zeep.xsd.types.builtins.NmToken object at 0x000000001C770438>)
# register_type('{http://www.w3.org/2001/XMLSchema}NMTOKENS', <zeep.xsd.types.builtins.NmTokens object at 0x000000001C770390>)
# register_type('{http://www.w3.org/2001/XMLSchema}Name', <zeep.xsd.types.builtins.Name object at 0x000000001C770400>)
# register_type('{http://www.w3.org/2001/XMLSchema}NCName', <zeep.xsd.types.builtins.NCName object at 0x000000001C7704E0>)
# register_type('{http://www.w3.org/2001/XMLSchema}ID', <zeep.xsd.types.builtins.ID object at 0x000000001C7705C0>)
# register_type('{http://www.w3.org/2001/XMLSchema}IDREF', <zeep.xsd.types.builtins.IDREF object at 0x000000001C770470>)
# register_type('{http://www.w3.org/2001/XMLSchema}IDREFS', <zeep.xsd.types.builtins.IDREFS object at 0x000000001C7705F8>)
# register_type('{http://www.w3.org/2001/XMLSchema}ENTITY', <zeep.xsd.types.builtins.Entity object at 0x000000001C770630>)
# register_type('{http://www.w3.org/2001/XMLSchema}ENTITIES', <zeep.xsd.types.builtins.Entities object at 0x000000001C770748>)
# register_type('{http://www.w3.org/2001/XMLSchema}integer', <zeep.xsd.types.builtins.Integer object at 0x000000001C7707B8>)
# register_type('{http://www.w3.org/2001/XMLSchema}nonPositiveInteger', <zeep.xsd.types.builtins.NonPositiveInteger object at 0x000000001C7706A0>)
# register_type('{http://www.w3.org/2001/XMLSchema}negativeInteger', <zeep.xsd.types.builtins.NegativeInteger object at 0x000000001C770780>)
# register_type('{http://www.w3.org/2001/XMLSchema}long', <zeep.xsd.types.builtins.Long object at 0x000000001C770908>)
# register_type('{http://www.w3.org/2001/XMLSchema}int', <zeep.xsd.types.builtins.Int object at 0x000000001C770898>)
# register_type('{http://www.w3.org/2001/XMLSchema}short', <zeep.xsd.types.builtins.Short object at 0x000000001C7708D0>)
# register_type('{http://www.w3.org/2001/XMLSchema}byte', <zeep.xsd.types.builtins.Byte object at 0x000000001C770828>)
# register_type('{http://www.w3.org/2001/XMLSchema}nonNegativeInteger', <zeep.xsd.types.builtins.NonNegativeInteger object at 0x000000001C770978>)
# register_type('{http://www.w3.org/2001/XMLSchema}unsignedByte', <zeep.xsd.types.builtins.UnsignedByte object at 0x000000001C770A58>)
# register_type('{http://www.w3.org/2001/XMLSchema}unsignedInt', <zeep.xsd.types.builtins.UnsignedInt object at 0x000000001C7709E8>)
# register_type('{http://www.w3.org/2001/XMLSchema}unsignedLong', <zeep.xsd.types.builtins.UnsignedLong object at 0x000000001C770B00>)
# register_type('{http://www.w3.org/2001/XMLSchema}unsignedShort', <zeep.xsd.types.builtins.UnsignedShort object at 0x000000001C770B70>)
# register_type('{http://www.w3.org/2001/XMLSchema}positiveInteger', <zeep.xsd.types.builtins.PositiveInteger object at 0x000000001C770B38>)
# register_type('{http://www.w3.org/2001/XMLSchema}anyType', <zeep.xsd.types.any.AnyType object at 0x000000001C770BE0>)
# register_type('{http://www.w3.org/2001/XMLSchema}anySimpleType', <zeep.xsd.types.simple.AnySimpleType object at 0x000000001C770C18>)
# register_element('{http://www.w3.org/2001/XMLSchema}schema', <zeep.xsd.elements.builtins.Schema object at 0x000000001C770C50>)
# Add document with tns http://www.w3.org/2001/XMLSchema to schema 477468824
# Starting new HTTPS connection (1): data.hkvservices.nl
# https://data.hkvservices.nl:443 "GET /dataservices/data.asmx?WSDL HTTP/1.1" 200 20460
# Creating definition for https://data.hkvservices.nl/dataservices/data.asmx?WSDL
# Init schema document for 'https://data.hkvservices.nl/dataservices/data.asmx?WSDL'
# Add document with tns http://tempuri.org/ to schema 477468824
# register_element('{http://tempuri.org/}create', <Element(name='create', type=<zeep.xsd.dynamic_types.create object at 0x000000001C77D400>)>)
# register_element('{http://tempuri.org/}createResponse', <Element(name='createResponse', type=<zeep.xsd.dynamic_types.createResponse object at 0x000000001C796400>)>)
# register_element('{http://tempuri.org/}createbytes', <Element(name='createbytes', type=<zeep.xsd.dynamic_types.createbytes object at 0x000000001C7964A8>)>)
# register_element('{http://tempuri.org/}createbytesResponse', <Element(name='createbytesResponse', type=<zeep.xsd.dynamic_types.createbytesResponse object at 0x000000001C796710>)>)
# register_element('{http://tempuri.org/}read', <Element(name='read', type=<zeep.xsd.dynamic_types.read object at 0x000000001C796AC8>)>)
# register_element('{http://tempuri.org/}readResponse', <Element(name='readResponse', type=<zeep.xsd.dynamic_types.readResponse object at 0x000000001C796BE0>)>)
# register_element('{http://tempuri.org/}list', <Element(name='list', type=<zeep.xsd.dynamic_types.list object at 0x000000001C796A20>)>)
# register_element('{http://tempuri.org/}listResponse', <Element(name='listResponse', type=<zeep.xsd.dynamic_types.listResponse object at 0x000000001C796EB8>)>)
# register_element('{http://tempuri.org/}update', <Element(name='update', type=<zeep.xsd.dynamic_types.update object at 0x000000001C796F28>)>)
# register_element('{http://tempuri.org/}updateResponse', <Element(name='updateResponse', type=<zeep.xsd.dynamic_types.updateResponse object at 0x000000001C7AC240>)>)
# register_element('{http://tempuri.org/}delete', <Element(name='delete', type=<zeep.xsd.dynamic_types.delete object at 0x000000001C7AC4E0>)>)
# register_element('{http://tempuri.org/}deleteResponse', <Element(name='deleteResponse', type=<zeep.xsd.dynamic_types.deleteResponse object at 0x000000001C7AC5F8>)>)
# register_element('{http://tempuri.org/}string', <Element(name='string', type=<UnresolvedType(qname='{http://www.w3.org/2001/XMLSchema}string')>)>)
# Init schema document for 'https://data.hkvservices.nl/dataservices/data.asmx?WSDL'
# Add document with tns http://tempuri.org/AbstractTypes to schema 477468824
# Ignoring import statement for namespace 'http://schemas.xmlsoap.org/soap/encoding/' (missing schemaLocation)
# Auto importing missing known schema: http://schemas.xmlsoap.org/soap/encoding/
# Starting new HTTP connection (1): schemas.xmlsoap.org
# http://schemas.xmlsoap.org:80 "GET /soap/encoding/ HTTP/1.1" 200 3382
# Init schema document for 'http://schemas.xmlsoap.org/soap/encoding/'
# Add document with tns http://schemas.xmlsoap.org/soap/encoding/ to schema 477468824
# register_attribute('{http://schemas.xmlsoap.org/soap/encoding/}root', <Attribute(name='root', type=<UnresolvedCustomType(qname='{http://schemas.xmlsoap.org/soap/encoding/}root', base_type=<UnresolvedType(qname='{http://www.w3.org/2001/XMLSchema}boolean')>)>)>)
# register_attribute_group('{http://schemas.xmlsoap.org/soap/encoding/}commonAttributes', <zeep.xsd.elements.attribute.AttributeGroup object at 0x000000001C7ACF98>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}arrayCoordinate', <UnresolvedCustomType(qname='{http://schemas.xmlsoap.org/soap/encoding/}arrayCoordinate', base_type=<UnresolvedType(qname='{http://www.w3.org/2001/XMLSchema}string')>)>)
# register_attribute('{http://schemas.xmlsoap.org/soap/encoding/}arrayType', <Attribute(name='arrayType', type=<UnresolvedType(qname='{http://www.w3.org/2001/XMLSchema}string')>)>)
# Auto importing missing known schema: http://schemas.xmlsoap.org/soap/encoding/
# Returning existing schema: 'http://schemas.xmlsoap.org/soap/encoding/'
# register_attribute('{http://schemas.xmlsoap.org/soap/encoding/}offset', <Attribute(name='offset', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}arrayCoordinate')>)>)
# register_attribute_group('{http://schemas.xmlsoap.org/soap/encoding/}arrayAttributes', <zeep.xsd.elements.attribute.AttributeGroup object at 0x000000001C7B2780>)
# register_attribute('{http://schemas.xmlsoap.org/soap/encoding/}position', <Attribute(name='position', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}arrayCoordinate')>)>)
# register_attribute_group('{http://schemas.xmlsoap.org/soap/encoding/}arrayMemberAttributes', <zeep.xsd.elements.attribute.AttributeGroup object at 0x000000001C7B2898>)
# register_group('{http://schemas.xmlsoap.org/soap/encoding/}Array', <Group(<zeep.xsd.elements.indicators.Group object at 0x000000001C7B27F0>)>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}Array', <Element(name='Array', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}Array')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}Array', <zeep.xsd.dynamic_types.Array object at 0x000000001C7B2B00>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}Struct', <Element(name='Struct', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}Struct')>)>)
# register_group('{http://schemas.xmlsoap.org/soap/encoding/}Struct', <Group(<zeep.xsd.elements.indicators.Group object at 0x000000001C7B2CF8>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}Struct', <zeep.xsd.dynamic_types.Struct object at 0x000000001C7B2E10>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}base64', <UnresolvedCustomType(qname='{http://schemas.xmlsoap.org/soap/encoding/}base64', base_type=<UnresolvedType(qname='{http://www.w3.org/2001/XMLSchema}base64Binary')>)>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}duration', <Element(name='duration', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}duration')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}duration', <zeep.xsd.dynamic_types.duration object at 0x000000001C7BA160>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}dateTime', <Element(name='dateTime', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}dateTime')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}dateTime', <zeep.xsd.dynamic_types.dateTime object at 0x000000001C7BA240>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}NOTATION', <Element(name='NOTATION', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}NOTATION')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}NOTATION', <zeep.xsd.dynamic_types.NOTATION object at 0x000000001C7BA2E8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}time', <Element(name='time', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}time')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}time', <zeep.xsd.dynamic_types.time object at 0x000000001C7BA5C0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}date', <Element(name='date', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}date')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}date', <zeep.xsd.dynamic_types.date object at 0x000000001C7BA828>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}gYearMonth', <Element(name='gYearMonth', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}gYearMonth')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}gYearMonth', <zeep.xsd.dynamic_types.gYearMonth object at 0x000000001C7BA9E8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}gYear', <Element(name='gYear', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}gYear')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}gYear', <zeep.xsd.dynamic_types.gYear object at 0x000000001C7BAB70>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}gMonthDay', <Element(name='gMonthDay', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}gMonthDay')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}gMonthDay', <zeep.xsd.dynamic_types.gMonthDay object at 0x000000001C7BACC0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}gDay', <Element(name='gDay', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}gDay')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}gDay', <zeep.xsd.dynamic_types.gDay object at 0x000000001C7BAFD0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}gMonth', <Element(name='gMonth', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}gMonth')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}gMonth', <zeep.xsd.dynamic_types.gMonth object at 0x000000001C7C01D0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}boolean', <Element(name='boolean', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}boolean')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}boolean', <zeep.xsd.dynamic_types.boolean object at 0x000000001C7C0320>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}base64Binary', <Element(name='base64Binary', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}base64Binary')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}base64Binary', <zeep.xsd.dynamic_types.base64Binary object at 0x000000001C7C0550>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}hexBinary', <Element(name='hexBinary', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}hexBinary')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}hexBinary', <zeep.xsd.dynamic_types.hexBinary object at 0x000000001C7C0630>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}float', <Element(name='float', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}float')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}float', <zeep.xsd.dynamic_types.float object at 0x000000001C7C0860>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}double', <Element(name='double', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}double')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}double', <zeep.xsd.dynamic_types.double object at 0x000000001C7C0AC8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}anyURI', <Element(name='anyURI', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}anyURI')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}anyURI', <zeep.xsd.dynamic_types.anyURI object at 0x000000001C7C0D30>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}QName', <Element(name='QName', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}QName')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}QName', <zeep.xsd.dynamic_types.QName object at 0x000000001C7C0FD0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}string', <Element(name='string', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}string')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}string', <zeep.xsd.dynamic_types.string object at 0x000000001C7C9240>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}normalizedString', <Element(name='normalizedString', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}normalizedString')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}normalizedString', <zeep.xsd.dynamic_types.normalizedString object at 0x000000001C7C9470>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}token', <Element(name='token', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}token')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}token', <zeep.xsd.dynamic_types.token object at 0x000000001C7C95F8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}language', <Element(name='language', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}language')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}language', <zeep.xsd.dynamic_types.language object at 0x000000001C7C9748>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}Name', <Element(name='Name', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}Name')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}Name', <zeep.xsd.dynamic_types.Name object at 0x000000001C7C9A20>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}NMTOKEN', <Element(name='NMTOKEN', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}NMTOKEN')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}NMTOKEN', <zeep.xsd.dynamic_types.NMTOKEN object at 0x000000001C7C9C18>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}NCName', <Element(name='NCName', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}NCName')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}NCName', <zeep.xsd.dynamic_types.NCName object at 0x000000001C7C9E80>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}NMTOKENS', <Element(name='NMTOKENS', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}NMTOKENS')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}NMTOKENS', <zeep.xsd.dynamic_types.NMTOKENS object at 0x000000001C7C9F98>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}ID', <Element(name='ID', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}ID')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}ID', <zeep.xsd.dynamic_types.ID object at 0x000000001C7CD2E8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}IDREF', <Element(name='IDREF', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}IDREF')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}IDREF', <zeep.xsd.dynamic_types.IDREF object at 0x000000001C7CD4E0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}ENTITY', <Element(name='ENTITY', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}ENTITY')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}ENTITY', <zeep.xsd.dynamic_types.ENTITY object at 0x000000001C7CD748>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}IDREFS', <Element(name='IDREFS', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}IDREFS')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}IDREFS', <zeep.xsd.dynamic_types.IDREFS object at 0x000000001C7CD9B0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}ENTITIES', <Element(name='ENTITIES', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}ENTITIES')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}ENTITIES', <zeep.xsd.dynamic_types.ENTITIES object at 0x000000001C7CDB00>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}decimal', <Element(name='decimal', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}decimal')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}decimal', <zeep.xsd.dynamic_types.decimal object at 0x000000001C7CDD68>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}integer', <Element(name='integer', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}integer')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}integer', <zeep.xsd.dynamic_types.integer object at 0x000000001C7CDFD0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}nonPositiveInteger', <Element(name='nonPositiveInteger', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}nonPositiveInteger')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}nonPositiveInteger', <zeep.xsd.dynamic_types.nonPositiveInteger object at 0x000000001C7D6160>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}negativeInteger', <Element(name='negativeInteger', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}negativeInteger')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}negativeInteger', <zeep.xsd.dynamic_types.negativeInteger object at 0x000000001C7D62B0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}long', <Element(name='long', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}long')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}long', <zeep.xsd.dynamic_types.long object at 0x000000001C7D6588>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}int', <Element(name='int', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}int')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}int', <zeep.xsd.dynamic_types.int object at 0x000000001C7D67F0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}short', <Element(name='short', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}short')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}short', <zeep.xsd.dynamic_types.short object at 0x000000001C7D69E8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}byte', <Element(name='byte', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}byte')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}byte', <zeep.xsd.dynamic_types.byte object at 0x000000001C7D6C88>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}nonNegativeInteger', <Element(name='nonNegativeInteger', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}nonNegativeInteger')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}nonNegativeInteger', <zeep.xsd.dynamic_types.nonNegativeInteger object at 0x000000001C7D6DD8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}unsignedLong', <Element(name='unsignedLong', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}unsignedLong')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}unsignedLong', <zeep.xsd.dynamic_types.unsignedLong object at 0x000000001C7D6F60>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}unsignedInt', <Element(name='unsignedInt', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}unsignedInt')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}unsignedInt', <zeep.xsd.dynamic_types.unsignedInt object at 0x000000001C7E00B8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}unsignedShort', <Element(name='unsignedShort', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}unsignedShort')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}unsignedShort', <zeep.xsd.dynamic_types.unsignedShort object at 0x000000001C7E01D0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}unsignedByte', <Element(name='unsignedByte', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}unsignedByte')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}unsignedByte', <zeep.xsd.dynamic_types.unsignedByte object at 0x000000001C7E03C8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}positiveInteger', <Element(name='positiveInteger', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}positiveInteger')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}positiveInteger', <zeep.xsd.dynamic_types.positiveInteger object at 0x000000001C7E04A8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}anyType', <Element(name='anyType', type=<zeep.xsd.types.any.AnyType object at 0x000000001C7E04E0>)>)
# register_type('{http://tempuri.org/AbstractTypes}StringArray', <zeep.xsd.dynamic_types.StringArray object at 0x000000001C7ACE10>)
# Resolving in schema <SchemaDocument(location='https://data.hkvservices.nl/dataservices/data.asmx?WSDL', tns='http://tempuri.org/', is_empty=False)>
# Resolving in schema <SchemaDocument(location='https://data.hkvservices.nl/dataservices/data.asmx?WSDL', tns='http://tempuri.org/AbstractTypes', is_empty=False)>
# Resolving in schema <SchemaDocument(location='http://schemas.xmlsoap.org/soap/encoding/', tns='http://schemas.xmlsoap.org/soap/encoding/', is_empty=False)>
# Resolving in schema <SchemaDocument(location='http://schemas.xmlsoap.org/soap/encoding/', tns='http://schemas.xmlsoap.org/soap/encoding/', is_empty=False)>
# Adding message: {http://tempuri.org/}createSoapIn
# Adding message: {http://tempuri.org/}createSoapOut
# Adding message: {http://tempuri.org/}createbytesSoapIn
# Adding message: {http://tempuri.org/}createbytesSoapOut
# Adding message: {http://tempuri.org/}readSoapIn
# Adding message: {http://tempuri.org/}readSoapOut
# Adding message: {http://tempuri.org/}listSoapIn
# Adding message: {http://tempuri.org/}listSoapOut
# Adding message: {http://tempuri.org/}updateSoapIn
# Adding message: {http://tempuri.org/}updateSoapOut
# Adding message: {http://tempuri.org/}deleteSoapIn
# Adding message: {http://tempuri.org/}deleteSoapOut
# Adding message: {http://tempuri.org/}createHttpGetIn
# Adding message: {http://tempuri.org/}createHttpGetOut
# Adding message: {http://tempuri.org/}createbytesHttpGetIn
# Adding message: {http://tempuri.org/}createbytesHttpGetOut
# Adding message: {http://tempuri.org/}readHttpGetIn
# Adding message: {http://tempuri.org/}readHttpGetOut
# Adding message: {http://tempuri.org/}listHttpGetIn
# Adding message: {http://tempuri.org/}listHttpGetOut
# Adding message: {http://tempuri.org/}updateHttpGetIn
# Adding message: {http://tempuri.org/}updateHttpGetOut
# Adding message: {http://tempuri.org/}deleteHttpGetIn
# Adding message: {http://tempuri.org/}deleteHttpGetOut
# Adding message: {http://tempuri.org/}createHttpPostIn
# Adding message: {http://tempuri.org/}createHttpPostOut
# Adding message: {http://tempuri.org/}createbytesHttpPostIn
# Adding message: {http://tempuri.org/}createbytesHttpPostOut
# Adding message: {http://tempuri.org/}readHttpPostIn
# Adding message: {http://tempuri.org/}readHttpPostOut
# Adding message: {http://tempuri.org/}listHttpPostIn
# Adding message: {http://tempuri.org/}listHttpPostOut
# Adding message: {http://tempuri.org/}updateHttpPostIn
# Adding message: {http://tempuri.org/}updateHttpPostOut
# Adding message: {http://tempuri.org/}deleteHttpPostIn
# Adding message: {http://tempuri.org/}deleteHttpPostOut
# Adding port: {http://tempuri.org/}dataSoap
# Adding port: {http://tempuri.org/}dataHttpGet
# Adding port: {http://tempuri.org/}dataHttpPost
# Adding binding: {http://tempuri.org/}dataSoap
# Adding binding: {http://tempuri.org/}dataSoap12
# Adding binding: {http://tempuri.org/}dataHttpGet
# Adding binding: {http://tempuri.org/}dataHttpPost
# Adding service: data
# Starting new HTTPS connection (1): data.hkvservices.nl
# https://data.hkvservices.nl:443 "GET /dataservices/database.asmx/create?database=PR2877_20 HTTP/1.1" 200 46
# dataservice is set. https://data.hkvservices.nl/dataservices/ will be used as portal
# {'exception': 'database name already exists'}

# %%
folder_in = r'D:\Projects\Pr\2877.20\resultaten\json'

# %%
spec = glob.glob('{}//centerpoints_transect.geojson'.format(folder_in))[0]

# %%
spec
# Out:
# 'D:\\Projects\\Pr\\2877.20\\resultaten\\json//centerpoints_transect.geojson'

# %%
# load the vega spec
vega_spec = json.load(open(spec))

# %%
dp.setEntryDatabase(database='PR2877_20', key='transect_centerpoint',
                    data=json.dumps(vega_spec), description='Centerpoint Outline')
# Out:
# HTTP Post to https://data.hkvservices.nl/dataservices/data.asmx:
# <?xml version='1.0' encoding='utf-8'?>
# <soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
#   <soap-env:Body>
#     <ns0:create xmlns:ns0="http://tempuri.org/">
#       <ns0:database>PR2877_20</ns0:database>
#       <ns0:key>transect_centerpoint</ns0:key>
#       <ns0:description>Centerpoint Outline</ns0:description>
#       <ns0:data>[{"lat": 52.77338775222117, "profieltype": "P1", "lon": 4.657291378813992}, {"lat": 52.768332075150155, "profieltype": "P2N", "lon": 4.65533583169991}, {"lat": 52.761802639095144, "profieltype": "P3N", "lon": 4.651258144639883}, {"lat": 52.75018525211387, "profieltype": "P4", "lon": 4.645911322807939}, {"lat": 52.73660178650772, "profieltype": "P3Z", "lon": 4.641245637858741}, {"lat": 52.72868634477473, "profieltype": "P2Z", "lon": 4.639562988809997}]</ns0:data>
#     </ns0:create>
#   </soap-env:Body>
# </soap-env:Envelope>
#
# Resetting dropped connection: data.hkvservices.nl
# https://data.hkvservices.nl:443 "POST /dataservices/data.asmx HTTP/1.1" 200 444
# HTTP Response from https://data.hkvservices.nl/dataservices/data.asmx (status: 200):
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><createResponse xmlns="http://tempuri.org/"><createResult>{"id": "78fc9502-d2e2-4e43-821c-35b4659567b1", "key": "transect_centerpoint", "date": "2018-05-07 15:24:26"}</createResult></createResponse></soap:Body></soap:Envelope>
# {'date': '2018-05-07 15:24:26',
#  'id': '78fc9502-d2e2-4e43-821c-35b4659567b1',
#  'key': 'transect_centerpoint'}

# %%
for spec in specs:    
    key = os.path.basename(spec).split('.')[0]
    print(key)
    
    # load the vega spec
    vega_spec = json.load(open(spec))
    # json data uploaden naar data portal
    dp.setEntryDatabase(database='PR2877_20', key='vega_spec_{}'.format(key),
                        data=json.dumps(vega_spec), description='Vega Specification for {}'.format(key))
# Out:
# HTTP Post to https://data.hkvservices.nl/dataservices/data.asmx:
# <?xml version='1.0' encoding='utf-8'?>
# <soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
#   <soap-env:Body>
#     <ns0:create xmlns:ns0="http://tempuri.org/">
#       <ns0:database>PR2877_20</ns0:database>
#       <ns0:key>vega_spec_T1T2</ns0:key>
#       <ns0:description>Vega Specification for T1T2</ns0:description>
#       <ns0:data>{"legends": [{"fill": "color", "type": "gradient", "encode": {"title": {"update": {"fontSize": {"value": 14}, "limit": {"value": 400}}}}, "title": {"signal": "variable"}}], "layout": {"bounds": "full", "columns": 2, "align": "none", "padding": {"column": 10, "row": 10}, "offset": 10}, "title": {"text": "T1T2 - A self-organizing map of Hondsbossche Dunes using variables representing the geographical characteristics of their growth", "orient": "top", "anchor": "start"}, "scales": [{"name": "size", "range": [50, 1500], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}}, {"range": ["#3D3D3D", "#F0F8FF", "cornflowerblue", "mediumseagreen", "#FFEE00", "darkorange", "firebrick"], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}, "type": "sequential", "nice": false, "name": "color", "zero": false}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_x_step"}}, "domain": {"sort": true, "field": "X", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_x"}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_y_step"}}, "domain": {"sort": true, "field": "Y", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_y"}], "config": {"axisY": {"minExtent": 30}, "style": {"text": {"baseline": "middle"}}, "title": {"fontSize": 18, "offset": 10}, "legend": {"orient": "bottom", "offset": 30}}, "marks": [{"style": "cell", "marks": [{"name": "brush_brush_bg", "clip": true, "encode": {"enter": {"fill": {"value": "#333"}, "fillOpacity": {"value": 0.125}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}, {"style": ["rect"], "name": "matrix_layer_marks", "encode": {"update": {"y": {"field": "Y", "scale": "matrix_y"}, "fillOpacity": [{"value": 1, "test": "!(length(data(\"brush_store\"))) || (vlInterval(\"brush_store\", datum))"}, {"value": 0.25}], "x": {"field": "X", "scale": "matrix_x"}, "stroke": {"value": "white"}, "fill": {"field": {"signal": "variable"}, "scale": "color"}, "width": {"band": 1, "scale": "matrix_x", "offset": -0.25}, "strokeWidth": {"value": 0.25}, "height": {"band": 1, "scale": "matrix_y", "offset": -0.25}}, "hover": {"stroke": {"value": "#000"}, "strokeWidth": {"value": 2}}}, "from": {"data": "matrix_data"}, "type": "rect"}, {"name": "brush_brush", "clip": true, "encode": {"enter": {"fill": {"value": "transparent"}, "stroke": {"value": "white"}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}], "encode": {"update": {"width": {"signal": "matrix_width"}, "y": {"signal": "matrix_y"}, "x": {"signal": "matrix_x"}, "height": {"signal": "matrix_height"}}}, "title": {"text": "matrix element: create box to filter locations", "orient": "bottom", "anchor": "start"}, "name": "matrix_group", "type": "group", "axes": [{"tickCount": 5, "lab ...
#     </ns0:create>
#   </soap-env:Body>
# </soap-env:Envelope>
# T1T2
# https://data.hkvservices.nl:443 "POST /dataservices/data.asmx HTTP/1.1" 200 438
# HTTP Response from https://data.hkvservices.nl/dataservices/data.asmx (status: 200):
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><createResponse xmlns="http://tempuri.org/"><createResult>{"id": "bd0b0de0-d472-4fdc-8088-9d838123272b", "key": "vega_spec_T1T2", "date": "2018-05-04 14:56:09"}</createResult></createResponse></soap:Body></soap:Envelope>
# HTTP Post to https://data.hkvservices.nl/dataservices/data.asmx:
# <?xml version='1.0' encoding='utf-8'?>
# <soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
#   <soap-env:Body>
#     <ns0:create xmlns:ns0="http://tempuri.org/">
#       <ns0:database>PR2877_20</ns0:database>
#       <ns0:key>vega_spec_T1T9</ns0:key>
#       <ns0:description>Vega Specification for T1T9</ns0:description>
#       <ns0:data>{"legends": [{"fill": "color", "type": "gradient", "encode": {"title": {"update": {"fontSize": {"value": 14}, "limit": {"value": 400}}}}, "title": {"signal": "variable"}}], "layout": {"bounds": "full", "columns": 2, "align": "none", "padding": {"column": 10, "row": 10}, "offset": 10}, "title": {"text": "T1T9 - A self-organizing map of Hondsbossche Dunes using variables representing the geographical characteristics of their growth", "orient": "top", "anchor": "start"}, "scales": [{"name": "size", "range": [50, 1500], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}}, {"range": ["#3D3D3D", "#F0F8FF", "cornflowerblue", "mediumseagreen", "#FFEE00", "darkorange", "firebrick"], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}, "type": "sequential", "nice": false, "name": "color", "zero": false}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_x_step"}}, "domain": {"sort": true, "field": "X", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_x"}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_y_step"}}, "domain": {"sort": true, "field": "Y", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_y"}], "config": {"axisY": {"minExtent": 30}, "style": {"text": {"baseline": "middle"}}, "title": {"fontSize": 18, "offset": 10}, "legend": {"orient": "bottom", "offset": 30}}, "marks": [{"style": "cell", "marks": [{"name": "brush_brush_bg", "clip": true, "encode": {"enter": {"fill": {"value": "#333"}, "fillOpacity": {"value": 0.125}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}, {"style": ["rect"], "name": "matrix_layer_marks", "encode": {"update": {"y": {"field": "Y", "scale": "matrix_y"}, "fillOpacity": [{"value": 1, "test": "!(length(data(\"brush_store\"))) || (vlInterval(\"brush_store\", datum))"}, {"value": 0.25}], "x": {"field": "X", "scale": "matrix_x"}, "stroke": {"value": "white"}, "fill": {"field": {"signal": "variable"}, "scale": "color"}, "width": {"band": 1, "scale": "matrix_x", "offset": -0.25}, "strokeWidth": {"value": 0.25}, "height": {"band": 1, "scale": "matrix_y", "offset": -0.25}}, "hover": {"stroke": {"value": "#000"}, "strokeWidth": {"value": 2}}}, "from": {"data": "matrix_data"}, "type": "rect"}, {"name": "brush_brush", "clip": true, "encode": {"enter": {"fill": {"value": "transparent"}, "stroke": {"value": "white"}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}], "encode": {"update": {"width": {"signal": "matrix_width"}, "y": {"signal": "matrix_y"}, "x": {"signal": "matrix_x"}, "height": {"signal": "matrix_height"}}}, "title": {"text": "matrix element: create box to filter locations", "orient": "bottom", "anchor": "start"}, "name": "matrix_group", "type": "group", "axes": [{"tickCount": 5, "lab ...
#     </ns0:create>
#   </soap-env:Body>
# </soap-env:Envelope>
# T1T9
# https://data.hkvservices.nl:443 "POST /dataservices/data.asmx HTTP/1.1" 200 438
# HTTP Response from https://data.hkvservices.nl/dataservices/data.asmx (status: 200):
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><createResponse xmlns="http://tempuri.org/"><createResult>{"id": "25f0dba3-0cb5-4ff4-bee9-bc2389aa0e04", "key": "vega_spec_T1T9", "date": "2018-05-04 14:56:10"}</createResult></createResponse></soap:Body></soap:Envelope>
# HTTP Post to https://data.hkvservices.nl/dataservices/data.asmx:
# <?xml version='1.0' encoding='utf-8'?>
# <soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
#   <soap-env:Body>
#     <ns0:create xmlns:ns0="http://tempuri.org/">
#       <ns0:database>PR2877_20</ns0:database>
#       <ns0:key>vega_spec_T2T3</ns0:key>
#       <ns0:description>Vega Specification for T2T3</ns0:description>
#       <ns0:data>{"legends": [{"fill": "color", "type": "gradient", "encode": {"title": {"update": {"fontSize": {"value": 14}, "limit": {"value": 400}}}}, "title": {"signal": "variable"}}], "layout": {"bounds": "full", "columns": 2, "align": "none", "padding": {"column": 10, "row": 10}, "offset": 10}, "title": {"text": "T2T3 - A self-organizing map of Hondsbossche Dunes using variables representing the geographical characteristics of their growth", "orient": "top", "anchor": "start"}, "scales": [{"name": "size", "range": [50, 1500], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}}, {"range": ["#3D3D3D", "#F0F8FF", "cornflowerblue", "mediumseagreen", "#FFEE00", "darkorange", "firebrick"], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}, "type": "sequential", "nice": false, "name": "color", "zero": false}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_x_step"}}, "domain": {"sort": true, "field": "X", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_x"}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_y_step"}}, "domain": {"sort": true, "field": "Y", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_y"}], "config": {"axisY": {"minExtent": 30}, "style": {"text": {"baseline": "middle"}}, "title": {"fontSize": 18, "offset": 10}, "legend": {"orient": "bottom", "offset": 30}}, "marks": [{"style": "cell", "marks": [{"name": "brush_brush_bg", "clip": true, "encode": {"enter": {"fill": {"value": "#333"}, "fillOpacity": {"value": 0.125}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}, {"style": ["rect"], "name": "matrix_layer_marks", "encode": {"update": {"y": {"field": "Y", "scale": "matrix_y"}, "fillOpacity": [{"value": 1, "test": "!(length(data(\"brush_store\"))) || (vlInterval(\"brush_store\", datum))"}, {"value": 0.25}], "x": {"field": "X", "scale": "matrix_x"}, "stroke": {"value": "white"}, "fill": {"field": {"signal": "variable"}, "scale": "color"}, "width": {"band": 1, "scale": "matrix_x", "offset": -0.25}, "strokeWidth": {"value": 0.25}, "height": {"band": 1, "scale": "matrix_y", "offset": -0.25}}, "hover": {"stroke": {"value": "#000"}, "strokeWidth": {"value": 2}}}, "from": {"data": "matrix_data"}, "type": "rect"}, {"name": "brush_brush", "clip": true, "encode": {"enter": {"fill": {"value": "transparent"}, "stroke": {"value": "white"}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}], "encode": {"update": {"width": {"signal": "matrix_width"}, "y": {"signal": "matrix_y"}, "x": {"signal": "matrix_x"}, "height": {"signal": "matrix_height"}}}, "title": {"text": "matrix element: create box to filter locations", "orient": "bottom", "anchor": "start"}, "name": "matrix_group", "type": "group", "axes": [{"tickCount": 5, "lab ...
#     </ns0:create>
#   </soap-env:Body>
# </soap-env:Envelope>
# T2T3
# https://data.hkvservices.nl:443 "POST /dataservices/data.asmx HTTP/1.1" 200 438
# HTTP Response from https://data.hkvservices.nl/dataservices/data.asmx (status: 200):
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><createResponse xmlns="http://tempuri.org/"><createResult>{"id": "5d469ebf-87ad-48db-b97b-8a521d54cf2c", "key": "vega_spec_T2T3", "date": "2018-05-04 14:56:10"}</createResult></createResponse></soap:Body></soap:Envelope>
# HTTP Post to https://data.hkvservices.nl/dataservices/data.asmx:
# <?xml version='1.0' encoding='utf-8'?>
# <soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
#   <soap-env:Body>
#     <ns0:create xmlns:ns0="http://tempuri.org/">
#       <ns0:database>PR2877_20</ns0:database>
#       <ns0:key>vega_spec_T3T4</ns0:key>
#       <ns0:description>Vega Specification for T3T4</ns0:description>
#       <ns0:data>{"legends": [{"fill": "color", "type": "gradient", "encode": {"title": {"update": {"fontSize": {"value": 14}, "limit": {"value": 400}}}}, "title": {"signal": "variable"}}], "layout": {"bounds": "full", "columns": 2, "align": "none", "padding": {"column": 10, "row": 10}, "offset": 10}, "title": {"text": "T3T4 - A self-organizing map of Hondsbossche Dunes using variables representing the geographical characteristics of their growth", "orient": "top", "anchor": "start"}, "scales": [{"name": "size", "range": [50, 1500], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}}, {"range": ["#3D3D3D", "#F0F8FF", "cornflowerblue", "mediumseagreen", "#FFEE00", "darkorange", "firebrick"], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}, "type": "sequential", "nice": false, "name": "color", "zero": false}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_x_step"}}, "domain": {"sort": true, "field": "X", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_x"}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_y_step"}}, "domain": {"sort": true, "field": "Y", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_y"}], "config": {"axisY": {"minExtent": 30}, "style": {"text": {"baseline": "middle"}}, "title": {"fontSize": 18, "offset": 10}, "legend": {"orient": "bottom", "offset": 30}}, "marks": [{"style": "cell", "marks": [{"name": "brush_brush_bg", "clip": true, "encode": {"enter": {"fill": {"value": "#333"}, "fillOpacity": {"value": 0.125}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}, {"style": ["rect"], "name": "matrix_layer_marks", "encode": {"update": {"y": {"field": "Y", "scale": "matrix_y"}, "fillOpacity": [{"value": 1, "test": "!(length(data(\"brush_store\"))) || (vlInterval(\"brush_store\", datum))"}, {"value": 0.25}], "x": {"field": "X", "scale": "matrix_x"}, "stroke": {"value": "white"}, "fill": {"field": {"signal": "variable"}, "scale": "color"}, "width": {"band": 1, "scale": "matrix_x", "offset": -0.25}, "strokeWidth": {"value": 0.25}, "height": {"band": 1, "scale": "matrix_y", "offset": -0.25}}, "hover": {"stroke": {"value": "#000"}, "strokeWidth": {"value": 2}}}, "from": {"data": "matrix_data"}, "type": "rect"}, {"name": "brush_brush", "clip": true, "encode": {"enter": {"fill": {"value": "transparent"}, "stroke": {"value": "white"}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}], "encode": {"update": {"width": {"signal": "matrix_width"}, "y": {"signal": "matrix_y"}, "x": {"signal": "matrix_x"}, "height": {"signal": "matrix_height"}}}, "title": {"text": "matrix element: create box to filter locations", "orient": "bottom", "anchor": "start"}, "name": "matrix_group", "type": "group", "axes": [{"tickCount": 5, "lab ...
#     </ns0:create>
#   </soap-env:Body>
# </soap-env:Envelope>
# T3T4
# https://data.hkvservices.nl:443 "POST /dataservices/data.asmx HTTP/1.1" 200 438
# HTTP Response from https://data.hkvservices.nl/dataservices/data.asmx (status: 200):
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><createResponse xmlns="http://tempuri.org/"><createResult>{"id": "2db0e219-5f4a-48d7-9f9f-ad9e2b412984", "key": "vega_spec_T3T4", "date": "2018-05-04 14:56:10"}</createResult></createResponse></soap:Body></soap:Envelope>
# HTTP Post to https://data.hkvservices.nl/dataservices/data.asmx:
# <?xml version='1.0' encoding='utf-8'?>
# <soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
#   <soap-env:Body>
#     <ns0:create xmlns:ns0="http://tempuri.org/">
#       <ns0:database>PR2877_20</ns0:database>
#       <ns0:key>vega_spec_T4T5</ns0:key>
#       <ns0:description>Vega Specification for T4T5</ns0:description>
#       <ns0:data>{"legends": [{"fill": "color", "type": "gradient", "encode": {"title": {"update": {"fontSize": {"value": 14}, "limit": {"value": 400}}}}, "title": {"signal": "variable"}}], "layout": {"bounds": "full", "columns": 2, "align": "none", "padding": {"column": 10, "row": 10}, "offset": 10}, "title": {"text": "T4T5 - A self-organizing map of Hondsbossche Dunes using variables representing the geographical characteristics of their growth", "orient": "top", "anchor": "start"}, "scales": [{"name": "size", "range": [50, 1500], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}}, {"range": ["#3D3D3D", "#F0F8FF", "cornflowerblue", "mediumseagreen", "#FFEE00", "darkorange", "firebrick"], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}, "type": "sequential", "nice": false, "name": "color", "zero": false}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_x_step"}}, "domain": {"sort": true, "field": "X", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_x"}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_y_step"}}, "domain": {"sort": true, "field": "Y", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_y"}], "config": {"axisY": {"minExtent": 30}, "style": {"text": {"baseline": "middle"}}, "title": {"fontSize": 18, "offset": 10}, "legend": {"orient": "bottom", "offset": 30}}, "marks": [{"style": "cell", "marks": [{"name": "brush_brush_bg", "clip": true, "encode": {"enter": {"fill": {"value": "#333"}, "fillOpacity": {"value": 0.125}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}, {"style": ["rect"], "name": "matrix_layer_marks", "encode": {"update": {"y": {"field": "Y", "scale": "matrix_y"}, "fillOpacity": [{"value": 1, "test": "!(length(data(\"brush_store\"))) || (vlInterval(\"brush_store\", datum))"}, {"value": 0.25}], "x": {"field": "X", "scale": "matrix_x"}, "stroke": {"value": "white"}, "fill": {"field": {"signal": "variable"}, "scale": "color"}, "width": {"band": 1, "scale": "matrix_x", "offset": -0.25}, "strokeWidth": {"value": 0.25}, "height": {"band": 1, "scale": "matrix_y", "offset": -0.25}}, "hover": {"stroke": {"value": "#000"}, "strokeWidth": {"value": 2}}}, "from": {"data": "matrix_data"}, "type": "rect"}, {"name": "brush_brush", "clip": true, "encode": {"enter": {"fill": {"value": "transparent"}, "stroke": {"value": "white"}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}], "encode": {"update": {"width": {"signal": "matrix_width"}, "y": {"signal": "matrix_y"}, "x": {"signal": "matrix_x"}, "height": {"signal": "matrix_height"}}}, "title": {"text": "matrix element: create box to filter locations", "orient": "bottom", "anchor": "start"}, "name": "matrix_group", "type": "group", "axes": [{"tickCount": 5, "lab ...
#     </ns0:create>
#   </soap-env:Body>
# </soap-env:Envelope>
# T4T5
# https://data.hkvservices.nl:443 "POST /dataservices/data.asmx HTTP/1.1" 200 438
# HTTP Response from https://data.hkvservices.nl/dataservices/data.asmx (status: 200):
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><createResponse xmlns="http://tempuri.org/"><createResult>{"id": "9203e354-eb5e-4ed0-b5e4-df67ffbf7af6", "key": "vega_spec_T4T5", "date": "2018-05-04 14:56:11"}</createResult></createResponse></soap:Body></soap:Envelope>
# HTTP Post to https://data.hkvservices.nl/dataservices/data.asmx:
# <?xml version='1.0' encoding='utf-8'?>
# <soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
#   <soap-env:Body>
#     <ns0:create xmlns:ns0="http://tempuri.org/">
#       <ns0:database>PR2877_20</ns0:database>
#       <ns0:key>vega_spec_T5T6</ns0:key>
#       <ns0:description>Vega Specification for T5T6</ns0:description>
#       <ns0:data>{"legends": [{"fill": "color", "type": "gradient", "encode": {"title": {"update": {"fontSize": {"value": 14}, "limit": {"value": 400}}}}, "title": {"signal": "variable"}}], "layout": {"bounds": "full", "columns": 2, "align": "none", "padding": {"column": 10, "row": 10}, "offset": 10}, "title": {"text": "T5T6 - A self-organizing map of Hondsbossche Dunes using variables representing the geographical characteristics of their growth", "orient": "top", "anchor": "start"}, "scales": [{"name": "size", "range": [50, 1500], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}}, {"range": ["#3D3D3D", "#F0F8FF", "cornflowerblue", "mediumseagreen", "#FFEE00", "darkorange", "firebrick"], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}, "type": "sequential", "nice": false, "name": "color", "zero": false}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_x_step"}}, "domain": {"sort": true, "field": "X", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_x"}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_y_step"}}, "domain": {"sort": true, "field": "Y", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_y"}], "config": {"axisY": {"minExtent": 30}, "style": {"text": {"baseline": "middle"}}, "title": {"fontSize": 18, "offset": 10}, "legend": {"orient": "bottom", "offset": 30}}, "marks": [{"style": "cell", "marks": [{"name": "brush_brush_bg", "clip": true, "encode": {"enter": {"fill": {"value": "#333"}, "fillOpacity": {"value": 0.125}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}, {"style": ["rect"], "name": "matrix_layer_marks", "encode": {"update": {"y": {"field": "Y", "scale": "matrix_y"}, "fillOpacity": [{"value": 1, "test": "!(length(data(\"brush_store\"))) || (vlInterval(\"brush_store\", datum))"}, {"value": 0.25}], "x": {"field": "X", "scale": "matrix_x"}, "stroke": {"value": "white"}, "fill": {"field": {"signal": "variable"}, "scale": "color"}, "width": {"band": 1, "scale": "matrix_x", "offset": -0.25}, "strokeWidth": {"value": 0.25}, "height": {"band": 1, "scale": "matrix_y", "offset": -0.25}}, "hover": {"stroke": {"value": "#000"}, "strokeWidth": {"value": 2}}}, "from": {"data": "matrix_data"}, "type": "rect"}, {"name": "brush_brush", "clip": true, "encode": {"enter": {"fill": {"value": "transparent"}, "stroke": {"value": "white"}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}], "encode": {"update": {"width": {"signal": "matrix_width"}, "y": {"signal": "matrix_y"}, "x": {"signal": "matrix_x"}, "height": {"signal": "matrix_height"}}}, "title": {"text": "matrix element: create box to filter locations", "orient": "bottom", "anchor": "start"}, "name": "matrix_group", "type": "group", "axes": [{"tickCount": 5, "lab ...
#     </ns0:create>
#   </soap-env:Body>
# </soap-env:Envelope>
# T5T6
# https://data.hkvservices.nl:443 "POST /dataservices/data.asmx HTTP/1.1" 200 438
# HTTP Response from https://data.hkvservices.nl/dataservices/data.asmx (status: 200):
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><createResponse xmlns="http://tempuri.org/"><createResult>{"id": "c0851d52-6245-411a-8e42-895b9660d5c0", "key": "vega_spec_T5T6", "date": "2018-05-04 14:56:11"}</createResult></createResponse></soap:Body></soap:Envelope>
# HTTP Post to https://data.hkvservices.nl/dataservices/data.asmx:
# <?xml version='1.0' encoding='utf-8'?>
# <soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
#   <soap-env:Body>
#     <ns0:create xmlns:ns0="http://tempuri.org/">
#       <ns0:database>PR2877_20</ns0:database>
#       <ns0:key>vega_spec_T6T7</ns0:key>
#       <ns0:description>Vega Specification for T6T7</ns0:description>
#       <ns0:data>{"legends": [{"fill": "color", "type": "gradient", "encode": {"title": {"update": {"fontSize": {"value": 14}, "limit": {"value": 400}}}}, "title": {"signal": "variable"}}], "layout": {"bounds": "full", "columns": 2, "align": "none", "padding": {"column": 10, "row": 10}, "offset": 10}, "title": {"text": "T6T7 - A self-organizing map of Hondsbossche Dunes using variables representing the geographical characteristics of their growth", "orient": "top", "anchor": "start"}, "scales": [{"name": "size", "range": [50, 1500], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}}, {"range": ["#3D3D3D", "#F0F8FF", "cornflowerblue", "mediumseagreen", "#FFEE00", "darkorange", "firebrick"], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}, "type": "sequential", "nice": false, "name": "color", "zero": false}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_x_step"}}, "domain": {"sort": true, "field": "X", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_x"}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_y_step"}}, "domain": {"sort": true, "field": "Y", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_y"}], "config": {"axisY": {"minExtent": 30}, "style": {"text": {"baseline": "middle"}}, "title": {"fontSize": 18, "offset": 10}, "legend": {"orient": "bottom", "offset": 30}}, "marks": [{"style": "cell", "marks": [{"name": "brush_brush_bg", "clip": true, "encode": {"enter": {"fill": {"value": "#333"}, "fillOpacity": {"value": 0.125}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}, {"style": ["rect"], "name": "matrix_layer_marks", "encode": {"update": {"y": {"field": "Y", "scale": "matrix_y"}, "fillOpacity": [{"value": 1, "test": "!(length(data(\"brush_store\"))) || (vlInterval(\"brush_store\", datum))"}, {"value": 0.25}], "x": {"field": "X", "scale": "matrix_x"}, "stroke": {"value": "white"}, "fill": {"field": {"signal": "variable"}, "scale": "color"}, "width": {"band": 1, "scale": "matrix_x", "offset": -0.25}, "strokeWidth": {"value": 0.25}, "height": {"band": 1, "scale": "matrix_y", "offset": -0.25}}, "hover": {"stroke": {"value": "#000"}, "strokeWidth": {"value": 2}}}, "from": {"data": "matrix_data"}, "type": "rect"}, {"name": "brush_brush", "clip": true, "encode": {"enter": {"fill": {"value": "transparent"}, "stroke": {"value": "white"}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}], "encode": {"update": {"width": {"signal": "matrix_width"}, "y": {"signal": "matrix_y"}, "x": {"signal": "matrix_x"}, "height": {"signal": "matrix_height"}}}, "title": {"text": "matrix element: create box to filter locations", "orient": "bottom", "anchor": "start"}, "name": "matrix_group", "type": "group", "axes": [{"tickCount": 5, "lab ...
#     </ns0:create>
#   </soap-env:Body>
# </soap-env:Envelope>
# T6T7
# https://data.hkvservices.nl:443 "POST /dataservices/data.asmx HTTP/1.1" 200 438
# HTTP Response from https://data.hkvservices.nl/dataservices/data.asmx (status: 200):
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><createResponse xmlns="http://tempuri.org/"><createResult>{"id": "6d472703-8115-43e6-ab82-95e6644069ad", "key": "vega_spec_T6T7", "date": "2018-05-04 14:56:11"}</createResult></createResponse></soap:Body></soap:Envelope>
# HTTP Post to https://data.hkvservices.nl/dataservices/data.asmx:
# <?xml version='1.0' encoding='utf-8'?>
# <soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
#   <soap-env:Body>
#     <ns0:create xmlns:ns0="http://tempuri.org/">
#       <ns0:database>PR2877_20</ns0:database>
#       <ns0:key>vega_spec_T7T8</ns0:key>
#       <ns0:description>Vega Specification for T7T8</ns0:description>
#       <ns0:data>{"legends": [{"fill": "color", "type": "gradient", "encode": {"title": {"update": {"fontSize": {"value": 14}, "limit": {"value": 400}}}}, "title": {"signal": "variable"}}], "layout": {"bounds": "full", "columns": 2, "align": "none", "padding": {"column": 10, "row": 10}, "offset": 10}, "title": {"text": "T7T8 - A self-organizing map of Hondsbossche Dunes using variables representing the geographical characteristics of their growth", "orient": "top", "anchor": "start"}, "scales": [{"name": "size", "range": [50, 1500], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}}, {"range": ["#3D3D3D", "#F0F8FF", "cornflowerblue", "mediumseagreen", "#FFEE00", "darkorange", "firebrick"], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}, "type": "sequential", "nice": false, "name": "color", "zero": false}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_x_step"}}, "domain": {"sort": true, "field": "X", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_x"}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_y_step"}}, "domain": {"sort": true, "field": "Y", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_y"}], "config": {"axisY": {"minExtent": 30}, "style": {"text": {"baseline": "middle"}}, "title": {"fontSize": 18, "offset": 10}, "legend": {"orient": "bottom", "offset": 30}}, "marks": [{"style": "cell", "marks": [{"name": "brush_brush_bg", "clip": true, "encode": {"enter": {"fill": {"value": "#333"}, "fillOpacity": {"value": 0.125}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}, {"style": ["rect"], "name": "matrix_layer_marks", "encode": {"update": {"y": {"field": "Y", "scale": "matrix_y"}, "fillOpacity": [{"value": 1, "test": "!(length(data(\"brush_store\"))) || (vlInterval(\"brush_store\", datum))"}, {"value": 0.25}], "x": {"field": "X", "scale": "matrix_x"}, "stroke": {"value": "white"}, "fill": {"field": {"signal": "variable"}, "scale": "color"}, "width": {"band": 1, "scale": "matrix_x", "offset": -0.25}, "strokeWidth": {"value": 0.25}, "height": {"band": 1, "scale": "matrix_y", "offset": -0.25}}, "hover": {"stroke": {"value": "#000"}, "strokeWidth": {"value": 2}}}, "from": {"data": "matrix_data"}, "type": "rect"}, {"name": "brush_brush", "clip": true, "encode": {"enter": {"fill": {"value": "transparent"}, "stroke": {"value": "white"}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}], "encode": {"update": {"width": {"signal": "matrix_width"}, "y": {"signal": "matrix_y"}, "x": {"signal": "matrix_x"}, "height": {"signal": "matrix_height"}}}, "title": {"text": "matrix element: create box to filter locations", "orient": "bottom", "anchor": "start"}, "name": "matrix_group", "type": "group", "axes": [{"tickCount": 5, "lab ...
#     </ns0:create>
#   </soap-env:Body>
# </soap-env:Envelope>
# T7T8
# https://data.hkvservices.nl:443 "POST /dataservices/data.asmx HTTP/1.1" 200 438
# HTTP Response from https://data.hkvservices.nl/dataservices/data.asmx (status: 200):
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><createResponse xmlns="http://tempuri.org/"><createResult>{"id": "5260a824-89cf-4eef-a9e7-5c6bad42c612", "key": "vega_spec_T7T8", "date": "2018-05-04 14:56:12"}</createResult></createResponse></soap:Body></soap:Envelope>
# HTTP Post to https://data.hkvservices.nl/dataservices/data.asmx:
# <?xml version='1.0' encoding='utf-8'?>
# <soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
#   <soap-env:Body>
#     <ns0:create xmlns:ns0="http://tempuri.org/">
#       <ns0:database>PR2877_20</ns0:database>
#       <ns0:key>vega_spec_T8T9</ns0:key>
#       <ns0:description>Vega Specification for T8T9</ns0:description>
#       <ns0:data>{"legends": [{"fill": "color", "type": "gradient", "encode": {"title": {"update": {"fontSize": {"value": 14}, "limit": {"value": 400}}}}, "title": {"signal": "variable"}}], "layout": {"bounds": "full", "columns": 2, "align": "none", "padding": {"column": 10, "row": 10}, "offset": 10}, "title": {"text": "T8T9 - A self-organizing map of Hondsbossche Dunes using variables representing the geographical characteristics of their growth", "orient": "top", "anchor": "start"}, "scales": [{"name": "size", "range": [50, 1500], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}}, {"range": ["#3D3D3D", "#F0F8FF", "cornflowerblue", "mediumseagreen", "#FFEE00", "darkorange", "firebrick"], "domain": {"sort": true, "fields": [{"field": {"signal": "variable"}, "data": "matrix_data"}]}, "type": "sequential", "nice": false, "name": "color", "zero": false}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_x_step"}}, "domain": {"sort": true, "field": "X", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_x"}, {"paddingInner": 0, "range": {"step": {"signal": "matrix_y_step"}}, "domain": {"sort": true, "field": "Y", "data": "matrix_data_static"}, "type": "band", "paddingOuter": 0, "name": "matrix_y"}], "config": {"axisY": {"minExtent": 30}, "style": {"text": {"baseline": "middle"}}, "title": {"fontSize": 18, "offset": 10}, "legend": {"orient": "bottom", "offset": 30}}, "marks": [{"style": "cell", "marks": [{"name": "brush_brush_bg", "clip": true, "encode": {"enter": {"fill": {"value": "#333"}, "fillOpacity": {"value": 0.125}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}, {"style": ["rect"], "name": "matrix_layer_marks", "encode": {"update": {"y": {"field": "Y", "scale": "matrix_y"}, "fillOpacity": [{"value": 1, "test": "!(length(data(\"brush_store\"))) || (vlInterval(\"brush_store\", datum))"}, {"value": 0.25}], "x": {"field": "X", "scale": "matrix_x"}, "stroke": {"value": "white"}, "fill": {"field": {"signal": "variable"}, "scale": "color"}, "width": {"band": 1, "scale": "matrix_x", "offset": -0.25}, "strokeWidth": {"value": 0.25}, "height": {"band": 1, "scale": "matrix_y", "offset": -0.25}}, "hover": {"stroke": {"value": "#000"}, "strokeWidth": {"value": 2}}}, "from": {"data": "matrix_data"}, "type": "rect"}, {"name": "brush_brush", "clip": true, "encode": {"enter": {"fill": {"value": "transparent"}, "stroke": {"value": "white"}}, "update": {"y2": [{"signal": "brush_y[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "y": [{"signal": "brush_y[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x2": [{"signal": "brush_x[1]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}], "x": [{"signal": "brush_x[0]", "test": "data(\"brush_store\").length &amp;&amp; data(\"brush_store\")[0].unit === \"matrix_layer\""}, {"value": 0}]}}, "type": "rect"}], "encode": {"update": {"width": {"signal": "matrix_width"}, "y": {"signal": "matrix_y"}, "x": {"signal": "matrix_x"}, "height": {"signal": "matrix_height"}}}, "title": {"text": "matrix element: create box to filter locations", "orient": "bottom", "anchor": "start"}, "name": "matrix_group", "type": "group", "axes": [{"tickCount": 5, "lab ...
#     </ns0:create>
#   </soap-env:Body>
# </soap-env:Envelope>
# T8T9
# https://data.hkvservices.nl:443 "POST /dataservices/data.asmx HTTP/1.1" 200 438
# HTTP Response from https://data.hkvservices.nl/dataservices/data.asmx (status: 200):
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><createResponse xmlns="http://tempuri.org/"><createResult>{"id": "aa9ebfb6-aac9-4702-a5fb-8db18185ca9c", "key": "vega_spec_T8T9", "date": "2018-05-04 14:56:12"}</createResult></createResponse></soap:Body></soap:Envelope>
