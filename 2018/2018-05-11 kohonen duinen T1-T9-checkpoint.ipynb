# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import sompy
from sompy.visualization.mapview import View2D
from sompy.visualization.umatrix import UMatrixView
import matplotlib.pyplot as plt
from hkvportal.io.services import dataportal
import json
import pandas as pd
from io import StringIO
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline

# %%
# function to get user feedback
def ask_user():
    check = str(input("upload results? (Y/N): ")).lower().strip()
    try:
        if check[0] == 'y':
            return True
        elif check[0] == 'n':
            return False
        else:
            print('Invalid Input')
            return ask_user()
    except Exception as error:
        print("Please enter valid inputs")
        print(error)
        return ask_user()
    
## Import up sound alert dependencies
from IPython.display import Audio, display

def user_sound():
    display(Audio(url='https://sound.peal.io/ps/audios/000/000/537/original/woo_vu_luvub_dub_dub.wav', autoplay=True))

# %%
file_name = r'D:\Projects\Pr\2877.20\toeleveringen\v2\Transectinfo_v2_metkorreldiameter.xlsx'

# %%
# open excel files and read all sheets
xl_file = pd.ExcelFile(file_name)

dfs = {sheet_name: xl_file.parse(sheet_name) 
          for sheet_name in xl_file.sheet_names}

# %%
# Initiate HKV dataportal
dp = dataportal()
dp.setDataservice(dataservice='https://data.hkvservices.nl/dataservices/')

# create db if not existing
dp.createDatabase(database='PR2877_20')
# Out:
# Init schema document for None
# register_type('{http://www.w3.org/2001/XMLSchema}string', <zeep.xsd.types.builtins.String object at 0x000000001C193160>)
# register_type('{http://www.w3.org/2001/XMLSchema}boolean', <zeep.xsd.types.builtins.Boolean object at 0x000000001C193048>)
# register_type('{http://www.w3.org/2001/XMLSchema}decimal', <zeep.xsd.types.builtins.Decimal object at 0x000000001C1932B0>)
# register_type('{http://www.w3.org/2001/XMLSchema}float', <zeep.xsd.types.builtins.Float object at 0x000000001C193EB8>)
# register_type('{http://www.w3.org/2001/XMLSchema}double', <zeep.xsd.types.builtins.Double object at 0x000000001C193FD0>)
# register_type('{http://www.w3.org/2001/XMLSchema}duration', <zeep.xsd.types.builtins.Duration object at 0x000000001C193D68>)
# register_type('{http://www.w3.org/2001/XMLSchema}dateTime', <zeep.xsd.types.builtins.DateTime object at 0x000000001C193240>)
# register_type('{http://www.w3.org/2001/XMLSchema}time', <zeep.xsd.types.builtins.Time object at 0x000000001C193C50>)
# register_type('{http://www.w3.org/2001/XMLSchema}date', <zeep.xsd.types.builtins.Date object at 0x000000001C193E10>)
# register_type('{http://www.w3.org/2001/XMLSchema}gYearMonth', <zeep.xsd.types.builtins.gYearMonth object at 0x000000001C193AC8>)
# register_type('{http://www.w3.org/2001/XMLSchema}gYear', <zeep.xsd.types.builtins.gYear object at 0x000000001C193DA0>)
# register_type('{http://www.w3.org/2001/XMLSchema}gMonthDay', <zeep.xsd.types.builtins.gMonthDay object at 0x0000000004A49320>)
# register_type('{http://www.w3.org/2001/XMLSchema}gDay', <zeep.xsd.types.builtins.gDay object at 0x000000001C15F8D0>)
# register_type('{http://www.w3.org/2001/XMLSchema}gMonth', <zeep.xsd.types.builtins.gMonth object at 0x0000000004AAE7F0>)
# register_type('{http://www.w3.org/2001/XMLSchema}hexBinary', <zeep.xsd.types.builtins.HexBinary object at 0x000000001E7F8080>)
# register_type('{http://www.w3.org/2001/XMLSchema}base64Binary', <zeep.xsd.types.builtins.Base64Binary object at 0x000000001E7F8240>)
# register_type('{http://www.w3.org/2001/XMLSchema}anyURI', <zeep.xsd.types.builtins.AnyURI object at 0x000000001E7F82E8>)
# register_type('{http://www.w3.org/2001/XMLSchema}QName', <zeep.xsd.types.builtins.QName object at 0x000000001E7F8198>)
# register_type('{http://www.w3.org/2001/XMLSchema}NOTATION', <zeep.xsd.types.builtins.Notation object at 0x000000001E7F8128>)
# register_type('{http://www.w3.org/2001/XMLSchema}normalizedString', <zeep.xsd.types.builtins.NormalizedString object at 0x000000001E7F84A8>)
# register_type('{http://www.w3.org/2001/XMLSchema}token', <zeep.xsd.types.builtins.Token object at 0x000000001E7F83C8>)
# register_type('{http://www.w3.org/2001/XMLSchema}language', <zeep.xsd.types.builtins.Language object at 0x000000001E7F8320>)
# register_type('{http://www.w3.org/2001/XMLSchema}NMTOKEN', <zeep.xsd.types.builtins.NmToken object at 0x000000001E7F8470>)
# register_type('{http://www.w3.org/2001/XMLSchema}NMTOKENS', <zeep.xsd.types.builtins.NmTokens object at 0x000000001E7F8438>)
# register_type('{http://www.w3.org/2001/XMLSchema}Name', <zeep.xsd.types.builtins.Name object at 0x000000001E7F85F8>)
# register_type('{http://www.w3.org/2001/XMLSchema}NCName', <zeep.xsd.types.builtins.NCName object at 0x000000001C18C278>)
# register_type('{http://www.w3.org/2001/XMLSchema}ID', <zeep.xsd.types.builtins.ID object at 0x000000001E7F8668>)
# register_type('{http://www.w3.org/2001/XMLSchema}IDREF', <zeep.xsd.types.builtins.IDREF object at 0x000000001E7F87B8>)
# register_type('{http://www.w3.org/2001/XMLSchema}IDREFS', <zeep.xsd.types.builtins.IDREFS object at 0x000000001E7F86D8>)
# register_type('{http://www.w3.org/2001/XMLSchema}ENTITY', <zeep.xsd.types.builtins.Entity object at 0x000000001E7F87F0>)
# register_type('{http://www.w3.org/2001/XMLSchema}ENTITIES', <zeep.xsd.types.builtins.Entities object at 0x000000001E7F8940>)
# register_type('{http://www.w3.org/2001/XMLSchema}integer', <zeep.xsd.types.builtins.Integer object at 0x000000001E7F8A90>)
# register_type('{http://www.w3.org/2001/XMLSchema}nonPositiveInteger', <zeep.xsd.types.builtins.NonPositiveInteger object at 0x000000001E7F8978>)
# register_type('{http://www.w3.org/2001/XMLSchema}negativeInteger', <zeep.xsd.types.builtins.NegativeInteger object at 0x000000001E7F8BA8>)
# register_type('{http://www.w3.org/2001/XMLSchema}long', <zeep.xsd.types.builtins.Long object at 0x000000001E7F8B70>)
# register_type('{http://www.w3.org/2001/XMLSchema}int', <zeep.xsd.types.builtins.Int object at 0x000000001E7F8B00>)
# register_type('{http://www.w3.org/2001/XMLSchema}short', <zeep.xsd.types.builtins.Short object at 0x000000001E7F8C50>)
# register_type('{http://www.w3.org/2001/XMLSchema}byte', <zeep.xsd.types.builtins.Byte object at 0x000000001E7F8D30>)
# register_type('{http://www.w3.org/2001/XMLSchema}nonNegativeInteger', <zeep.xsd.types.builtins.NonNegativeInteger object at 0x000000001E7F8BE0>)
# register_type('{http://www.w3.org/2001/XMLSchema}unsignedByte', <zeep.xsd.types.builtins.UnsignedByte object at 0x000000001E7F8E10>)
# register_type('{http://www.w3.org/2001/XMLSchema}unsignedInt', <zeep.xsd.types.builtins.UnsignedInt object at 0x000000001E7F8F28>)
# register_type('{http://www.w3.org/2001/XMLSchema}unsignedLong', <zeep.xsd.types.builtins.UnsignedLong object at 0x000000001E7F8EB8>)
# register_type('{http://www.w3.org/2001/XMLSchema}unsignedShort', <zeep.xsd.types.builtins.UnsignedShort object at 0x000000001E7F8FD0>)
# register_type('{http://www.w3.org/2001/XMLSchema}positiveInteger', <zeep.xsd.types.builtins.PositiveInteger object at 0x000000001E7F8F60>)
# register_type('{http://www.w3.org/2001/XMLSchema}anyType', <zeep.xsd.types.any.AnyType object at 0x000000001E7F8E80>)
# register_type('{http://www.w3.org/2001/XMLSchema}anySimpleType', <zeep.xsd.types.simple.AnySimpleType object at 0x000000001E372160>)
# register_element('{http://www.w3.org/2001/XMLSchema}schema', <zeep.xsd.elements.builtins.Schema object at 0x000000001E3721D0>)
# Add document with tns http://www.w3.org/2001/XMLSchema to schema 471412976
# Starting new HTTPS connection (1): data.hkvservices.nl
# https://data.hkvservices.nl:443 "GET /dataservices/data.asmx?WSDL HTTP/1.1" 200 20460
# Creating definition for https://data.hkvservices.nl/dataservices/data.asmx?WSDL
# Init schema document for 'https://data.hkvservices.nl/dataservices/data.asmx?WSDL'
# Add document with tns http://tempuri.org/ to schema 471412976
# register_element('{http://tempuri.org/}create', <Element(name='create', type=<zeep.xsd.dynamic_types.create object at 0x000000001E2FB748>)>)
# register_element('{http://tempuri.org/}createResponse', <Element(name='createResponse', type=<zeep.xsd.dynamic_types.createResponse object at 0x000000001E2FB8D0>)>)
# register_element('{http://tempuri.org/}createbytes', <Element(name='createbytes', type=<zeep.xsd.dynamic_types.createbytes object at 0x000000001E2FBDD8>)>)
# register_element('{http://tempuri.org/}createbytesResponse', <Element(name='createbytesResponse', type=<zeep.xsd.dynamic_types.createbytesResponse object at 0x000000001E2FB630>)>)
# register_element('{http://tempuri.org/}read', <Element(name='read', type=<zeep.xsd.dynamic_types.read object at 0x000000001E750390>)>)
# register_element('{http://tempuri.org/}readResponse', <Element(name='readResponse', type=<zeep.xsd.dynamic_types.readResponse object at 0x000000001E750240>)>)
# register_element('{http://tempuri.org/}list', <Element(name='list', type=<zeep.xsd.dynamic_types.list object at 0x000000001E7506A0>)>)
# register_element('{http://tempuri.org/}listResponse', <Element(name='listResponse', type=<zeep.xsd.dynamic_types.listResponse object at 0x000000001E7502E8>)>)
# register_element('{http://tempuri.org/}update', <Element(name='update', type=<zeep.xsd.dynamic_types.update object at 0x000000001E750898>)>)
# register_element('{http://tempuri.org/}updateResponse', <Element(name='updateResponse', type=<zeep.xsd.dynamic_types.updateResponse object at 0x000000001E7509E8>)>)
# register_element('{http://tempuri.org/}delete', <Element(name='delete', type=<zeep.xsd.dynamic_types.delete object at 0x000000001E7F8048>)>)
# register_element('{http://tempuri.org/}deleteResponse', <Element(name='deleteResponse', type=<zeep.xsd.dynamic_types.deleteResponse object at 0x000000001E750CC0>)>)
# register_element('{http://tempuri.org/}string', <Element(name='string', type=<UnresolvedType(qname='{http://www.w3.org/2001/XMLSchema}string')>)>)
# Init schema document for 'https://data.hkvservices.nl/dataservices/data.asmx?WSDL'
# Add document with tns http://tempuri.org/AbstractTypes to schema 471412976
# Ignoring import statement for namespace 'http://schemas.xmlsoap.org/soap/encoding/' (missing schemaLocation)
# Auto importing missing known schema: http://schemas.xmlsoap.org/soap/encoding/
# Starting new HTTP connection (1): schemas.xmlsoap.org
# http://schemas.xmlsoap.org:80 "GET /soap/encoding/ HTTP/1.1" 200 3382
# Init schema document for 'http://schemas.xmlsoap.org/soap/encoding/'
# Add document with tns http://schemas.xmlsoap.org/soap/encoding/ to schema 471412976
# register_attribute('{http://schemas.xmlsoap.org/soap/encoding/}root', <Attribute(name='root', type=<UnresolvedCustomType(qname='{http://schemas.xmlsoap.org/soap/encoding/}root', base_type=<UnresolvedType(qname='{http://www.w3.org/2001/XMLSchema}boolean')>)>)>)
# register_attribute_group('{http://schemas.xmlsoap.org/soap/encoding/}commonAttributes', <zeep.xsd.elements.attribute.AttributeGroup object at 0x000000001E774358>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}arrayCoordinate', <UnresolvedCustomType(qname='{http://schemas.xmlsoap.org/soap/encoding/}arrayCoordinate', base_type=<UnresolvedType(qname='{http://www.w3.org/2001/XMLSchema}string')>)>)
# register_attribute('{http://schemas.xmlsoap.org/soap/encoding/}arrayType', <Attribute(name='arrayType', type=<UnresolvedType(qname='{http://www.w3.org/2001/XMLSchema}string')>)>)
# Auto importing missing known schema: http://schemas.xmlsoap.org/soap/encoding/
# Returning existing schema: 'http://schemas.xmlsoap.org/soap/encoding/'
# register_attribute('{http://schemas.xmlsoap.org/soap/encoding/}offset', <Attribute(name='offset', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}arrayCoordinate')>)>)
# register_attribute_group('{http://schemas.xmlsoap.org/soap/encoding/}arrayAttributes', <zeep.xsd.elements.attribute.AttributeGroup object at 0x000000001E774400>)
# register_attribute('{http://schemas.xmlsoap.org/soap/encoding/}position', <Attribute(name='position', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}arrayCoordinate')>)>)
# register_attribute_group('{http://schemas.xmlsoap.org/soap/encoding/}arrayMemberAttributes', <zeep.xsd.elements.attribute.AttributeGroup object at 0x000000001E6E40B8>)
# register_group('{http://schemas.xmlsoap.org/soap/encoding/}Array', <Group(<zeep.xsd.elements.indicators.Group object at 0x000000001E6E4128>)>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}Array', <Element(name='Array', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}Array')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}Array', <zeep.xsd.dynamic_types.Array object at 0x000000001E6E4198>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}Struct', <Element(name='Struct', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}Struct')>)>)
# register_group('{http://schemas.xmlsoap.org/soap/encoding/}Struct', <Group(<zeep.xsd.elements.indicators.Group object at 0x000000001E6E4588>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}Struct', <zeep.xsd.dynamic_types.Struct object at 0x000000001E6E46A0>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}base64', <UnresolvedCustomType(qname='{http://schemas.xmlsoap.org/soap/encoding/}base64', base_type=<UnresolvedType(qname='{http://www.w3.org/2001/XMLSchema}base64Binary')>)>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}duration', <Element(name='duration', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}duration')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}duration', <zeep.xsd.dynamic_types.duration object at 0x000000001E6E49B0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}dateTime', <Element(name='dateTime', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}dateTime')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}dateTime', <zeep.xsd.dynamic_types.dateTime object at 0x000000001E6E4AC8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}NOTATION', <Element(name='NOTATION', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}NOTATION')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}NOTATION', <zeep.xsd.dynamic_types.NOTATION object at 0x000000001E774A58>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}time', <Element(name='time', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}time')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}time', <zeep.xsd.dynamic_types.time object at 0x000000001E6E4C18>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}date', <Element(name='date', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}date')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}date', <zeep.xsd.dynamic_types.date object at 0x000000001E6E4E48>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}gYearMonth', <Element(name='gYearMonth', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}gYearMonth')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}gYearMonth', <zeep.xsd.dynamic_types.gYearMonth object at 0x000000001E6E4F60>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}gYear', <Element(name='gYear', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}gYear')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}gYear', <zeep.xsd.dynamic_types.gYear object at 0x000000001E6E8128>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}gMonthDay', <Element(name='gMonthDay', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}gMonthDay')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}gMonthDay', <zeep.xsd.dynamic_types.gMonthDay object at 0x000000001E6E8390>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}gDay', <Element(name='gDay', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}gDay')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}gDay', <zeep.xsd.dynamic_types.gDay object at 0x000000001E6E8588>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}gMonth', <Element(name='gMonth', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}gMonth')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}gMonth', <zeep.xsd.dynamic_types.gMonth object at 0x000000001E6E87B8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}boolean', <Element(name='boolean', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}boolean')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}boolean', <zeep.xsd.dynamic_types.boolean object at 0x000000001E6E89E8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}base64Binary', <Element(name='base64Binary', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}base64Binary')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}base64Binary', <zeep.xsd.dynamic_types.base64Binary object at 0x000000001E6E8AC8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}hexBinary', <Element(name='hexBinary', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}hexBinary')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}hexBinary', <zeep.xsd.dynamic_types.hexBinary object at 0x000000001E6E8D68>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}float', <Element(name='float', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}float')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}float', <zeep.xsd.dynamic_types.float object at 0x000000001E6E8FD0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}double', <Element(name='double', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}double')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}double', <zeep.xsd.dynamic_types.double object at 0x000000001E6FC358>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}anyURI', <Element(name='anyURI', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}anyURI')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}anyURI', <zeep.xsd.dynamic_types.anyURI object at 0x000000001E6FC630>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}QName', <Element(name='QName', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}QName')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}QName', <zeep.xsd.dynamic_types.QName object at 0x000000001E6FC908>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}string', <Element(name='string', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}string')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}string', <zeep.xsd.dynamic_types.string object at 0x000000001E6FCBE0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}normalizedString', <Element(name='normalizedString', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}normalizedString')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}normalizedString', <zeep.xsd.dynamic_types.normalizedString object at 0x000000001E6FCCC0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}token', <Element(name='token', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}token')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}token', <zeep.xsd.dynamic_types.token object at 0x000000001E6FCFD0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}language', <Element(name='language', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}language')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}language', <zeep.xsd.dynamic_types.language object at 0x000000001E614198>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}Name', <Element(name='Name', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}Name')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}Name', <zeep.xsd.dynamic_types.Name object at 0x000000001E614550>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}NMTOKEN', <Element(name='NMTOKEN', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}NMTOKEN')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}NMTOKEN', <zeep.xsd.dynamic_types.NMTOKEN object at 0x000000001E614828>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}NCName', <Element(name='NCName', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}NCName')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}NCName', <zeep.xsd.dynamic_types.NCName object at 0x000000001E614B00>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}NMTOKENS', <Element(name='NMTOKENS', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}NMTOKENS')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}NMTOKENS', <zeep.xsd.dynamic_types.NMTOKENS object at 0x000000001E614BE0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}ID', <Element(name='ID', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}ID')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}ID', <zeep.xsd.dynamic_types.ID object at 0x000000001E614F98>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}IDREF', <Element(name='IDREF', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}IDREF')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}IDREF', <zeep.xsd.dynamic_types.IDREF object at 0x000000001E6BF2B0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}ENTITY', <Element(name='ENTITY', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}ENTITY')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}ENTITY', <zeep.xsd.dynamic_types.ENTITY object at 0x000000001E6BF588>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}IDREFS', <Element(name='IDREFS', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}IDREFS')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}IDREFS', <zeep.xsd.dynamic_types.IDREFS object at 0x000000001E6BF860>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}ENTITIES', <Element(name='ENTITIES', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}ENTITIES')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}ENTITIES', <zeep.xsd.dynamic_types.ENTITIES object at 0x000000001E6BFA20>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}decimal', <Element(name='decimal', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}decimal')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}decimal', <zeep.xsd.dynamic_types.decimal object at 0x000000001E6BFCF8>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}integer', <Element(name='integer', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}integer')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}integer', <zeep.xsd.dynamic_types.integer object at 0x000000001E6BFFD0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}nonPositiveInteger', <Element(name='nonPositiveInteger', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}nonPositiveInteger')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}nonPositiveInteger', <zeep.xsd.dynamic_types.nonPositiveInteger object at 0x000000001E6B00F0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}negativeInteger', <Element(name='negativeInteger', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}negativeInteger')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}negativeInteger', <zeep.xsd.dynamic_types.negativeInteger object at 0x000000001E6B0390>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}long', <Element(name='long', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}long')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}long', <zeep.xsd.dynamic_types.long object at 0x000000001E6B0668>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}int', <Element(name='int', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}int')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}int', <zeep.xsd.dynamic_types.int object at 0x000000001E6B0940>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}short', <Element(name='short', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}short')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}short', <zeep.xsd.dynamic_types.short object at 0x000000001E6B0C18>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}byte', <Element(name='byte', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}byte')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}byte', <zeep.xsd.dynamic_types.byte object at 0x000000001E6B0EF0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}nonNegativeInteger', <Element(name='nonNegativeInteger', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}nonNegativeInteger')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}nonNegativeInteger', <zeep.xsd.dynamic_types.nonNegativeInteger object at 0x000000001E565080>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}unsignedLong', <Element(name='unsignedLong', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}unsignedLong')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}unsignedLong', <zeep.xsd.dynamic_types.unsignedLong object at 0x000000001E5652B0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}unsignedInt', <Element(name='unsignedInt', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}unsignedInt')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}unsignedInt', <zeep.xsd.dynamic_types.unsignedInt object at 0x000000001E565470>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}unsignedShort', <Element(name='unsignedShort', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}unsignedShort')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}unsignedShort', <zeep.xsd.dynamic_types.unsignedShort object at 0x000000001E565630>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}unsignedByte', <Element(name='unsignedByte', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}unsignedByte')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}unsignedByte', <zeep.xsd.dynamic_types.unsignedByte object at 0x000000001E5657F0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}positiveInteger', <Element(name='positiveInteger', type=<UnresolvedType(qname='{http://schemas.xmlsoap.org/soap/encoding/}positiveInteger')>)>)
# register_type('{http://schemas.xmlsoap.org/soap/encoding/}positiveInteger', <zeep.xsd.dynamic_types.positiveInteger object at 0x000000001E5659B0>)
# register_element('{http://schemas.xmlsoap.org/soap/encoding/}anyType', <Element(name='anyType', type=<zeep.xsd.types.any.AnyType object at 0x000000001E565978>)>)
# register_type('{http://tempuri.org/AbstractTypes}StringArray', <zeep.xsd.dynamic_types.StringArray object at 0x000000001E7746A0>)
# Resolving in schema <SchemaDocument(location='https://data.hkvservices.nl/dataservices/data.asmx?WSDL', tns='http://tempuri.org/', is_empty=False)>
# Resolving in schema <SchemaDocument(location='https://data.hkvservices.nl/dataservices/data.asmx?WSDL', tns='http://tempuri.org/AbstractTypes', is_empty=False)>
# Resolving in schema <SchemaDocument(location='http://schemas.xmlsoap.org/soap/encoding/', tns='http://schemas.xmlsoap.org/soap/encoding/', is_empty=False)>
# Resolving in schema <SchemaDocument(location='http://schemas.xmlsoap.org/soap/encoding/', tns='http://schemas.xmlsoap.org/soap/encoding/', is_empty=False)>
# Adding message: {http://tempuri.org/}createSoapIn
# Adding message: {http://tempuri.org/}createSoapOut
# Adding message: {http://tempuri.org/}createbytesSoapIn
# Adding message: {http://tempuri.org/}createbytesSoapOut
# Adding message: {http://tempuri.org/}readSoapIn
# Adding message: {http://tempuri.org/}readSoapOut
# Adding message: {http://tempuri.org/}listSoapIn
# Adding message: {http://tempuri.org/}listSoapOut
# Adding message: {http://tempuri.org/}updateSoapIn
# Adding message: {http://tempuri.org/}updateSoapOut
# Adding message: {http://tempuri.org/}deleteSoapIn
# Adding message: {http://tempuri.org/}deleteSoapOut
# Adding message: {http://tempuri.org/}createHttpGetIn
# Adding message: {http://tempuri.org/}createHttpGetOut
# Adding message: {http://tempuri.org/}createbytesHttpGetIn
# Adding message: {http://tempuri.org/}createbytesHttpGetOut
# Adding message: {http://tempuri.org/}readHttpGetIn
# Adding message: {http://tempuri.org/}readHttpGetOut
# Adding message: {http://tempuri.org/}listHttpGetIn
# Adding message: {http://tempuri.org/}listHttpGetOut
# Adding message: {http://tempuri.org/}updateHttpGetIn
# Adding message: {http://tempuri.org/}updateHttpGetOut
# Adding message: {http://tempuri.org/}deleteHttpGetIn
# Adding message: {http://tempuri.org/}deleteHttpGetOut
# Adding message: {http://tempuri.org/}createHttpPostIn
# Adding message: {http://tempuri.org/}createHttpPostOut
# Adding message: {http://tempuri.org/}createbytesHttpPostIn
# Adding message: {http://tempuri.org/}createbytesHttpPostOut
# Adding message: {http://tempuri.org/}readHttpPostIn
# Adding message: {http://tempuri.org/}readHttpPostOut
# Adding message: {http://tempuri.org/}listHttpPostIn
# Adding message: {http://tempuri.org/}listHttpPostOut
# Adding message: {http://tempuri.org/}updateHttpPostIn
# Adding message: {http://tempuri.org/}updateHttpPostOut
# Adding message: {http://tempuri.org/}deleteHttpPostIn
# Adding message: {http://tempuri.org/}deleteHttpPostOut
# Adding port: {http://tempuri.org/}dataSoap
# Adding port: {http://tempuri.org/}dataHttpGet
# Adding port: {http://tempuri.org/}dataHttpPost
# Adding binding: {http://tempuri.org/}dataSoap
# Adding binding: {http://tempuri.org/}dataSoap12
# Adding binding: {http://tempuri.org/}dataHttpGet
# Adding binding: {http://tempuri.org/}dataHttpPost
# Adding service: data
# Starting new HTTPS connection (1): data.hkvservices.nl
# https://data.hkvservices.nl:443 "GET /dataservices/database.asmx/create?database=PR2877_20 HTTP/1.1" 200 46
# dataservice is set. https://data.hkvservices.nl/dataservices/ will be used as portal
# {'exception': 'database name already exists'}

# %%
# get the spatial connection file
shp_file_in = r'D:\Projects\Pr\2877.20\toeleveringen\transecten.shp'
gdf = gpd.read_file(shp_file_in)
# Out:
# GDAL_DATA: C:\Python35\Lib\site-packages\osgeo\data\gdal
# PROJ_LIB: c:\python35\lib\site-packages\osgeo\data\proj
# Got coordinate system
# Failed to auto identify EPSG: 7
# Params: b'+proj=sterea +lat_0=52.15616055555555 +lon_0=5.38763888888889 +k=0.9999079 +x_0=155000 +y_0=463000 +ellps=bessel +units=m +no_defs '
# Index: 0
# Got coordinate system
# Flushed buffer
# Stopped session

# %%
keys = list(dfs.keys()) #['T1T2']#

# %%
for key in keys:#list(dfs.keys()):
    print(key)
    T_from = key[0:2]
    T_to = key[2:4]

    # read sheet as DataFrame
    df = dfs[key]

    # get spatial key and filter columns
    shp_key = df['Transectnummer'].copy()
    # exclude some columns
    df = df[df.columns.difference(['Transectnummer', 'Tijdsstap', 'xzee', 'yzee', 'xland', 'yland', 'Profieltype',
                                   'breedte transect kustdwars', 'aanlegmoment'])]
    df = df.astype(np.float32)

    # drop NaN columns
    df.dropna(axis=1, how='all', inplace=True)
    X = df.as_matrix()
    # format all these values to three decimales

    # train a kohonen network
    mapsize = [50, 60]
    som = sompy.SOMFactory.build(X, mapsize, mask=None, mapshape='planar', lattice='rect',
                                 normalization='var', initialization='pca', neighborhood='gaussian',
                                 training='batch', component_names=df.columns, name='sompy')

    # verbose='debug' will print more, and verbose=None wont print anything
    som.train(n_job=1, verbose='debug')

    # view the codebook
    view2D = View2D(10, 10, "rand data", text_size=10)
    view2D.show(som, col_sz=3, which_dim="all", desnormalize=True)
    view2D.save(
        r'D:\Projects\Pr\2877.20\resultaten\png\d2018_05_16/som_codebook_{}.png'.format(key))

    # compute the umatrix
    u = sompy.umatrix.UMatrixView(
        50, 60, 'umatrix', show_axis=True, text_size=8, show_text=True)

    # and its values
    UMAT = u.build_u_matrix(som, distance=1, row_normalized=False)
    UMAT2 = u.show(som, distance2=1, row_normalized=False,
                   show_data=True, contooor=False, blob=False,
                   filename=r'D:\Projects\Pr\2877.20\resultaten\png\d2018_05_16//u_matrix_{}.png'.format(key))

    # get the coordinates from the derived network (codebook)
    codebook = som._normalizer.denormalize_by(
        som.data_raw, som.codebook.matrix)
    msz = som.codebook.mapsize
    cents = som.bmu_ind_to_xy(np.arange(0, msz[0] * msz[1]))

    yv = cents[:, 0].astype(int)
    xv = cents[:, 1].astype(int)
    xyv = cents[:, 2].astype(int)  # coordinates

    # combine the results from the kohonen network with the original data
    df_cb = pd.DataFrame(
        data=codebook, columns=df.columns.str.replace('_', ' '))  # keywords)
    df_cb['U-matrix'] = UMAT.flatten('C')
    df_cb['X'] = xv
    df_cb['Y'] = yv
    df_cb['XY'] = xyv

    # show codebook head
    df_cb.head()

    #df.columns = keywords
    df['transectnummer'] = shp_key.values.astype(int)
    df['som_key'] = som._bmu[0].astype(int)

    # get the spatial connection file
    shp_file_in = r'D:\Projects\Pr\2877.20\toeleveringen\transecten.shp'
    gdf = gpd.read_file(shp_file_in)

    # print and check the coordinate reference system
    print(gdf.crs)

    # Let's take a copy of our layer
    gdf_proj = gdf.copy()

    # Reproject the geometries by replacing the values with projected ones
    gdf_proj['geometry'] = gdf_proj['geometry'].to_crs(epsg=4326)

    gdf_proj.loc[:, 'transectnu'] = gdf_proj.loc[:, 'transectnu'].astype(int)
    gdf_proj.head()

    # reprojection seems right lets puts back
    gdf = gdf_proj

    # apply inner join with GeoDataFrame and DataFrame on the transectnummer
    gdf_merge_df = gdf.merge(df, left_on='transectnu',
                             right_on='transectnummer')

    # and select few columns
    # gdf_merge_df.head()
    gdf_sel = gdf_merge_df.loc[:, ['transectnummer', 'som_key', 'geometry']]

    # get the number transects belonging to each nodes in the kohonen network
    som_key_all = np.sort(gdf_sel['som_key'].values)
    unique, counts = np.unique(som_key_all, return_counts=True)
    df_counts = pd.DataFrame(np.array((unique.astype(int), counts)).T, columns=[
                             'som_key_unique', 'number of transects'])

    # combine the number of number of transects representing each node to the codebook dataframe
    df_cb_counts = pd.merge(df_cb, df_counts, left_on='XY',
                            right_on='som_key_unique', how='left')
    df_cb_counts.drop('som_key_unique', axis=1, inplace=True)

    # and set format to 3 decimals
    integer_columns = ['aanlegmoment', 'X', 'Y', 'XY', 'number of transects']
    df_cb_counts[df_cb_counts.columns.difference(integer_columns)] = df_cb_counts[df_cb_counts.columns.difference(
        integer_columns)].applymap("{0:.3f}".format)
    #df_cb_counts = df_cb_counts.applymap("{0:.3f}".format)

    # in the geodataframe we can drop the duplicates avoiding overlap
    gdf_dropdp = gdf_sel.drop_duplicates(subset=['transectnummer', 'som_key'])

    # one final check if all is fine
    print('# one final check if all is fine')
    gdf_dropdp.head()
    df_cb_counts.head()

    #user_sound()
    #answer = ask_user()
    answer = True
    if answer == True:
        # save the spatial GeoDataFrame to a geojson
        json_locs_out = r'D:\Projects\Pr\2877.20\resultaten\json\d2018_05_16\transect_locations_{}.json'.format(
            key)
        with open(json_locs_out, 'w') as f:
            f.write(gdf_dropdp.to_json())

        # and the codebook DataFrame to a csv
        csv_som_out = r'D:\Projects\Pr\2877.20\resultaten\csv\d2018_05_16\transect_som_codebook_{}.csv'.format(
            key)
        df_cb_counts.to_csv(csv_som_out, index=False)

        # load the spatial GeoJSON from file
        vega_spec = json.load(open(json_locs_out))
        # json data uploaden naar data portal
        dp.setEntryDatabase(database='PR2877_20', key='transects{}'.format(key),
                            data=json.dumps(vega_spec), description='Transects Duinen')

        output = StringIO()
        df_cb_counts.to_csv(output, index=False)

        dp.setEntryDatabase(database='PR2877_20', key='som{}'.format(key),
                            data=output.getvalue(), description='Self-organizing map Duinen for {}'.format(key))
    else:
        print('results for {} not saved and not uploaded'.format(key))
# Out:
#  Training...
# --------------------------------------------------------------
#  details:
#       > data len is 5695 and data dimension is 6
#       > map size is 50,60
#       > array size in log10 scale is 8.010766233518424
#       > number of jobs in parallel: 1
#  -------------------------------------------------------------
#
#  pca_linear_initialization took: 0.045000 seconds
#  Rough training...
#  radius_ini: 8.000000 , radius_final: 2.000000, trainlen: 16
# T4T5
# maxtrainlen %d inf
#  find_bmu took: 0.405000 seconds
#  update_codebook_voronoi took: 0.014000 seconds
#  epoch: 1 ---> elapsed time:  0.563000, quantization error: 1.095848
#
#  find_bmu took: 0.503000 seconds
#  update_codebook_voronoi took: 0.013000 seconds
#  epoch: 2 ---> elapsed time:  0.671000, quantization error: 0.911601
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.012000 seconds
#  epoch: 3 ---> elapsed time:  0.676000, quantization error: 0.772564
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 4 ---> elapsed time:  0.687000, quantization error: 0.704107
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.014000 seconds
#  epoch: 5 ---> elapsed time:  0.677000, quantization error: 0.662455
#
#  find_bmu took: 0.505000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 6 ---> elapsed time:  0.687000, quantization error: 0.628785
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.013000 seconds
#  epoch: 7 ---> elapsed time:  0.668000, quantization error: 0.595545
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.014000 seconds
#  epoch: 8 ---> elapsed time:  0.680000, quantization error: 0.559463
#
#  find_bmu took: 0.505000 seconds
#  update_codebook_voronoi took: 0.013000 seconds
#  epoch: 9 ---> elapsed time:  0.681000, quantization error: 0.524516
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.012000 seconds
#  epoch: 10 ---> elapsed time:  0.681000, quantization error: 0.489544
#
#  find_bmu took: 0.505000 seconds
#  update_codebook_voronoi took: 0.025000 seconds
#  epoch: 11 ---> elapsed time:  0.679000, quantization error: 0.455213
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 12 ---> elapsed time:  0.705000, quantization error: 0.420749
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 13 ---> elapsed time:  0.679000, quantization error: 0.386239
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.011000 seconds
#  epoch: 14 ---> elapsed time:  0.659000, quantization error: 0.351239
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.013000 seconds
#  epoch: 15 ---> elapsed time:  0.681000, quantization error: 0.315729
#
#  find_bmu took: 0.505000 seconds
#  update_codebook_voronoi took: 0.013000 seconds
#  epoch: 16 ---> elapsed time:  0.665000, quantization error: 0.279083
#
#  Finetune training...
#  radius_ini: 2.000000 , radius_final: 1.000000, trainlen: 22
# maxtrainlen %d inf
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 1 ---> elapsed time:  0.668000, quantization error: 0.240501
#
#  find_bmu took: 0.503000 seconds
#  update_codebook_voronoi took: 0.012000 seconds
#  epoch: 2 ---> elapsed time:  0.667000, quantization error: 0.235766
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 3 ---> elapsed time:  0.675000, quantization error: 0.228960
#
#  find_bmu took: 0.505000 seconds
#  update_codebook_voronoi took: 0.014000 seconds
#  epoch: 4 ---> elapsed time:  0.664000, quantization error: 0.222580
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.011000 seconds
#  epoch: 5 ---> elapsed time:  0.665000, quantization error: 0.216633
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.012000 seconds
#  epoch: 6 ---> elapsed time:  0.676000, quantization error: 0.211356
#
#  find_bmu took: 0.505000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 7 ---> elapsed time:  0.679000, quantization error: 0.206185
#
#  find_bmu took: 0.505000 seconds
#  update_codebook_voronoi took: 0.012000 seconds
#  epoch: 8 ---> elapsed time:  0.667000, quantization error: 0.200608
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 9 ---> elapsed time:  0.679000, quantization error: 0.195555
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.014000 seconds
#  epoch: 10 ---> elapsed time:  0.674000, quantization error: 0.190588
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.011000 seconds
#  epoch: 11 ---> elapsed time:  0.672000, quantization error: 0.185421
#
#  find_bmu took: 0.503000 seconds
#  update_codebook_voronoi took: 0.014000 seconds
#  epoch: 12 ---> elapsed time:  0.688000, quantization error: 0.180298
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.013000 seconds
#  epoch: 13 ---> elapsed time:  0.716000, quantization error: 0.175158
#
#  find_bmu took: 0.505000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 14 ---> elapsed time:  0.710000, quantization error: 0.170200
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 15 ---> elapsed time:  0.707000, quantization error: 0.165102
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 16 ---> elapsed time:  0.715000, quantization error: 0.160074
#
#  find_bmu took: 0.503000 seconds
#  update_codebook_voronoi took: 0.014000 seconds
#  epoch: 17 ---> elapsed time:  0.719000, quantization error: 0.154775
#
#  find_bmu took: 0.505000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 18 ---> elapsed time:  0.727000, quantization error: 0.149328
#
#  find_bmu took: 0.505000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 19 ---> elapsed time:  0.739000, quantization error: 0.143810
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 20 ---> elapsed time:  0.740000, quantization error: 0.138522
#
#  find_bmu took: 0.504000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 21 ---> elapsed time:  0.756000, quantization error: 0.133506
#
#  find_bmu took: 0.505000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 22 ---> elapsed time:  0.760000, quantization error: 0.128267
#
#  --------------------------------------------------------------
#  Final quantization error: 0.128267
#  train took: 26.251000 seconds
# GDAL_DATA: C:\Python35\Lib\site-packages\osgeo\data\gdal
# PROJ_LIB: c:\python35\lib\site-packages\osgeo\data\proj
# Got coordinate system
# Failed to auto identify EPSG: 7
# Params: b'+proj=sterea +lat_0=52.15616055555555 +lon_0=5.38763888888889 +k=0.9999079 +x_0=155000 +y_0=463000 +ellps=bessel +units=m +no_defs '
# Index: 0
# Got coordinate system
# Flushed buffer
# Stopped session
# {'lon_0': 5.38763888888889, 'ellps': 'bessel', 'units': 'm', 'proj': 'sterea', 'no_defs': True, 'y_0': 463000, 'lat_0': 52.15616055555555, 'k': 0.9999079, 'x_0': 155000}
# # one final check if all is fine
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-6c3fd66bc957> in <module>()
#     128         json_locs_out = r'D:\Projects\Pr\2877.20\resultaten\data\json\d2018_05_16\transect_locations_{}.json'.format(
#     129             key)
# --> 130         with open(json_locs_out, 'w') as f:
#     131             f.write(gdf_dropdp.to_json())
#     132
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Projects\\Pr\\2877.20\\resultaten\\data\\json\\d2018_05_16\\transect_locations_T4T5.json'
