# %%
import subprocess as sp
import glob
import os
import concurrent.futures

# %%
def cmd(command, parse_directly=False):
    
    if parse_directly==True:
        #print(command)
        norm = sp.Popen(command,stdout=sp.PIPE, shell=True)
    else:
        #print(sp.list2cmdline(command))
        norm = sp.Popen(sp.list2cmdline(command),stdout=sp.PIPE, shell=True)            
             
    out_cmd = norm.communicate()
    return out_cmd

# %%
def func_fillnodata(in_file):
    # The fill_nodata will be named "<original_filename>_fillnodata.asc"
    base_filename, file_extension = os.path.splitext(in_file)
    tmp_file_tif = r'{0}_fillnodata{1}'.format(base_filename,'.tif')    
    out_file =  r'{0}_fillnodata{1}'.format(base_filename,file_extension)
        
    python_exe = r'C:\Python35\python.exe'
    rootOgrGdal = r'C:\Python35\Lib\site-packages\osgeo'
    gdal_fillnodata = os.path.join(rootOgrGdal, 'scripts','gdal_fillnodata.py')    
    gdal_translate = os.path.join(rootOgrGdal, 'gdal_translate.exe')
    
    command = [python_exe, gdal_fillnodata, '-q', '-md', '600', in_file, tmp_file_tif]
    cmd(command)

    command = [gdal_translate, '-of', 'AAIGrid', '-a_nodata', '-9999', tmp_file_tif, out_file]
    cmd(command)    
    
    
    return os.path.basename(out_file)

# %%
asc_files = glob.glob(r'D:\FEWSProjecten\OmsWaddenzee\trunk\fews\Import\hkv\coefficienten\asciiData//*/*/*.asc', recursive=True)
#asc_files = asc_files[0:5]

# %%
for asc_file in asc_files:
    out_file = func_fillnodata(asc_file)
    print(r'processed {0} into {1}'.format(os.path.basename(asc_file),out_file))
# Out:
# processed grid175_20170707000000.asc into grid175_20170707000000_fillnodata.asc
# processed grid176_20170707000000.asc into grid176_20170707000000_fillnodata.asc
# processed grid200_20170707000000.asc into grid200_20170707000000_fillnodata.asc
# processed grid202_20170707000000.asc into grid202_20170707000000_fillnodata.asc
# processed grid228_20170707000000.asc into grid228_20170707000000_fillnodata.asc
# processed grid315_20170707000000.asc into grid315_20170707000000_fillnodata.asc
# processed grid316_20170707000000.asc into grid316_20170707000000_fillnodata.asc
# processed grid316_20170707000000_01.asc into grid316_20170707000000_01_fillnodata.asc
# processed grid317_20170707000000.asc into grid317_20170707000000_fillnodata.asc
# processed grid319_20170707000000.asc into grid319_20170707000000_fillnodata.asc
# processed grid321_20170707000000.asc into grid321_20170707000000_fillnodata.asc
# processed grid322_20170707000000.asc into grid322_20170707000000_fillnodata.asc
# processed grid322_20170707000000_01.asc into grid322_20170707000000_01_fillnodata.asc
# processed grid323_20170707000000.asc into grid323_20170707000000_fillnodata.asc
# processed grid389_20170707000000.asc into grid389_20170707000000_fillnodata.asc
# processed grid451_20170707000000.asc into grid451_20170707000000_fillnodata.asc
# processed grid045_20170707000000.asc into grid045_20170707000000_fillnodata.asc
# processed grid045_20170707000000_fillnodata.asc into grid045_20170707000000_fillnodata_fillnodata.asc
# processed grid079_20170707000000.asc into grid079_20170707000000_fillnodata.asc
# processed grid079_20170707000000_fillnodata.asc into grid079_20170707000000_fillnodata_fillnodata.asc
# processed grid081_20170707000000.asc into grid081_20170707000000_fillnodata.asc
# processed grid081_20170707000000_fillnodata.asc into grid081_20170707000000_fillnodata_fillnodata.asc
# processed grid083_20170707000000.asc into grid083_20170707000000_fillnodata.asc
# processed grid083_20170707000000_fillnodata.asc into grid083_20170707000000_fillnodata_fillnodata.asc
# processed grid084_20170707000000.asc into grid084_20170707000000_fillnodata.asc
# processed grid084_20170707000000_fillnodata.asc into grid084_20170707000000_fillnodata_fillnodata.asc
# processed grid114_20170707000000.asc into grid114_20170707000000_fillnodata.asc
# processed grid114_20170707000000_fillnodata.asc into grid114_20170707000000_fillnodata_fillnodata.asc
# processed grid129_20170707000000.asc into grid129_20170707000000_fillnodata.asc
# processed grid129_20170707000000_fillnodata.asc into grid129_20170707000000_fillnodata_fillnodata.asc
# processed grid132_20170707000000.asc into grid132_20170707000000_fillnodata.asc
# processed grid132_20170707000000_fillnodata.asc into grid132_20170707000000_fillnodata_fillnodata.asc
# processed grid135_20170707000000.asc into grid135_20170707000000_fillnodata.asc
# processed grid135_20170707000000_fillnodata.asc into grid135_20170707000000_fillnodata_fillnodata.asc
# processed grid138_20170707000000.asc into grid138_20170707000000_fillnodata.asc
# processed grid138_20170707000000_fillnodata.asc into grid138_20170707000000_fillnodata_fillnodata.asc
# processed grid140_20170707000000.asc into grid140_20170707000000_fillnodata.asc
# processed grid140_20170707000000_fillnodata.asc into grid140_20170707000000_fillnodata_fillnodata.asc
# processed grid143_20170707000000.asc into grid143_20170707000000_fillnodata.asc
# processed grid143_20170707000000_fillnodata.asc into grid143_20170707000000_fillnodata_fillnodata.asc
# processed grid146_20170707000000.asc into grid146_20170707000000_fillnodata.asc
# processed grid146_20170707000000_fillnodata.asc into grid146_20170707000000_fillnodata_fillnodata.asc
# processed grid148_20170707000000.asc into grid148_20170707000000_fillnodata.asc
# processed grid148_20170707000000_fillnodata.asc into grid148_20170707000000_fillnodata_fillnodata.asc
# processed grid152_20170707000000.asc into grid152_20170707000000_fillnodata.asc
# processed grid152_20170707000000_fillnodata.asc into grid152_20170707000000_fillnodata_fillnodata.asc
# processed grid159_20170707000000.asc into grid159_20170707000000_fillnodata.asc
# processed grid159_20170707000000_fillnodata.asc into grid159_20170707000000_fillnodata_fillnodata.asc
# processed grid160_20170707000000.asc into grid160_20170707000000_fillnodata.asc
# processed grid160_20170707000000_fillnodata.asc into grid160_20170707000000_fillnodata_fillnodata.asc
# processed grid161_20170707000000.asc into grid161_20170707000000_fillnodata.asc
# processed grid161_20170707000000_fillnodata.asc into grid161_20170707000000_fillnodata_fillnodata.asc
# processed grid162_20170707000000.asc into grid162_20170707000000_fillnodata.asc
# processed grid162_20170707000000_fillnodata.asc into grid162_20170707000000_fillnodata_fillnodata.asc
# processed grid163_20170707000000.asc into grid163_20170707000000_fillnodata.asc
# processed grid163_20170707000000_fillnodata.asc into grid163_20170707000000_fillnodata_fillnodata.asc
# processed grid164_20170707000000.asc into grid164_20170707000000_fillnodata.asc
# processed grid164_20170707000000_fillnodata.asc into grid164_20170707000000_fillnodata_fillnodata.asc
# processed grid165_20170707000000.asc into grid165_20170707000000_fillnodata.asc
# processed grid165_20170707000000_fillnodata.asc into grid165_20170707000000_fillnodata_fillnodata.asc
# processed grid166_20170707000000.asc into grid166_20170707000000_fillnodata.asc
# processed grid166_20170707000000_fillnodata.asc into grid166_20170707000000_fillnodata_fillnodata.asc
# processed grid167_20170707000000.asc into grid167_20170707000000_fillnodata.asc
# processed grid167_20170707000000_fillnodata.asc into grid167_20170707000000_fillnodata_fillnodata.asc
# processed grid168_20170707000000.asc into grid168_20170707000000_fillnodata.asc
# processed grid168_20170707000000_fillnodata.asc into grid168_20170707000000_fillnodata_fillnodata.asc
# processed grid169_20170707000000.asc into grid169_20170707000000_fillnodata.asc
# processed grid169_20170707000000_fillnodata.asc into grid169_20170707000000_fillnodata_fillnodata.asc
# processed grid170_20170707000000.asc into grid170_20170707000000_fillnodata.asc
# processed grid170_20170707000000_fillnodata.asc into grid170_20170707000000_fillnodata_fillnodata.asc
# processed grid171_20170707000000.asc into grid171_20170707000000_fillnodata.asc
# processed grid171_20170707000000_fillnodata.asc into grid171_20170707000000_fillnodata_fillnodata.asc
# processed grid172_20170707000000.asc into grid172_20170707000000_fillnodata.asc
# processed grid172_20170707000000_fillnodata.asc into grid172_20170707000000_fillnodata_fillnodata.asc
# processed grid173_20170707000000.asc into grid173_20170707000000_fillnodata.asc
# processed grid173_20170707000000_fillnodata.asc into grid173_20170707000000_fillnodata_fillnodata.asc
# processed grid174_20170707000000.asc into grid174_20170707000000_fillnodata.asc
# processed grid174_20170707000000_fillnodata.asc into grid174_20170707000000_fillnodata_fillnodata.asc
# processed grid175_20170707000000.asc into grid175_20170707000000_fillnodata.asc
# processed grid175_20170707000000_fillnodata.asc into grid175_20170707000000_fillnodata_fillnodata.asc
# processed grid176_20170707000000.asc into grid176_20170707000000_fillnodata.asc
# processed grid176_20170707000000_fillnodata.asc into grid176_20170707000000_fillnodata_fillnodata.asc
# processed grid177_20170707000000.asc into grid177_20170707000000_fillnodata.asc
# processed grid177_20170707000000_fillnodata.asc into grid177_20170707000000_fillnodata_fillnodata.asc
# processed grid178_20170707000000.asc into grid178_20170707000000_fillnodata.asc
# processed grid178_20170707000000_fillnodata.asc into grid178_20170707000000_fillnodata_fillnodata.asc
# processed grid179_20170707000000.asc into grid179_20170707000000_fillnodata.asc
# processed grid179_20170707000000_fillnodata.asc into grid179_20170707000000_fillnodata_fillnodata.asc
# processed grid180_20170707000000.asc into grid180_20170707000000_fillnodata.asc
# processed grid180_20170707000000_fillnodata.asc into grid180_20170707000000_fillnodata_fillnodata.asc
# processed grid181_20170707000000.asc into grid181_20170707000000_fillnodata.asc
# processed grid181_20170707000000_fillnodata.asc into grid181_20170707000000_fillnodata_fillnodata.asc
# processed grid182_20170707000000.asc into grid182_20170707000000_fillnodata.asc
# processed grid182_20170707000000_fillnodata.asc into grid182_20170707000000_fillnodata_fillnodata.asc
# processed grid183_20170707000000.asc into grid183_20170707000000_fillnodata.asc
# processed grid183_20170707000000_fillnodata.asc into grid183_20170707000000_fillnodata_fillnodata.asc
# processed grid184_20170707000000.asc into grid184_20170707000000_fillnodata.asc
# processed grid184_20170707000000_fillnodata.asc into grid184_20170707000000_fillnodata_fillnodata.asc
# processed grid185_20170707000000.asc into grid185_20170707000000_fillnodata.asc
# processed grid185_20170707000000_fillnodata.asc into grid185_20170707000000_fillnodata_fillnodata.asc
# processed grid186_20170707000000.asc into grid186_20170707000000_fillnodata.asc
# processed grid186_20170707000000_fillnodata.asc into grid186_20170707000000_fillnodata_fillnodata.asc
# processed grid187_20170707000000.asc into grid187_20170707000000_fillnodata.asc
# processed grid187_20170707000000_fillnodata.asc into grid187_20170707000000_fillnodata_fillnodata.asc
# processed grid188_20170707000000.asc into grid188_20170707000000_fillnodata.asc
# processed grid188_20170707000000_fillnodata.asc into grid188_20170707000000_fillnodata_fillnodata.asc
# processed grid189_20170707000000.asc into grid189_20170707000000_fillnodata.asc
# processed grid189_20170707000000_fillnodata.asc into grid189_20170707000000_fillnodata_fillnodata.asc
# processed grid190_20170707000000.asc into grid190_20170707000000_fillnodata.asc
# processed grid190_20170707000000_fillnodata.asc into grid190_20170707000000_fillnodata_fillnodata.asc
# processed grid191_20170707000000.asc into grid191_20170707000000_fillnodata.asc
# processed grid191_20170707000000_fillnodata.asc into grid191_20170707000000_fillnodata_fillnodata.asc
# processed grid192_20170707000000.asc into grid192_20170707000000_fillnodata.asc
# processed grid192_20170707000000_fillnodata.asc into grid192_20170707000000_fillnodata_fillnodata.asc
# processed grid193_20170707000000.asc into grid193_20170707000000_fillnodata.asc
# processed grid193_20170707000000_fillnodata.asc into grid193_20170707000000_fillnodata_fillnodata.asc
# processed grid194_20170707000000.asc into grid194_20170707000000_fillnodata.asc
# processed grid194_20170707000000_fillnodata.asc into grid194_20170707000000_fillnodata_fillnodata.asc
# processed grid195_20170707000000.asc into grid195_20170707000000_fillnodata.asc
# processed grid195_20170707000000_fillnodata.asc into grid195_20170707000000_fillnodata_fillnodata.asc
# processed grid196_20170707000000.asc into grid196_20170707000000_fillnodata.asc
# processed grid196_20170707000000_fillnodata.asc into grid196_20170707000000_fillnodata_fillnodata.asc
# processed grid197_20170707000000.asc into grid197_20170707000000_fillnodata.asc
# processed grid197_20170707000000_fillnodata.asc into grid197_20170707000000_fillnodata_fillnodata.asc
# processed grid198_20170707000000.asc into grid198_20170707000000_fillnodata.asc
# processed grid198_20170707000000_fillnodata.asc into grid198_20170707000000_fillnodata_fillnodata.asc
# processed grid199_20170707000000.asc into grid199_20170707000000_fillnodata.asc
# processed grid199_20170707000000_fillnodata.asc into grid199_20170707000000_fillnodata_fillnodata.asc
# processed grid200_20170707000000.asc into grid200_20170707000000_fillnodata.asc
# processed grid200_20170707000000_fillnodata.asc into grid200_20170707000000_fillnodata_fillnodata.asc
# processed grid201_20170707000000.asc into grid201_20170707000000_fillnodata.asc
# processed grid201_20170707000000_fillnodata.asc into grid201_20170707000000_fillnodata_fillnodata.asc
# processed grid202_20170707000000.asc into grid202_20170707000000_fillnodata.asc
# processed grid202_20170707000000_fillnodata.asc into grid202_20170707000000_fillnodata_fillnodata.asc
# processed grid203_20170707000000.asc into grid203_20170707000000_fillnodata.asc
# processed grid203_20170707000000_fillnodata.asc into grid203_20170707000000_fillnodata_fillnodata.asc
# processed grid204_20170707000000.asc into grid204_20170707000000_fillnodata.asc
# processed grid204_20170707000000_fillnodata.asc into grid204_20170707000000_fillnodata_fillnodata.asc
# processed grid205_20170707000000.asc into grid205_20170707000000_fillnodata.asc
# processed grid205_20170707000000_fillnodata.asc into grid205_20170707000000_fillnodata_fillnodata.asc
# processed grid206_20170707000000.asc into grid206_20170707000000_fillnodata.asc
# processed grid206_20170707000000_fillnodata.asc into grid206_20170707000000_fillnodata_fillnodata.asc
# processed grid216_20170707000000.asc into grid216_20170707000000_fillnodata.asc
# processed grid216_20170707000000_fillnodata.asc into grid216_20170707000000_fillnodata_fillnodata.asc
# processed grid221_20170707000000.asc into grid221_20170707000000_fillnodata.asc
# processed grid221_20170707000000_fillnodata.asc into grid221_20170707000000_fillnodata_fillnodata.asc
# processed grid224_20170707000000.asc into grid224_20170707000000_fillnodata.asc
# processed grid224_20170707000000_fillnodata.asc into grid224_20170707000000_fillnodata_fillnodata.asc
# processed grid225_20170707000000.asc into grid225_20170707000000_fillnodata.asc
# processed grid225_20170707000000_fillnodata.asc into grid225_20170707000000_fillnodata_fillnodata.asc
# processed grid226_20170707000000.asc into grid226_20170707000000_fillnodata.asc
# processed grid226_20170707000000_fillnodata.asc into grid226_20170707000000_fillnodata_fillnodata.asc
# processed grid227_20170707000000.asc into grid227_20170707000000_fillnodata.asc
# processed grid227_20170707000000_fillnodata.asc into grid227_20170707000000_fillnodata_fillnodata.asc
# processed grid228_20170707000000.asc into grid228_20170707000000_fillnodata.asc
# processed grid228_20170707000000_fillnodata.asc into grid228_20170707000000_fillnodata_fillnodata.asc
# processed grid229_20170707000000.asc into grid229_20170707000000_fillnodata.asc
# processed grid229_20170707000000_fillnodata.asc into grid229_20170707000000_fillnodata_fillnodata.asc
# processed grid230_20170707000000.asc into grid230_20170707000000_fillnodata.asc
# processed grid230_20170707000000_fillnodata.asc into grid230_20170707000000_fillnodata_fillnodata.asc
# processed grid231_20170707000000.asc into grid231_20170707000000_fillnodata.asc
# processed grid231_20170707000000_fillnodata.asc into grid231_20170707000000_fillnodata_fillnodata.asc
# processed grid234_20170707000000.asc into grid234_20170707000000_fillnodata.asc
# processed grid234_20170707000000_fillnodata.asc into grid234_20170707000000_fillnodata_fillnodata.asc
# processed grid237_20170707000000.asc into grid237_20170707000000_fillnodata.asc
# processed grid237_20170707000000_fillnodata.asc into grid237_20170707000000_fillnodata_fillnodata.asc
# processed grid238_20170707000000.asc into grid238_20170707000000_fillnodata.asc
# processed grid238_20170707000000_fillnodata.asc into grid238_20170707000000_fillnodata_fillnodata.asc
# processed grid241_20170707000000.asc into grid241_20170707000000_fillnodata.asc
# processed grid241_20170707000000_fillnodata.asc into grid241_20170707000000_fillnodata_fillnodata.asc
# processed grid242_20170707000000.asc into grid242_20170707000000_fillnodata.asc
# processed grid242_20170707000000_fillnodata.asc into grid242_20170707000000_fillnodata_fillnodata.asc
# processed grid249_20170707000000.asc into grid249_20170707000000_fillnodata.asc
# processed grid249_20170707000000_fillnodata.asc into grid249_20170707000000_fillnodata_fillnodata.asc
# processed grid254_20170707000000.asc into grid254_20170707000000_fillnodata.asc
# processed grid254_20170707000000_fillnodata.asc into grid254_20170707000000_fillnodata_fillnodata.asc
# processed grid256_20170707000000.asc into grid256_20170707000000_fillnodata.asc
# processed grid256_20170707000000_fillnodata.asc into grid256_20170707000000_fillnodata_fillnodata.asc
# processed grid265_20170707000000.asc into grid265_20170707000000_fillnodata.asc
# processed grid265_20170707000000_fillnodata.asc into grid265_20170707000000_fillnodata_fillnodata.asc

# %%
# with concurrent.futures.ProcessPoolExecutor() as executor:
#     asc_files = glob.glob(r'D:\FEWSProjecten\OmsWaddenzee\trunk\fews\Import\hkv\coefficienten\asciiData//*/*/*.asc', recursive=True)
#     asc_files = asc_files[0:5]
#     # Process the list of files, but split the work across the process pool to use all CPUs!
#     for in_file, out_file in zip(asc_files, executor.map(func_fillnodata, asc_files)):
#         print(r'processed {0} into {1}'.format(os.path.basename(in_file),out_file))
