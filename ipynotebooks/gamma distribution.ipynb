# %%
import pandas as pd
import scipy as sp
import scipy.stats as ss
import os
from mattijn import dikkelul

# %%
path = r'C:\Users\lenovo\Downloads\SPI_samplefiles//Kita.cor'
series = pd.read_csv(path, sep=None)
# Out:
# Using Python parser to sniff delimiter

# %%
series['PREC'].plot()

# %%
ss.gamma.rvs(fit(series['PREC'])
# Out:
# (0.17190671766888022, -2.0033799604408631e-26, 83.163188452215365)

# %%
ss.gamma.cdf(series['PREC'],)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-b24f3b221bba> in <module>()
# ----> 1 ss.gamma.cdf(series['PREC'])
#
# D:\Python33\lib\site-packages\scipy\stats\distributions.py in cdf(self, x, *args, **kwds)
#    1300         if any(cond):  #call only if at least 1 entry
#    1301             goodargs = argsreduce(cond, *((x,)+args))
# -> 1302             place(output,cond,self._cdf(*goodargs))
#    1303         if output.ndim == 0:
#    1304             return output[()]
#
# TypeError: _cdf() missing 1 required positional argument: 'a'
