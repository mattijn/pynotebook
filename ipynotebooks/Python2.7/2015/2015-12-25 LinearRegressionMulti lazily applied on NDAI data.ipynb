# %%
import numpy as np
from osgeo import gdal
import os
import sys

# %%
def saveRaster(path, array, dsSource, datatype=3, formatraster="GTiff", nan=None): 
    """
    Datatypes:
    unknown = 0
    byte = 1
    unsigned int16 = 2
    signed int16 = 3
    unsigned int32 = 4
    signed int32 = 5
    float32 = 6
    float64 = 7
    complex int16 = 8
    complex int32 = 9
    complex float32 = 10
    complex float64 = 11
    float32 = 6, 
    signed int = 3
    
    Formatraster:
    GeoTIFF = GTiff
    Erdas = HFA (output = .img)
    OGC web map service = WMS
    png = PNG
    """
    # Set Driver
    format_ = formatraster #save as format
    driver = gdal.GetDriverByName( format_ )
    driver.Register()
    
    # Set Metadata for Raster output
    cols = dsSource.RasterXSize
    rows = dsSource.RasterYSize
    bands = dsSource.RasterCount
    datatype = datatype#band.DataType
    
    # Set Projection for Raster
    outDataset = driver.Create(path, cols, rows, bands, datatype)
    geoTransform = dsSource.GetGeoTransform()
    outDataset.SetGeoTransform(geoTransform)
    proj = dsSource.GetProjection()
    outDataset.SetProjection(proj)
    
    # Write output to band 1 of new Raster and write NaN value
    outBand = outDataset.GetRasterBand(1)
    if nan != None:
        outBand.SetNoDataValue(nan)
    outBand.WriteArray(array) #save input array
    #outBand.WriteArray(dem)
    
    # Close and finalise newly created Raster
    #F_M01 = None
    outBand = None
    proj = None
    geoTransform = None
    outDataset = None
    driver = None
    datatype = None
    bands = None
    rows = None
    cols = None
    driver = None
    array = None

# %%
def listall(RootFolder, wildcard='', extension='.tif'):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if wildcard in name
                     if name.endswith(extension)]
    return lists

# %%
class LinearRegression_Multi:
    def stacked_lstsq(self, L, b, rcond=1e-10):
        """
        Solve L x = b, via SVD least squares cutting of small singular values
        L is an array of shape (..., M, N) and b of shape (..., M).
        Returns x of shape (..., N)
        """
        u, s, v = np.linalg.svd(L, full_matrices=False)
        s_max = s.max(axis=-1, keepdims=True)
        s_min = rcond*s_max
        inv_s = np.zeros_like(s)
        inv_s[s >= s_min] = 1/s[s>=s_min]
        x = np.einsum('...ji,...j->...i', v,
                      inv_s * np.einsum('...ji,...j->...i', u, b.conj()))
        return np.conj(x, x)    
    
    def center_data(self, X, y):
        """ Centers data to have mean zero along axis 0. 
        """
        # center X        
        X_mean = np.average(X,axis=1)
        X_std = np.ones(X.shape[0::2])
        X = X - X_mean[:,None,:] 
        # center y
        y_mean = np.average(y,axis=1)
        y = y - y_mean[:,None]
        return X, y, X_mean, y_mean, X_std

    def set_intercept(self, X_mean, y_mean, X_std):
        """ Calculate the intercept_
        """
        self.coef_ = self.coef_ / X_std # not really necessary
        self.intercept_ = y_mean - np.einsum('ij,ij->i',X_mean,self.coef_)

    def scores(self, y_pred, y_true ):
        """ 
        The coefficient R^2 is defined as (1 - u/v), where u is the regression
        sum of squares ((y_true - y_pred) ** 2).sum() and v is the residual
        sum of squares ((y_true - y_true.mean()) ** 2).sum().        
        """        
        u = ((y_true - y_pred) ** 2).sum(axis=-1)
        v = ((y_true - y_true.mean(axis=-1)[None].T) ** 2).sum(axis=-1)
        r_2 = 1 - u/v
        return r_2
    
    def fit(self,X, y):
        """ Fit linear model.        
        """        
        # get coefficients by applying linear regression on stack
        X_, y, X_mean, y_mean, X_std = self.center_data(X, y)
        self.coef_ = self.stacked_lstsq(X_, y)
        self.set_intercept(X_mean, y_mean, X_std)

    def predict(self, X):
        """Predict using the linear model
        """
        return np.einsum('ijx,ix->ij',X,self.coef_) + self.intercept_[None].T

# %%
def forecast(to_forecast, k=7, h=1, alpha=0.5):
    """
    Forecast method using linear regresion
    Input
    to_forecast: input of matrix to forecast
    k          : forecast window, number of previous observation to use
                 default 7 (one week)
    h          : forecast horizon, number of periods ahead to forecast
                 default 1 (one day)
    alpha      : default 0.5. Use first half to train, 2nd half to predict
                 0.1: use first 10% to train and remaining 90% to predict
                 0.9: use first 90% to train and remaining 10% to predict                  
    
    Output
    y_pred     : matrix containing the predictions
    R2         : matrix containing the R2 values
    """
    # prepare a matrix X where each row contains a forecast window
    shape = to_forecast.shape[:-1] + (to_forecast.shape[-1] - k + 1, k)
    strides = to_forecast.strides + (to_forecast.strides[-1],)
    X = np.lib.stride_tricks.as_strided(to_forecast, shape=shape, strides=strides)
    
    # prepare a matrix y with the target values for each row of X
    y = X[:,:,-1][:,h:]
    X = X[:,:-h]
    
    # training data is rounded down, prediction data is rounded up
    half_ = int(np.floor(to_forecast[0].shape[0]*alpha))
    half  = int(np.ceil(to_forecast[0].shape[0]*(1-alpha)))
    print 'training:',half_,'prediction:',half
    #half = to_forecast[0].shape[0]*0.5

    # do the work
    # apply linear regression
    LR_Multi = LinearRegression_Multi()
    # train first half of the data
    LR_Multi.fit(X[:,:half_], y[:,:half_])
    print 'shape X training:',X[:,:half_].shape
    print 'shape y training:',y[:,:half_].shape
    # predict second half of the data
    
    y_pred = LR_Multi.predict(X[:,half:])
    R2 = LR_Multi.scores(y_pred, y[:,half:])
    print 'shape X prediction:',X[:,half:].shape
    print 'shape y prediciton:',y[:,half:].shape
    
    return y_pred, R2

# %%
path_base = r'D:\Data\LS_DATA\NDAI-1day_IM_bbox_warp//NDAI_2003_001_IM_bbox_wrap.tif'
folder_ndai = r'D:\Data\LS_DATA\NDAI-1day_IM_bbox_warp'

# %%
# register all of the GDAL drivers
gdal.AllRegister()

# open the image
ds = gdal.Open(path_base)
if ds is None:
    print ('Could not open base file')
    sys.exit(1)

# get image size
rows = ds.RasterYSize
cols = ds.RasterXSize
bands = ds.RasterCount

# get the band and block sizes
band = ds.GetRasterBand(1)
base = band.ReadAsArray()
nan = band.GetNoDataValue()

#blockSizes = utils.GetBlockSize(band)
xBlockSize = 200
yBlockSize = 200

files_ndai = listall(folder_ndai)
noFiles = len(files_ndai)
Files = np.array([len(files_ndai)])
print ( noFiles )
# Out:
# 4379

# %%
# prepare output prediction array
window = 14 # forecast window (last 7 days)
horizon = 7 # forecast horizon (1 day)
alpha = 0.5
split = int(np.ceil(Files*(1-alpha)) - (window + horizon))
split
# Out:
# 2169

# %%
filename_out = files_ndai[(noFiles - split):]
print files_rename[0][0:-24]+'NDAI_W14H07_'+filename_out[0][-25:-17]+'.tif'
# Out:
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_021.tif

# %%
files_rename = listall(r'D:\tmp\ndai_out\NDAI\window14horizon7', wildcard='', extension='.tif')
len(files_rename)
files_rename[0][0:-24]
# Out:
# 'D:\\tmp\\ndai_out\\NDAI\\window14horizon7\\'

# %%
for idx, file in enumerate(files_rename):
    old = file
    new = file[0:-24]+'NDAI_W14H07_'+filename_out[idx][-25:-17]+'.tif'
    os.rename(old, new)
    print old, new, '\n'
# Out:
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_021.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_021.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_022.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_022.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_023.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_023.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_024.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_024.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_025.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_025.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_026.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_026.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_027.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_027.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_028.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_028.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_029.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_029.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_030.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_030.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_031.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_031.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_032.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_032.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_033.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_033.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_034.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_034.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_035.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_035.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_036.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_036.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_037.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_037.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_038.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_038.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_039.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_039.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_040.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_040.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_041.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_041.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_042.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_042.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_043.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_043.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_044.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_044.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_045.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_045.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_046.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_046.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_047.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_047.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_048.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_048.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_049.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_049.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_050.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_050.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_051.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_051.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_052.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_052.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_053.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_053.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_054.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_054.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_055.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_055.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_056.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_056.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_057.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_057.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_058.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_058.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_059.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_059.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_060.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_060.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_061.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_061.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_062.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_062.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_063.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_063.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_064.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_064.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_065.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_065.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_066.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_066.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_067.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_067.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_068.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_068.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_069.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_069.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_070.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_070.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_071.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_071.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_072.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_072.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_073.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_073.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_074.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_074.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_075.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_075.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_076.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_076.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_077.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_077.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_078.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_078.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_079.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_079.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_080.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_080.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_081.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_081.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_082.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_082.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_083.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_083.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_084.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_084.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_085.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_085.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_086.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_086.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_087.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_087.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_088.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_088.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_089.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_089.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_090.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_090.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_091.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_091.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_092.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_092.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_093.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_093.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_094.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_094.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_095.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_095.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_096.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_096.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_097.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_097.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_098.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_098.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_099.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_099.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_100.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_100.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_101.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_101.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_102.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_102.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_103.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_103.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_104.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_104.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_105.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_105.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_106.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_106.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_107.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_107.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_108.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_108.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_109.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_109.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_110.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_110.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_111.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_111.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_112.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_112.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_113.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_113.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_114.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_114.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_115.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_115.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_116.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_116.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_117.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_117.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_118.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_118.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_119.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_119.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_120.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_120.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_121.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_121.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_122.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_122.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_123.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_123.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_124.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_124.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_125.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_125.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_126.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_126.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_127.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_127.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_128.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_128.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_129.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_129.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_130.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_130.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_131.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_131.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_132.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_132.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_133.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_133.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_134.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_134.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_135.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_135.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_136.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_136.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_137.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_137.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_138.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_138.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_139.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_139.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_140.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_140.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_141.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_141.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_142.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_142.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_143.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_143.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_144.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_144.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_145.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_145.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_146.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_146.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_147.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_147.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_148.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_148.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_149.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_149.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_150.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_150.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_151.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_151.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_152.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_152.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_153.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_153.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_154.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_154.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_155.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_155.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_156.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_156.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_157.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_157.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_158.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_158.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_159.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_159.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_160.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_160.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_161.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_161.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_162.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_162.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_163.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_163.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_164.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_164.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_165.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_165.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_166.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_166.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_167.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_167.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_168.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_168.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_169.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_169.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_170.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_170.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_171.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_171.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_172.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_172.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_173.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_173.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_174.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_174.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_175.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_175.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_176.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_176.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_177.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_177.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_178.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_178.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_179.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_179.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_180.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_180.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_181.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_181.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_182.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_182.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_183.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_183.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_184.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_184.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_185.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_185.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_186.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_186.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_187.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_187.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_188.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_188.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_189.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_189.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_190.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_190.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_191.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_191.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_192.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_192.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_193.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_193.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_194.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_194.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_195.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_195.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_196.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_196.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_197.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_197.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_198.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_198.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_199.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_199.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_200.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_200.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_201.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_201.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_202.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_202.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_203.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_203.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_204.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_204.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_205.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_205.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_206.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_206.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_207.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_207.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_208.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_208.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_209.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_209.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_210.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_210.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_211.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_211.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_212.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_212.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_213.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_213.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_214.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_214.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_215.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_215.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_216.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_216.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_217.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_217.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_218.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_218.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_219.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_219.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_220.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_220.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_221.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_221.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_222.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_222.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_223.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_223.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_224.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_224.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_225.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_225.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_226.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_226.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_227.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_227.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_228.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_228.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_229.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_229.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_230.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_230.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_231.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_231.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_232.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_232.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_233.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_233.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_234.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_234.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_235.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_235.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_236.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_236.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_237.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_237.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_238.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_238.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_239.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_239.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_240.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_240.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_241.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_241.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_242.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_242.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_243.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_243.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_244.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_244.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_245.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_245.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_246.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_246.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_247.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_247.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_248.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_248.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_249.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_249.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_250.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_250.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_251.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_251.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_252.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_252.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_253.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_253.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_254.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_254.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_255.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_255.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_256.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_256.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_257.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_257.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_258.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_258.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_259.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_259.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_260.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_260.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_261.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_261.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_262.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_262.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_263.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_263.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_264.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_264.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_265.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_265.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_266.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_266.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_267.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_267.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_268.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_268.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_269.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_269.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_270.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_270.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_271.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_271.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_272.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_272.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_273.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_273.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_274.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_274.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_275.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_275.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_276.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_276.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_277.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_277.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_278.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_278.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_279.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_279.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_280.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_280.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_281.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_281.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_282.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_282.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_283.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_283.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_284.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_284.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_285.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_285.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_286.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_286.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_287.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_287.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_288.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_288.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_289.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_289.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_290.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_290.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_291.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_291.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_292.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_292.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_293.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_293.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_294.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_294.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_295.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_295.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_296.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_296.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_297.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_297.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_298.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_298.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_299.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_299.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_300.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_300.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_301.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_301.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_302.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_302.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_303.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_303.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_304.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_304.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_305.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_305.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_306.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_306.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_307.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_307.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_308.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_308.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_309.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_309.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_310.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_310.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_311.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_311.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_312.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_312.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_313.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_313.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_314.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_314.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_315.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_315.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_316.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_316.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_317.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_317.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_318.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_318.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_319.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_319.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_320.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_320.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_321.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_321.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_322.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_322.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_323.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_323.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_324.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_324.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_325.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_325.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_326.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_326.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_327.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_327.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_328.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_328.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_329.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_329.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_330.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_330.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_331.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_331.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_332.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_332.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_333.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_333.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_334.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_334.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_335.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_335.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_336.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_336.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_337.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_337.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_338.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_338.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_339.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_339.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_340.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_340.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_341.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_341.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_342.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_342.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_343.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_343.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_344.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_344.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_345.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_345.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_346.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_346.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_347.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_347.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_348.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_348.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_349.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_349.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_350.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_350.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_351.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_351.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_352.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_352.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_353.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_353.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_354.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_354.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_355.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_355.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_356.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_356.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_357.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_357.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_358.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_358.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_359.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_359.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_360.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_360.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_361.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_361.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_362.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_362.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_363.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_363.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_364.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_364.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2009_365.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2009_365.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_001.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_001.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_002.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_002.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_003.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_003.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_004.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_004.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_005.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_005.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_006.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_006.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_007.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_007.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_008.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_008.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_009.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_009.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_010.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_010.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_011.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_011.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_012.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_012.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_013.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_013.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_014.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_014.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_015.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_015.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_016.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_016.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_017.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_017.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_018.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_018.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_019.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_019.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_020.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_020.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_021.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_021.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_022.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_022.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_023.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_023.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_024.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_024.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_025.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_025.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_026.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_026.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_027.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_027.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_028.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_028.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_029.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_029.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2010_030.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2010_030.tif
#
# ...
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_240.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_240.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_241.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_241.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_242.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_242.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_243.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_243.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_244.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_244.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_245.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_245.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_246.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_246.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_247.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_247.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_248.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_248.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_249.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_249.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_250.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_250.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_251.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_251.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_252.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_252.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_253.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_253.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_254.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_254.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_255.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_255.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_256.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_256.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_257.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_257.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_258.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_258.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_259.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_259.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_260.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_260.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_261.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_261.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_262.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_262.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_263.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_263.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_264.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_264.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_265.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_265.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_266.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_266.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_267.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_267.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_268.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_268.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_269.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_269.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_270.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_270.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_271.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_271.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_272.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_272.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_273.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_273.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_274.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_274.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_275.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_275.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_276.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_276.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_277.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_277.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_278.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_278.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_279.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_279.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_280.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_280.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_281.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_281.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_282.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_282.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_283.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_283.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_284.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_284.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_285.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_285.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_286.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_286.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_287.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_287.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_288.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_288.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_289.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_289.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_290.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_290.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_291.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_291.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_292.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_292.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_293.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_293.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_294.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_294.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_296.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_296.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_297.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_297.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_298.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_298.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_299.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_299.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_300.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_300.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_301.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_301.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_302.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_302.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_303.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_303.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_304.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_304.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_305.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_305.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_306.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_306.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_307.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_307.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_308.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_308.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_309.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_309.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_310.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_310.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_311.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_311.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_312.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_312.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_313.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_313.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_314.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_314.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_315.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_315.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_316.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_316.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_317.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_317.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_318.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_318.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_319.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_319.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_320.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_320.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_321.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_321.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_322.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_322.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_323.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_323.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_324.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_324.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_325.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_325.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_326.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_326.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_327.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_327.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_328.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_328.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_329.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_329.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_330.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_330.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_331.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_331.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_332.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_332.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_333.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_333.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_334.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_334.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_335.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_335.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_336.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_336.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_337.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_337.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_338.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_338.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_339.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_339.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_340.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_340.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_341.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_341.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_342.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_342.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_343.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_343.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_344.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_344.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_345.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_345.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_346.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_346.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_347.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_347.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_348.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_348.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_349.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_349.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_350.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_350.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_351.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_351.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_352.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_352.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_353.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_353.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_354.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_354.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_355.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_355.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_356.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_356.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_357.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_357.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_358.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_358.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_359.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_359.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_360.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_360.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_361.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_361.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_362.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_362.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_363.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_363.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_364.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_364.tif
#
# D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W07H01_2014_365.tif D:\tmp\ndai_out\NDAI\window14horizon7\NDAI_W14H07_2014_365.tif

# %%
os.rename(files_rename[0]
#'NDAI_R2_'+filename_out[i][-25:-17]+'.tif'
# Out:
# 'D:\\tmp\\ndai_out\\NDAI\\window7horizon1\\NDAI_R2_0000.tif'

# %%
#base_ = np.zeros(shape=(len_,rows,cols), dtype=np.float32)

# loop through the rows
for i in range(0, rows, yBlockSize): #(0, rows, yBlockSize)
    if i + yBlockSize < rows:
        numRows = yBlockSize
    else:
        numRows = rows - i
    
    # loop through the columns
    for j in range(0, cols, xBlockSize):# (0, cols, xBlockSize)
        if j + xBlockSize < cols:
            numCols = xBlockSize
        else:
            numCols = cols - j
        
        print ('column',j,'row',i,'numCols',numCols,'numRows',numRows)
        # set base array to fill 
        ap_ndai = np.zeros(shape=(noFiles,numRows,numCols), dtype=np.float32)        

        #select blocks from trmm and ndvi files
        for m, file_ndai in enumerate(files_ndai):
            try:
                raster = gdal.Open(file_ndai, gdal.GA_ReadOnly)
                band = raster.GetRasterBand(1)
                ap_ndai[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)
            except:
                print m,file_ndai

        #reshape from 3D to 2D
        ap_ndai_2D = ap_ndai.reshape((noFiles,numRows*numCols)).T
        ap_ndai_2D = np.nan_to_num(ap_ndai_2D)

        # prepare output prediction array
        window = 7 # forecast window (last 7 days)
        horizon = 1 # forecast horizon (1 day)
        alpha = 0.5
        split = int(np.ceil(ap_ndai_2D[0].shape[0]*(1-alpha)) - (window + 1))
        y_pred = np.zeros_like(ap_ndai_2D[:,:split])
        R2 = np.zeros((numRows,numCols)).ravel()
        # prepare prediction array
        #y_pred = np.zeros_like(ap_ndai_2D[:,int(math.ceil(ap_ndai_2D[0].shape[0]*(1-alpha))):])        
        #hants_trmm = np.zeros_like(ap_ndai_2D)

        # apply linear regression prediction lazily with maximum 10000 rows each time
        for k in range(0, (numRows*numCols), 10000):
            if k + 10000 < (numRows*numCols):
                l = k + 10000
            else:
                l = k + (numRows*numCols) - k
            print ('start',k,'end',l,ap_ndai_2D[k:l].shape)

            y_pred[k:l], R2[k:l]  = forecast(ap_ndai_2D[k:l], window, horizon, alpha)

        # reshape from 2D to 3D
        y_pred = y_pred.T.reshape(split,numRows,numCols)
        R2 = R2.reshape(numRows,numCols)
        
        # save 3D blocks to temp
        folder_temp = r'D:\tmp\ndai'
        file_temp_y_pred = 'Y_PRED_col_'+str(j).zfill(4)+'_row_'+str(i).zfill(4)+'_numCols_'+str(numCols).zfill(4)+'_numRows_'+str(numRows).zfill(4)
        file_temp_r2 = 'R2_col_'+str(j).zfill(4)+'_row_'+str(i).zfill(4)+'_numCols_'+str(numCols).zfill(4)+'_numRows_'+str(numRows).zfill(4)
        path_temp_y_pred = folder_temp + '//' + file_temp_y_pred
        path_temp_r2 = folder_temp + '//' + file_temp_r2
        print path_temp_y_pred
        print path_temp_r2
        np.save(path_temp_y_pred, y_pred)
        np.save(path_temp_r2, R2)

# %%
# load 2D tiles from temp and save as tif
folder_temp = r'D:\tmp\ndai\R2'
files_temp = listall(folder_temp, extension='.npy')
noFilesTemp = len(files_temp)
print ( noFilesTemp ) 

base_ = np.zeros(shape=(rows,cols), dtype=np.float32)
#for i in range(noFiles):
#    print (i)
for j in files_temp:
    print (j)
    numRows = int(j[-8:-4])
    numCols = int(j[-21:-17])    
    row = int(j[-34:-30])
    col = int(j[-43:-39])
    
    
    print ('col',col,'row',row,'numCols',numCols,'numRows',numRows)

    load_temp_tile = np.load(j,mmap_mode='r')
    base_[row:row+numRows,col:col+numCols] = load_temp_tile[:,:]

folder_out = r'D:\tmp\ndai_out\R2//'
file_out = 'NDAI_R2_.tif'
path_out = folder_out+file_out
print (path_out)
saveRaster(path_out,base_,ds,datatype=6)

# %%
split

# %%
# load 2D tiles from temp and save as tif
folder_temp = r'D:\tmp\ndai\ndai'
files_temp = listall(folder_temp, extension='.npy')
noFilesTemp = len(files_temp)
print ( noFilesTemp ) 

base_ = np.zeros(shape=(rows,cols), dtype=np.float32)
for i in range(noFiles):
    print (i)
    for j in files_temp:
        print (j)
        numRows = int(j[-8:-4])
        numCols = int(j[-21:-17])    
        row = int(j[-34:-30])
        col = int(j[-43:-39])


        print ('col',col,'row',row,'numCols',numCols,'numRows',numRows)

        load_temp_tile = np.load(j,mmap_mode='r')
        base_[row:row+numRows,col:col+numCols] = load_temp_tile[i,:,:]

    print '\n'
    folder_out = r'D:\tmp\ndai_out\R2//'
    file_out = 'NDAI_R2_'+str(i).zfill(4)+'.tif'
    path_out = folder_out+file_out
    print (path_out)
    saveRaster(path_out,base_,ds,datatype=6)

# %%
load_temp_tile[0,:]

# %%
str(200).zfill(4)
