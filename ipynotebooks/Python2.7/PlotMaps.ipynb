# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np
import os
import matplotlib.pyplot as plt
from osgeo import gdal, osr

# %%
def convertXY(xy_source, inproj, outproj):
    # function to convert coordinates

    shape = xy_source[0,:,:].shape
    size = xy_source[0,:,:].size

    # the ct object takes and returns pairs of x,y, not 2d grids
    # so the the grid needs to be reshaped (flattened) and back.
    ct = osr.CoordinateTransformation(inproj, outproj)
    xy_target = np.array(ct.TransformPoints(xy_source.reshape(2, size).T))

    xx = xy_target[:,0].reshape(shape)
    yy = xy_target[:,1].reshape(shape)

    return xx, yy
    
def listall(RootFolder, varname=''):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if varname in name
                     if name.endswith('.tif')]
    return lists
  
def setMap(rasterBase):

    # Read the data and metadata
    ds = gdal.Open(rasterBase)
    #band = ds.GetRasterBand(20)
    
    data = ds.ReadAsArray()
    gt = ds.GetGeoTransform()
    proj = ds.GetProjection()
    
    nan = ds.GetRasterBand(1).GetNoDataValue()
    if nan != None:
        data = np.ma.masked_equal(data,value=nan)
    
    xres = gt[1]
    yres = gt[5]
    
    # get the edge coordinates and add half the resolution 
    # to go to center coordinates
    xmin = gt[0] + xres * 0.5
    xmax = gt[0] + (xres * ds.RasterXSize) - xres * 0.5
    ymin = gt[3] + (yres * ds.RasterYSize) + yres * 0.5
    ymax = gt[3] - yres * 0.5
    
    x = ds.RasterXSize 
    y = ds.RasterYSize  
    extent = [ gt[0],gt[0]+x*gt[1], gt[3],gt[3]+y*gt[5]]
    #ds = None
    
    # create a grid of xy coordinates in the original projection
    xy_source = np.mgrid[xmin:xmax+xres:xres, ymax+yres:ymin:yres]
    
    return extent, xy_source, proj

# %%
RasterFolder = r'D:\Data\GPCP_doy8DayMean'
raster = listall(RasterFolder)
path = r'D:\Data\GPCP_30acc_anomalyNormTypeII//GPCP_2009193.tif'
#path = r'D:\Data\NDVI_agg_clip_anomalySVInormalized//NDVI_2009193.tif'
rasterBase = path#raster[0]
extent, xy_source, proj = setMap(rasterBase)
extent
# Out:
# [-179.875, 180.125, 89.875, -90.125]

# %% [markdown]
# PRECIPITATION

# %%
# Set the colormap and norm to correspond to the data for which
# the colorbar will be used.
cmap = cm.cool
norm = cm.colors.Normalize(vmin=-1, vmax=1)

# The third example illustrates the use of custom length colorbar
# extensions, used on a colorbar with discrete intervals.
cmap = cm.colors.ListedColormap([[1,1,1],
                                 [0.745,0.909,1.],
                                 [0.617,0.635,1.],
                                 [0.396,0.443,1.],
                                 [0.309,0.368,1.],
                                 [0.,0.086,0.784],
                                 [0.,0.,0.404],
                                 [1.,0.667,0.], # light organge
                                 [1.,0.309,0.], # dutch orange                                 
                                 [0.902,0.,0.], # red
                                 [0.462,0.05,0.],
                                 #[0.537,0.027,0.],
                                 ]) # purple

#cmap.set_under((0.239, 0., 0.)) # dark purple
cmap.set_over((0.709,0.,0.678)) # pruple   

bounds = [0, 0.5, 1, 1.5, 2, 3.5, 5, 7.5, 10., 12.5, 15.]     
norm = cm.colors.BoundaryNorm(bounds, cmap.N)

# %% [markdown]
# PRECIPITATION ANOMALY SPI

# %%
# Set the colormap and norm to correspond to the data for which
# the colorbar will be used.
cmap = cm.cool
norm = cm.colors.Normalize(vmin=-1, vmax=1)

# The third example illustrates the use of custom length colorbar
# extensions, used on a colorbar with discrete intervals.
cmap = cm.colors.ListedColormap([[0.470, 0.094, 0.], # dark blue
                                  [0.702, 0.278, 0.], # light blue
                                  [0.941, 0.580, 0.], # green
                                  [1., 0.745, 0.231], # light green
                                  [1., 0.847, 0.541],
                                  [1, 1, 1.], # null
                                  [0., 0.961, 0.961], # light yellow
                                  [0.204, 0.357, 0.969], # yellow
                                  [0., 0, 0.961], # orange
                                  [0.431, 0., 0.961], # red
                                  [0.706, 0., 0.961]]) # pink

cmap.set_under((0.239, 0., 0.)) # dark purple
cmap.set_over((0.961, 0., 0.961)) # brown    

#bounds =  [-5., -3.5, -2.5, -1.83, -1.17, -0.5, 0.5, 1.17, 1.83, 2.5, 3.5, 5.]
#bounds =  [-8., -6.5, -5.5, -4.83, -4.17, -3.5, -2.5, -1.83, -1.17, -0.5, 0.5, 2.]
#bounds = [-1., -.8,  -.6,  -.4,   -.20, -.05,  .05,    .2,   .4,   .6, .8, 1.]    
bounds = [-4., -3.,  -2.,  -1.5,   -1., -.5,  .5,    1.,   1.5,   2., 3., 4.]
#bounds = [-.3, -.25,  -.2,  -.15,   -.1, -.05,  .05,    .1,   .15,   .2, .25, .3]    # OLD
norm = cm.colors.BoundaryNorm(bounds, cmap.N)

# %% [markdown]
# SVI ANOMALY

# %%
# Set the colormap and norm to correspond to the data for which
# the colorbar will be used.
cmap = cm.cool
norm = cm.colors.Normalize(vmin=-1, vmax=1)

# The third example illustrates the use of custom length colorbar
# extensions, used on a colorbar with discrete intervals.
cmap = cm.colors.ListedColormap([[0.470, 0.094, 0.], # dark blue
                                  [0.702, 0.278, 0.], # light blue
                                  [0.941, 0.580, 0.], # green
                                  [1., 0.745, 0.231], # light green
                                  [1., 0.847, 0.541],
                                  [1, 1, 1.], # null
                                  [0.714, 0.839, 0.463], # light yellow
                                  [0.545, 0.729, 0.176], # yellow
                                  [0.376, 0.631, 0.], # orange
                                  [0.106, 0.522, 0.], # red
                                  [0, 0.412, 0.082]]) # pink

cmap.set_under((0.239, 0., 0.)) # dark purple
cmap.set_over((0., 0.298, 0.184)) # brown    

bounds = [-.3, -.25, -.2, -.15, -.1, -.05, .05, .1, .15, .2, .25, .3]
#bounds = [0.1, 0.2,  0.25, 0.30, 0.35, 0.4,0.6,0.65,0.70,0.75, 0.8, 0.9]

#bounds =  [-5., -3.5, -2.5, -1.83, -1.17, -0.5, 0.5, 1.17, 1.83, 2.5, 3.5, 5.]
#bounds =  [-8., -6.5, -5.5, -4.83, -4.17, -3.5, -2.5, -1.83, -1.17, -0.5, 0.5, 2.]
#bounds = [-1., -.8,  -.6,  -.4,   -.20, -.05,  .05,    .2,   .4,   .6, .8, 1.]    
#bounds = [-.3, -.25,  -.2,  -.15,   -.1, -.05,  .05,    .1,   .15,   .2, .25, .3]    # OLD
norm = cm.colors.BoundaryNorm(bounds, cmap.N)

# %%
ds = gdal.Open(path)# hased out raster[0])
array = ds.ReadAsArray()

fig = plt.figure(figsize=(10,10))

img_extent = (extent[0], extent[1], extent[2], extent[3])
img = np.flipud(array)

ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent(img_extent, ccrs.Geodetic())
ax.coastlines(resolution='50m', color='black', linewidth=1)

gl = ax.gridlines(draw_labels=True, axes=0)
gl.ylabels_right = False
gl.xlabels_top = False


ax.add_feature(cfeature.OCEAN, facecolor='aqua', alpha='0.1')
ax.add_feature(cfeature.BORDERS, alpha='0.2')


im = ax.imshow(img, origin='upper', extent=img_extent, cmap=cmap, norm=norm, interpolation='nearest')#, transform=ccrs.Mercator())
cb = fig.colorbar(im, ticks=bounds+[1], norm=norm, extend='both', extendfrac='auto', orientation='horizontal', pad=0.05).set_label('SPI Difference')
ax.set_title("SPI YEAR2009 DOY193", fontsize=20)

#outPath = r'D:\Data\NDVIanomalytimeseriesPNG//'+i[-16:-4]+'.png' # [-15:-4] original
outPath = r'C:\Users\lenovo\Pictures\ImagesGEWEX//plotSPI.png'
print outPath

#plt.savefig(outPath, dpi=200)
#plt.close(fig)
#fig.clf() 
#ax.cla()
plt.show()
# Out:
# C:\Users\lenovo\Pictures\ImagesGEWEX//plotSPI.png

# %%
for i in raster[92:138]:
    ds = gdal.Open(i)
    array = ds.ReadAsArray()
    
    fig = plt.figure(figsize=(10,10))
    
    img_extent = (extent[0], extent[1], extent[2], extent[3])
    img = np.flipud(array)
    
    ax = plt.axes(projection=ccrs.PlateCarree())
    
    ax.set_extent([72, 136, 52, 17], ccrs.Geodetic())
    ax.coastlines(resolution='50m', color='black', linewidth=1)
    
    ax.gridlines(draw_labels=True, axes=0)
    ax.add_feature(cfeature.OCEAN, facecolor='aqua', alpha='0.1')
    ax.add_feature(cfeature.BORDERS, alpha='0.2')


    im = ax.imshow(img, origin='upper', extent=img_extent, cmap=cmap, norm=norm)#, transform=ccrs.Mercator())
    cb = fig.colorbar(im, ticks=[-1]+bounds+[1], norm=norm, extend='both', extendfrac='auto', orientation='horizontal', pad=0.05).set_label('NDVI Difference')
    title = 'NDVI Anomaly '+i[-11:-4] #[-11:-4] original
    plt.text(0.5, 1.08, title,
             horizontalalignment='center',
             fontsize=20,
             transform = ax.transAxes)
    
    outPath = r'D:\Data\NDVIanomalytimeseriesPNG//'+i[-16:-4]+'.png' # [-15:-4] original
    print outPath
    plt.savefig(outPath, dpi=200)
    plt.close(fig)
    fig.clf() 
    ax.cla()

# %%
for i in raster[138:184]:
    ds = gdal.Open(i)
    array = ds.ReadAsArray()
    
    fig = plt.figure(figsize=(10,10))
    
    img_extent = (extent[0], extent[1], extent[2], extent[3])
    img = np.flipud(array)
    
    ax = plt.axes(projection=ccrs.PlateCarree())
    
    ax.set_extent([72, 136, 52, 17], ccrs.Geodetic())
    ax.coastlines(resolution='50m', color='black', linewidth=1)
    
    ax.gridlines(draw_labels=True, axes=0)
    ax.add_feature(cfeature.OCEAN, facecolor='aqua', alpha='0.1')
    ax.add_feature(cfeature.BORDERS, alpha='0.2')


    im = ax.imshow(img, origin='upper', extent=img_extent, cmap=cmap, norm=norm)#, transform=ccrs.Mercator())
    cb = fig.colorbar(im, ticks=[-1]+bounds+[1], norm=norm, extend='both', extendfrac='auto', orientation='horizontal', pad=0.05).set_label('NDVI Difference')
    title = 'NDVI Anomaly '+i[-11:-4] #[-11:-4] original
    plt.text(0.5, 1.08, title,
             horizontalalignment='center',
             fontsize=20,
             transform = ax.transAxes)
    
    outPath = r'D:\Data\NDVIanomalytimeseriesPNG//'+i[-16:-4]+'.png' # [-15:-4] original
    print outPath
    plt.savefig(outPath, dpi=200)
    plt.close(fig)
    fig.clf() 
    ax.cla()

# %%
for i in raster[184:230]:
    ds = gdal.Open(i)
    array = ds.ReadAsArray()
    
    fig = plt.figure(figsize=(10,10))
    
    img_extent = (extent[0], extent[1], extent[2], extent[3])
    img = np.flipud(array)
    
    ax = plt.axes(projection=ccrs.PlateCarree())
    
    ax.set_extent([72, 136, 52, 17], ccrs.Geodetic())
    ax.coastlines(resolution='50m', color='black', linewidth=1)
    
    ax.gridlines(draw_labels=True, axes=0)
    ax.add_feature(cfeature.OCEAN, facecolor='aqua', alpha='0.1')
    ax.add_feature(cfeature.BORDERS, alpha='0.2')


    im = ax.imshow(img, origin='upper', extent=img_extent, cmap=cmap, norm=norm)#, transform=ccrs.Mercator())
    cb = fig.colorbar(im, ticks=[-1]+bounds+[1], norm=norm, extend='both', extendfrac='auto', orientation='horizontal', pad=0.05).set_label('NDVI Difference')
    title = 'NDVI Anomaly '+i[-11:-4] #[-11:-4] original
    plt.text(0.5, 1.08, title,
             horizontalalignment='center',
             fontsize=20,
             transform = ax.transAxes)
    
    outPath = r'D:\Data\NDVIanomalytimeseriesPNG//'+i[-16:-4]+'.png' # [-15:-4] original
    print outPath
    plt.savefig(outPath, dpi=200)
    plt.close(fig)
    fig.clf() 
    ax.cla()

# %%
for i in raster[230:276]:
    ds = gdal.Open(i)
    array = ds.ReadAsArray()
    
    fig = plt.figure(figsize=(10,10))
    
    img_extent = (extent[0], extent[1], extent[2], extent[3])
    img = np.flipud(array)
    
    ax = plt.axes(projection=ccrs.PlateCarree())
    
    ax.set_extent([72, 136, 52, 17], ccrs.Geodetic())
    ax.coastlines(resolution='50m', color='black', linewidth=1)
    
    ax.gridlines(draw_labels=True, axes=0)
    ax.add_feature(cfeature.OCEAN, facecolor='aqua', alpha='0.1')
    ax.add_feature(cfeature.BORDERS, alpha='0.2')


    im = ax.imshow(img, origin='upper', extent=img_extent, cmap=cmap, norm=norm)#, transform=ccrs.Mercator())
    cb = fig.colorbar(im, ticks=[-1]+bounds+[1], norm=norm, extend='both', extendfrac='auto', orientation='horizontal', pad=0.05).set_label('NDVI Difference')
    title = 'NDVI Anomaly '+i[-11:-4] #[-11:-4] original
    plt.text(0.5, 1.08, title,
             horizontalalignment='center',
             fontsize=20,
             transform = ax.transAxes)
    
    outPath = r'D:\Data\NDVIanomalytimeseriesPNG//'+i[-16:-4]+'.png' # [-15:-4] original
    print outPath
    plt.savefig(outPath, dpi=200)
    plt.close(fig)
    fig.clf() 
    ax.cla()

# %%
for i in raster[276:322]:
    ds = gdal.Open(i)
    array = ds.ReadAsArray()
    
    fig = plt.figure(figsize=(10,10))
    
    img_extent = (extent[0], extent[1], extent[2], extent[3])
    img = np.flipud(array)
    
    ax = plt.axes(projection=ccrs.PlateCarree())
    
    ax.set_extent([72, 136, 52, 17], ccrs.Geodetic())
    ax.coastlines(resolution='50m', color='black', linewidth=1)
    
    ax.gridlines(draw_labels=True, axes=0)
    ax.add_feature(cfeature.OCEAN, facecolor='aqua', alpha='0.1')
    ax.add_feature(cfeature.BORDERS, alpha='0.2')


    im = ax.imshow(img, origin='upper', extent=img_extent, cmap=cmap, norm=norm)#, transform=ccrs.Mercator())
    cb = fig.colorbar(im, ticks=[-1]+bounds+[1], norm=norm, extend='both', extendfrac='auto', orientation='horizontal', pad=0.05).set_label('NDVI Difference')
    title = 'NDVI Anomaly '+i[-11:-4] #[-11:-4] original
    plt.text(0.5, 1.08, title,
             horizontalalignment='center',
             fontsize=20,
             transform = ax.transAxes)
    
    outPath = r'D:\Data\NDVIanomalytimeseriesPNG//'+i[-16:-4]+'.png' # [-15:-4] original
    print outPath
    plt.savefig(outPath, dpi=200)
    plt.close(fig)
    fig.clf() 
    ax.cla()

# %%
for i in raster[322:368]:
    ds = gdal.Open(i)
    array = ds.ReadAsArray()
    
    fig = plt.figure(figsize=(10,10))
    
    img_extent = (extent[0], extent[1], extent[2], extent[3])
    img = np.flipud(array)
    
    ax = plt.axes(projection=ccrs.PlateCarree())
    
    ax.set_extent([72, 136, 52, 17], ccrs.Geodetic())
    ax.coastlines(resolution='50m', color='black', linewidth=1)
    
    ax.gridlines(draw_labels=True, axes=0)
    ax.add_feature(cfeature.OCEAN, facecolor='aqua', alpha='0.1')
    ax.add_feature(cfeature.BORDERS, alpha='0.2')


    im = ax.imshow(img, origin='upper', extent=img_extent, cmap=cmap, norm=norm)#, transform=ccrs.Mercator())
    cb = fig.colorbar(im, ticks=[-1]+bounds+[1], norm=norm, extend='both', extendfrac='auto', orientation='horizontal', pad=0.05).set_label('NDVI Difference')
    title = 'NDVI Anomaly '+i[-11:-4] #[-11:-4] original
    plt.text(0.5, 1.08, title,
             horizontalalignment='center',
             fontsize=20,
             transform = ax.transAxes)
    
    outPath = r'D:\Data\NDVIanomalytimeseriesPNG//'+i[-16:-4]+'.png' # [-15:-4] original
    print outPath
    plt.savefig(outPath, dpi=200)
    plt.close(fig)
    fig.clf() 
    ax.cla()

# %%
for i in raster[368:414]:
    ds = gdal.Open(i)
    array = ds.ReadAsArray()
    
    fig = plt.figure(figsize=(10,10))
    
    img_extent = (extent[0], extent[1], extent[2], extent[3])
    img = np.flipud(array)
    
    ax = plt.axes(projection=ccrs.PlateCarree())
    
    ax.set_extent([72, 136, 52, 17], ccrs.Geodetic())
    ax.coastlines(resolution='50m', color='black', linewidth=1)
    
    ax.gridlines(draw_labels=True, axes=0)
    ax.add_feature(cfeature.OCEAN, facecolor='aqua', alpha='0.1')
    ax.add_feature(cfeature.BORDERS, alpha='0.2')


    im = ax.imshow(img, origin='upper', extent=img_extent, cmap=cmap, norm=norm)#, transform=ccrs.Mercator())
    cb = fig.colorbar(im, ticks=[-1]+bounds+[1], norm=norm, extend='both', extendfrac='auto', orientation='horizontal', pad=0.05).set_label('NDVI Difference')
    title = 'NDVI Anomaly '+i[-11:-4] #[-11:-4] original
    plt.text(0.5, 1.08, title,
             horizontalalignment='center',
             fontsize=20,
             transform = ax.transAxes)
    
    outPath = r'D:\Data\NDVIanomalytimeseriesPNG//'+i[-16:-4]+'.png' # [-15:-4] original
    print outPath
    plt.savefig(outPath, dpi=200)
    plt.close(fig)
    fig.clf() 
    ax.cla()

# %%
for i in raster[414:465]:
    ds = gdal.Open(i)
    array = ds.ReadAsArray()
    
    fig = plt.figure(figsize=(10,10))
    
    img_extent = (extent[0], extent[1], extent[2], extent[3])
    img = np.flipud(array)
    
    ax = plt.axes(projection=ccrs.PlateCarree())
    
    ax.set_extent([72, 136, 52, 17], ccrs.Geodetic())
    ax.coastlines(resolution='50m', color='black', linewidth=1)
    
    ax.gridlines(draw_labels=True, axes=0)
    ax.add_feature(cfeature.OCEAN, facecolor='aqua', alpha='0.1')
    ax.add_feature(cfeature.BORDERS, alpha='0.2')


    im = ax.imshow(img, origin='upper', extent=img_extent, cmap=cmap, norm=norm)#, transform=ccrs.Mercator())
    cb = fig.colorbar(im, ticks=[-1]+bounds+[1], norm=norm, extend='both', extendfrac='auto', orientation='horizontal', pad=0.05).set_label('NDVI Difference')
    title = 'NDVI Anomaly '+i[-11:-4] #[-11:-4] original
    plt.text(0.5, 1.08, title,
             horizontalalignment='center',
             fontsize=20,
             transform = ax.transAxes)
    
    outPath = r'D:\Data\NDVIanomalytimeseriesPNG//'+i[-16:-4]+'.png' # [-15:-4] original
    print outPath
    plt.savefig(outPath, dpi=200)
    plt.close(fig)
    fig.clf() 
    ax.cla()

# %%
ax

# %%
raster[466]
