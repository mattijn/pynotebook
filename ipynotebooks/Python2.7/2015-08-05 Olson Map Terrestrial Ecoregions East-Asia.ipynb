# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
# %matplotlib inline

# %%
extent = [111.91693268, 123.85693268, 49.43324112, 40.67324112]
extent = [72.6,141.5,-12.5,54]

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

import cartopy.feature as cfeature
import matplotlib.pyplot as plt
from cartopy.io.shapereader import Reader

plt.figure(figsize=(12,12))
ax = plt.axes(projection=ccrs.AlbersEqualArea(central_longitude=120, central_latitude=15))
ax.set_extent(extent)
ax.coastlines(resolution='110m')
ax.gridlines()
bound = r'D:\MicrosoftEdgeDownloads\Ecoregions_EastAsia//ea_clip.shp'
shape_bound = cfeature.ShapelyFeature(Reader(bound).geometries(), ccrs.PlateCarree(), facecolor='b')
ax.add_feature(shape_bound, linewidth='1.0', alpha='1.0')

# %%
from osgeo import gdal, ogr
import sys
import subprocess as sp
import os

# %%
file_in = r'D:\Data\ChinaWorld_GlobCover\Globcover2009_V2.3_Global_//GLOBCOVER_L4_200901_200912_V2.3.tif'

# %%
ds = gdal.Open(file_in)

# %%
band = ds.GetRasterBand(1)

# %%
array = band.ReadAsArray()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-f86be015bded> in <module>()
# ----> 1 array = band.ReadAsArray()
#
# C:\Python27x86\lib\site-packages\osgeo\gdal.pyc in ReadAsArray(self, xoff, yoff, win_xsize, win_ysize, buf_xsize, buf_ysize, buf_obj)
#    1160         return gdalnumeric.BandReadAsArray( self, xoff, yoff,
#    1161                                             win_xsize, win_ysize,
# -> 1162                                             buf_xsize, buf_ysize, buf_obj )
#    1163
#    1164     def WriteArray(self, array, xoff=0, yoff=0):
#
# C:\Python27x86\lib\site-packages\osgeo\gdal_array.pyc in BandReadAsArray(band, xoff, yoff, win_xsize, win_ysize, buf_xsize, buf_ysize, buf_obj)
#     274         if datatype == gdalconst.GDT_Byte and band.GetMetadataItem('PIXELTYPE', 'IMAGE_STRUCTURE') == 'SIGNEDBYTE':
#     275             typecode = numpy.int8
# --> 276         ar = numpy.empty([buf_ysize,buf_xsize], dtype = typecode)
#     277         if BandRasterIONumPy( band, 0, xoff, yoff, win_xsize, win_ysize,
#     278                                 ar, datatype ) != 0:
#
# ValueError: array is too big.

# %%
shapefile = r'D:\MicrosoftEdgeDownloads\Ecoregions_EastAsia//ea_clip.shp'
daShapefile = shapefile
driver = ogr.GetDriverByName('ESRI Shapefile')
dataSource = driver.Open(daShapefile, 0)
layer = dataSource.GetLayer()
ex1,ex2,ex3,ex4 = layer.GetExtent()
gdal_translate = 'D:\Python34\Lib\site-packages\osgeo\\gdal_translate.exe'

# %%
file_in = r'D:\Data\ChinaWorld_GlobCover\Globcover2009_V2.3_Global_//GLOBCOVER_L4_200901_200912_V2.3.tif'

# %%
out = r'D:\MicrosoftEdgeDownloads\Ecoregions_EastAsia//eastAsia_GlobCover.tif'
#path = folderout+out
#j2 = "NETCDF:"+r'D:\Downloads\Mattijn@Shakir\CL\CL.nc'+":CL"
paramsnorm = [gdal_translate, "-projwin", str(ex1), str(ex4), str(ex2), str(ex3), file_in, out]
print (sp.list2cmdline(paramsnorm))
#print (j2)
norm = sp.Popen(sp.list2cmdline(paramsnorm), shell=True)     
norm.communicate()
# Out:
# D:\Python34\Lib\site-packages\osgeo\gdal_translate.exe -projwin 73.4469604497 53.5579261777 141.011764525 -11.0047187809 D:\Data\ChinaWorld_GlobCover\Globcover2009_V2.3_Global_//GLOBCOVER_L4_200901_200912_V2.3.tif D:\MicrosoftEdgeDownloads\Ecoregions_EastAsia//eastAsia_GlobCover.tif
# (None, None)
