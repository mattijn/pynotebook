# %%
import os
from osgeo import gdal, gdalconst
import numpy as np

def FilesFolder(inGSODFolder, format_end=''):
    st_wmo = [os.path.join(root, name)
               for root, dirs, files in os.walk(inGSODFolder)
                 for name in files                 
                 if name.endswith(format_end)]
    return st_wmo

def OpenRaster(filepath, band=1):
    """
    In:
    filepath = path to file
    band     = 1

    Return:
    raster   = raster info
    array    = numpy array
    extent   = extent info
    """
    raster = gdal.Open(filepath, gdal.GA_ReadOnly)
    band = raster.GetRasterBand(band)
    array = band.ReadAsArray()
    extent = raster.GetGeoTransform()
    return raster, array, extent

# %%
path = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\RAW'
files = FilesFolder(path, '.tif')

files_01 = []
files_02 = []
files_03 = []
files_04 = []
files_05 = []
files_06 = []
files_07 = []
files_08 = []
files_09 = []
files_10 = []
files_11 = []
files_12 = []

for i in files:
    if int(i[-9:-7]) == 1:        
        files_01.append(i)
    elif int(i[-9:-7]) == 2:
        files_02.append(i)
    elif int(i[-9:-7]) == 3:
        files_03.append(i)        
    elif int(i[-9:-7]) == 4:
        files_04.append(i)
    elif int(i[-9:-7]) == 5:
        files_05.append(i)
    elif int(i[-9:-7]) == 6:
        files_06.append(i)
    elif int(i[-9:-7]) == 7:
        files_07.append(i)
    elif int(i[-9:-7]) == 8:
        files_08.append(i)        
    elif int(i[-9:-7]) == 9:
        files_09.append(i)        
    elif int(i[-9:-7]) == 10:
        files_10.append(i)
    elif int(i[-9:-7]) == 11:
        files_11.append(i)
    elif int(i[-9:-7]) == 12:
        files_12.append(i)

# %%
bar_01 = np.empty((len(files_01),array.shape[0],array.shape[1]))
for i in range(len(files_01)):
    file_ = files_01[i]
    raster, array, extent = OpenRaster(file_)
    bar_01[i] = array
    
bar_02 = np.empty((len(files_02),array.shape[0],array.shape[1]))
for i in range(len(files_02)):
    file_ = files_02[i]
    raster, array, extent = OpenRaster(file_)
    bar_02[i] = array

bar_03 = np.empty((len(files_03),array.shape[0],array.shape[1]))
for i in range(len(files_03)):
    file_ = files_03[i]
    raster, array, extent = OpenRaster(file_)
    bar_03[i] = array

bar_04 = np.empty((len(files_04),array.shape[0],array.shape[1]))
for i in range(len(files_04)):
    file_ = files_04[i]
    raster, array, extent = OpenRaster(file_)
    bar_04[i] = array

bar_05 = np.empty((len(files_05),array.shape[0],array.shape[1]))
for i in range(len(files_05)):
    file_ = files_05[i]
    raster, array, extent = OpenRaster(file_)
    bar_05[i] = array

bar_06 = np.empty((len(files_06),array.shape[0],array.shape[1]))
for i in range(len(files_06)):
    file_ = files_06[i]
    raster, array, extent = OpenRaster(file_)
    bar_06[i] = array

bar_07 = np.empty((len(files_07),array.shape[0],array.shape[1]))
for i in range(len(files_07)):
    file_ = files_07[i]
    raster, array, extent = OpenRaster(file_)
    bar_07[i] = array

bar_08 = np.empty((len(files_08),array.shape[0],array.shape[1]))
for i in range(len(files_08)):
    file_ = files_08[i]
    raster, array, extent = OpenRaster(file_)
    bar_08[i] = array

bar_09 = np.empty((len(files_09),array.shape[0],array.shape[1]))
for i in range(len(files_09)):
    file_ = files_09[i]
    raster, array, extent = OpenRaster(file_)
    bar_09[i] = array    

bar_10 = np.empty((len(files_10),array.shape[0],array.shape[1]))
for i in range(len(files_10)):
    file_ = files_10[i]
    raster, array, extent = OpenRaster(file_)
    bar_10[i] = array

bar_11 = np.empty((len(files_11),array.shape[0],array.shape[1]))
for i in range(len(files_11)):
    file_ = files_11[i]
    raster, array, extent = OpenRaster(file_)
    bar_11[i] = array

bar_12 = np.empty((len(files_12),array.shape[0],array.shape[1]))
for i in range(len(files_12)):
    file_ = files_12[i]
    raster, array, extent = OpenRaster(file_)
    bar_12[i] = array

# %%
base_all = np.empty((12,array.shape[0],array.shape[1]))
base_all[0] = bar_01.sum(axis=0)
base_all[1] = bar_02.sum(axis=0)
base_all[2] = bar_03.sum(axis=0)
base_all[3] = bar_04.sum(axis=0)
base_all[4] = bar_05.sum(axis=0)
base_all[5] = bar_06.sum(axis=0)
base_all[6] = bar_07.sum(axis=0)
base_all[7] = bar_08.sum(axis=0)
base_all[8] = bar_09.sum(axis=0)
base_all[9] = bar_10.sum(axis=0)
base_all[10] = bar_11.sum(axis=0)
base_all[11] = bar_12.sum(axis=0)

# %%
mean = base_all.mean(axis=0)
std = base_all.std(axis=0)
cv = std/mean

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
im = plt.imshow(mean)
plt.colorbar(im, orientation='horizontal')
plt.subplot(122)
im2 = plt.imshow(cv)
plt.colorbar(im2, orientation='horizontal')
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x0000000019421AC8>

# %%
def saveRaster(path, array, dsSource, datatype=3, formatraster="GTiff", nan=None): 
    """
    Datatypes:
    unknown = 0
    byte = 1
    unsigned int16 = 2
    signed int16 = 3
    unsigned int32 = 4
    signed int32 = 5
    float32 = 6
    float64 = 7
    complex int16 = 8
    complex int32 = 9
    complex float32 = 10
    complex float64 = 11
    float32 = 6, 
    signed int = 3
    
    Formatraster:
    GeoTIFF = GTiff
    Erdas = HFA (output = .img)
    OGC web map service = WMS
    png = PNG
    """
    # Set Driver
    format_ = formatraster #save as format
    driver = gdal.GetDriverByName( format_ )
    driver.Register()
    
    # Set Metadata for Raster output
    cols = dsSource.RasterXSize
    rows = dsSource.RasterYSize
    bands = dsSource.RasterCount
    datatype = datatype#band.DataType
    
    # Set Projection for Raster
    outDataset = driver.Create(path, cols, rows, bands, datatype)
    geoTransform = dsSource.GetGeoTransform()
    outDataset.SetGeoTransform(geoTransform)
    proj = dsSource.GetProjection()
    outDataset.SetProjection(proj)
    
    # Write output to band 1 of new Raster and write NaN value
    outBand = outDataset.GetRasterBand(1)
    if nan != None:
        outBand.SetNoDataValue(nan)
    outBand.WriteArray(array) #save input array
    #outBand.WriteArray(dem)
    
    # Close and finalise newly created Raster
    #F_M01 = None
    outBand = None
    proj = None
    geoTransform = None
    outDataset = None
    driver = None
    datatype = None
    bands = None
    rows = None
    cols = None
    driver = None
    array = None

# %%
path_mean = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2//mean.tif'
path_cv = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2//cv.tif'

saveRaster(path_mean, mean, raster, datatype=6)
saveRaster(path_cv, cv, raster, datatype=6)
