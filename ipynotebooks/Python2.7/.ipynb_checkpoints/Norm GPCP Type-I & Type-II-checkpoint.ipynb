# %% [markdown]
# # NORM TYPE-I

# %%
import os
import pandas as pd
from osgeo import gdal
import numpy as np

def listall(RootFolder):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if 'GPCP' in name
                     if name.endswith('.tif')]
    return lists

# ______________________________________________________
# SET PIXEL ROW AND COLUMN

pixelrow = 40
pixelcolumn = 90

# ______________________________________________________
# ANNUAL ACCUMULATED MEAN

li = []
da = []
i = 0
path = r'D:\Data\GPCP_30acc_anomalyNorm'# removed 'NormTypeII'
#path = r'D:\Data\GPCP_30acc_AnnualAcc'
test = listall(path)
test = test[0:-46]
print (len(test))
print (test[0])
for t in test:    
    raster = gdal.Open(t, gdal.GA_ReadOnly)
    nameRas = raster.GetDescription()[-11:-4]
    date = datetime.datetime(int(nameRas[0:4]), 1, 1) + datetime.timedelta(int(nameRas[4:9]) - 1) # replaced "int(nameRas[0:4])" with "2010" first year then add doy
    # print date
    da.append(date)

    band = raster.GetRasterBand(1)
    array = band.ReadAsArray()    
    
    # print array[879,4142] # Grassland pixel
    li.append(array[pixelrow, pixelcolumn])
    
    array = None
    band = None
    raster = None
    #print (str(i))
    i = i + 1
    
seriesNDVI = pd.Series(data = li, index = da)
GPCPnormTypeI = seriesNDVI

maxy = seriesNDVI.max()

print ('max', seriesNDVI.max(), seriesNDVI.plot() )

# %% [markdown]
# # NORM TYPE-II

# %%
import os
import pandas as pd
from osgeo import gdal
import numpy as np

def listall(RootFolder):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if 'GPCP' in name
                     if name.endswith('.tif')]
    return lists

# ______________________________________________________
# SET PIXEL ROW AND COLUMN

pixelrow = 40
pixelcolumn = 90

# ______________________________________________________
# ANNUAL ACCUMULATED MEAN

li = []
da = []
i = 0
path = r'D:\Data\GPCP_30acc_anomalyNormTypeII'# removed 'NormTypeII'
#path = r'D:\Data\GPCP_30acc_AnnualAcc'
test = listall(path)

print (len(test))
print (test[0])
for t in test:    
    raster = gdal.Open(t, gdal.GA_ReadOnly)
    nameRas = raster.GetDescription()[-11:-4]
    date = datetime.datetime(int(nameRas[0:4]), 1, 1) + datetime.timedelta(int(nameRas[4:9]) - 1) # replaced "int(nameRas[0:4])" with "2010" first year then add doy
    # print date
    da.append(date)

    band = raster.GetRasterBand(1)
    array = band.ReadAsArray()    
    
    # print array[879,4142] # Grassland pixel
    li.append(array[pixelrow, pixelcolumn])
    
    array = None
    band = None
    raster = None
    #print (str(i))
    i = i + 1
    
seriesNDVI = pd.Series(data = li, index = da)
GPCPnormTypeII = seriesNDVI
maxy = seriesNDVI.max()

print ('max', seriesNDVI.max(), seriesNDVI.plot() )

# %% [markdown]
# # FFT OF TYPE-I AND TYPE-II

# %%
import scipy
import scipy.fftpack
import pylab
from scipy import pi

FFT = abs(scipy.fft(GPCPnormTypeII))
freqs = scipy.fftpack.fftfreq(GPCPnormTypeII.size, GPCPnormTypeII.index[1] - GPCPnormTypeII.index[0])

fig = plt.figure(figsize=(12,6))
pylab.subplot(211)
pylab.plot(t, signal)
pylab.subplot(212)
pylab.plot(freqs,20*scipy.log10(FFT),'-')
pylab.show()
