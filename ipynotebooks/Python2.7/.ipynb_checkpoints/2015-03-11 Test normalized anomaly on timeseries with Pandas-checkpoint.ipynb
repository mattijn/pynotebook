# %%
import pandas as pd
import numpy as np

# %%
rng = pd.date_range(start = '2001-01-01',periods = 5113)
ts = pd.TimeSeries(np.random.randn(len(rng)), rng)

# %%
ts.plot()

# %%
mean = ts.groupby([ts.index.month, ts.index.day]).mean()

# %%
mean.plot()
