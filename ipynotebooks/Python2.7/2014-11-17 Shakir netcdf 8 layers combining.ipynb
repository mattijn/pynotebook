# %%
# %matplotlib inline

# %%
from osgeo import gdal
import numpy as np
import matplotlib.pyplot as plt

# %%
def saveRaster(path, array, dsSource, datatype=3, formatraster="GTiff", nan=None): 
    """
    Datatypes:
    unknown = 0
    byte = 1
    unsigned int16 = 2
    signed int16 = 3
    unsigned int32 = 4
    signed int32 = 5
    float32 = 6
    float64 = 7
    complex int16 = 8
    complex int32 = 9
    complex float32 = 10
    complex float64 = 11
    float32 = 6, 
    signed int = 3
    
    Formatraster:
    GeoTIFF = GTiff
    Erdas = HFA (output = .img)
    OGC web map service = WMS
    png = PNG
    """
    # Set Driver
    format_ = formatraster #save as format
    driver = gdal.GetDriverByName( format_ )
    driver.Register()
    
    # Set Metadata for Raster output
    cols = dsSource.RasterXSize
    rows = dsSource.RasterYSize
    bands = 1#dsSource.RasterCount
    datatype = datatype#band.DataType
    
    # Set Projection for Raster
    outDataset = driver.Create(path, cols, rows, bands, datatype)
    geoTransform = dsSource.GetGeoTransform()
    outDataset.SetGeoTransform(geoTransform)
    proj = dsSource.GetProjection()
    outDataset.SetProjection(proj)
    
    # Write output to band 1 of new Raster and write NaN value
    outBand = outDataset.GetRasterBand(1)
    if nan != None:
        outBand.SetNoDataValue(nan)
    outBand.WriteArray(array) #save input array
    #outBand.WriteArray(dem)
    
    # Close and finalise newly created Raster
    #F_M01 = None
    outBand = None
    proj = None
    geoTransform = None
    outDataset = None
    driver = None
    datatype = None
    bands = None
    rows = None
    cols = None
    driver = None
    array = None

# %%
depth = np.array([4.5, 4.6, 7.5, 12.3, 20.4, 33.6, 55.4, 91.3])
xj = r'D:\GoogleChromeDownloads\CL\out//xinjiang.tif'

dsXJ = gdal.Open(xj)

# %%
bds = dsXJ.RasterCount
xds = dsXJ.RasterXSize
yds = dsXJ.RasterYSize

[bds,xds,yds]
# Out:
# [8, 2752, 1781]

# %%
fdf = dsXJ.GetRasterBand(1)
fdf.GetNoDataValue()
# Out:
# -999.0

# %%
for i in range(1,9):
    out = depth[0:i]
    out_arr = np.zeros((out.size,yds,xds))
    for j in range(out.size):
        print(j+1)
        bdXJ = dsXJ.GetRasterBand(j+1)
        arXJ = bdXJ.ReadAsArray()
        ar_msk_XJ = np.ma.masked_where(arXJ==-999.0, arXJ)
        
        # print (awc, out[j-1])
        # out_arr[j-1] = awc*out[j-1]
        out_arr[j] = ar_msk_XJ*out[j]
    #msk = ar33[None]
    #ar_msk = np.ma.masked_where(msk==-9999.0,out_arr)
    msk = np.zeros((out.size, arXJ.shape[0], arXJ.shape[1]))
    for i in range(out.size):
        msk[i-1] = arXJ
    ar_msk = np.ma.masked_where(msk == -999.0, out_arr)    
    ar_msk = np.ma.sum(ar_msk, axis=0)/sum(out)
    #check = out_arr.sum(axis=0)/sum(out)
    print(sum(out))
    path_out = r'D:\GoogleChromeDownloads\CL\out\layers//avg_CL_0-'+str(sum(out)).replace('.','_')+'cm_XinJiang.tif'
    path_out_fig = r'D:\GoogleChromeDownloads\CL\out\layers//png_avg_CL_0-'+str(sum(out)).replace('.','_')+'cm_XinJiang.png'
    print(path_out)
    im = plt.imshow(ar_msk, vmin=2, vmax=30)
    plt.colorbar(im).set_label('Clay units')
    plt.title('soil depth 0-'+str(sum(out))+' (cm)')
    plt.savefig(path_out_fig, dpi=200)
    plt.show()
    
    print("")
    
    
    #saveRaster(path_out, ar_msk, dsXJ, datatype=6, nan = -999.0)
# Out:
# 1
# 4.5
# D:\GoogleChromeDownloads\CL\out\layers//avg_CL_0-4_5cm_XinJiang.tif
# 1
# 2
# 9.1
# D:\GoogleChromeDownloads\CL\out\layers//avg_CL_0-9_1cm_XinJiang.tif
# 1
# 2
# 3
# 16.6
# D:\GoogleChromeDownloads\CL\out\layers//avg_CL_0-16_6cm_XinJiang.tif
# 1
# 2
# 3
# 4
# 28.9
# D:\GoogleChromeDownloads\CL\out\layers//avg_CL_0-28_9cm_XinJiang.tif
# 1
# 2
# 3
# 4
# 5
# 49.3
# D:\GoogleChromeDownloads\CL\out\layers//avg_CL_0-49_3cm_XinJiang.tif
# 1
# 2
# 3
# 4
# 5
# 6
# 82.9
# D:\GoogleChromeDownloads\CL\out\layers//avg_CL_0-82_9cm_XinJiang.tif
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 138.3
# D:\GoogleChromeDownloads\CL\out\layers//avg_CL_0-138_3cm_XinJiang.tif
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 229.6
# D:\GoogleChromeDownloads\CL\out\layers//avg_CL_0-229_6cm_XinJiang.tif

# %%
out
# Out:
# array([  4.5,   4.6,   7.5,  12.3,  20.4,  33.6,  55.4])

# %%
out[0-1]
# Out:
# 55.399999999999999
