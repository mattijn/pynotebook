# %%
import os
import pandas as pd
from osgeo import gdal
import numpy as np
import datetime
import matplotlib.pyplot as plt
from scipy.signal import detrend as sp_detrend
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as pl
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig
import scipy.stats.distributions as dist

import nitime.algorithms as tsa
import nitime.utils as utils
from nitime.viz import winspect
from nitime.viz import plot_spectral_estimate

import datetime
import numpy as np
import pandas as pd
import matplotlib as mpl
import sys, os, re
from scipy import stats
# Out:
# D:\Python27\lib\site-packages\matplotlib\cbook.py:122: MatplotlibDeprecationWarning: The matplotlib.mpl module was deprecated in version 1.3. Use `import matplotlib as mpl` instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
def saveRaster(path, array, dsSource, datatype=3, formatraster="GTiff", nan=None): 
    """
    Datatypes:
    unknown = 0
    byte = 1
    unsigned int16 = 2
    signed int16 = 3
    unsigned int32 = 4
    signed int32 = 5
    float32 = 6
    float64 = 7
    complex int16 = 8
    complex int32 = 9
    complex float32 = 10
    complex float64 = 11
    float32 = 6, 
    signed int = 3
    
    Formatraster:
    GeoTIFF = GTiff
    Erdas = HFA (output = .img)
    OGC web map service = WMS
    png = PNG
    """
    # Set Driver
    format_ = formatraster #save as format
    driver = gdal.GetDriverByName( format_ )
    driver.Register()
    
    # Set Metadata for Raster output
    cols = dsSource.RasterXSize
    rows = dsSource.RasterYSize
    bands = dsSource.RasterCount
    datatype = datatype#band.DataType
    
    # Set Projection for Raster
    outDataset = driver.Create(path, cols, rows, bands, datatype)
    geoTransform = dsSource.GetGeoTransform()
    outDataset.SetGeoTransform(geoTransform)
    proj = dsSource.GetProjection()
    outDataset.SetProjection(proj)
    
    # Write output to band 1 of new Raster and write NaN value
    outBand = outDataset.GetRasterBand(1)
    if nan != None:
        outBand.SetNoDataValue(nan)
    outBand.WriteArray(array) #save input array
    #outBand.WriteArray(dem)
    
    # Close and finalise newly created Raster
    #F_M01 = None
    outBand = None
    proj = None
    geoTransform = None
    outDataset = None
    driver = None
    datatype = None
    bands = None
    rows = None
    cols = None
    driver = None
    array = None

# %%
# Colors via http://colorbrewer2.com/
WHITE, LIGHT_GRAY, GRAY, BLACK = [ "#FFFFFF", "#E5E5E5", "#777777", "#000000" ] 
COLORS = [ "#2C7BB6", "#FF6600", "#660099", "#D7191C", "#FFFFBF", "#ABD9E9"]
BLUE, ORANGE, PURPLE, RED, YELLOW, LIGHT_BLUE = COLORS
HIGH_ALPHA = 0.9
MEDIUM_ALPHA = 0.5
LOW_ALPHA = 0.1
rgba = mpl.colors.colorConverter.to_rgba

def set_styles(style_dict):
    """Set matplotlib styles from nested a nested dictionary"""
    for obj in style_dict: mpl.rc(obj, **style_dict[obj]) 

set_styles({
    "figure": { "figsize": [ 12, 4 ], "facecolor": WHITE },
    "savefig": { "dpi": 200, "bbox": "tight" },
    "patch": { "linewidth": 0.5, "facecolor": ORANGE, "edgecolor": WHITE, "antialiased": True },
    "font": { "size": 8 },
    "legend": { "fontsize": 10 },
    "axes": { 
        "facecolor": LIGHT_GRAY, 
        "edgecolor": WHITE, 
        "linewidth": 1, 
        "grid": True, 
        "titlesize": "large", 
        "labelsize": "large", 
        "labelcolor": BLACK,
        "axisbelow": True,
        "color_cycle": COLORS
    },
    "xtick": { "color": GRAY, "direction": "out" }, #GRAY
    "ytick": { "color": GRAY, "direction": "out" }, #GRAY
    "grid": { "color": WHITE, "linestyle": "-" }
})

# %%
def savitzky_golay(y, window_size, order, deriv=0, rate=1):
    r"""Smooth (and optionally differentiate) data with a Savitzky-Golay filter.
    The Savitzky-Golay filter removes high frequency noise from data.
    It has the advantage of preserving the original shape and
    features of the signal better than other types of filtering
    approaches, such as moving averages techniques.
    Parameters
    ----------
    y : array_like, shape (N,)
        the values of the time history of the signal.
    window_size : int
        the length of the window. Must be an odd integer number.
    order : int
        the order of the polynomial used in the filtering.
        Must be less then `window_size` - 1.
    deriv: int
        the order of the derivative to compute (default = 0 means only smoothing)
    Returns
    -------
    ys : ndarray, shape (N)
        the smoothed signal (or it's n-th derivative).
    Notes
    -----
    The Savitzky-Golay is a type of low-pass filter, particularly
    suited for smoothing noisy data. The main idea behind this
    approach is to make for each point a least-square fit with a
    polynomial of high order over a odd-sized window centered at
    the point.
    Examples
    --------
    t = np.linspace(-4, 4, 500)
    y = np.exp( -t**2 ) + np.random.normal(0, 0.05, t.shape)
    ysg = savitzky_golay(y, window_size=31, order=4)
    import matplotlib.pyplot as plt
    plt.plot(t, y, label='Noisy signal')
    plt.plot(t, np.exp(-t**2), 'k', lw=1.5, label='Original signal')
    plt.plot(t, ysg, 'r', label='Filtered signal')
    plt.legend()
    plt.show()
    References
    ----------
    .. [1] A. Savitzky, M. J. E. Golay, Smoothing and Differentiation of
       Data by Simplified Least Squares Procedures. Analytical
       Chemistry, 1964, 36 (8), pp 1627-1639.
    .. [2] Numerical Recipes 3rd Edition: The Art of Scientific Computing
       W.H. Press, S.A. Teukolsky, W.T. Vetterling, B.P. Flannery
       Cambridge University Press ISBN-13: 9780521880688
    """
    import numpy as np
    from math import factorial

    try:
        window_size = np.abs(np.int(window_size))
        order = np.abs(np.int(order))
    except ValueError as msg:
        raise ValueError("window_size and order have to be of type int")
    if window_size % 2 != 1 or window_size < 1:
        raise TypeError("window_size size must be a positive odd number")
    if window_size < order + 2:
        raise TypeError("window_size is too small for the polynomials order")
    order_range = range(order+1)
    half_window = (window_size -1) // 2
    # precompute coefficients
    b = np.mat([[k**i for i in order_range] for k in range(-half_window, half_window+1)])
    m = np.linalg.pinv(b).A[deriv] * rate**deriv * factorial(deriv)
    # pad the signal at the extremes with
    # values taken from the signal itself
    firstvals = y[0] - np.abs( y[1:half_window+1][::-1] - y[0] )
    lastvals = y[-1] + np.abs(y[-half_window-1:-1][::-1] - y[-1])
    y = np.concatenate((firstvals, y, lastvals))
    return np.convolve( m[::-1], y, mode='valid')

# %%
def _datacheck_peakdetect(x_axis, y_axis):
    if x_axis is None:
        x_axis = range(len(y_axis))
    
    if len(y_axis) != len(x_axis):
        raise (ValueError, 
                'Input vectors y_axis and x_axis must have same length')
    
    #needs to be a numpy array
    y_axis = np.array(y_axis)
    x_axis = np.array(x_axis)
    return x_axis, y_axis

# %%
def peakdetect(y_axis, x_axis = None, lookahead = 300, delta=0):
    """
    Converted from/based on a MATLAB script at: 
    http://billauer.co.il/peakdet.html
    
    function for detecting local maximas and minmias in a signal.
    Discovers peaks by searching for values which are surrounded by lower
    or larger values for maximas and minimas respectively
    
    keyword arguments:
    y_axis -- A list containg the signal over which to find peaks
    x_axis -- (optional) A x-axis whose values correspond to the y_axis list
        and is used in the return to specify the postion of the peaks. If
        omitted an index of the y_axis is used. (default: None)
    lookahead -- (optional) distance to look ahead from a peak candidate to
        determine if it is the actual peak (default: 200) 
        '(sample / period) / f' where '4 >= f >= 1.25' might be a good value
    delta -- (optional) this specifies a minimum difference between a peak and
        the following points, before a peak may be considered a peak. Useful
        to hinder the function from picking up false peaks towards to end of
        the signal. To work well delta should be set to delta >= RMSnoise * 5.
        (default: 0)
            delta function causes a 20% decrease in speed, when omitted
            Correctly used it can double the speed of the function
    
    return -- two lists [max_peaks, min_peaks] containing the positive and
        negative peaks respectively. Each cell of the lists contains a tupple
        of: (position, peak_value) 
        to get the average peak value do: np.mean(max_peaks, 0)[1] on the
        results to unpack one of the lists into x, y coordinates do: 
        x, y = zip(*tab)
    """
    max_peaks = []
    min_peaks = []
    dump = []   #Used to pop the first hit which almost always is false
       
    # check input data
    x_axis, y_axis = _datacheck_peakdetect(x_axis, y_axis)
    # store data length for later use
    length = len(y_axis)
    
    
    #perform some checks
    if lookahead < 1:
        raise ValueError ( "Lookahead must be '1' or above in value")
    if not (np.isscalar(delta) and delta >= 0):
        raise ValueError ( "delta must be a positive number" )
    
    #maxima and minima candidates are temporarily stored in
    #mx and mn respectively
    mn, mx = np.Inf, -np.Inf
    
    #Only detect peak if there is 'lookahead' amount of points after it
    for index, (x, y) in enumerate(zip(x_axis[:-lookahead], 
                                        y_axis[:-lookahead])):
        if y > mx:
            mx = y
            mxpos = x
        if y < mn:
            mn = y
            mnpos = x
        
        ####look for max####
        if y < mx-delta and mx != np.Inf:
            #Maxima peak candidate found
            #look ahead in signal to ensure that this is a peak and not jitter
            if y_axis[index:index+lookahead].max() < mx:
                max_peaks.append([mxpos, mx])
                dump.append(True)
                #set algorithm to only find minima now
                mx = np.Inf
                mn = np.Inf
                if index+lookahead >= length:
                    #end is within lookahead no more peaks can be found
                    break
                continue
            #else:  #slows shit down this does
            #    mx = ahead
            #    mxpos = x_axis[np.where(y_axis[index:index+lookahead]==mx)]
        
        ####look for min####
        if y > mn+delta and mn != -np.Inf:
            #Minima peak candidate found 
            #look ahead in signal to ensure that this is a peak and not jitter
            if y_axis[index:index+lookahead].min() > mn:
                min_peaks.append([mnpos, mn])
                dump.append(False)
                #set algorithm to only find maxima now
                mn = -np.Inf
                mx = -np.Inf
                if index+lookahead >= length:
                    #end is within lookahead no more peaks can be found
                    break
            #else:  #slows shit down this does
            #    mn = ahead
            #    mnpos = x_axis[np.where(y_axis[index:index+lookahead]==mn)]
    
    
    #Remove the false hit on the first value of the y_axis
    try:
        if dump[0]:
            max_peaks.pop(0)
        else:
            min_peaks.pop(0)
        del dump
    except IndexError:
        #no peaks were found, should the function return empty lists?
        pass
        
    return [max_peaks, min_peaks]

# %%
def listall(RootFolder, wildcard=''):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if wildcard in name
                     if name.endswith('.tif')]
    return lists

def getvalues(rootpath, pc, pr, wildcard=''):
    
    li = []
    da = []
    i = 0
    
    #path = r'D:\Data\GPCP_30acc_AnnualAcc'
    test = listall(rootpath, wildcard)
    #test = test[0:-46]
    #print (len(test))
    #print (test[0])
    for t in test:    
        raster = gdal.Open(t, gdal.GA_ReadOnly)
        nameRas = raster.GetDescription()[-11:-4]
        date = datetime.datetime(int(nameRas[0:4]), 1, 1) + datetime.timedelta(int(nameRas[4:9]) - 1) # replaced "int(nameRas[0:4])" with "2010" first year then add doy
        # print date
        da.append(date)
    
        band = raster.GetRasterBand(1)
        array = band.ReadAsArray()    
        
        # print array[879,4142] # Grassland pixel
        li.append(array[pr, pc])
        
        array = None
        band = None
        raster = None
        #print (str(i))
        i = i + 1
        
    signal = pd.Series(data = li, index = da)
    return signal

# %%
mth = [0.5, 1, 2, 3, 4, 5]
prd = [15, 30, 60, 90, 120, 150]
pth1 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2_2008\XX_Day_Period\XX_DaySums_StdNormAnomaly'# removed 'NormTypeII'
pth2 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\NDVI_2008\DaySums_StdNormAnomalyRes'# removed 'NormTypeII'

#pixelcolumn = 23 # extract from rasterXSize (0:62) horizontal latitude - whatever
#pixelrow = 21 # extract from rasterYSize (0:36) vertical longitude 
folderp1 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\PLOT_CHARTS_2009\COHERENCE2\p5//'
folderp2 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\PLOT_CHARTS_2009\COHERENCE2\p4//'

ph = pth2+'//TRMM_CQ_2008001.tif'
ds = gdal.Open(ph)
base = ds.ReadAsArray()

for i in range(0,6):
    phase_array = np.zeros_like(base)
    coher_array = np.zeros_like(base)
    rmse_array = np.zeros_like(base)
    
    for j in range(0, 48): # pixelcolumn
        for k in range(0,35): # pixelrow
        
            # Set path for cumulative period of precipitation
            # And corresponding period time
            cumper = mth[i]
            period = prd[i]
            paths1 = pth1.replace('XX', str(period))
            paths2 = pth2
            
    
            # Set pixelvalues
            # TODO: Implementation to read row by row or all-in-one
            pixelcolumn = j
            pixelrow = k
            
            # Get values for precipitation based on cumper 
            # And only update values for NDVI with a new pixel
            s_org2 = getvalues(paths2, pixelcolumn, pixelrow, wildcard='CQ')            
            if s_org2.mean()<>-99999.0:
                s_org1 = getvalues(paths1, pixelcolumn, pixelrow, wildcard='TRMM')                
            
                # Create dataframe from the two series and apply an outer join            
                df1 = pd.DataFrame(s_org1, columns=['prcp'])
                df2 = pd.DataFrame(s_org2, columns=['ndvi'])            
                df = pd.concat([df1, df2], join='outer', axis=1)
                
                # Before splitting the signals, first drop eventual NaN values
                df = df.dropna()            
                s1 = df['prcp']
                s2 = df['ndvi']
                x = s1.values
                y = s2.values
                # Extent annual signal to 20 years
                
                x = np.resize(x, (x.size*20) )
                y = np.resize(y, (y.size*20) )
                
                # Normalise annual signal
                x = (x - x.mean())/x.std()
                y = (y - y.mean())/y.std()  
                q = np.array([x,y])
                #plot(x)
                #plot(y)
    
                f, fxx, fyy, fxy = tsa.spectral.get_spectra_bi(x,y, method=dict(this_method='multi_taper_csd', Fs=1./0.4, BW=0.00122135, 
                                                                                adaptive=True, low_bias=True ))
                #plot(f, fxx)
                #plot(f, fyy)
                #plot(f, fxy)
                #xlim([0,0.012])
                #xticks([0.002,0.0022,0.0024,0.0026,0.0028,0.003,0.0032,0.0034,0.0036,0.0038,0.004])
                
                f, ccy = tsa.cohere.coherency(q, csd_method=dict(this_method='multi_taper_csd', Fs=1./0.4, BW=0.00122135, 
                                                                                adaptive=True, low_bias=True ))
                #plot(f,ccy[1][0])
                #xlim([0,0.012])
    
                f, cce = tsa.cohere.coherence(q, csd_method=dict(this_method='multi_taper_csd', Fs=1./0.4, BW=0.00122135, 
                                                                                adaptive=True, low_bias=True ))
                #plot(f,cce[0][1])
                #xlim([0,0.012])
                #ylim([-0.1,1.1])
    
                f, p = tsa.cohere.coherency_phase_spectrum(q, csd_method=dict(this_method='multi_taper_csd', Fs=1./0.4, BW=0.00122135, 
                                                                                adaptive=True, low_bias=True ))
                #plot(f,p[0][1])
                #xlim([0,0.012])
                
                c = cce[0][1][(0.0022 < f) & (f <0.0032)]
                y = p[0][1][(0.0022 < f) & (f <0.0032)]
                xi = f[(0.0022 < f) & (f <0.0032)]
                #plot(xi,y)
                
                
                slope, intercept, r_value, p_value, std_err = stats.linregress(xi,y)
                
                #print 'r value', r_value
                #print  'p_value', p_value
                #print 'standard deviation', std_err
                
                line = slope*xi+intercept
                #plot(xi,line,'r-',xi,y,'o')
                #show()
                mse = ((y - line)**2).mean(axis=None)
                rmse = math.sqrt(mse)
                cohe = c.mean()
                phse = y.mean()
                #print (rmse, coher, phase) 
                phase_array[k][j] = phse
                coher_array[k][j] = cohe
                rmse_array[k][j] = rmse
            else:
                phase_array[k][j] = -99999.0
                coher_array[k][j] = -99999.0
                rmse_array[k][j] = -99999.0
            print 'Col',j,'Row', k, 'CumPer', i, 'Phase',phase_array[k][j], 'Coherence', coher_array[k][j], 'RMSE', rmse_array[k][j]
                
            
    folder = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\PLOT_MAPS_2008//'
    path_phase = folder+'phase_'+str(prd[i])+'.tif'
    path_coher = folder+'coherence_'+str(prd[i])+'.tif'
    path_rmse = folder+'rmse_'+str(prd[i])+'.tif'

    saveRaster(path_phase, phase_array, ds, datatype=6, nan=-99999.0)
    saveRaster(path_coher, coher_array, ds, datatype=6, nan=-99999.0)
    saveRaster(path_rmse, rmse_array, ds, datatype=6, nan=-99999.0)
    
    print path_phase
    print path_coher
    print path_rmse
# Out:
# Col 0 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 18 CumPer 0 Phase 1.65165 Coherence 0.995055 RMSE 0.00807594
# Col
#  0 Row 19 CumPer 0 Phase 1.96503 Coherence 0.996691 RMSE 0.00167468
# Col
#  0 Row 20 CumPer 0 Phase 1.03843 Coherence 0.885647 RMSE 0.0114499
# Col
#  0 Row 21 CumPer 0 Phase 1.62991 Coherence 0.972703 RMSE 0.0201047
# Col
#  0 Row 22 CumPer 0 Phase 0.527952 Coherence 0.981459 RMSE 0.012475
# Col
#  0 Row 23 CumPer 0 Phase 1.84787 Coherence 0.99759 RMSE 0.00885782
# Col
#  0 Row 24 CumPer 0 Phase 2.40686 Coherence 0.999172 RMSE 0.00269995
# Col
#  0 Row 25 CumPer 0 Phase 2.08201 Coherence 0.860291 RMSE 0.0162596
# Col
#  0 Row 26 CumPer 0 Phase 2.19717 Coherence 0.991566 RMSE 0.0081566
# Col
#  0 Row 27 CumPer 0 Phase 0.214649 Coherence 0.99683 RMSE 0.00540335
# Col
#  0 Row 28 CumPer 0 Phase 0.143157 Coherence 0.997966 RMSE 0.00410238
# Col
#  0 Row 29 CumPer 0 Phase 1.10482 Coherence 0.992227 RMSE 0.0059216
# Col
#  0 Row 30 CumPer 0 Phase 0.321556 Coherence 0.999457 RMSE 0.00111503
# Col
#  0 Row 31 CumPer 0 Phase 2.62861 Coherence 0.997121 RMSE 0.00280351
# Col
#  0 Row 32 CumPer 0 Phase 1.80991 Coherence 0.991397 RMSE 0.00542746
# Col
#  0 Row 33 CumPer 0 Phase 0.926428 Coherence 0.955616 RMSE 0.0240007
# Col
#  0 Row 34 CumPer 0 Phase 0.9556 Coherence 0.913206 RMSE 0.0249068
# Col
#  1 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  1 Row 18 CumPer 0 Phase 1.11909 Coherence 0.99323 RMSE 0.00874025
# Col
#  1 Row 19 CumPer 0 Phase 0.950206 Coherence 0.94236 RMSE 0.0116277
# Col
#  1 Row 20 CumPer 0 Phase 0.806464 Coherence 0.991979 RMSE 0.00929757
# Col
#  1 Row 21 CumPer 0 Phase 0.908593 Coherence 0.996964 RMSE 0.00556002
# Col
#  1 Row 22 CumPer 0 Phase 1.4147 Coherence 0.996342 RMSE 0.00674344
# Col
#  1 Row 23 CumPer 0 Phase 1.57051 Coherence 0.995231 RMSE 0.0109396
# Col
#  1 Row 24 CumPer 0 Phase 2.04392 Coherence 0.997601 RMSE 0.00225999
# Col
#  1 Row 25 CumPer 0 Phase 1.61245 Coherence 0.99141 RMSE 0.0049696
# Col
#  1 Row 26 CumPer 0 Phase 1.32465 Coherence 0.997607 RMSE 0.00825118
# Col
#  1 Row 27 CumPer 0 Phase 0.867553 Coherence 0.786115 RMSE 0.0856685
# Col
#  1 Row 28 CumPer 0 Phase 0.507773 Coherence 0.996308 RMSE 0.00169768
# Col
#  1 Row 29 CumPer 0 Phase 0.211277 Coherence 0.995556 RMSE 0.00690448
# Col
#  1 Row 30 CumPer 0 Phase 1.06523 Coherence 0.996911 RMSE 0.00152996
# Col
#  1 Row 31 CumPer 0 Phase 2.57314 Coherence 0.9961 RMSE 0.00501452
# Col
#  1 Row 32 CumPer 0 Phase 1.84887 Coherence 0.989501 RMSE 0.00750677
# Col
#  1 Row 33 CumPer 0 Phase -0.906356 Coherence 0.825039 RMSE 0.594367
# Col
#  1 Row 34 CumPer 0 Phase 0.394642 Coherence 0.86684 RMSE 0.0614025
# Col
#  2 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  2 Row 18 CumPer 0 Phase 1.71395 Coherence 0.974481 RMSE 0.00240085
# Col
#  2 Row 19 CumPer 0 Phase 0.0357925 Coherence 0.908638 RMSE 0.0509219
# Col
#  2 Row 20 CumPer 0 Phase -0.540318 Coherence 0.989873 RMSE 0.0102303
# Col
#  2 Row 21 CumPer 0 Phase 0.690029 Coherence 0.997665 RMSE 0.00581223
# Col
#  2 Row 22 CumPer 0 Phase 1.18105 Coherence 0.985577 RMSE 0.0040311
# Col
#  2 Row 23 CumPer 0 Phase 1.90845 Coherence 0.831934 RMSE 0.00398163
# Col
#  2 Row 24 CumPer 0 Phase 1.14945 Coherence 0.887805 RMSE 0.0367809
# Col
#  2 Row 25 CumPer 0 Phase 1.82756 Coherence 0.82913 RMSE 0.05246
# Col
#  2 Row 26 CumPer 0 Phase 1.18858 Coherence 0.961604 RMSE 0.0120102
# Col
#  2 Row 27 CumPer 0 Phase 1.75799 Coherence 0.994497 RMSE 0.010002
# Col
#  2 Row 28 CumPer 0 Phase 1.08522 Coherence 0.994381 RMSE 0.00263844
# Col
#  2 Row 29 CumPer 0 Phase 0.361735 Coherence 0.980214 RMSE 0.00833204
# Col
#  2 Row 30 CumPer 0 Phase 1.73376 Coherence 0.995086 RMSE 0.00559797
# Col
#  2 Row 31 CumPer 0 Phase 2.91247 Coherence 0.987997 RMSE 0.0122696
# Col
#  2 Row 32 CumPer 0 Phase 1.07038 Coherence 0.894685 RMSE 0.00860244
# Col
#  2 Row 33 CumPer 0 Phase 1.472 Coherence 0.841102 RMSE 0.00461057
# Col
#  2 Row 34 CumPer 0 Phase 0.700149 Coherence 0.974587 RMSE 0.00682795
# Col
#  3 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 18 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  3 Row 19 CumPer 0 Phase 2.54312 Coherence 0.948701 RMSE 0.0443429
# Col
#  3 Row 20 CumPer 0 Phase -1.26593 Coherence 0.814256 RMSE 0.00942485
# Col
#  3 Row 21 CumPer 0 Phase -0.130733 Coherence 0.775336 RMSE 0.0271695
# Col
#  3 Row 22 CumPer 0 Phase 1.48441 Coherence 0.987374 RMSE 0.0112519
# Col
#  3 Row 23 CumPer 0 Phase 0.694332 Coherence 0.835071 RMSE 0.0150849
# Col
#  3 Row 24 CumPer 0 Phase 1.86584 Coherence 0.770517 RMSE 0.0162591
# Col
#  3 Row 25 CumPer 0 Phase 0.653638 Coherence 0.831205 RMSE 0.029166
# Col
#  3 Row 26 CumPer 0 Phase 0.785358 Coherence 0.818946 RMSE 0.00804431
# Col
#  3 Row 27 CumPer 0 Phase 1.34706 Coherence 0.987437 RMSE 0.00746037
# Col
#  3 Row 28 CumPer 0 Phase 0.847329 Coherence 0.994002 RMSE 0.00341897
# Col
#  3 Row 29 CumPer 0 Phase 0.782317 Coherence 0.937364 RMSE 0.00335447
# Col
#  3 Row 30 CumPer 0 Phase 0.291362 Coherence 0.989016 RMSE 0.00430037
# Col
#  3 Row 31 CumPer 0 Phase 2.17149 Coherence 0.90983 RMSE 0.0303625
# Col
#  3 Row 32 CumPer 0 Phase -2.64361 Coherence 0.942453 RMSE 0.00264146
# Col
#  3 Row 33 CumPer 0 Phase 1.4855 Coherence 0.801545 RMSE 0.00407428
# Col
#  3 Row 34 CumPer 0 Phase 0.576807 Coherence 0.870016 RMSE 0.0126527
# Col
#  4 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 18 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  4 Row 19 CumPer 0 Phase 0.191717 Coherence 0.998192 RMSE 0.00678638
# Col
#  4 Row 20 CumPer 0 Phase -1.97106 Coherence 0.990434 RMSE 0.00639987
# Col
#  4 Row 21 CumPer 0 Phase 0.318892 Coherence 0.989642 RMSE 0.00891906
# Col
#  4 Row 22 CumPer 0 Phase 0.941313 Coherence 0.996871 RMSE 0.00405498
# Col
#  4 Row 23 CumPer 0 Phase 0.160078 Coherence 0.997491 RMSE 0.00395483
# Col
#  4 Row 24 CumPer 0 Phase -0.0403778 Coherence 0.935673 RMSE 0.00371857
# Col
#  4 Row 25 CumPer 0 Phase -0.282094 Coherence 0.986952 RMSE 0.0133716
# Col
#  4 Row 26 CumPer 0 Phase 1.85078 Coherence 0.992684 RMSE 0.00495908
# Col
#  4 Row 27 CumPer 0 Phase 0.726923 Coherence 0.834726 RMSE 0.0141399
# Col
#  4 Row 28 CumPer 0 Phase 0.987903 Coherence 0.995898 RMSE 0.00639362
# Col
#  4 Row 29 CumPer 0 Phase 1.63665 Coherence 0.765451 RMSE 0.0326511
# Col
#  4 Row 30 CumPer 0 Phase 1.59532 Coherence 0.791843 RMSE 0.00555427
# Col
#  4 Row 31 CumPer 0 Phase 1.50565 Coherence 0.911501 RMSE 0.268558
# Col
#  4 Row 32 CumPer 0 Phase 2.94673 Coherence 0.943459 RMSE 0.0132241
# Col
#  4 Row 33 CumPer 0 Phase 3.09627 Coherence 0.932755 RMSE 0.0145414
# Col
#  4 Row 34 CumPer 0 Phase 0.82369 Coherence 0.919567 RMSE 0.01671
# Col
#  5 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 18 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  5 Row 19 CumPer 0 Phase -0.614144 Coherence 0.794758 RMSE 0.018586
# Col
#  5 Row 20 CumPer 0 Phase -0.925593 Coherence 0.76641 RMSE 0.0236009
# Col
#  5 Row 21 CumPer 0 Phase -0.322198 Coherence 0.813524 RMSE 0.0241215
# Col
#  5 Row 22 CumPer 0 Phase 0.971585 Coherence 0.896336 RMSE 0.00316296
# Col
#  5 Row 23 CumPer 0 Phase 0.764166 Coherence 0.921451 RMSE 0.0117474
# Col
#  5 Row 24 CumPer 0 Phase -0.395924 Coherence 0.998588 RMSE 0.00506462
# Col
#  5 Row 25 CumPer 0 Phase 0.0851624 Coherence 0.999587 RMSE 0.000318287
# Col
#  5 Row 26 CumPer 0 Phase 1.15127 Coherence 0.98969 RMSE 0.0112974
# Col
#  5 Row 27 CumPer 0 Phase -0.016789 Coherence 0.925369 RMSE 0.0132385
# Col
#  5 Row 28 CumPer 0 Phase 0.114355 Coherence 0.784085 RMSE 0.0199516
# Col
#  5 Row 29 CumPer 0 Phase 1.47324 Coherence 0.856213 RMSE 0.00960665
# Col
#  5 Row 30 CumPer 0 Phase 0.524359 Coherence 0.798585 RMSE 0.0168526
# Col
#  5 Row 31 CumPer 0 Phase 3.00335 Coherence 0.899774 RMSE 0.0115892
# Col
#  5 Row 32 CumPer 0 Phase 2.023 Coherence 0.769939 RMSE 0.039127
# Col
#  5 Row 33 CumPer 0 Phase -2.46207 Coherence 0.847563 RMSE 0.151215
# Col
#  5 Row 34 CumPer 0 Phase 1.34564 Coherence 0.877306 RMSE 0.0575063
# Col
#  6 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 18 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  6 Row 19 CumPer 0 Phase 1.67287 Coherence 0.445535 RMSE 0.134602
# Col
#  6 Row 20 CumPer 0 Phase 0.828845 Coherence 0.470251 RMSE 0.0380476
# Col
#  6 Row 21 CumPer 0 Phase 1.42531 Coherence 0.472186 RMSE 0.0409197
# Col
#  6 Row 22 CumPer 0 Phase 1.42013 Coherence 0.761236 RMSE 0.0220163
# Col
#  6 Row 23 CumPer 0 Phase 1.52193 Coherence 0.90777 RMSE 0.018081
# Col
#  6 Row 24 CumPer 0 Phase -0.738192 Coherence 0.995586 RMSE 0.007352
# Col
#  6 Row 25 CumPer 0 Phase 0.255471 Coherence 0.997668 RMSE 0.00587547
# Col
#  6 Row 26 CumPer 0 Phase 0.324039 Coherence 0.970217 RMSE 0.00569774
# Col
#  6 Row 27 CumPer 0 Phase -0.137346 Coherence 0.474485 RMSE 0.0690362
# Col
#  6 Row 28 CumPer 0 Phase 0.585371 Coherence 0.471068 RMSE 0.0269007
# Col
#  6 Row 29 CumPer 0 Phase 2.23021 Coherence 0.798045 RMSE 0.0100665
# Col
#  6 Row 30 CumPer 0 Phase 0.248925 Coherence 0.829736 RMSE 0.0340369
# Col
#  6 Row 31 CumPer 0 Phase -1.62606 Coherence 0.740952 RMSE 0.0430618
# Col
#  6 Row 32 CumPer 0 Phase -0.28216 Coherence 0.766114 RMSE 0.0411096
# Col
#  6 Row 33 CumPer 0 Phase -1.81842 Coherence 0.875004 RMSE 0.00860299
# Col
#  6 Row 34 CumPer 0 Phase 2.72149 Coherence 0.858563 RMSE 0.0105844
# Col
#  7 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 18 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  7 Row 19 CumPer 0 Phase 3.09886 Coherence 0.99388 RMSE 0.00430811
# Col
#  7 Row 20 CumPer 0 Phase 2.45613 Coherence 0.851666 RMSE 0.00801236
# Col
#  7 Row 21 CumPer 0 Phase 1.62925 Coherence 0.609559 RMSE 0.0134056
# Col
#  7 Row 22 CumPer 0 Phase 1.48828 Coherence 0.757074 RMSE 0.00180224
# Col
#  7 Row 23 CumPer 0 Phase 0.898803 Coherence 0.946974 RMSE 0.0101176
# Col
#  7 Row 24 CumPer 0 Phase -0.23629 Coherence 0.995865 RMSE 0.00803136
# Col
#  7 Row 25 CumPer 0 Phase 0.64685 Coherence 0.961584 RMSE 0.0172431
# Col
#  7 Row 26 CumPer 0 Phase 0.544678 Coherence 0.983523 RMSE 0.0118588
# Col
#  7 Row 27 CumPer 0 Phase -0.435556 Coherence 0.479828 RMSE 0.055997
# Col
#  7 Row 28 CumPer 0 Phase 1.22436 Coherence 0.757364 RMSE 0.0296071
# Col
#  7 Row 29 CumPer 0 Phase 1.57146 Coherence 0.848541 RMSE 0.00954518
# Col
#  7 Row 30 CumPer 0 Phase 1.35953 Coherence 0.809001 RMSE 0.0209661
# Col
#  7 Row 31 CumPer 0 Phase 0.177195 Coherence 0.795138 RMSE 0.0859319
# Col
#  7 Row 32 CumPer 0 Phase -0.682391 Coherence 0.474139 RMSE 0.0368883
# Col
#  7 Row 33 CumPer 0 Phase -0.779031 Coherence 0.475968 RMSE 0.0386514
# Col
#  7 Row 34 CumPer 0 Phase 0.0146787 Coherence 0.75351 RMSE 0.0386426
# Col
#  8 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 18 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  8 Row 19 CumPer 0 Phase 2.3647 Coherence 0.472961 RMSE 0.121527
# Col
#  8 Row 20 CumPer 0 Phase 1.70727 Coherence 0.778166 RMSE 0.0204073
# Col
#  8 Row 21 CumPer 0 Phase 0.718637 Coherence 0.756423 RMSE 0.00881873
# Col
#  8 Row 22 CumPer 0 Phase 1.04961 Coherence 0.750047 RMSE 0.03138
# Col
#  8 Row 23 CumPer 0 Phase -0.484474 Coherence 0.955085 RMSE 0.0104754
# Col
#  8 Row 24 CumPer 0 Phase -0.0845244 Coherence 0.990005 RMSE 0.00256841
# Col
#  8 Row 25 CumPer 0 Phase 0.259056 Coherence 0.895938 RMSE 0.0173909
# Col
#  8 Row 26 CumPer 0 Phase -0.666829 Coherence 0.769042 RMSE 0.0179923
# Col
#  8 Row 27 CumPer 0 Phase 0.741716 Coherence 0.614811 RMSE 0.00519995
# Col
#  8 Row 28 CumPer 0 Phase 2.39012 Coherence 0.820209 RMSE 0.00971433
# Col
#  8 Row 29 CumPer 0 Phase 1.95989 Coherence 0.994788 RMSE 0.00665517
# Col
#  8 Row 30 CumPer 0 Phase 0.586125 Coherence 0.817201 RMSE 0.057736
# Col
#  8 Row 31 CumPer 0 Phase 0.16752 Coherence 0.829166 RMSE 0.182388
# Col
#  8 Row 32 CumPer 0 Phase -1.17277 Coherence 0.767007 RMSE 0.0135345
# Col
#  8 Row 33 CumPer 0 Phase -0.791106 Coherence 0.470454 RMSE 0.0456534
# Col
#  8 Row 34 CumPer 0 Phase 2.85144 Coherence 0.752172 RMSE 0.0239355
# Col
#  9 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  9 Row 18 CumPer 0 Phase 0.920143 Coherence 0.98479 RMSE 0.0129418
# Col
#  9 Row 19 CumPer 0 Phase 0.190699 Coherence 0.992032 RMSE 0.00518919
# Col
#  9 Row 20 CumPer 0 Phase -0.454975 Coherence 0.84136 RMSE 0.0285557
# Col
#  9 Row 21 CumPer 0 Phase -1.65584 Coherence 0.826081 RMSE 0.0123837
# Col
#  9 Row 22 CumPer 0 Phase 0.135835 Coherence 0.850445 RMSE 0.00211481
# Col
#  9 Row 23 CumPer 0 Phase -0.788635 Coherence 0.892538 RMSE 0.0109829
# Col
#  9 Row 24 CumPer 0 Phase -0.439124 Coherence 0.932894 RMSE 0.0167983
# Col
#  9 Row 25 CumPer 0 Phase 0.210807 Coherence 0.802029 RMSE 0.0136784
# Col
#  9 Row 26 CumPer 0 Phase 1.78421 Coherence 0.852516 RMSE 0.0108453
# Col
#  9 Row 27 CumPer 0 Phase 1.09983 Coherence 0.993006 RMSE 0.0068867
# Col
#  9 Row 28 CumPer 0 Phase 1.52368 Coherence 0.994496 RMSE 0.00696909
# Col
#  9 Row 29 CumPer 0 Phase 2.35944 Coherence 0.998785 RMSE 0.00421812
# Col
#  9 Row 30 CumPer 0 Phase -0.61956 Coherence 0.895969 RMSE 0.23247
# Col
#  9 Row 31 CumPer 0 Phase -1.17041 Coherence 0.859359 RMSE 0.353909
# Col
#  9 Row 32 CumPer 0 Phase 1.33097 Coherence 0.473221 RMSE 0.0913681
# Col
#  9 Row 33 CumPer 0 Phase 1.28805 Coherence 0.747114 RMSE 0.0225424
# Col
#  9 Row 34 CumPer 0 Phase 2.06096 Coherence 0.741506 RMSE 0.00988857
# Col
#  10 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  10 Row 17 CumPer 0 Phase -3.1092 Coherence 0.993577 RMSE 0.00447629
# Col
#  10 Row 18 CumPer 0 Phase -0.14552 Coherence 0.859114 RMSE 0.0623782
# Col
#  10 Row 19 CumPer 0 Phase -0.495661 Coherence 0.918914 RMSE 0.0170929
# Col
#  10 Row 20 CumPer 0 Phase 0.566078 Coherence 0.984456 RMSE 0.010096
# Col
#  10 Row 21 CumPer 0 Phase -0.183314 Coherence 0.79958 RMSE 0.0140759
# Col
#  10 Row 22 CumPer 0 Phase -0.832451 Coherence 0.808597 RMSE 0.038622
# Col
#  10 Row 23 CumPer 0 Phase -2.4457 Coherence 0.472383 RMSE 0.0224673
# Col
#  10 Row 24 CumPer 0 Phase -0.661677 Coherence 0.871565 RMSE 0.0124724
# Col
#  10 Row 25 CumPer 0 Phase 1.65233 Coherence 0.641807 RMSE 0.0435618
# Col
#  10 Row 26 CumPer 0 Phase 2.13568 Coherence 0.838262 RMSE 0.0112637
# Col
#  10 Row 27 CumPer 0 Phase 2.34255 Coherence 0.99319 RMSE 0.00738685
# Col
#  10 Row 28 CumPer 0 Phase 1.87559 Coherence 0.995092 RMSE 0.00925595
# Col
#  10 Row 29 CumPer 0 Phase 1.60037 Coherence 0.997321 RMSE 0.00670531
# Col
#  10 Row 30 CumPer 0 Phase -0.666051 Coherence 0.949966 RMSE 0.0609776
# Col
#  10 Row 31 CumPer 0 Phase -1.35274 Coherence 0.941988 RMSE 0.0231023
# Col
#  10 Row 32 CumPer 0 Phase 0.222733 Coherence 0.465087 RMSE 0.013854
# Col
#  10 Row 33 CumPer 0 Phase 1.87764 Coherence 0.971952 RMSE 0.0112054
# Col
#  10 Row 34 CumPer 0 Phase 2.01062 Coherence 0.953943 RMSE 0.00372658
# Col
#  11 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  11 Row 17 CumPer 0 Phase 1.31833 Coherence 0.983069 RMSE 0.0111573
# Col
#  11 Row 18 CumPer 0 Phase -2.20351 Coherence 0.747615 RMSE 0.0739627
# Col
#  11 Row 19 CumPer 0 Phase 0.318525 Coherence 0.872209 RMSE 0.0126213
# Col
#  11 Row 20 CumPer 0 Phase -2.07609 Coherence 0.683332 RMSE 0.0235204
# Col
#  11 Row 21 CumPer 0 Phase -0.507858 Coherence 0.970971 RMSE 0.0170673
# Col
#  11 Row 22 CumPer 0 Phase -1.28863 Coherence 0.938107 RMSE 0.00458879
# Col
#  11 Row 23 CumPer 0 Phase -1.10021 Coherence 0.916068 RMSE 0.00415104
# Col
#  11 Row 24 CumPer 0 Phase -0.918944 Coherence 0.901707 RMSE 0.010991
# Col
#  11 Row 25 CumPer 0 Phase 2.54649 Coherence 0.857555 RMSE 0.0382069
# Col
#  11 Row 26 CumPer 0 Phase 2.67934 Coherence 0.987607 RMSE 0.00644954
# Col
#  11 Row 27 CumPer 0 Phase 1.97485 Coherence 0.888242 RMSE 0.0113776
# Col
#  11 Row 28 CumPer 0 Phase 1.90167 Coherence 0.994156 RMSE 0.00724301
# Col
#  11 Row 29 CumPer 0 Phase 2.2769 Coherence 0.948432 RMSE 0.00570241
# Col
#  11 Row 30 CumPer 0 Phase -0.658317 Coherence 0.876389 RMSE 0.188428
# Col
#  11 Row 31 CumPer 0 Phase 1.97724 Coherence 0.777829 RMSE 0.113392
# Col
#  11 Row 32 CumPer 0 Phase -0.158971 Coherence 0.891767 RMSE 0.000291521
# Col
#  11 Row 33 CumPer 0 Phase 1.0875 Coherence 0.872951 RMSE 0.0124187
# Col
#  11 Row 34 CumPer 0 Phase 1.73045 Coherence 0.775095 RMSE 0.015674
# Col
#  12 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  12 Row 17 CumPer 0 Phase 0.859594 Coherence 0.993306 RMSE 0.0106388
# Col
#  12 Row 18 CumPer 0 Phase -0.0489814 Coherence 0.929068 RMSE 0.0120088
# Col
#  12 Row 19 CumPer 0 Phase 0.961081 Coherence 0.485568 RMSE 0.0202051
# Col
#  12 Row 20 CumPer 0 Phase -0.213568 Coherence 0.610499 RMSE 0.222238
# Col
#  12 Row 21 CumPer 0 Phase -1.02698 Coherence 0.983204 RMSE 0.0157338
# Col
#  12 Row 22 CumPer 0 Phase -1.0531 Coherence 0.799896 RMSE 0.0412401
# Col
#  12 Row 23 CumPer 0 Phase 2.72111 Coherence 0.61087 RMSE 0.0238416
# Col
#  12 Row 24 CumPer 0 Phase -0.945789 Coherence 0.474334 RMSE 0.0352644
# Col
#  12 Row 25 CumPer 0 Phase 2.91888 Coherence 0.955749 RMSE 0.0166164
# Col
#  12 Row 26 CumPer 0 Phase 2.65596 Coherence 0.993596 RMSE 0.0060301
# Col
#  12 Row 27 CumPer 0 Phase 1.59718 Coherence 0.989967 RMSE 0.0103989
# Col
#  12 Row 28 CumPer 0 Phase 2.42305 Coherence 0.998594 RMSE 0.0030523
# Col
#  12 Row 29 CumPer 0 Phase -1.33669 Coherence 0.996792 RMSE 0.0107966
# Col
#  12 Row 30 CumPer 0 Phase -0.038539 Coherence 0.996931 RMSE 0.00809882
# Col
#  12 Row 31 CumPer 0 Phase 0.00595897 Coherence 0.994072 RMSE 0.000941771
# Col
#  12 Row 32 CumPer 0 Phase 1.664 Coherence 0.965704 RMSE 0.0325157
# Col
#  12 Row 33 CumPer 0 Phase 1.98697 Coherence 0.97871 RMSE 0.00671497
# Col
#  12 Row 34 CumPer 0 Phase -3.0 Coherence 0.944432 RMSE 0.035758
# Col
#  13 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  13 Row 17 CumPer 0 Phase 1.83948 Coherence 0.640025 RMSE 0.0564874
# Col
#  13 Row 18 CumPer 0 Phase 2.08893 Coherence 0.607439 RMSE 1.69568
# Col
#  13 Row 19 CumPer 0 Phase -0.404726 Coherence 0.809953 RMSE 0.0665863
# Col
#  13 Row 20 CumPer 0 Phase 2.49317 Coherence 0.59656 RMSE 0.0741636
# Col
#  13 Row 21 CumPer 0 Phase -0.681545 Coherence 0.81263 RMSE 0.0650421
# Col
#  13 Row 22 CumPer 0 Phase 2.98831 Coherence 0.786634 RMSE 0.0375611
# Col
#  13 Row 23 CumPer 0 Phase -1.12528 Coherence 0.760887 RMSE 0.0308584
# Col
#  13 Row 24 CumPer 0 Phase -2.78933 Coherence 0.456374 RMSE 0.0628094
# Col
#  13 Row 25 CumPer 0 Phase 2.40317 Coherence 0.957946 RMSE 0.00382667
# Col
#  13 Row 26 CumPer 0 Phase 2.48625 Coherence 0.950021 RMSE 0.0167189
# Col
#  13 Row 27 CumPer 0 Phase 2.18677 Coherence 0.989144 RMSE 0.00448123
# Col
#  13 Row 28 CumPer 0 Phase 2.57694 Coherence 0.999088 RMSE 0.00159412
# Col
#  13 Row 29 CumPer 0 Phase 2.32945 Coherence 0.997623 RMSE 0.00317787
# Col
#  13 Row 30 CumPer 0 Phase 0.472608 Coherence 0.999062 RMSE 0.00584663
# Col
#  13 Row 31 CumPer 0 Phase 0.172834 Coherence 0.996259 RMSE 0.00698596
# Col
#  13 Row 32 CumPer 0 Phase -0.220665 Coherence 0.991637 RMSE 0.0142003
# Col
#  13 Row 33 CumPer 0 Phase 2.18432 Coherence 0.800237 RMSE 0.250133
# Col
#  13 Row 34 CumPer 0 Phase 2.11894 Coherence 0.984903 RMSE 0.00400258
# Col
#  14 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  14 Row 17 CumPer 0 Phase 1.48109 Coherence 0.770708 RMSE 0.08737
# Col
#  14 Row 18 CumPer 0 Phase 1.54729 Coherence 0.942054 RMSE 0.0337163
# Col
#  14 Row 19 CumPer 0 Phase 2.39184 Coherence 0.470643 RMSE 0.226887
# Col
#  14 Row 20 CumPer 0 Phase -1.30822 Coherence 0.795913 RMSE 0.0608412
# Col
#  14 Row 21 CumPer 0 Phase -0.633479 Coherence 0.603269 RMSE 0.135897
# Col
#  14 Row 22 CumPer 0 Phase -2.15151 Coherence 0.757595 RMSE 0.0401079
# Col
#  14 Row 23 CumPer 0 Phase 0.34924 Coherence 0.871831 RMSE 0.0346113
# Col
#  14 Row 24 CumPer 0 Phase -0.602304 Coherence 0.477594 RMSE 0.00399129
# Col
#  14 Row 25 CumPer 0 Phase 2.86585 Coherence 0.925579 RMSE 0.0174186
# Col
#  14 Row 26 CumPer 0 Phase 2.88549 Coherence 0.99463 RMSE 0.0053375
# Col
#  14 Row 27 CumPer 0 Phase 2.27881 Coherence 0.991011 RMSE 0.0152148
# Col
#  14 Row 28 CumPer 0 Phase 2.58308 Coherence 0.996179 RMSE 0.0018144
# Col
#  14 Row 29 CumPer 0 Phase 2.2009 Coherence 0.997777 RMSE 0.0075518
# Col
#  14 Row 30 CumPer 0 Phase 0.631663 Coherence 0.999494 RMSE 0.00345413
# Col
#  14 Row 31 CumPer 0 Phase 1.06882 Coherence 0.994209 RMSE 0.00467738
# Col
#  14 Row 32 CumPer 0 Phase 1.55735 Coherence 0.993076 RMSE 0.00596516
# Col
#  14 Row 33 CumPer 0 Phase 2.20303 Coherence 0.986341 RMSE 0.00882783
# Col
#  14 Row 34 CumPer 0 Phase 1.33946 Coherence 0.9209 RMSE 0.00800298
# Col
#  15 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  15 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  15 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  15 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  15 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  15 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  15 Row 6 CumPer 0 Phase -2.27164 Coherence 0.918325 RMSE 0.0187671
# Col
#  15 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  15 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  15 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  15 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  15 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  15 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  15 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  15 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  15 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  15 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  15 Row 17 CumPer 0 Phase 1.62238 Coherence 0.918681 RMSE 0.0346574
# Col
#  15 Row 18 CumPer 0 Phase 1.45456 Coherence 0.932002 RMSE 0.0389145
# Col
#  15 Row 19 CumPer 0 Phase 2.04693 Coherence 0.800494 RMSE 0.131883
# Col
#  15 Row 20 CumPer 0 Phase -1.1853 Coherence 0.870387 RMSE 0.0153591
# Col
#  15 Row 21 CumPer 0 Phase -1.91395 Coherence 0.863048 RMSE 0.0305062
# Col
#  15 Row 22 CumPer 0 Phase 1.48486 Coherence 0.901307 RMSE 0.046105
# Col
#  15 Row 23 CumPer 0 Phase 1.93818 Coherence 0.77075 RMSE 0.0350921
# Col
#  15 Row 24 CumPer 0 Phase 2.83069 Coherence 0.88728 RMSE 0.00738292
# Col
#  15 Row 25 CumPer 0 Phase 2.44284 Coherence 0.962494 RMSE 0.00304993
# Col
#  15 Row 26 CumPer 0 Phase 1.33625 Coherence 0.966134 RMSE 2.78154
# Col
#  15 Row 27 CumPer 0 Phase -1.48581 Coherence 0.961209 RMSE 0.0426764
# Col
#  15 Row 28 CumPer 0 Phase 0.539837 Coherence 0.985923 RMSE 0.0108845
# Col
#  15 Row 29 CumPer 0 Phase 0.878409 Coherence 0.993624 RMSE 0.0124224
# Col
#  15 Row 30 CumPer 0 Phase 0.269749 Coherence 0.997447 RMSE 0.00279743
# Col
#  15 Row 31 CumPer 0 Phase 0.84416 Coherence 0.998277 RMSE 0.00275851
# Col
#  15 Row 32 CumPer 0 Phase 1.84776 Coherence 0.976628 RMSE 0.0357343
# Col
#  15 Row 33 CumPer 0 Phase 0.601186 Coherence 0.905807 RMSE 0.0122205
# Col
#  15 Row 34 CumPer 0 Phase 1.03538 Coherence 0.990562 RMSE 0.00847394
# Col
#  16 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  16 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  16 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  16 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  16 Row 4 CumPer 0 Phase -2.3629 Coherence 0.982461 RMSE 0.00740915
# Col
#  16 Row 5 CumPer 0 Phase 2.7652 Coherence 0.83211 RMSE 0.00794853
# Col
#  16 Row 6 CumPer 0 Phase -0.0629345 Coherence 0.98779 RMSE 0.0255888
# Col
#  16 Row 7 CumPer 0 Phase 1.38056 Coherence 0.882869 RMSE 0.0588172
# Col
#  16 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  16 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  16 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  16 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  16 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  16 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  16 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  16 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  16 Row 16 CumPer 0 Phase 1.01902 Coherence 0.889532 RMSE 0.0303568
# Col
#  16 Row 17 CumPer 0 Phase 2.27842 Coherence 0.959111 RMSE 0.0191781
# Col
#  16 Row 18 CumPer 0 Phase 2.10799 Coherence 0.971653 RMSE 0.0277584
# Col
#  16 Row 19 CumPer 0 Phase 2.79948 Coherence 0.83673 RMSE 0.0673793
# Col
#  16 Row 20 CumPer 0 Phase 3.09552 Coherence 0.924242 RMSE 0.00953915
# Col
#  16 Row 21 CumPer 0 Phase -0.283522 Coherence 0.83568 RMSE 0.0398222
# Col
#  16 Row 22 CumPer 0 Phase 2.31989 Coherence 0.738376 RMSE 0.012826
# Col
#  16 Row 23 CumPer 0 Phase 2.65847 Coherence 0.485496 RMSE 0.00310185
# Col
#  16 Row 24 CumPer 0 Phase 2.50903 Coherence 0.477148 RMSE 0.0520261
# Col
#  16 Row 25 CumPer 0 Phase -3.13545 Coherence 0.981556 RMSE 0.000599065
# Col
#  16 Row 26 CumPer 0 Phase -2.4788 Coherence 0.979398 RMSE 0.0163346
# Col
#  16 Row 27 CumPer 0 Phase 2.52869 Coherence 0.998304 RMSE 0.00668877
# Col
#  16 Row 28 CumPer 0 Phase 2.16347 Coherence 0.997161 RMSE 0.00887461
# Col
#  16 Row 29 CumPer 0 Phase 2.01066 Coherence 0.992194 RMSE 0.0102732
# Col
#  16 Row 30 CumPer 0 Phase 0.604341 Coherence 0.996439 RMSE 0.00501767
# Col
#  16 Row 31 CumPer 0 Phase 1.06494 Coherence 0.995687 RMSE 0.00735281
# Col
#  16 Row 32 CumPer 0 Phase 0.678858 Coherence 0.988412 RMSE 0.00924448
# Col
#  16 Row 33 CumPer 0 Phase 1.24285 Coherence 0.817348 RMSE 0.00708092
# Col
#  16 Row 34 CumPer 0 Phase 0.816413 Coherence 0.994847 RMSE 0.00533861
# Col
#  17 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  17 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  17 Row 2 CumPer 0 Phase -1.78225 Coherence 0.945213 RMSE 0.0252733
# Col
#  17 Row 3 CumPer 0 Phase -2.22667 Coherence 0.96875 RMSE 0.00856691
# Col
#  17 Row 4 CumPer 0 Phase 3.02872 Coherence 0.880554 RMSE 0.0312276
# Col
#  17 Row 5 CumPer 0 Phase -0.401805 Coherence 0.802106 RMSE 0.00714907
# Col
#  17 Row 6 CumPer 0 Phase 1.39629 Coherence 0.98787 RMSE 0.0148349
# Col
#  17 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  17 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  17 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  17 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  17 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  17 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  17 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  17 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  17 Row 15 CumPer 0 Phase 1.36774 Coherence 0.956946 RMSE 0.0136337
# Col
#  17 Row 16 CumPer 0 Phase 2.31174 Coherence 0.802682 RMSE 0.0318904
# Col
#  17 Row 17 CumPer 0 Phase 2.69212 Coherence 0.463855 RMSE 0.133137
# Col
#  17 Row 18 CumPer 0 Phase 2.08637 Coherence 0.792958 RMSE 1.71417
# Col
#  17 Row 19 CumPer 0 Phase -2.56109 Coherence 0.998714 RMSE 0.0107809
# Col
#  17 Row 20 CumPer 0 Phase -1.76624 Coherence 0.9665 RMSE 0.00248317
# Col
#  17 Row 21 CumPer 0 Phase 0.0681796 Coherence 0.60799 RMSE 0.0609808
# Col
#  17 Row 22 CumPer 0 Phase 0.434948 Coherence 0.615219 RMSE 0.00721355
# Col
#  17 Row 23 CumPer 0 Phase 0.616298 Coherence 0.621503 RMSE 0.0965517
# Col
#  17 Row 24 CumPer 0 Phase 1.18145 Coherence 0.822172 RMSE 0.0144704
# Col
#  17 Row 25 CumPer 0 Phase 3.09778 Coherence 0.996435 RMSE 0.00473555
# Col
#  17 Row 26 CumPer 0 Phase -2.6738 Coherence 0.987902 RMSE 0.012362
# Col
#  17 Row 27 CumPer 0 Phase 2.88096 Coherence 0.998577 RMSE 0.00530445
# Col
#  17 Row 28 CumPer 0 Phase 2.81759 Coherence 0.998287 RMSE 0.00402847
# Col
#  17 Row 29 CumPer 0 Phase 1.70746 Coherence 0.990802 RMSE 0.00928417
# Col
#  17 Row 30 CumPer 0 Phase 1.04327 Coherence 0.992783 RMSE 0.0112627
# Col
#  17 Row 31 CumPer 0 Phase 1.32568 Coherence 0.996028 RMSE 0.00768209
# Col
#  17 Row 32 CumPer 0 Phase 1.01079 Coherence 0.819646 RMSE 0.0346078
# Col
#  17 Row 33 CumPer 0 Phase 1.50773 Coherence 0.744244 RMSE 0.0431244
# Col
#  17 Row 34 CumPer 0 Phase 1.88389 Coherence 0.857538 RMSE 0.00586266
# Col
#  18 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  18 Row 1 CumPer 0 Phase -0.110611 Coherence 0.970801 RMSE 0.0353397
# Col
#  18 Row 2 CumPer 0 Phase -1.64957 Coherence 0.969797 RMSE 0.0205859
# Col
#  18 Row 3 CumPer 0 Phase 0.164083 Coherence 0.98079 RMSE 0.0196713
# Col
#  18 Row 4 CumPer 0 Phase 2.1483 Coherence 0.901874 RMSE 1.70441
# Col
#  18 Row 5 CumPer 0 Phase -1.1116 Coherence 0.900207 RMSE 0.0127035
# Col
#  18 Row 6 CumPer 0 Phase 0.272967 Coherence 0.952165 RMSE 0.0441574
# Col
#  18 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  18 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  18 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  18 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  18 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  18 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  18 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  18 Row 14 CumPer 0 Phase 0.413261 Coherence 0.995232 RMSE 0.00245445
# Col
#  18 Row 15 CumPer 0 Phase 1.34374 Coherence 0.912797 RMSE 0.00327696
# Col
#  18 Row 16 CumPer 0 Phase 0.368972 Coherence 0.944166 RMSE 0.169053
# Col
#  18 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  18 Row 18 CumPer 0 Phase 2.04603 Coherence 0.806642 RMSE 1.70512
# Col
#  18 Row 19 CumPer 0 Phase -1.56204 Coherence 0.996847 RMSE 0.00835439
# Col
#  18 Row 20 CumPer 0 Phase 3.02804 Coherence 0.991085 RMSE 0.0147824
# Col
#  18 Row 21 CumPer 0 Phase -2.58381 Coherence 0.877326 RMSE 0.123988
# Col
#  18 Row 22 CumPer 0 Phase 0.154408 Coherence 0.772463 RMSE 0.0226405
# Col
#  18 Row 23 CumPer 0 Phase -1.12486 Coherence 0.640417 RMSE 0.524829
# Col
#  18 Row 24 CumPer 0 Phase 1.39138 Coherence 0.858399 RMSE 1.19232
# Col
#  18 Row 25 CumPer 0 Phase 3.06355 Coherence 0.999512 RMSE 0.00314617
# Col
#  18 Row 26 CumPer 0 Phase 3.05609 Coherence 0.993019 RMSE 0.0102351
# Col
#  18 Row 27 CumPer 0 Phase 2.78205 Coherence 0.994026 RMSE 0.0131065
# Col
#  18 Row 28 CumPer 0 Phase -2.71382 Coherence 0.989143 RMSE 0.0091419
# Col
#  18 Row 29 CumPer 0 Phase 1.76143 Coherence 0.994776 RMSE 0.00714049
# Col
#  18 Row 30 CumPer 0 Phase -0.130113 Coherence 0.99188 RMSE 0.013384
# Col
#  18 Row 31 CumPer 0 Phase 0.871662 Coherence 0.998635 RMSE 0.00468169
# Col
#  18 Row 32 CumPer 0 Phase 1.13991 Coherence 0.991755 RMSE 0.00213228
# Col
#  18 Row 33 CumPer 0 Phase 1.73118 Coherence 0.858655 RMSE 0.00414842
# Col
#  18 Row 34 CumPer 0 Phase 1.32515 Coherence 0.774785 RMSE 0.00896418
# Col
#  19 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  19 Row 1 CumPer 0 Phase -0.811751 Coherence 0.944615 RMSE 0.0376673
# Col
#  19 Row 2 CumPer 0 Phase 1.47213 Coherence 0.759864 RMSE 0.233651
# Col
#  19 Row 3 CumPer 0 Phase 0.22879 Coherence 0.994186 RMSE 0.00747989
# Col
#  19 Row 4 CumPer 0 Phase -2.89204 Coherence 0.978189 RMSE 0.0145464
# Col
# ...
# Col
#  41 Row 31 CumPer 5 Phase -0.893085 Coherence 0.99712 RMSE 0.0113773
# Col
#  41 Row 32 CumPer 5 Phase 0.209962 Coherence 0.634028 RMSE 0.11472
# Col
#  41 Row 33 CumPer 5 Phase -1.72 Coherence 0.993111 RMSE 0.0118682
# Col
#  41 Row 34 CumPer 5 Phase -1.53438 Coherence 0.983123 RMSE 0.00829066
# Col
#  42 Row 0 CumPer 5 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  42 Row 1 CumPer 5 Phase -1.22994 Coherence 0.992797 RMSE 0.00362581
# Col
#  42 Row 2 CumPer 5 Phase -0.45082 Coherence 0.994933 RMSE 0.00313378
# Col
#  42 Row 3 CumPer 5 Phase -1.30129 Coherence 0.997242 RMSE 0.00954516
# Col
#  42 Row 4 CumPer 5 Phase -1.01348 Coherence 0.993515 RMSE 0.00619478
# Col
#  42 Row 5 CumPer 5 Phase -1.90248 Coherence 0.992059 RMSE 0.0119822
# Col
#  42 Row 6 CumPer 5 Phase -2.72201 Coherence 0.999225 RMSE 0.00279751
# Col
#  42 Row 7 CumPer 5 Phase -0.908558 Coherence 0.989786 RMSE 0.00854017
# Col
#  42 Row 8 CumPer 5 Phase -1.75017 Coherence 0.991599 RMSE 0.00748949
# Col
#  42 Row 9 CumPer 5 Phase -0.229774 Coherence 0.98356 RMSE 0.0106531
# Col
#  42 Row 10 CumPer 5 Phase -1.21019 Coherence 0.972481 RMSE 0.0342227
# Col
#  42 Row 11 CumPer 5 Phase 0.826886 Coherence 0.978236 RMSE 0.0273806
# Col
#  42 Row 12 CumPer 5 Phase 3.0265 Coherence 0.973004 RMSE 0.0320343
# Col
#  42 Row 13 CumPer 5 Phase -1.73349 Coherence 0.995109 RMSE 0.0133881
# Col
#  42 Row 14 CumPer 5 Phase -2.66458 Coherence 0.968563 RMSE 0.03546
# Col
#  42 Row 15 CumPer 5 Phase 1.8152 Coherence 0.867187 RMSE 0.0720361
# Col
#  42 Row 16 CumPer 5 Phase 0.342967 Coherence 0.997118 RMSE 0.0126529
# Col
#  42 Row 17 CumPer 5 Phase 0.196935 Coherence 0.98189 RMSE 0.0187668
# Col
#  42 Row 18 CumPer 5 Phase 1.11349 Coherence 0.987695 RMSE 0.0214509
# Col
#  42 Row 19 CumPer 5 Phase 1.00814 Coherence 0.999445 RMSE 0.00801541
# Col
#  42 Row 20 CumPer 5 Phase 0.204735 Coherence 0.999606 RMSE 0.00148354
# Col
#  42 Row 21 CumPer 5 Phase -0.120988 Coherence 0.881691 RMSE 0.0791458
# Col
#  42 Row 22 CumPer 5 Phase 2.59947 Coherence 0.994975 RMSE 0.00792922
# Col
#  42 Row 23 CumPer 5 Phase 2.01449 Coherence 0.998001 RMSE 0.00701172
# Col
#  42 Row 24 CumPer 5 Phase 2.60535 Coherence 0.984873 RMSE 0.0128897
# Col
#  42 Row 25 CumPer 5 Phase -0.533392 Coherence 0.982228 RMSE 0.0193242
# Col
#  42 Row 26 CumPer 5 Phase -0.468438 Coherence 0.999531 RMSE 0.00399743
# Col
#  42 Row 27 CumPer 5 Phase 0.511291 Coherence 0.990346 RMSE 0.00857065
# Col
#  42 Row 28 CumPer 5 Phase -1.46762 Coherence 0.998384 RMSE 0.00591107
# Col
#  42 Row 29 CumPer 5 Phase -0.946406 Coherence 0.998601 RMSE 0.00796639
# Col
#  42 Row 30 CumPer 5 Phase -1.10348 Coherence 0.996343 RMSE 0.0121894
# Col
#  42 Row 31 CumPer 5 Phase 0.319328 Coherence 0.70703 RMSE 0.159366
# Col
#  42 Row 32 CumPer 5 Phase -1.95843 Coherence 0.969666 RMSE 0.0157294
# Col
#  42 Row 33 CumPer 5 Phase -2.8356 Coherence 0.90096 RMSE 0.0644385
# Col
#  42 Row 34 CumPer 5 Phase 2.64808 Coherence 0.976325 RMSE 0.00232575
# Col
#  43 Row 0 CumPer 5 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  43 Row 1 CumPer 5 Phase -2.13534 Coherence 0.98993 RMSE 0.00831991
# Col
#  43 Row 2 CumPer 5 Phase -1.12617 Coherence 0.992618 RMSE 0.0126815
# Col
#  43 Row 3 CumPer 5 Phase -1.62038 Coherence 0.995241 RMSE 0.0131307
# Col
#  43 Row 4 CumPer 5 Phase -1.68201 Coherence 0.990605 RMSE 0.0143268
# Col
#  43 Row 5 CumPer 5 Phase 2.70092 Coherence 0.993247 RMSE 0.0163629
# Col
#  43 Row 6 CumPer 5 Phase 1.68778 Coherence 0.991074 RMSE 0.00833812
# Col
#  43 Row 7 CumPer 5 Phase -1.98069 Coherence 0.992807 RMSE 0.00828616
# Col
#  43 Row 8 CumPer 5 Phase -2.11946 Coherence 0.997852 RMSE 0.00624593
# Col
#  43 Row 9 CumPer 5 Phase -0.339588 Coherence 0.991569 RMSE 0.0154705
# Col
#  43 Row 10 CumPer 5 Phase -1.33293 Coherence 0.980258 RMSE 0.0259773
# Col
#  43 Row 11 CumPer 5 Phase -0.457346 Coherence 0.875517 RMSE 0.0344341
# Col
#  43 Row 12 CumPer 5 Phase -0.582605 Coherence 0.99374 RMSE 0.00800329
# Col
#  43 Row 13 CumPer 5 Phase 2.94999 Coherence 0.997133 RMSE 0.00507499
# Col
#  43 Row 14 CumPer 5 Phase 0.970933 Coherence 0.824571 RMSE 0.0882222
# Col
#  43 Row 15 CumPer 5 Phase 2.35832 Coherence 0.862168 RMSE 0.0692908
# Col
#  43 Row 16 CumPer 5 Phase 1.70227 Coherence 0.99886 RMSE 0.010346
# Col
#  43 Row 17 CumPer 5 Phase 1.737 Coherence 0.997355 RMSE 0.0109043
# Col
#  43 Row 18 CumPer 5 Phase 2.79532 Coherence 0.998557 RMSE 0.00662108
# Col
#  43 Row 19 CumPer 5 Phase 1.73837 Coherence 0.998573 RMSE 0.00762877
# Col
#  43 Row 20 CumPer 5 Phase -1.86503 Coherence 0.992381 RMSE 0.0147143
# Col
#  43 Row 21 CumPer 5 Phase 1.37295 Coherence 0.995553 RMSE 0.00858316
# Col
#  43 Row 22 CumPer 5 Phase 2.58887 Coherence 0.998687 RMSE 0.0059064
# Col
#  43 Row 23 CumPer 5 Phase 2.09472 Coherence 0.995138 RMSE 0.0136089
# Col
#  43 Row 24 CumPer 5 Phase -1.08976 Coherence 0.994637 RMSE 0.00995759
# Col
#  43 Row 25 CumPer 5 Phase -0.410129 Coherence 0.971654 RMSE 0.0278303
# Col
#  43 Row 26 CumPer 5 Phase -0.185154 Coherence 0.998733 RMSE 0.00664152
# Col
#  43 Row 27 CumPer 5 Phase 1.95157 Coherence 0.590596 RMSE 1.62471
# Col
#  43 Row 28 CumPer 5 Phase -0.263493 Coherence 0.998544 RMSE 0.00727809
# Col
#  43 Row 29 CumPer 5 Phase 1.22403 Coherence 0.497137 RMSE 0.750011
# Col
#  43 Row 30 CumPer 5 Phase -2.49488 Coherence 0.997215 RMSE 0.00911101
# Col
#  43 Row 31 CumPer 5 Phase -3.01058 Coherence 0.964921 RMSE 0.0356412
# Col
#  43 Row 32 CumPer 5 Phase 0.466526 Coherence 0.994718 RMSE 0.00847888
# Col
#  43 Row 33 CumPer 5 Phase -0.162592 Coherence 0.987893 RMSE 0.009588
# Col
#  43 Row 34 CumPer 5 Phase -1.16386 Coherence 0.967504 RMSE 0.0375475
# Col
#  44 Row 0 CumPer 5 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  44 Row 1 CumPer 5 Phase -1.8271 Coherence 0.995104 RMSE 0.00490455
# Col
#  44 Row 2 CumPer 5 Phase -1.88628 Coherence 0.99683 RMSE 0.00978524
# Col
#  44 Row 3 CumPer 5 Phase -1.41515 Coherence 0.992679 RMSE 0.0122717
# Col
#  44 Row 4 CumPer 5 Phase -2.81782 Coherence 0.997594 RMSE 0.00838633
# Col
#  44 Row 5 CumPer 5 Phase 2.99572 Coherence 0.996976 RMSE 0.00980207
# Col
#  44 Row 6 CumPer 5 Phase -2.54639 Coherence 0.980196 RMSE 0.00701111
# Col
#  44 Row 7 CumPer 5 Phase -2.01688 Coherence 0.995992 RMSE 0.0108323
# Col
#  44 Row 8 CumPer 5 Phase -1.51061 Coherence 0.993264 RMSE 0.0134876
# Col
#  44 Row 9 CumPer 5 Phase 2.7692 Coherence 0.994489 RMSE 0.00956616
# Col
#  44 Row 10 CumPer 5 Phase -0.438873 Coherence 0.993383 RMSE 0.0110439
# Col
#  44 Row 11 CumPer 5 Phase 0.834163 Coherence 0.982738 RMSE 0.0216576
# Col
#  44 Row 12 CumPer 5 Phase -1.50841 Coherence 0.983559 RMSE 0.00540307
# Col
#  44 Row 13 CumPer 5 Phase -2.17694 Coherence 0.989877 RMSE 0.00633628
# Col
#  44 Row 14 CumPer 5 Phase 2.70231 Coherence 0.982951 RMSE 0.0249091
# Col
#  44 Row 15 CumPer 5 Phase 1.97623 Coherence 0.998374 RMSE 0.00777386
# Col
#  44 Row 16 CumPer 5 Phase 1.66253 Coherence 0.998154 RMSE 0.00917646
# Col
#  44 Row 17 CumPer 5 Phase 1.09427 Coherence 0.999461 RMSE 0.00791437
# Col
#  44 Row 18 CumPer 5 Phase 2.49353 Coherence 0.997864 RMSE 0.00693824
# Col
#  44 Row 19 CumPer 5 Phase 1.36807 Coherence 0.992104 RMSE 0.0122459
# Col
#  44 Row 20 CumPer 5 Phase -1.27114 Coherence 0.735946 RMSE 0.250585
# Col
#  44 Row 21 CumPer 5 Phase 1.81963 Coherence 0.989817 RMSE 0.017957
# Col
#  44 Row 22 CumPer 5 Phase -2.94015 Coherence 0.998042 RMSE 0.0070288
# Col
#  44 Row 23 CumPer 5 Phase 2.29341 Coherence 0.996852 RMSE 0.00914729
# Col
#  44 Row 24 CumPer 5 Phase 0.392985 Coherence 0.974459 RMSE 0.0303751
# Col
#  44 Row 25 CumPer 5 Phase 0.486833 Coherence 0.95563 RMSE 0.0410236
# Col
#  44 Row 26 CumPer 5 Phase -2.24441 Coherence 0.997713 RMSE 0.00903051
# Col
#  44 Row 27 CumPer 5 Phase -0.808315 Coherence 0.99958 RMSE 0.00429667
# Col
#  44 Row 28 CumPer 5 Phase -0.142549 Coherence 0.998067 RMSE 0.00855128
# Col
#  44 Row 29 CumPer 5 Phase 0.506605 Coherence 0.971258 RMSE 0.0350682
# Col
#  44 Row 30 CumPer 5 Phase 2.85041 Coherence 0.988172 RMSE 0.020462
# Col
#  44 Row 31 CumPer 5 Phase 2.45871 Coherence 0.995758 RMSE 0.00341416
# Col
#  44 Row 32 CumPer 5 Phase 0.877133 Coherence 0.993695 RMSE 0.00290491
# Col
#  44 Row 33 CumPer 5 Phase -0.161594 Coherence 0.987492 RMSE 0.0179946
# Col
#  44 Row 34 CumPer 5 Phase 0.305016 Coherence 0.930841 RMSE 0.0381724
# Col
#  45 Row 0 CumPer 5 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  45 Row 1 CumPer 5 Phase -2.19419 Coherence 0.995954 RMSE 0.00572036
# Col
#  45 Row 2 CumPer 5 Phase -2.27472 Coherence 0.997833 RMSE 0.00662114
# Col
#  45 Row 3 CumPer 5 Phase -1.85109 Coherence 0.995022 RMSE 0.0112601
# Col
#  45 Row 4 CumPer 5 Phase 3.06954 Coherence 0.990289 RMSE 0.0161407
# Col
#  45 Row 5 CumPer 5 Phase -2.41869 Coherence 0.988859 RMSE 0.0108683
# Col
#  45 Row 6 CumPer 5 Phase -1.80945 Coherence 0.997562 RMSE 0.00345177
# Col
#  45 Row 7 CumPer 5 Phase -2.20742 Coherence 0.996304 RMSE 0.0112258
# Col
#  45 Row 8 CumPer 5 Phase -1.41227 Coherence 0.992918 RMSE 0.0157707
# Col
#  45 Row 9 CumPer 5 Phase 2.02105 Coherence 0.985636 RMSE 0.0198809
# Col
#  45 Row 10 CumPer 5 Phase -3.09524 Coherence 0.998978 RMSE 0.000396915
# Col
#  45 Row 11 CumPer 5 Phase -2.20507 Coherence 0.993917 RMSE 0.00393727
# Col
#  45 Row 12 CumPer 5 Phase -1.21671 Coherence 0.978645 RMSE 0.00860594
# Col
#  45 Row 13 CumPer 5 Phase -2.16264 Coherence 0.997107 RMSE 0.00573994
# Col
#  45 Row 14 CumPer 5 Phase 0.496645 Coherence 0.998897 RMSE 0.00451886
# Col
#  45 Row 15 CumPer 5 Phase 2.68304 Coherence 0.995977 RMSE 0.00982453
# Col
#  45 Row 16 CumPer 5 Phase 2.85619 Coherence 0.994994 RMSE 0.0128746
# Col
#  45 Row 17 CumPer 5 Phase 1.63239 Coherence 0.998964 RMSE 0.00735058
# Col
#  45 Row 18 CumPer 5 Phase 0.982768 Coherence 0.774416 RMSE 0.157987
# Col
#  45 Row 19 CumPer 5 Phase 1.63042 Coherence 0.997102 RMSE 0.0123865
# Col
#  45 Row 20 CumPer 5 Phase 3.00896 Coherence 0.997817 RMSE 0.00902874
# Col
#  45 Row 21 CumPer 5 Phase -0.104222 Coherence 0.983986 RMSE 0.0192185
# Col
#  45 Row 22 CumPer 5 Phase 1.1375 Coherence 0.988098 RMSE 0.0203941
# Col
#  45 Row 23 CumPer 5 Phase -1.33115 Coherence 0.846703 RMSE 0.0778919
# Col
#  45 Row 24 CumPer 5 Phase -0.762348 Coherence 0.983744 RMSE 0.00839913
# Col
#  45 Row 25 CumPer 5 Phase -0.931944 Coherence 0.991217 RMSE 0.0146059
# Col
#  45 Row 26 CumPer 5 Phase -0.858362 Coherence 0.99899 RMSE 0.00564457
# Col
#  45 Row 27 CumPer 5 Phase 2.22768 Coherence 0.997499 RMSE 1.7328
# Col
#  45 Row 28 CumPer 5 Phase -2.02299 Coherence 0.999614 RMSE 0.00326537
# Col
#  45 Row 29 CumPer 5 Phase 2.30892 Coherence 0.994744 RMSE 0.0143306
# Col
#  45 Row 30 CumPer 5 Phase -2.84682 Coherence 0.915585 RMSE 0.0562882
# Col
#  45 Row 31 CumPer 5 Phase -2.02265 Coherence 0.766908 RMSE 0.173763
# Col
#  45 Row 32 CumPer 5 Phase 0.89974 Coherence 0.961711 RMSE 0.0250091
# Col
#  45 Row 33 CumPer 5 Phase 0.125763 Coherence 0.971306 RMSE 0.0323764
# Col
#  45 Row 34 CumPer 5 Phase -0.644179 Coherence 0.798876 RMSE 0.127505
# Col
#  46 Row 0 CumPer 5 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  46 Row 1 CumPer 5 Phase -2.88105 Coherence 0.998019 RMSE 0.00600338
# Col
#  46 Row 2 CumPer 5 Phase -2.81067 Coherence 0.993882 RMSE 0.0114226
# Col
#  46 Row 3 CumPer 5 Phase -2.68489 Coherence 0.977195 RMSE 0.0241763
# Col
#  46 Row 4 CumPer 5 Phase -1.50734 Coherence 0.953069 RMSE 0.0141981
# Col
#  46 Row 5 CumPer 5 Phase -0.987121 Coherence 0.980131 RMSE 0.0163499
# Col
#  46 Row 6 CumPer 5 Phase -0.165937 Coherence 0.998889 RMSE 0.00525213
# Col
#  46 Row 7 CumPer 5 Phase -1.52126 Coherence 0.998254 RMSE 0.00711629
# Col
#  46 Row 8 CumPer 5 Phase -1.43838 Coherence 0.995921 RMSE 0.011204
# Col
#  46 Row 9 CumPer 5 Phase 0.140717 Coherence 0.988303 RMSE 0.0041541
# Col
#  46 Row 10 CumPer 5 Phase -1.87899 Coherence 0.995743 RMSE 0.0101754
# Col
#  46 Row 11 CumPer 5 Phase -1.53999 Coherence 0.990853 RMSE 0.0108086
# Col
#  46 Row 12 CumPer 5 Phase -0.63144 Coherence 0.996737 RMSE 0.0051896
# Col
#  46 Row 13 CumPer 5 Phase 0.140503 Coherence 0.997618 RMSE 0.00758619
# Col
#  46 Row 14 CumPer 5 Phase -3.0382 Coherence 0.998813 RMSE 0.00215642
# Col
#  46 Row 15 CumPer 5 Phase -3.11215 Coherence 0.999842 RMSE 0.00225567
# Col
#  46 Row 16 CumPer 5 Phase 2.99808 Coherence 0.997125 RMSE 0.00931653
# Col
#  46 Row 17 CumPer 5 Phase 2.18096 Coherence 0.999445 RMSE 0.00793493
# Col
#  46 Row 18 CumPer 5 Phase 1.52274 Coherence 0.999754 RMSE 0.0063567
# Col
#  46 Row 19 CumPer 5 Phase 2.30718 Coherence 0.99806 RMSE 0.00949538
# Col
#  46 Row 20 CumPer 5 Phase 2.59097 Coherence 0.988296 RMSE 0.0188286
# Col
#  46 Row 21 CumPer 5 Phase 0.706126 Coherence 0.995967 RMSE 0.0106363
# Col
#  46 Row 22 CumPer 5 Phase -1.56144 Coherence 0.89868 RMSE 0.05804
# Col
#  46 Row 23 CumPer 5 Phase -2.19326 Coherence 0.998873 RMSE 0.010085
# Col
#  46 Row 24 CumPer 5 Phase -2.64805 Coherence 0.951608 RMSE 0.0334583
# Col
#  46 Row 25 CumPer 5 Phase -2.24526 Coherence 0.999708 RMSE 0.00533021
# Col
#  46 Row 26 CumPer 5 Phase 1.10267 Coherence 0.660423 RMSE 0.301965
# Col
#  46 Row 27 CumPer 5 Phase 2.53478 Coherence 0.907941 RMSE 0.0467043
# Col
#  46 Row 28 CumPer 5 Phase -1.85127 Coherence 0.944818 RMSE 0.0503153
# Col
#  46 Row 29 CumPer 5 Phase 2.04015 Coherence 0.988194 RMSE 0.0198707
# Col
#  46 Row 30 CumPer 5 Phase 1.73976 Coherence 0.839975 RMSE 0.073444
# Col
#  46 Row 31 CumPer 5 Phase 1.24537 Coherence 0.824933 RMSE 0.0936997
# Col
#  46 Row 32 CumPer 5 Phase 0.0983093 Coherence 0.960104 RMSE 0.0369002
# Col
#  46 Row 33 CumPer 5 Phase 1.33975 Coherence 0.875483 RMSE 0.0793487
# Col
#  46 Row 34 CumPer 5 Phase 1.37023 Coherence 0.907165 RMSE 0.0704384
# Col
#  47 Row 0 CumPer 5 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  47 Row 1 CumPer 5 Phase -2.7618 Coherence 0.977963 RMSE 0.028143
# Col
#  47 Row 2 CumPer 5 Phase -2.36257 Coherence 0.988128 RMSE 0.0184146
# Col
#  47 Row 3 CumPer 5 Phase -2.45683 Coherence 0.979021 RMSE 0.027664
# Col
#  47 Row 4 CumPer 5 Phase -1.29041 Coherence 0.991572 RMSE 0.0158503
# Col
#  47 Row 5 CumPer 5 Phase -1.47287 Coherence 0.985134 RMSE 0.0161795
# Col
#  47 Row 6 CumPer 5 Phase -1.0858 Coherence 0.991447 RMSE 0.010985
# Col
#  47 Row 7 CumPer 5 Phase -0.603802 Coherence 0.992163 RMSE 0.011109
# Col
#  47 Row 8 CumPer 5 Phase -1.30118 Coherence 0.996064 RMSE 0.0036017
# Col
#  47 Row 9 CumPer 5 Phase -1.52957 Coherence 0.99408 RMSE 0.0111624
# Col
#  47 Row 10 CumPer 5 Phase -1.93338 Coherence 0.994747 RMSE 0.0130477
# Col
#  47 Row 11 CumPer 5 Phase -0.444891 Coherence 0.998777 RMSE 0.00441783
# Col
#  47 Row 12 CumPer 5 Phase -0.27034 Coherence 0.996803 RMSE 0.0103787
# Col
#  47 Row 13 CumPer 5 Phase 2.23728 Coherence 0.998598 RMSE 0.00814141
# Col
#  47 Row 14 CumPer 5 Phase -1.03664 Coherence 0.932755 RMSE 0.0172043
# Col
#  47 Row 15 CumPer 5 Phase 2.91189 Coherence 0.995623 RMSE 0.0118183
# Col
#  47 Row 16 CumPer 5 Phase 0.097946 Coherence 0.468543 RMSE 0.830537
# Col
#  47 Row 17 CumPer 5 Phase 2.65716 Coherence 0.997027 RMSE 0.00954743
# Col
#  47 Row 18 CumPer 5 Phase 0.574581 Coherence 0.998991 RMSE 0.00647443
# Col
#  47 Row 19 CumPer 5 Phase 2.32023 Coherence 0.999635 RMSE 0.00862707
# Col
#  47 Row 20 CumPer 5 Phase 1.85531 Coherence 0.994747 RMSE 0.00739728
# Col
#  47 Row 21 CumPer 5 Phase -2.94013 Coherence 0.999054 RMSE 0.00295601
# Col
#  47 Row 22 CumPer 5 Phase -2.79895 Coherence 0.992373 RMSE 0.0158545
# Col
#  47 Row 23 CumPer 5 Phase 2.40978 Coherence 0.814566 RMSE 0.0704193
# Col
#  47 Row 24 CumPer 5 Phase 2.64324 Coherence 0.999318 RMSE 0.00478376
# Col
#  47 Row 25 CumPer 5 Phase 2.97319 Coherence 0.999223 RMSE 0.00387192
# Col
#  47 Row 26 CumPer 5 Phase 2.96725 Coherence 0.997172 RMSE 0.00728416
# Col
#  47 Row 27 CumPer 5 Phase -2.87787 Coherence 0.994707 RMSE 0.0126498
# Col
#  47 Row 28 CumPer 5 Phase -2.20888 Coherence 0.965858 RMSE 0.0109408
# Col
#  47 Row 29 CumPer 5 Phase -2.34476 Coherence 0.905566 RMSE 0.0621661
# Col
#  47 Row 30 CumPer 5 Phase 0.856533 Coherence 0.799557 RMSE 0.0965358
# Col
#  47 Row 31 CumPer 5 Phase 1.1001 Coherence 0.916246 RMSE 0.0533427
# Col
#  47 Row 32 CumPer 5 Phase -0.520309 Coherence 0.93876 RMSE 0.0387638
# Col
#  47 Row 33 CumPer 5 Phase -0.609493 Coherence 0.834481 RMSE 0.134323
# Col
#  47 Row 34 CumPer 5 Phase -0.012444 Coherence 0.924257 RMSE 0.0591554
# D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\PLOT_MAPS_2008//phase_150.tif
# D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\PLOT_MAPS_2008//coherence_150.tif
# D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\PLOT_MAPS_2008//rmse_150.tif
# D:\Python27\lib\site-packages\nitime\utils.py:557: RuntimeWarning: Breaking due to iterative meltdown in nitime.utils.adaptive_weights.
#   warnings.warn(e_s, RuntimeWarning)

# %%
f, fxx, fyy, fxy = tsa.spectral.get_spectra_bi(x,y, method=dict(this_method='multi_taper_csd', Fs=1./0.4, BW=0.00122135, 
                                                                adaptive=True, low_bias=True ))
plot(f, fxx)
plot(f, fyy)
plot(f, fxy)
xlim([0,0.012])
xticks([0.002,0.0022,0.0024,0.0026,0.0028,0.003,0.0032,0.0034,0.0036,0.0038,0.004])

# %%
f, ccy = tsa.cohere.coherency(q, csd_method=dict(this_method='multi_taper_csd', Fs=1./0.4, BW=0.00122135, 
                                                                adaptive=True, low_bias=True ))
plot(f,ccy[1][0])
xlim([0,0.012])

# %%
f, cce = tsa.cohere.coherence(q, csd_method=dict(this_method='multi_taper_csd', Fs=1./0.4, BW=0.00122135, 
                                                                adaptive=True, low_bias=True ))
plot(f,cce[0][1])
xlim([0,0.012])
ylim([-0.1,1.1])

# %%
f, p = tsa.cohere.coherency_phase_spectrum(q, csd_method=dict(this_method='multi_taper_csd', Fs=1./0.4, BW=0.00122135, 
                                                                adaptive=True, low_bias=True ))
plot(f,p[0][1])
xlim([0,0.012])

# %%
c = cce[0][1][(0.0022 < f) & (f <0.0032)]
y = p[0][1][(0.0022 < f) & (f <0.0032)]
xi = f[(0.0022 < f) & (f <0.0032)]
plot(xi,y)

# %%
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(xi,y)

print 'r value', r_value
print  'p_value', p_value
print 'standard deviation', std_err

line = slope*xi+intercept
plot(xi,line,'r-',xi,y,'o')
show()

# %%
mse = ((y - line)**2).mean(axis=None)
rmse = math.sqrt(mse)
coher = c.mean()
phase = y.mean()
print (rmse, coher, phase)

# %%
np.arctan2(
