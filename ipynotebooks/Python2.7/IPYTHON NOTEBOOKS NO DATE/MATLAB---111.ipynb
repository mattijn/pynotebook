# %%
import pymat2
import os
import pandas as pd
from osgeo import gdal
import numpy as np
import datetime
import matplotlib.pyplot as plt
from scipy.signal import detrend as sp_detrend
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as pl
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig
import scipy.stats.distributions as dist

import nitime.algorithms as tsa
import nitime.utils as utils
from nitime.viz import winspect
from nitime.viz import plot_spectral_estimate

import datetime
import numpy as np
import pandas as pd
import matplotlib as mpl
import sys, os, re
from scipy import stats
# Out:
# D:\Python27\lib\site-packages\matplotlib\cbook.py:122: MatplotlibDeprecationWarning: The matplotlib.mpl module was deprecated in version 1.3. Use `import matplotlib as mpl` instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
def saveRaster(path, array, dsSource, datatype=3, formatraster="GTiff", nan=None): 
    """
    Datatypes:
    unknown = 0
    byte = 1
    unsigned int16 = 2
    signed int16 = 3
    unsigned int32 = 4
    signed int32 = 5
    float32 = 6
    float64 = 7
    complex int16 = 8
    complex int32 = 9
    complex float32 = 10
    complex float64 = 11
    float32 = 6, 
    signed int = 3
    
    Formatraster:
    GeoTIFF = GTiff
    Erdas = HFA (output = .img)
    OGC web map service = WMS
    png = PNG
    """
    # Set Driver
    format_ = formatraster #save as format
    driver = gdal.GetDriverByName( format_ )
    driver.Register()
    
    # Set Metadata for Raster output
    cols = dsSource.RasterXSize
    rows = dsSource.RasterYSize
    bands = dsSource.RasterCount
    datatype = datatype#band.DataType
    
    # Set Projection for Raster
    outDataset = driver.Create(path, cols, rows, bands, datatype)
    geoTransform = dsSource.GetGeoTransform()
    outDataset.SetGeoTransform(geoTransform)
    proj = dsSource.GetProjection()
    outDataset.SetProjection(proj)
    
    # Write output to band 1 of new Raster and write NaN value
    outBand = outDataset.GetRasterBand(1)
    if nan != None:
        outBand.SetNoDataValue(nan)
    outBand.WriteArray(array) #save input array
    #outBand.WriteArray(dem)
    
    # Close and finalise newly created Raster
    #F_M01 = None
    outBand = None
    proj = None
    geoTransform = None
    outDataset = None
    driver = None
    datatype = None
    bands = None
    rows = None
    cols = None
    driver = None
    array = None

# %%
# Colors via http://colorbrewer2.com/
WHITE, LIGHT_GRAY, GRAY, BLACK = [ "#FFFFFF", "#E5E5E5", "#777777", "#000000" ] 
COLORS = [ "#2C7BB6", "#FF6600", "#660099", "#D7191C", "#FFFFBF", "#ABD9E9"]
BLUE, ORANGE, PURPLE, RED, YELLOW, LIGHT_BLUE = COLORS
HIGH_ALPHA = 0.9
MEDIUM_ALPHA = 0.5
LOW_ALPHA = 0.1
rgba = mpl.colors.colorConverter.to_rgba

def set_styles(style_dict):
    """Set matplotlib styles from nested a nested dictionary"""
    for obj in style_dict: mpl.rc(obj, **style_dict[obj]) 

set_styles({
    "figure": { "figsize": [ 12, 4 ], "facecolor": WHITE },
    "savefig": { "dpi": 200, "bbox": "tight" },
    "patch": { "linewidth": 0.5, "facecolor": ORANGE, "edgecolor": WHITE, "antialiased": True },
    "font": { "size": 8 },
    "legend": { "fontsize": 10 },
    "axes": { 
        "facecolor": LIGHT_GRAY, 
        "edgecolor": WHITE, 
        "linewidth": 1, 
        "grid": True, 
        "titlesize": "large", 
        "labelsize": "large", 
        "labelcolor": BLACK,
        "axisbelow": True,
        "color_cycle": COLORS
    },
    "xtick": { "color": GRAY, "direction": "out" }, #GRAY
    "ytick": { "color": GRAY, "direction": "out" }, #GRAY
    "grid": { "color": WHITE, "linestyle": "-" }
})

# %%
def savitzky_golay(y, window_size, order, deriv=0, rate=1):
    r"""Smooth (and optionally differentiate) data with a Savitzky-Golay filter.
    The Savitzky-Golay filter removes high frequency noise from data.
    It has the advantage of preserving the original shape and
    features of the signal better than other types of filtering
    approaches, such as moving averages techniques.
    Parameters
    ----------
    y : array_like, shape (N,)
        the values of the time history of the signal.
    window_size : int
        the length of the window. Must be an odd integer number.
    order : int
        the order of the polynomial used in the filtering.
        Must be less then `window_size` - 1.
    deriv: int
        the order of the derivative to compute (default = 0 means only smoothing)
    Returns
    -------
    ys : ndarray, shape (N)
        the smoothed signal (or it's n-th derivative).
    Notes
    -----
    The Savitzky-Golay is a type of low-pass filter, particularly
    suited for smoothing noisy data. The main idea behind this
    approach is to make for each point a least-square fit with a
    polynomial of high order over a odd-sized window centered at
    the point.
    Examples
    --------
    t = np.linspace(-4, 4, 500)
    y = np.exp( -t**2 ) + np.random.normal(0, 0.05, t.shape)
    ysg = savitzky_golay(y, window_size=31, order=4)
    import matplotlib.pyplot as plt
    plt.plot(t, y, label='Noisy signal')
    plt.plot(t, np.exp(-t**2), 'k', lw=1.5, label='Original signal')
    plt.plot(t, ysg, 'r', label='Filtered signal')
    plt.legend()
    plt.show()
    References
    ----------
    .. [1] A. Savitzky, M. J. E. Golay, Smoothing and Differentiation of
       Data by Simplified Least Squares Procedures. Analytical
       Chemistry, 1964, 36 (8), pp 1627-1639.
    .. [2] Numerical Recipes 3rd Edition: The Art of Scientific Computing
       W.H. Press, S.A. Teukolsky, W.T. Vetterling, B.P. Flannery
       Cambridge University Press ISBN-13: 9780521880688
    """
    import numpy as np
    from math import factorial

    try:
        window_size = np.abs(np.int(window_size))
        order = np.abs(np.int(order))
    except ValueError as msg:
        raise ValueError("window_size and order have to be of type int")
    if window_size % 2 != 1 or window_size < 1:
        raise TypeError("window_size size must be a positive odd number")
    if window_size < order + 2:
        raise TypeError("window_size is too small for the polynomials order")
    order_range = range(order+1)
    half_window = (window_size -1) // 2
    # precompute coefficients
    b = np.mat([[k**i for i in order_range] for k in range(-half_window, half_window+1)])
    m = np.linalg.pinv(b).A[deriv] * rate**deriv * factorial(deriv)
    # pad the signal at the extremes with
    # values taken from the signal itself
    firstvals = y[0] - np.abs( y[1:half_window+1][::-1] - y[0] )
    lastvals = y[-1] + np.abs(y[-half_window-1:-1][::-1] - y[-1])
    y = np.concatenate((firstvals, y, lastvals))
    return np.convolve( m[::-1], y, mode='valid')

# %%
def _datacheck_peakdetect(x_axis, y_axis):
    if x_axis is None:
        x_axis = range(len(y_axis))
    
    if len(y_axis) != len(x_axis):
        raise (ValueError, 
                'Input vectors y_axis and x_axis must have same length')
    
    #needs to be a numpy array
    y_axis = np.array(y_axis)
    x_axis = np.array(x_axis)
    return x_axis, y_axis

# %%
def peakdetect(y_axis, x_axis = None, lookahead = 300, delta=0):
    """
    Converted from/based on a MATLAB script at: 
    http://billauer.co.il/peakdet.html
    
    function for detecting local maximas and minmias in a signal.
    Discovers peaks by searching for values which are surrounded by lower
    or larger values for maximas and minimas respectively
    
    keyword arguments:
    y_axis -- A list containg the signal over which to find peaks
    x_axis -- (optional) A x-axis whose values correspond to the y_axis list
        and is used in the return to specify the postion of the peaks. If
        omitted an index of the y_axis is used. (default: None)
    lookahead -- (optional) distance to look ahead from a peak candidate to
        determine if it is the actual peak (default: 200) 
        '(sample / period) / f' where '4 >= f >= 1.25' might be a good value
    delta -- (optional) this specifies a minimum difference between a peak and
        the following points, before a peak may be considered a peak. Useful
        to hinder the function from picking up false peaks towards to end of
        the signal. To work well delta should be set to delta >= RMSnoise * 5.
        (default: 0)
            delta function causes a 20% decrease in speed, when omitted
            Correctly used it can double the speed of the function
    
    return -- two lists [max_peaks, min_peaks] containing the positive and
        negative peaks respectively. Each cell of the lists contains a tupple
        of: (position, peak_value) 
        to get the average peak value do: np.mean(max_peaks, 0)[1] on the
        results to unpack one of the lists into x, y coordinates do: 
        x, y = zip(*tab)
    """
    max_peaks = []
    min_peaks = []
    dump = []   #Used to pop the first hit which almost always is false
       
    # check input data
    x_axis, y_axis = _datacheck_peakdetect(x_axis, y_axis)
    # store data length for later use
    length = len(y_axis)
    
    
    #perform some checks
    if lookahead < 1:
        raise ValueError ( "Lookahead must be '1' or above in value")
    if not (np.isscalar(delta) and delta >= 0):
        raise ValueError ( "delta must be a positive number" )
    
    #maxima and minima candidates are temporarily stored in
    #mx and mn respectively
    mn, mx = np.Inf, -np.Inf
    
    #Only detect peak if there is 'lookahead' amount of points after it
    for index, (x, y) in enumerate(zip(x_axis[:-lookahead], 
                                        y_axis[:-lookahead])):
        if y > mx:
            mx = y
            mxpos = x
        if y < mn:
            mn = y
            mnpos = x
        
        ####look for max####
        if y < mx-delta and mx != np.Inf:
            #Maxima peak candidate found
            #look ahead in signal to ensure that this is a peak and not jitter
            if y_axis[index:index+lookahead].max() < mx:
                max_peaks.append([mxpos, mx])
                dump.append(True)
                #set algorithm to only find minima now
                mx = np.Inf
                mn = np.Inf
                if index+lookahead >= length:
                    #end is within lookahead no more peaks can be found
                    break
                continue
            #else:  #slows shit down this does
            #    mx = ahead
            #    mxpos = x_axis[np.where(y_axis[index:index+lookahead]==mx)]
        
        ####look for min####
        if y > mn+delta and mn != -np.Inf:
            #Minima peak candidate found 
            #look ahead in signal to ensure that this is a peak and not jitter
            if y_axis[index:index+lookahead].min() > mn:
                min_peaks.append([mnpos, mn])
                dump.append(False)
                #set algorithm to only find maxima now
                mn = -np.Inf
                mx = -np.Inf
                if index+lookahead >= length:
                    #end is within lookahead no more peaks can be found
                    break
            #else:  #slows shit down this does
            #    mn = ahead
            #    mnpos = x_axis[np.where(y_axis[index:index+lookahead]==mn)]
    
    
    #Remove the false hit on the first value of the y_axis
    try:
        if dump[0]:
            max_peaks.pop(0)
        else:
            min_peaks.pop(0)
        del dump
    except IndexError:
        #no peaks were found, should the function return empty lists?
        pass
        
    return [max_peaks, min_peaks]

# %%
def listall(RootFolder, wildcard=''):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if wildcard in name
                     if name.endswith('.tif')]
    return lists

def getvalues(rootpath, pc, pr, wildcard=''):
    
    li = []
    da = []
    i = 0
    
    #path = r'D:\Data\GPCP_30acc_AnnualAcc'
    test = listall(rootpath, wildcard)
    #test = test[0:-46]
    #print (len(test))
    #print (test[0])
    for t in test:    
        raster = gdal.Open(t, gdal.GA_ReadOnly)
        nameRas = raster.GetDescription()[-11:-4]
        date = datetime.datetime(int(nameRas[0:4]), 1, 1) + datetime.timedelta(int(nameRas[4:9]) - 1) # replaced "int(nameRas[0:4])" with "2010" first year then add doy
        # print date
        da.append(date)
    
        band = raster.GetRasterBand(1)
        array = band.ReadAsArray()    
        
        # print array[879,4142] # Grassland pixel
        li.append(array[pr, pc])
        
        array = None
        band = None
        raster = None
        #print (str(i))
        i = i + 1
        
    signal = pd.Series(data = li, index = da)
    return signal

# %%
import pymat2
ml = pymat2.Matlab()
ml.start()

ml.outputBufferSize = 5000

# %%
ml.restart()
ml.eval('x=3*7;x')
# Out:
# 'x =\n\n    21\n\n'

# %%
mth = [0.5, 1, 2, 3, 4, 5]
prd = [15, 30, 60, 90, 120, 150]
pth1 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2_2009\XX_Day_Period\XX_DaySums_StdNormAnomaly'# removed 'NormTypeII'
pth2 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\NDVI_2009\DaySums_StdNormAnomalyRes'# removed 'NormTypeII'

#pixelcolumn = 23 # extract from rasterXSize (0:62) horizontal latitude - whatever
#pixelrow = 21 # extract from rasterYSize (0:36) vertical longitude 
#folderp1 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\PLOT_CHARTS_2009\COHERENCE2\p5//'
#folderp2 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\PLOT_CHARTS_2009\COHERENCE2\p4//'

ph = pth2+'//TRMM_CQ_2009001.tif'
ds = gdal.Open(ph)
base = ds.ReadAsArray()

for i in range(0,6):
    phase_array = np.zeros_like(base)
    coher_array = np.zeros_like(base)
    rmse_array = np.zeros_like(base)
    
    for j in range(0, 48): # pixelcolumn
        for k in range(0,35): # pixelrow
        
            # Set path for cumulative period of precipitation
            # And corresponding period time
            cumper = mth[i]
            period = prd[i]
            paths1 = pth1.replace('XX', str(period))
            paths2 = pth2
            
    
            # Set pixelvalues
            # TODO: Implementation to read row by row or all-in-one
            pixelcolumn = j
            pixelrow = k
            
            # Get values for precipitation based on cumper 
            # And only update values for NDVI with a new pixel
            s_org2 = getvalues(paths2, pixelcolumn, pixelrow, wildcard='CQ')            
            if s_org2.mean()<>-99999.0:
                s_org1 = getvalues(paths1, pixelcolumn, pixelrow, wildcard='TRMM')                
            
                # Create dataframe from the two series and apply an outer join            
                df1 = pd.DataFrame(s_org1, columns=['prcp'])
                df2 = pd.DataFrame(s_org2, columns=['ndvi'])            
                df = pd.concat([df1, df2], join='outer', axis=1)
                
                # Before splitting the signals, first drop eventual NaN values
                df = df.dropna()            
                s1 = df['prcp']
                s2 = df['ndvi']
                
                hg = mlab.csd(np.resize(s1, (s1.size*100) ),np.resize(s2, (s2.size*100) ), NFFT=100*len(np.resize(s2, (s2.size*100) )), Fs=1)
                kl = peakdetect(hg[0].real[0:20000], hg[1][0:20000])
                jh = angle(hg[0])
                try:
                    lo= jh[np.where(hg[1]==kl[0][0][0])]/(2*np.pi*kl[0][0][0])
                    cl= kl[0][0][1]
                except IndexError:
                    lo= jh[np.where(hg[1]==kl[1][0][0])]/(2*np.pi*kl[1][0][0])
                    cl= kl[1][0][1]

                
                
                #lo= jh[np.where(hg[1]==kl[1][0][0])]/(2*np.pi*kl[1][0][0])
                #cl= kl[1][0][1]
                
                phase_array[k][j] = lo.flatten()                
                coher_array[k][j] = cl.flatten()                
                #x = s1.values
                #y = s2.values
                # Extent annual signal to 20 years
                
                
                #x = np.resize(x, (x.size*20) )
                #y = np.resize(y, (y.size*20) )
                
                # Normalise annual signal
                #x = (x - x.mean())/x.std()
                #y = (y - y.mean())/y.std()  
                #print len(x)
                #print len(y)
                #ml.putArray("x",x)
                #ml.putArray("y",y)
                #print (rmse, coher, phase) 
                #phase_array[k][j] = phl
                #coher_array[k][j] = cl
                #rmse_array[k][j] = phil
            else:
                phase_array[k][j] = -99999.0
                coher_array[k][j] = -99999.0
                #rmse_array[k][j] = -99999.0
            print 'Col',j,'Row', k, 'CumPer', i, 'Phase',phase_array[k][j], 'Coherence', coher_array[k][j], #'RMSE', rmse_array[k][j]
                
            
    folder = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\PLOT_MAPS_2009\matlab2//'
    path_phase = folder+'phase_'+str(prd[i])+'.tif'
    path_coher = folder+'coherence_'+str(prd[i])+'.tif'
    #path_rmse = folder+'rmse_'+str(prd[i])+'.tif'

    saveRaster(path_phase, phase_array, ds, datatype=6, nan=-99999.0)
    saveRaster(path_coher, coher_array, ds, datatype=6, nan=-99999.0)
    #saveRaster(path_rmse, rmse_array, ds, datatype=6, nan=-99999.0)
    
    print path_phase
    print path_coher
    #print path_rmse
# Out:
#  Col 0 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 0 Row 18 CumPer 0 Phase 5.06353 Coherence 7.98495e-08
# Col 0 Row 19 CumPer 0 Phase 129.096 Coherence -8.50437e-08
# Col 0 Row 20 CumPer 0 Phase -311.324 Coherence -1.56556e-11
# Col 0 Row 21 CumPer 0 Phase -225.972 Coherence -3.52465e-11
# Col 0 Row 22 CumPer 0 Phase -86.9847 Coherence 1.24365e-08
# Col 0 Row 23 CumPer 0 Phase -193.798 Coherence -2.643e-12
# Col 0 Row 24 CumPer 0 Phase -3.30094 Coherence 1.32215e-07
# Col 0 Row 25 CumPer 0 Phase -38.8371 Coherence 6.00246e-08
# Col 0 Row 26 CumPer 0 Phase 9.09703 Coherence 1.50169e-07
# Col 0 Row 27 CumPer 0 Phase 11.3561 Coherence 3.06706e-07
# Col 0 Row 28 CumPer 0 Phase 45.6014 Coherence 3.71507e-07
# Col 0 Row 29 CumPer 0 Phase 17.7786 Coherence 3.33084e-07
# Col 0 Row 30 CumPer 0 Phase -48.7137 Coherence 6.9608e-08
# Col 0 Row 31 CumPer 0 Phase -12.0955 Coherence 3.23039e-08
# Col 0 Row 32 CumPer 0 Phase 9.14299 Coherence 5.37207e-08
# Col 0 Row 33 CumPer 0 Phase -22.2394 Coherence 1.42656e-07
# Col 0 Row 34 CumPer 0 Phase -66.7381 Coherence 4.71263e-08
# Col 1 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 1 Row 18 CumPer 0 Phase 89.5176 Coherence 6.18058e-11
# Col 1 Row 19 CumPer 0 Phase 166.411 Coherence -2.34806e-07
# Col 1 Row 20 CumPer 0 Phase -128.793 Coherence -1.0643e-08
# Col 1 Row 21 CumPer 0 Phase -276.606 Coherence -3.12081e-11
# Col 1 Row 22 CumPer 0 Phase -81.1985 Coherence 3.15244e-08
# Col 1 Row 23 CumPer 0 Phase -58.8019 Coherence 1.23444e-07
# Col 1 Row 24 CumPer 0 Phase -13.9367 Coherence 1.02166e-07
# Col 1 Row 25 CumPer 0 Phase 21.9718 Coherence 2.22375e-07
# Col 1 Row 26 CumPer 0 Phase 6.37774 Coherence 2.42624e-07
# Col 1 Row 27 CumPer 0 Phase 14.5811 Coherence 2.98762e-07
# Col 1 Row 28 CumPer 0 Phase 23.5968 Coherence 3.04571e-07
# Col 1 Row 29 CumPer 0 Phase -35.09 Coherence 1.49154e-07
# Col 1 Row 30 CumPer 0 Phase -19.2095 Coherence 1.72862e-07
# Col 1 Row 31 CumPer 0 Phase 0.901919 Coherence 1.47059e-07
# Col 1 Row 32 CumPer 0 Phase -21.2431 Coherence 1.37446e-07
# Col 1 Row 33 CumPer 0 Phase -29.9276 Coherence 1.91763e-07
# Col 1 Row 34 CumPer 0 Phase -45.0376 Coherence 1.96806e-07
# Col 2 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 2 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 2 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 2 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 2 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 2 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 2 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 2 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 2 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 2 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 2 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col
CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 18 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 4 Row 19 CumPer 0 Phase -255.882 Coherence -1.22022e-12
# Col 4 Row 20 CumPer 0 Phase -48.3539 Coherence 8.17345e-08
# Col 4 Row 21 CumPer 0 Phase -190.736 Coherence -8.91404e-12
# Col 4 Row 22 CumPer 0 Phase -70.8381 Coherence 3.91726e-08
# Col 4 Row 23 CumPer 0 Phase -19.2109 Coherence 1.81233e-07
# Col 4 Row 24 CumPer 0 Phase -10.4206 Coherence 1.15101e-07
# Col 4 Row 25 CumPer 0 Phase -8.77964 Coherence 1.44525e-07
# Col 4 Row 26 CumPer 0 Phase -9.79107 Coherence 2.34123e-07
# Col 4 Row 27 CumPer 0 Phase -41.6697 Coherence 7.56369e-08
# Col 4 Row 28 CumPer 0 Phase -20.4697 Coherence 2.76426e-07
# Col 4 Row 29 CumPer 0 Phase -15.4055 Coherence 3.62127e-07
# Col 4 Row 30 CumPer 0 Phase -23.6156 Coherence 2.4443e-07
# Col 4 Row 31 CumPer 0 Phase -24.1805 Coherence 1.89031e-07
# Col 4 Row 32 CumPer 0 Phase -10.2665 Coherence 2.84399e-07
# Col 4 Row 33 CumPer 0 Phase -7.85615 Coherence 3.79199e-07
# Col 4 Row 34 CumPer 0 Phase -23.9943 Coherence 1.31649e-07
# Col 5 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 18 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 5 Row 19 CumPer 0 Phase 77.0962 Coherence 1.77329e-08
# Col 5 Row 20 CumPer 0 Phase -29.474 Coherence 1.10795e-07
# Col 5 Row 21 CumPer 0 Phase -59.6294 Coherence 7.91261e-08
# Col 5 Row 22 CumPer 0 Phase -221.046 Coherence -7.36604e-11
# Col 5 Row 23 CumPer 0 Phase -81.4145 Coherence 4.70693e-08
# Col 5 Row 24 CumPer 0 Phase -37.9423 Coherence 3.80383e-08
# Col 5 Row 25 CumPer 0 Phase -7.71204 Coherence 1.45305e-07
# Col 5 Row 26 CumPer 0 Phase -5.0754 Coherence 4.0208e-07
# Col 5 Row 27 CumPer 0 Phase -28.4321 Coherence 2.30019e-07
# Col 5 Row 28 CumPer 0 Phase -66.3093 Coherence 2.01282e-07
# Col 5 Row 29 CumPer 0 Phase -54.1439 Coherence 2.14019e-07
# Col 5 Row 30 CumPer 0 Phase -51.9119 Coherence 2.07969e-07
# Col 5 Row 31 CumPer 0 Phase -20.9036 Coherence 2.46659e-07
# Col 5 Row 32 CumPer 0 Phase -8.07802 Coherence 3.49975e-07
# Col 5 Row 33 CumPer 0 Phase -0.187497 Coherence 4.83026e-07
# Col 5 Row 34 CumPer 0 Phase -20.5279 Coherence 1.16279e-07
# Col 6 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col
Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 18 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 8 Row 19 CumPer 0 Phase -68.0196 Coherence 3.93687e-08
# Col 8 Row 20 CumPer 0 Phase -37.9723 Coherence 2.40734e-07
# Col 8 Row 21 CumPer 0 Phase -74.1074 Coherence 5.691e-08
# Col 8 Row 22 CumPer 0 Phase -67.8457 Coherence 1.59398e-07
# Col 8 Row 23 CumPer 0 Phase -64.2793 Coherence 2.07793e-07
# Col 8 Row 24 CumPer 0 Phase -29.2303 Coherence 2.43776e-07
# Col 8 Row 25 CumPer 0 Phase -9.29969 Coherence 1.57371e-07
# Col 8 Row 26 CumPer 0 Phase -215.2 Coherence -1.88344e-11
# Col 8 Row 27 CumPer 0 Phase -13.7967 Coherence 3.28018e-07
# Col 8 Row 28 CumPer 0 Phase -45.9875 Coherence 1.8499e-07
# Col 8 Row 29 CumPer 0 Phase -42.2276 Coherence 1.98267e-07
# Col 8 Row 30 CumPer 0 Phase -38.683 Coherence 3.04071e-07
# Col 8 Row 31 CumPer 0 Phase 39.4137 Coherence 1.84251e-07
# Col 8 Row 32 CumPer 0 Phase -10.1107 Coherence 3.34603e-07
# Col 8 Row 33 CumPer 0 Phase 11.8874 Coherence 2.49611e-07
# Col 8 Row 34 CumPer 0 Phase -47.2604 Coherence 1.88546e-07
# Col 9 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 17 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 9 Row 18 CumPer 0 Phase -4.48043 Coherence 6.77724e-08
# Col 9 Row 19 CumPer 0 Phase -76.4081 Coherence 3.46428e-08
# Col 9 Row 20 CumPer 0 Phase -22.0931 Coherence 1.96139e-07
# Col 9 Row 21 CumPer 0 Phase -46.809 Coherence 1.57582e-07
# Col 9 Row 22 CumPer 0 Phase -25.7668 Coherence 3.65587e-07
# Col 9 Row 23 CumPer 0 Phase -30.0798 Coherence 1.00797e-07
# Col 9 Row 24 CumPer 0 Phase -19.2788 Coherence 2.35782e-07
# Col 9 Row 25 CumPer 0 Phase 25.6676 Coherence 7.00596e-08
# Col 9 Row 26 CumPer 0 Phase -266.585 Coherence -1.20361e-10
# Col 9 Row 27 CumPer 0 Phase -9.06931 Coherence 2.85705e-07
# Col 9 Row 28 CumPer 0 Phase -59.1406 Coherence 1.95295e-07
# Col 9 Row 29 CumPer 0 Phase -66.1508 Coherence 1.03834e-07
# Col 9 Row 30 CumPer 0 Phase 0.458404 Coherence 3.83528e-07
# Col 9 Row 31 CumPer 0 Phase 63.2295 Coherence 6.96008e-08
# Col 9 Row 32 CumPer 0 Phase 30.054 Coherence 1.55217e-07
# Col 9 Row 33 CumPer 0 Phase -16.568 Coherence 2.86069e-07
# Col 9 Row 34 CumPer 0 Phase -12.9967 Coherence 2.39527e-07
# Col 10 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col
# Col 19 Row 26 CumPer 0 Phase -52.2351 Coherence 2.01756e-07
# Col 19 Row 27 CumPer 0 Phase -22.8873 Coherence 6.5334e-07
# Col 19 Row 28 CumPer 0 Phase -51.8451 Coherence 7.14207e-07
# Col 19 Row 29 CumPer 0 Phase -51.8062 Coherence 6.08569e-07
# Col 19 Row 30 CumPer 0 Phase -33.1004 Coherence 4.14591e-07
# Col 19 Row 31 CumPer 0 Phase -40.666 Coherence 5.08954e-07
# Col 19 Row 32 CumPer 0 Phase -54.1584 Coherence 1.84245e-07
# Col 19 Row 33 CumPer 0 Phase -36.8371 Coherence 2.41451e-07
# Col 19 Row 34 CumPer 0 Phase -11.7474 Coherence 1.47826e-07
# Col 20 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 20 Row 1 CumPer 0 Phase 83.066 Coherence 1.74614e-08
# Col 20 Row 2 CumPer 0 Phase 62.262 Coherence 5.3446e-08
# Col 20 Row 3 CumPer 0 Phase -162.637 Coherence -2.91633e-08
# Col 20 Row 4 CumPer 0 Phase 398.706 Coherence -5.05734e-11
# Col 20 Row 5 CumPer 0 Phase -330.376 Coherence -8.01824e-11
# Col 20 Row 6 CumPer 0 Phase -313.632 Coherence -3.29285e-11
# Col 20 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 20 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 20 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 20 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 20 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 20 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 20 Row 13 CumPer 0 Phase -84.1076 Coherence 1.09903e-08
# Col 20 Row 14 CumPer 0 Phase -351.376 Coherence -1.69817e-11
# Col 20 Row 15 CumPer 0 Phase -45.9896 Coherence 1.72062e-07
# Col 20 Row 16 CumPer 0 Phase 1.95627 Coherence 3.29936e-07
# Col 20 Row 17 CumPer 0 Phase 9.10958 Coherence 3.3148e-07
# Col 20 Row 18 CumPer 0 Phase 27.478 Coherence 5.41696e-07
# Col 20 Row 19 CumPer 0 Phase 3.70625 Coherence 4.62174e-07
# Col 20 Row 20 CumPer 0 Phase 23.4345 Coherence 7.2287e-07
# Col 20 Row 21 CumPer 0 Phase 28.4206 Coherence 6.82948e-07
# Col 20 Row 22 CumPer 0 Phase 19.0961 Coherence 8.50135e-07
# Col 20 Row 23 CumPer 0 Phase -45.9583 Coherence 3.77203e-07
# Col 20 Row 24 CumPer 0 Phase -216.86 Coherence -4.10976e-11
# Col 20 Row 25 CumPer 0 Phase -60.3718 Coherence 2.53355e-07
# Col 20 Row 26 CumPer 0 Phase -5.11903 Coherence 6.28252e-07
# Col 20 Row 27 CumPer 0 Phase -47.7556 Coherence 6.66533e-07
# Col 20 Row 28 CumPer 0 Phase -33.8826 Coherence 7.41193e-07
# Col 20 Row 29 CumPer 0 Phase -41.4475 Coherence 7.19873e-07
# Col 20 Row 30 CumPer 0 Phase -47.6248 Coherence 2.45982e-07
# Col 20 Row 31 CumPer 0 Phase -45.1267 Coherence 3.35627e-07
# Col 20 Row 32 CumPer 0 Phase -22.5561 Coherence 1.63324e-07
# Col 20 Row 33 CumPer 0 Phase -59.85 Coherence 6.69366e-08
# Col 20 Row 34 CumPer 0 Phase 39.3375 Coherence 1.68791e-07
# Col 21 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 21 Row 1 CumPer 0 Phase 97.1239 Coherence 1.15343e-11
# Col 21 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 21 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 21 Row 4 CumPer 0 Phase -313.981 Coherence -4.90956e-11
# Col 21 Row 5 CumPer 0 Phase -308.79 Coherence -7.13882e-11
# Col 21 Row 6 CumPer 0 Phase 332.722 Coherence -9.98507e-11
# Col 21 Row 7 CumPer 0 Phase 41.4976 Coherence 1.73376e-08
# Col 21 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 21 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 21 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 21 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 21 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 21 Row 13 CumPer 0 Phase -267.505 Coherence -4.26445e-12
# Col 21 Row 14 CumPer 0 Phase -82.6466 Coherence 1.10663e-08
# Col 21 Row 15 CumPer 0 Phase -61.2131 Coherence 5.28379e-08
# Col 21 Row 16 CumPer 0 Phase -0.0201823 Coherence 3.09736e-07
# Col 21 Row 17 CumPer 0 Phase 11.5404 Coherence 4.52649e-07
# Col 21 Row 18 CumPer 0 Phase 34.2959 Coherence 2.9625e-07
# Col 21 Row 19 CumPer 0 Phase 1.57403 Coherence 5.85501e-07
# Col 21 Row 20 CumPer 0 Phase 22.497 Coherence 6.64765e-07
# Col 21 Row 21 CumPer 0 Phase 23.768 Coherence 4.75066e-07
# Col 21 Row 22 CumPer 0 Phase -13.2775 Coherence 8.27158e-07
# Col 21 Row 23 CumPer 0 Phase -41.2825 Coherence 2.2872e-07
# Col 21 Row 24 CumPer 0 Phase -49.3128 Coherence 1.41795e-07
# Col 21 Row 25 CumPer 0 Phase -25.3234 Coherence 4.34791e-07
# Col 21 Row 26 CumPer 0 Phase -66.7917 Coherence 1.5311e-07
# Col 21 Row 27 CumPer 0 Phase -33.5917 Coherence 8.58378e-07
# Col 21 Row 28 CumPer 0 Phase -42.3508 Coherence 7.05493e-07
# Col 21 Row 29 CumPer 0 Phase -19.3849 Coherence 1.06333e-06
# Col 21 Row 30 CumPer 0 Phase -30.8191 Coherence 5.89774e-07
# Col 21 Row 31 CumPer 0 Phase -51.3227 Coherence 4.41138e-07
# Col 21 Row 32 CumPer 0 Phase -7.86739 Coherence 2.08758e-07
# Col 21 Row 33 CumPer 0 Phase -29.343 Coherence 1.27792e-07
# Col 21 Row 34 CumPer 0 Phase -2.56086 Coherence 1.61904e-07
# Col 22 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 22 Row 1 CumPer 0 Phase 109.066 Coherence -4.29418e-12
# Col 22 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 22 Row 3 CumPer 0 Phase -88.7083 Coherence 4.24027e-09
# Col 22 Row 4 CumPer 0 Phase -305.666 Coherence -4.86695e-11
# Col 22 Row 5 CumPer 0 Phase 324.405 Coherence -1.0016e-10
# Col 22 Row 6 CumPer 0 Phase 230.668 Coherence -8.51749e-11
# Col 22 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 22 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 22 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 22 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 22 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 22 Row 12 CumPer 0 Phase -273.608 Coherence -2.39307e-11
# Col 22 Row 13 CumPer 0 Phase 362.371 Coherence -1.29646e-11
# Col 22 Row 14 CumPer 0 Phase -61.7723 Coherence 3.99688e-08
# Col 22 Row 15 CumPer 0 Phase -6.06815 Coherence 3.06693e-07
# Col 22 Row 16 CumPer 0 Phase 2.08665 Coherence 2.4257e-07
# Col 22 Row 17 CumPer 0 Phase 9.93498 Coherence 2.89561e-07
# Col 22 Row 18 CumPer 0 Phase 10.5334 Coherence 4.27566e-07
# Col 22 Row 19 CumPer 0 Phase 5.17437 Coherence 5.36821e-07
# Col 22 Row 20 CumPer 0 Phase 15.5317 Coherence 4.61828e-07
# Col 22 Row 21 CumPer 0 Phase -1.58605 Coherence 3.8476e-07
# Col 22 Row 22 CumPer 0 Phase -22.9567 Coherence 5.90496e-07
# Col 22 Row 23 CumPer 0 Phase -36.5256 Coherence 3.0003e-07
# Col 22 Row 24 CumPer 0 Phase -48.9867 Coherence 2.0577e-07
# Col 22 Row 25 CumPer 0 Phase -23.4485 Coherence 2.43073e-07
# Col 22 Row 26 CumPer 0 Phase -56.1687 Coherence 3.8477e-07
# Col 22 Row 27 CumPer 0 Phase -24.3913 Coherence 1.02395e-06
# Col 22 Row 28 CumPer 0 Phase -63.24 Coherence 4.02149e-07
# Col 22 Row 29 CumPer 0 Phase -42.2632 Coherence 1.72924e-07
# Col 22 Row 30 CumPer 0 Phase -56.9586 Coherence 3.54517e-07
# Col 22 Row 31 CumPer 0 Phase -53.8651 Coherence 3.54205e-07
# Col 22 Row 32 CumPer 0 Phase -42.2132 Coherence 2.20926e-07
# Col 22 Row 33 CumPer 0 Phase -35.1707 Coherence 3.34362e-07
# Col 22 Row 34 CumPer 0 Phase -0.869558 Coherence 3.27559e-07
# Col 23 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 23 Row 1 CumPer 0 Phase -454.239 Coherence -1.76058e-11
# Col 23 Row 2 CumPer 0 Phase 47.0471 Coherence 8.09097e-08
# Col 23 Row 3 CumPer 0 Phase 79.3373 Coherence 7.15292e-08
# Col 23 Row 4 CumPer 0 Phase 246.253 Coherence -2.48744e-11
# Col 23 Row 5 CumPer 0 Phase 272.323 Coherence -1.35544e-10
# Col 23 Row 6 CumPer 0 Phase -303.351 Coherence -6.58394e-11
# Col 23 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 23 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 23 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 23 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 23 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0
# Col 23 Row 12 CumPer 0 Phase -138.099 Coherence -7.20346e-08
# Col 23 Row 13 CumPer 0 Phase 401.393 Coherence -3.34448e-12
# Col 23 Row 14 CumPer 0 Phase 144.839 Coherence -2.01128e-08
# Col 23 Row 15 CumPer 0 Phase -14.4845 Coherence 6.28606e-07
# Col 23 Row 16 CumPer 0 Phase -10.293 Coherence 4.08123e-07
# Col 23 Row 17 CumPer 0 Phase 24.4137 Coherence 2.38142e-07
# Col 23 Row 18 CumPer 0 Phase 4.98333 Coherence 3.65214e-07
# Col 23 Row 19 CumPer 0 Phase 12.1312 Coherence 5.65986e-07
# Col 23 Row 20 CumPer 0 Phase 10.8933 Coherence 6.21612e-07
# Col 23 Row 21 CumPer 0 Phase 25.0896 Coherence 4.34396e-07
# Col 23 Row 22 CumPer 0 Phase -0.148493 Coherence 6.02719e-07
# Col 23 Row 23 CumPer 0 Phase 24.057 Coherence 2.69728e-07
# Col 23 Row 24 CumPer 0 Phase -36.7905 Coherence 2.13902e-07
# ...
# Col 40 Row 13 CumPer 5 Phase 124.583 Coherence 6.24358e-11
# Col 40 Row 14 CumPer 5 Phase 473.363 Coherence -4.42015e-11
# Col 40 Row 15 CumPer 5 Phase -588.944 Coherence -1.63149e-11
# Col 40 Row 16 CumPer 5 Phase 223.194 Coherence -3.14955e-11
# Col 40 Row 17 CumPer 5 Phase 109.118 Coherence -2.39248e-10
# Col 40 Row 18 CumPer 5 Phase 89.2176 Coherence 3.46578e-08
# Col 40 Row 19 CumPer 5 Phase -93.1318 Coherence -1.11964e-10
# Col 40 Row 20 CumPer 5 Phase 39.9991 Coherence 3.61442e-07
# Col 40 Row 21 CumPer 5 Phase 71.9977 Coherence 2.2744e-07
# Col 40 Row 22 CumPer 5 Phase 71.3248 Coherence 2.80015e-07
# Col 40 Row 23 CumPer 5 Phase 188.562 Coherence -1.59042e-11
# Col 40 Row 24 CumPer 5 Phase 120.264 Coherence -6.71836e-12
# Col 40 Row 25 CumPer 5 Phase 83.106 Coherence 2.22314e-07
# Col 40 Row 26 CumPer 5 Phase 126.532 Coherence -6.48176e-07
# Col 40 Row 27 CumPer 5 Phase 101.131 Coherence -1.29941e-07
# Col 40 Row 28 CumPer 5 Phase 53.7294 Coherence 6.56492e-07
# Col 40 Row 29 CumPer 5 Phase 48.1922 Coherence 1.28754e-06
# Col 40 Row 30 CumPer 5 Phase -11.3613 Coherence 1.17244e-06
# Col 40 Row 31 CumPer 5 Phase -26.0773 Coherence 1.40841e-06
# Col 40 Row 32 CumPer 5 Phase 30.3441 Coherence 4.97153e-07
# Col 40 Row 33 CumPer 5 Phase 51.3307 Coherence 3.77312e-07
# Col 40 Row 34 CumPer 5 Phase 42.3028 Coherence 1.06406e-06
# Col 41 Row 0 CumPer 5 Phase -99999.0 Coherence -99999.0
# Col 41 Row 1 CumPer 5 Phase 82.2453 Coherence 5.48068e-11
# Col 41 Row 2 CumPer 5 Phase 218.212 Coherence -7.84518e-12
# Col 41 Row 3 CumPer 5 Phase -210.124 Coherence -7.92142e-13
# Col 41 Row 4 CumPer 5 Phase -47.1455 Coherence 2.25029e-07
# Col 41 Row 5 CumPer 5 Phase -399.006 Coherence -2.37589e-11
# Col 41 Row 6 CumPer 5 Phase -69.7108 Coherence 2.89709e-08
# Col 41 Row 7 CumPer 5 Phase -66.676 Coherence -1.02474e-11
# Col 41 Row 8 CumPer 5 Phase -106.714 Coherence -3.01383e-11
# Col 41 Row 9 CumPer 5 Phase -84.6319 Coherence 4.4839e-08
# Col 41 Row 10 CumPer 5 Phase 70.6408 Coherence 1.14292e-07
# Col 41 Row 11 CumPer 5 Phase -253.965 Coherence -5.7797e-11
# Col 41 Row 12 CumPer 5 Phase 2.17489 Coherence 2.36664e-07
# Col 41 Row 13 CumPer 5 Phase 48.5346 Coherence 2.44176e-07
# Col 41 Row 14 CumPer 5 Phase 278.503 Coherence -3.05943e-11
# Col 41 Row 15 CumPer 5 Phase 114.474 Coherence -1.12637e-10
# Col 41 Row 16 CumPer 5 Phase 288.739 Coherence -9.17081e-11
# Col 41 Row 17 CumPer 5 Phase -82.0536 Coherence -5.30698e-11
# Col 41 Row 18 CumPer 5 Phase 85.4247 Coherence 5.45326e-11
# Col 41 Row 19 CumPer 5 Phase 149.956 Coherence 8.9502e-12
# Col 41 Row 20 CumPer 5 Phase 250.644 Coherence -8.74907e-11
# Col 41 Row 21 CumPer 5 Phase 93.8784 Coherence 5.65666e-10
# Col 41 Row 22 CumPer 5 Phase 76.1488 Coherence 4.43243e-07
# Col 41 Row 23 CumPer 5 Phase 83.8772 Coherence 1.49232e-07
# Col 41 Row 24 CumPer 5 Phase 63.496 Coherence 5.44522e-07
# Col 41 Row 25 CumPer 5 Phase 91.2948 Coherence 1.02707e-08
# Col 41 Row 26 CumPer 5 Phase 77.1956 Coherence 2.86509e-07
# Col 41 Row 27 CumPer 5 Phase 72.4796 Coherence 3.17685e-07
# Col 41 Row 28 CumPer 5 Phase 49.7285 Coherence 7.68247e-07
# Col 41 Row 29 CumPer 5 Phase 18.7264 Coherence 8.4593e-07
# Col 41 Row 30 CumPer 5 Phase -11.623 Coherence 8.63464e-07
# Col 41 Row 31 CumPer 5 Phase 14.6483 Coherence 1.07054e-06
# Col 41 Row 32 CumPer 5 Phase 4.41797 Coherence 2.55161e-06
# Col 41 Row 33 CumPer 5 Phase 4.66479 Coherence 1.19985e-06
# Col 41 Row 34 CumPer 5 Phase 0.0773391 Coherence 2.23379e-06
# Col 42 Row 0 CumPer 5 Phase -99999.0 Coherence -99999.0
# Col 42 Row 1 CumPer 5 Phase 54.5432 Coherence 3.20116e-07
# Col 42 Row 2 CumPer 5 Phase -63.5254 Coherence -6.33207e-11
# Col 42 Row 3 CumPer 5 Phase 132.639 Coherence 1.07466e-13
# Col 42 Row 4 CumPer 5 Phase 196.132 Coherence -2.83534e-13
# Col 42 Row 5 CumPer 5 Phase -312.251 Coherence -3.19876e-12
# Col 42 Row 6 CumPer 5 Phase 82.0064 Coherence 4.97409e-12
# Col 42 Row 7 CumPer 5 Phase 137.878 Coherence -1.25106e-12
# Col 42 Row 8 CumPer 5 Phase 99.9517 Coherence -6.17709e-11
# Col 42 Row 9 CumPer 5 Phase -79.3158 Coherence -1.42472e-11
# Col 42 Row 10 CumPer 5 Phase -84.9446 Coherence 1.52233e-10
# Col 42 Row 11 CumPer 5 Phase 115.335 Coherence -8.17136e-11
# Col 42 Row 12 CumPer 5 Phase -89.5929 Coherence -8.1049e-11
# Col 42 Row 13 CumPer 5 Phase 86.26 Coherence 2.26335e-10
# Col 42 Row 14 CumPer 5 Phase 67.6413 Coherence 4.912e-07
# Col 42 Row 15 CumPer 5 Phase -301.832 Coherence -1.35109e-10
# Col 42 Row 16 CumPer 5 Phase -297.758 Coherence -1.84951e-10
# Col 42 Row 17 CumPer 5 Phase -303.07 Coherence -1.07409e-11
# Col 42 Row 18 CumPer 5 Phase 118.002 Coherence 1.36681e-11
# Col 42 Row 19 CumPer 5 Phase 77.9047 Coherence 1.55786e-07
# Col 42 Row 20 CumPer 5 Phase 94.6092 Coherence 3.88375e-10
# Col 42 Row 21 CumPer 5 Phase 56.3157 Coherence 9.21098e-07
# Col 42 Row 22 CumPer 5 Phase 56.7967 Coherence 5.48777e-07
# Col 42 Row 23 CumPer 5 Phase 54.7948 Coherence 2.53645e-12
# Col 42 Row 24 CumPer 5 Phase 107.241 Coherence -4.62998e-07
# Col 42 Row 25 CumPer 5 Phase 63.0768 Coherence -3.66199e-11
# Col 42 Row 26 CumPer 5 Phase 84.5779 Coherence 1.38416e-07
# Col 42 Row 27 CumPer 5 Phase 74.3526 Coherence 3.86298e-07
# Col 42 Row 28 CumPer 5 Phase 4.21873 Coherence 5.16051e-07
# Col 42 Row 29 CumPer 5 Phase -29.1048 Coherence 5.49281e-07
# Col 42 Row 30 CumPer 5 Phase -21.6716 Coherence 1.27784e-06
# Col 42 Row 31 CumPer 5 Phase 17.2151 Coherence 6.59211e-07
# Col 42 Row 32 CumPer 5 Phase 23.4408 Coherence 2.46329e-06
# Col 42 Row 33 CumPer 5 Phase 92.2611 Coherence 1.19295e-09
# Col 42 Row 34 CumPer 5 Phase -49.7548 Coherence 1.16057e-06
# Col 43 Row 0 CumPer 5 Phase -99999.0 Coherence -99999.0
# Col 43 Row 1 CumPer 5 Phase 37.2705 Coherence 2.3714e-07
# Col 43 Row 2 CumPer 5 Phase 2.67612 Coherence 6.01606e-08
# Col 43 Row 3 CumPer 5 Phase 76.3587 Coherence 1.99063e-11
# Col 43 Row 4 CumPer 5 Phase 64.9029 Coherence 2.19675e-11
# Col 43 Row 5 CumPer 5 Phase 43.0481 Coherence 3.68405e-11
# Col 43 Row 6 CumPer 5 Phase -260.504 Coherence -2.92131e-12
# Col 43 Row 7 CumPer 5 Phase -140.314 Coherence 6.74847e-12
# Col 43 Row 8 CumPer 5 Phase -627.696 Coherence -5.46952e-11
# Col 43 Row 9 CumPer 5 Phase -414.029 Coherence -1.04346e-10
# Col 43 Row 10 CumPer 5 Phase -64.5748 Coherence 7.05453e-11
# Col 43 Row 11 CumPer 5 Phase -58.255 Coherence 1.34584e-07
# Col 43 Row 12 CumPer 5 Phase -66.636 Coherence 1.63938e-10
# Col 43 Row 13 CumPer 5 Phase -113.061 Coherence -1.19586e-10
# Col 43 Row 14 CumPer 5 Phase 43.8993 Coherence 7.17444e-07
# Col 43 Row 15 CumPer 5 Phase 67.237 Coherence 3.33141e-07
# Col 43 Row 16 CumPer 5 Phase -57.6212 Coherence 2.6638e-07
# Col 43 Row 17 CumPer 5 Phase 73.0262 Coherence 3.07532e-11
# Col 43 Row 18 CumPer 5 Phase 73.5464 Coherence 2.13837e-07
# Col 43 Row 19 CumPer 5 Phase 99.4608 Coherence 1.24426e-10
# Col 43 Row 20 CumPer 5 Phase 115.024 Coherence 5.38695e-11
# Col 43 Row 21 CumPer 5 Phase -134.361 Coherence -1.85539e-10
# Col 43 Row 22 CumPer 5 Phase 116.592 Coherence 5.59927e-11
# Col 43 Row 23 CumPer 5 Phase 46.4051 Coherence 3.3502e-11
# Col 43 Row 24 CumPer 5 Phase 68.9659 Coherence -1.5882e-10
# Col 43 Row 25 CumPer 5 Phase 98.915 Coherence 2.2367e-10
# Col 43 Row 26 CumPer 5 Phase 85.9151 Coherence 8.6229e-08
# Col 43 Row 27 CumPer 5 Phase 83.2911 Coherence 2.82563e-07
# Col 43 Row 28 CumPer 5 Phase 20.9453 Coherence 1.02736e-06
# Col 43 Row 29 CumPer 5 Phase -23.0211 Coherence 2.30209e-06
# Col 43 Row 30 CumPer 5 Phase -8.64843 Coherence 1.69778e-06
# Col 43 Row 31 CumPer 5 Phase -81.9044 Coherence 6.74384e-08
# Col 43 Row 32 CumPer 5 Phase -30.4075 Coherence 2.13681e-06
# Col 43 Row 33 CumPer 5 Phase -33.9616 Coherence 2.28754e-06
# Col 43 Row 34 CumPer 5 Phase 14.1709 Coherence 1.69453e-06
# Col 44 Row 0 CumPer 5 Phase -99999.0 Coherence -99999.0
# Col 44 Row 1 CumPer 5 Phase 278.857 Coherence -3.51023e-11
# Col 44 Row 2 CumPer 5 Phase -86.4133 Coherence 3.51148e-08
# Col 44 Row 3 CumPer 5 Phase 415.431 Coherence -2.78997e-12
# Col 44 Row 4 CumPer 5 Phase -49.9028 Coherence 1.63575e-11
# Col 44 Row 5 CumPer 5 Phase -64.8634 Coherence 1.72996e-07
# Col 44 Row 6 CumPer 5 Phase -63.9954 Coherence 4.73251e-12
# Col 44 Row 7 CumPer 5 Phase -49.6902 Coherence 2.30086e-12
# Col 44 Row 8 CumPer 5 Phase -46.0608 Coherence 1.25091e-11
# Col 44 Row 9 CumPer 5 Phase -397.225 Coherence -8.79222e-11
# Col 44 Row 10 CumPer 5 Phase -41.739 Coherence 1.57206e-07
# Col 44 Row 11 CumPer 5 Phase -80.0945 Coherence 4.57261e-08
# Col 44 Row 12 CumPer 5 Phase -121.594 Coherence -8.88535e-11
# Col 44 Row 13 CumPer 5 Phase -57.9381 Coherence -2.38575e-11
# Col 44 Row 14 CumPer 5 Phase -113.335 Coherence -1.28683e-10
# Col 44 Row 15 CumPer 5 Phase -75.9682 Coherence 4.65501e-08
# Col 44 Row 16 CumPer 5 Phase 86.9924 Coherence 3.60431e-08
# Col 44 Row 17 CumPer 5 Phase 177.034 Coherence -3.93543e-07
# Col 44 Row 18 CumPer 5 Phase 55.6971 Coherence 7.02557e-07
# Col 44 Row 19 CumPer 5 Phase 93.0611 Coherence 4.51559e-10
# Col 44 Row 20 CumPer 5 Phase 86.4391 Coherence 1.63534e-07
# Col 44 Row 21 CumPer 5 Phase -250.875 Coherence -9.25434e-11
# Col 44 Row 22 CumPer 5 Phase 84.7669 Coherence 1.34258e-07
# Col 44 Row 23 CumPer 5 Phase 77.4124 Coherence 5.33415e-07
# Col 44 Row 24 CumPer 5 Phase 97.9235 Coherence 2.89779e-10
# Col 44 Row 25 CumPer 5 Phase 80.2915 Coherence 2.40438e-07
# Col 44 Row 26 CumPer 5 Phase 81.8766 Coherence 3.40407e-07
# Col 44 Row 27 CumPer 5 Phase 43.5772 Coherence 1.77511e-06
# Col 44 Row 28 CumPer 5 Phase 2.14093 Coherence 1.82728e-06
# Col 44 Row 29 CumPer 5 Phase -30.1798 Coherence 1.1046e-06
# Col 44 Row 30 CumPer 5 Phase -5.47371 Coherence 2.28246e-06
# Col 44 Row 31 CumPer 5 Phase 1.62164 Coherence 1.98357e-06
# Col 44 Row 32 CumPer 5 Phase 25.9064 Coherence 1.7669e-06
# Col 44 Row 33 CumPer 5 Phase -23.5104 Coherence 2.72857e-06
# Col 44 Row 34 CumPer 5 Phase 45.258 Coherence 9.11378e-07
# Col 45 Row 0 CumPer 5 Phase -99999.0 Coherence -99999.0
# Col 45 Row 1 CumPer 5 Phase -379.902 Coherence -1.882e-11
# Col 45 Row 2 CumPer 5 Phase 154.385 Coherence -2.90882e-07
# Col 45 Row 3 CumPer 5 Phase 303.898 Coherence -1.42006e-11
# Col 45 Row 4 CumPer 5 Phase 84.841 Coherence 4.0262e-11
# Col 45 Row 5 CumPer 5 Phase -148.149 Coherence -1.69106e-11
# Col 45 Row 6 CumPer 5 Phase 113.3 Coherence -5.41303e-11
# Col 45 Row 7 CumPer 5 Phase -108.328 Coherence -3.99807e-11
# Col 45 Row 8 CumPer 5 Phase -428.156 Coherence -9.38085e-11
# Col 45 Row 9 CumPer 5 Phase -67.8584 Coherence 6.26538e-11
# Col 45 Row 10 CumPer 5 Phase 417.686 Coherence -1.55936e-10
# Col 45 Row 11 CumPer 5 Phase -214.88 Coherence -3.814e-11
# Col 45 Row 12 CumPer 5 Phase -10.7123 Coherence 3.3028e-07
# Col 45 Row 13 CumPer 5 Phase 160.683 Coherence -2.24449e-07
# Col 45 Row 14 CumPer 5 Phase 70.4487 Coherence 5.30309e-08
# Col 45 Row 15 CumPer 5 Phase 66.3575 Coherence 7.00523e-08
# Col 45 Row 16 CumPer 5 Phase 331.022 Coherence -6.33987e-11
# Col 45 Row 17 CumPer 5 Phase 235.329 Coherence 1.22815e-11
# Col 45 Row 18 CumPer 5 Phase 77.0432 Coherence 2.72485e-07
# Col 45 Row 19 CumPer 5 Phase 59.3738 Coherence 6.95823e-07
# Col 45 Row 20 CumPer 5 Phase 97.6788 Coherence 1.69359e-10
# Col 45 Row 21 CumPer 5 Phase 231.323 Coherence -1.35721e-11
# Col 45 Row 22 CumPer 5 Phase 90.2865 Coherence 3.7935e-08
# Col 45 Row 23 CumPer 5 Phase 69.4281 Coherence 8.01634e-07
# Col 45 Row 24 CumPer 5 Phase 52.8234 Coherence 9.3104e-07
# Col 45 Row 25 CumPer 5 Phase 56.6607 Coherence 8.88356e-07
# Col 45 Row 26 CumPer 5 Phase 91.6437 Coherence 4.62334e-09
# Col 45 Row 27 CumPer 5 Phase -19.8572 Coherence 2.14801e-06
# Col 45 Row 28 CumPer 5 Phase 9.36795 Coherence 2.25576e-06
# Col 45 Row 29 CumPer 5 Phase -23.506 Coherence 1.99015e-06
# Col 45 Row 30 CumPer 5 Phase 34.4847 Coherence 1.32893e-06
# Col 45 Row 31 CumPer 5 Phase -64.6158 Coherence 6.66512e-08
# Col 45 Row 32 CumPer 5 Phase -15.3141 Coherence 2.73161e-06
# Col 45 Row 33 CumPer 5 Phase 15.8845 Coherence 1.27609e-06
# Col 45 Row 34 CumPer 5 Phase 49.195 Coherence 1.60725e-06
# Col 46 Row 0 CumPer 5 Phase -99999.0 Coherence -99999.0
# Col 46 Row 1 CumPer 5 Phase 89.4303 Coherence 7.17511e-10
# Col 46 Row 2 CumPer 5 Phase -1.4997 Coherence 2.0546e-12
# Col 46 Row 3 CumPer 5 Phase 90.9063 Coherence 4.22239e-10
# Col 46 Row 4 CumPer 5 Phase 113.97 Coherence -2.35455e-08
# Col 46 Row 5 CumPer 5 Phase -142.941 Coherence -1.13631e-07
# Col 46 Row 6 CumPer 5 Phase -169.24 Coherence -4.34424e-07
# Col 46 Row 7 CumPer 5 Phase 502.116 Coherence -1.04534e-10
# Col 46 Row 8 CumPer 5 Phase -87.4474 Coherence 7.20931e-08
# Col 46 Row 9 CumPer 5 Phase -87.5236 Coherence 5.69988e-08
# Col 46 Row 10 CumPer 5 Phase -81.7255 Coherence -2.8002e-11
# Col 46 Row 11 CumPer 5 Phase -24.6141 Coherence 2.32239e-07
# Col 46 Row 12 CumPer 5 Phase 6.35469 Coherence 1.86807e-07
# Col 46 Row 13 CumPer 5 Phase 32.0442 Coherence 1.91016e-07
# Col 46 Row 14 CumPer 5 Phase -61.2553 Coherence 1.43653e-07
# Col 46 Row 15 CumPer 5 Phase 47.842 Coherence 8.64676e-08
# Col 46 Row 16 CumPer 5 Phase 85.8694 Coherence 3.66493e-10
# Col 46 Row 17 CumPer 5 Phase 75.9664 Coherence 1.26784e-07
# Col 46 Row 18 CumPer 5 Phase 89.3495 Coherence 3.38944e-08
# Col 46 Row 19 CumPer 5 Phase 65.8517 Coherence 8.6539e-07
# Col 46 Row 20 CumPer 5 Phase 94.1256 Coherence 5.04042e-10
# Col 46 Row 21 CumPer 5 Phase 91.5295 Coherence 3.82553e-09
# Col 46 Row 22 CumPer 5 Phase 84.1798 Coherence 2.21241e-07
# Col 46 Row 23 CumPer 5 Phase 72.3071 Coherence 5.85772e-07
# Col 46 Row 24 CumPer 5 Phase 78.6288 Coherence 2.21643e-07
# Col 46 Row 25 CumPer 5 Phase 75.9619 Coherence 5.08046e-07
# Col 46 Row 26 CumPer 5 Phase 34.0738 Coherence 6.40603e-07
# Col 46 Row 27 CumPer 5 Phase 4.33339 Coherence 2.37684e-06
# Col 46 Row 28 CumPer 5 Phase 19.3547 Coherence 3.62805e-06
# Col 46 Row 29 CumPer 5 Phase -8.42147 Coherence 2.7845e-06
# Col 46 Row 30 CumPer 5 Phase 10.6387 Coherence 2.92726e-06
# Col 46 Row 31 CumPer 5 Phase -271.27 Coherence -2.45656e-10
# Col 46 Row 32 CumPer 5 Phase -22.2129 Coherence 2.23976e-06
# Col 46 Row 33 CumPer 5 Phase 81.5475 Coherence 2.8257e-07
# Col 46 Row 34 CumPer 5 Phase 34.157 Coherence 2.17315e-06
# Col 47 Row 0 CumPer 5 Phase -99999.0 Coherence -99999.0
# Col 47 Row 1 CumPer 5 Phase 70.5325 Coherence 1.33684e-07
# Col 47 Row 2 CumPer 5 Phase -207.025 Coherence -4.07691e-11
# Col 47 Row 3 CumPer 5 Phase 22.7281 Coherence 6.2173e-12
# Col 47 Row 4 CumPer 5 Phase 61.812 Coherence 2.62117e-08
# Col 47 Row 5 CumPer 5 Phase -118.173 Coherence -3.14409e-07
# Col 47 Row 6 CumPer 5 Phase -159.283 Coherence -1.00056e-06
# Col 47 Row 7 CumPer 5 Phase -73.558 Coherence -4.17546e-11
# Col 47 Row 8 CumPer 5 Phase -60.3747 Coherence 4.68243e-11
# Col 47 Row 9 CumPer 5 Phase -68.8838 Coherence -2.29197e-12
# Col 47 Row 10 CumPer 5 Phase -116.475 Coherence -1.49987e-11
# Col 47 Row 11 CumPer 5 Phase 65.9347 Coherence 7.42397e-08
# Col 47 Row 12 CumPer 5 Phase -21.7535 Coherence 2.17625e-07
# Col 47 Row 13 CumPer 5 Phase -41.9364 Coherence 5.92216e-08
# Col 47 Row 14 CumPer 5 Phase 7.83101 Coherence 4.82088e-07
# Col 47 Row 15 CumPer 5 Phase 51.2698 Coherence 2.92061e-07
# Col 47 Row 16 CumPer 5 Phase 85.038 Coherence 5.07746e-10
# Col 47 Row 17 CumPer 5 Phase 85.6479 Coherence 1.18773e-07
# Col 47 Row 18 CumPer 5 Phase -2.19971 Coherence 1.57719e-06
# Col 47 Row 19 CumPer 5 Phase 6.09056 Coherence 1.69292e-06
# Col 47 Row 20 CumPer 5 Phase 28.0627 Coherence 1.00024e-06
# Col 47 Row 21 CumPer 5 Phase 52.8581 Coherence 4.6009e-07
# Col 47 Row 22 CumPer 5 Phase 80.9795 Coherence 2.05258e-07
# Col 47 Row 23 CumPer 5 Phase 54.2004 Coherence 1.27019e-06
# Col 47 Row 24 CumPer 5 Phase 14.3275 Coherence 1.51076e-06
# Col 47 Row 25 CumPer 5 Phase 26.9186 Coherence 1.94663e-06
# Col 47 Row 26 CumPer 5 Phase 6.7827 Coherence 1.51182e-06
# Col 47 Row 27 CumPer 5 Phase 15.7446 Coherence 2.08198e-06
# Col 47 Row 28 CumPer 5 Phase -30.75 Coherence 1.99274e-06
# Col 47 Row 29 CumPer 5 Phase 58.3031 Coherence 9.32823e-07
# Col 47 Row 30 CumPer 5 Phase -20.4888 Coherence 2.86264e-06
# Col 47 Row 31 CumPer 5 Phase -23.0911 Coherence 1.68084e-06
# Col 47 Row 32 CumPer 5 Phase -26.0368 Coherence 1.6081e-06
# Col 47 Row 33 CumPer 5 Phase 25.7823 Coherence 2.70539e-06
# Col 47 Row 34 CumPer 5 Phase 43.5434 Coherence 1.46849e-06 D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\PLOT_MAPS_2009\matlab2//phase_150.tif
# D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\PLOT_MAPS_2009\matlab2//coherence_150.tif

# %%
kl[0]>0
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-190-648a2cf04ff7> in <module>()
# ----> 1 kl[0][0]>0
#
# IndexError: list index out of range

# %%
if len(kl[1]):
    k[1][0][1]

# %%
if len(kl[1])>0:
    print 'ok'
else:
    print 'ki'
# Out:
# ki

# %%
kl
# Out:
# [[[0.0027394520547945203, array([  1.24365122e-08])]], []]

# %%
hg[0][np.where(hg[1]==k[0][0][0])]
# Out:
# array([[  7.98495495e-08 +6.97633772e-09j]])

# %%
gh = psd(np.resize(s1, (s1.size*100) ), NFFT=100*len(y), Fs=1)
gh = psd(np.resize(s2, (s2.size*100) ), NFFT=100*len(y), Fs=1)
hg = csd(np.resize(s1, (s1.size*100) ),np.resize(s2, (s2.size*100) ), NFFT=100*len(np.resize(s2, (s2.size*100) )), Fs=1)
xlim([0,0.013])
# Out:
# (0, 0.013)

# %%
#hg = csd(np.resize(s1, (s1.size*100) ),np.resize(s2, (s2.size*100) ), NFFT=100*len(np.resize(s2, (s2.size*100) )), Fs=1)
hg = mlab.csd(np.resize(s1, (s1.size*100) ),np.resize(s2, (s2.size*100) ), NFFT=100*len(np.resize(s2, (s2.size*100) )), Fs=1)
k = peakdetect(hg[0].real[0:20000], hg[1][0:20000])
jh[np.where(hg[1]==k[0][0][0])]/(2*np.pi*k[0][0][0])
# Out:
# array([ 37.94573887])

# %%
jh = angle(hg[0])
plot(hg[1], jh)

xlim([0,0.025])
# Out:
# (0, 0.025)

# %%
import matplotlib.mlab as mlab

# %%
mth = [0.5, 1, 2, 3, 4, 5]
prd = [15, 30, 60, 90, 120, 150]
pth1 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2_2009\XX_Day_Period\XX_DaySums_StdNormAnomaly'# removed 'NormTypeII'
pth2 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\NDVI_2009\DaySums_StdNormAnomalyRes'# removed 'NormTypeII'

#pixelcolumn = 23 # extract from rasterXSize (0:62) horizontal latitude - whatever
#pixelrow = 21 # extract from rasterYSize (0:36) vertical longitude 
#folderp1 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\PLOT_CHARTS_2009\COHERENCE2\p5//'
#folderp2 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\PLOT_CHARTS_2009\COHERENCE2\p4//'

ph = pth2+'//TRMM_CQ_2009001.tif'
ds = gdal.Open(ph)
base = ds.ReadAsArray()

for i in range(0,6):
    phase_array = np.zeros_like(base)
    coher_array = np.zeros_like(base)
    rmse_array = np.zeros_like(base)
    
    for j in range(0, 48): # pixelcolumn
        for k in range(0,35): # pixelrow
        
            # Set path for cumulative period of precipitation
            # And corresponding period time
            cumper = mth[i]
            period = prd[i]
            paths1 = pth1.replace('XX', str(period))
            paths2 = pth2
            
    
            # Set pixelvalues
            # TODO: Implementation to read row by row or all-in-one
            pixelcolumn = j
            pixelrow = k
            
            # Get values for precipitation based on cumper 
            # And only update values for NDVI with a new pixel
            s_org2 = getvalues(paths2, pixelcolumn, pixelrow, wildcard='CQ')            
            if s_org2.mean()<>-99999.0:
                s_org1 = getvalues(paths1, pixelcolumn, pixelrow, wildcard='TRMM')                
            
                # Create dataframe from the two series and apply an outer join            
                df1 = pd.DataFrame(s_org1, columns=['prcp'])
                df2 = pd.DataFrame(s_org2, columns=['ndvi'])            
                df = pd.concat([df1, df2], join='outer', axis=1)
                
                # Before splitting the signals, first drop eventual NaN values
                df = df.dropna()            
                s1 = df['prcp']
                s2 = df['ndvi']
                x = s1.values
                y = s2.values
                # Extent annual signal to 20 years
                
                x = np.resize(x, (x.size*20) )
                y = np.resize(y, (y.size*20) )
                
                # Normalise annual signal
                x = (x - x.mean())/x.std()
                y = (y - y.mean())/y.std()  
                #print len(x)
                #print len(y)
                ml.putArray("x",x)
                ml.putArray("y",y)

                ml.eval("[s,c,ph,ci,phi] = cmtm(x,y,1,4,1,10,0);")
                s = ml.getArray("s")                
                c = ml.getArray("c")                
                ph = ml.getArray("ph")                
                ci = ml.getArray("ci")                
                phi = ml.getArray("phi")
                
                cl = c[(0.0024 < s) & (s <0.0031)].mean()
                sl = s[(0.0024 < s) & (s <0.0031)].mean()
                phl = ph[(0.0024 < s) & (s <0.0031)].mean() # frequency
                phil = phi[(0.0024 < s) & (s <0.0031)].mean() # frequency
                phl = phl/(2*np.pi*sl) # time domain
                phil = phil/(2*np.pi*sl) # time domain
  
                #print (rmse, coher, phase) 
                phase_array[k][j] = phl
                coher_array[k][j] = cl
                rmse_array[k][j] = phil
            else:
                phase_array[k][j] = -99999.0
                coher_array[k][j] = -99999.0
                rmse_array[k][j] = -99999.0
            print 'Col',j,'Row', k, 'CumPer', i, 'Phase',phase_array[k][j], 'Coherence', coher_array[k][j], 'RMSE', rmse_array[k][j]
                
            
    folder = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\PLOT_MAPS_2009\matlab//'
    path_phase = folder+'phase_'+str(prd[i])+'.tif'
    path_coher = folder+'coherence_'+str(prd[i])+'.tif'
    path_rmse = folder+'rmse_'+str(prd[i])+'.tif'

    saveRaster(path_phase, phase_array, ds, datatype=6, nan=-99999.0)
    saveRaster(path_coher, coher_array, ds, datatype=6, nan=-99999.0)
    saveRaster(path_rmse, rmse_array, ds, datatype=6, nan=-99999.0)
    
    print path_phase
    print path_coher
    print path_rmse
# Out:
# Col 0 Row 0 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 1 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 2 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 3 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 4 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 5 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 6 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 7 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 8 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 9 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 10 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 11 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 12 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 13 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 14 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 15 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col
#  0 Row 16 CumPer 0 Phase -99999.0 Coherence -99999.0 RMSE -99999.0
# Col

# %%
f, fxx, fyy, fxy = tsa.spectral.get_spectra_bi(x,y, method=dict(this_method='multi_taper_csd', Fs=1./0.4, BW=0.00122135, 
                                                                adaptive=True, low_bias=True ))
plot(f, fxx)
plot(f, fyy)
plot(f, fxy)
xlim([0,0.012])
xticks([0.002,0.0022,0.0024,0.0026,0.0028,0.003,0.0032,0.0034,0.0036,0.0038,0.004])

# %%
f, ccy = tsa.cohere.coherency(q, csd_method=dict(this_method='multi_taper_csd', Fs=1./0.4, BW=0.00122135, 
                                                                adaptive=True, low_bias=True ))
plot(f,ccy[1][0])
xlim([0,0.012])

# %%
f, cce = tsa.cohere.coherence(q, csd_method=dict(this_method='multi_taper_csd', Fs=1./0.4, BW=0.00122135, 
                                                                adaptive=True, low_bias=True ))
plot(f,cce[0][1])
xlim([0,0.012])
ylim([-0.1,1.1])

# %%
f, p = tsa.cohere.coherency_phase_spectrum(q, csd_method=dict(this_method='multi_taper_csd', Fs=1./0.4, BW=0.00122135, 
                                                                adaptive=True, low_bias=True ))
plot(f,p[0][1])
xlim([0,0.012])

# %%
c = cce[0][1][(0.0022 < f) & (f <0.0032)]
y = p[0][1][(0.0022 < f) & (f <0.0032)]
xi = f[(0.0022 < f) & (f <0.0032)]
plot(xi,y)

# %%
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(xi,y)

print 'r value', r_value
print  'p_value', p_value
print 'standard deviation', std_err

line = slope*xi+intercept
plot(xi,line,'r-',xi,y,'o')
show()

# %%
mse = ((y - line)**2).mean(axis=None)
rmse = math.sqrt(mse)
coher = c.mean()
phase = y.mean()
print (rmse, coher, phase)

# %%
np.arctan2(
