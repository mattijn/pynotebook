# %%
shp = 'H:\Documents\Klusjes\RiverbasinBoundaries\Raw Data\TM_WORLD_BORDERS-0.3//provinces.shp'

# %%
import matplotlib.pyplot as plt

import cartopy.crs as ccrs
import cartopy.feature as cfeature

import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.io.shapereader import Reader

ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([73.43693268011174, 135.06693268011173, 53.57324111988825, 18.203241119888254])

shape_feature = ShapelyFeature(Reader(shp).geometries(), ccrs.PlateCarree(), facecolor='none')
ax.add_feature(cfeature.LAND, facecolor='0.9')
#ax.add_feature(cfeature.BORDERS, linewidth = '0.3')
ax.add_feature(shape_feature, linewidth='0.5', alpha='0.8')

ax.add_feature(cfeature.OCEAN, facecolor='aqua', alpha='0.1')


ax.add_feature(cfeature.COASTLINE)
#ax.add_feature(states_provinces, edgecolor='gray')
#ax.coastlines(resolution='50m', linewidth='0.5')

plt.show()
