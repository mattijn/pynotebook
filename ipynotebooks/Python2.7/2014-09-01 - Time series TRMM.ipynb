# %%
# %matplotlib inline
from __future__ import division
from osgeo import gdal
import numpy as np
import scipy.signal
import os
import matplotlib.pyplot as plt
import nitime.algorithms as tsa

# %% [markdown]
# Extract timeseries from satellite imagery

# %%
import os
from osgeo import gdal
import scipy.signal
def listall(RootFolder, wildcard=''):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if wildcard in name
                     if name.endswith('.tif')]
    return lists

# %% [markdown]
# # xx-day sum

# %%
rowx = 12
coly = 29

xBlockSize = 9
yBlockSize = 9

folder_trmm = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\150_Day_Period\150_DaySums'
path_base = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2_2009\10_Day_Period\10_DaySums_StdNormAnomaly//TRMM_IM_2009001.tif'

#Read files and check length
files_trmm = listall(folder_trmm)
files_trmm = files_trmm[2192:2557]#60-day sum [2192:2557]#30-day sum #[2898:3263]#[2903:3268]#20-day sum ##[2192:2557]# 15-day sum ##[2913:3278] # 10-day sum
print len(files_trmm)
print files_trmm[0]
print files_trmm[-1]

# %%
#files_ndvi = listall(folder_ndvi)

#if len(files_ndvi) <> len(files_trmm):
#    print 'Input length time series not equal: x ', len(files_ndvi), 'y ', len(files_trmm)
#    sys.exit()
#else:
#    print 'Input length time series equal: series1', len(files_ndvi), 'series2', len(files_trmm)
    
# loop through the rows
for i in range(rowx-1, rowx, yBlockSize): #(0, rows, yBlockSize)
    if i + yBlockSize < rows:
        numRows = yBlockSize
    else:
        numRows = rows - i
    
    # loop through the columns
    for j in range(coly-1, coly, xBlockSize):# (0, cols, xBlockSize)
        if j + xBlockSize < cols:
            numCols = xBlockSize
        else:
            numCols = cols - j
        
        print j, i, numCols, numRows
        # set base array to fill 
        ap_trmm = np.zeros(shape=(len(files_trmm),numRows,numCols), dtype=np.float32)
        #ap_ndvi = np.zeros(shape=(len(files_ndvi),numRows,numCols), dtype=np.float32)
        
        # select blocks from trmm and ndvi files
        for m in range(len(files_trmm)):
            raster = gdal.Open(files_trmm[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_trmm[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)
                
            #raster = gdal.Open(files_ndvi[m], gdal.GA_ReadOnly)
            #band = raster.GetRasterBand(1)            
            #ap_ndvi[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

        # reshape from 3D to 2D
        ap_trmm = ap_trmm.reshape((int(ap_trmm.shape[0]),int(ap_trmm.shape[1]*ap_trmm.shape[2]))).T
        #ap_ndvi = ap_ndvi.reshape((int(ap_ndvi.shape[0]),int(ap_ndvi.shape[1]*ap_ndvi.shape[2]))).T

b = np.ascontiguousarray(ap_trmm).view(np.dtype((np.void, ap_trmm.dtype.itemsize * ap_trmm.shape[1])))
_, idx = np.unique(b, return_index=True)

unique_a = ap_trmm[idx]
#unique_b = ap_ndvi[idx]

plt.figure(figsize=(7,5))
for i in unique_a:
    p1, = plt.plot(i, color='c', alpha=0.2)
#for j in unique_b:
#    p2, = plt.plot(j, color='m', alpha=0.2)

p3, = plt.plot(unique_a.mean(axis=0), 'k-', lw=1.5)
#p4, = plt.plot(unique_b.mean(axis=0), 'k--', lw=1.5)


plt.grid(axis='both')
plt.ylim(0,390)
plt.xlim(0,364)
plt.xlabel('day of year')
plt.ylabel('precipitation (mm)')
plt.title('150-day sum precipitation')
leg = plt.legend([p1,p3],['precipitation','precipitation mean'],ncol=1, loc=2)
leg.get_frame().set_linewidth(0.5)
leg.get_frame().set_edgecolor('lightgray')
plt.tight_layout()        
plt.savefig(r'C:\Users\lenovo\Documents\HOME\Figures AJ\precipitation//150daysum_precip.png', dpi=400)

# %% [markdown]
# # xx-day mean

# %%
def listall(RootFolder, wildcard=''):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if wildcard in name
                     if name.endswith('.tif')]
    return lists

rowx = 12
coly = 29

folder_trmm = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\10_Day_Period\10_DaySums_AnnualMean'
#folder_ndvi = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\NDVI_2009\DaySums_StdNormAnomaly'
path_base = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2_2009\10_Day_Period\10_DaySums_StdNormAnomaly//TRMM_IM_2009001.tif'

# register all of the GDAL drivers
gdal.AllRegister()

# open the image
ds = gdal.Open(path_base, gdal.GA_ReadOnly)
if ds is None:
    print 'Could not open base file'
    sys.exit(1)

# get image size
rows = ds.RasterYSize
cols = ds.RasterXSize
bands = ds.RasterCount

# get the band and block sizes
band = ds.GetRasterBand(1)
base = band.ReadAsArray()
nan = band.GetNoDataValue()

#blockSizes = utils.GetBlockSize(band)
xBlockSize = 9
yBlockSize = 9

files_trmm = listall(folder_trmm)
#files_trmm = files_trmm[2913:3278] ## xx-day sum
#files_trmm = files_trmm[2922:3287] ## Folder RAW
print len(files_trmm)
print files_trmm[0]
print files_trmm[-1]

# %%
#files_ndvi = listall(folder_ndvi)

#if len(files_ndvi) <> len(files_trmm):
#    print 'Input length time series not equal: x ', len(files_ndvi), 'y ', len(files_trmm)
#    sys.exit()
#else:
#    print 'Input length time series equal: series1', len(files_ndvi), 'series2', len(files_trmm)
    
# loop through the rows
for i in range(rowx-1, rowx, yBlockSize): #(0, rows, yBlockSize)
    if i + yBlockSize < rows:
        numRows = yBlockSize
    else:
        numRows = rows - i
    
    # loop through the columns
    for j in range(coly-1, coly, xBlockSize):# (0, cols, xBlockSize)
        if j + xBlockSize < cols:
            numCols = xBlockSize
        else:
            numCols = cols - j
        
        print j, i, numCols, numRows
        # set base array to fill 
        ap_trmm = np.zeros(shape=(len(files_trmm),numRows,numCols), dtype=np.float32)
        #ap_ndvi = np.zeros(shape=(len(files_ndvi),numRows,numCols), dtype=np.float32)
        
        # select blocks from trmm and ndvi files
        for m in range(len(files_trmm)):
            raster = gdal.Open(files_trmm[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_trmm[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)
                
            #raster = gdal.Open(files_ndvi[m], gdal.GA_ReadOnly)
            #band = raster.GetRasterBand(1)            
            #ap_ndvi[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

        # reshape from 3D to 2D
        ap_trmm = ap_trmm.reshape((int(ap_trmm.shape[0]),int(ap_trmm.shape[1]*ap_trmm.shape[2]))).T
        #ap_ndvi = ap_ndvi.reshape((int(ap_ndvi.shape[0]),int(ap_ndvi.shape[1]*ap_ndvi.shape[2]))).T

b = np.ascontiguousarray(ap_trmm).view(np.dtype((np.void, ap_trmm.dtype.itemsize * ap_trmm.shape[1])))
_, idx = np.unique(b, return_index=True)

unique_a = ap_trmm[idx]
#unique_b = ap_ndvi[idx]

plt.figure(figsize=(7,5))
for i in unique_a:
    p1, = plt.plot(i, color='c', alpha=0.2)
#for j in unique_b:
#    p2, = plt.plot(j, color='m', alpha=0.2)

p3, = plt.plot(unique_a.mean(axis=0), 'k-', lw=1.5)
#p4, = plt.plot(unique_b.mean(axis=0), 'k--', lw=1.5)


plt.grid(axis='both')
plt.ylim(0,120)
plt.xlim(0,364)
plt.xlabel('day of year')
plt.ylabel('precipitation (mm)')
plt.title('10-day sum precipitation long term mean')
leg = plt.legend([p1,p3],['precipitation','precipitation mean'],ncol=1, loc=2)
leg.get_frame().set_linewidth(0.5)
leg.get_frame().set_edgecolor('lightgray')
plt.tight_layout()        
plt.savefig(r'C:\Users\lenovo\Documents\HOME\Figures AJ\precipitation//10daysum_mean.png', dpi=400)

# %% [markdown]
# # xx-day abs anomaly

# %%
def listall(RootFolder, wildcard=''):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if wildcard in name
                     if name.endswith('.tif')]
    return lists

rowx = 12
coly = 29

xBlockSize = 9
yBlockSize = 9

folder_trmm = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\10_Day_Period\10_DaySums_Anomaly'
#path_base = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2_2009\10_Day_Period\10_DaySums_StdNormAnomaly//TRMM_IM_2009001.tif'

#Read files and check length
files_trmm = listall(folder_trmm)
#[2192:2557]#30-day sum 
#[2898:3263]#25-day sum
#[2903:3268]#20-day sum 
#[2192:2557]#15-day sum 
#[2913:3278]# 10-day sum
files_trmm = files_trmm[2913:3278] ## xx-day sum
print len(files_trmm)
print files_trmm[0]
print files_trmm[-1]
# Out:
# 365
# D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\10_Day_Period\10_DaySums_Anomaly\TRMM_IM_2009001.tif
# D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\10_Day_Period\10_DaySums_Anomaly\TRMM_IM_2009365.tif

# %%
#files_ndvi = listall(folder_ndvi)

#if len(files_ndvi) <> len(files_trmm):
#    print 'Input length time series not equal: x ', len(files_ndvi), 'y ', len(files_trmm)
#    sys.exit()
#else:
#    print 'Input length time series equal: series1', len(files_ndvi), 'series2', len(files_trmm)
    
# loop through the rows
for i in range(rowx-1, rowx, yBlockSize): #(0, rows, yBlockSize)
    if i + yBlockSize < rows:
        numRows = yBlockSize
    else:
        numRows = rows - i
    
    # loop through the columns
    for j in range(coly-1, coly, xBlockSize):# (0, cols, xBlockSize)
        if j + xBlockSize < cols:
            numCols = xBlockSize
        else:
            numCols = cols - j
        
        print j, i, numCols, numRows
        # set base array to fill 
        ap_trmm = np.zeros(shape=(len(files_trmm),numRows,numCols), dtype=np.float32)
        #ap_ndvi = np.zeros(shape=(len(files_ndvi),numRows,numCols), dtype=np.float32)
        
        # select blocks from trmm and ndvi files
        for m in range(len(files_trmm)):
            raster = gdal.Open(files_trmm[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_trmm[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)
                
            #raster = gdal.Open(files_ndvi[m], gdal.GA_ReadOnly)
            #band = raster.GetRasterBand(1)            
            #ap_ndvi[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

        # reshape from 3D to 2D
        ap_trmm = ap_trmm.reshape((int(ap_trmm.shape[0]),int(ap_trmm.shape[1]*ap_trmm.shape[2]))).T
        #ap_ndvi = ap_ndvi.reshape((int(ap_ndvi.shape[0]),int(ap_ndvi.shape[1]*ap_ndvi.shape[2]))).T

b = np.ascontiguousarray(ap_trmm).view(np.dtype((np.void, ap_trmm.dtype.itemsize * ap_trmm.shape[1])))
_, idx = np.unique(b, return_index=True)

unique_a = ap_trmm[idx]
#unique_b = ap_ndvi[idx]

plt.figure(figsize=(7,5))
for i in unique_a:
    p1, = plt.plot(i, color='c', alpha=0.2)
#for j in unique_b:
#    p2, = plt.plot(j, color='m', alpha=0.2)

p3, = plt.plot(unique_a.mean(axis=0), 'k-', lw=1.5)
#p4, = plt.plot(unique_b.mean(axis=0), 'k--', lw=1.5)


plt.grid(axis='both')
plt.ylim(-120,80)
plt.xlim(0,364)
plt.xlabel('day of year')
plt.ylabel('precipitation (mm)')
plt.title('10-day sum absolute anomaly')
leg = plt.legend([p1,p3],['precipitation anomaly','precipitation anomaly mean'],ncol=1, loc=3)
leg.get_frame().set_linewidth(0.5)
leg.get_frame().set_edgecolor('lightgray')
plt.tight_layout()        
plt.savefig(r'C:\Users\lenovo\Documents\HOME\Figures AJ\precipitation//10daysum_abs_anom.png', dpi=400)
# Out:
# 28 11 9 9

# %% [markdown]
# # xx-day std anomaly

# %%
def listall(RootFolder, wildcard=''):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if wildcard in name
                     if name.endswith('.tif')]
    return lists

rowx = 12
coly = 29

xBlockSize = 9
yBlockSize = 9

folder_trmm = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\10_Day_Period\10_DaySums_StdNormAnomaly'
#path_base = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2_2009\10_Day_Period\10_DaySums_StdNormAnomaly//TRMM_IM_2009001.tif'

#Read files and check length
files_trmm = listall(folder_trmm)
files_trmm = files_trmm[2913:3278] ## xx-day sum
print len(files_trmm)
print files_trmm[0]
print files_trmm[-1]
# Out:
# 365
# D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\10_Day_Period\10_DaySums_StdNormAnomaly\TRMM_IM_2009001.tif
# D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\10_Day_Period\10_DaySums_StdNormAnomaly\TRMM_IM_2009365.tif

# %%
#files_ndvi = listall(folder_ndvi)

#if len(files_ndvi) <> len(files_trmm):
#    print 'Input length time series not equal: x ', len(files_ndvi), 'y ', len(files_trmm)
#    sys.exit()
#else:
#    print 'Input length time series equal: series1', len(files_ndvi), 'series2', len(files_trmm)
    
# loop through the rows
for i in range(rowx-1, rowx, yBlockSize): #(0, rows, yBlockSize)
    if i + yBlockSize < rows:
        numRows = yBlockSize
    else:
        numRows = rows - i
    
    # loop through the columns
    for j in range(coly-1, coly, xBlockSize):# (0, cols, xBlockSize)
        if j + xBlockSize < cols:
            numCols = xBlockSize
        else:
            numCols = cols - j
        
        print j, i, numCols, numRows
        # set base array to fill 
        ap_trmm = np.zeros(shape=(len(files_trmm),numRows,numCols), dtype=np.float32)
        #ap_ndvi = np.zeros(shape=(len(files_ndvi),numRows,numCols), dtype=np.float32)
        
        # select blocks from trmm and ndvi files
        for m in range(len(files_trmm)):
            raster = gdal.Open(files_trmm[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_trmm[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)
                
            #raster = gdal.Open(files_ndvi[m], gdal.GA_ReadOnly)
            #band = raster.GetRasterBand(1)            
            #ap_ndvi[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

        # reshape from 3D to 2D
        ap_trmm = ap_trmm.reshape((int(ap_trmm.shape[0]),int(ap_trmm.shape[1]*ap_trmm.shape[2]))).T
        #ap_ndvi = ap_ndvi.reshape((int(ap_ndvi.shape[0]),int(ap_ndvi.shape[1]*ap_ndvi.shape[2]))).T

b = np.ascontiguousarray(ap_trmm).view(np.dtype((np.void, ap_trmm.dtype.itemsize * ap_trmm.shape[1])))
_, idx = np.unique(b, return_index=True)

unique_a = ap_trmm[idx]
#unique_b = ap_ndvi[idx]

plt.figure(figsize=(7,5))
for i in unique_a:
    p1, = plt.plot(i, color='c', alpha=0.2)
#for j in unique_b:
#    p2, = plt.plot(j, color='m', alpha=0.2)

p3, = plt.plot(unique_a.mean(axis=0), 'k-', lw=1.5)
#p4, = plt.plot(unique_b.mean(axis=0), 'k--', lw=1.5)


plt.grid(axis='both')
plt.ylim(-0.6,0.5)
plt.xlim(0,364)
plt.xlabel('day of year')
plt.ylabel('precipitation ')
plt.title('10-day sum standardized anomaly')
leg = plt.legend([p1,p3],['precipitation anomaly','precipitation anomaly mean'],ncol=2, loc=3)
leg.get_frame().set_linewidth(0.5)
leg.get_frame().set_edgecolor('lightgray')
plt.tight_layout()        
#plt.savefig(r'C:\Users\lenovo\Documents\HOME\Figures AJ\precipitation//10daysum_std_anom.png', dpi=400)
# Out:
# 28 11 9 9

# %% [markdown]
# # All Std anom combined

# %%
def listall(RootFolder, wildcard=''):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if wildcard in name
                     if name.endswith('.tif')]
    return lists

rowx = 12
coly = 29

xBlockSize = 9
yBlockSize = 9

folder_trmm10 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\10_Day_Period\10_DaySums_StdNormAnomaly'
folder_trmm15 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\15_Day_Period\15_DaySums_StdNormAnomaly'
folder_trmm20 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\20_Day_Period\20_DaySums_StdNormAnomaly'
folder_trmm25 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\25_Day_Period\25_DaySums_StdNormAnomaly'
folder_trmm30 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\30_Day_Period\30_DaySums_StdNormAnomaly'
folder_trmm60 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\60_Day_Period\60_DaySums_StdNormAnomaly'
folder_trmm90 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\90_Day_Period\90_DaySums_StdNormAnomaly'
folder_trmm120 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\120_Day_Period\120_DaySums_StdNormAnomaly'
folder_trmm150 = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\150_Day_Period\150_DaySums_StdNormAnomaly'

#[2192:2557]#30-day sum 
#[2898:3263]#25-day sum
#[2903:3268]#20-day sum 
#[2192:2557]#15-day sum 
#[2913:3278]# 10-day sum

#Read files and check length
files_trmm10 = listall(folder_trmm10)
files_trmm10 = files_trmm10[2913:3278] ## xx-day sum
print len(files_trmm10), files_trmm10[0], files_trmm10[-1]

#Read files and check length
files_trmm15 = listall(folder_trmm15)
files_trmm15 = files_trmm15[2192:2557] ## xx-day sum
print len(files_trmm15), files_trmm15[0], files_trmm15[-1]

#Read files and check length
files_trmm20 = listall(folder_trmm20)
files_trmm20 = files_trmm20[2903:3268] ## xx-day sum
print len(files_trmm20), files_trmm20[0], files_trmm20[-1]

#Read files and check length
files_trmm25 = listall(folder_trmm25)
files_trmm25 = files_trmm25[2898:3263] ## xx-day sum
print len(files_trmm25), files_trmm25[0], files_trmm25[-1]

#Read files and check length
files_trmm30 = listall(folder_trmm30)
files_trmm30 = files_trmm30[2192:2557] ## xx-day sum
print len(files_trmm30), files_trmm30[0], files_trmm30[-1]

#Read files and check length
files_trmm60 = listall(folder_trmm60)
files_trmm60 = files_trmm60[2192:2557] ## xx-day sum
print len(files_trmm60), files_trmm60[0], files_trmm60[-1]

#Read files and check length
files_trmm90 = listall(folder_trmm90)
files_trmm90 = files_trmm90[2192:2557] ## xx-day sum
print len(files_trmm90), files_trmm90[0], files_trmm90[-1]

#Read files and check length
files_trmm120 = listall(folder_trmm120)
files_trmm120 = files_trmm120[2192:2557] ## xx-day sum
print len(files_trmm120), files_trmm120[0], files_trmm120[-1]

#Read files and check length
files_trmm150 = listall(folder_trmm150)
files_trmm150 = files_trmm150[2192:2557] ## xx-day sum
print len(files_trmm150), files_trmm150[0], files_trmm150[-1]
# Out:
# 365 D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\10_Day_Period\10_DaySums_StdNormAnomaly\TRMM_IM_2009001.tif D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\10_Day_Period\10_DaySums_StdNormAnomaly\TRMM_IM_2009365.tif
# 365
#  D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\15_Day_Period\15_DaySums_StdNormAnomaly\TRMM_IM_2009001.tif D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\15_Day_Period\15_DaySums_StdNormAnomaly\TRMM_IM_2009365.tif
# 365
#  D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\20_Day_Period\20_DaySums_StdNormAnomaly\TRMM_IM_2009001.tif D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\20_Day_Period\20_DaySums_StdNormAnomaly\TRMM_IM_2009365.tif
# 365
#  D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\25_Day_Period\25_DaySums_StdNormAnomaly\TRMM_IM_2009001.tif D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\25_Day_Period\25_DaySums_StdNormAnomaly\TRMM_IM_2009365.tif
# 365
#  D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\30_Day_Period\30_DaySums_StdNormAnomaly\TRMM_IM_2009001.tif D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\30_Day_Period\30_DaySums_StdNormAnomaly\TRMM_IM_2009365.tif
# 365
#  D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\60_Day_Period\60_DaySums_StdNormAnomaly\TRMM_IM_2009001.tif D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\60_Day_Period\60_DaySums_StdNormAnomaly\TRMM_IM_2009365.tif
# 365
#  D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\90_Day_Period\90_DaySums_StdNormAnomaly\TRMM_IM_2009001.tif D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\90_Day_Period\90_DaySums_StdNormAnomaly\TRMM_IM_2009365.tif
# 365
#  D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\120_Day_Period\120_DaySums_StdNormAnomaly\TRMM_IM_2009001.tif D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\120_Day_Period\120_DaySums_StdNormAnomaly\TRMM_IM_2009365.tif
# 365
#  D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\150_Day_Period\150_DaySums_StdNormAnomaly\TRMM_IM_2009001.tif D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\150_Day_Period\150_DaySums_StdNormAnomaly\TRMM_IM_2009365.tif

# %%
#files_ndvi = listall(folder_ndvi)

#if len(files_ndvi) <> len(files_trmm):
#    print 'Input length time series not equal: x ', len(files_ndvi), 'y ', len(files_trmm)
#    sys.exit()
#else:
#    print 'Input length time series equal: series1', len(files_ndvi), 'series2', len(files_trmm)
    
# loop through the rows
for i in range(rowx-1, rowx, yBlockSize): #(0, rows, yBlockSize)
    if i + yBlockSize < rows:
        numRows = yBlockSize
    else:
        numRows = rows - i
    
    # loop through the columns
    for j in range(coly-1, coly, xBlockSize):# (0, cols, xBlockSize)
        if j + xBlockSize < cols:
            numCols = xBlockSize
        else:
            numCols = cols - j
        
        print j, i, numCols, numRows
        # set base array to fill 
        ap_trmm10 = np.zeros(shape=(len(files_trmm10),numRows,numCols), dtype=np.float32)
        ap_trmm15 = np.zeros(shape=(len(files_trmm15),numRows,numCols), dtype=np.float32)
        ap_trmm20 = np.zeros(shape=(len(files_trmm20),numRows,numCols), dtype=np.float32)
        ap_trmm25 = np.zeros(shape=(len(files_trmm25),numRows,numCols), dtype=np.float32)
        ap_trmm30 = np.zeros(shape=(len(files_trmm30),numRows,numCols), dtype=np.float32)
        ap_trmm60 = np.zeros(shape=(len(files_trmm60),numRows,numCols), dtype=np.float32)
        ap_trmm90 = np.zeros(shape=(len(files_trmm90),numRows,numCols), dtype=np.float32)
        ap_trmm120 = np.zeros(shape=(len(files_trmm120),numRows,numCols), dtype=np.float32)
        ap_trmm150 = np.zeros(shape=(len(files_trmm150),numRows,numCols), dtype=np.float32)        
        #ap_ndvi = np.zeros(shape=(len(files_ndvi),numRows,numCols), dtype=np.float32)
        
        # select blocks from trmm and ndvi files
        for m in range(len(files_trmm10)):
            raster = gdal.Open(files_trmm10[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_trmm10[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

            raster = gdal.Open(files_trmm15[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_trmm15[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

            raster = gdal.Open(files_trmm20[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_trmm20[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

            raster = gdal.Open(files_trmm25[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_trmm25[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

            raster = gdal.Open(files_trmm30[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_trmm30[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

            raster = gdal.Open(files_trmm60[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_trmm60[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

            raster = gdal.Open(files_trmm90[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_trmm90[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

            raster = gdal.Open(files_trmm120[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_trmm120[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

            raster = gdal.Open(files_trmm150[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_trmm150[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)
            
            #raster = gdal.Open(files_ndvi[m], gdal.GA_ReadOnly)
            #band = raster.GetRasterBand(1)            
            #ap_ndvi[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

        # reshape from 3D to 2D
        ap_trmm10 = ap_trmm10.reshape((int(ap_trmm10.shape[0]),int(ap_trmm10.shape[1]*ap_trmm10.shape[2]))).T
        ap_trmm15 = ap_trmm15.reshape((int(ap_trmm15.shape[0]),int(ap_trmm15.shape[1]*ap_trmm15.shape[2]))).T
        ap_trmm20 = ap_trmm20.reshape((int(ap_trmm20.shape[0]),int(ap_trmm20.shape[1]*ap_trmm20.shape[2]))).T
        ap_trmm25 = ap_trmm25.reshape((int(ap_trmm25.shape[0]),int(ap_trmm25.shape[1]*ap_trmm25.shape[2]))).T
        ap_trmm30 = ap_trmm30.reshape((int(ap_trmm30.shape[0]),int(ap_trmm30.shape[1]*ap_trmm30.shape[2]))).T
        ap_trmm60 = ap_trmm60.reshape((int(ap_trmm60.shape[0]),int(ap_trmm60.shape[1]*ap_trmm60.shape[2]))).T
        ap_trmm90 = ap_trmm90.reshape((int(ap_trmm90.shape[0]),int(ap_trmm90.shape[1]*ap_trmm90.shape[2]))).T
        ap_trmm120 = ap_trmm120.reshape((int(ap_trmm120.shape[0]),int(ap_trmm120.shape[1]*ap_trmm120.shape[2]))).T        
        ap_trmm150 = ap_trmm150.reshape((int(ap_trmm150.shape[0]),int(ap_trmm150.shape[1]*ap_trmm150.shape[2]))).T        
        #ap_ndvi = ap_ndvi.reshape((int(ap_ndvi.shape[0]),int(ap_ndvi.shape[1]*ap_ndvi.shape[2]))).T

b = np.ascontiguousarray(ap_trmm10).view(np.dtype((np.void, ap_trmm10.dtype.itemsize * ap_trmm10.shape[1])))
_, idx = np.unique(b, return_index=True)

unique_10 = ap_trmm10[idx]
unique_15 = ap_trmm15[idx]
unique_20 = ap_trmm20[idx]
unique_25 = ap_trmm25[idx]
unique_30 = ap_trmm30[idx]
unique_60 = ap_trmm60[idx]
unique_90 = ap_trmm90[idx]
unique_120 = ap_trmm120[idx]
unique_150 = ap_trmm150[idx]
#unique_b = ap_ndvi[idx]
# Out:
# 28 11 9 9

# %%
plt.figure(figsize=(14,5))
# for i in unique_a:
#     p1, = plt.plot(i, color='c', alpha=0.2)
#for j in unique_b:
#    p2, = plt.plot(j, color='m', alpha=0.2)

a1,=plt.plot(unique_10.mean(axis=0), c='darkgreen',lw=2.0)
a2,=plt.plot(unique_15.mean(axis=0), lw=1.0, alpha=0.5)
a3,=plt.plot(unique_20.mean(axis=0), lw=1.0, alpha=0.5)
a4,=plt.plot(unique_25.mean(axis=0), lw=1.0, alpha=0.5)
a5,=plt.plot(unique_30.mean(axis=0), lw=1.0, alpha=0.5)
a6,=plt.plot(unique_60.mean(axis=0), lw=1.0, alpha=0.5)
a7,=plt.plot(unique_90.mean(axis=0), lw=1.0, alpha=0.5)
a8,=plt.plot(unique_120.mean(axis=0), lw=1.0, alpha=0.5)
a9,=plt.plot(unique_150.mean(axis=0), c='darkblue',lw=2.0)
a0,=plt.plot(y, 'm-', lw=2)
plt.axhline(ls='-', color='gray', alpha=0.5)
#p4, = plt.plot(unique_b.mean(axis=0), 'k--', lw=1.5)


plt.grid(axis='both')
plt.ylim(-0.30,0.15)
plt.xlim(0,364)
plt.xlabel('day of year')
plt.ylabel('anomaly difference')
plt.title('standardized NDVI and precipitation anomaly')
leg = plt.legend([a0,a1,a2,a3,a4,a5,a6,a7,a8,a9],['NDVI','10-day sum','15-day sum','20-day sum','25-day sum',
                                                  '30-day sum','60-day sum','90-day sum','120-day sum',
                                                  '150-day sum'],ncol=2, loc=3)
leg.get_frame().set_linewidth(0.5)
leg.get_frame().set_edgecolor('lightgray')
plt.tight_layout()        
plt.savefig(r'C:\Users\lenovo\Documents\HOME\Figures AJ\precipitation//all_daysum_std_anom_NDVI.png', dpi=400)

# %%
plt.plot(y[0:364])

# %% [markdown]
# # AND NOW THE PHASE-DELAY ESTIMATES

# %%
def dB(x, out=None):
    if out is None:
        return 10 * np.log10(x)
    else:
        np.log10(x, out)
        np.multiply(out, 10, out)

def mtem(x, y):
    """
    multitaper estimation method
    input:
    x  first time series
    y  second time series

    output:
    fkx  power spectral density x
    fky  power spectral density y
    cxy  cross-spectral density xy
    coh  coherence
    ph  phase between xy at input freq
    
    """
    print 'x size', x.shape
    print 'y size', y.shape
    
    # apply multi taper cross spectral density from nitime module
    f, pcsd_est = tsa.multi_taper_csd(np.vstack([x,y]), Fs=1., low_bias=True, adaptive=True, sides='onesided')
    
    # output is MxMxN matrix, extract the psd and csd
    fkx = pcsd_est.diagonal().T[0]
    fky = pcsd_est.diagonal().T[1]
    cxy = pcsd_est.diagonal(+1).T.ravel()
    
    # using complex argument of cxy extract phase component
    ph = np.angle(cxy)
    
    # calculate coherence using csd and psd
    coh = np.abs(cxy)**2 / (fkx * fky)   
    
    return f, fkx, fky, cxy, ph, coh 

def mtem_unct(x_, y_, cf, mc_no=20):
    """
    Uncertainty function using Monte Carlo analysis
    Input:
    x_ = timeseries x
    y_ = timeseries y
    cf = coherence function between x and y
    mc_no = number of iterations default is 20, minimum is 3
    
    Output:
    phif = phase uncertainty bounded between 0 and pi
    """
    print 'iteration no is', mc_no
    
    data = np.vstack([x_,y_])
    # number of iterations
    # flip coherence and horizontal stack    
    cg = np.hstack((cf[:-1], np.flipud(cf[:-1])))
    
    # random time series fx
    mc_fx = random.standard_normal(size=(mc_no,len(data[0])))
    mc_fx = mc_fx / np.sum(abs(mc_fx),axis=1)[None].T
    
    # random time series fy
    mc_fy = random.standard_normal(size=(mc_no,len(data[0])))
    mc_fy = mc_fy / np.sum(abs(mc_fy),axis=1)[None].T
    
    # create semi random timeseries based on magnitude squared coherence
    # and inverse fourier transform for ys
    ys = real(ifft(mc_fy * sqrt(1 - cg ** 2))) 
    ys = ys + real(ifft(mc_fx *cg))
    
    # inverse fourier transform for xs
    xs = real(ifft(mc_fx))
    
    # spectral analysis
    f_s, pcsd_est = tsa.multi_taper_csd(np.vstack([xs,ys]), Fs=1., low_bias=True, adaptive=True, sides='onesided')
    cxyi = pcsd_est.diagonal(+int(xs.shape[0])).T
    phi = np.angle(cxyi)
    
    # sort and average the highest uncertianties
    pl = int(round(0.975*mc_no)+1)
    phi = sort(phi,axis=0)        
    phi = phi[((mc_no+1)-pl):pl]
    phi = np.array([phi[pl-2,:],-phi[pl-mc_no,:]])
    phi = phi.mean(axis=0)#
    phi = np.convolve(phi, np.array([1,1,1])/3)
    phif = phi[1:-1]
    return phif

# %%
def listall(RootFolder, wildcard=''):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if wildcard in name
                     if name.endswith('.tif')]
    return lists

rowx = 300
coly = 700

folder_trmm = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2_2009\10_Day_Period\10_DaySums_StdNormAnomalyRes'
folder_ndvi = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\NDVI_2009\DaySums_StdNormAnomaly'
path_base = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\NDVI_2009\DaySums_StdNormAnomaly//NDVI_IM_2009001.tif'

files_trmm = listall(folder_trmm)
files_ndvi = listall(folder_ndvi)
if len(files_ndvi) <> len(files_trmm):
    print 'Input length time series not equal: x ', len(files_ndvi), 'y ', len(files_trmm)
    sys.exit()
else:
    print 'Input length time series equal: series1', len(files_ndvi), 'series2', len(files_trmm)

# register all of the GDAL drivers
gdal.AllRegister()

# open the image
ds = gdal.Open(path_base, gdal.GA_ReadOnly)
if ds is None:
    print 'Could not open base file'
    sys.exit(1)

# get image size
rows = ds.RasterYSize
cols = ds.RasterXSize
bands = ds.RasterCount

# get the band and block sizes
band = ds.GetRasterBand(1)
base = band.ReadAsArray()
nan = band.GetNoDataValue()

#blockSizes = utils.GetBlockSize(band)
xBlockSize = 200
yBlockSize = 200

# files_trmm = listall(folder_trmm)
# files_ndvi = listall(folder_ndvi)
# if len(files_ndvi) <> len(files_trmm):
#     print 'Input length time series not equal: x ', len(files_ndvi), 'y ', len(files_trmm)
#     sys.exit()
# else:
#     print 'Input length time series equal: series1', len(files_ndvi), 'series2', len(files_trmm)
    
# loop through the rows
for i in range(rowx-1, rowx, yBlockSize): #(0, rows, yBlockSize)
    if i + yBlockSize < rows:
        numRows = yBlockSize
    else:
        numRows = rows - i
    
    # loop through the columns
    for j in range(coly-1, coly, xBlockSize):# (0, cols, xBlockSize)
        if j + xBlockSize < cols:
            numCols = xBlockSize
        else:
            numCols = cols - j
        
        print j, i, numCols, numRows
        # set base array to fill 
        ap_trmm = np.zeros(shape=(len(files_trmm),numRows,numCols), dtype=np.float32)
        ap_ndvi = np.zeros(shape=(len(files_ndvi),numRows,numCols), dtype=np.float32)
        
        # select blocks from trmm and ndvi files
        for m in range(len(files_trmm)):
            raster = gdal.Open(files_trmm[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_trmm[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)
                
            raster = gdal.Open(files_ndvi[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_ndvi[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

        # reshape from 3D to 2D
        ap_trmm = ap_trmm.reshape((int(ap_trmm.shape[0]),int(ap_trmm.shape[1]*ap_trmm.shape[2]))).T
        ap_ndvi = ap_ndvi.reshape((int(ap_ndvi.shape[0]),int(ap_ndvi.shape[1]*ap_ndvi.shape[2]))).T

b = np.ascontiguousarray(ap_trmm).view(np.dtype((np.void, ap_trmm.dtype.itemsize * ap_trmm.shape[1])))
_, idx = np.unique(b, return_index=True)

unique_a = ap_trmm[idx]
unique_b = ap_ndvi[idx]
y = unique_b.mean(axis=0) 

m_x = unique_a.mean(axis=0)
m_y = unique_b.mean(axis=0)
print files_trmm[0]
print files_trmm[-1]

print files_ndvi[0]
print files_ndvi[-1]
# Out:
# Input length time series equal: series1 364 series2 364
# 699
#  299 200 200
# D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2_2009\10_Day_Period\10_DaySums_StdNormAnomalyRes\TRMM_IM_2009001.tif
# D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2_2009\10_Day_Period\10_DaySums_StdNormAnomalyRes\TRMM_IM_2009365.tif
# D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\NDVI_2009\DaySums_StdNormAnomaly\NDVI_IM_2009001.tif
# D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\NDVI_2009\DaySums_StdNormAnomaly\NDVI_IM_2009365.tif

# %%
def listall(RootFolder, wildcard=''):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if wildcard in name
                     if name.endswith('.tif')]
    return lists

rowx = 12
coly = 29

xBlockSize = 9
yBlockSize = 9

folder_trmm = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\90_Day_Period\90_DaySums_StdNormAnomaly'
#path_base = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2_2009\10_Day_Period\10_DaySums_StdNormAnomaly//TRMM_IM_2009001.tif'

#Read files and check length
files_trmm = listall(folder_trmm)
files_trmm = files_trmm[2192:2557] #60-day sum [2192:2557]#30-day sum #[2898:3263]#[2903:3268]#20-day sum ##[2192:2557]# 15-day sum ##[2913:3278] # 10-day sum## xx-day sum
print len(files_trmm)
print files_trmm[0]
print files_trmm[-1]
# Out:
# 365
# D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\90_Day_Period\90_DaySums_StdNormAnomaly\TRMM_IM_2009001.tif
# D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\TRMM2\90_Day_Period\90_DaySums_StdNormAnomaly\TRMM_IM_2009365.tif

# %%
# loop through the rows
for i in range(rowx-1, rowx, yBlockSize): #(0, rows, yBlockSize)
    if i + yBlockSize < rows:
        numRows = yBlockSize
    else:
        numRows = rows - i
    
    # loop through the columns
    for j in range(coly-1, coly, xBlockSize):# (0, cols, xBlockSize)
        if j + xBlockSize < cols:
            numCols = xBlockSize
        else:
            numCols = cols - j
        
        print j, i, numCols, numRows
        # set base array to fill 
        ap_trmm = np.zeros(shape=(len(files_trmm),numRows,numCols), dtype=np.float32)
        #ap_ndvi = np.zeros(shape=(len(files_ndvi),numRows,numCols), dtype=np.float32)
        
        # select blocks from trmm and ndvi files
        for m in range(len(files_trmm)):
            raster = gdal.Open(files_trmm[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_trmm[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)
                
            #raster = gdal.Open(files_ndvi[m], gdal.GA_ReadOnly)
            #band = raster.GetRasterBand(1)            
            #ap_ndvi[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

        # reshape from 3D to 2D
        ap_trmm = ap_trmm.reshape((int(ap_trmm.shape[0]),int(ap_trmm.shape[1]*ap_trmm.shape[2]))).T
        #ap_ndvi = ap_ndvi.reshape((int(ap_ndvi.shape[0]),int(ap_ndvi.shape[1]*ap_ndvi.shape[2]))).T

b = np.ascontiguousarray(ap_trmm).view(np.dtype((np.void, ap_trmm.dtype.itemsize * ap_trmm.shape[1])))
_, idx = np.unique(b, return_index=True)

unique_a = ap_trmm[idx]
x = unique_a.mean(axis=0)
# Out:
# 28 11 9 9

# %%
x=x[0:364]
y=y[0:364]
x = np.tile(x, 200)
y = np.tile(y, 200)
t = np.arange(x.shape[0])

#m_x = np.tile(m_x, 200)
#m_y = np.tile(m_y, 200)

# %%
plt.plot(x, 'k-', lw=1.5)
plt.plot(y, 'k--',lw=1.5)
# plt.plot(m_x, 'r--', lw=1.5)
# plt.plot(m_y, 'r--',lw=1.5)

plt.grid(axis='both')
plt.ylim(-0.4,0.2)
plt.xlim(0,364)
plt.xlabel('day of year')
plt.ylabel('normalised anomaly')
plt.title('anomaly time series')
leg = plt.legend(['precipitation mean','ndvi mean'],ncol=2, loc=3)
leg.get_frame().set_linewidth(0.5)
leg.get_frame().set_edgecolor('lightgray')
plt.tight_layout()

# %%
f, fkx, fky, cxy, ph, coh = mtem(x,y)
phif = mtem_unct(x,y,coh, mc_no=20)
# Out:
# x size (72800L,)
# y size (72800L,)
# iteration no is
#  20

# %%
vspan_start = 0.0026
vspan_end = 0.0028
xlim_start = 0.000
xlim_end = 0.012

# %%
plt.figure(figsize=(7,5))

from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA

rad2time = ph/(2*np.pi*f)
mtcl2time = phif/(2*np.pi*f)
neg_time= np.where(rad2time<0)
dur_cycl = (1/f)
rad2time[neg_time] = rad2time[neg_time]+dur_cycl[neg_time]


ax = host_subplot(111, axes_class=AA.Axes)

p1 = Rectangle((0, 0), 1, 1, fc='c', ec='c')
p2, = ax.plot(f, rad2time, color='m', zorder=5, label='Phase')
p3, = ax.plot(f, dur_cycl, color='gray', linestyle='-.', zorder=5, label='Period')
p4, = ax.plot(f, dur_cycl/2, color='gray', linestyle='--', zorder=5, label='Halve period')

ax.fill_between(f,(rad2time+mtcl2time),(rad2time-mtcl2time), where=(((rad2time+mtcl2time)<dur_cycl)), 
             facecolor='c' ,edgecolor='c', lw=0.0 ,interpolate=True, zorder=4)
ax.fill_between(f,(rad2time-mtcl2time),dur_cycl, where=(((rad2time+mtcl2time)>dur_cycl)),
             facecolor='c' ,edgecolor='c', lw=0.0 ,interpolate=True, zorder=4)
ax.fill_between(f,(rad2time+mtcl2time)-dur_cycl, where=(((rad2time+mtcl2time)>0)),
             facecolor='c' ,edgecolor='c', lw=0.0 ,interpolate=True, zorder=4)
ax.fill_between(f,((rad2time-mtcl2time)+dur_cycl),dur_cycl, where=((rad2time-mtcl2time)<0), 
             facecolor='c' ,edgecolor='c', lw=0.0 ,interpolate=True, zorder=4)

ax.set_xlim([xlim_start,xlim_end])
ax.set_ylim([0,366])
#ax.set_xticks([(1/366),(1./(366./2)),(1./(366./3)),(1./(366./4))])

ax.set_xlabel('frequency (Hz)')
ax.set_ylabel('phase (days)')
ax.set_title('time (days)', loc='left', fontsize=10)

p5= axvspan(vspan_start,vspan_end, color='gray', alpha=0.1, zorder=-1)
#axvspan(0.099,0.101, color='gray', alpha=0.1, zorder=0)

ax2 = ax.twin() # ax2 is responsible for "top" axis and "right" axis
ax2.set_xlabel('phase between x and y for all frequencies + uncertainty')
ax2.set_xticks([0.05,0.1,0.15,0.2])#0., .5*np.pi, np.pi, 1.5*np.pi, 2*np.pi])
ax2.set_xticklabels([str(round(1./0.05, 1)),str(round(1./0.1,1)),str(round(1./0.15,1)),str(round(1./0.2,1))])
ax2.axis["right"].major_ticklabels.set_visible(False)
ax2.xaxis.label.set_size(2)

plt.legend([p2,p3,p4,p1,p5], ['phase-delay','single period','halve period','phase uncertainty estimates', 'frequencies of interest'])
plt.grid(axis='y', zorder=0 )

plt.tight_layout()
plt.savefig(r'C:\Users\lenovo\Documents\HOME\Figures AJ\precipitation//90daysum_phase.png', dpi=400)

plt.show()

# %%
plt.figure(figsize=(14,5))
plt.subplot(121)
plt.grid(axis='y')

plt.plot(f,dB(fkx), 'r-', lw=1)
plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
plt.xlim(xlim_start,xlim_end)
#plt.axvspan(0.099,0.101, color='gray', alpha=0.1)

#plt.ylim(-5,35)

plt.ylabel('power spectrum magnitude ($10log10$)')
plt.xlabel('frequency (Hz)')
plt.title('power spectral density of x')
plt.gcf().tight_layout()

plt.subplot(122)
plt.grid(axis='y')
plt.plot(f,dB(fky), 'b-', lw=1)
plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
#plt.axvspan(0.099,0.101, color='gray', alpha=0.1)
plt.xlim(xlim_start,xlim_end)
#plt.ylim(-5,35)

plt.ylabel('power spectrum magnitude ($10log10$)')
plt.xlabel('frequency (Hz)')
plt.title('power spectral density of y')
plt.gcf().tight_layout()

# %%
plt.figure(figsize=(14,5))
plt.subplot(121)
plt.grid(axis='y')

plt.plot(f,dB(cxy), 'g-', lw=1)
plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
#plt.axvspan(0.099,0.101, color='gray', alpha=0.1)
plt.xlim(xlim_start,xlim_end)
#plt.ylim(-5,35)

plt.ylabel('cross-power spectrum magnitude ($10log10$)')
plt.xlabel('frequency (Hz)')
plt.title('cross spectral density of x and y')
plt.gcf().tight_layout()

plt.subplot(122)
plt.grid(axis='y')

plt.plot(f,coh, 'y')

plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
#plt.axvspan(0.099,0.101, color='gray', alpha=0.1)
plt.xlim(xlim_start,xlim_end)
plt.ylim(0,1.01)

plt.ylabel('coherence')
plt.xlabel('frequency (Hz)')
plt.title('coherence of x and y')

plt.gcf().tight_layout()

# %%
plt.figure(figsize=(14,5))
plt.subplot(121)
plt.grid(axis='y')

plt.plot(f,ph, 'm', lw=1)
plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
#plt.axvspan(0.099,0.101, color='gray', alpha=0.1)
plt.xlim(xlim_start,xlim_end)
plt.ylim(-np.pi,np.pi)

plt.ylabel('phase (radian, bounded [$-{\pi}-{\pi}$])')
plt.xlabel('frequency (Hz)')
plt.title('phase between x and y for all frequencies')
plt.gcf().tight_layout()

plt.subplot(122)
plt.grid(axis='y')

plt.plot(f,phif, 'c', lw=1)
plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
#plt.axvspan(0.099,0.101, color='gray', alpha=0.1)
plt.xlim(xlim_start,xlim_end)
plt.ylim(-0.05,3.2)

plt.ylabel('phase uncertainty (radian, bounded [$0-{\pi}$])')
plt.xlabel('frequency (Hz)')
plt.title('phase uncertainty between x and y for all frequencies')
plt.gcf().tight_layout()

# %%
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
rad2time = ph/(2*np.pi*f)
mtcl2time = phif/(2*np.pi*f)
neg_time= np.where(rad2time<0)
dur_cycl = (1/f)
rad2time[neg_time] = rad2time[neg_time]+dur_cycl[neg_time]

# %%
plt.figure(figsize=(14,5))
# plt.subplot(121)
# plt.grid(axis='y')
# plt.plot(f,ph, 'm')
# plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
# #plt.axvspan(0.099,0.101, color='gray', alpha=0.1)

# plt.fill_between(f,ph,(ph-phif),facecolor='c' ,edgecolor='c', lw=0.0)#, where=(ph-phif)>=-np.pi)
# plt.fill_between(f,ph,(ph+phif),facecolor='c' ,edgecolor='c', lw=0.0)

# plt.fill_between(f,(ph+2*np.pi),((ph+2*np.pi)-phif), where=(ph-phif)<=-np.pi,
#                  facecolor='c' ,edgecolor='c', lw=0.0)
# plt.fill_between(f,(ph-2*np.pi),((ph-2*np.pi)+phif), where=(ph+phif)>=np.pi,
#                  facecolor='c' ,edgecolor='c', lw=0.0)


# plt.xlim(xlim_start,xlim_end)
# plt.ylim(-np.pi,np.pi)

# plt.ylabel('phase (radian, bounded [$-{\pi}-{\pi}$])')
# plt.xlabel('frequency (Hz)')
# plt.title('phase between x and y for all frequencies + uncertainty')
# plt.gcf().tight_layout()

# from mpl_toolkits.axes_grid1 import host_subplot
# import mpl_toolkits.axisartist as AA

# rad2time = ph/(2*np.pi*f)
# mtcl2time = phif/(2*np.pi*f)
# neg_time= np.where(rad2time<0)
# dur_cycl = (1/f)
# rad2time[neg_time] = rad2time[neg_time]+dur_cycl[neg_time]


ax = host_subplot(121, axes_class=AA.Axes)

p1 = Rectangle((0, 0), 1, 1, fc='c', ec='c')
p2, = ax.plot(f, rad2time, color='m', zorder=5, label='Phase')
p3, = ax.plot(f, dur_cycl, color='gray', linestyle='-.', zorder=5, label='Period')
p4, = ax.plot(f, dur_cycl/2, color='gray', linestyle='--', zorder=5, label='Halve period')

ax.fill_between(f,(rad2time+mtcl2time),(rad2time-mtcl2time), where=(((rad2time+mtcl2time)<dur_cycl)), 
             facecolor='c' ,edgecolor='c', lw=0.0 ,interpolate=True, zorder=4)
ax.fill_between(f,(rad2time-mtcl2time),dur_cycl, where=(((rad2time+mtcl2time)>dur_cycl)),
             facecolor='c' ,edgecolor='c', lw=0.0 ,interpolate=True, zorder=4)
ax.fill_between(f,(rad2time+mtcl2time)-dur_cycl, where=(((rad2time+mtcl2time)>0)),
             facecolor='c' ,edgecolor='c', lw=0.0 ,interpolate=True, zorder=4)
ax.fill_between(f,((rad2time-mtcl2time)+dur_cycl),dur_cycl, where=((rad2time-mtcl2time)<0), 
             facecolor='c' ,edgecolor='c', lw=0.0 ,interpolate=True, zorder=4)

ax.set_xlim([xlim_start,xlim_end])
ax.set_ylim([0,366])
#ax.set_xticks([(1/366),(1./(366./2)),(1./(366./3)),(1./(366./4))])

ax.set_xlabel('frequency (Hz)')
ax.set_ylabel('phase (days)')
ax.set_title('time (days)', loc='left', fontsize=10)

p5= axvspan(vspan_start,vspan_end, color='gray', alpha=0.1, zorder=-1)
#axvspan(0.099,0.101, color='gray', alpha=0.1, zorder=0)

ax2 = ax.twin() # ax2 is responsible for "top" axis and "right" axis
ax2.set_xlabel('phase between x and y for all frequencies + uncertainty')
ax2.set_xticks([0.05,0.1,0.15,0.2])#0., .5*np.pi, np.pi, 1.5*np.pi, 2*np.pi])
ax2.set_xticklabels([str(round(1./0.05, 1)),str(round(1./0.1,1)),str(round(1./0.15,1)),str(round(1./0.2,1))])
ax2.axis["right"].major_ticklabels.set_visible(False)
ax2.xaxis.label.set_size(2)

plt.legend([p2,p3,p4,p1,p5], ['phase-delay','single period','halve period','phase uncertainty estimates', 'frequencies of interest'])
plt.grid(axis='y', zorder=0 )

plt.tight_layout()

plt.show()

# %% [markdown]
# Open basefile and set arrays for initial rasters

# %% [markdown]
# The single loop part for a single timeseries

# %%
# loop through the rows
for i in range(rowx-1, rowx, yBlockSize): #(0, rows, yBlockSize)
    if i + yBlockSize < rows:
        numRows = yBlockSize
    else:
        numRows = rows - i
    
    # loop through the columns
    for j in range(coly-1, coly, xBlockSize):# (0, cols, xBlockSize)
        if j + xBlockSize < cols:
            numCols = xBlockSize
        else:
            numCols = cols - j
        
        print j, i, numCols, numRows
        
        # set base array to fill 
        ap_ndvi = np.zeros(shape=(len(files_ndvi),numRows,numCols), dtype=np.float32)
        
        # select blocks from trmm and ndvi files
        for m in range(len(files_ndvi)):
                
            raster = gdal.Open(files_ndvi[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_ndvi[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

        # reshape from 3D to 2D
        ap_ndvi = ap_ndvi.reshape((int(ap_ndvi.shape[0]),int(ap_ndvi.shape[1]*ap_ndvi.shape[2]))).T

# %%
unique_b = ap_ndvi[idx]

plt.figure(figsize=(7,5))

for j in unique_b:
    p2, = plt.plot(j, color='m', alpha=0.2)

p4, = plt.plot(unique_b.mean(axis=0), 'k--', lw=1.5)


plt.grid(axis='both')
plt.ylim(-0.1,0.9)
plt.xlim(0,364)
plt.xlabel('day of year')
plt.ylabel('NDVI')
plt.title('NDVI time series long-term mean')
leg = plt.legend([p2,p4],['ndvi','ndvi mean'],ncol=2, loc=3)
leg.get_frame().set_linewidth(0.5)
leg.get_frame().set_edgecolor('lightgray')
plt.tight_layout()
plt.savefig(r'C:\Users\lenovo\Documents\HOME\Figures AJ\timeseries_chart//y_NDVI_lt_mean_timeseries.png', dpi=400)

# %%
folder_ndvi = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\NDVI\RAW2'
#path_base = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\NDVI_2009\DaySums_StdNormAnomaly//NDVI_IM_2009001.tif'

#Read files and check length
files_ndvi = listall(folder_ndvi)
files_ndvi = files_ndvi[2191:2556]
print len(files_ndvi)
print files_ndvi[0]

# %%
# loop through the rows
for i in range(rowx-1, rowx, yBlockSize): #(0, rows, yBlockSize)
    if i + yBlockSize < rows:
        numRows = yBlockSize
    else:
        numRows = rows - i
    
    # loop through the columns
    for j in range(coly-1, coly, xBlockSize):# (0, cols, xBlockSize)
        if j + xBlockSize < cols:
            numCols = xBlockSize
        else:
            numCols = cols - j
        
        print j, i, numCols, numRows
        
        # set base array to fill 
        ap_ndvi = np.zeros(shape=(len(files_ndvi),numRows,numCols), dtype=np.float32)
        
        # select blocks from trmm and ndvi files
        for m in range(len(files_ndvi)):
                
            raster = gdal.Open(files_ndvi[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_ndvi[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

        # reshape from 3D to 2D
        ap_ndvi = ap_ndvi.reshape((int(ap_ndvi.shape[0]),int(ap_ndvi.shape[1]*ap_ndvi.shape[2]))).T

# %%
unique_b = ap_ndvi[idx]

plt.figure(figsize=(7,5))

for j in unique_b:
    p2, = plt.plot(j, color='m', alpha=0.2)

p4, = plt.plot(unique_b.mean(axis=0), 'k--', lw=1.5)


plt.grid(axis='both')
plt.ylim(-0.1,0.9)
plt.xlim(0,364)
#plt.axhline(0, color='k')
plt.xlabel('day of year')
plt.ylabel('NDVI')
plt.title('NDVI time series 2009')
leg = plt.legend([p2,p4],['ndvi','ndvi mean'],ncol=2, loc=3)
leg.get_frame().set_linewidth(0.5)
leg.get_frame().set_edgecolor('lightgray')
plt.tight_layout()
plt.savefig(r'C:\Users\lenovo\Documents\HOME\Figures AJ\timeseries_chart//y_NDVI_2009_timeseries.png', dpi=400)

# %%
folder_ndvi = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\NDVI\DaySums_Anomaly'
#path_base = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\NDVI_2009\DaySums_StdNormAnomaly//NDVI_IM_2009001.tif'

#Read files and check length
files_ndvi = listall(folder_ndvi)
files_ndvi = files_ndvi[2191:2556]
print len(files_ndvi)

# %%
# loop through the rows
for i in range(rowx-1, rowx, yBlockSize): #(0, rows, yBlockSize)
    if i + yBlockSize < rows:
        numRows = yBlockSize
    else:
        numRows = rows - i
    
    # loop through the columns
    for j in range(coly-1, coly, xBlockSize):# (0, cols, xBlockSize)
        if j + xBlockSize < cols:
            numCols = xBlockSize
        else:
            numCols = cols - j
        
        print j, i, numCols, numRows
        
        # set base array to fill 
        ap_ndvi = np.zeros(shape=(len(files_ndvi),numRows,numCols), dtype=np.float32)
        
        # select blocks from trmm and ndvi files
        for m in range(len(files_ndvi)):
                
            raster = gdal.Open(files_ndvi[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_ndvi[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

        # reshape from 3D to 2D
        ap_ndvi = ap_ndvi.reshape((int(ap_ndvi.shape[0]),int(ap_ndvi.shape[1]*ap_ndvi.shape[2]))).T

# %%
unique_b = ap_ndvi[idx]

plt.figure(figsize=(7,5))

for j in unique_b:
    p2, = plt.plot(j, color='m', alpha=0.2)

p4, = plt.plot(unique_b.mean(axis=0), 'k--', lw=1.5)


plt.grid(axis='both')
plt.ylim(-0.6,0.5)
plt.xlim(0,364)
plt.axhline(0, color='k')
plt.xlabel('day of year')
plt.ylabel('NDVI difference')
plt.title('NDVI absolute anomaly time series')
leg = plt.legend([p2,p4],['ndvi abs anomaly','ndvi abs anomaly mean'],ncol=2, loc=3)
leg.get_frame().set_linewidth(0.5)
leg.get_frame().set_edgecolor('lightgray')
plt.tight_layout()
plt.savefig(r'C:\Users\lenovo\Documents\HOME\Figures AJ\timeseries_chart//y_NDVI_abs_anom_timeseries.png', dpi=400)

# %%
folder_ndvi = r'D:\Data\0_DAILY_INTERVAL_NDVI_TRMM\InnerMongolia\NDVI\DaySums_StdNormAnomaly'

#Read files and check length
files_ndvi = listall(folder_ndvi)
files_ndvi = files_ndvi[2191:2556]
print len(files_ndvi)

# loop through the rows
for i in range(rowx-1, rowx, yBlockSize): #(0, rows, yBlockSize)
    if i + yBlockSize < rows:
        numRows = yBlockSize
    else:
        numRows = rows - i
    
    # loop through the columns
    for j in range(coly-1, coly, xBlockSize):# (0, cols, xBlockSize)
        if j + xBlockSize < cols:
            numCols = xBlockSize
        else:
            numCols = cols - j
        
        print j, i, numCols, numRows
        
        # set base array to fill 
        ap_ndvi = np.zeros(shape=(len(files_ndvi),numRows,numCols), dtype=np.float32)
        
        # select blocks from trmm and ndvi files
        for m in range(len(files_ndvi)):
                
            raster = gdal.Open(files_ndvi[m], gdal.GA_ReadOnly)
            band = raster.GetRasterBand(1)            
            ap_ndvi[m] = band.ReadAsArray(j, i, numCols, numRows).astype(np.float)

        # reshape from 3D to 2D
        ap_ndvi = ap_ndvi.reshape((int(ap_ndvi.shape[0]),int(ap_ndvi.shape[1]*ap_ndvi.shape[2]))).T

# %%
unique_b = ap_ndvi[idx]

plt.figure(figsize=(7,5))

for j in unique_b:
    p2, = plt.plot(j, color='m', alpha=0.2)

p4, = plt.plot(unique_b.mean(axis=0), 'k--', lw=1.5)


plt.grid(axis='both')
plt.ylim(-0.6,0.5)
plt.xlim(0,364)
plt.axhline(0, color='k')
plt.xlabel('day of year')
plt.ylabel('NDVI difference')
plt.title('NDVI standardized anomaly time series')
leg = plt.legend([p2,p4],['ndvi std anomaly','ndvi std anomaly mean'],ncol=2, loc=3)
leg.get_frame().set_linewidth(0.5)
leg.get_frame().set_edgecolor('lightgray')
plt.tight_layout()
plt.savefig(r'C:\Users\lenovo\Documents\HOME\Figures AJ\timeseries_chart//y_NDVI_std_anom_timeseries.png', dpi=400)

# %%
plt.Line2D((0,1),(0,0), color='k', marker='o', linestyle='')

# %%
m1, m2 = unique_a.mean(axis=0),unique_b.mean(axis=0)
xmin = m1.min()
xmax = m1.max()
ymin = m2.min()
ymax = m2.max()

# X, Y = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
# positions = np.vstack([X.ravel(), Y.ravel()])
# values = np.vstack([m1, m2])
# kernel = stats.gaussian_kde(values)
# Z = np.reshape(kernel(positions).T, X.shape)

# fig = plt.figure(figsize=(14,5))
# ax = fig.add_subplot(111)
# ax.imshow(np.rot90(Z), cmap=plt.cm.gist_earth_r,
#           extent=[xmin, xmax, ymin, ymax])
# ax.plot(m1, m2, 'k.', markersize=2)
# ax.set_xlim([xmin, xmax])
# ax.set_ylim([ymin, ymax])
# plt.show()

x = np.tile(m1, 200)
y = np.tile(m2, 200)
t = np.arange(x.shape[0])

# %%
w = np.zeros(ap_ndvi.shape[1])
w[98:304] = ap_trmm.T[98:304].ravel()

q = np.zeros(ap_ndvi.shape[1])
q[98:304] = ap_ndvi.T[98:304].ravel()

x = np.tile(w, 200)
y = np.tile(q, 200)

t = np.arange(x.shape[0])
w = np.tile(ap_trmm, 200).ravel()
q = np.tile(ap_ndvi, 200).ravel()

# %%
# extend signal
trmm = np.tile(ap_trmm, 200)
ndvi = np.tile(ap_ndvi, 200)
plt.plot(ndvi.T.ravel())
plt.plot(trmm.T)
plt.xlim(0,365)

# %%
x = trmm.ravel()
y = ndvi.ravel()
t = np.arange(x.shape[0])

# %% [markdown]
# Create two test signals. One simple and one sophisticated, including noise and multiple trends

# %%
# t = np.arange(0,1774, 0.2)
# rand1 = np.random.rand(len(t))
# rand2 = np.random.rand(len(t))

# # simple sinus signal
# x  = np.sin(2*(np.pi/(1./0.1))*t+0)
# y  = np.sin(2*(np.pi/(1./0.1))*t+1) # last element is the phase in radian, this time 1

# # sophisticated sinus signal
# x = 1 * np.cos(2 * np.pi * 60/360 + 2 * np.pi/26 * t) + 4 * np.cos(-2 * np.pi *  0/360-2 * np.pi/10 * t) + 1.5 * (-1 + 2 * rand1)
# y = 0.5 * np.cos(2 * np.pi * 90/360 + 2 * np.pi/21 * t) + 4 * np.cos(+2 * np.pi * 70/360-2 * np.pi/10 * t) + 1.5 * (-1 + 2 * rand2)

# %% [markdown]
# Plot the two timeseries as is

# %%
plt.figure(figsize=(14,5))
plt.subplot(121)
plt.grid()

plt.plot(t,x, 'k-', lw=1, label='x')
plt.plot(t,y, 'k--', lw=1, label='y')
plt.xlim(0,365)

plt.ylabel('normalised anomaly')
plt.xlabel('time (days)')
plt.title('two timeseries')
plt.legend()

plt.subplot(122)
plt.grid()

plt.plot(t,x, 'k-', lw=1, label='x')
plt.plot(t,y, 'k--', lw=1, label='y')
#plt.xlim(0,365)

plt.ylabel('normalised anomaly')
plt.xlabel('time (days)')
plt.title('two timeseries')
plt.legend()
plt.gcf().tight_layout()

# %% [markdown]
# Compute all the components we need: frequencies, power spectral density of x, power spectral density of y, cross spectral density between x and y, coherence between x and y, phase spectrum between x and y and last the phase uncertainty between x and y.

# %%
f, fkx, fky, cxy, ph, coh = mtem(x,y)
phif = mtem_unct(x,y,coh, mc_no=20)

# %%
vspan_start = 0.0026
vspan_end = 0.0028
xlim_start = 0.000
xlim_end = 0.012

# %% [markdown]
# So now only making some plots of the result. First the psd of x and y.

# %%
plt.figure(figsize=(14,5))
plt.subplot(121)
plt.grid(axis='y')

plt.plot(f,dB(fkx), 'r-', lw=1)
plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
plt.xlim(xlim_start,xlim_end)
#plt.axvspan(0.099,0.101, color='gray', alpha=0.1)

#plt.ylim(-5,35)

plt.ylabel('power spectrum magnitude ($10log10$)')
plt.xlabel('frequency (Hz)')
plt.title('power spectral density of x')
plt.gcf().tight_layout()

plt.subplot(122)
plt.grid(axis='y')
plt.plot(f,dB(fky), 'b-', lw=1)
plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
#plt.axvspan(0.099,0.101, color='gray', alpha=0.1)
plt.xlim(xlim_start,xlim_end)
#plt.ylim(-5,35)

plt.ylabel('power spectrum magnitude ($10log10$)')
plt.xlabel('frequency (Hz)')
plt.title('power spectral density of y')
plt.gcf().tight_layout()

# %% [markdown]
# Timeseries of x contains noise and two components relating to frequency 0.1 and 0.047 Hz. Psd of y only contains one component related to frequency 0.1 Hz. Next we plot the cross spectral density and the corresponding coherence, which is the normalised csd.

# %%
plt.figure(figsize=(14,5))
plt.subplot(121)
plt.grid(axis='y')

plt.plot(f,dB(cxy), 'g-', lw=1)
plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
#plt.axvspan(0.099,0.101, color='gray', alpha=0.1)
plt.xlim(xlim_start,xlim_end)
#plt.ylim(-5,35)

plt.ylabel('cross-power spectrum magnitude ($10log10$)')
plt.xlabel('frequency (Hz)')
plt.title('cross spectral density of x and y')
plt.gcf().tight_layout()

plt.subplot(122)
plt.grid(axis='y')

plt.plot(f,coh, 'y')

plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
#plt.axvspan(0.099,0.101, color='gray', alpha=0.1)
plt.xlim(xlim_start,xlim_end)
plt.ylim(0,1.01)

plt.ylabel('coherence')
plt.xlabel('frequency (Hz)')
plt.title('coherence of x and y')

plt.gcf().tight_layout()

# %% [markdown]
# Cross spectral density shows single peak for 0.1 Hz and the other peak of 0.047 Hz is still visible but weaker. In the coherence plot its visible there is a clear coherence for the 0.1 Hz peak and the two timeseries are near 0 coherent for the frequency of 0.047 Hz. Next we plot the phase spectrum and phase uncertainty seperately.

# %%
plt.figure(figsize=(14,5))
plt.subplot(121)
plt.grid(axis='y')

plt.plot(f,ph, 'm', lw=1)
plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
#plt.axvspan(0.099,0.101, color='gray', alpha=0.1)
plt.xlim(xlim_start,xlim_end)
plt.ylim(-np.pi,np.pi)

plt.ylabel('phase (radian, bounded [$-{\pi}-{\pi}$])')
plt.xlabel('frequency (Hz)')
plt.title('phase between x and y for all frequencies')
plt.gcf().tight_layout()

plt.subplot(122)
plt.grid(axis='y')

plt.plot(f,phif, 'c', lw=1)
plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
#plt.axvspan(0.099,0.101, color='gray', alpha=0.1)
plt.xlim(xlim_start,xlim_end)
plt.ylim(-0.05,3.2)

plt.ylabel('phase uncertainty (radian, bounded [$0-{\pi}$])')
plt.xlabel('frequency (Hz)')
plt.title('phase uncertainty between x and y for all frequencies')
plt.gcf().tight_layout()

# %% [markdown]
# Phase of frequency 0.1 Hz is stable at 1 radian. Phase uncertainty shows high uncertainty for all frequencies excempt frequency corresponding to 0.1 Hz. So by combining the phase and phase uncertainty we get last two plots with phase in radian and phase in time domain units, which are hours this time.

# %%
plt.figure(figsize=(14,5))
plt.subplot(121)
plt.grid(axis='y')
plt.plot(f,ph, 'm')
plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
#plt.axvspan(0.099,0.101, color='gray', alpha=0.1)

plt.fill_between(f,ph,(ph-phif),facecolor='c' ,edgecolor='c', lw=0.0)#, where=(ph-phif)>=-np.pi)
plt.fill_between(f,ph,(ph+phif),facecolor='c' ,edgecolor='c', lw=0.0)

plt.fill_between(f,(ph+2*np.pi),((ph+2*np.pi)-phif), where=(ph-phif)<=-np.pi,
                 facecolor='c' ,edgecolor='c', lw=0.0)
plt.fill_between(f,(ph-2*np.pi),((ph-2*np.pi)+phif), where=(ph+phif)>=np.pi,
                 facecolor='c' ,edgecolor='c', lw=0.0)


plt.xlim(xlim_start,xlim_end)
plt.ylim(-np.pi,np.pi)

plt.ylabel('phase (radian, bounded [$-{\pi}-{\pi}$])')
plt.xlabel('frequency (Hz)')
plt.title('phase between x and y for all frequencies + uncertainty')
plt.gcf().tight_layout()

from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA

rad2time = ph/(2*np.pi*f)
mtcl2time = phif/(2*np.pi*f)
neg_time= np.where(rad2time<0)
dur_cycl = (1/f)
rad2time[neg_time] = rad2time[neg_time]+dur_cycl[neg_time]


ax = host_subplot(122, axes_class=AA.Axes)

p1 = Rectangle((0, 0), 1, 1, fc='c', ec='c')
p2, = ax.plot(f, rad2time, color='m', zorder=5, label='Phase')
p3, = ax.plot(f, dur_cycl, color='gray', linestyle='-.', zorder=5, label='Period')
p4, = ax.plot(f, dur_cycl/2, color='gray', linestyle='--', zorder=5, label='Halve period')

ax.fill_between(f,(rad2time+mtcl2time),(rad2time-mtcl2time), where=(((rad2time+mtcl2time)<dur_cycl)), 
             facecolor='c' ,edgecolor='c', lw=0.0 ,interpolate=True, zorder=4)
ax.fill_between(f,(rad2time-mtcl2time),dur_cycl, where=(((rad2time+mtcl2time)>dur_cycl)),
             facecolor='c' ,edgecolor='c', lw=0.0 ,interpolate=True, zorder=4)
ax.fill_between(f,(rad2time+mtcl2time)-dur_cycl, where=(((rad2time+mtcl2time)>0)),
             facecolor='c' ,edgecolor='c', lw=0.0 ,interpolate=True, zorder=4)
ax.fill_between(f,((rad2time-mtcl2time)+dur_cycl),dur_cycl, where=((rad2time-mtcl2time)<0), 
             facecolor='c' ,edgecolor='c', lw=0.0 ,interpolate=True, zorder=4)

ax.set_xlim([xlim_start,xlim_end])
ax.set_ylim([0,366])
#ax.set_xticks([(1/366),(1./(366./2)),(1./(366./3)),(1./(366./4))])

ax.set_xlabel('frequency (Hz)')
ax.set_ylabel('phase (days)')
ax.set_title('time (days)', loc='left', fontsize=10)

p5= axvspan(vspan_start,vspan_end, color='gray', alpha=0.1, zorder=-1)
#axvspan(0.099,0.101, color='gray', alpha=0.1, zorder=0)

ax2 = ax.twin() # ax2 is responsible for "top" axis and "right" axis
ax2.set_xlabel('phase between x and y for all frequencies + uncertainty')
ax2.set_xticks([0.05,0.1,0.15,0.2])#0., .5*np.pi, np.pi, 1.5*np.pi, 2*np.pi])
ax2.set_xticklabels([str(round(1./0.05, 1)),str(round(1./0.1,1)),str(round(1./0.15,1)),str(round(1./0.2,1))])
ax2.axis["right"].major_ticklabels.set_visible(False)
ax2.xaxis.label.set_size(2)

plt.legend([p2,p3,p4,p1,p5], ['phase-delay','single period','halve period','phase uncertainty estimates', 'frequencies of interest'])
plt.grid(axis='y', zorder=0 )

plt.tight_layout()

plt.show()

# %% [markdown]
# For plot on the right matplotlib shows some glimpses as he found it difficult to plot it perfectly. It's forgiven.
# So to get some results out of the plot. Apply a bandpass filter between 0.099 and 0.101 Hz to see the phase in radian and in hour.

# %%
# frequency index
f_lb = vspan_start
f_ub = vspan_end
f_ix = np.where((f > f_lb) * (f < f_ub))[0]
p_r2t = np.mean(rad2time[f_ix], -1)
p_ph = np.mean(ph[f_ix], -1)
print 'phase in radian is', round(p_ph,2)   
print 'which correspond to',round(p_r2t,2), 'days (',(365-round(p_r2t,2))*-1,')'

# %%
#x_  = 4 * np.sin(2*(np.pi/10)*t)
#y_  = 4 * np.sin(2*(np.pi/10)*t+1)
y0  = 0.10 * np.sin(2*(np.pi/(1./0.0027))*t+1.2)
y1  = 0.10 * np.sin(2*(np.pi/(1./0.0027))*t+1.2-p_ph)
#x1 = 4 * np.sin(2*(np.pi/(1./0.1)*t-p_ph))#ps)
#y1 = 4 * np.sin(2*(np.pi/(1./0.1)*t))
plt.figure(figsize=(7,5))
#plt.subplot(121)
plt.grid()

p1, = plt.plot(t,x, 'k-', alpha=0.3,lw=1, label='precipitation mean')
p2, = plt.plot(t,y, 'k--', alpha=0.3, lw=1, label='NDVI mean')

#plt.plot(t,x1, 'r', lw=1, label='x1')
p3, = plt.plot(t,y0, 'c', lw=1.4, label='annual period precipitation')
p4, = plt.plot(t,y1, 'm--', lw=1.4, label='annual period NDVI')
#plt.plot(t,x2, 'b-', lw=1, label='x2')
#plt.plot(t,y1, 'g.', lw=1, label='y1')
#plt.plot(t,y2, 'm-', lw=1, label='y2')

plt.xlim(0,365)

plt.ylabel('normalised anomaly')
plt.xlabel('day of year')
plt.title('anomaly timeseries + annual period')
plt.ylim(-0.25,0.15)
leg = plt.legend([p1,p3,p2,p4],['precipitation mean','annual period precipitation',
                                'NDVI mean', 'annual period NDVI'],ncol=2, loc=3)
leg.get_frame().set_lw(0.5)
leg.get_frame().set_ec('lightgray')
#leg.get_frame().set_alpha(0.5)
plt.tight_layout()
#plt.savefig(r'C:\Users\lenovo\Documents\HOME\Figures paper//y_anomaly_annual_period', dpi=400)

# %% [markdown]
# That's nice, let's throw everything in one plot. Just for fun

# %%
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA

plt.figure(figsize=(14,7.5))

## PLOT 1
plt.subplot(331)
plt.grid(axis='y')

plt.plot(t,x, 'k-', lw=1, label='x')
plt.plot(t,y, 'k--', lw=1, label='y')

plt.xlim(0,364)
plt.ylim(-0.2,0.2)
plt.yticks([-0.2,-0.1,0,0.1,0.2])
plt.ylabel('normalised anomaly')
plt.xlabel('day of year')
plt.title('anomaly timeseries')
leg = plt.legend(loc=3, frameon=True, ncol=2)
leg.get_frame().set_edgecolor('lightgray')
leg.get_frame().set_lw(0.5)

## PLOT 2
plt.subplot(332)
plt.grid(axis='y')

plt.plot(f,dB(fkx), 'r-', lw=1)
plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
plt.xticks([(1/366),(1./(366./2)),(1./(366./3)),(1./(366./4))],[str(0.0027),str(0.0055),str(0.0082),str(0.0109)])
plt.xlim(xlim_start,xlim_end)
#plt.ylim(-5,35)

plt.ylabel('power ($10log10$)')
plt.xlabel('frequency (Hz)')
plt.title('power spectrum x')
#plt.gcf().tight_layout()

## PLOT 3
plt.subplot(333)
plt.grid(axis='y')
plt.plot(f,dB(fky), 'b-', lw=1)
plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
plt.xticks([(1/366),(1./(366./2)),(1./(366./3)),(1./(366./4))],[str(0.0027),str(0.0055),str(0.0082),str(0.0109)])
plt.xlim(xlim_start,xlim_end)
#plt.ylim(-5,35)

plt.ylabel('power ($10log10$)')
plt.xlabel('frequency (Hz)')
plt.title('power spectrum y')

## PLOT 4
plt.subplot(334)
plt.grid(axis='y')

plt.plot(f,dB(cxy), 'g-', lw=1)
plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
plt.xticks([(1/366),(1./(366./2)),(1./(366./3)),(1./(366./4))],[str(0.0027),str(0.0055),str(0.0082),str(0.0109)])
plt.xlim(xlim_start,xlim_end)
#plt.ylim(-5,35)

plt.ylabel('cross-power ($10log10$)')
plt.xlabel('frequency (Hz)')
plt.title('cross-spectrum x/y')
#plt.gcf().tight_layout()

## PLOT 5
plt.subplot(335)
plt.grid(axis='y')

plt.plot(f,coh, 'y')

plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
plt.xticks([(1/366),(1./(366./2)),(1./(366./3)),(1./(366./4))],[str(0.0027),str(0.0055),str(0.0082),str(0.0109)])
plt.xlim(xlim_start,xlim_end)
plt.ylim(0,1.01)

plt.ylabel('coherence')
plt.xlabel('frequency (Hz)')
plt.title('coherence x/y')


## PLOT 6
plt.subplot(336)
plt.grid(axis='y')

plt.plot(f,ph, 'm', lw=1)
plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
plt.yticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
           ['$-\pi$', r'$-\frac{\pi}{2}$', r'$0$', r'$\frac{\pi}{2}$', r'$\pi$'])
plt.xticks([(1/366),(1./(366./2)),(1./(366./3)),(1./(366./4))],[str(0.0027),str(0.0055),str(0.0082),str(0.0109)])
plt.xlim(xlim_start,xlim_end)
plt.ylim(-np.pi,np.pi)

plt.ylabel('phase (radian)')
plt.xlabel('frequency (Hz)')
plt.title('phase spectrum x/y')
#plt.gcf().tight_layout()

## PLOT 7
plt.subplot(337)
plt.grid(axis='y')

plt.plot(f,phif, 'c', lw=1)
plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
plt.yticks([0,1./4*np.pi, np.pi/2, 3./4*np.pi,np.pi],
           [r'$0$', r'$\frac{1}{4}\pi$', r'$\frac{\pi}{2}$', r'$\frac{3}{4}\pi$', r'$\pi$'])
plt.xticks([(1/366),(1./(366./2)),(1./(366./3)),(1./(366./4))],[str(0.0027),str(0.0055),str(0.0082),str(0.0109)])
plt.xlim(xlim_start,xlim_end)
plt.ylim(-0.05,3.2)

plt.ylabel('phase uncert (radian)')
plt.xlabel('frequency (Hz)')
plt.title('phase uncertainty x/y')

## PLOT 8
plt.subplot(338)
plt.grid(axis='y')
plt.plot(f,ph, 'm')

plt.fill_between(f,ph,(ph-phif),facecolor='c' ,edgecolor='c', lw=0.0)#, where=(ph-phif)>=-np.pi)
plt.fill_between(f,ph,(ph+phif),facecolor='c' ,edgecolor='c', lw=0.0)

plt.fill_between(f,(ph+2*np.pi),((ph+2*np.pi)-phif), where=(ph-phif)<=-np.pi,
                 facecolor='c' ,edgecolor='c', lw=0.0)
plt.fill_between(f,(ph-2*np.pi),((ph-2*np.pi)+phif), where=(ph+phif)>=np.pi,
                 facecolor='c' ,edgecolor='c', lw=0.0)

plt.axvspan(vspan_start,vspan_end, color='gray', alpha=0.1)
plt.yticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
           ['$-\pi$', r'$-\frac{\pi}{2}$', r'$0$', r'$\frac{\pi}{2}$', r'$\pi$'])

plt.xticks([(1/366),(1./(366./2)),(1./(366./3)),(1./(366./4))],[str(0.0027),str(0.0055),str(0.0082),str(0.0109)])


plt.xlim(xlim_start,xlim_end)
plt.ylim(-np.pi,np.pi)

plt.ylabel('phase (radian)')
plt.xlabel('frequency (Hz)')
plt.title('phase spectrum x/y + uncertainty')
#plt.gcf().tight_layout()



## PLOT 9
rad2time = ph/(2*np.pi*f)
mtcl2time = phif/(2*np.pi*f)
neg_time= np.where(rad2time<0)
dur_cycl = (1/f)
rad2time[neg_time] = rad2time[neg_time]+dur_cycl[neg_time]


ax = host_subplot(339, axes_class=AA.Axes)

p1 = Rectangle((0, 0), 1, 1, fc='c', ec='c')
p2, = ax.plot(f, rad2time, color='m', zorder=5, label='Phase')
p3, = ax.plot(f, dur_cycl, color='gray', linestyle='-.', zorder=5, label='Period')
p4, = ax.plot(f, dur_cycl/2, color='gray', linestyle='--', zorder=5, label='Halve period')

ax.fill_between(f,(rad2time+mtcl2time),(rad2time-mtcl2time), where=(((rad2time+mtcl2time)<dur_cycl)), 
             facecolor='c' ,edgecolor='c', lw=0.0 ,interpolate=True, zorder=4)
ax.fill_between(f,(rad2time-mtcl2time),dur_cycl, where=(((rad2time+mtcl2time)>dur_cycl)),
             facecolor='c' ,edgecolor='c', lw=0.0 ,interpolate=True, zorder=4)
ax.fill_between(f,(rad2time+mtcl2time)-dur_cycl, where=(((rad2time+mtcl2time)>0)),
             facecolor='c' ,edgecolor='c', lw=0.0 ,interpolate=True, zorder=4)
ax.fill_between(f,((rad2time-mtcl2time)+dur_cycl),dur_cycl, where=((rad2time-mtcl2time)<0), 
             facecolor='c' ,edgecolor='c', lw=0.0 ,interpolate=True, zorder=4)

ax.set_xlim([xlim_start,xlim_end])
ax.set_ylim([0,365])
ax.set_xticks([(1/366),(1./(366./2)),(1./(366./3)),(1./(366./4))])
ax.set_xticklabels([str(0.0027),str(0.0055),str(0.0082),str(0.0109)])

ax.set_xlabel('frequency (Hz)')
ax.set_ylabel('phase (day)')
ax.set_title('t (month)', loc='left', fontsize=10)

p5= axvspan(vspan_start,vspan_end, color='gray', alpha=0.1, zorder=-1)
#axvspan(0.099,0.101, color='gray', alpha=0.1, zorder=0)

ax2 = ax.twin() # ax2 is responsible for "top" axis and "right" axis
ax2.set_xlabel('phase spectrum x/y + uncertainty')
ax2.set_xticks([(1/366),(1./(366./2)),(1./(366./3)),(1./(366./4))])
ax2.set_xticklabels([str(12),str(6),str(4),str(3)])
ax2.axis["right"].major_ticklabels.set_visible(False)
ax2.xaxis.label.set_size(2)


lg = plt.legend([p3,p4], ['single period','halve period'], ncol=1)
lg.get_frame().set_ec('lightgray')
lg.get_frame().set_lw(0.5)
plt.grid(axis='y', zorder=0 )

plt.gcf().tight_layout()
plt.savefig(r'C:\Users\lenovo\Documents\HOME\Figures paper//y_psdcsdcohphase.png', dpi=400)

# frequency index
f_lb = vspan_start
f_ub = vspan_end
f_ix = np.where((f > f_lb) * (f < f_ub))[0]
p_r2t = np.mean(rad2time[f_ix], -1)
p_ph = np.mean(ph[f_ix], -1)
print 'phase in radian is', round(p_ph,2)
print 'which correspond to', round(p_r2t,2), 'day'
