# %% [markdown]
# #### 1. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#Wrapper-file-to-read-GPCP-data-into-python,-include-some-byte-swapping-from-big-endian-system-to-little-endian-system">Wrapper file to read GPCP data into python, include some byte-swapping from big-endian system to little-endian system</a>
#
#
# 2. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#Function-to-save-raster-as-tif-file">
# Function to save raster as tif file</a>
#
# 3. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#First-open-GPCP-raw-data-and-convert-to-numpy-array,-roll-array-180-degrees,-set-projection-and-extent-and-save-to-tif-file">First open GPCP raw data and convert to numpy array, roll array 180 degrees, set projection and extent and save to tif file</a>
#
# 4. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#Rename-original-files-which-are-YYYY-MM-DD-to-YYYY-DDD">
# Rename original files which are YYYY MM DD to YYYY DDD</a>
#
# 5. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#Then-create-octad-data-files,-calculates-the-mean-for-each-8-days">
# Then create octad data files, calculates the mean for each 8 days</a>
#
# 6. <a href="
# http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#Next-step-is-to-create-annual-mean-data.-So-take-the-DOY-of-each-year-and-calculate-the-mean">
# Next step is to create annual mean data. So take the DOY of each year and calculate the mean</a>
#
# 7. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#Create-accumulated-data-files-for-GPCP_annualMean-data">
# Create accumulated data files for GPCP_annualMean data</a>
#
# 8. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#Next-step-is-to-calculate-the-anomaly:-(This-is-for-the-8-day-interval)">
# Next step is to calculate the anomaly: (This is for the 8 day interval)</a>
#
# 9. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#Find-the-most-minimum-and-maximum-values-over-the-set-period.-Save-as-new-raster-file.-(This-is-for-the-8-day-interval)">Find the most minimum and maximum values over the set period. Save as new raster file. (This is for the 8 day interval)</a>
#
# 10. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#Calculate-normalized-anomaly-index-by-dividing-anomaly-over-(max---min).-(This-is-for-the-8-day-interval)">
# Calculate normalized anomaly index by dividing anomaly over (max - min). (This is for the 8 day interval)
# </a>
#
# 11. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#Calculate-accumulation-with-a-30-day-window-period-with-a-8-day-stepsize,-including-4-measurements.">Calculate accumulation with a 30 day window period with a 8 day stepsize, including 4 measurements.</a>
#
# 12. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#Accumulate-the-output-of-the-30-day-moving-window-for-each-year">Accumulate the output of the 30-day moving window for each year</a>
#
# 13. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#Annual-Mean-of-30-day-moving-window">Annual Mean of 30-day moving window</a>
#
# 14. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#Annual-mean-of-30-day-window-accumulated-annually">
# Annual mean of 30-day window accumulated annually</a>
#
# 15. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#Anomaly-for-30-day-moving-window">Anomaly for 30-day moving window</a>
#
# 16. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#Find-the-most-minimum-and-maximum-values-over-the-set-period.-Save-as-new-raster-file.-(This-is-for-the-30-day-moving-window)">
# Find the most minimum and maximum values over the set period. Save as new raster file. (This is for the 30-day moving window)</a>
#
# 17. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#TYPE-I-**-Calculate-normalized-anomaly-index-by-dividing-anomaly-over-(max---min).-(This-is-for-the-30-day-moving-window)">
# TYPE I ** Calculate normalized anomaly index by dividing anomaly over (max - min). (This is for the 30-day moving window)</a>
#
# 18. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#calculate-longterm-mean-of-anomaly--calculate-longterm-standard-deviation-of-anomaly">
# calculate longterm mean of anomaly calculate longterm standard deviation of anomaly</a>
#
# 19. <a href="http://127.0.0.1:8888/notebooks/gpcp/THE%20BIG%20GPCP%20IPY%20NOTEBOOK%2C%20FROM%20SAV%201DD%20TO%20END%20PRODUCT.ipynb#TYPE-II-Calculate-normalized-anomaly-index-by-anomaly---anomaly_longterm-mean-/-anomaly_longterm-std.-(This-is-for-the-30-day-moving-window)">TYPE II ** Calculate normalized anomaly index by anomaly - anomaly_longterm-mean / anomaly_longterm-std. (This is for the 30-day moving window)</a>
#
# 20. <a href="">text</a>
#
# 21. <a href="">text</a>

# %%
from scipy.io import readsav
from mattijn import dikkelul
from mattijn import dikkelul as dl
from mattijn import read_1dd
import os
import pandas as pd
from osgeo import gdal, osr
import sys
import numpy as np

# %% [markdown]
# # Wrapper file to read GPCP data into python, include some byte-swapping from big-endian system to little-endian system

# %%
def read_1dd_num_days(filepath):
    """    
    The "days" metadata is days=1-nn, where nn is the number
    of days in the month, which is what we want for the 3rd 
    dimension. Hence the "+7".    
    """
    
    num_lon = 360
    with open(filepath, 'rb') as filein:
        #filein = open(filepath, 'rb')
        header = filein.read(num_lon*4)
        
        header = header.rstrip()
        days = header.find(b'days=')+7
        num_days = int(header[days:days+2])
    return num_days, header


def byte_swap_1DD_struct(filepath, num_days, header): 
    """
    Uses output of read_1dd_num_day to determine if byte-swap is needed
    """
    
    num_lon = 360 # rows
    num_lat = 180 # cols
    
    # see if file is written in big-endian (indicated by Silicon machine)
    if b'Silicon' in header:
        file_byte_order = 'big'
    else:
        file_byte_order = 'little'
    #file_byte_order = 'little' 
    

    if sys.byteorder == 'little' and file_byte_order == 'big':
        
        # open file using big endian dtype and select all values that correspond with to the metadata
        data = np.fromfile(filepath, dtype='>f')[-(num_lon*num_lat*num_days)::]
    else:
        data = np.fromfile(filepath, dtype='f')[-(num_lon*num_lat*num_days)::]
        
    data = data.reshape((num_days,num_lat,num_lon))
    
    return data


def read_1DD(filepath, inheader=False):
    """
    The main procedure; read both 
    header and data, and swap bytes if needed.
    
    input: filepath
    inheader: True/False (False is default), determines if header is included in output
    
    output:
    if inheader = False, no header is included, output is numpy array (default)
    if inheader = True, header is included output is dictionary
    """
    
    num_days, header = read_1dd_num_days(filepath) 
    data = byte_swap_1DD_struct(filepath, num_days, header)
    
    if inheader == False:
        struct = data
    elif inheader == True:
        struct = { 'header': header, 'data': data }
    return struct


def read_1DD_header(filepath):    
    """    
     Just read the header
    """
    
    num_lon = 360
    with open(filepath, 'rb') as filein:
        #filein = open(filepath, 'rb')
        header = filein.read(num_lon*4)        
        header = header.rstrip()
    return header

# %% [markdown]
# # Function to save raster as tif file

# %%
def saveRaster(path, array, proj, gt, ds, datatype=6, formatraster="GTiff", nan=-99999.): 
    """
    Datatypes:
    unknown = 0
    byte = 1
    unsigned int16 = 2
    signed int16 = 3
    unsigned int32 = 4
    signed int32 = 5
    float32 = 6
    float64 = 7
    complex int16 = 8
    complex int32 = 9
    complex float32 = 10
    complex float64 = 11
    float32 = 6, 
    signed int = 3
    
    Formatraster:
    GeoTIFF = GTiff
    Erdas = HFA (output = .img)
    OGC web map service = WMS
    png = PNG
    """
    # Set Driver
    format_ = formatraster #save as format
    driver = gdal.GetDriverByName( format_ )
    driver.Register()
    
    # Set Metadata for Raster output
    cols = struct[j,:,:].shape[1] # dsSource.RasterXSize 
    rows = struct[j,:,:].shape[0] # dsSource.RasterYSize 
    bands = 1
    datatype = datatype#band.DataType
    
    # Set Projection for Raster
    outDataset = driver.Create(path, cols, rows, bands, datatype)
    #geoTransform = dsSource.GetGeoTransform()
    outDataset.SetGeoTransform(gt)
    #proj = dsSource.GetProjection()
    outDataset.SetProjection(proj)
    
    # Write output to band 1 of new Raster and write NaN value
    outBand = outDataset.GetRasterBand(1)
    outBand.SetNoDataValue(nan)
    outBand.WriteArray(array) #save input array
    #outBand.WriteArray(dem)
    
    # Close and finalise newly created Raster
    #F_M01 = None
    outBand = None
    proj = None
    geoTransform = None
    outDataset = None
    driver = None
    datatype = None
    bands = None
    rows = None
    cols = None
    driver = None
    array = None

# %% [markdown]
# # First open GPCP raw data and convert to numpy array, roll array 180 degrees, set projection and extent and save to tif file

# %%
ds = gdal.Open(r'H:\Data\VUA_AMSR-E\2009//LPRM-AMSR_E_L3_A_SM3_20090101_SM_C.tif')
proj = ds.GetProjection()
gt = (-179.875, 1., 0., 89.875, 0., -1.)

folderin = r'E:\Data\GPCP'
folderout = r'D:\Data\GPCP_tif//'
gpcpfiles = dikkelul.FilesFolder(folderin)

for i in gpcpfiles:
    
    #print (i)
    
    #data = readsav(i)
    data = read_1DD(i)
    struct = np.roll(data, 180, axis=2) # original data start at 0 degrees greewhich, move to -180
        
    print (struct.shape)
    
    for j in range(struct.shape[0]):        
        
        #print (j)
        out_file = 'GPCP_'+i[-6::]+str(j+1).zfill(2)+'.tif'
        path = folderout+out_file  
        
        print (path)
        print ( 'max', struct[j,:,:].max(), 'min', struct[j,:,:].min() )
        
        array = struct[j,:,:].astype(np.float32)
        saveRaster(path, array, proj, gt, ds, datatype=6, formatraster="GTiff", nan=-99999.)

# %% [markdown]
# # Rename original files which are YYYY MM DD to YYYY DDD

# %%
path = r'D:\Data\GPCP_tif'
files = dikkelul.FilesFolder(path, '.tif')

import os

for root, dirs, files in os.walk(r'D:\Data\GPCP_tif'):

    for fil in files:
        #print (fil)
        # get datetime from original file YYYY, MM, DD
        dt = datetime.datetime(int(fil[-12:-8]), int(fil[-8:-6]), int(fil[-6:-4])).timetuple()
        
        # output datetime is YYYY DDD
        da = str('GPCP_')+str(dt.tm_year)+str(dt.tm_yday).zfill(3)+'.tif'
        #print (da)
        print (root + os.sep + fil)
        print (root + os.sep + da)
        os.rename(root + os.sep + fil, root + os.sep + da)

# %% [markdown]
# # Then create octad data files, calculates the mean for each 8 days

# %%
path = r'D:\Data\GPCP_tif'
files = dikkelul.FilesFolder(path, '.tif')

ds = gdal.Open(files[0])
arr = ds.ReadAsArray()
band = ds.GetRasterBand(1)
nan = band.GetNoDataValue()
if nan == None:
    nan = -99999.0
base_array = np.full_like(arr, nan)
base_array.shape

for m in range(2000,2014):
    year = []
    for n in files:
        if int(n[-11:-7]) == m:
            year.append(n)
    print (m)
    #print (len(year))
    
#    if len(year)== 365:
    for i in range(8, 369,8):
        
        # prepare for next for loop
        # first set range
        
        start = i - 8
        end = i
        print ('i', i)
        
        # then set empy base array plus counter            
        base_array = np.full_like(arr, nan)
        base_array = base_array[None]
        #base_array = np.empty_like(arr, dtype=float)
        #base_array = np.ma.masked_equal(base_array, -99999.)
        count = 0
        
        for j in range(start,end):
            
            # first try if raster is available
            # what shall we do? sumation or mean? now it's mean
            
            try:
                print (year[j])
                array = gdal.Open(year[j]).ReadAsArray()
                array = array[None]
                base_array = np.vstack((base_array, array))
                #array = np.ma.masked_equal(array, -99999.)                
                #base_array += array                
            except IndexError:
                pass
            continue
                
        # mask nan values and calculate mean over axis 0
        base_array = np.ma.masked_values(base_array, nan)
        base_array = base_array.mean(axis=0)
        #base_array = base_array.sum(axis=0) # DO THIS for accumulation
        
        folder = r'D:\Data\GPCP_doy8DayMean//'
        filename = 'GPCP_'+str(m)+str(start+1).zfill(3)+'.tif'
        path = folder+filename
        print (path)
        #print(base_array.data)
        dikkelul.saveRaster(path, base_array.data, ds, 6, nan=nan)                

        base_array = None
        array = None
    year = None

# %% [markdown]
# # Next step is to create annual mean data. So take the DOY of each year and calculate the mean

# %%
path = r'D:\Data\GPCP_doy8DayMean'
files = dikkelul.FilesFolder(path, '.tif')

outfolder = r'D:\Data\GPCP_annualMean//'

ds = gdal.Open(files[0])
band = ds.GetRasterBand(1)
barray = band.ReadAsArray()
nan = band.GetNoDataValue()

outfolder = r'D:\Data\GPCP_annualMean//'

for i in range(1,366,8):
    #print (i)
    base = np.full_like(barray, nan)
    base = base[None] # add another dimenstion for vstack
    for fil in files:    
        
        if int(fil[-7:-4]) == i:
            print (fil)
            array = gdal.Open(fil).ReadAsArray().astype(float)

            array = array[None] # add another dimension for vstack
            base = np.vstack((base,array)) # vstack all rasters with same doy
            
    # mask where value is nan
    base = np.ma.masked_equal(base, nan)
    base = np.mean(base, axis=0)
    
    outpath = outfolder+'GPCP_'+str(i).zfill(3)+'.tif'
    print (outpath)
    dikkelul.saveRaster(outpath, base, ds, 6, nan=nan)

# %% [markdown]
# # Create accumulated data files for GPCP_annualMean data

# %%
path = r'D:\Data\GPCP_annualMean'
files = dikkelul.FilesFolder(path, '.tif')

ds = gdal.Open(files[0])
band = ds.GetRasterBand(1)
barray = band.ReadAsArray()
nan = band.GetNoDataValue()

outfolder = r'D:\Data\GPCP_accumulatedMean//'

base = np.full_like(barray, nan)
base = base[None] # add another dimenstion for vstack
for fil in files:    
    #print (fil)
    array = gdal.Open(fil).ReadAsArray().astype(float)
    array = array[None] # add another dimension for vstack
    base = np.vstack((base,array)) # vstack all rasters with same doy
        
    # mask where value is nan
    base = np.ma.masked_equal(base, nan)        
    base = np.sum(base, axis=0) # calculate sum
    
    outpath = outfolder+fil[-12::]
    print (outpath)
    dikkelul.saveRaster(outpath, base, ds, 6, nan=nan)
    
    # set values for new loop
    base = base.data
    base = base[None]

# %% [markdown]
# # Next step is to calculate the anomaly:
# (This is for the 8 day interval)

# %%
files_annual = dl.FilesFolder(r'D:\Data\GPCP_annualMean')
files_year = dl.FilesFolder(r'D:\Data\GPCP_doy8DayMean')

ds = gdal.Open(files_annual[0])
band = ds.GetRasterBand(1)
nan = band.GetNoDataValue()
print (nan)

for i in files_annual:
    fil_annual = gdal.Open(i).ReadAsArray().astype(float)
    fil_annual = np.ma.masked_values(fil_annual, nan)
    print (i, fil_annual.max())
    for j in files_year:
        if i[-7:-4] == j[-7:-4]:
                        
            fil_year = gdal.Open(j).ReadAsArray().astype(float)
            fil_year = np.ma.masked_values(fil_year, nan)
            
            print (j, fil_year.max())
            # subtract meanDOY from each yearDOY
            anomaly = fil_year - fil_annual
            
            path_anomaly = j.replace('GPCP_doy8DayMean', 'GPCP_anomaly')
            print('anomaly', path_anomaly, anomaly.max())
            
            dl.saveRaster(path_anomaly, anomaly, ds, datatype=6, nan=nan)

# %% [markdown]
# # Find the most minimum and maximum values over the set period. Save as new raster file. (This is for the 8 day interval)

# %%
files = dl.FilesFolder(r'D:\Data\GPCP_anomaly')
ds = gdal.Open(files[0])
band = ds.GetRasterBand(1)
nan = band.GetNoDataValue()

# Open two basefiles, one for max one for min, mask arrays where NaN
max_ds = gdal.Open(files[0]).ReadAsArray()
max_ds = np.ma.masked_values(max_ds, nan)
min_ds = gdal.Open(files[0]).ReadAsArray()
min_ds = np.ma.masked_values(min_ds, nan)

for i in files:
    
    # Open file, mask where NaN. 
    ds_comp = gdal.Open(i).ReadAsArray()
    ds_comp = np.ma.masked_values(ds_comp, nan)
    
    # Compare two arrays and returns a new array containing the element-wise maxima
    max_ds = np.maximum(max_ds, ds_comp)
    min_ds = np.minimum(min_ds, ds_comp)
    
    print (max_ds.max(), min_ds.min())    
    
dl.saveRaster(r'D:\Data\GPCP_maxmin//GPCP_max.tif', max_ds.data, ds, datatype=6, nan=nan)
dl.saveRaster(r'D:\Data\GPCP_maxmin//GPCP_min.tif', min_ds.data, ds, datatype=6, nan=nan)

# %% [markdown]
# # Calculate normalized anomaly index by dividing anomaly over (max - min). (This is for the 8 day interval)

# %%
pathmax = r'D:\Data\GPCP_maxmin//GPCP_max.tif'
pathmin = r'D:\Data\GPCP_maxmin//GPCP_min.tif'
pathano = r'D:\Data\GPCP_anomaly'

fileano = dl.FilesFolder(pathano, '.tif')

# open basefile
ds = gdal.Open(fileano[0])
band = ds.GetRasterBand(1)
nan = band.GetNoDataValue()

# open max and min files, mask where NaN
maxin = gdal.Open(pathmax).ReadAsArray()
maxin = np.ma.masked_values(maxin, nan)
minin = gdal.Open(pathmin).ReadAsArray()
minin = np.ma.masked_values(minin, nan)

for i in fileano:
    # open anomaly and mask where NaN
    ano = gdal.Open(i).ReadAsArray()
    ano = np.ma.masked_values(ano, nan)
    
    # normalized anomaly index
    normano = ano / (maxin - minin)
    
    print ('max', normano.max(), 'min', normano.min(), 'std', normano.std())
    path = r'D:\Data\GPCP_anomalyNorm'+i[-17::]
    print (path)
    
    dl.saveRaster(path, normano.data, ds, datatype=6, nan=nan)

# %% [markdown]
# # Calculate accumulation with a 30 day window period with a 8 day stepsize, including 4 measurements.

# %%
path = r'D:\Data\GPCP_doy8DayMean'
file8daymean = dl.FilesFolder(path, '.tif')
#file8daymean = file[0:-43]

# open basefile
ds = gdal.Open(file8daymean[0])
band = ds.GetRasterBand(1)
nan = band.GetNoDataValue()
if nan == None:
    nan = -99999.0
arr = band.ReadAsArray()
    
for start in range(1,366,8):
    
    # set start and end doy    
    end = start + 30
    print ('\nstart', str(start).zfill(3), 'end', str(end).zfill(3))
    
    for year in range(2000,2014):
        print (year)
        
        # select all files for each year        
        annual = []        
        for fil in file8daymean:
            if int(fil[-11:-7]) == year:
                annual.append(fil)
        
        # create base_array        
        base_array = np.full_like(arr, nan)        
        base_array = base_array[None]
        
        # for each year within start and end doy hstack all available rasters        
        for filannual in annual:
            if start <= int(filannual[-7:-4]) <= end:
                
                # first try if raster is available                
                try:
                    print (filannual)
                    array = gdal.Open(filannual).ReadAsArray()
                    array = array[None]
                    base_array = np.vstack((base_array, array))
         
                except IndexError:
                    pass
                continue
                
            # mask nan values and calculate sum/accumulation over axis 0        
        base_array = np.ma.masked_values(base_array, nan)
        base_array = base_array.mean(axis=0) # try '.mean' or '.sum' and check results
        print ('max',base_array.max(),'min', base_array.min(), 'std', base_array.std() )

        # set outpath
        folder = r'D:\Data\GPCP_30acc//'
        filename = 'GPCP_'+str(year)+str(start).zfill(3)+'.tif'
        path = folder+filename
        print (path)

        #print(base_array.data)
        #dikkelul.saveRaster(path, base_array.data, ds, 6, nan=nan)                

        base_array = None
        array = None
    year = None

# %% [markdown]
# # Accumulate the output of the 30-day moving window for each year

# %%
path = r'D:\Data\GPCP_30acc'
files = dl.FilesFolder(path, '.tif')

# open basefile
ds = gdal.Open(files[0])
band = ds.GetRasterBand(1)
nan = band.GetNoDataValue()
if nan == None:
    nan = -99999.0
arr = band.ReadAsArray()
print ('gt:', ds.GetGeoTransform(), '\nproj', ds.GetProjection(), '\nnan', nan )

for year in range(2000,2014):
    print ('\n',year)

    # select all files for each year        
    annual = []        
    for fil in files:
        if int(fil[-11:-7]) == year:
            annual.append(fil)

    # create base_array        
    base_array = np.full_like(arr, nan)        
    base_array = base_array[None]

    for i in annual:
        print ('in', i)
        array = gdal.Open(i).ReadAsArray()
        array = array[None]
        
        base_array = np.vstack((base_array, array))

        # mask nan values and calculate sum/accumulation over axis 0        
        base_array = np.ma.masked_values(base_array, nan)
        #base_array = base_array.mean(axis=0)
        base_array = base_array.sum(axis=0)

        print ('max',base_array.max(),'min', base_array.min(), 'std', base_array.std(), 'mean', base_array.mean() )

        # set outpath
        folder = r'D:\Data\GPCP_30acc_AnnualAcc//'
        filename = i[-16::]
        path = folder+filename
        print ('out', path)

        #print(base_array.data)
        dl.saveRaster(path, base_array.data, ds, 6, nan=nan)        
        base_array = base_array[None]

# %% [markdown]
# # Annual Mean of 30-day moving window

# %%
path = r'D:\Data\GPCP_30acc'
files = dl.FilesFolder(path, '.tif')
files = files[0:-43]

ds = gdal.Open(files[0])
band = ds.GetRasterBand(1)
barray = band.ReadAsArray()
nan = band.GetNoDataValue()

for i in range(1,366,8):
    #print (i)
    base = np.full_like(barray, nan)
    base = base[None] # add another dimenstion for vstack
    for fil in files:    
        
        if int(fil[-7:-4]) == i:
            print (fil)
            array = gdal.Open(fil).ReadAsArray().astype(float)

            array = array[None] # add another dimension for vstack
            base = np.vstack((base,array)) # vstack all rasters with same doy
            
    # mask where value is nan
    base = np.ma.masked_equal(base, nan)
    basestd = np.std(base, axis=0) #unhash for standard deviation calculation
    basemean = np.mean(base, axis=0)
    
    outfoldermean = r'D:\Data\GPCP_30acc_annualMean//' #replace 'GPCP_30acc_annualMean' with 'GPCP_30acc_annualStd' for standard deviation folder
    outfolderstd = r'D:\Data\GPCP_30acc_annualStd//'
    
    outpathmean = outfoldermean+'GPCP_'+str(i).zfill(3)+'.tif'
    outpathstd = outfolderstd+'GPCP_'+str(i).zfill(3)+'.tif'
    print (outpathmean, outpathstd)
    
    dl.saveRaster(outpathmean, basemean.data, ds, 6, nan=nan)
    dl.saveRaster(outpathstd, basestd.data, ds, 6, nan=nan)

# %% [markdown]
# # Annual mean of 30-day window accumulated annually

# %%
path = r'D:\Data\GPCP_30acc_annualMean'
files = dl.FilesFolder(path, '.tif')

# open basefile
ds = gdal.Open(files[0])
band = ds.GetRasterBand(1)
nan = band.GetNoDataValue()
if nan == None:
    nan = -99999.0
arr = band.ReadAsArray()

# create base_array        
base_array = np.full_like(arr, nan)        
base_array = base_array[None]

print ('gt:', ds.GetGeoTransform(), '\nproj', ds.GetProjection(), '\nnan', nan )


for i in files:
    print ('in', i)
    array = gdal.Open(i).ReadAsArray()
    array = array[None]

    base_array = np.vstack((base_array, array))

    # mask nan values and calculate sum/accumulation over axis 0        
    base_array = np.ma.masked_values(base_array, nan)
    #base_array = base_array.mean(axis=0)
    base_array = base_array.sum(axis=0)

    print ('max',base_array.max(),'min', base_array.min(), 'std', base_array.std(), 'mean', base_array.mean() )

    # set outpath
    folder = r'D:\Data\GPCP_30acc_annualMeanAnnualAcc//'
    filename = i[-12::]
    path = folder+filename
    print ('out', path)

    #print(base_array.data)
    dl.saveRaster(path, base_array.data, ds, 6, nan=nan)        
    base_array = base_array[None]

base_array = None
array = None

# %% [markdown]
# # Anomaly for 30-day moving window

# %%
files_annual = dl.FilesFolder(r'D:\Data\GPCP_30acc_annualMean', '.tif')
files_year = dl.FilesFolder(r'D:\Data\GPCP_30acc', '.tif')

ds = gdal.Open(files_annual[0])
band = ds.GetRasterBand(1)
nan = band.GetNoDataValue()
print (nan)

for i in files_annual:
    fil_annual = gdal.Open(i).ReadAsArray().astype(float)
    fil_annual = np.ma.masked_values(fil_annual, nan)
    print ('\n',i, fil_annual.max())
    for j in files_year:
        if i[-7:-4] == j[-7:-4]:
                        
            fil_year = gdal.Open(j).ReadAsArray().astype(float)
            fil_year = np.ma.masked_values(fil_year, nan)
            
            print (j, fil_year.max())
            # subtract meanDOY from each yearDOY
            anomaly = fil_year - fil_annual
            
            path_anomaly = j.replace('GPCP_30acc', 'GPCP_30acc_anomaly')
            print('anomaly', path_anomaly, anomaly.max())
            
            dl.saveRaster(path_anomaly, anomaly, ds, datatype=6, nan=nan)

# %% [markdown]
# # Find the most minimum and maximum values over the set period. Save as new raster file. (This is for the 30-day moving window)

# %%
files = dl.FilesFolder(r'D:\Data\GPCP_30acc')
ds = gdal.Open(files[0])
band = ds.GetRasterBand(1)
nan = band.GetNoDataValue()

# Open two basefiles, one for max one for min, mask arrays where NaN
max_ds = gdal.Open(files[0]).ReadAsArray()
max_ds = np.ma.masked_values(max_ds, nan)
min_ds = gdal.Open(files[0]).ReadAsArray()
min_ds = np.ma.masked_values(min_ds, nan)

for i in files:
    
    # Open file, mask where NaN. 
    ds_comp = gdal.Open(i).ReadAsArray()
    ds_comp = np.ma.masked_values(ds_comp, nan)
    
    # Compare two arrays and returns a new array containing the element-wise maxima
    max_ds = np.maximum(max_ds, ds_comp)
    min_ds = np.minimum(min_ds, ds_comp)
    
    print (max_ds.max(), min_ds.min())    
    
dl.saveRaster(r'D:\Data\GPCP_30acc_maxmin//GPCP_30acc_max.tif', max_ds.data, ds, datatype=6, nan=nan)
dl.saveRaster(r'D:\Data\GPCP_30acc_maxmin//GPCP_30acc_min.tif', min_ds.data, ds, datatype=6, nan=nan)

# %% [markdown]
# # TYPE I ** Calculate normalized anomaly index by dividing anomaly over (max - min). (This is for the 30-day moving window)

# %%
pathmax = r'D:\Data\GPCP_30acc_maxmin//GPCP_30acc_max.tif'
pathmin = r'D:\Data\GPCP_30acc_maxmin//GPCP_30acc_min.tif'
pathano = r'D:\Data\GPCP_anomaly'

fileano = dl.FilesFolder(pathano, '.tif')

# open basefile
ds = gdal.Open(fileano[0])
band = ds.GetRasterBand(1)
nan = band.GetNoDataValue()

# open max and min files, mask where NaN
maxin = gdal.Open(pathmax).ReadAsArray()
maxin = np.ma.masked_values(maxin, nan)
minin = gdal.Open(pathmin).ReadAsArray()
minin = np.ma.masked_values(minin, nan)

for i in fileano:
    # open anomaly and mask where NaN
    ano = gdal.Open(i).ReadAsArray()
    ano = np.ma.masked_values(ano, nan)
    
    # normalized anomaly index
    normano = ano / (maxin - minin)
    
    print ('max', normano.max(), 'min', normano.min(), 'std', normano.std(), 'mean', normano.mean())
    path = r'D:\Data\GPCP_30acc_anomalyNorm'+i[-17::]
    print (path)
    
    dl.saveRaster(path, normano.data, ds, datatype=6, nan=nan)

# %% [markdown]
# # calculate longterm mean of anomaly
# calculate longterm standard deviation of anomaly

# %%
# ____________________________
# MEAN

path = r'D:\Data\GPCP_30acc_annualMean'
files = dl.FilesFolder(path, '.tif')

ds = gdal.Open(files[0])
band = ds.GetRasterBand(1)
barray = band.ReadAsArray()
nan = band.GetNoDataValue()


base = np.full_like(barray, nan)
base = base[None] # add another dimenstion for vstack
for i in range(1,366,8):
    #print (i)
    for fil in files: 
        
        
        if int(fil[-7:-4]) == i:
            print (fil)
            array = gdal.Open(fil).ReadAsArray().astype(float)

            array = array[None] # add another dimension for vstack
            base = np.vstack((base,array)) # vstack all rasters with same doy
            
# mask where value is nan
base = np.ma.masked_equal(base, nan)
#base = np.std(base, axis=0) #unhash for standard deviation calculation
base = np.mean(base, axis=0)

outfolder = r'D:\Data\GPCP_30acc_maxmin//GPCP_30acc_mean.tif' #replace 'GPCP_30acc_annualMean' with 'GPCP_30acc_annualStd' for standard deviation folder
#outfolder = r'D:\Data\GPCP_30acc_maxmin//GPCP_30acc_std.tif'

outpath = outfolder
print (outpath)
print (base.shape)

dl.saveRaster(outpath, base.data, ds, 6, nan=nan)

# ____________________________
# STANDARD DEVIATION

path = r'D:\Data\GPCP_30acc_annualStd'
files = dl.FilesFolder(path, '.tif')

ds = gdal.Open(files[0])
band = ds.GetRasterBand(1)
barray = band.ReadAsArray()
nan = band.GetNoDataValue()


base = np.full_like(barray, nan)
base = base[None] # add another dimenstion for vstack
for i in range(1,366,8):
    #print (i)
    for fil in files: 
        
        
        if int(fil[-7:-4]) == i:
            print (fil)
            array = gdal.Open(fil).ReadAsArray().astype(float)

            array = array[None] # add another dimension for vstack
            base = np.vstack((base,array)) # vstack all rasters with same doy
            
# mask where value is nan
base = np.ma.masked_equal(base, nan)
#base = np.std(base, axis=0) #unhash for standard deviation calculation
base = np.mean(base, axis=0)

outfolder = r'D:\Data\GPCP_30acc_maxmin//GPCP_30acc_std.tif' #replace 'GPCP_30acc_annualMean' with 'GPCP_30acc_annualStd' for standard deviation folder
#outfolder = r'D:\Data\GPCP_30acc_maxmin//GPCP_30acc_std.tif'

outpath = outfolder
print (outpath)
print (base.shape)

dl.saveRaster(outpath, base.data, ds, 6, nan=nan)

# %% [markdown]
# # TYPE II Calculate normalized anomaly index by anomaly / anomaly_longterm-std. (This is for the 30-day moving window)

# %%
pathmean = r'D:\Data\GPCP_30acc_maxmin//GPCP_30acc_mean.tif'
pathstd = r'D:\Data\GPCP_30acc_maxmin//GPCP_30acc_std.tif'
pathano = r'D:\Data\GPCP_30acc_anomaly'


fileano = dl.FilesFolder(pathano, '.tif')
fileano = fileano[0:-46]
print (fileano)

# open basefile
ds = gdal.Open(fileano[0])
band = ds.GetRasterBand(1)
nan = band.GetNoDataValue()

# open max and min files, mask where NaN
meanin = gdal.Open(pathmean).ReadAsArray()
meanin = np.ma.masked_values(meanin, nan)
stdin = gdal.Open(pathstd).ReadAsArray()
stdin = np.ma.masked_values(stdin, nan)

for i in fileano:
    # open anomaly and mask where NaN
    ano = gdal.Open(i).ReadAsArray()
    ano = np.ma.masked_values(ano, nan)
    
    # normalized anomaly index
    normano = ano / stdin
    
    print ('\nmax', normano.max(), 'min', normano.min(), 'std', normano.std(), 'mean', normano.mean())
    path = r'D:\Data\GPCP_30acc_anomalyNormTypeII'+i[-17::]
    print (path)
    
    dl.saveRaster(path, normano.data, ds, datatype=6, nan=nan)
