# %%
#inStations = r'I:\Documents\Klusjes\GIDS Interpolation Air Temperature\GSOD//NEARNLSTATIONS_MERGED_8_monday.csv'
folderSM = r'D:\Data\SoilMoisture_AMSRE\4D'
#RasterDEM = r'I:\Documents\Klusjes\GIDS Interpolation Air Temperature\GSOD//AALBERS_25KM_DEM.tif'
outFolder = r'D:\Data\SoilMoisture_AMSRE\output//'
prefix = 'SM'
date_all = [20120723, 20120724, 20120725, 20120726, 20120727, 20120728, 20120729, 20120730]

# %%
def savitzky_golay(y, window_size, order, deriv=0, rate=1):
    r"""Smooth (and optionally differentiate) data with a Savitzky-Golay filter.
    The Savitzky-Golay filter removes high frequency noise from data.
    It has the advantage of preserving the original shape and
    features of the signal better than other types of filtering
    approaches, such as moving averages techniques.
    Parameters
    ----------
    y : array_like, shape (N,)
        the values of the time history of the signal.
    window_size : int
        the length of the window. Must be an odd integer number.
    order : int
        the order of the polynomial used in the filtering.
        Must be less then `window_size` - 1.
    deriv: int
        the order of the derivative to compute (default = 0 means only smoothing)
    Returns
    -------
    ys : ndarray, shape (N)
        the smoothed signal (or it's n-th derivative).
    Notes
    -----
    The Savitzky-Golay is a type of low-pass filter, particularly
    suited for smoothing noisy data. The main idea behind this
    approach is to make for each point a least-square fit with a
    polynomial of high order over a odd-sized window centered at
    the point.
    Examples
    --------
    t = np.linspace(-4, 4, 500)
    y = np.exp( -t**2 ) + np.random.normal(0, 0.05, t.shape)
    ysg = savitzky_golay(y, window_size=31, order=4)
    import matplotlib.pyplot as plt
    plt.plot(t, y, label='Noisy signal')
    plt.plot(t, np.exp(-t**2), 'k', lw=1.5, label='Original signal')
    plt.plot(t, ysg, 'r', label='Filtered signal')
    plt.legend()
    plt.show()
    References
    ----------
    .. [1] A. Savitzky, M. J. E. Golay, Smoothing and Differentiation of
       Data by Simplified Least Squares Procedures. Analytical
       Chemistry, 1964, 36 (8), pp 1627-1639.
    .. [2] Numerical Recipes 3rd Edition: The Art of Scientific Computing
       W.H. Press, S.A. Teukolsky, W.T. Vetterling, B.P. Flannery
       Cambridge University Press ISBN-13: 9780521880688
    """
    import numpy as np
    from math import factorial

    try:
        window_size = np.abs(np.int(window_size))
        order = np.abs(np.int(order))
    except ValueError, msg:
        raise ValueError("window_size and order have to be of type int")
    if window_size % 2 != 1 or window_size < 1:
        raise TypeError("window_size size must be a positive odd number")
    if window_size < order + 2:
        raise TypeError("window_size is too small for the polynomials order")
    order_range = range(order+1)
    half_window = (window_size -1) // 2
    # precompute coefficients
    b = np.mat([[k**i for i in order_range] for k in range(-half_window, half_window+1)])
    m = np.linalg.pinv(b).A[deriv] * rate**deriv * factorial(deriv)
    # pad the signal at the extremes with
    # values taken from the signal itself
    firstvals = y[0] - np.abs( y[1:half_window+1][::-1] - y[0] )
    lastvals = y[-1] + np.abs(y[-half_window-1:-1][::-1] - y[-1])
    y = np.concatenate((firstvals, y, lastvals))
    return np.convolve( m[::-1], y, mode='valid')

# %%
#from scipy import stats
#import scipy
#import statsmodels.api as sm
import numpy as np
import pandas as pd
from osgeo import gdal
#import gdal
import os
from __future__ import division
import datetime
from pylab import figure, title, hold, plot, meshgrid, show, contourf, subplot, xlabel, ylabel, text, axes, colorbar, rcParams
from numpy import arange, flipud
from numpy.fft import fft
#from scipy.signal import lfilter, butter
import matplotlib.pyplot as plt

# %%
def SMfiles(inGSODFolder):
    st_wmo = [os.path.join(root, name)
               for root, dirs, files in os.walk(inGSODFolder)
                 for name in files                 
                 if name.endswith('.tif')]
    return st_wmo

# %%
def listall(RootFolder):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if 'LST' in name
                     if name.endswith('.tif')]
    return lists

# %%
li = []
da = []
i = 0
path = r'D:\Data\DataTimeSeries'
test = listall(path)
print len(test)
print test[0]
for t in test:    
    raster = gdal.Open(t, gdal.GA_ReadOnly)
    nameRas = raster.GetDescription()[-11:-4]
    date = datetime.datetime(int(nameRas[0:4]), 1, 1) + datetime.timedelta(int(nameRas[4:9]) - 1)
    # print date
    da.append(date)

    band = raster.GetRasterBand(1)
    array = band.ReadAsArray()    
    
    # print array[879,4142] # Grassland pixel
    li.append(array[879,4142])
    
    array = None
    band = None
    raster = None
    print str(i)
    i = i + 1

# %%
seriesSM = pd.Series(data = li, index = da) # Created a series for Soil Moisture for pixel 879,4142 -- Grassland inner mongolia

# %%
seriesSM.to_csv(r'D:\Data\DataTimeSeries_csv//seriesSM.csv')

# %%
pd.__version__
# Out:
# '0.12.0'

# %%
seriesSM = pd.read_csv(r'D:\Data\DataTimeSeries_csv//seriesSM.csv', header=None, parse_dates=[[0]], index_col=[0] )
seriesSM.rename(columns={1:'SM'}, inplace=True)
seriesSM.index.names=['Date']

seriesLST = pd.read_csv(r'D:\Data\DataTimeSeries_csv//seriesLST.csv', header=None, parse_dates=[[0]], index_col=[0] )
seriesLST.rename(columns={1:'LST'}, inplace=True)
seriesLST.index.names=['Date']

seriesNDVI = pd.read_csv(r'D:\Data\DataTimeSeries_csv//seriesNDVI.csv', header=None, parse_dates=[[0]], index_col=[0] )
seriesNDVI.rename(columns={1:'NDVI'}, inplace=True)
seriesNDVI.index.names=['Date']
seriesSM.plot()
seriesLST.plot()
seriesNDVI.plot()

# %%
seriesNDVI = pd.Series(data = li, index = da) # Series for response variable NDVI for pixel 879, 4142 -- Grassland inner mongolia

# %%
seriesNDVI.to_csv(r'D:\Data\DataTimeSeries_csv//seriesNDVI.csv')

# %%
seriesNDVI = pd.read_csv(r'D:\Data\DataTimeSeries_csv//seriesNDVI.csv')

# %%
seriesLST = pd.Series(data = li, index = da) # Series for response variable LST, land surface temperature for pixel 879, 4142 -- Grassland inner mongolia

# %%
seriesLST.to_csv(r'D:\Data\DataTimeSeries_csv//seriesLST.csv')

# %%
seriesLST = pd.read_csv(r'D:\Data\DataTimeSeries_csv//seriesLST.csv')

# %%
normSM = (seriesSM - seriesSM.mean()) / (seriesSM.max() - seriesSM.min())
normNDVI = (seriesNDVI - seriesNDVI.mean()) / (seriesNDVI.max() - seriesNDVI.min())
normLST = (seriesLST - seriesLST.mean()) / (seriesLST.max() - seriesLST.min())

# %% [markdown]
# #### Unfiltered raw data from Soil moisture in Green and Savitzky-Golay filtered data in red

# %%
SM_sg = savitzky_golay(seriesSM.SM, 5, 0, 0)

plt.figure(num=1, figsize=(30,5), dpi=400)
seriesSM.SM.plot(style='c-')
plt.plot(seriesSM.index, SM_sg, 'r-', linewidth=2)
plt.title("Soil Moisture Time-series Inner-Mongolia (Grassland)")
plt.xlabel("Time in years")
plt.ylabel("Volumetric Soil Moisture Raw (%)")
plt.legend(["original time series SM","savitzky-golay filtered time-series SM"])
plt.show()

# %% [markdown]
# #### Unfiltered raw data from NDVI in Green and Savitzky-Golay filtered data in red

# %%
seriesLST_nan = seriesLST.LST.astype(float)
seriesLST_nan = seriesLST_nan.replace(0,np.nan)
seriesLST_intp = seriesLST_nan.interpolate(method='linear')
seriesLST_df = pd.DataFrame(data=seriesLST_intp, index=seriesLST.index)
seriesLST_df = seriesLST_df.dropna()
seriesLST_df.head()
# Out:
#               LST
# Date
# 2001-01-09  25220
# 2001-01-17  25480
# 2001-01-25  25638
# 2001-02-02  24842
# 2001-02-10  25682

# %%
seriesLST_nan = seriesLST.LST.astype(float)
seriesLST_nan = seriesLST_nan.replace(0,np.nan)
seriesLST_intp = seriesLST_nan.interpolate(method='linear')
seriesLST_df = pd.DataFrame(data=seriesLST_intp, index=seriesLST.index)
seriesLST_df = seriesLST_df.dropna()
seriesLST_df.head()

plt.figure(num=1, figsize=(30,5))
seriesLST.LST.plot(style='c-')
LST_sg = savitzky_golay(seriesLST_df.LST, 5, 0)

plt.plot(seriesLST_df.LST.index,LST_sg, 'r-', linewidth=2)
plt.ylim(24000,33000)
plt.title("Land Surface Temperature Time-series Inner-Mongolia (Grassland)")
plt.xlabel("Time in years")
plt.ylabel("LST (temp in K * 100)")
plt.legend(["original time series","savitzky-golay filtered time-series"])
plt.show()

# %% [markdown]
# #### Preprocessed NDVI timeseries

# %%
plt.figure(num=1, figsize=(30,5))
plt.title("Preprocessed NDVI Time-series Inner-Mongolia (Grassland)")
plt.xlabel("Time in years")
plt.ylabel("NDVI (raw)")
seriesNDVI.NDVI.plot(style='r-')
plt.legend(["original time series"])#,"savitzky-golay filtered time-series"])
plt.show()

# %%
SM_sg2 = pd.Series(data = SM_sg, index = seriesSM.index)
normSM = (SM_sg2 - SM_sg2.mean()) / (SM_sg2.max() - SM_sg2.min())
normNDVI = (seriesNDVI - seriesNDVI.mean()) / (seriesNDVI.max() - seriesNDVI.min())
LST_sg2 = pd.Series(data = LST_sg, index = seriesLST_df.index)
normLST = (LST_sg2 - LST_sg2.mean()) / (LST_sg2.max() - LST_sg2.min())

# %%
plt.figure(num=1, figsize=(24,10))
plt.subplot(2,1,1)

plt.title("Normalised Time-series of Soil Moisture and the response variable NDVI in Inner-Mongolia (Grassland)")
plt.xlabel("Time in years")
plt.ylabel("normalised")

normSM.plot(style="c-")
normNDVI.NDVI.plot(style="m-", linewidth=2)

plt.legend(["SM","NDVI"])

plt.subplot(2,1,2)

plt.title("Normalised Time-series of Soil Moisture and the response variable Land Surface Temperature in Inner-Mongolia (Grassland)")
plt.xlabel("Time in years")
plt.ylabel("normalised")

normSM.plot(style="c-")
normLST.plot(style="r-", linewidth=2)

plt.legend(["SM","LST"])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Here we are going to calculate and filter the original time series in the frequency domain by using some band filters (e.g Butterworth filter)

# %% [markdown]
# The following code shows a low band pass filter

# %%
#seriesSM.plot()
fft = scipy.fft(seriesSM.SM) # fourier transform of seriesSM
bp_low = fft[:]
for i in range(len(bp_low)):    
    if i > 100 :bp_low[i]=0
#    elif i < 2:        
#        bp[i]=0
#        bp[0]=scipy.fft(seriesSM)[0]

ibp_low = scipy.ifft(bp_low)
plt.figure(num=1, figsize=(24,10))
plt.subplot(2,1,1)
plt.plot(seriesSM.SM.index,seriesSM.SM, 'c-')
plt.plot(seriesSM.SM.index,SM_sg, 'r-')
plt.plot(seriesSM.SM.index,ibp_low, linewidth=2)
plt.legend(['SM','SM sg Filter','SM low bandpass filter'])
plt.grid(True)

plt.axes([0.0205,0.33,0.974,0.15])
plt.plot(scipy.fft(seriesSM.SM), 'c--')
plt.plot(bp_low)
plt.legend(['Fourier transform SM original','Fourier transform SM low bandpass filter'])

plt.xlim(1,200)
plt.ylim(-4,4)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# High pass filter, clearly can be seen that it's not the underlying signal but the tendencies in time, the short term variations

# %%
#seriesSM.plot()
fft = scipy.fft(seriesSM.SM) # fourier transform of seriesSM
bp_high = fft[:]
for i in range(len(bp_high)):    
    if i > 200 :
        bp_high[i]=0
    elif i < 100:        
        bp_high[i]=0
        bp_high[0]=scipy.fft(seriesSM.SM)[0]

ibp_high = scipy.ifft(bp_high)
plt.figure(num=1, figsize=(24,10))
plt.subplot(2,1,1)

plt.plot(seriesSM.SM.index,seriesSM.SM, 'c-')
plt.plot(seriesSM.SM.index,SM_sg, 'r-')
plt.plot(seriesSM.SM.index,ibp_high, linewidth=2)
plt.legend(['SM','SM sg Filter','SM high bandpass filter'])
plt.grid(True)

plt.axes([0.0205,0.33,0.974,0.15])
plt.plot(scipy.fft(seriesSM.SM), 'c--')
plt.plot(bp_high)
plt.legend(['Fourier transform SM original','Fourier transform SM high bandpass filter'])

plt.xlim(1,200)
plt.ylim(-4,4)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Now apply Butterworth filter as a low bandpass filter to remoive the noise in the timeseries for the Soil Moisture time series

# %%
def bandpass_data(data, low_f, high_f, sample_rate, order):
    # apply a low-pass filter
    normfreq = high_f/(sample_rate/2.0)
    (butter_low_b, butter_low_a) = butter(order, normfreq, btype='low')
    forward = lfilter(butter_low_b, butter_low_a, data, axis=0)
    tmp_data = flipud(lfilter(butter_low_b, butter_low_a, flipud(forward), axis=0))

    # Apply a high pass filter
    normfreq = low_f/(sample_rate/2.0)
    (butter_low_b, butter_low_a) = butter(order, normfreq, btype='high')
    forward = lfilter(butter_low_b, butter_low_a, tmp_data, axis=0)
    filt_data = flipud(lfilter(butter_low_b, butter_low_a, flipud(forward), axis=0))

    return filt_data

# %%
butterSM = bandpass_data(seriesSM.SM, 0, 30, 600, 4)
plt.figure(num=1, figsize=(24,10))
plt.subplot(2,1,1)

plt.plot(seriesSM.SM.index,seriesSM.SM, 'c-')
plt.plot(seriesSM.SM.index,SM_sg,'r-')
plt.plot(seriesSM.SM.index,butterSM, linewidth=2)
plt.legend(['SM','SM sg Filter','SM Butterworth bandpass filter'])
plt.grid(True)

plt.axes([0.0205,0.33,0.974,0.15])
plt.plot(scipy.fft(seriesSM.SM), 'c--')
plt.plot(scipy.fft(butterSM))
plt.legend(['Fourier transform SM original','Fourier transform SM Butterworth bandpass filter'])

plt.xlim(1,200)
plt.ylim(-4,4)
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Let's see what we can do by filtering out the peak at 10 in the frequency representation of the Land Surface Temperature time-series

# %%
fft = scipy.fft(seriesLST_df.LST) # fourier transform of seriesSM
bp_high = fft[:]
for i in range(len(bp_high)):    
    if i > 20 :
        bp_high[i]=0
    elif i< 5:        
        bp_high[i]=0
        bp_high[0]=scipy.fft(seriesLST_df.LST)[0]

ibp_high = scipy.ifft(bp_high)
plt.figure(num=1, figsize=(24,10))
plt.subplot(2,1,1)

plt.plot(seriesLST_df.LST.index,seriesLST_df.LST, 'c-')
plt.plot(seriesLST_df.LST.index,LST_sg, 'r-')
plt.plot(seriesLST_df.LST.index,ibp_high, linewidth=2)
plt.grid(True)

plt.axes([0.0265,0.33,0.967,0.15])
plt.plot(scipy.fft(seriesLST_df.LST), 'c--')
plt.plot(bp_high)

plt.xlim(5,15)
plt.ylim(-0.07e7,0.01e7)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Now apply Butterworth filter as a low bandpass filter to remoive the noise in the timeseries for the Land Surface Temperature time series

# %%
len(seriesLST.LST.index)
len(seriesLST.LST.index)
# Out:
# 458

# %%
#seriesLST2_intp = seriesLST_intp.dropna()
butterLST = bandpass_data(seriesLST_df.LST, 0, 30, 600, 4)
plt.figure(num=1, figsize=(24,10))
plt.subplot(2,1,1)

plt.plot(seriesLST_df.LST.index,seriesLST_df.LST, 'c-')
plt.plot(seriesLST_df.LST.index,LST_sg, 'r-')
plt.plot(seriesLST_df.LST.index,butterLST, linewidth=2)
plt.ylim(24000,33000)
plt.legend(['LST','LST sg filter','LST Butterworth bandpass filter'])
plt.grid(True)

plt.axes([0.0205,0.33,0.974,0.15])
plt.plot(scipy.fft(seriesLST_df.LST), 'c--')
plt.plot(scipy.fft(butterLST))
plt.legend(['Fourier transform LST original','Fourier transform LST Butterworth bandpass filter'])

plt.xlim(0,20)
plt.ylim(-0.9e6,0.1e6)
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### By using the autocorrelation function is is possible to detect a repetitive signal in the presence of unwanted noise. It can be used to characterise a sequence's time domain structure. So we are going to compare the original and filterted time series with their corresponding autocorrelation function and see how they are related.

# %%
normalisedSM = (butterSM - butterSM.mean()) / (butterSM.max() - butterSM.min())
normalisedLST = (butterLST - butterLST.mean()) / (butterLST.max() - butterLST.min()) 
normalisedNDVI = (seriesNDVI - seriesNDVI.mean()) / (seriesNDVI.max() - seriesNDVI.min())

# %%
plt.figure(num=1, figsize=(30,12))

# SM time series
plt.subplot(3,2,1)
plt.plot(seriesSM.index,butterSM, linewidth=2)
plt.plot(seriesSM.index,seriesSM)
plt.ylim(0.05,0.20)
plt.legend(['SM Butterworth','SM raw'])
plt.grid(True)

# Calculation of the autocorrelation function with using 100 lags
acf_SM_butter = sm.tsa.acf(butterSM, nlags=100, )
acf_SM_series = sm.tsa.acf(seriesSM, nlags=100, )

# SM acf
plt.subplot(3,2,2)
plt.plot(acf_SM_butter)
plt.plot(acf_SM_series)
plt.legend(['ACF SM Butterworth','ACF SM raw'])

# NDVI time series
plt.subplot(3,2,3)
plt.plot(seriesNDVI.index,seriesNDVI)
plt.legend(['NDVI raw'])
plt.grid(True)

# Calculation of the autocorrelation function with using 100 lags
acf_NDVI = sm.tsa.acf(seriesNDVI, nlags=100, )

# NDVI acf
plt.subplot(3,2,4)
plt.plot(acf_NDVI)
plt.legend(['ACF NDVI'])

# LST time series
plt.subplot(3,2,5)
plt.plot(seriesLST_df.index,butterLST, linewidth=2)
plt.plot(seriesLST.index,seriesLST)
plt.ylim(25000,32500)
plt.legend(['LST Butterworth', 'LST raw'])
plt.grid(True)

# Calculation of the autocorrelation function with using 100 lags
acf_LST_butter = sm.tsa.acf(butterLST, nlags=100, )
acf_LST_series = sm.tsa.acf(seriesLST, nlags=100, )

# LST acf
plt.subplot(3,2,6)
plt.plot(acf_LST_butter)
plt.plot(acf_LST_series)
plt.legend(['ACF LST Butterworth','ACF LST raw'])

# %%
print len(butterSM)
print len(seriesSM.SM)
# Out:
# 846
# 846

# %% [markdown]
# #### Next step on the list is to compare the autocorrelation function with it's corresponding the powerspectrum. The powerspectrum is calculated by taking the fourier transform of the autocorrelation function

# %%
plt.figure(num=1, figsize=(30,12))

# SM acf
plt.subplot(3,2,1)
plt.plot(acf_SM_butter)
plt.plot(acf_SM_series)
plt.legend(['ACF SM Butterworth','ACF SM raw'])
plt.grid(True)

# SM pws
plt.subplot(3,2,2)
pws_SM_butter = np.fft.fft(acf_SM_butter)
pws_SM_series = np.fft.fft(acf_SM_series)
plt.plot(abs(pws_SM_butter))
plt.plot(abs(pws_SM_series))
plt.legend(['PWS SM Butterworth','PWS SM raw'])
plt.grid(True)

# NDVI acf
plt.subplot(3,2,3)
plt.plot(acf_NDVI)
plt.legend(['ACF NDVI'])
plt.grid(True)

# NDVI pws
plt.subplot(3,2,4)
pws_NDVI_series = np.fft.fft(acf_NDVI)
plt.plot(abs(pws_NDVI_series))
plt.legend(['PWS NDVI raw'])
plt.grid(True)

# LST acf
plt.subplot(3,2,5)
plt.plot(acf_LST_butter)
plt.plot(acf_LST_series)
plt.legend(['ACF LST Butterworth','ACF LST raw'])
plt.grid(True)

# LST pws
plt.subplot(3,2,6)
pws_LST_butter = np.fft.fft(acf_LST_butter)
pws_LST_series = np.fft.fft(acf_LST_series)
plt.plot(abs(pws_LST_butter))
plt.plot(abs(pws_LST_series))
plt.legend(['ACF LST Butterworth','ACF LST raw'])
plt.grid(True)

# %% [markdown]
# #### Then we get the CCF, the cross-correlation function, that reflects the various frequency components held in common between the the time series. Firstly we correlate the raw time series of NDVI against Soil Moisture and then we correlate the raw and butterworth filtered LST time series against Soil Moisture.

# %%
seriesSM_NDVI = pd.concat([seriesSM.SM, seriesNDVI.NDVI], join='outer', axis=1)
seriesSM_NDVI.head()
#seriesSM_NDVI.corr()
#seriesSM_NDVI.SM.head(120)
#series = seriesSM_NDVI.dropna()
#series.NDVI.plot()

# %%
seriesSM.SM
#seriesLST_df.LST
#df_2 = pd.merge(seriesNDVI.NDVI, seriesSM.SM)
#np.correlate(seriesSM.SM, seriesNDVI.NDVI)
# Out:
# Date
# 2002-06-18    0.112000
# 2002-06-22    0.190333
# 2002-06-26    0.134000
# 2002-06-30    0.093000
# 2002-07-04    0.098667
# 2002-07-08    0.106333
# 2002-07-12    0.134500
# 2002-07-16    0.166250
# 2002-07-20    0.094333
# 2002-07-24    0.090000
# 2002-07-28    0.129000
# 2002-08-01    0.087000
# 2002-08-05    0.087000
# 2002-08-09    0.094000
# 2002-08-13    0.094750
# ...
# 2011-08-05    0.119000
# 2011-08-09    0.107000
# 2011-08-13    0.115000
# 2011-08-17    0.106750
# 2011-08-21    0.102500
# 2011-08-25    0.102750
# 2011-08-29    0.097333
# 2011-09-02    0.096250
# 2011-09-06    0.158500
# 2011-09-10    0.093250
# 2011-09-14    0.083667
# 2011-09-18    0.082750
# 2011-09-22    0.092500
# 2011-09-26    0.124000
# 2011-09-30    0.114000
# Name: SM, Length: 846, dtype: float64

# %%
x = linspace(-np.pi, np.pi)
a = np.sin(x)
b = np.sin(x+1)
#a = [1, 2, 3]
#b = [0, 1, 0.5]
c = np.correlate(a, b)

plt.figure(num=1, figsize=(6,10))
plt.subplot(3,1,1)
plt.plot(a)
plt.plot(b)
plt.plot(c)
#plt.show()


d = np.correlate(a, b, "same")
plt.subplot(3,1,2)
plt.plot(a)
plt.plot(b)
plt.plot(d)
#plt.show()
#print d

e = np.correlate(a, b, "full")
plt.subplot(3,1,3)
plt.plot(a)
plt.plot(b)
plt.plot(e)
plt.show()
#print e

# %%
d = np.correlate(a, b, "same")

plt.plot(a)
plt.plot(b)
plt.plot(d)

# %%
e = np.correlate(a, b, "full")
plt.plot(a)
plt.plot(b)
plt.plot(e)

# %% [markdown]
# #### Frequency domain counterpart of a cross-correlation function relating two sequences is kown as the cross-spectral density or the cross-spectrum

# %% [markdown]
# #### From here Play and test

# %%
#plt.figure(num=1, figsize=(30,8))
# First Row where NDVI is compared against SM
plt.subplot(2,3,1)
plt.plot(seriesSM.SM.index,normalisedSM)
plt.plot(seriesNDVI.NDVI.index,normalisedNDVI)
plt.grid(True)

plt.subplot(2,3,2)
acf_SM = sm.tsa.acf(normalisedSM, nlags=100, )
acf_NDVI = sm.tsa.acf(normalisedNDVI, nlags=100, )


plt.subplot(2,3,3)
pws_SM = np.fft.fft(acf_SM)
pws_NDVI = np.fft.fft(acf_NDVI)
plt.plot(abs(pws_SM))
plt.plot(abs(pws_NDVI))

# First Row where LST is compared against SM
plt.subplot(2,3,4)
plt.plot(seriesSM.SM.index,normalisedSM)
plt.plot(seriesLST_df.LST.index,normalisedLST)
plt.grid(True)

plt.subplot(2,3,5)
acf_SM = sm.tsa.acf(normalisedSM, nlags=100, )
acf_LST = sm.tsa.acf(normalisedLST, nlags=100, )
plt.plot(acf_SM)
plt.plot(acf_LST)

plt.subplot(2,3,6)
pws_SM = np.fft.fft(acf_SM)
pws_LST = np.fft.fft(acf_LST)
plt.plot(abs(pws_SM))
plt.plot(abs(pws_LST))
plt.tight_layout()

# %%
import statsmodels.api as sm

# %%
acf_SM = sm.tsa.acf(normSM, nlags=100, )
acf_NDVI = sm.tsa.acf(normNDVI, nlags=100, )
plt.subplot(2,1,1)
plt.plot(acf_SM)
plt.plot(acf_NDVI)

pws_SM = np.fft.fft(acf_SM)
pws_NDVI = np.fft.fft(acf_NDVI)
plt.subplot(2,1,2)
plt.plot(abs(pws_SM))
plt.plot(abs(pws_NDVI))

# %%
normSM.mean()
# Out:
# -3.7135385389279394e-16

# %%
plt.figure(num=1, figsize=(20,4))
seriesNDVI.plot(style='c-')
hold(True)

s_g = savitzky_golay(seriesNDVI.NDVI, 5, 0)
#plt.figure(num=1, figsize=(4,2))
plt.plot(seriesNDVI.NDVI.index, s_g, 'r-')
#plt.grid(True)
#plt.ylim(0,0.25)
plt.show()

# %% [markdown]
# Combined plot of normalised time series data of forcing variable soil moisture with responsing variables land surface temperature and the NDVI

# %%
SM_SG = savitzky_golay(normSM, 5, 0)
LST_SG = savitzky_golay(normLST, 5, 0)
plt.figure(num=1, figsize=(20,4))
plt.plot(seriesNDVI.index, normNDVI, 'r-')
#normNDVI.plot(style='r-')
hold(True)
plt.plot(seriesSM.SM.index, SM_SG, 'b-')
hold(True)
plt.plot(seriesLST_df.LST.index, LST_SG, 'c-')
plt.grid(True)
#plt.ylim(0,0.25)
plt.show()

# %% [markdown]
# Power spectrum of the orginal raw series

# %%
power = abs(np.fft.fft(seriesSM.SM))
plt.figure(num=1, figsize=(4,2))
plt.plot(power)
plt.grid(True)
plt.ylim(0,20)
plt.xlim(0,100)
plt.show()

# %% [markdown]
# Bandpass filtering using butterworth filter together with plot

# %%
from pylab import figure, title, hold, plot, meshgrid, show, contourf, subplot, xlabel, ylabel, text, axes, colorbar, rcParams
from numpy import arange, flipud
from numpy.fft import fft
from scipy.signal import lfilter, butter

# %%
def bandpass_data(data, low_f, high_f, sample_rate, order):
    # apply a low-pass filter
    normfreq = high_f/(sample_rate/2.0)
    (butter_low_b, butter_low_a) = butter(order, normfreq, btype='low')
    forward = lfilter(butter_low_b, butter_low_a, data, axis=0)
    tmp_data = flipud(lfilter(butter_low_b, butter_low_a, flipud(forward), axis=0))

    # Apply a high pass filter
    normfreq = low_f/(sample_rate/2.0)
    (butter_low_b, butter_low_a) = butter(order, normfreq, btype='high')
    forward = lfilter(butter_low_b, butter_low_a, tmp_data, axis=0)
    filt_data = flipud(lfilter(butter_low_b, butter_low_a, flipud(forward), axis=0))

    return filt_data

# %%
xseries = bandpass_data(seriesSM.SM, 3, 30, 1000, 4)
plt.figure(num=1, figsize=(20,4))
plt.plot(seriesSM.SM.index,xseries)
plt.grid(True)
#plt.ylim(0,20)
#plt.xlim(0,100)
plt.show()

# %%
from scipy import signal
import matplotlib.pyplot as plt

# %% [markdown]
# USING the following link was able to compute both the Welch power spectral density and Welch power spectrum, which is kind of awesome eventhough I've no idea what it really means... http://docs.scipy.org/doc/scipy-dev/reference/generated/scipy.signal.welch.html

# %% [markdown]
# First creation of some test signal

# %%
fs = 10e3
N = 1e5
amp = 2*np.sqrt(2)
freq = 1234.0
noise_power = 0.001 * fs / 2
time = np.arange(N) / fs
x = amp*np.sin(2*np.pi*freq*time)
x += np.random.normal(scale=np.sqrt(noise_power), size=time.shape)

# %%
plt.plot(time, x)

# %% [markdown]
# Power spectral density for test signal

# %%
f, Pxx_den = signal.welch(x, fs, nperseg=1024)
plt.semilogy(f, Pxx_den)
plt.ylim(0.5e-3,1)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
np.mean(Pxx_den[256:])
# Out:
# 0.0010046273682858542

# %% [markdown]
# Power spectrum for test signal

# %%
f, Pxx_spec = signal.welch(x, fs, 'flattop', 1024, scaling='spectrum')
plt.figure()
plt.semilogy(f, np.sqrt(Pxx_spec))
plt.xlabel('frequency [Hz]')
plt.ylabel('Linear spectrum [V RMS]')
plt.show()

# %%
np.sqrt(Pxx_spec.max())
# Out:
# 1.9969149158709287

# %% [markdown]
# And now for our own data, firstly the power spectral density estimate of NDVI and LST compared againt SM

# %%
normalisedSM
#normLST.LST
# Out:
# array([ -1.82157937e-01,  -1.15901295e-01,  -5.64166129e-02,
#         -6.22600749e-03,   3.28489126e-02,   5.98066275e-02,
#          7.45030428e-02,   7.76156736e-02,   7.05450564e-02,
#          5.52650052e-02,   3.41372878e-02,   9.71010092e-03,
#         -1.54800825e-02,  -3.90870264e-02,  -5.91021284e-02,
#         -7.39644649e-02,  -8.26322498e-02,  -8.46179932e-02,
#         -7.99909331e-02,  -6.93498402e-02,  -5.37680773e-02,
#         -3.47116964e-02,  -1.39309183e-02,   6.67382055e-03,
#          2.52072258e-02,   3.99467905e-02,   4.95073424e-02,
#          5.29819597e-02,   5.00372689e-02,   4.09450195e-02,
#          2.65410355e-02,   8.11544003e-03,  -1.27485883e-02,
#         -3.43602579e-02,  -5.51007514e-02,  -7.35725106e-02,
#         -8.87043912e-02,  -9.98090681e-02,  -1.06595798e-01,
#         -1.09145160e-01,  -1.07854131e-01,  -1.03360902e-01,
#         -9.64594194e-02,  -8.80136641e-02,  -7.88804087e-02,
#         -6.98466435e-02,  -6.15845187e-02,  -5.46235816e-02,
#         -4.93380799e-02,  -4.59464362e-02,  -4.45201735e-02,
#         -4.49996395e-02,  -4.72134827e-02,  -5.08985631e-02,
#         -5.57176583e-02,  -6.12743848e-02,  -6.71276036e-02,
#         -7.28092482e-02,  -7.78481307e-02,  -8.17988439e-02,
#         -8.42725702e-02,  -8.49671076e-02,  -8.36955686e-02,
#         -8.04148332e-02,  -7.52538458e-02,  -6.85373880e-02,
#         -6.07954285e-02,  -5.27459853e-02,  -4.52428489e-02,
#         -3.91872256e-02,  -3.54120535e-02,  -3.45569413e-02,
#         -3.69567763e-02,  -4.25651343e-02,  -5.09258796e-02,
#         -6.11971431e-02,  -7.22241687e-02,  -8.26514405e-02,
#         -9.10600042e-02,  -9.61140413e-02,  -9.67018214e-02,
#         -9.20587950e-02,  -8.18631107e-02,  -6.62956310e-02,
#         -4.60580552e-02,  -2.23449603e-02,   3.23104393e-03,
#          2.87576547e-02,   5.21769896e-02,   7.14634707e-02,
#          8.48093247e-02,   9.07987011e-02,   8.85511828e-02,
#          7.78172231e-02,   5.90107661e-02,   3.31700536e-02,
#          1.84887439e-03,  -3.30456211e-02,  -6.94426521e-02,
#         -1.05296954e-01,  -1.38753086e-01,  -1.68267877e-01,
#         -1.92682409e-01,  -2.11243207e-01,  -2.23579629e-01,
#         -2.29650278e-01,  -2.29674277e-01,  -2.24063027e-01,
#         -2.13364752e-01,  -1.98228679e-01,  -1.79389011e-01,
#         -1.57662826e-01,  -1.33952592e-01,  -1.09243320e-01,
#         -8.45855958e-02,  -6.10582644e-02,  -3.97088571e-02,
#         -2.14754991e-02,  -7.09930551e-03,   2.96015184e-03,
#          8.59241509e-03,   1.00738679e-02,   8.06606757e-03,
#          3.57047904e-03,  -2.15826228e-03,  -7.73268281e-03,
#         -1.17742484e-02,  -1.30614398e-02,  -1.06670409e-02,
#         -4.06735869e-03,   6.79140922e-03,   2.14790852e-02,
#          3.91218512e-02,   5.84913571e-02,   7.81300672e-02,
#          9.64958689e-02,   1.12107932e-01,   1.23677808e-01,
#          1.30213536e-01,   1.31088950e-01,   1.26075087e-01,
#          1.15335027e-01,   9.93872522e-02,   7.90449758e-02,
#          5.53397779e-02,   2.94377372e-02,   2.55553371e-03,
#         -2.41169170e-02,  -4.94820950e-02,  -7.25854555e-02,
#         -9.26497916e-02,  -1.09094180e-01,  -1.21539825e-01,
#         -1.29806032e-01,  -1.33899592e-01,  -1.34000097e-01,
#         -1.30442423e-01,  -1.23696535e-01,  -1.14343909e-01,
#         -1.03049133e-01,  -9.05248194e-02,  -7.74886662e-02,
#         -6.46141392e-02,  -5.24795564e-02,  -4.15225181e-02,
#         -3.20064376e-02,  -2.40040518e-02,  -1.74000098e-02,
#         -1.19113200e-02,  -7.12149651e-03,  -2.52319063e-03,
#          2.43490580e-03,   8.29958224e-03,   1.55652628e-02,
#          2.46295090e-02,   3.57550864e-02,   4.90415529e-02,
#          6.44083946e-02,   8.15906017e-02,   1.00146672e-01,
#          1.19478427e-01,   1.38861545e-01,   1.57485078e-01,
#          1.74497439e-01,   1.89055559e-01,   2.00373280e-01,
#          2.07764826e-01,   2.10679844e-01,   2.08729093e-01,
#          2.01703356e-01,   1.89590022e-01,   1.72589549e-01,
#          1.51129112e-01,   1.25867191e-01,   9.76836736e-02,
#          6.76536078e-02,   3.70051762e-02,   7.06291640e-03,
#         -2.08222798e-02,  -4.53528007e-02,  -6.53679648e-02,
#         -7.99257212e-02,  -8.83769847e-02,  -9.04268287e-02,
#         -8.61756986e-02,  -7.61338757e-02,  -6.12041826e-02,
#         -4.26303003e-02,  -2.19107110e-02,  -6.82109575e-04,
#          1.94186892e-02,   3.69003932e-02,   5.05535602e-02,
#          5.95605577e-02,   6.35647507e-02,   6.26898196e-02,
#          5.75071388e-02,   4.89563305e-02,   3.82299868e-02,
#          2.66372516e-02,   1.54622325e-02,   5.83235689e-03,
#         -1.39052609e-03,  -5.68656705e-03,  -6.91566642e-03,
#         -5.31435955e-03,  -1.45394685e-03,   3.83390467e-03,
#          9.55459190e-03,   1.46597906e-02,   1.81571944e-02,
#          1.92106736e-02,   1.72222317e-02,   1.18886852e-02,
#          3.22800141e-03,  -8.42687649e-03,  -2.24652770e-02,
#         -3.80620244e-02,  -5.42586022e-02,  -7.00524186e-02,
#         -8.44837115e-02,  -9.67101111e-02,  -1.06060710e-01,
#         -1.12064875e-01,  -1.14455537e-01,  -1.13151237e-01,
#         -1.08224509e-01,  -9.98653684e-02,  -8.83476873e-02,
#         -7.40036000e-02,  -5.72076369e-02,  -3.83689807e-02,
#         -1.79282539e-02,   3.64509278e-03,   2.58581553e-02,
#          4.82053408e-02,   7.01861133e-02,   9.13295266e-02,
#          1.11222974e-01,   1.29540384e-01,   1.46063963e-01,
#          1.60693932e-01,   1.73442603e-01,   1.84412135e-01,
#          1.93758742e-01,   2.01649180e-01,   2.08216848e-01,
#          2.13524708e-01,   2.17540372e-01,   2.20126017e-01,
#          2.21043633e-01,   2.19975776e-01,   2.16562183e-01,
#          2.10451086e-01,   2.01360338e-01,   1.89139041e-01,
#          1.73817078e-01,   1.55629395e-01,   1.35006676e-01,
#          1.12534257e-01,   8.88917068e-02,   6.47903320e-02,
#          4.09233487e-02,   1.79367474e-02,  -3.57846179e-03,
#         -2.30775945e-02,  -4.00454461e-02,  -5.39807921e-02,
#         -6.43917507e-02,  -7.08094219e-02,  -7.28222507e-02,
#         -7.01272201e-02,  -6.25892444e-02,  -5.02981725e-02,
#         -3.36127482e-02,  -1.31820305e-02,   1.00626347e-02,
#          3.49480259e-02,   6.01301576e-02,   8.41900693e-02,
#          1.05744886e-01,   1.23562623e-01,   1.36668249e-01,
#          1.44428594e-01,   1.46605219e-01,   1.43368177e-01,
#          1.35269501e-01,   1.23181490e-01,   1.08209214e-01,
#          9.15880104e-02,   7.45760064e-02,   5.83503161e-02,
#          4.39144907e-02,   3.20237029e-02,   2.31329380e-02,
#          1.73722836e-02,   1.45518982e-02,   1.41965382e-02,
#          1.56057132e-02,   1.79321642e-02,   2.02700632e-02,
#          2.17452917e-02,   2.16018290e-02,   1.92787871e-02,
#          1.44715796e-02,   7.16966166e-03,  -2.33591804e-03,
#         -1.34785731e-02,  -2.54739859e-02,  -3.74018871e-02,
#         -4.82994072e-02,  -5.72522299e-02,  -6.34722238e-02,
#         -6.63549711e-02,  -6.55152418e-02,  -6.08014909e-02,
#         -5.22916206e-02,  -4.02720399e-02,  -2.52015619e-02,
#         -7.66242669e-03,   1.16967620e-02,   3.22187824e-02,
#          5.32884863e-02,   7.43712969e-02,   9.50382352e-02,
#          1.14979201e-01,   1.34007354e-01,   1.52056943e-01,
#          1.69175740e-01,   1.85512096e-01,   2.01296028e-01,
#          2.16813762e-01,   2.32375579e-01,   2.48277571e-01,
#          2.64759047e-01,   2.81959014e-01,   2.99876727e-01,
#          3.18341975e-01,   3.36999897e-01,   3.55313299e-01,
#          3.72583015e-01,   3.87984397e-01,   4.00616109e-01,
#          4.09556533e-01,   4.13923298e-01,   4.12932031e-01,
#          4.05950712e-01,   3.92545827e-01,   3.72516690e-01,
#          3.45915948e-01,   3.13057460e-01,   2.74515342e-01,
#          2.31117658e-01,   1.83935389e-01,   1.34264702e-01,
#          8.36000483e-02,   3.35965075e-02,  -1.39799913e-02,
#         -5.73170230e-02,  -9.46379623e-02,  -1.24304094e-01,
#         -1.44933572e-01,  -1.55527271e-01,  -1.55585255e-01,
#         -1.45194954e-01,  -1.25074354e-01,  -9.65595123e-02,
#         -6.15336800e-02,  -2.23036111e-02,   1.85642653e-02,
#          5.84310241e-02,   9.47787009e-02,   1.25395144e-01,
#          1.48537665e-01,   1.63064128e-01,   1.68520633e-01,
#          1.65175476e-01,   1.53990519e-01,   1.36525933e-01,
#          1.14783747e-01,   9.10075751e-02,   6.74646688e-02,
#          4.62377618e-02,   2.90484029e-02,   1.71253123e-02,
#          1.11253461e-02,   1.11112320e-02,   1.65861754e-02,
#          2.65791180e-02,   3.97677572e-02,   5.46222194e-02,
#          6.95517927e-02,   8.30402506e-02,   9.37606860e-02,
#          1.00665918e-01,   1.03053196e-01,   1.00602033e-01,
#          9.33838898e-02,   8.18441101e-02,   6.67595319e-02,
#          4.91769977e-02,   3.03370350e-02,   1.15848002e-02,
#         -5.72998043e-03,  -2.03598283e-02,  -3.12653740e-02,
#         -3.77102746e-02,  -3.93345603e-02,  -3.61963298e-02,
#         -2.87734826e-02,  -1.79206856e-02,  -4.78231567e-03,
#          9.33075336e-03,   2.30850326e-02,   3.52673507e-02,
#          4.49036754e-02,   5.13362431e-02,   5.42526811e-02,
#          5.36723514e-02,   4.99022254e-02,   4.34763169e-02,
#          3.50906511e-02,   2.55417847e-02,   1.56725815e-02,
#          6.32547604e-03,  -1.69851498e-03,  -7.67717600e-03,
#         -1.10021044e-02,  -1.12109601e-02,  -8.01505945e-03,
#         -1.31984564e-03,   8.76364927e-03,   2.19170297e-02,
#          3.76220221e-02,   5.51761302e-02,   7.37152660e-02,
#          9.22427548e-02,   1.09665331e-01,   1.24838033e-01,
#          1.36620328e-01,   1.43944486e-01,   1.45894379e-01,
#          1.41789799e-01,   1.31269438e-01,   1.14364580e-01,
#          9.15542307e-02,   6.37903258e-02,   3.24806115e-02,
#         -5.80505673e-04,  -3.33344867e-02,  -6.36239465e-02,
#         -8.93798514e-02,  -1.08805781e-01,  -1.20536992e-01,
#         -1.23758248e-01,  -1.18271039e-01,  -1.04506534e-01,
#         -8.34851638e-02,  -5.67275111e-02,  -2.61244517e-02,
#          6.22243860e-03,   3.81763661e-02,   6.77407666e-02,
#          9.32181235e-02,   1.13336673e-01,   1.27332457e-01,
#          1.34978797e-01,   1.36561290e-01,   1.32803053e-01,
#          1.24751239e-01,   1.13640238e-01,   1.00748951e-01,
#          8.72690854e-02,   7.41989450e-02,   6.22725500e-02,
#          5.19273549e-02,   4.33069580e-02,   3.62903086e-02,
#          3.05377309e-02,   2.55465060e-02,   2.07129404e-02,
#          1.54009655e-02,   9.01722817e-03,   1.08938485e-03,
#         -8.66000811e-03,  -2.02546546e-02,  -3.34319091e-02,
#         -4.76454132e-02,  -6.21073254e-02,  -7.58677186e-02,
#         -8.79209815e-02,  -9.73226930e-02,  -1.03298082e-01,
#         -1.05325770e-01,  -1.03186479e-01,  -9.69733830e-02,
#         -8.70668101e-02,  -7.40803070e-02,  -5.87873457e-02,
#         -4.20386277e-02,  -2.46793508e-02,  -7.47437224e-03,
#          8.95254306e-03,   2.41607192e-02,   3.79124717e-02,
#          5.01692755e-02,   6.10651133e-02,   7.08610233e-02,
#          7.98877637e-02,   8.84854962e-02,   9.69496845e-02,
#          1.05490286e-01,   1.14207154e-01,   1.23080171e-01,
#          1.31970275e-01,   1.40627628e-01,   1.48704278e-01,
#          1.55769062e-01,   1.61323698e-01,   1.64822376e-01,
#          1.65700802e-01,   1.63420261e-01,   1.57526645e-01,
#          1.47717006e-01,   1.33901347e-01,   1.16246757e-01,
#          9.51930098e-02,   7.14319628e-02,   4.58481892e-02,
#          1.94260449e-02,  -6.86283768e-03,  -3.21713492e-02,
#         -5.58666612e-02,  -7.75809322e-02,  -9.72135933e-02,
#         -1.14884338e-01,  -1.30844183e-01,  -1.45359874e-01,
#         -1.58593549e-01,  -1.70502717e-01,  -1.80783283e-01,
#         -1.88870233e-01,  -1.93998541e-01,  -1.95314676e-01,
#         -1.92020331e-01,  -1.83525611e-01,  -1.69587890e-01,
#         -1.50414237e-01,  -1.26709400e-01,  -9.96579669e-02,
#         -7.08382766e-02,  -4.20759970e-02,  -1.52555345e-02,
#          7.88477123e-03,   2.59443006e-02,   3.80112717e-02,
#          4.37525776e-02,   4.34311017e-02,   3.78500231e-02,
#          2.82342928e-02,   1.60683456e-02,   2.91422235e-03,
#         -9.76535916e-03,  -2.07579503e-02,  -2.92106387e-02,
#         -3.46877714e-02,  -3.71737856e-02,  -3.70251791e-02,
#         -3.48825734e-02,  -3.15585144e-02,  -2.79184469e-02,
#         -2.47714915e-02,  -2.27846987e-02,  -2.24297679e-02,
#         -2.39651775e-02,  -2.74498727e-02,  -3.27785580e-02,
#         -3.97254590e-02,  -4.79845512e-02,  -5.71988166e-02,
#         -6.69766953e-02,  -7.68985099e-02,  -8.65183575e-02,
#         -9.53676227e-02,  -1.02965142e-01,  -1.08836776e-01,
#         -1.12544523e-01,  -1.13722943e-01,  -1.12118951e-01,
#         -1.07630273e-01,  -1.00337967e-01,  -9.05285485e-02,
#         -7.87011839e-02,  -6.55555538e-02,  -5.19572871e-02,
#         -3.88804146e-02,  -2.73293268e-02,  -1.82454913e-02,
#         -1.24067570e-02,  -1.03299237e-02,  -1.21905258e-02,
#         -1.77760372e-02,  -2.64868677e-02,  -3.73915255e-02,
#         -4.93304014e-02,  -6.10520196e-02,  -7.13599915e-02,
#         -7.92486293e-02,  -8.40086649e-02,  -8.52899372e-02,
#         -8.31140432e-02,  -7.78365419e-02,  -7.00653305e-02,
#         -6.05487047e-02,  -5.00523601e-02,  -3.92477469e-02,
#         -2.86326979e-02,  -1.84977807e-02,  -8.94023379e-03,
#          8.39147379e-05,   8.68612778e-03,   1.69684254e-02,
#          2.49588193e-02,   3.25695598e-02,   3.95835854e-02,
#          4.56703335e-02,   5.04280665e-02,   5.34460297e-02,
#          5.43769899e-02,   5.30097580e-02,   4.93317348e-02,
#          4.35718848e-02,   3.62139403e-02,   2.79697082e-02,
#          1.97067067e-02,   1.23343815e-02,   6.66485970e-03,
#          3.27153711e-03,   2.37003383e-03,   3.74383355e-03,
#          6.73246652e-03,   1.02917090e-02,   1.31226150e-02,
#          1.38524501e-02,   1.12397885e-02,   4.37035162e-03,
#         -7.18958380e-03,  -2.33085055e-02,  -4.32868664e-02,
#         -6.59336188e-02,  -8.97065574e-02,  -1.12893230e-01,
#         -1.33805981e-01,  -1.50964867e-01,  -1.63245479e-01,
#         -1.69975186e-01,  -1.70970482e-01,  -1.66518235e-01,
#         -1.57311489e-01,  -1.44354206e-01,  -1.28849462e-01,
#         -1.12084350e-01,  -9.53237574e-02,  -7.97234293e-02,
#         -6.62690725e-02,  -5.57424771e-02,  -4.87094303e-02,
#         -4.55202536e-02,  -4.63140399e-02,  -5.10216870e-02,
#         -5.93680340e-02,  -7.08772256e-02,  -8.48868236e-02,
#         -1.00575345e-01,  -1.17005499e-01,  -1.33182188e-01,
#         -1.48121164e-01,  -1.60921599e-01,  -1.70834484e-01,
#         -1.77318748e-01,  -1.80078413e-01,  -1.79076382e-01,
#         -1.74523431e-01,  -1.66844347e-01,  -1.56626574e-01,
#         -1.44559150e-01,  -1.31370564e-01,  -1.17773595e-01,
#         -1.04423587e-01,  -9.18942754e-02,  -8.06715893e-02,
#         -7.11609239e-02,  -6.36988697e-02,  -5.85586831e-02,
#         -5.59410886e-02,  -5.59475433e-02,  -5.85401205e-02,
#         -6.34988551e-02,  -7.03916358e-02,  -7.85710017e-02,
#         -8.72054753e-02,  -9.53432339e-02,  -1.01998412e-01,
#         -1.06248120e-01,  -1.07329496e-01,  -1.04727007e-01,
#         -9.82396860e-02,  -8.80178705e-02,  -7.45617056e-02,
#         -5.86787757e-02,  -4.14041072e-02,  -2.38911867e-02,
#         -7.28725113e-03,   7.39035326e-03,   1.93583564e-02,
#          2.81360332e-02,   3.35690257e-02,   3.58104755e-02,
#          3.52706639e-02,   3.25495937e-02,   2.83645783e-02,
#          2.34803833e-02,   1.86455588e-02,   1.45363752e-02,
#          1.17093319e-02,   1.05639988e-02,   1.13188185e-02,
#          1.40022797e-02,   1.84600120e-02,   2.43752160e-02,
#          3.12970483e-02,   3.86716811e-02,   4.58747061e-02,
#          5.22486241e-02,   5.71508441e-02,   6.00141204e-02,
#          6.04149814e-02,   5.81400495e-02,   5.32373187e-02,
#          4.60399499e-02,   3.71538222e-02,   2.74062278e-02,
#          1.77601182e-02,   9.20444949e-03,   2.63556803e-03,
#         -1.25288213e-03,  -2.05384772e-03,   3.09830152e-04,
#          5.58986052e-03,   1.32624361e-02,   2.26127754e-02,
#          3.28379372e-02,   4.31501240e-02,   5.28647316e-02,
#          6.14616017e-02,   6.86131158e-02,   7.41784248e-02,
#          7.81687930e-02,   8.06936074e-02,   8.18988351e-02,
#          8.19093757e-02,   8.07847683e-02,   7.84951027e-02,
#          7.49209980e-02,   6.98778897e-02,   6.31609383e-02,
#          5.46032819e-02,   4.41368344e-02,   3.18417020e-02,
#          1.79705964e-02,   2.94103961e-03,  -1.27020104e-02,
#         -2.83434247e-02,  -4.33634876e-02,  -5.72006853e-02,
#         -6.94012121e-02,  -7.96470185e-02,  -8.77594970e-02,
#         -9.36822670e-02,  -9.74511777e-02,  -9.91613330e-02,
#         -9.89397499e-02,  -9.69286708e-02,  -9.32796014e-02,
#         -8.81537416e-02,  -8.17226317e-02,  -7.41642001e-02,
#         -6.56528110e-02,  -5.63453615e-02,  -4.63676160e-02,
#         -3.58056206e-02,  -2.47065372e-02,  -1.30913718e-02,
#         -9.78516959e-04,   1.15874174e-02,   2.45100405e-02,
#          3.76271162e-02,   5.07126949e-02,   6.34950146e-02,
#          7.56843415e-02,   8.70001562e-02,   9.71844756e-02,
#          1.05989981e-01,   1.13139315e-01,   1.18263176e-01,
#          1.20834575e-01,   1.20120678e-01,   1.15171225e-01,
#          1.04856061e-01,   8.79567246e-02,   6.33094691e-02,
#          2.99888289e-02,  -1.24882607e-02,  -6.39664508e-02,
#         -1.23498472e-01,  -1.89269485e-01,  -2.58630289e-01,
#         -3.28261131e-01,  -3.94473914e-01,  -4.53641851e-01,
#         -5.02720730e-01,  -5.39793117e-01,  -5.64524976e-01,
#         -5.78376227e-01,  -5.84357458e-01,  -5.86076702e-01])

# %%
f_SM, Pxx_den_SM = signal.welch(normalisedSM.SM)
f_NDVI, Pxx_den_NDVI = signal.welch(normalisedNDVI.NDVI)
#norm2LST = normLST.dropna()
f_LST, Pxx_den_LST = signal.welch(normalisedLST.LST)

plt.figure(num=1, figsize=(10,10))

plt.subplot(2,1,1)

plt.xlabel('normalised frequency [Hz]')
plt.ylabel('PSD [Amplitude**2/Hz]')
plt.title('Welch Power Spectral Density Estimate of NDVI compared against Soil Moisture')
#plt.xlim(0,0.15)

plt.semilogy(f_SM, Pxx_den_SM, 'c-')
plt.semilogy(f_NDVI, Pxx_den_NDVI, 'm-')
plt.legend(['SM','NDVI'])

plt.grid()
plt.subplot(2,1,2)

plt.xlabel('normalised frequency [Hz]')
plt.ylabel('PSD [Amplitude**2/Hz]')
plt.title('Welch Power Spectral Density Estimate of Land Surface Temperature compared against Soil Moisture')
#plt.xlim(0,0.15)

plt.semilogy(f_SM, Pxx_den_SM, 'c-')
plt.semilogy(f_LST, Pxx_den_LST, 'r-')
plt.legend(['SM','LST'])
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-149-f52f6a5bfc23> in <module>()
# ----> 1 f_SM, Pxx_den_SM = signal.welch(normalisedSM.SM)
#       2 f_NDVI, Pxx_den_NDVI = signal.welch(normalisedNDVI.NDVI)
#       3 #norm2LST = normLST.dropna()
#       4 f_LST, Pxx_den_LST = signal.welch(normalisedLST.LST)
#       5
#
# AttributeError: 'numpy.ndarray' object has no attribute 'SM'

# %% [markdown]
# And following is the power spectrum of NDVI and LST compared against SM

# %%
f_SM2, Pxx_spec_SM2 = signal.welch(normSM, window='flattop', scaling='spectrum')
f_NDVI2, Pxx_spec_NDVI2 = signal.welch(normNDVI, window='flattop', scaling='spectrum')
#norm2LST = normLST.dropna()
f_LST2, Pxx_spec_LST2 = signal.welch(norm2LST, window='flattop', scaling='spectrum')

plt.figure(num=1, figsize=(10,10))

plt.subplot(2,1,1)
plt.xlabel('Normalised Frequency [Hz]')
plt.ylabel('Linear spectrum [Amplitude RMS]')#e.g Volt RMS
plt.title('Welch Power Spectrum of NDVI compared against Soil Moisture')

plt.semilogy(f_SM2, np.sqrt(Pxx_spec_SM2), 'c-')
plt.semilogy(f_NDVI2, np.sqrt(Pxx_spec_NDVI2), 'm-')
plt.legend(['SM','NDVI'])

plt.grid()

plt.subplot(2,1,2)
plt.xlabel('Normalised Frequency [Hz]')
plt.ylabel('Linear spectrum [Amplitude RMS]')#e.g. Volt RMS
plt.title('Welch Power Spectrum of Land Surface Temperature compared against Soil Moisture')

plt.semilogy(f_SM2, np.sqrt(Pxx_spec_SM2), 'c-')
plt.semilogy(f_LST2, np.sqrt(Pxx_spec_LST2), 'r-')
plt.legend(['SM','LST'])
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-cbbf49f3e390> in <module>()
#      12
#      13 plt.semilogy(f_SM2, np.sqrt(Pxx_spec_SM2), 'c-')
# ---> 14 plt.semilogy(f_NDVI2, np.sqrt(Pxx_spec_NDVI2), 'm-')
#      15 plt.legend(['SM','NDVI'])
#      16
#
# D:\Python27\lib\site-packages\matplotlib\pyplot.pyc in semilogy(*args, **kwargs)
#    2967         ax.hold(hold)
#    2968     try:
# -> 2969         ret = ax.semilogy(*args, **kwargs)
#    2970         draw_if_interactive()
#    2971     finally:
#
# D:\Python27\lib\site-packages\matplotlib\axes.pyc in semilogy(self, *args, **kwargs)
#    4230         b =  self._hold
#    4231         self._hold = True # we've already processed the hold
# -> 4232         l = self.plot(*args, **kwargs)
#    4233         self._hold = b    # restore the hold
#    4234
#
# D:\Python27\lib\site-packages\matplotlib\axes.pyc in plot(self, *args, **kwargs)
#    3994         lines = []
#    3995
# -> 3996         for line in self._get_lines(*args, **kwargs):
#    3997             self.add_line(line)
#    3998             lines.append(line)
#
# D:\Python27\lib\site-packages\matplotlib\axes.pyc in _grab_next_args(self, *args, **kwargs)
#     328                 return
#     329             if len(remaining) <= 3:
# --> 330                 for seg in self._plot_args(remaining, kwargs):
#     331                     yield seg
#     332                 return
#
# D:\Python27\lib\site-packages\matplotlib\axes.pyc in _plot_args(self, tup, kwargs)
#     306             x = np.arange(y.shape[0], dtype=float)
#     307
# --> 308         x, y = self._xy_from_xy(x, y)
#     309
#     310         if self.command == 'plot':
#
# D:\Python27\lib\site-packages\matplotlib\axes.pyc in _xy_from_xy(self, x, y)
#     246         y = np.atleast_1d(y)
#     247         if x.shape[0] != y.shape[0]:
# --> 248             raise ValueError("x and y must have same first dimension")
#     249         if x.ndim > 2 or y.ndim > 2:
#     250             raise ValueError("x and y can be no greater than 2-D")
#
# ValueError: x and y must have same first dimension

# %%
norm2LST
