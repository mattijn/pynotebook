# %%
# %matplotlib inline
import scipy
from scipy import fftpack as fft

# %% [markdown]
# # NDVI Anomaly

# %%
import os
import pandas as pd
from osgeo import gdal
import numpy as np
import datetime
import matplotlib.pyplot as plt

def listall(RootFolder):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if 'NDVI' in name
                     if name.endswith('.tif')]
    return lists

# ______________________________________________________
# SET PIXEL ROW AND COLUMN


pixelrow = 879
pixelcolumn = 4142

# ______________________________________________________
# ANNUAL ACCUMULATED MEAN

li = []
da = []
i = 0
path = r'D:\Data\NDVIanomalytimeseries'# removed 'NormTypeII'
#path = r'D:\Data\GPCP_30acc_AnnualAcc'
test = listall(path)
test = test[0:-46]
print (len(test))
print (test[0])
for t in test:    
    raster = gdal.Open(t, gdal.GA_ReadOnly)
    nameRas = raster.GetDescription()[-11:-4]
    date = datetime.datetime(int(nameRas[0:4]), 1, 1) + datetime.timedelta(int(nameRas[4:9]) - 1) # replaced "int(nameRas[0:4])" with "2010" first year then add doy
    # print date
    da.append(date)

    band = raster.GetRasterBand(1)
    array = band.ReadAsArray()    
    
    # print array[879,4142] # Grassland pixel
    li.append(array[pixelrow, pixelcolumn])
    
    array = None
    band = None
    raster = None
    #print (str(i))
    i = i + 1
    
seriesNDVI = pd.Series(data = li, index = da)
NDVIanomaly = seriesNDVI

maxy = seriesNDVI.max()

print ('max', seriesNDVI.max(), NDVIanomaly.plot() )
# Out:
# 414
# D:\Data\NDVIanomalytimeseries\abs_NDVI_2001001.tif
# max
#  0.235750004649 Axes(0.125,0.2;0.775x0.7)

# %% [markdown]
# # NTAI

# %%
import os
import pandas as pd
from osgeo import gdal
import numpy as np

def listall(RootFolder):
    lists = [os.path.join(root, name)    
                 for root, dirs, files in os.walk(RootFolder)
                   for name in files
                   if 'NDVI' in name
                     if name.endswith('.tif')]
    return lists

# ______________________________________________________
# SET PIXEL ROW AND COLUMN

pixelrow = 879
pixelcolumn = 4142

# ______________________________________________________
# ANNUAL ACCUMULATED MEAN

li = []
da = []
i = 0
path = r'D:\Data\NVAI'# removed 'NormTypeII'
#path = r'D:\Data\GPCP_30acc_AnnualAcc'
test = listall(path)

print (len(test))
print (test[0])
for t in test:    
    raster = gdal.Open(t, gdal.GA_ReadOnly)
    nameRas = raster.GetDescription()[-11:-4]
    date = datetime.datetime(int(nameRas[0:4]), 1, 1) + datetime.timedelta(int(nameRas[4:9]) - 1) # replaced "int(nameRas[0:4])" with "2010" first year then add doy
    # print date
    da.append(date)

    band = raster.GetRasterBand(1)
    array = band.ReadAsArray()    
    
    # print array[879,4142] # Grassland pixel
    li.append(array[pixelrow, pixelcolumn])
    
    array = None
    band = None
    raster = None
    #print (str(i))
    i = i + 1
    
seriesNDVI = pd.Series(data = li, index = da)
NVAI = seriesNDVI
maxy = seriesNDVI.max()

print ('max', seriesNDVI.max(), NVAI.plot() )
# Out:
# 460
# D:\Data\NVAI\abs_NDVI_2001001.tif
# max
#  0.421509027481 Axes(0.125,0.2;0.775x0.7)

# %% [markdown]
# # VISUALIZATION OF TYPE-I AND TYPE-II

# %%
import matplotlib.pyplot as plt
import numpy as np


#______________________________
# TYPE-I

t = NDVIanomaly.index
signal = NDVIanomaly

FFT = abs(scipy.fft(signal))
timestep = t[1] - t[0]
freqs = scipy.fftpack.fftfreq(signal.size, timestep.days)

roll = int(len(freqs)/2)
t_FFT = np.roll(freqs,roll)
s_FFT = np.roll(FFT,roll)

fig = plt.figure(figsize=(14,10))

ax1 = fig.add_subplot(321)
ax1.bar(t,signal)
#ax1.fill_between(t, signal, where=signal>=0, facecolor='lightblue', interpolate=True)#, alpha=0.5)
#ax1.fill_between(t, signal, where=signal<=0, facecolor='orange', interpolate=True)#, alpha=0.5)
ax1.set_title('Standardized Anomaly')
ax1.grid(True)
ax1.axhline(0, color='grey', lw=2)

ax3 = fig.add_subplot(323)
ax3.acorr(signal, usevlines=True, normed=True, maxlags=50, lw=2)#, color='b')
ax3.set_title('Autocorrelation of the Standardized Anomaly')
ax3.grid(True)
ax3.axhline(0, color='grey', lw=2)

ax5 = fig.add_subplot(325)
ax5.plot(t_FFT,s_FFT,"-", color='black') # removed '20*scipy.log10(FFT)'
ax5.set_title('Frequency representation of the Standardized Anomaly')
ax5.grid(True)
#ax3.axhline(-10, color='grey', lw=2)

#______________________________
# TYPE-II

t = NVAI.index
signal = NVAI

FFT = abs(scipy.fft(signal))
timestep = t[1] - t[0]
freqs = scipy.fftpack.fftfreq(signal.size, timestep.days)

#fig = plt.figure(figsize=(12,10))

ax2 = fig.add_subplot(322)
ax2.bar(t,signal)
#ax1.fill_between(t, signal, where=signal>=0, facecolor='lightblue', interpolate=True)#, alpha=0.5)
#ax1.fill_between(t, signal, where=signal<=0, facecolor='orange', interpolate=True)#, alpha=0.5)
ax2.set_title('Standardized Anomaly')
ax2.grid(True)
ax2.axhline(0, color='grey', lw=2)

ax4 = fig.add_subplot(324)
ax4.acorr(signal, usevlines=True, normed=True, maxlags=50, lw=2)#, color='b')
ax4.set_title('Autocorrelation of the Standardized Anomaly')
ax4.grid(True)
ax4.axhline(0, color='grey', lw=2)

ax6 = fig.add_subplot(326)
ax6.plot(t_FFT,s_FFT,"-", color='black') # removed '20*scipy.log10(FFT)'
ax6.set_title('Frequency representation of the Standardized Anomaly')
ax6.grid(True)
#ax3.axhline(-10, color='grey', lw=2)

plt.tight_layout()
print('Visualization TYPE-II')
plt.show()
# Out:
# Visualization TYPE-II

# %%
timestep = GPCPnormTypeII.index[1] - GPCPnormTypeII.index[0]

# %%
int(roll/2)
# Out:
# 230

# %%
roll = int(len(freqs)/2)
np.roll(freqs,roll)
# Out:
# array([-0.0625    , -0.06222826, -0.06195652, -0.06168478, -0.06141304,
#        -0.0611413 , -0.06086957, -0.06059783, -0.06032609, -0.06005435,
#        -0.05978261, -0.05951087, -0.05923913, -0.05896739, -0.05869565,
#        -0.05842391, -0.05815217, -0.05788043, -0.0576087 , -0.05733696,
#        -0.05706522, -0.05679348, -0.05652174, -0.05625   , -0.05597826,
#        -0.05570652, -0.05543478, -0.05516304, -0.0548913 , -0.05461957,
#        -0.05434783, -0.05407609, -0.05380435, -0.05353261, -0.05326087,
#        -0.05298913, -0.05271739, -0.05244565, -0.05217391, -0.05190217,
