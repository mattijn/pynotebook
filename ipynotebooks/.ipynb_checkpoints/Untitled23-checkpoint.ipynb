# %%
from osgeo import gdal

# %%
path = r'E:\Data\DataTimeSeries\2007\NDVI//NDVI_2007089.tif'
raster = gdal.Open(path, gdal.GA_ReadOnly)
band = raster.GetRasterBand(1)
arr_NDVI = band.ReadAsArray()

# %%
plt.imshow(arr_NDVI)

# %%
arr_NDVI.shape
# Out:
# (3537, 6163)

# %%
for x in range(5000000):
    print x

# %%
print ('ok')
