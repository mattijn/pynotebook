# %%
def inRaster(fileDEM):
    raster = gdal.Open(fileDEM, gdal.GA_ReadOnly)
    band = raster.GetRasterBand(1)
    dem = band.ReadAsArray()
    extent = raster.GetGeoTransform()
    return raster, dem, extent

# %%
from osgeo import gdal
import numpy as np
import pandas as pd

# %%
fileDEM = r'I:/Data/baseline\\DOY2002170_2002173.tif'
raster, array, extent = inRaster(fileDEM)
arraymask = np.ma.masked_equal(array, 65535.)

# %%
testmap = plt.imshow ( arraymask, interpolation='nearest', vmin=0, cmap=plt.cm.gist_earth)

# %%
plt.colorbar(testmap)
plt.show()

# %%
arraymask
# Out:
# masked_array(data = <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x0509E950> >,
#              mask = False,
#        fill_value = 65535.0)

# %%
raster
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x0509E950> >

# %%
array
# Out:
# array([[ 65535.,  65535.,  65535., ...,  65535.,  65535.,  65535.],
#        [ 65535.,  65535.,  65535., ...,  65535.,  65535.,  65535.],
#        [ 65535.,  65535.,  65535., ...,  65535.,  65535.,  65535.],
#        ...,
#        [ 65535.,  65535.,  65535., ...,  65535.,  65535.,  65535.],
#        [ 65535.,  65535.,  65535., ...,  65535.,  65535.,  65535.],
#        [ 65535.,  65535.,  65535., ...,  65535.,  65535.,  65535.]], dtype=float32)
