# %%
import os
import pandas as pd
import numpy as np

# %%
path = r'I:\Documents\Klusjes\GIDS Interpolation Air Temperature\2009'

# %%
def rasterList(varpath, endwith, namefile):
    # 1 - Precipitation
    input_folder = varpath
    varList = [os.path.join(root, name)
                 for root, dirs, files in os.walk(input_folder)
                 for name in files
                 if name.endswith((endwith))]
    print namefile + " files : "  + str(len(varList))
    return varList

# %%
q = rasterList(path,'.op','stations')
# Out:
# stations files : 391

# %%
date
# Out:
# 20090101

# %%
series = pd.Series(str(date))
list_ = []
for q_ in q:    
    with open(q_) as f:
        reader = csv.reader((f),delimiter=' ')
        reader.next()    
        for row in reader:
            if row[3] == str(date):
                if len(row[7]):                
                    g = float(row[7])
                    series.append(g)
                    list_.append(g)                
                elif len(row[8]):
                    g = float(row[8])
                    series.append(g)
                    list_.append(g)                
                elif len(row[6]):
                    g = float(row[6])
                    series.append(g)
                    list_.append(g)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-146-2cf3831905f2> in <module>()
#       9                 if len(row[7]):
#      10                     g = float(row[7])
# ---> 11                     series.append(g)
#      12                     list_.append(g)
#      13                 elif len(row[8]):
#
# D:\Python27\lib\site-packages\pandas\core\series.pyc in append(self, to_append, verify_integrity)
#    2038             to_concat = [self, to_append]
#    2039         return concat(to_concat, ignore_index=False,
# -> 2040                       verify_integrity=verify_integrity)
#    2041
#    2042     def _binop(self, other, func, level=None, fill_value=None):
#
# D:\Python27\lib\site-packages\pandas\tools\merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity)
#     876                        ignore_index=ignore_index, join=join,
#     877                        keys=keys, levels=levels, names=names,
# --> 878                        verify_integrity=verify_integrity)
#     879     return op.get_result()
#     880
#
# D:\Python27\lib\site-packages\pandas\tools\merge.pyc in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity)
#     952         self.verify_integrity = verify_integrity
#     953
# --> 954         self.new_axes = self._get_new_axes()
#     955
#     956     def get_result(self):
#
# D:\Python27\lib\site-packages\pandas\tools\merge.pyc in _get_new_axes(self)
#    1144             concat_axis = None
#    1145         else:
# -> 1146             concat_axis = self._get_concat_axis()
#    1147
#    1148         new_axes[self.axis] = concat_axis
#
# D:\Python27\lib\site-packages\pandas\tools\merge.pyc in _get_concat_axis(self)
#    1161         if self._is_series:
#    1162             if self.axis == 0:
# -> 1163                 indexes = [x.index for x in self.objs]
#    1164             elif self.keys is None:
#    1165                 names = []
#
# AttributeError: 'float' object has no attribute 'index'

# %%
x = pd.Series()
# Out:
# [58.4,
#  51.8,
#  55.7,
#  58.6,
#  57.6,
#  61.8,
#  23.0,
#  8.0,
#  -3.2,
#  8.0,
#  5.9,
#  8.0,
#  -2.3,
#  -6.9,
#  -2.7,
#  8.0,
#  0.7,
#  0.6,
#  8.0,
#  1.2,
#  2.0,
#  3.1,
#  7.3,
#  6.3,
#  1.8,
#  15.3,
#  -4.1,
#  6.8,
#  5.3,
#  0.9,
#  -0.4,
#  13.0,
#  13.3,
#  3.9,
#  3.5,
#  -2.2,
#  14.6,
#  12.5,
#  8.8,
#  12.7,
#  9.6,
#  0.9,
#  21.4,
#  9.4,
#  8.7,
#  14.3,
#  16.1,
#  -4.2,
#  18.6,
#  15.6,
#  20.5,
#  25.3,
#  9.2,
#  22.3,
#  20.5,
#  7.5,
#  13.4,
#  14.3,
#  20.6,
#  19.9,
#  22.5,
#  10.6,
#  8.4,
#  14.1,
#  7.7,
#  8.6,
#  5.5,
#  10.7,
#  10.1,
#  9.7,
#  7.1,
#  19.8,
#  7.5,
#  10.6,
#  17.2,
#  9.8,
#  12.8,
#  11.6,
#  10.4,
#  16.0,
#  12.4,
#  19.4,
#  -1.9,
#  11.7,
#  21.9,
#  18.0,
#  -2.4,
#  -5.4,
#  12.4,
#  -6.3,
#  7.4,
#  11.5,
#  7.2,
#  8.0,
#  5.2,
#  9.8,
#  8.8,
#  10.9,
#  9.6,
#  13.5,
#  15.7,
#  17.2,
#  10.2,
#  15.6,
#  10.3,
#  18.3,
#  18.2,
#  19.0,
#  27.7,
#  19.6,
#  16.9,
#  16.3,
#  18.4,
#  16.3,
#  28.0,
#  20.3,
#  18.1,
#  25.1,
#  25.4,
#  24.9,
#  25.0,
#  21.8,
#  -4.7,
#  14.9,
#  11.7,
#  8.7,
#  11.5,
#  10.1,
#  -4.4,
#  7.8,
#  10.3,
#  6.0,
#  5.7,
#  2.2,
#  8.7,
#  -6.5,
#  11.7,
#  12.5,
#  10.9,
#  6.2,
#  5.5,
#  15.5,
#  14.4,
#  7.6,
#  14.2,
#  22.1,
#  7.7,
#  7.3,
#  11.1,
#  7.5,
#  13.3,
#  1.4,
#  16.3,
#  17.2,
#  10.2,
#  16.8,
#  16.4,
#  14.9,
#  22.1,
#  22.3,
#  23.0,
#  22.7,
#  16.0,
#  23.1,
#  26.8,
#  22.7,
#  23.0,
#  23.4,
#  23.1,
#  29.4,
#  29.3,
#  30.9,
#  24.1,
#  24.3,
#  14.4,
#  23.8,
#  23.8,
#  25.3,
#  27.8,
#  24.8,
#  26.4,
#  25.3,
#  27.7,
#  5.2,
#  5.2,
#  9.5,
#  8.7,
#  28.1,
#  30.2,
#  18.4,
#  25.4,
#  16.3,
#  -0.1,
#  17.3,
#  7.5,
#  24.0,
#  4.0,
#  13.8,
#  15.2,
#  22.2,
#  17.6,
#  39.7,
#  17.6,
#  18.5,
#  28.8,
#  29.9,
#  30.6,
#  17.3,
#  31.5,
#  32.3,
#  25.1,
#  41.1,
#  41.6,
#  41.7,
#  23.8,
#  41.3,
#  42.1,
#  33.9,
#  22.8,
#  25.0,
#  16.4,
#  29.2,
#  35.1,
#  44.4,
#  46.0,
#  32.5,
#  40.1,
#  44.9,
#  39.3,
#  32.3,
#  50.6,
#  51.0,
#  50.4,
#  56.9,
#  50.2,
#  50.3,
#  43.6,
#  57.6,
#  41.4,
#  55.8,
#  54.3,
#  59.6,
#  64.5,
#  58.7,
#  64.2,
#  60.5,
#  57.6,
#  52.1,
#  31.8,
#  26.1,
#  29.1,
#  23.8,
#  28.9,
#  29.0,
#  28.3,
#  37.7,
#  29.5,
#  32.0,
#  29.0,
#  37.7,
#  41.1,
#  34.8,
#  33.8,
#  34.0,
#  30.0,
#  31.1,
#  43.0,
#  43.1,
#  45.8,
#  37.4,
#  35.9,
#  43.4,
#  42.2,
#  40.1,
#  39.5,
#  38.8,
#  38.4,
#  68.1,
#  44.3,
#  38.2,
#  38.5,
#  36.8,
#  44.1,
#  37.9,
#  40.5,
#  39.2,
#  39.9,
#  33.4,
#  42.9,
#  41.0,
#  41.2,
#  24.9,
#  40.5,
#  40.7,
#  30.9,
#  36.9,
#  38.5,
#  39.9,
#  41.0,
#  37.0,
#  46.9,
#  35.1,
#  44.5,
#  44.0,
#  41.2,
#  42.5,
#  26.3,
#  26.7,
#  28.6,
#  27.3,
#  30.5,
#  26.1,
#  30.3,
#  27.7,
#  29.4,
#  30.4,
#  32.9,
#  27.5,
#  29.6,
#  35.7,
#  30.9,
#  31.0,
#  34.7,
#  34.0,
#  34.7,
#  21.0,
#  33.4,
#  36.2,
#  37.5,
#  25.2,
#  38.6,
#  33.0,
#  35.7,
#  39.5,
#  35.5,
#  37.9,
#  37.7,
#  37.8,
#  39.4,
#  38.8,
#  41.5,
#  37.6,
#  41.6,
#  40.9,
#  39.7,
#  43.1,
#  46.9,
#  40.5,
#  44.0,
#  46.3,
#  33.7,
#  49.1,
#  51.3,
#  41.9,
#  50.3,
#  48.6,
#  47.8,
#  44.4,
#  45.3,
#  51.4,
#  47.9,
#  45.6,
#  49.8,
#  49.7,
#  47.6,
#  53.2,
#  52.9,
#  51.3,
#  55.2,
#  54.0,
#  40.4,
#  50.2,
#  53.4,
#  57.3,
#  50.8,
#  56.5,
#  57.5,
#  56.2,
#  54.5,
#  54.2,
#  55.3,
#  55.4,
#  56.8,
#  59.7,
#  67.1,
#  60.3,
#  56.0,
#  60.6,
#  59.4,
#  78.5]

# %%
# Out:
# 82.8

# %%
list_ = []
with open(q[10]) as f:
    reader = csv.reader((f),delimiter=' ')
    reader.next()    
    for row in reader:
        if row[3] == str(date):
            if len(row[7]):                
                g = row[7]
                list_.append(g)                
            elif len(row[8]):
                g = row[8]
                list_.append(g)                
            elif len(row[6]):
                g = row[6]
                list_.append(g)

# %%
list_
# Out:
# ['5.9']

# %%
df = pd.DataFrame(pd.Series())
df.append('date',g)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-1673eaef8090> in <module>()
#       1 df = pd.DataFrame(pd.Series())
# ----> 2 df.append('date',g)
#
# D:\Python27\lib\site-packages\pandas\core\frame.pyc in append(self, other, ignore_index, verify_integrity)
#    4606             to_concat = [self, other]
#    4607         return concat(to_concat, ignore_index=ignore_index,
# -> 4608                       verify_integrity=verify_integrity)
#    4609
#    4610     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# D:\Python27\lib\site-packages\pandas\tools\merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity)
#     876                        ignore_index=ignore_index, join=join,
#     877                        keys=keys, levels=levels, names=names,
# --> 878                        verify_integrity=verify_integrity)
#     879     return op.get_result()
#     880
#
# D:\Python27\lib\site-packages\pandas\tools\merge.pyc in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity)
#     952         self.verify_integrity = verify_integrity
#     953
# --> 954         self.new_axes = self._get_new_axes()
#     955
#     956     def get_result(self):
#
# D:\Python27\lib\site-packages\pandas\tools\merge.pyc in _get_new_axes(self)
#    1129                 if i == self.axis:
#    1130                     continue
# -> 1131                 new_axes[i] = self._get_comb_axis(i)
#    1132         else:
#    1133             if not ((len(self.join_axes) == ndim - 1)):
#
# D:\Python27\lib\site-packages\pandas\tools\merge.pyc in _get_comb_axis(self, i)
#    1154             all_indexes = [x.index for x in self.objs]
#    1155         else:
# -> 1156             all_indexes = [x._data.axes[i] for x in self.objs]
#    1157
#    1158         return _get_combined_index(all_indexes, intersect=self.intersect)
#
# AttributeError: 'str' object has no attribute '_data'

# %%
# Out:
# '20090101'
