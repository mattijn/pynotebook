# %%
import pandas as pd

# %%
url = r'P:\Pr\3427.10\werkmap\PrecipitationShowcase\FEWS_BACKUP\Config\MapLayerFiles//GSOD_locations_Myanmar.csv'
df = pd.read_csv(url)

# %%
df.shape
# Out:
# (59, 7)

# %%
for idx in range(df.shape[0]):
    row = df.ix[idx]
    print (r'<stationName>'+str(row['NAME'])+r'</stationName>')
    print (r'<lat>'+str(row['LAT'])+r'</lat>')
    print (r'<lon>'+str(row['LON'])+r'</lon>')
    print ('\n')
# Out:
# <stationName>PUTAO</stationName>
# <lat>27.333</lat>
# <lon>97.417</lon>
#
#
# <stationName>HKAMTI</stationName>
# <lat>26.0</lat>
# <lon>95.7</lon>
#
#
# <stationName>MYITKYINA</stationName>
# <lat>25.367</lat>
# <lon>97.4</lon>
#
#
# <stationName>HOMALIN</stationName>
# <lat>24.867</lat>
# <lon>94.917</lon>
#
#
# <stationName>PINLEBU</stationName>
# <lat>24.083</lat>
# <lon>95.367</lon>
#
#
# <stationName>KATHA</stationName>
# <lat>24.167</lat>
# <lon>96.333</lon>
#
#
# <stationName>BHAMO</stationName>
# <lat>24.267</lat>
# <lon>97.2</lon>
#
#
# <stationName>MAWLAIK</stationName>
# <lat>23.633</lat>
# <lon>94.417</lon>
#
#
# <stationName>KALEMYO</stationName>
# <lat>23.2</lat>
# <lon>94.067</lon>
#
#
# <stationName>KALEWA</stationName>
# <lat>23.2</lat>
# <lon>94.3</lon>
#
#
# <stationName>HAKHA</stationName>
# <lat>22.65</lat>
# <lon>93.633</lon>
#
#
# <stationName>FALAM</stationName>
# <lat>22.917</lat>
# <lon>93.683</lon>
#
#
# <stationName>SHWEBO</stationName>
# <lat>22.583</lat>
# <lon>95.717</lon>
#
#
# <stationName>LASHIO</stationName>
# <lat>22.933</lat>
# <lon>97.75</lon>
#
#
# <stationName>GANGAW</stationName>
# <lat>22.167</lat>
# <lon>94.133</lon>
#
#
# <stationName>MONYWA</stationName>
# <lat>22.1</lat>
# <lon>95.133</lon>
#
#
# <stationName>HSIPAW</stationName>
# <lat>22.6</lat>
# <lon>97.3</lon>
#
#
# <stationName>MANDALAY</stationName>
# <lat>21.983</lat>
# <lon>96.1</lon>
#
#
# <stationName>MINDAT</stationName>
# <lat>21.383</lat>
# <lon>93.95</lon>
#
#
# <stationName>PAKOKKU</stationName>
# <lat>21.333</lat>
# <lon>95.083</lon>
#
#
# <stationName>MYINGYAN</stationName>
# <lat>21.467</lat>
# <lon>95.383</lon>
#
#
# <stationName>NYAUNG-U</stationName>
# <lat>21.2</lat>
# <lon>94.917</lon>
#
#
# <stationName>KYAUKTAW</stationName>
# <lat>20.85</lat>
# <lon>92.633</lon>
#
#
# <stationName>CHAUK</stationName>
# <lat>20.9</lat>
# <lon>94.833</lon>
#
#
# <stationName>MEIKTILA</stationName>
# <lat>20.833</lat>
# <lon>95.833</lon>
#
#
# <stationName>TAUNGGYI</stationName>
# <lat>20.783</lat>
# <lon>97.05</lon>
#
#
# <stationName>LOILEM</stationName>
# <lat>20.917</lat>
# <lon>97.55</lon>
#
#
# <stationName>KENGTUNG</stationName>
# <lat>21.3</lat>
# <lon>99.617</lon>
#
#
# <stationName>SITTWE</stationName>
# <lat>20.133</lat>
# <lon>92.873</lon>
#
#
# <stationName>MINBU</stationName>
# <lat>20.167</lat>
# <lon>94.883</lon>
#
#
# <stationName>YAMETHIN</stationName>
# <lat>20.417</lat>
# <lon>96.15</lon>
#
#
# <stationName>PINLAUNG</stationName>
# <lat>20.133</lat>
# <lon>96.767</lon>
#
#
# <stationName>MONGHSAT</stationName>
# <lat>20.55</lat>
# <lon>99.267</lon>
#
#
# <stationName>KYAUKPYU</stationName>
# <lat>19.417</lat>
# <lon>93.55</lon>
#
#
# <stationName>MANAUNG</stationName>
# <lat>18.85</lat>
# <lon>93.733</lon>
#
#
# <stationName>PYINMANA</stationName>
# <lat>19.717</lat>
# <lon>96.217</lon>
#
#
# <stationName>LOIKAW</stationName>
# <lat>19.683</lat>
# <lon>97.217</lon>
#
#
# <stationName>PROME</stationName>
# <lat>18.8</lat>
# <lon>95.217</lon>
#
#
# <stationName>TOUNGOO</stationName>
# <lat>18.917</lat>
# <lon>96.467</lon>
#
#
# <stationName>SANDOWAY</stationName>
# <lat>18.467</lat>
# <lon>94.35</lon>
#
#
# <stationName>GWA</stationName>
# <lat>17.583</lat>
# <lon>94.583</lon>
#
#
# <stationName>HINTHADA</stationName>
# <lat>17.667</lat>
# <lon>95.417</lon>
#
#
# <stationName>THARRAWADDY</stationName>
# <lat>17.633</lat>
# <lon>95.8</lon>
#
#
# <stationName>SHWEGYIN</stationName>
# <lat>17.917</lat>
# <lon>96.867</lon>
#
#
# <stationName>BAGO</stationName>
# <lat>17.333</lat>
# <lon>96.5</lon>
#
#
# <stationName>PATHEIN</stationName>
# <lat>16.767</lat>
# <lon>94.767</lon>
#
#
# <stationName>MAUBIN</stationName>
# <lat>16.733</lat>
# <lon>95.65</lon>
#
#
# <stationName>MINGALADON</stationName>
# <lat>16.9</lat>
# <lon>96.183</lon>
#
#
# <stationName>YANGON INTL</stationName>
# <lat>16.907</lat>
# <lon>96.133</lon>
#
#
# <stationName>THATON</stationName>
# <lat>16.917</lat>
# <lon>97.367</lon>
#
#
# <stationName>HPAAN</stationName>
# <lat>16.75</lat>
# <lon>97.667</lon>
#
#
# <stationName>BILIN</stationName>
# <lat>17.217</lat>
# <lon>97.233</lon>
#
#
# <stationName>PHYAPON</stationName>
# <lat>16.267</lat>
# <lon>95.667</lon>
#
#
# <stationName>MAWLAMYINE</stationName>
# <lat>16.5</lat>
# <lon>97.617</lon>
#
#
# <stationName>YE</stationName>
# <lat>15.25</lat>
# <lon>97.867</lon>
#
#
# <stationName>DAWEI</stationName>
# <lat>14.1</lat>
# <lon>98.217</lon>
#
#
# <stationName>COCO ISLAND</stationName>
# <lat>14.117</lat>
# <lon>93.367</lon>
#
#
# <stationName>MERGUI</stationName>
# <lat>12.433</lat>
# <lon>98.6</lon>
#
#
# <stationName>VICTORIA POINT</stationName>
# <lat>9.967</lat>
# <lon>98.583</lon>

# %%
print (r'<stationName>'+str(row['NAME'])+r'</stationName>')
print (r'<lat>'+str(row['LAT'])+r'</lat>')
print (r'<lon>'+str(row['LON'])+r'</lon>')
print ('\n')
# Out:
# <stationName>VICTORIA POINT</stationName>
# <lat>9.967</lat>
# <lon>98.583</lon>

# %%
row
# Out:
# WMO                  481120
# NAME         VICTORIA POINT
# LAT                   9.967
# LON                  98.583
# ELEVATION                47
# START              19460101
# END                20170401
# Name: 58, dtype: object
