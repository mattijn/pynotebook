# %%
from scipy import stats
from scipy.spatial.distance import cdist
from scipy.spatial import cKDTree as KDTree
import statsmodels.api as sm
import numpy as np
import pandas as pd
import gdal
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def inRaster(file_raster):
    raster = gdal.Open(file_raster, gdal.GA_ReadOnly)
    band = raster.GetRasterBand(1)
    array = band.ReadAsArray()
    extent = raster.GetGeoTransform()
    return raster, array, extent

# %%
def saveRaster(path, array, raster, datatype=6, formatraster="GTiff"):
    # Set Driver
    format_ = formatraster #save as format
    driver = gdal.GetDriverByName( format_ )
    driver.Register()
    
    # Set Metadata for Raster output
    cols = raster.RasterXSize
    rows = raster.RasterYSize
    bands = raster.RasterCount
    datatype = 6#band.DataType
    
    # Set Projection for Raster
    outDataset = driver.Create(path, cols, rows, bands, datatype)
    geoTransform = raster.GetGeoTransform()
    outDataset.SetGeoTransform(geoTransform)
    proj = raster.GetProjection()
    outDataset.SetProjection(proj)
    
    # Write output to band 1 of new Raster
    outBand = outDataset.GetRasterBand(1)
    outBand.WriteArray(array) #save input array
    #outBand.WriteArray(dem)
    
    # Close and finalise newly created Raster
    #F_M01 = None
    outBand = None
    proj = None
    geoTransform = None
    outDataset = None
    driver = None
    datatype = None
    bands = None
    rows = None
    cols = None
    driver = None
    array = None

# %%
def cartesian(arrays, out=None):
    """
    Generate a cartesian product of input arrays.

    Parameters
    ----------
    arrays : list of array-like
        1-D arrays to form the cartesian product of.
    out : ndarray
        Array to place the cartesian product in.

    Returns
    -------
    out : ndarray
        2-D array of shape (M, len(arrays)) containing cartesian products
        formed of input arrays.

    Examples
    --------
    >>> cartesian(([1, 2, 3], [4, 5], [6, 7]))
    array([[1, 4, 6],
           [1, 4, 7],
           [1, 5, 6],
           [1, 5, 7],
           [2, 4, 6],
           [2, 4, 7],
           [2, 5, 6],
           [2, 5, 7],
           [3, 4, 6],
           [3, 4, 7],
           [3, 5, 6],
           [3, 5, 7]])

    """

    arrays = [np.asarray(x) for x in arrays]
    dtype = arrays[0].dtype

    n = np.prod([x.size for x in arrays])
    if out is None:
        out = np.zeros([n, len(arrays)], dtype=dtype)

    m = n / arrays[0].size
    out[:,0] = np.repeat(arrays[0], m)
    if arrays[1:]:
        cartesian(arrays[1:], out=out[0:m,1:])
        for j in range(1, arrays[0].size):
            out[j*m:(j+1)*m,1:] = out[0:m,1:]
    return out

# %%
# read locations file and set station code as object type and change columns names
locations_file = r'D:\Projects\Pr\3492.10\KNMI//locations.csv'
locations = pd.read_csv(locations_file)
locations['SCODE'] = locations['SCODE'].astype(str).str.zfill(3)
locations.rename(columns = {'X':'X_RD'}, inplace = True)
locations.rename(columns = {'Y':'Y_RD'}, inplace = True)
locations.head()
# Out:
#    HCODE SCODE   LON    LAT       X_RD       Y_RD      Z       SNAAM
# 0      1   210  4.42  52.16   88757.74  464535.30 -43.51  VALKENBURG
# 1      2   225  4.58  52.46   99802.05  497559.47 -38.40    IJMUIDEN
# 2      3   235  4.79  52.92  114500.72  548715.77 -41.46     DE_KOOY
# 3      4   240  4.77  52.30  113173.42  479401.88 -47.49    SCHIPHOL
# 4      5   242  4.94  53.26  125286.46  585474.16 -40.43    VLIELAND

# %%
# read csv data, and skip the first 81 rows and for each column skip the initial spaces
data_file = r'D:\Projects\Pr\3492.10\KNMI\KNMI_20170130_hourly//KNMI_20170130_hourly.txt'
data = pd.read_csv(data_file, skiprows=81, sep=',', skipinitialspace=True)

# for the hours subtract 1 as pandas daterange for hour goes from 0 - 23 
# but data reported from 1 - 24
data['HH'] = data['HH'] - 1
data['HH'] = data['HH'].astype(str).str.zfill(2)

# convert location id from int64 to object 
data['STN'] = data['STN'].astype(str).str.zfill(3)

# combine column year-month-day with column hour and convert to datetime
data['Datum'] = data['YYYYMMDD'].map(str) + data['HH']
data['Datum'] = pd.to_datetime(data['Datum'], format='%Y%m%d%H')

# join the data and location table on station name
data = pd.merge(data, locations, how='inner', left_on='STN', right_on='SCODE')

# set multiindex based on location and datum column
data.set_index(['STN','Datum'], inplace=True) # 
# display head(5)
#data.head()

# %%
# parameter to use for interpoltation
columns = 'T'
conversion = 0.1
stat = 'max'

# select colums with parameter and the X/Y coordinates in RD projection
data = data[[columns,'X_RD','Y_RD']]

# next lines are important!@
# resample from hour values to daily values taking the AVERAGE value of the day
level_values = data.index.get_level_values
if stat == 'max':
    data_day = (data.groupby([level_values(i) for i in [0]] + [pd.Grouper(freq='1D', level=-1)]).max())
if stat == 'min':
    data_day = (data.groupby([level_values(i) for i in [0]] + [pd.Grouper(freq='1D', level=-1)]).min())
if stat == 'mean':
    data_day = (data.groupby([level_values(i) for i in [0]] + [pd.Grouper(freq='1D', level=-1)]).mean())

# apply conversion for temperature as the notation is in 0.1 degrees Celsius (at +1.5 mNAP)
data_day[columns] *= conversion
data_day = data_day[pd.notnull(data_day[columns])]

# display head(5)
data_day.head()
# Out:
#                   T      X_RD      Y_RD
# STN Datum
# 210 2016-01-01  8.1  88757.74  464535.3
#     2016-01-02  7.2  88757.74  464535.3
#     2016-01-03  8.8  88757.74  464535.3
#     2016-01-04  7.7  88757.74  464535.3
#     2016-01-05  7.6  88757.74  464535.3

# %%
# select first day of which data is available
date_selected = data_day.index.get_level_values('Datum').unique()[0]

# select all datA from stations that has data for this selected datE
day_df = data_day.iloc[data_day.index.get_level_values('Datum') == date_selected]

tree = KDTree(list(zip(day_df['X_RD'],day_df['Y_RD'])), leafsize=11)
    
day_df.head()
# Out:
#                   T       X_RD       Y_RD
# STN Datum
# 210 2016-01-01  8.1   88757.74  464535.30
# 235 2016-01-01  8.7  114500.72  548715.77
# 240 2016-01-01  7.8  113173.42  479401.88
# 242 2016-01-01  9.1  125286.46  585474.16
# 249 2016-01-01  8.2  127371.42  517467.65

# %%
# table data is finished and right shape, next load a template raster to use as base for interpolation

# %%
# read grid as template for IDW application
file_EUMETSAT = r'D:\Projects\Pr\3492.10\DIDSLF_NL//RD_prj_base.tif'
raster, array, extent = inRaster(file_EUMETSAT)

# plot as test
plt.imshow(array)
plt.show()

# create array with all coordinates in array using the extent
x_steps = np.arange(array.shape[1]) * extent[1]
y_steps = np.arange(array.shape[0]) * extent[-1]        
x_coords = extent[0] + x_steps + extent[1]/2
y_coords = extent[3] + y_steps + extent[-1]/2        
xy = cartesian([x_coords, y_coords])
print ('xy coordinates shape:', xy.shape, '\nlooks like:\n',xy[0:5])
array = array.T
# Out:
# xy coordinates shape: (8200, 2)
# looks like:
#  [[ -40837.58244589  696043.65059201]
#  [ -40837.58244589  691043.65059201]
#  [ -40837.58244589  686043.65059201]
#  [ -40837.58244589  681043.65059201]
#  [ -40837.58244589  676043.65059201]]
# c:\python35\lib\site-packages\ipykernel\__main__.py:46: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# c:\python35\lib\site-packages\ipykernel\__main__.py:48: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
# %%timeit 170x times quicker than the single np.dot approach
# IDW KDTREE
dist, idx = tree.query(xy, k=8, eps=0, p=1)
#columns = 'T'
tmp = day_df[[columns]].values.T[:, idx, None]
tmp = np.squeeze(tmp)
weights = (1/dist)**2
q = np.sum(weights, axis=1)
q = q[:,None]
weightsq =  weights / q
wz = np.einsum("ij,ij->i", weightsq, tmp)

# reshape to shape array
outArray = wz.reshape([array.shape[0],array.shape[1]]).T

# %%
# plot the result for checking purposes
plt.imshow(outArray)
plt.show()

# %%
# save the file
baseDir = r'D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//'
path_out = os.path.join(baseDir, columns+stat+r'_2016-01-01.tif')
print ('path to save: ',path_out)
#saveRaster(path_out, outArray, raster)
# Out:
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_2016-01-01.tif

# %%
# Do it in batch mode!

# %%
# select first day of which data is available
for date_selected in data_day.index.get_level_values('Datum').unique():

    # select all datA from stations that has data for this selected datE
    day_df = data_day.iloc[data_day.index.get_level_values('Datum') == date_selected]

    tree = KDTree(list(zip(day_df['X_RD'],day_df['Y_RD'])), leafsize=11)

    # IDW KDTREE
    dist, idx = tree.query(xy, k=8, eps=0, p=1)
    #columns = 'T'
    tmp = day_df[[columns]].values.T[:, idx, None]
    tmp = np.squeeze(tmp)
    weights = (1/dist)**2
    q = np.sum(weights, axis=1)
    q = q[:,None]
    weightsq =  weights / q
    wz = np.einsum("ij,ij->i", weightsq, tmp)

    # reshape to shape array
    outArray = wz.reshape([array.shape[0],array.shape[1]]).T   
#     im = plt.imshow(outArray)
#     plt.colorbar()
#     plt.show()

    # save the file
    file_out = columns+stat+'_'+date_selected.strftime('%Y%m%d')+'_'+str(date_selected.dayofyear).zfill(3)+'.tif'
    path_out = os.path.join(baseDir, file_out)
    print ('path to save: ',path_out)
    saveRaster(path_out, outArray, raster)
# Out:
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160101_001.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160102_002.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160103_003.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160104_004.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160105_005.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160106_006.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160107_007.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160108_008.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160109_009.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160110_010.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160111_011.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160112_012.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160113_013.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160114_014.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160115_015.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160116_016.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160117_017.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160118_018.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160119_019.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160120_020.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160121_021.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160122_022.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160123_023.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160124_024.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160125_025.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160126_026.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160127_027.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160128_028.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160129_029.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160130_030.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160131_031.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160201_032.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160202_033.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160203_034.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160204_035.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160205_036.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160206_037.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160207_038.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160208_039.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160209_040.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160210_041.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160211_042.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160212_043.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160213_044.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160214_045.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160215_046.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160216_047.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160217_048.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160218_049.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160219_050.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160220_051.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160221_052.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160222_053.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160223_054.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160224_055.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160225_056.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160226_057.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160227_058.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160228_059.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160229_060.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160301_061.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160302_062.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160303_063.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160304_064.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160305_065.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160306_066.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160307_067.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160308_068.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160309_069.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160310_070.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160311_071.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160312_072.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160313_073.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160314_074.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160315_075.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160316_076.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160317_077.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160318_078.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160319_079.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160320_080.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160321_081.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160322_082.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160323_083.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160324_084.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160325_085.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160326_086.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160327_087.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160328_088.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160329_089.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160330_090.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160331_091.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160401_092.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160402_093.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160403_094.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160404_095.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160405_096.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160406_097.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160407_098.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160408_099.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160409_100.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160410_101.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20160411_102.tif
# path to save:  D:\Projects\Pr\3492.10\KNMI\InterpolatedData\Tmax//Tmax_20