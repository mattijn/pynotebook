# %%
import untangle

# %%
url = r'C:\Users\Hoek\Sumo\v0.1.2\edgDump.xml'

# %%
obj = untangle.parse(url)

# %%
edges = []
for interval in obj.meandata.interval:
    edges.append(interval)

# %%
edges
# Out:
# [Element(name = interval, attributes = {'begin': '0.00', 'id': 'SIOtoSIW', 'end': '600.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ),
#  Element(name = interval, attributes = {'begin': '600.00', 'id': 'SIOtoSIW', 'end': '1200.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ),
#  Element(name = interval, attributes = {'begin': '1200.00', 'id': 'SIOtoSIW', 'end': '1800.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ),
#  Element(name = interval, attributes = {'begin': '1800.00', 'id': 'SIOtoSIW', 'end': '2400.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ),
#  Element(name = interval, attributes = {'begin': '2400.00', 'id': 'SIOtoSIW', 'end': '3000.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ),
#  Element(name = interval, attributes = {'begin': '3000.00', 'id': 'SIOtoSIW', 'end': '3600.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ),
#  Element(name = interval, attributes = {'begin': '3600.00', 'id': 'SIOtoSIW', 'end': '4200.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ),
#  Element(name = interval, attributes = {'begin': '4200.00', 'id': 'SIOtoSIW', 'end': '4800.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ),
#  Element(name = interval, attributes = {'begin': '4800.00', 'id': 'SIOtoSIW', 'end': '5400.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ),
#  Element(name = interval, attributes = {'begin': '5400.00', 'id': 'SIOtoSIW', 'end': '6000.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ),
#  Element(name = interval, attributes = {'begin': '6000.00', 'id': 'SIOtoSIW', 'end': '6600.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ),
#  Element(name = interval, attributes = {'begin': '6600.00', 'id': 'SIOtoSIW', 'end': '7200.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ),
#  Element(name = interval, attributes = {'begin': '7200.00', 'id': 'SIOtoSIW', 'end': '7800.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ),
#  Element(name = interval, attributes = {'begin': '7800.00', 'id': 'SIOtoSIW', 'end': '8400.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ),
#  Element(name = interval, attributes = {'begin': '8400.00', 'id': 'SIOtoSIW', 'end': '9000.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ),
#  Element(name = interval, attributes = {'begin': '9000.00', 'id': 'SIOtoSIW', 'end': '9600.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ),
#  Element(name = interval, attributes = {'begin': '9600.00', 'id': 'SIOtoSIW', 'end': '10000.00'}, cdata =
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      )]

# %%
ivl = obj.meandata.interval[2]
try:
    SIWtoSIO = float(ivl.edge[-1]['occupancy'])
except:
    SIWtoSIO = float(0)

try:
    SIOtoSIW = float(ivl.edge[-3]['occupancy'])
except:
    SIOtoSIW = float(0)

# %%
# Out:
# 17

# %%
SIWtoSIO = []
SIOtoSIW = []
freqs = len(obj.meandata.interval)
for i in range(0,freqs,2):
    ivl = obj.meandata.interval[i]
    try:
        SIWtoSIO.append(float(ivl.edge[-1]['occupancy']))
        print ('SIWtoSIOmean:',sum(SIWtoSIO) / len(SIWtoSIO))
    except:
        try:
            SIOtoSIW.append(float(ivl.edge[-3]['occupancy']))
            print ('SIOtoSIWmean:',sum(SIOtoSIW) / len(SIOtoSIW))
        except: 
            continue
        #SIWtoSIO.append(0)

#     try:
        
#     except:
#         continue
#         #SIOtoSIW.append(0)
# Out:
# SIWtoSIOmean: 86.47
# SIWtoSIOmean: 85.705
# SIOtoSIWmean: 74.26
# SIWtoSIOmean: 65.61333333333333
# SIOtoSIWmean: 83.80000000000001
# SIOtoSIWmean: 86.47000000000001

# %%
import pandas as pd
# %matplotlib inline

# %%
pd.Series(SIWtoSIO).mean()
# Out:
# 65.61333333333333

# %%
pd.Series(SIOtoSIW).mean()
# Out:
# 86.470000000000013

# %%
# Out:
# Element(name = edge, attributes = {'id': 'SIOtoSIW', 'arrived': '0', 'departed': '0', 'entered': '0', 'laneChangedTo': '0', 'sampledSeconds': '0.00', 'laneChangedFrom': '0', 'left': '0'}, cdata = )
