# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from time import time
import sompy
# %matplotlib inline

# %%
file_shp = r'D:\Projects\RO\Jong HKV\Toeleveringen\DominikPaprotny\ExtremeDischargesEUCatchments\Stations_total_v3.shp'
file_csv = r'D:\Projects\RO\Jong HKV\Toeleveringen\DominikPaprotny\ExtremeDischargesEUCatchments\BN_data_full.csv'

# %%
# read and parse data
df = pd.read_csv(file_csv,sep=';', decimal=',')
df.replace(np.inf, 0, inplace=True)
df.replace(np.nan, 0, inplace=True)

df_key = df['WSO1_ID'].copy()
# exclude some columns
df = df[df.columns.difference(['OBJECTID', 'Station_ID','WSO1_ID','Catchment_ID','Indicator_of_daily_discharge_availability'])]
df = df.astype(np.float32)

# %%
# standardize matrix
X = df.as_matrix()
# _mu = np.nanmean(X, axis=0)
# _sigma = np.sqrt(np.nanmean((X - _mu) ** 2.0, axis=0))
# X = (X - _mu) / _sigma

# %%
# go back to pandas dataframe and drop NaN columns
df = pd.DataFrame(data=X, columns=df.columns)
df.dropna(axis=1, how='all', inplace=True)
X = df.as_matrix()

# %%
#df.plot(subplots=True,figsize=(12,35))

# %%
# train a kohonen network
mapsize = [137,77]
som = sompy.SOMFactory.build(X, mapsize, mask=None, mapshape='planar', lattice='rect', normalization='var', initialization='pca', neighborhood='gaussian', training='batch',component_names=df.columns, name='sompy')  # this will use the default parameters, but i can change the initialization and neighborhood methods
som.train(n_job=1, verbose='debug')  # verbose='debug' will print more, and verbose=None wont print anything
# Out:
#  Training...
# --------------------------------------------------------------
#  details:
#       > data len is 74756 and data dimension is 35
#       > map size is 137,77
#       > array size in log10 scale is 10.440925392034398
#       > number of jobs in parallel: 1
#  -------------------------------------------------------------
#
#  pca_linear_initialization took: 0.261000 seconds
#  Rough training...
#  radius_ini: 18.000000 , radius_final: 4.500000, trainlen: 5
# maxtrainlen %d inf
#  find_bmu took: 16.849000 seconds
#  update_codebook_voronoi took: 0.218000 seconds
#  epoch: 1 ---> elapsed time:  18.673000, quantization error: 4.081365
#
#  find_bmu took: 20.047000 seconds
#  update_codebook_voronoi took: 0.249000 seconds
#  epoch: 2 ---> elapsed time:  22.072000, quantization error: 3.810625
#
#  find_bmu took: 19.751000 seconds
#  update_codebook_voronoi took: 0.188000 seconds
#  epoch: 3 ---> elapsed time:  21.655000, quantization error: 3.546116
#
# ...

# %%
# topographic_error = som.calculate_topographic_error()
# quantization_error = np.mean(som._bmu[1])
# print ("Topographic error = %s; Quantization error = %s" % (topographic_error, quantization_error))

# %%
from sompy.visualization.mapview import View2D
view2D  = View2D(10,10,"rand data",text_size=10)
view2D.show(som, col_sz=7, which_dim="all", desnormalize=True)

# %%
som.codebook.matrix[:,0]
# Out:
# array([-0.340509, -0.339374, -0.328521, ..., -0.214215, -0.241794,
#        -0.280482])

# %%
X_project = som.project_data(X)

# %%
np.unique(X_project)
# Out:
# array([    0,     1,     3, ..., 10546, 10547, 10548])

# %%
som.codebook.mapsize[0] * som.codebook.mapsize[0]
# Out:
# 18769

# %%
# Out:
# (10549,)

# %%
codebook = som._normalizer.denormalize_by(som.data_raw, som.codebook.matrix)

# %%
codebook.shape
# Out:
# (10549, 35)

# %%
df_cb = pd.DataFrame(data=codebook, columns=df.columns)

# %%
som.codebook.mapsize[1]
# Out:
# 77

# %%
y = np.linspace(0, 1, som.codebook.mapsize[0])
x = np.linspace(0, 1, som.codebook.mapsize[0])
xv, yv = np.meshgrid(x, y)
grid = np.dstack((xv, yv)).reshape(-1, 2)

# %%
X = grid[:,0]
Y = grid[:,1]

# %%
X
# Out:
# array([ 0.        ,  0.01315789,  0.02631579, ...,  0.97368421,
#         0.98684211,  1.        ])

# %%
df_cb['X'] = X
df_cb['Y'] = Y

# %%
df_cb.head()
# Out:
#    Annual_maxima_of_daily_discharge  Annual_maxima_of_daily_precipitation  \
# 0                          2.211375                             28.741950
# 1                          3.339044                             28.211558
# 2                         14.121934                             27.065807
# 3                         24.660414                             27.124539
# 4                         26.192453                             27.683480
#
#    Annual_maxima_of_daily_precipitation_and_snowmelt  \
# 0                                          31.516790
# 1                                          31.608764
# 2                                          34.111886
# 3                                          36.237532
# 4                                          36.204320
#
#    Annual_maxima_of_daily_snowmelt  \
# 0                        16.991266
# 1                        17.947952
# 2                        23.737908
# 3                        27.089702
# ...

# %%
df_cb.plot.scatter('Y','X',c='Glaciers', cmap='viridis', vmin=1, vmax=5)

# %%
df_cb.plot.scatter('X','Y',c='Glaciers', cmap='viridis', vmin=1, vmax=5)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
im = plt.imshow(codebook[:,0].reshape(som.codebook.mapsize[0],som.codebook.mapsize[1]), vmin=100, vmax=1000)
plt.colorbar(im)
plt.show()

# %%
df_2 = pd.DataFrame(data=X, columns=df.columns)
df_2['projected'] = X_project
df_2['WSO1_ID'] = df_key.values

# %%
source_cols = df_2.columns

# %%
from itertools import product
from string import ascii_lowercase
keywords = [''.join(i) for i in product(ascii_lowercase, repeat = 2)]

# %%
df_2.columns = keywords[0:df_2.columns.size]

# %%
df_2.head()
# Out:
#       aa         ab         ac         ad        ae        af          ag  \
# 0   7.46  28.798899  53.799698  51.204853  0.992210  0.923197  277.346313
# 1  10.50  33.087471  33.146503  21.040306  0.593966  2.148729  278.410156
# 2   8.75  33.962662  34.116840  12.289010  0.529617  1.384836  278.711853
# 3   8.31  28.224432  28.224432  12.579762  0.533033  1.694277  278.446747
# 4   8.08  51.569351  51.569351  23.977259  0.534044  3.006746  277.322723
#
#          ah        ai          aj  ...           bb        bc        bd  \
# 0  2.260450  0.439113  247.199997  ...    26.318661  2.677269  0.272607
# 1  1.878416  0.390958  247.199997  ...    26.318661  2.677269  0.272607
# 2  1.844083  0.350141  247.199997  ...    26.318661  2.677269  0.272607
# 3  1.807386  0.336921  247.199997  ...    26.318661  2.677269  0.272607
# 4  2.517452  0.412666  247.199997  ...    26.318661  2.677269  0.272607
#
#          be         bf         bg          bh   bi   bj     bk
# ...

# %%
out_json = r'D:\Projects\RO\Jong HKV\Toeleveringen\DominikPaprotny\ExtremeDischargesEUCatchments//SOM_projected.json'
out_gzip = r'D:\Projects\RO\Jong HKV\Toeleveringen\DominikPaprotny\ExtremeDischargesEUCatchments//SOM_projected.gzip'

# %%
df_2.to_json(out_gzip,orient='records', compression='gzip')

# %%
print(source_cols)
# Out:
# Index(['Annual_maxima_of_daily_discharge',
#        'Annual_maxima_of_daily_precipitation',
#        'Annual_maxima_of_daily_precipitation_and_snowmelt',
#        'Annual_maxima_of_daily_snowmelt',
#        'Annual_maxima_of_daily_total_runoff_coefficient',
#        'Annual_mean_of_daily_discharge',
#        'Annual_mean_of_daily_near-surface_air_temperature',
#        'Annual_mean_of_daily_precipitation',
#        'Annual_mean_of_daily_total_runoff_coefficient', 'Area',
#        'Average_elevation', 'Average_water_capacity', 'Build-up_areas',
#        'Circularity', 'Clay', 'Confidence', 'Eolian_deposits', 'Forests',
#        'Glaciers', 'Gravel', 'Irrigated_agriculture', 'Lakes', 'Marshes',
#        'Peat', 'River_network_density', 'River_slopeness', 'Sand', 'Silt',
#        'Slopeness_(average)', 'Soil_sealing',
#        'Soil_texture_(dimensionless_index_from_1_to_13)',
#        'Steepness_(equation)', 'Time_of_concentration', 'Total_area',
# ...

# %%
df_2['bj']
# Out:
# 0         157
# 1         237
# 2         240
# 3         240
# 4         238
# 5         240
# 6         156
# 7         156
# 8         156
# 9         156
# 10        157
# 11        239
# 12        156
# 13        316
# 14        157
# 15        156
# 16        156
# 17        316
# 18        240
# 19        156
# 20        156
# 21        156
# 22        156
# 23        156
# 24        314
# 25        156
# 26        462
# 27        462
# 28        462
# 29        462
#          ...
# 74726    7854
# 74727    7854
# 74728    7854
# 74729    7854
# 74730    7854
# 74731    7854
# 74732    7854
# 74733    7854
# 74734    7854
# 74735    7854
# 74736    7854
# 74737    7854
# 74738    7854
# 74739    7854
# 74740    7854
# 74741    7854
# 74742    7854
# 74743    7854
# 74744    7854
# 74745    7854
# 74746    7777
# 74747    7854
# 74748    7854
# 74749    7854
# 74750    7854
# 74751    7854
# 74752    7854
# 74753    7854
# 74754    7854
# 74755    7854
# ...

# %%
df_2['projected'].min()

# %%
np.arange(som.codebook.mapsize[0]*som.codebook.mapsize[1]).reshape(som.codebook.mapsize[0],som.codebook.mapsize[1])

# %%
from sompy.visualization.bmuhits import BmuHitsView

vhts  = BmuHitsView(4,4,"Hits Map",text_size=12)
vhts.show(som, anotate=True, onlyzeros=False, labelsize=12, cmap="Greys", logaritmic=False)

# %%
# from sompy.visualization.hitmap import HitMapView
# som.cluster(4)
# hits  = HitMapView(20,20,"Clustering",text_size=12)
# a=hits.show(som)

# %%
#But Umatrix finds the clusters easily
u = sompy.umatrix.UMatrixView(50, 50, 'umatrix', show_axis=True, text_size=8, show_text=True)

# #This is the Umat value
UMAT = u.build_u_matrix(som, distance=1, row_normalized=False)
UMAT = u.show(som, distance2=1, row_normalized=False, show_data=True, contooor=False, blob=False)

# %%
u = sompy.umatrix.UMatrixView(50, 50, 'umatrix', show_axis=True, text_size=8, show_text=True)

#This is the Umat value
UMAT  = u.build_u_matrix(som, distance=1, row_normalized=False)

#Here you have Umatrix plus its render
u.show(som, distance2=1, row_normalized=False, show_data=True, contooor=True, blob=False)

# %%
u = sompy.umatrix.UMatrixView(50, 50, 'umatrix', show_axis=True, text_size=8, show_text=True)

#This is the Umat value
UMAT  = u.build_u_matrix(som, distance=1, row_normalized=False)

#Here you have Umatrix plus its render
U2 = u.show(som, distance2=1, row_normalized=False, show_data=True, contooor=True, blob=False)
