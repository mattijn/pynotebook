# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
basedir = r'D:\Projects\Pr\3517.10\Werkfolder'
file_1  = r'schelle1.xlsx' 
file_2  = r'schelle2.xlsx' 
schell1 = os.path.join(basedir,file_1)
schell2 = os.path.join(basedir,file_1)

# %%
paddle_whls = pd.read_excel(schell1, 0)
surfplanken = pd.read_excel(schell1, 1)

# %%
surfplanken.head()
# Out:
#     Time  Surfplank I  Surfplank II  Surfplank III
# 0  0.000     0.002451           NaN       0.263369
# 1  0.007     0.001935           NaN       0.263190
# 2  0.014     0.002193           NaN       0.263190
# 3  0.022     0.001935           NaN       0.262625
# 4  0.029     0.001935           NaN       0.263190

# %%
surfplanken.set_index('Time', inplace=True)

# %%
surfplanken.plot()

# %%
paddle_whls.set_index('Time', inplace=True)
paddle_whls.plot()

# %%
schelle1 = surfplanken.join(paddle_whls, how = 'right', lsuffix='_x')
schelle1.index.name = 'time (s)'

# %%
schelle1.head()
# Out:
#           Surfplank I  Surfplank II  Surfplank III  paddle wheel 1  \
# time (s)
# 0.000        0.002451           NaN       0.263369        0.010454
# 0.007        0.001935           NaN       0.263190        0.026136
# 0.014        0.002193           NaN       0.263190        0.010454
# 0.022        0.001935           NaN       0.262625        0.005227
# 0.029        0.001935           NaN       0.263190        0.005227
#
#           paddle wheel 2  paddle wheel 3  paddle wheel 5  paddle wheel 4  \
# time (s)
# 0.000           0.010454       -0.026136       -0.020908        0.005227
# 0.007           0.005227        0.005227       -0.031362        0.000000
# 0.014          -0.031362        0.005227       -0.015682       -0.036590
# 0.022           0.010454       -0.010454       -0.015682        0.005227
# 0.029           0.005227        0.000000       -0.026136        0.005227
#
#           paddle wheel 6  paddle wheel 7
# time (s)
# 0.000          -0.015682        0.005227
# ...

# %%
schelle1.columns = ['Flow thickness crest', 'Flow thickness slope', 'Flow thickness toe', 'Flow velocity crest (water surface)',
       'Flow velocity crest (ground)', 'Flow velocity slope (ground)', 'Flow velocity toe R (ground)', 'Flow velocity toe R (water surface)',
       'Flow velocity toe L (water surface)', 'Flow velocity toe L (ground)']
schelle1.head()
# Out:
#           Flow thickness crest  Flow thickness slope  Flow thickness toe  \
# time (s)
# 0.000                 0.002451                   NaN            0.263369
# 0.007                 0.001935                   NaN            0.263190
# 0.014                 0.002193                   NaN            0.263190
# 0.022                 0.001935                   NaN            0.262625
# 0.029                 0.001935                   NaN            0.263190
#
#           Flow velocity crest (water surface)  Flow velocity crest (ground)  \
# time (s)
# 0.000                                0.010454                      0.010454
# 0.007                                0.026136                      0.005227
# 0.014                                0.010454                     -0.031362
# 0.022                                0.005227                      0.010454
# 0.029                                0.005227                      0.005227
#
# ...

# %%
golf_1 = schelle1[(schelle1.index > 22) & (schelle1.index < 32)]
golf_2 = schelle1[(schelle1.index > 33) & (schelle1.index < 45)]
golf_3 = schelle1[(schelle1.index > 46) & (schelle1.index < 56)]
golf_4 = schelle1[(schelle1.index > 60) & (schelle1.index < 73)]
golf_5 = schelle1[(schelle1.index > 74) & (schelle1.index < 84)]
golf_6 = schelle1[(schelle1.index > 87) & (schelle1.index < 97)]
golf_7 = schelle1[(schelle1.index > 99) & (schelle1.index < 112)]
golf_8 = schelle1[(schelle1.index > 116) & (schelle1.index < 126)]
golf_9 = schelle1[(schelle1.index > 132) & (schelle1.index < 141)]
golf_10 = schelle1[(schelle1.index > 145) & (schelle1.index < 158)]
golf_11 = schelle1[(schelle1.index > 166) & (schelle1.index < 179)]
golf_12 = schelle1[(schelle1.index > 187) & (schelle1.index < 199)]

# %%
#golf_4[['Surfplank I','Surfplank II','Surfplank III']].plot()

# %%
golf_1.head()
# Out:
#           Flow thickness crest  Flow thickness slope  Flow thickness toe  \
# time (s)
# 22.006                0.001935                   NaN            0.262833
# 22.013                0.001935                   NaN            0.262625
# 22.021                0.001634                   NaN            0.262833
# 22.028                0.001634                   NaN            0.262833
# 22.035                0.003999                   NaN            0.262833
#
#           Flow velocity crest (water surface)  Flow velocity crest (ground)  \
# time (s)
# 22.006                              -0.041816                      0.015682
# 22.013                               0.005227                      0.010454
# 22.021                               0.000000                      0.031362
# 22.028                               0.010454                      0.005227
# 22.035                               0.000000                      0.005227
#
# ...

# %%
# golf_1.columns = ['Flow thickness crest', 'Flow thickness toe', 'Flow thickness toe', 'Flow velocity crest (water surface)',
#        'Flow velocity crest (ground)', 'Flow velocity toe R (ground)', 'Flow velocity toe R (ground)', 'Flow velocity toe R (water surface)',
#        'Flow velocity toe L (water surface)', 'Flow velocity toe L (ground)']

# %%
import matplotlib.pyplot as plt
plt.style.use('bmh')

fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(12,16))
fig.suptitle('Wave 2',y=1.01)
golf_1[['Flow thickness crest']].plot(grid=True, ax=axes[0,0])
axes[0,0].set_ylabel("flow thickness (m)")
golf_1[['Flow velocity crest (ground)','Flow velocity crest (water surface)']].plot(grid=True, ax=axes[0,1], ylim=[-0.05,6])
axes[0,1].set_ylabel("flow velocity (m/s)")

golf_1[['Flow thickness toe']].plot(grid=True, ax=axes[1,0])
axes[1,0].set_ylabel("flow thickness (m)")
golf_1[['Flow velocity toe R (ground)']].plot(grid=True, ax=axes[1,1], ylim=[-0.05,6])
axes[1,1].set_ylabel("flow velocity (m/s)")

golf_1[['Flow thickness toe']].plot(grid=True, ax=axes[2,0])
axes[2,0].set_ylabel("flow thickness (m)")
golf_1[['Flow velocity toe R (ground)','Flow velocity toe R (water surface)']].plot(grid=True, ax=axes[2,1], ylim=[-0.05,6],colormap='Paired')
axes[2,1].set_ylabel("flow velocity (m/s)")

#golf_1[['Surfplank IV']].plot(grid=True, ax=axes[3,0])
golf_1[['Flow velocity toe L (ground)','Flow velocity toe L (water surface)']].plot(grid=True, ax=axes[3,1], ylim=[-0.05,6])
axes[3,1].set_ylabel("flow velocity (m/s)")
fig.tight_layout()
fig.show()
# Out:
# c:\python35\lib\site-packages\matplotlib\figure.py:402: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
import numpy as np

# %%
print ('wave I')
import matplotlib.pyplot as plt
plt.style.use('default')

fig = plt.figure(figsize=(6,20))

ax = fig.add_subplot(411)
ax2 = ax.twinx()

# Axis 1 to plot Flow velocity
golf_1[['Flow velocity crest (water surface)']].plot(grid=False, ax=ax, ylim=[0,6], 
                                                     color='#A60628', lw=1.5, legend=False)
ax.set_ylabel("flow velocity (m/s)")
# get id of x1
x1 = golf_1[['Flow velocity crest (water surface)']].idxmax()[0]
x2 = x1
y1 = 0
# get value of y by x1
y2 = golf_1[['Flow velocity crest (water surface)']].ix[x1][0]
peak_v_b_0 = y2
print ('peak flow velocity at crest (water surface):',y2)
ax.annotate(s='', xytext=(x1,y1), xy=(x2,y2), arrowprops=dict(arrowstyle='<|-|>',
                                                              shrinkA=0, 
                                                              #shrinkB=0,
                                                              ls='dashed',
                                                              lw=0.5,
                                                              fc='#A60628',
                                                              color='#A60628'
                                                              ))
ax.annotate(s='v', xytext=(x1+x1*0.002,y2/3), xy=(x2,y2/3), color='#A60628')

# Axis 2 to plot Flow thickness
golf_1[['Flow thickness crest']].plot(grid=False, ax=ax2, ylim=[0,0.11], 
                                      color='black', lw=1.5, legend=False)
ax2.set_ylabel("flow thickness (m)")
# get id of x1
x1 = golf_1[['Flow thickness crest']].idxmax()[0]
x2 = x1
y1 = 0
# get value of y by x1
y2 = golf_1[['Flow thickness crest']].ix[x1][0]
peak_h_b_0 = y2
print ('peak flow thickness at crest:',y2)
ax2.annotate(s='', xytext=(x1,y1), xy=(x2,y2), arrowprops=dict(arrowstyle='<|-|>',
                                                              shrinkA=0, 
                                                              #shrinkB=0,
                                                              ls='dashed',
                                                              lw=0.5,
                                                              fc='black',
                                                              color='black'
                                                              ))
ax2.annotate(s='h', xytext=(x1+x1*0.002,y2/3), xy=(x2,y2/3), color='black')

# ask matplotlib for the plotted objects and their labels
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0, fancybox=False, frameon=False)

# add text for the volume
ix_50 = int(golf_1[['Flow thickness crest']].index.size*0.5)
ix_x = golf_1[['Flow thickness crest']].index[ix_50]
ix_y = ax2.get_ylim()[1]  * 0.73

from scipy.integrate import simps
# Compute the area using the composite Simpson's rule.
# multiply h * v and integrate over time to get overtopping wave volume (m3/m)
y = golf_1[['Flow thickness crest']].as_matrix() * golf_1[['Flow velocity crest (water surface)']].as_matrix()
x = golf_1[['Flow thickness crest']].index
area = simps(y.flatten(), x=x)
ax2.text(ix_x, ix_y, "overtopping wave volume \nV = "+str(float("{0:.2f}".format(area)))+" m3 per m", fontsize=10)


#fig = plt.figure()
ax = fig.add_subplot(412)
ax2 = ax.twinx()

# Axis 1 to plot Flow velocity
golf_1[['Flow velocity slope (ground)']].plot(grid=False, ax=ax, ylim=[0,6], 
                                                     color='#A60628', lw=1.5, legend=False)
ax.set_ylabel("flow velocity (m/s)")
# get id of x1
x1 = golf_1[['Flow velocity slope (ground)']].idxmax()[0]
x2 = x1
y1 = 0
# get value of y by x1
y2 = golf_1[['Flow velocity slope (ground)']].ix[x1][0]
peak_v_b_0 = y2
print ('peak flow velocity at slope (ground):',y2)
ax.annotate(s='', xytext=(x1,y1), xy=(x2,y2), arrowprops=dict(arrowstyle='<|-|>',
                                                              shrinkA=0, 
                                                              #shrinkB=0,
                                                              ls='dashed',
                                                              lw=0.5,
                                                              fc='#A60628',
                                                              color='#A60628'
                                                              ))
ax.annotate(s='v', xytext=(x1+x1*0.002,y2/3), xy=(x2,y2/3), color='#A60628')

# Axis 2 to plot Flow thickness
golf_1[['Flow thickness slope']].plot(grid=False, ax=ax2, ylim=[0,0.11], 
                                      color='black', lw=1.5, legend=False)
ax2.set_ylabel("flow thickness (m)")
# get id of x1
x1 = golf_1[['Flow thickness slope']].idxmax()[0]
x2 = x1
y1 = 0
# get value of y by x1
y2 = golf_1[['Flow thickness slope']].ix[x1][0]
peak_h_b_0 = y2
print ('peak flow thickness at slope:',y2)
ax2.annotate(s='', xytext=(x1,y1), xy=(x2,y2), arrowprops=dict(arrowstyle='<|-|>',
                                                              shrinkA=0, 
                                                              #shrinkB=0,
                                                              ls='dashed',
                                                              lw=0.5,
                                                              fc='black',
                                                              color='black'
                                                              ))
ax2.annotate(s='h', xytext=(x1+x1*0.002,y2/3), xy=(x2,y2/3), color='black')

# ask matplotlib for the plotted objects and their labels
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0, fancybox=False, frameon=False)

# add text for the volume
ix_50 = int(golf_1[['Flow thickness slope']].index.size*0.5)
ix_x = golf_1[['Flow thickness slope']].index[ix_50]
ix_y = ax2.get_ylim()[1]  * 0.73

from scipy.integrate import simps
# Compute the area using the composite Simpson's rule.
# multiply h * v and integrate over time to get overtopping wave volume (m3/m)
y = golf_1[['Flow thickness slope']].as_matrix() * golf_1[['Flow velocity slope (ground)']].as_matrix()
y = np.nan_to_num(y)
x = golf_1[['Flow thickness slope']].index
area = simps(y.flatten(), x=x)
ax2.text(ix_x, ix_y, "overtopping wave volume \nV = "+str(float("{0:.2f}".format(area)))+" m3 per m", fontsize=10)


ax = fig.add_subplot(413)
ax2 = ax.twinx()

# Axis 1 to plot Flow velocity
golf_1[['Flow velocity toe R (ground)']].plot(grid=False, ax=ax, ylim=[0,6], 
                                                     color='#A60628', lw=1.5, legend=False)
ax.set_ylabel("flow velocity (m/s)")
# get id of x1
x1 = golf_1[['Flow velocity toe R (ground)']].idxmax()[0]
x2 = x1
y1 = 0
# get value of y by x1
y2 = golf_1[['Flow velocity toe R (ground)']].ix[x1][0]
peak_v_b_0 = y2
print ('peak flow velocity at toe R (ground):',y2)
ax.annotate(s='', xytext=(x1,y1), xy=(x2,y2), arrowprops=dict(arrowstyle='<|-|>',
                                                              shrinkA=0, 
                                                              #shrinkB=0,
                                                              ls='dashed',
                                                              lw=0.5,
                                                              fc='#A60628',
                                                              color='#A60628'
                                                              ))
ax.annotate(s='v', xytext=(x1+x1*0.002,y2/3), xy=(x2,y2/3), color='#A60628')

# Axis 2 to plot Flow thickness
golf_1[['Flow thickness toe']].plot(grid=False, ax=ax2, ylim=[0,0.34], 
                                      color='black', lw=1.5, legend=False)
ax2.set_ylabel("flow thickness (m)")
# get id of x1
x1 = golf_1[['Flow thickness toe']].idxmax()[0]
x2 = x1
y1 = 0
# get value of y by x1
y2 = golf_1[['Flow thickness toe']].ix[x1][0]
peak_h_b_0 = y2
print ('peak flow thickness at toe R:',y2)
ax2.annotate(s='', xytext=(x1,y1), xy=(x2,y2), arrowprops=dict(arrowstyle='<|-|>',
                                                              shrinkA=0, 
                                                              #shrinkB=0,
                                                              ls='dashed',
                                                              lw=0.5,
                                                              fc='black',
                                                              color='black'
                                                              ))
ax2.annotate(s='h', xytext=(x1+x1*0.002,y2/3), xy=(x2,y2/3), color='black')

# ask matplotlib for the plotted objects and their labels
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0, fancybox=False, frameon=False)

# add text for the volume
ix_50 = int(golf_1[['Flow thickness toe']].index.size*0.5)
ix_x = golf_1[['Flow thickness toe']].index[ix_50]
ix_y = ax2.get_ylim()[1]  * 0.73

from scipy.integrate import simps
# Compute the area using the composite Simpson's rule.
# multiply h * v and integrate over time to get overtopping wave volume (m3/m)
y = golf_1[['Flow thickness toe']].as_matrix() * golf_1[['Flow velocity toe R (ground)']].as_matrix()
y = np.nan_to_num(y)
x = golf_1[['Flow thickness toe']].index
area = simps(y.flatten(), x=x)
ax2.text(ix_x, ix_y, "overtopping wave volume \nV = "+str(float("{0:.2f}".format(area)))+" m3 per m", fontsize=10)

ax = fig.add_subplot(414)
ax2 = ax.twinx()

# Axis 1 to plot Flow velocity
golf_1[['Flow velocity toe R (water surface)']].plot(grid=False, ax=ax, ylim=[0,6], 
                                                     color='#A60628', lw=1.5, legend=False)
ax.set_ylabel("flow velocity (m/s)")
# get id of x1
x1 = golf_1[['Flow velocity toe R (water surface)']].idxmax()[0]
x2 = x1
y1 = 0
# get value of y by x1
y2 = golf_1[['Flow velocity toe R (water surface)']].ix[x1][0]
peak_v_b_0 = y2
print ('peak flow velocity at toe R (water surface):',y2)
ax.annotate(s='', xytext=(x1,y1), xy=(x2,y2), arrowprops=dict(arrowstyle='<|-|>',
                                                              shrinkA=0, 
                                                              #shrinkB=0,
                                                              ls='dashed',
                                                              lw=0.5,
                                                              fc='#A60628',
                                                              color='#A60628'
                                                              ))
ax.annotate(s='v', xytext=(x1+x1*0.002,y2/3), xy=(x2,y2/3), color='#A60628')

# Axis 2 to plot Flow thickness
golf_1[['Flow thickness toe']].plot(grid=False, ax=ax2, ylim=[0,0.35], 
                                      color='black', lw=1.5, legend=False)
ax2.set_ylabel("flow thickness (m)")
# get id of x1
x1 = golf_1[['Flow thickness toe']].idxmax()[0]
x2 = x1
y1 = 0
# get value of y by x1
y2 = golf_1[['Flow thickness toe']].ix[x1][0]
peak_h_b_0 = y2
print ('peak flow thickness at toe R:',y2)
ax2.annotate(s='', xytext=(x1,y1), xy=(x2,y2), arrowprops=dict(arrowstyle='<|-|>',
                                                              shrinkA=0, 
                                                              #shrinkB=0,
                                                              ls='dashed',
                                                              lw=0.5,
                                                              fc='black',
                                                              color='black'
                                                              ))
ax2.annotate(s='h', xytext=(x1+x1*0.002,y2/3), xy=(x2,y2/3), color='black')

# ask matplotlib for the plotted objects and their labels
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=1, fancybox=False, frameon=False)

# add text for the volume
ix_50 = int(golf_1[['Flow thickness toe']].index.size*0.5)
ix_x = golf_1[['Flow thickness toe']].index[ix_50]
ix_y = ax2.get_ylim()[1]  * 0.73

from scipy.integrate import simps
# Compute the area using the composite Simpson's rule.
# multiply h * v and integrate over time to get overtopping wave volume (m3/m)
y = golf_1[['Flow thickness toe']].as_matrix() * golf_1[['Flow velocity toe R (water surface)']].as_matrix()
y = np.nan_to_num(y)
x = golf_1[['Flow thickness toe']].index
area = simps(y.flatten(), x=x)
ax2.text(ix_x, ix_y, "overtopping wave volume \nV = "+str(float("{0:.2f}".format(area)))+" m3 per m", fontsize=10)


#plt.legend(frameon=False)
plt.suptitle('wave II', y=1.0)
plt.tight_layout()
#plt.savefig(r'D:\Projects\Pr\3517.10\Werkfolder\plots//waveIII_crest_slope_ground.png', dpi=300)
plt.show()

#plt.savefig(r'D:\Projects\Pr\3517.10\Werkfolder\plots//waveII_slope_ground.png', dpi=300)
#plt.show()
# Out:
# wave I
# peak flow velocity at crest (water surface): 4.07706348
# peak flow thickness at crest: 0.086688
# peak flow velocity at slope (ground): 4.98142188
# peak flow thickness at slope: 0.0397295866324
# peak flow velocity at toe R (ground): 3.3558034
# peak flow thickness at toe R: 0.324751455818
# peak flow velocity at toe R (water surface): 5.70268196
# peak flow thickness at toe R: 0.324751455818

# %%
import matplotlib.patches as mpatches
import matplotlib.lines as mlines

# %%
peak_velocity_crestws_WI_III.mean()
# Out:
# 4.1537398266666665

# %%
x1 = golf_1[['Flow thickness crest']].idxmax()[0]
y1 = golf_1[['Flow thickness crest']].ix[x1][0]

x1 = golf_2[['Flow thickness crest']].idxmax()[0]
y2 = golf_2[['Flow thickness crest']].ix[x1][0]

x1 = golf_6[['Flow thickness crest']].idxmax()[0]
y3 = golf_6[['Flow thickness crest']].ix[x1][0]

peak_thickness_crest_WI_III = np.array([y1,y2,y3])

x1 = golf_1[['Flow velocity crest (water surface)']].idxmax()[0]
y1 = golf_1[['Flow velocity crest (water surface)']].ix[x1][0]

x1 = golf_2[['Flow velocity crest (water surface)']].idxmax()[0]
y2 = golf_2[['Flow velocity crest (water surface)']].ix[x1][0]

x1 = golf_6[['Flow velocity crest (water surface)']].idxmax()[0]
y3 = golf_6[['Flow velocity crest (water surface)']].ix[x1][0]

peak_velocity_crestws_WI_III = np.array([y1,y2,y3])

x1 = golf_1[['Flow velocity crest (ground)']].idxmax()[0]
y1 = golf_1[['Flow velocity crest (ground)']].ix[x1][0]

x1 = golf_2[['Flow velocity crest (ground)']].idxmax()[0]
y2 = golf_2[['Flow velocity crest (ground)']].ix[x1][0]

x1 = golf_6[['Flow velocity crest (ground)']].idxmax()[0]
y3 = golf_6[['Flow velocity crest (ground)']].ix[x1][0]

peak_velocity_crestg_WI_III = np.array([y1,y2,y3])

x1 = golf_1[['Flow velocity slope (ground)']].idxmax()[0]
y1 = golf_1[['Flow velocity slope (ground)']].ix[x1][0]

x1 = golf_2[['Flow velocity slope (ground)']].idxmax()[0]
y2 = golf_2[['Flow velocity slope (ground)']].ix[x1][0]

x1 = golf_6[['Flow velocity slope (ground)']].idxmax()[0]
y3 = golf_6[['Flow velocity slope (ground)']].ix[x1][0]

peak_velocity_slopeg_WI_III = np.array([y1,y2,y3])

x1 = golf_1[['Flow velocity toe R (water surface)']].idxmax()[0]
y1 = golf_1[['Flow velocity toe R (water surface)']].ix[x1][0]

x1 = golf_2[['Flow velocity toe R (water surface)']].idxmax()[0]
y2 = golf_2[['Flow velocity toe R (water surface)']].ix[x1][0]

x1 = golf_6[['Flow velocity toe R (water surface)']].idxmax()[0]
y3 = golf_6[['Flow velocity toe R (water surface)']].ix[x1][0]

peak_velocity_toeRws_WI_III = np.array([y1,y2,y3])

x1 = golf_1[['Flow velocity toe R (ground)']].idxmax()[0]
y1 = golf_1[['Flow velocity toe R (ground)']].ix[x1][0]

x1 = golf_2[['Flow velocity toe R (ground)']].idxmax()[0]
y2 = golf_2[['Flow velocity toe R (ground)']].ix[x1][0]

x1 = golf_6[['Flow velocity toe R (ground)']].idxmax()[0]
y3 = golf_6[['Flow velocity toe R (ground)']].ix[x1][0]

peak_velocity_toeRg_WI_III = np.array([y1,y2,y3])

x1 = golf_1[['Flow velocity toe L (water surface)']].idxmax()[0]
y1 = golf_1[['Flow velocity toe L (water surface)']].ix[x1][0]

x1 = golf_2[['Flow velocity toe L (water surface)']].idxmax()[0]
y2 = golf_2[['Flow velocity toe L (water surface)']].ix[x1][0]

x1 = golf_6[['Flow velocity toe L (water surface)']].idxmax()[0]
y3 = golf_6[['Flow velocity toe L (water surface)']].ix[x1][0]

peak_velocity_toeLws_WI_III = np.array([y1,y2,y3])

x1 = golf_1[['Flow velocity toe L (ground)']].idxmax()[0]
y1 = golf_1[['Flow velocity toe L (ground)']].ix[x1][0]

x1 = golf_2[['Flow velocity toe L (ground)']].idxmax()[0]
y2 = golf_2[['Flow velocity toe L (ground)']].ix[x1][0]

x1 = golf_6[['Flow velocity toe L (ground)']].idxmax()[0]
y3 = golf_6[['Flow velocity toe L (ground)']].ix[x1][0]

peak_velocity_toeLg_WI_III = np.array([y1,y2,y3])

# calculation of overtopping flow velocities using literature

v_b_0 = peak_velocity_crestws_WI_III.mean() # overtopping flow velocity at beginning of the landward toe R (m/s)
h_b_0 = peak_thickness_crest_WI_III.mean() # overtopping flow thickness at beginning of the landward toe R (m)
g = 9.81 # gravitational acceleration
f = 0.02 # bottom friction coeffiecient depending on the toe R material (eg. grass)
o = 1
a = 1.8
offset = False
CJV = True
tal_deg = np.degrees(np.arctan(o / a))
beta = np.radians(tal_deg) #Talud helling voor teststrook I is 1:1,8
print ('talud: ',o,':',a)
print ('angle toe R (deg):',tal_deg)
print ('angle toe R (rad):',beta)
print ('v_b_0',v_b_0)
print ('h_b_0',h_b_0)

s = np.linspace(0,11,200)
v = [] # empty velocity list

# zie notitie CJV voor bepalen v_b op positie s_0
if CJV == True:
    v_b = ((2 * g * np.sin(beta) * (v_b_0 * h_b_0) ) / f) ** (1./3)
    h_b = (v_b_0 * h_b_0) / v_b
    print ('v_b',v_b)
    print ('h_b',h_b)
if CJV == False:
    h_b = (v_b_0 * h_b_0) / v_b_0
    v_b = np.sqrt((2*g * h_b*np.sin(beta))/f)    
    print ('v_b',v_b)
    print ('h_b',h_b)

# append initiatie
v.append(v_b)
for s_b in s[1::]:
    #sin2beta =  (1/2)( 1 - cos(2x) ) 
    t = -(v_b_0 / (g * np.sin(beta))) + np.sqrt(((v_b**2) / (g**2 * (0.5 * (1 - np.cos(2 * beta))))) + ((2 * s_b) / (g * np.sin(beta))))
    k_1 = np.sqrt( (2 * f * g * np.sin(beta)) / (h_b) )
    v_b = (v_b_0 + ((k_1 * h_b) / f) * np.tanh((k_1 * t)/2)) / (1 + ((f * v_b_0) / (h_b * k_1)) * np.tanh((k_1 * t) / 2))
    v.append(v_b)


EurOtop = pd.DataFrame({'flow velocity (m/s)':v,'horizontal distance from outer crest line (m)':s})
EurOtop.set_index('horizontal distance from outer crest line (m)', inplace=True)

crestDistance_ws = 2.7
crestDistance_g = 2.55
slopeDistance_g = 4.95 #meter from start point
toeDistanceR_ws = 9.15 #meter from start point
toeDistanceR_g = 8.9
toeDistanceL_ws = 9.20 #meter from start point
toeDistanceL_g = 9.10
plt.figure()

#ix_ = EurOtop.idxmin()[0]
#iy_ = EurOtop.ix[ix_]
#iy__ = np.copy(iy_)
#EurOtop['flow velocity (m/s)'][EurOtop.index <= ix_] = iy__[0]

if offset == True:
    yOffset = EurOtop.min()[0] - peak_velocity_crestws_WI_III.mean()
if offset == False:
    yOffset = 0

(EurOtop - yOffset).plot(color='k')

plt.scatter(np.repeat(crestDistance_ws, peak_velocity_crestws_WI_III.size),peak_velocity_crestws_WI_III, marker='s', color='purple', label='crest water surface', zorder=20)
plt.scatter(np.repeat(crestDistance_g, peak_velocity_crestg_WI_III.size),peak_velocity_crestg_WI_III, marker='^', facecolors='None',edgecolors='purple', label='crest ground', zorder=20)
plt.scatter(np.repeat(slopeDistance_g, peak_velocity_slopeg_WI_III.size),peak_velocity_slopeg_WI_III, marker='^', facecolors='None',edgecolors='magenta', label='slope ground', zorder=20)
plt.scatter(np.repeat(toeDistanceR_ws, peak_velocity_toeRws_WI_III.size),peak_velocity_toeRws_WI_III, marker='s', color='brown', label='toe R water surface', zorder=20)
plt.scatter(np.repeat(toeDistanceR_g, peak_velocity_toeRg_WI_III.size),peak_velocity_toeRg_WI_III, marker='^', facecolors='None',edgecolors='brown', label='toe R ground', zorder=20)
# plt.scatter(np.repeat(toeDistanceL_ws, peak_velocity_toeLws_WI_III.size),peak_velocity_toeLws_WI_III, marker='s', color='grey')
# plt.scatter(np.repeat(toeDistanceL_g, peak_velocity_toeLg_WI_III.size),peak_velocity_toeLg_WI_III, marker='^', facecolors='None',edgecolors='grey')

vLi = mlines.Line2D([],[],color='k',label='Predicted velocity')
vG = mlines.Line2D([],[],markerfacecolor='None', markeredgecolor='k', lw=0,marker='^',label='Measured velocity at ground')
vWS = mlines.Line2D([],[],color='k', lw=0,marker='s',label='Measured velocity at water surface')
leg = plt.legend(handles=[vG, vWS, vLi],frameon=True, loc=2,)
leg.get_frame().set_linewidth(0.0)
leg.get_frame().set_alpha(0.7)
#lines, labels = ax.get_legend_handles_labels()
#lines2, labels2 = ax2.get_legend_handles_labels()
#plt.legend(lines + lines2, labels + labels2, loc=1, fancybox=False, frameon=False)
plt.grid(axis='y', zorder=0)
#grid.set_zorder(1)

plt.ylabel('flow velocity (m/s)')
plt.title('Wave I-III 500l/m f=0.02')
plt.xlim(-3,15)

#plt.savefig(r'D:\Projects\Pr\3517.10\Werkfolder\plots//wave_I_III_f002_v2.png', dpi=300)
plt.show()
# Out:
# talud:  1 : 1.8
# angle toe R (deg): 29.0546040991
# angle toe R (rad): 0.507098504392
# v_b_0 4.15373982667
# h_b_0 0.111183666667
# v_b 6.0370131336
# h_b 0.0764994234878

# %%
o = 1
a = 3

tal_deg = np.degrees(np.arctan(o / a))
beta = np.radians(tal_deg) #Talud helling voor teststrook I is 1:1,8

# %%
beta
v_b_0 = 6
h_b_0 =
# Out:
# 0.32175055439664219

# %%
v_b = ((2 * g * np.sin(beta) * (v_b_0 * h_b_0) ) / f) ** (1./3)
h_b = (v_b_0 * h_b_0) / v_b
print ('v_b',v_b)
print ('h_b',h_b)

# %%
# Golf 4-6
x1 = golf_4[['Flow thickness crest']].idxmax()[0]
y1 = golf_4[['Flow thickness crest']].ix[x1][0]

x1 = golf_5[['Flow thickness crest']].idxmax()[0]
y2 = golf_5[['Flow thickness crest']].ix[x1][0]

x1 = golf_6[['Flow thickness crest']].idxmax()[0]
y3 = golf_6[['Flow thickness crest']].ix[x1][0]

peak_thickness_crest_WIV_VI = np.array([y1,y2,y3])

x1 = golf_4[['Flow velocity crest (water surface)']].idxmax()[0]
y1 = golf_4[['Flow velocity crest (water surface)']].ix[x1][0]

x1 = golf_5[['Flow velocity crest (water surface)']].idxmax()[0]
y2 = golf_5[['Flow velocity crest (water surface)']].ix[x1][0]

x1 = golf_6[['Flow velocity crest (water surface)']].idxmax()[0]
y3 = golf_6[['Flow velocity crest (water surface)']].ix[x1][0]

peak_velocity_crestws_WIV_VI = np.array([y1,y2,y3])

x1 = golf_4[['Flow velocity slope (ground)']].idxmax()[0]
y1 = golf_4[['Flow velocity slope (ground)']].ix[x1][0]

x1 = golf_5[['Flow velocity slope (ground)']].idxmax()[0]
y2 = golf_5[['Flow velocity slope (ground)']].ix[x1][0]

x1 = golf_6[['Flow velocity slope (ground)']].idxmax()[0]
y3 = golf_6[['Flow velocity slope (ground)']].ix[x1][0]

peak_velocity_slopeRg_WIV_VI = np.array([y1,y2,y3])

x1 = golf_4[['Flow velocity toe R (water surface)']].idxmax()[0]
y1 = golf_4[['Flow velocity toe R (water surface)']].ix[x1][0]

x1 = golf_5[['Flow velocity toe R (water surface)']].idxmax()[0]
y2 = golf_5[['Flow velocity toe R (water surface)']].ix[x1][0]

x1 = golf_6[['Flow velocity toe R (water surface)']].idxmax()[0]
y3 = golf_6[['Flow velocity toe R (water surface)']].ix[x1][0]

peak_velocity_toeRws_WIV_VI = np.array([y1,y2,y3])

x1 = golf_4[['Flow velocity toe R (ground)']].idxmax()[0]
y1 = golf_4[['Flow velocity toe R (ground)']].ix[x1][0]

x1 = golf_5[['Flow velocity toe R (ground)']].idxmax()[0]
y2 = golf_5[['Flow velocity toe R (ground)']].ix[x1][0]

x1 = golf_6[['Flow velocity toe R (ground)']].idxmax()[0]
y3 = golf_6[['Flow velocity toe R (ground)']].ix[x1][0]

peak_velocity_toeRg_WIV_VI = np.array([y1,y2,y3])

v_b_0 = peak_velocity_crestws_WIV_VI.mean() # overtopping flow velocity at beginning of the landward toe R (m/s)
h_b_0 = peak_thickness_crest_WIV_VI.mean() # overtopping flow thickness at beginning of the landward toe R (m)
g = 9.81 # gravitational acceleration
f = 0.01 # bottom friction coeffiecient depending on the toe R material (eg. grass)
o = 1
a = 1.8
CJV = True
tal_deg = np.degrees(np.arctan(o / a))
beta = np.radians(tal_deg) #Talud helling voor teststrook I is 1:1,8
print ('talud: ',o,':',a)
print ('angle toe R (deg):',tal_deg)
print ('angle toe R (rad):',beta)
print ('v_b_0',v_b_0)
print ('h_b_0',h_b_0)

s = np.linspace(0,11,200)
v = [] # empty velocity list

# zie notitie CJV voor bepalen v_b op positie s_0
if CJV == True:
    v_b = ((2 * g * np.sin(beta) * (v_b_0 * h_b_0) ) / f) ** (1./3)
    h_b = (v_b_0 * h_b_0) / v_b
    print ('v_b',v_b)
    print ('h_b',h_b)
if CJV == False:
    h_b = (v_b_0 * h_b_0) / v_b_0
    v_b = np.sqrt((2*g * h_b*np.sin(beta))/f)    
    print ('v_b',v_b)
    print ('h_b',h_b)

# append initiatie
v.append(v_b)
for s_b in s[1::]:
    #sin2beta =  (1/2)( 1 - cos(2x) ) 
    t = -(v_b_0 / (g * np.sin(beta))) + np.sqrt(((v_b**2) / (g**2 * (0.5 * (1 - np.cos(2 * beta))))) + ((2 * s_b) / (g * np.sin(beta))))
    k_1 = np.sqrt( (2 * f * g * np.sin(beta)) / (h_b) )
    v_b = (v_b_0 + ((k_1 * h_b) / f) * np.tanh((k_1 * t)/2)) / (1 + ((f * v_b_0) / (h_b * k_1)) * np.tanh((k_1 * t) / 2))
    v.append(v_b)


EurOtop = pd.DataFrame({'flow velocity (m/s)':v,'horizontal distance from outer crest line (m)':s})
EurOtop.set_index('horizontal distance from outer crest line (m)', inplace=True)

crestDistance = 0.5
slopeDistance = 6 #meter from start point
toeDistance = 11 #meter from start point
plt.figure()
yOffset = EurOtop.min()[0] - peak_velocity_crestws_WI_III.mean()
(EurOtop - yOffset).plot()
plt.legend(frameon=False)
plt.scatter(np.repeat(crestDistance, peak_velocity_crestws_WI_III.size),peak_velocity_crestws_WI_III, marker='s', color='grey')
plt.scatter(np.repeat(slopeDistance, peak_velocity_slopeRg_WI_III.size),peak_velocity_slopeRg_WI_III, marker='s', color='grey')
plt.scatter(np.repeat(toeDistance, peak_velocity_toeRws_WI_III.size),peak_velocity_toeRws_WI_III, marker='s', color='grey')
plt.ylabel('flow velocity (m/s)')
plt.title('Wave IV-VI 1000l/m f=0.01')
plt.savefig(r'D:\Projects\Pr\3517.10\Werkfolder\plots//wave_IV_VI_f001.png', dpi=300)
plt.show()

# %%
# wave 7-10
x1 = golf_7[['Flow thickness crest']].idxmax()[0]
y1 = golf_7[['Flow thickness crest']].ix[x1][0]

x1 = golf_11[['Flow thickness crest']].idxmax()[0]
y2 = golf_11[['Flow thickness crest']].ix[x1][0]

x1 = golf_9[['Flow thickness crest']].idxmax()[0]
y3 = golf_9[['Flow thickness crest']].ix[x1][0]

peak_thickness_crest_WIV_VI = np.array([y1,y2,y3])

x1 = golf_7[['Flow velocity crest (water surface)']].idxmax()[0]
y1 = golf_7[['Flow velocity crest (water surface)']].ix[x1][0]

x1 = golf_11[['Flow velocity crest (water surface)']].idxmax()[0]
y2 = golf_11[['Flow velocity crest (water surface)']].ix[x1][0]

x1 = golf_9[['Flow velocity crest (water surface)']].idxmax()[0]
y3 = golf_9[['Flow velocity crest (water surface)']].ix[x1][0]

peak_velocity_crestws_WIV_VI = np.array([y1,y2,y3])

x1 = golf_7[['Flow velocity slope (ground)']].idxmax()[0]
y1 = golf_7[['Flow velocity slope (ground)']].ix[x1][0]

x1 = golf_11[['Flow velocity slope (ground)']].idxmax()[0]
y2 = golf_11[['Flow velocity slope (ground)']].ix[x1][0]

x1 = golf_9[['Flow velocity slope (ground)']].idxmax()[0]
y3 = golf_9[['Flow velocity slope (ground)']].ix[x1][0]

peak_velocity_slopeRg_WIV_VI = np.array([y1,y2,y3])

x1 = golf_7[['Flow velocity toe R (water surface)']].idxmax()[0]
y1 = golf_7[['Flow velocity toe R (water surface)']].ix[x1][0]

x1 = golf_11[['Flow velocity toe R (water surface)']].idxmax()[0]
y2 = golf_11[['Flow velocity toe R (water surface)']].ix[x1][0]

x1 = golf_9[['Flow velocity toe R (water surface)']].idxmax()[0]
y3 = golf_9[['Flow velocity toe R (water surface)']].ix[x1][0]

peak_velocity_toeRws_WIV_VI = np.array([y1,y2,y3])

x1 = golf_7[['Flow velocity toe R (ground)']].idxmax()[0]
y1 = golf_7[['Flow velocity toe R (ground)']].ix[x1][0]

x1 = golf_11[['Flow velocity toe R (ground)']].idxmax()[0]
y2 = golf_11[['Flow velocity toe R (ground)']].ix[x1][0]

x1 = golf_9[['Flow velocity toe R (ground)']].idxmax()[0]
y3 = golf_9[['Flow velocity toe R (ground)']].ix[x1][0]

peak_velocity_toeRg_WIV_VI = np.array([y1,y2,y3])

v_b_0 = peak_velocity_crestws_WIV_VI.mean() # overtopping flow velocity at beginning of the landward toe R (m/s)
h_b_0 = peak_thickness_crest_WIV_VI.mean() # overtopping flow thickness at beginning of the landward toe R (m)
g = 9.81 # gravitational acceleration
f = 0.01 # bottom friction coeffiecient depending on the toe R material (eg. grass)
o = 1
a = 1.8
CJV = True
tal_deg = np.degrees(np.arctan(o / a))
beta = np.radians(tal_deg) #Talud helling voor teststrook I is 1:1,8
print ('talud: ',o,':',a)
print ('angle toe R (deg):',tal_deg)
print ('angle toe R (rad):',beta)
print ('v_b_0',v_b_0)
print ('h_b_0',h_b_0)

s = np.linspace(0,11,200)
v = [] # empty velocity list

# zie notitie CJV voor bepalen v_b op positie s_0
if CJV == True:
    v_b = ((2 * g * np.sin(beta) * (v_b_0 * h_b_0) ) / f) ** (1./3)
    h_b = (v_b_0 * h_b_0) / v_b
    print ('v_b',v_b)
    print ('h_b',h_b)
if CJV == False:
    h_b = (v_b_0 * h_b_0) / v_b_0
    v_b = np.sqrt((2*g * h_b*np.sin(beta))/f)    
    print ('v_b',v_b)
    print ('h_b',h_b)

# append initiatie
v.append(v_b)
for s_b in s[1::]:
    #sin2beta =  (1/2)( 1 - cos(2x) ) 
    t = -(v_b_0 / (g * np.sin(beta))) + np.sqrt(((v_b**2) / (g**2 * (0.5 * (1 - np.cos(2 * beta))))) + ((2 * s_b) / (g * np.sin(beta))))
    k_1 = np.sqrt( (2 * f * g * np.sin(beta)) / (h_b) )
    v_b = (v_b_0 + ((k_1 * h_b) / f) * np.tanh((k_1 * t)/2)) / (1 + ((f * v_b_0) / (h_b * k_1)) * np.tanh((k_1 * t) / 2))
    v.append(v_b)


EurOtop = pd.DataFrame({'flow velocity (m/s)':v,'horizontal distance from outer crest line (m)':s})
EurOtop.set_index('horizontal distance from outer crest line (m)', inplace=True)

crestDistance = 0.5
slopeDistance = 6 #meter from start point
toeDistance = 11 #meter from start point
plt.figure()
yOffset = EurOtop.min()[0] - peak_velocity_crestws_WI_III.mean()
(EurOtop - yOffset).plot()
plt.legend(frameon=False)
plt.scatter(np.repeat(crestDistance, peak_velocity_crestws_WI_III.size),peak_velocity_crestws_WI_III, marker='s', color='grey')
plt.scatter(np.repeat(slopeDistance, peak_velocity_slopeRg_WI_III.size),peak_velocity_slopeRg_WI_III, marker='s', color='grey')
plt.scatter(np.repeat(toeDistance, peak_velocity_toeRws_WI_III.size),peak_velocity_toeRws_WI_III, marker='s', color='grey')
plt.ylabel('flow velocity (m/s)')
plt.title('Wave VII-IX 1500l/m f=0.01')
plt.savefig(r'D:\Projects\Pr\3517.10\Werkfolder\plots//wave_VII_IX_f001.png', dpi=300)
plt.show()

# %%
# wave 7-10
x1 = golf_10[['Flow thickness crest']].idxmax()[0]
y1 = golf_10[['Flow thickness crest']].ix[x1][0]

x1 = golf_11[['Flow thickness crest']].idxmax()[0]
y2 = golf_11[['Flow thickness crest']].ix[x1][0]

x1 = golf_12[['Flow thickness crest']].idxmax()[0]
y3 = golf_12[['Flow thickness crest']].ix[x1][0]

peak_thickness_crest_WIV_VI = np.array([y1,y2,y3])

x1 = golf_10[['Flow velocity crest (water surface)']].idxmax()[0]
y1 = golf_10[['Flow velocity crest (water surface)']].ix[x1][0]

x1 = golf_11[['Flow velocity crest (water surface)']].idxmax()[0]
y2 = golf_11[['Flow velocity crest (water surface)']].ix[x1][0]

x1 = golf_12[['Flow velocity crest (water surface)']].idxmax()[0]
y3 = golf_12[['Flow velocity crest (water surface)']].ix[x1][0]

peak_velocity_crestws_WIV_VI = np.array([y1,y2,y3])

x1 = golf_10[['Flow velocity slope (ground)']].idxmax()[0]
y1 = golf_10[['Flow velocity slope (ground)']].ix[x1][0]

x1 = golf_11[['Flow velocity slope (ground)']].idxmax()[0]
y2 = golf_11[['Flow velocity slope (ground)']].ix[x1][0]

x1 = golf_12[['Flow velocity slope (ground)']].idxmax()[0]
y3 = golf_12[['Flow velocity slope (ground)']].ix[x1][0]

peak_velocity_slopeRg_WIV_VI = np.array([y1,y2,y3])

x1 = golf_10[['Flow velocity toe R (water surface)']].idxmax()[0]
y1 = golf_10[['Flow velocity toe R (water surface)']].ix[x1][0]

x1 = golf_11[['Flow velocity toe R (water surface)']].idxmax()[0]
y2 = golf_11[['Flow velocity toe R (water surface)']].ix[x1][0]

x1 = golf_12[['Flow velocity toe R (water surface)']].idxmax()[0]
y3 = golf_12[['Flow velocity toe R (water surface)']].ix[x1][0]

peak_velocity_toeRws_WIV_VI = np.array([y1,y2,y3])

x1 = golf_10[['Flow velocity toe R (ground)']].idxmax()[0]
y1 = golf_10[['Flow velocity toe R (ground)']].ix[x1][0]

x1 = golf_11[['Flow velocity toe R (ground)']].idxmax()[0]
y2 = golf_11[['Flow velocity toe R (ground)']].ix[x1][0]

x1 = golf_12[['Flow velocity toe R (ground)']].idxmax()[0]
y3 = golf_12[['Flow velocity toe R (ground)']].ix[x1][0]

peak_velocity_toeRg_WIV_VI = np.array([y1,y2,y3])

v_b_0 = peak_velocity_crestws_WIV_VI.mean() # overtopping flow velocity at beginning of the landward toe R (m/s)
h_b_0 = peak_thickness_crest_WIV_VI.mean() # overtopping flow thickness at beginning of the landward toe R (m)
g = 9.81 # gravitational acceleration
f = 0.01 # bottom friction coeffiecient depending on the toe R material (eg. grass)
o = 1
a = 1.8
CJV = True
tal_deg = np.degrees(np.arctan(o / a))
beta = np.radians(tal_deg) #Talud helling voor teststrook I is 1:1,8
print ('talud: ',o,':',a)
print ('angle toe R (deg):',tal_deg)
print ('angle toe R (rad):',beta)
print ('v_b_0',v_b_0)
print ('h_b_0',h_b_0)

s = np.linspace(0,11,200)
v = [] # empty velocity list

# zie notitie CJV voor bepalen v_b op positie s_0
if CJV == True:
    v_b = ((2 * g * np.sin(beta) * (v_b_0 * h_b_0) ) / f) ** (1./3)
    h_b = (v_b_0 * h_b_0) / v_b
    print ('v_b',v_b)
    print ('h_b',h_b)
if CJV == False:
    h_b = (v_b_0 * h_b_0) / v_b_0
    v_b = np.sqrt((2*g * h_b*np.sin(beta))/f)    
    print ('v_b',v_b)
    print ('h_b',h_b)

# append initiatie
v.append(v_b)
for s_b in s[1::]:
    #sin2beta =  (1/2)( 1 - cos(2x) ) 
    t = -(v_b_0 / (g * np.sin(beta))) + np.sqrt(((v_b**2) / (g**2 * (0.5 * (1 - np.cos(2 * beta))))) + ((2 * s_b) / (g * np.sin(beta))))
    k_1 = np.sqrt( (2 * f * g * np.sin(beta)) / (h_b) )
    v_b = (v_b_0 + ((k_1 * h_b) / f) * np.tanh((k_1 * t)/2)) / (1 + ((f * v_b_0) / (h_b * k_1)) * np.tanh((k_1 * t) / 2))
    v.append(v_b)


EurOtop = pd.DataFrame({'flow velocity (m/s)':v,'horizontal distance from outer crest line (m)':s})
EurOtop.set_index('horizontal distance from outer crest line (m)', inplace=True)

crestDistance = 0.5
slopeDistance = 6 #meter from start point
toeDistance = 11 #meter from start point
plt.figure()
yOffset = EurOtop.min()[0] - peak_velocity_crestws_WI_III.mean()
(EurOtop - yOffset).plot()
plt.legend(frameon=False)
plt.scatter(np.repeat(crestDistance, peak_velocity_crestws_WI_III.size),peak_velocity_crestws_WI_III, marker='s', color='grey')
plt.scatter(np.repeat(slopeDistance, peak_velocity_slopeRg_WI_III.size),peak_velocity_slopeRg_WI_III, marker='s', color='grey')
plt.scatter(np.repeat(toeDistance, peak_velocity_toeRws_WI_III.size),peak_velocity_toeRws_WI_III, marker='s', color='grey')
plt.ylabel('flow velocity (m/s)')
plt.title('Wave X-XII 2000l/m f=0.01')
plt.savefig(r'D:\Projects\Pr\3517.10\Werkfolder\plots//wave_X_XII_f001.png', dpi=300)
plt.show()
