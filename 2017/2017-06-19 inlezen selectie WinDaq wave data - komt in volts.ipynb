# %%
import pandas as pd
# %matplotlib notebook

# %%
file_sb1 = r"D:\Projects\Pr\3517.10\wdq_python\Schellebelle1_selection.xlsx"
df1 = pd.read_excel(file_sb1)

# %%
df1.head(1)['Time Stamp UTC'], df1.tail(1)['Time Stamp UTC']
# Out:
# (0    13:13:37
#  Name: Time Stamp UTC, dtype: object, 27597    13:29:54
#  Name: Time Stamp UTC, dtype: object)

# %%
df1['PADDLE WHEEL 1'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
file_sb2 = r"D:\Projects\Pr\3517.10\wdq_python\Schellebelle2_selection.xlsx"
df2 = pd.read_excel(file_sb2)

# %%
df2.head(1)['Time Stamp UTC'], df2.tail(1)['Time Stamp UTC']
# Out:
# (0    13:42:22
#  Name: Time Stamp UTC, dtype: object, 14394    13:50:51
#  Name: Time Stamp UTC, dtype: object)

# %%
df2.set_index('Relative Time', inplace=True)

# %%
df2.head()
# Out:
#                     Date Time Stamp UTC  PADDLE WHEEL 1  Angle Meter 1  \
# Relative Time
# 0.000000      2015-11-06       13:42:22        0.000610       2.012939
# 0.007222      2015-11-06       13:42:22       -0.001221       2.014160
# 0.014444      2015-11-06       13:42:22        0.000000       2.013550
# 0.021667      2015-11-06       13:42:22       -0.001221       2.013550
# 0.028889      2015-11-06       13:42:22       -0.001221       2.012329
#
#                PADDLE WHEEL 2  Angle meter 2  PADDLE WHEEL 3  Angle meter 3  \
# Relative Time
# 0.000000             0.000610      -0.066528       -0.002441       1.557007
# 0.007222            -0.001221      -0.065918       -0.001831       1.560669
# 0.014444             0.001221      -0.065918       -0.001221       1.560669
# 0.021667             0.000000      -0.066528        0.000000       1.560669
# 0.028889             0.000000      -0.065918       -0.001221       1.561279
#
# ...

# %%
df2_sel = df2[(df2.index > 10) & (df2.index < 20)]
df2_sel.ix[:,2::].plot(subplots=True)#, figsize=(15,25))
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000008264F60>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000008719630>], dtype=object)

# %%
df2_sel.ix[:,2::].plot(subplots=False)#, figsize=(15,25))
# Out:
# <img src="data:image/png;base64,..." width="640">
