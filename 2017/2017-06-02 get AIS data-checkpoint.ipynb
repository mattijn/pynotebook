# %%
import geopandas as gpd
import pandas as pd
from pandas.io.json import json_normalize
import urllib.request
import json
from geopandas import GeoDataFrame
from shapely.geometry import Point
from datetime import datetime, timedelta

# %%
def prettify(elem):
    """Return a pretty-printed XML string for the Element.
    """
    rough_string = ElementTree.tostring(elem, 'utf-8')
    reparsed = minidom.parseString(rough_string)
    return reparsed.toprettyxml(indent="  ")

# %%
def convert_coordinates(coordinates, srcEPSG, dstEPSG):
    """
    Converts points to coordinatesystem
    
    Input:
    coordinates: (list of) tuples
    """    
    from osgeo.osr import SpatialReference, CoordinateTransformation

    src = SpatialReference()
    dst = SpatialReference()
    
    src.ImportFromEPSG(srcEPSG)
    dst.ImportFromEPSG(dstEPSG)
    
    transform = CoordinateTransformation(src, dst)

    if not type(coordinates) is list:
        coordinates = [(coordinates)]
       
    if len(coordinates[0]) == 2:
        dimension = 2
    else:
        dimension = 3
       
    transformed = []
    for crd in coordinates:
        transformed.append((transform.TransformPoint(*crd)))
    
    if dimension == 2:
        transformed = [(i[0], i[1]) for i in transformed]
    return transformed

# %%
# set timedelta in epoch
min_timedelta = 0
time_epoch = int((datetime.now() - timedelta(minutes=min_timedelta)).timestamp())
print ((datetime.now() - timedelta(minutes=min_timedelta)).strftime('%c'))
print (time_epoch)
# Out:
# Mon Jun  5 21:47:57 2017
# 1496692077

# %%
# urls to retrieve AIS data from data providers
#url_marinetraffic  = 'https://www.marinetraffic.com/getData/get_data_json_4/z:5/X:7/Y:4/station:0'
minlat = str(52.316734)
maxlat = str(52.476281)
minlon = str(4.422955)
maxlon = str(5.059489)
timecode = str(time_epoch)
mmsi = str(244660778)
zoom = str(10)

url_vesselsonmap = 'http://www.myshiptracking.com/requests/vesselsonmap.php?type=json&minlat='+minlat+'&maxlat='+maxlat+'&minlon='+minlon+'&maxlon='+maxlon+'&zoom='+zoom+'&mmsi='+mmsi+'&timecode='+timecode
print (url_vesselsonmap)
# Out:
# http://www.myshiptracking.com/requests/vesselsonmap.php?type=json&minlat=52.316734&maxlat=52.476281&minlon=4.422955&maxlon=5.059489&zoom=10&mmsi=244660778&timecode=1496692077

# %%
# request the tracking url and decode as json and parse to pandas dataframe
r = urllib.request.urlopen(url_vesselsonmap)
data = json.loads(r.read().decode(r.info().get_param('charset') or 'utf-8'))
df_vesselsonmap = json_normalize(data[0]['DATA'])

# %%
# drop all the NaNs
# and convert strings to floats
df_vesselsonmap.dropna(inplace=True)
df_vesselsonmap.LNG = df_vesselsonmap.LNG.astype(float)
df_vesselsonmap.LAT = df_vesselsonmap.LAT.astype(float)

# %%
## convert LNG and LAT columns to geodataframe
# geometry = [Point(xy) for xy in zip(df.LNG.astype(float), df.LAT.astype(float))]
# df = df.drop(['LNG', 'LAT'], axis=1)
# crs = {'init': 'epsg:4326'}
# geo_df = GeoDataFrame(df, crs=crs, geometry=geometry)

# %%
df_vesselsonmap.head()
# Out:
#    ARV   COG                 DEST        IMO       LAT      LNG       MMSI  \
# 0       33.8              HAMBURG    9244192  52.67254  4.04029  235480000
# 15         0                                  52.64417  5.09833    2442024
# 17      17.3                                  52.62458  5.25283  244630529
# 36        35  AMSTEPDAM ANCHORING  947324800  52.53064  4.28022  311058400
# 41         0                                  52.58167  4.26000  992446023
#
#                 NAME           R   S1  S2  S3  S4  SOG           T TYPE  \
# 0       CONMAR FJORD  1496692078  118  15  12   7   12  1496692078    7
# 15                    1496692082                     0  1496692082   11
# 17           PEETIET  1496692077    6   4   3   0  5.2  1496692077    9
# 36  CLIPPER NEWHAVEN  1496692082  128  16  12  12  0.2  1496692082    0
# 41       WTG_22_PAWP  1496692078   56  56  56  56    0  1496692078   13
#
#          T_OLD
# 0   1496692078
# 15  1496692082
# 17  1496692077
# 36  1496692082
# 41  1496692078

# %%
import folium

mapa = folium.Map([52.419052, 4.800132],
                  zoom_start=int(zoom),
                  tiles='cartodbpositron')

fg=folium.FeatureGroup(name="ships")
#points = folium.features.GeoJson(df)

for lat,lon,name,dest in zip(df_vesselsonmap['LAT'],df_vesselsonmap['LNG'],df_vesselsonmap['NAME'],df_vesselsonmap['DEST']):
    #print (lat,lon,name,dest)
    try:
        fg.add_child(folium.Marker(location=[lat,lon],popup=(folium.Popup('NAME: '+name+'  '+'DEST: '+dest))))
    except:
        continue

mapa.add_child(fg)
mapa.add_child(folium.LayerControl())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# REQUEST SINGLE SHIP INFORMATION

# %%
def getVesselDetails(mmsi):
    # urls to retrieve AIS data from data providers
    # mmsi (type: string)

    url_vesseldetails = 'http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi='+mmsi
    #print (url_vesseldetails)

    # request the tracking url and decode as json and parse to pandas dataframe
    r = urllib.request.urlopen(url_vesseldetails)
    data = json.loads(r.read().decode(r.info().get_param('charset') or 'utf-8'))
    df_vesseldetails = json_normalize(data)

    try:
        df_vesseldetails['V.LENGTH'] = float(df_vesseldetails['V.TO_BOW']) + float(df_vesseldetails['V.TO_STERN'])
        df_vesseldetails['V.WIDTH']  = float(df_vesseldetails['V.TO_STARBOARD']) + float(df_vesseldetails['V.TO_PORT'])
    except Exception as e:
        print (e)
    return df_vesseldetails['V.WIDTH']

# %%
base_df_vDetails = getVesselDetails(str(df_vesselsonmap['MMSI'][0]))
# Out:
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=235480000

# %%
base_df_vDetails
# Out:
#                                                    P TZ V.COG V.DESTINATION  \
# 0  [{'N': 'HAMBURG', 'LINK': 'port-of-hamburg-in-...     32.6       HAMBURG
#
#   V.DRAUGHT                 V.ETA              V.FLAG     V.LAT V.LDEST  \
# 0       5.2  2017-06-06 12:00 UTC  United Kingdom[UK]  52.71343   NLRTM
#
#            V.LDESTT   ...   V.RECEIVED_STATIC  V.SOG V.STATION_ID V.TO_BOW  \
# 0  2017-06-05 14:31   ...    2017-06-05 19:44   11.8           14      118
#
#   V.TO_PORT V.TO_STARBOARD V.TO_STERN   V.VESSEL_TYPE V.LENGTH V.WIDTH
# 0        12              7         15  Container Ship    133.0    19.0
#
# [1 rows x 27 columns]

# %%
for mmsi in df_vesselsonmap['MMSI'][1::]:
    print (str(mmsi))
    df_vDetails = getVesselDetails(str(mmsi))
    base_df_vDetails = pd.concat([base_df_vDetails, df_vDetails], axis=0)
# Out:
# 2442024
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=2442024
# could not convert string to float:
# 244630529
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244630529
# 311058400
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=311058400
# 992446023
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=992446023
# 244820372
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244820372
# 244026043
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244026043
# 244010915
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244010915
# 244923000
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244923000
# 244730498
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244730498
# 244010542
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244010542
# 220569000
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=220569000
# 246657000
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=246657000
# 244239000
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244239000
# 244710444
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244710444
# 244820297
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244820297
# 244870932
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244870932
# 2444010
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=2444010
# 2444011
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=2444011
# could not convert string to float:
# 205410590
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=205410590
# 205439790
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=205439790
# 211386900
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=211386900
# 211509670
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=211509670
# 211625830
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=211625830
# 244010963
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244010963
# 244020692
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244020692
# 244670518
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244670518
# 244142000
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244142000
# 244650814
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244650814
# 244690914
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244690914
# 244820298
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244820298
# 205424690
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=205424690
# 244010988
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244010988
# 244020560
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244020560
# 244020823
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244020823
# 244660594
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244660594
# 244690818
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244690818
# 244770199
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244770199
# 244010489
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244010489
# 244660229
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244660229
# 244660783
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244660783
# 244690646
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244690646
# 244700923
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244700923
# 244710631
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244710631
# 244660563
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244660563
# 244700485
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244700485
# 245453000
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=245453000
# 244730602
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244730602
# 244030270
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244030270
# 244110350
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244110350
# 244130359
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244130359
# 244710965
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244710965
# 244615365
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244615365
# 244690144
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244690144
# 244670958
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244670958
# 244690778
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244690778
# 244690810
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244690810
# 244810551
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244810551
# 244780435
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244780435
# 244770939
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244770939
# could not convert string to float:
# 244740575
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244740575
# 244660224
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244660224
# 240265000
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=240265000
# 244670929
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244670929
# 2442006
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=2442006
# 244660682
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244660682
# 244670845
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244670845
# 2444016
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=2444016
# could not convert string to float:
# 244870678
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244870678
# 244660778
# http://www.myshiptracking.com/requests/vesseldetails.php?type=json&mmsi=244660778

# %%
df_vDetails
# Out:
#     P TZ V.COG V.DESTINATION V.DRAUGHT V.ETA           V.FLAG     V.LAT  \
# 0  []      511                     0.3        Netherlands[NL]  51.96866
#
#     V.LDEST          V.LDESTT   ...   V.RECEIVED_STATIC  V.SOG V.STATION_ID  \
# 0  MAASTRIC  2017-03-21 10:19   ...    2017-06-05 19:54    4.7           14
#
#   V.TO_BOW V.TO_PORT V.TO_STARBOARD V.TO_STERN  V.VESSEL_TYPE V.LENGTH V.WIDTH
# 0       57         2              5         10  Not available     67.0     7.0
#
# [1 rows x 27 columns]

# %%
base_df_vDetails.T
# Out:
#                                                                    0  \
# P                  [{'N': 'HAMBURG', 'LINK': 'port-of-hamburg-in-...
# TZ
# V.COG                                                           32.6
# V.DESTINATION                                                HAMBURG
# V.DRAUGHT                                                        5.2
# V.ETA                                           2017-06-06 12:00 UTC
# V.FLAG                                            United Kingdom[UK]
# V.LAT                                                       52.71343
# V.LDEST                                                        NLRTM
# V.LDESTT                                            2017-06-05 14:31
# V.LENGTH                                                         133
# V.LNG                                                        4.08499
# V.MMSI                                                     235480000
# V.NAME                                                  CONMAR FJORD
# V.NAV_STATUS                                  Under way using engine
# V.RECEIVED                                   2017-06-05 20:02:48 UTC
# V.RECEIVED_AGO                                            16 sec ago
# V.RECEIVED_SEC                                            16.0472573
# V.RECEIVED_STATIC                                   2017-06-05 19:44
# V.SOG                                                           11.8
# V.STATION_ID                                                      14
# V.TO_BOW                                                         118
# V.TO_PORT                                                         12
# V.TO_STARBOARD                                                     7
# V.TO_STERN                                                        15
# V.VESSEL_TYPE                                         Container Ship
# V.WIDTH                                                           19
#
#                                          0                        0  \
# P                                       []                       []
# TZ
# V.COG                                    0                     15.5
# V.DESTINATION
# V.DRAUGHT
# V.ETA
# V.FLAG                                              Netherlands[NL]
# V.LAT                             52.64417                  52.6457
# V.LDEST
# V.LDESTT
# V.LENGTH                               NaN                       10
# V.LNG                              5.09833                  5.26254
# V.MMSI                             2442024                244630529
# V.NAME                                                      PEETIET
# V.NAV_STATUS                       Default                  Default
# V.RECEIVED         2017-06-05 20:03:05 UTC  2017-06-05 20:02:56 UTC
# V.RECEIVED_AGO                   0 sec ago                9 sec ago
# V.RECEIVED_SEC                   0.9218967                9.8596094
# V.RECEIVED_STATIC                                  2017-06-05 19:02
# V.SOG                                    0                      5.2
# V.STATION_ID                            14                       14
# V.TO_BOW                                                          6
# V.TO_PORT                                                         3
# V.TO_STARBOARD                                                    0
# V.TO_STERN                                                        4
# V.VESSEL_TYPE                 Base Station           Pleasure Craft
# V.WIDTH                                NaN                        3
#
#                                          0                            0  \
# P                                       []                           []
# TZ
# V.COG                                   46                            0
# V.DESTINATION
# V.DRAUGHT                              6.4
# V.ETA
# V.FLAG                         Bahamas[BS]                  Unknown[00]
# V.LAT                             52.53083                     52.58167
# V.LDEST                          AMSTERDAM
# V.LDESTT                  2017-06-02 19:32
# V.LENGTH                               144                          112
# V.LNG                              4.27904                         4.26
# V.MMSI                           311058400                    992446023
# V.NAME                    CLIPPER NEWHAVEN                  WTG_22_PAWP
# V.NAV_STATUS                     At anchor  Restricted manoeuverability
# V.RECEIVED         2017-06-05 20:02:57 UTC      2017-06-05 20:01:38 UTC
# V.RECEIVED_AGO                   9 sec ago             1 m, 29 sec ago
# V.RECEIVED_SEC                    9.265787                   89.0802531
# V.RECEIVED_STATIC         2017-06-05 19:59             2017-06-05 20:01
# V.SOG                                  0.4                            0
# V.STATION_ID                            14                           14
# V.TO_BOW                               128                           56
# V.TO_PORT                               12                           56
# V.TO_STARBOARD                          12                           56
# V.TO_STERN                              16                           56
# V.VESSEL_TYPE                   Other Type               Navigation Aid
# V.WIDTH                                 24                          112
#
#                                          0                        0  \
# P                                       []                       []
# TZ
# V.COG                                  511                    199.8
# V.DESTINATION
# V.DRAUGHT                              0.2
# V.ETA
# V.FLAG                     Netherlands[NL]          Netherlands[NL]
# V.LAT                             52.56559                 52.51048
# V.LDEST                   ALPHEN AAN DE RI
# V.LDESTT                  2017-05-30 18:53
# V.LENGTH                                55                       12
# V.LNG                              4.74112                  5.17288
# V.MMSI                           244820372                244026043
# V.NAME                               LEEUW                     MYTH
# V.NAV_STATUS        Under way using engine                  Default
# V.RECEIVED         2017-06-05 20:02:48 UTC  2017-06-05 20:02:32 UTC
# V.RECEIVED_AGO                  19 sec ago               34 sec ago
# V.RECEIVED_SEC                  19.4848367                34.969584
# V.RECEIVED_STATIC         2017-06-05 19:53         2017-06-05 19:58
# V.SOG                                    0                      5.7
# V.STATION_ID                            14                       14
# V.TO_BOW                                46                        6
# V.TO_PORT                                3                        0
# V.TO_STARBOARD                           4                        4
# V.TO_STERN                               9                        6
# V.VESSEL_TYPE                Not available                  Sailing
# V.WIDTH                                  7                        4
#
#                                          0                        0  \
# P                                       []                       []
# TZ
# V.COG                                 17.3                      139
# V.DESTINATION
# V.DRAUGHT                              1.5                        0
# V.ETA
# V.FLAG                     Netherlands[NL]          Netherlands[NL]
# V.LAT                             52.57449                 52.57172
# V.LDEST                 COAST GUARD DUTIES       BLOCQ VAN KUFFELER
# V.LDESTT                  2015-10-17 09:45         2017-03-06 11:12
# V.LENGTH                                22                       20
# V.LNG                              5.20921                  5.36786
# V.MMSI                           244010915                244923000
# V.NAME                   WR-130 JOHANNA II                    KIM K
# V.NAV_STATUS                        Moored                  Default
# V.RECEIVED         2017-06-05 20:02:59 UTC  2017-06-05 20:03:01 UTC
# V.RECEIVED_AGO                   7 sec ago                6 sec ago
# V.RECEIVED_SEC                   7.9220618                6.4376534
# V.RECEIVED_STATIC         2017-06-05 19:58         2017-06-05 20:02
# V.SOG                                  7.3                      0.1
# V.STATION_ID                            14                       14
# V.TO_BOW                                 7                       10
# V.TO_PORT                                3                        3
# V.TO_STARBOARD                           2                        2
# V.TO_STERN                              15                       10
# V.VESSEL_TYPE                Not available              Work Vessel
# V.WIDTH                                  5                        5
#
#                                          0           ...             \
# P                                       []           ...
# TZ                                                   ...
# V.COG                                205.4           ...
# V.DESTINATION                                        ...
# V.DRAUGHT                                0           ...
# V.ETA                                                ...
# V.FLAG                     Netherlands[NL]           ...
# V.LAT                             52.54299           ...
# V.LDEST                         DUSSELDORF           ...
# V.LDESTT                  2017-04-26 15:22           ...
# V.LENGTH                                60           ...
# V.LNG                              5.44285           ...
# V.MMSI                           244730498           ...
# V.NAME                              MATHIA           ...
# V.NAV_STATUS        Under way using engine           ...
# V.RECEIVED         2017-06-05 20:02:49 UTC           ...
# V.RECEIVED_AGO                  18 sec ago           ...
# V.RECEIVED_SEC                  18.5941919           ...
# V.RECEIVED_STATIC         2017-06-05 19:48           ...
# V.SOG                                  7.6           ...
# V.STATION_ID                            14           ...
# V.TO_BOW                                51           ...
# V.TO_PORT                                3           ...
# V.TO_STARBOARD                           4           ...
# V.TO_STERN                               9           ...
# V.VESSEL_TYPE                Not available           ...
# V.WIDTH                                  7           ...
#
#                                          0                        0  \
# P                                       []                       []
# TZ
# V.COG                                  511                      511
# V.DESTINATION                       LEIDEN
# V.DRAUGHT                              0.9                      2.8
# V.ETA
# V.FLAG                     Netherlands[NL]          Netherlands[NL]
# V.LAT                             52.16116                 52.22311
# V.LDEST                                                 VAL VAN URK
# V.LDESTT                                           2017-06-01 15:42
# V.LENGTH                                27                       81
# V.LNG                              4.50098                  5.31356
# V.MMSI                           244740575                244660224
# V.NAME                            AMBIANCE                 ZAGRI 15
# V.NAV_STATUS        Under way using engine   Under way using engine
# V.RECEIVED         2017-06-05 20:02:58 UTC  2017-06-05 20:02:59 UTC
# V.RECEIVED_AGO                  13 sec ago               11 sec ago
# V.RECEIVED_SEC                   13.781574               11.9065744
# V.RECEIVED_STATIC         2017-06-05 19:58         2017-06-05 19:40
# V.SOG                                    0                        0
# V.STATION_ID                            14                       14
# V.TO_BOW                                 8                       73
# V.TO_PORT                                4                        0
# V.TO_STARBOARD                           2                        6
# V.TO_STERN                              19                        8
# V.VESSEL_TYPE                Not available            Not available
# V.WIDTH                                  6                        6
#
#                                          0                        0  \
# P                                       []                       []
# TZ
# V.COG                                   68                      511
# V.DESTINATION              N0. 5 ANCHORAGE             SCHEVENINGEN
# V.DRAUGHT                                9                      1.4
# V.ETA                 2017-06-05 17:30 UTC
# V.FLAG                          Greece[GR]          Netherlands[NL]
# V.LAT                              52.1196                 52.12276
# V.LDEST                             LUANDA            #CHPEVENINGEN
# V.LDESTT                  2017-06-05 17:05         2016-10-27 03:07
# V.LENGTH                               294                       10
# V.LNG                              3.72078                  4.08244
# V.MMSI                           240265000                244670929
# V.NAME                        MSC MANDRAKI               SCH3 RENZO
# V.NAV_STATUS                     At anchor       Engaged in Fishing
# V.RECEIVED         2017-06-05 20:02:59 UTC  2017-06-05 20:03:02 UTC
# V.RECEIVED_AGO                  12 sec ago                9 sec ago
# V.RECEIVED_SEC                  12.3596734                9.2502193
# V.RECEIVED_STATIC         2017-06-05 19:33         2017-06-05 19:57
# V.SOG                                    0                        1
# V.STATION_ID                            14                       14
# V.TO_BOW                               194                        2
# V.TO_PORT                               16                        2
# V.TO_STARBOARD                          16                        2
# V.TO_STERN                             100                        8
# V.VESSEL_TYPE               Container Ship            Not available
# V.WIDTH                                 32                        4
#
#                                          0                        0  \
# P                                       []                       []
# TZ
# V.COG                                    0                      511
# V.DESTINATION
# V.DRAUGHT                                                         0
# V.ETA
# V.FLAG                     Netherlands[NL]          Netherlands[NL]
# V.LAT                             52.09472                 52.06697
# V.LDEST                                                  BAARHE-NEC
# V.LDESTT                                           2014-12-27 05:32
# V.LENGTH                                 0                       70
# V.LNG                               4.2575                  4.34497
# V.MMSI                             2442006                244660682
# V.NAME                       O, COASTGUARD                    TRUON
# V.NAV_STATUS                       Default   Under way using engine
# V.RECEIVED         2017-06-05 20:03:03 UTC  2017-06-05 20:03:07 UTC
# V.RECEIVED_AGO                   8 sec ago                5 sec ago
# V.RECEIVED_SEC                   8.8752121                5.2032497
# V.RECEIVED_STATIC         2016-08-06 14:07         2017-06-05 18:18
# V.SOG                                    0                        0
# V.STATION_ID                            14                       14
# V.TO_BOW                                 0                       60
# V.TO_PORT                                0                        5
# V.TO_STARBOARD                           0                        3
# V.TO_STERN                               0                       10
# V.VESSEL_TYPE                 Base Station            Not available
# V.WIDTH                                  0                        8
#
#                                          0                        0  \
# P                                       []                       []
# TZ
# V.COG                                  511                        0
# V.DESTINATION
# V.DRAUGHT                              2.4
# V.ETA
# V.FLAG                     Netherlands[NL]
# V.LAT                             52.11944                 52.11313
# V.LDEST               IJMUIDEN         "50
# V.LDESTT                  2015-11-27 07:26
# V.LENGTH                                23                      NaN
# V.LNG                              4.67225                  5.07666
# V.MMSI                           244670845                  2444016
# V.NAME                              JENNIE
# V.NAV_STATUS        Under way using engine                  Default
# V.RECEIVED         2017-06-05 20:03:11 UTC  2017-06-05 20:03:12 UTC
# V.RECEIVED_AGO                   1 sec ago                0 sec ago
# V.RECEIVED_SEC                   1.4687798                0.8906786
# V.RECEIVED_STATIC         2017-06-05 19:43
# V.SOG                                    0                        0
# V.STATION_ID                            14                       15
# V.TO_BOW                                 5
# V.TO_PORT                                5
# V.TO_STARBOARD                           1
# V.TO_STERN                              18
# V.VESSEL_TYPE                Not available             Base Station
# V.WIDTH                                  6                      NaN
#
#                                          0                        0
# P                                       []                       []
# TZ
# V.COG                                  511                      511
# V.DESTINATION                    HUIS_____
# V.DRAUGHT                              0.2                      0.3
# V.ETA
# V.FLAG                     Netherlands[NL]          Netherlands[NL]
# V.LAT                             52.13064                 51.96866
# V.LDEST                                                    MAASTRIC
# V.LDESTT                                           2017-03-21 10:19
# V.LENGTH                                25                       67
# V.LNG                              5.05004                  5.31459
# V.MMSI                           244870678                244660778
# V.NAME                        SILVER CLOUD                      LIA
# V.NAV_STATUS                       Default   Under way using engine
# V.RECEIVED         2017-06-05 20:03:02 UTC  2017-06-05 20:03:09 UTC
# V.RECEIVED_AGO                  10 sec ago                3 sec ago
# V.RECEIVED_SEC                  10.2190374                3.9063436
# V.RECEIVED_STATIC         2017-06-05 19:46         2017-06-05 19:54
# V.SOG                                    0                      4.7
# V.STATION_ID                            14                       14
# V.TO_BOW                                 4                       57
# V.TO_PORT                                4                        2
# V.TO_STARBOARD                           1                        5
# V.TO_STERN                              21                       10
# V.VESSEL_TYPE                Not available            Not available
# V.WIDTH                                  5                        7
#
# [27 rows x 70 columns]

# %%
# START CREATING THE NODE XML FILE

# %%
# lat/lon coordinates in 4326
in_points = [(52.379972,4.958865),(51.967049,5.320434),(52.466740,4.606085),(52.014135,5.110308),(52.036883,5.112706),(52.374937,4.948080),(52.420181,4.809713),(52.396220,4.813572),(52.521354,3.521670),(53.036403,4.142134),(52.075505,2.839227)]

# corresponding nodes
loc_codes = ['OSZ','PIZ','SIJ','PBS','LKD','GMC','HPT','HHN','NZW','NZN','NZZ']

# convert to rd coordinates (28992)
c = []
for b in in_points: c.append(b[::-1])
rd_coords = convert_coordinates(c, 4326, 28992)

# %%
from xml.etree import ElementTree
from xml.dom import minidom
from xml.etree.ElementTree import Element, SubElement, Comment

# %%
# CREATE XML NODES
nodes = Element('nodes')
for idx in range(len(loc_codes)):
    #print (idx)
    loc = loc_codes[idx]
    x   = str(rd_coords[idx][0])
    y   = str(rd_coords[idx][1]    )
    #print (x,y,loc) 
    child_1 = SubElement(nodes, 'node')
    child_1.set('id',loc)
    child_1.set('x',x)
    child_1.set('y',y)
print(prettify(nodes))

# %%
# END CREATING THE NODE XML FILE

# %%
df.T

# %%
data.V.TO_BOW,data.V.TO_STERN,data.V.TO_STARBOARD,data.V.TO_PORT

# %%
function format_size(a, b, c, d) {
    if (isNaN(parseFloat(a) + parseFloat(b))) {
        return "---";
    } else {
        return (parseFloat(a) + parseFloat(b)) + " x " + (parseFloat(c) + parseFloat(d)) + " " + lang_files['m'];
