# %%
import hkvfewspy as hkv

# %%
pi = hkv.Pi()

# %%
url = 'https://oms-waddenzee.nl:8443/FewsWebServices/fewspiservice?wsdl'
pi.setClient(wsdl=url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-65cfcd63ff08> in <module>
#       1 url = 'https://oms-waddenzee.nl:8443/FewsWebServices/fewspiservice?wsdl'
# ----> 2 pi.setClient(wsdl=url)
#
# c:\programdata\miniconda3\lib\site-packages\hkvfewspy\io\soap_fewspi.py in setClient(self, wsdl)
#     131         """
#     132         settings = Settings(xml_huge_tree=True)
# --> 133         self.client = Client(wsdl=wsdl, settings=settings)
#     134
#     135     def setQueryParameters(self, prefill_defaults=True):
#
# c:\programdata\miniconda3\lib\site-packages\zeep\client.py in __init__(self, wsdl, wsse, transport, service_name, port_name, plugins, settings)
#      60         self.transport = transport if transport is not None else Transport()
#      61         self.wsdl = Document(
# ---> 62             wsdl, self.transport, settings=self.settings)
# ...

# %%
pi.getFilters()
# Out:
#                                                    f_werk_1  \
# description
# id                                                 f_werk.1
# name         Baggeren + Zandwinning + Agiteren (/baggervak)
#
#                                     f_werk_2  f_trend_1  f_trend_2  f_trend_3  \
# description
# id                                  f_werk.2  f_trend.1  f_trend.2  f_trend.3
# name         Verspreiden (/verspreidingsvak)   Cut-data  Fill-data  Wind-data
#
#                     f_fewsPi
# description
# id                  f_fewsPi
# name         Fews-Pi service

# %%
pi.getLocations()
# Out:
#                      bv_1_7_2_3_2           bv_1_7_1_3_1  \
# geoDatum    Rijks Driehoekstelsel  Rijks Driehoekstelsel
# lat            53.198056100473764      52.95700456525013
# locationId           bv.1.7.2.3.2           bv.1.7.1.3.1
# lon             5.306253896524052      5.017969181685596
# shortName            Blauwe Slenk        Visjagersgaatje
# x                        149590.0               130187.0
# y                        579048.0               552283.0
#
#                      bv_1_7_3_1_1         bv_1_7_3_1_2_A  \
# geoDatum    Rijks Driehoekstelsel  Rijks Driehoekstelsel
# lat             53.39451780052978      53.42342630960694
# locationId           bv.1.7.3.1.1         bv.1.7.3.1.2.A
# lon             5.848013172360157      5.778482295443792
# shortName          Holwerd - VA33              VA4 - VA6
# x                        185655.0               181012.0
# y                        601008.0      604198.0000000001
#
# ...
