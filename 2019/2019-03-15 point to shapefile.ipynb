# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %%
path_in = r"D:\Projects\Pr\3915.10\Data_Viewer\df_volume_sand_update20190603.csv"
df = pd.read_csv(path_in, sep=';', index_col='Index_Total')#'Index_Total', )

# %%
df.columns[0]
# Out:
# 'Unnamed: 0'

# %%
df.head()
# Out:
#              Unnamed: 0           X          Y  Jarkus  Angle_Deg  Angle_Rad  \
# Index_Total
# 0                     0  110198.000  552010.00    True      161.1   2.811725
# 1                     1  110197.675  552009.05   False      161.1   2.811725
# 2                     2  110197.350  552008.10   False      161.1   2.811725
# 3                     3  110197.025  552007.15   False      161.1   2.811725
# 4                     4  110196.700  552006.20   False      161.1   2.811725
#
#              Volume>0mzeespiegelstijging  Volume>0.25mzeespiegelstijging  \
# Index_Total
# 0                            1283.046639                     1186.796639
# 1                            1305.559158                     1208.059158
# 2                            1346.972275                     1246.972275
# 3                            1350.531578                     1250.531578
# 4                            1387.853613                     1285.353613
#
# ...

# %%
geometry = [Point(xy) for xy in zip(df.X, df.Y)]

# %%
df = df.drop(['Unnamed: 0','X', 'Y', 'Jarkus', 'Angle_Deg','Angle_Rad'], axis=1)
crs = {'init': 'epsg:28992'}
gdf = gpd.GeoDataFrame(df, crs=crs, geometry=geometry)
gdf = gdf.fillna(0)

# %%
gdf.to_crs(epsg=4326, inplace=True)

# %%
gdf.crs
# Out:
# {'init': 'epsg:4326', 'no_defs': True}

# %%
# %matplotlib inline
gdf.plot()

# %%
gdf.head()
# Out:
#              Volume>0mzeespiegelstijging  Volume>0.25mzeespiegelstijging  \
# Index_Total
# 0                            1283.046639                     1186.796639
# 1                            1305.559158                     1208.059158
# 2                            1346.972275                     1246.972275
# 3                            1350.531578                     1250.531578
# 4                            1387.853613                     1285.353613
#
#              Volume>0.50mzeespiegelstijging  Volume>0.75mzeespiegelstijging  \
# Index_Total
# 0                               1090.546639                      994.296639
# 1                               1110.559158                     1013.059158
# 2                               1146.972275                     1046.972275
# 3                               1150.531578                     1050.531578
# 4                               1182.853613                     1080.353613
#
# ...

# %%
cols = gdf.columns

# %%
cols[0]
# Out:
# 'Volume>0mzeespiegelstijging'

# %%
new_cols = []
for col in cols:
    col = col.replace('Volume>','')
    col2 = col.replace('mzeespiegelstijging','')
    try:
        #float(col2)
        col2 = "{0:.2f}".format(float(col2))
        col2 = float(col2)
        #col2=col2.replace('.', '_')
        new_cols.append(col2)
    except:
        new_cols.append(col)

# %%
gdf.columns = new_cols

# %%
gdf.head()
# Out:
#                      0.0         0.25          0.5         0.75         1.0  \
# Index_Total
# 0            1283.046639  1186.796639  1090.546639   994.296639  900.893068
# 1            1305.559158  1208.059158  1110.559158  1013.059158  918.405867
# 2            1346.972275  1246.972275  1146.972275  1046.972275  949.818878
# 3            1350.531578  1250.531578  1150.531578  1050.531578  953.378448
# 4            1387.853613  1285.353613  1182.853613  1080.353613  980.700283
#
#                    1.25         1.5        1.75         2.0        2.25  \
# Index_Total
# 0            814.643068  728.531036  643.531036  561.992364  488.242364
# 1            830.905867  743.544002  657.294002  574.485111  499.485111
# 2            859.818878  770.094728  682.594728  598.516135  522.266135
# 3            863.378448  773.654222  686.154222  602.075229  525.825229
# 4            888.200283  796.114354  707.364354  621.631250  542.881250
#
# ...

# %%
gdf_melt = gdf.melt(id_vars=['geometry'])

# %%
gdf_melt.head()
# Out:
#                                       geometry variable        value
# 0  POINT (4.720572174170165 52.95326176364703)        0  1283.046639
# 1  POINT (4.720567469170446 52.95325320018438)        0  1305.559158
# 2   POINT (4.72056276417257 52.95324463672156)        0  1346.972275
# 3  POINT (4.720558059176533 52.95323607325844)        0  1350.531578
# 4   POINT (4.720553354182343 52.9532275097952)        0  1387.853613

# %%
gdf_melt.variable = gdf_melt.variable.astype(float)

# %%
gdf_melt.head()
# Out:
#                                       geometry  variable        value
# 0  POINT (4.720572174170165 52.95326176364703)       0.0  1283.046639
# 1  POINT (4.720567469170446 52.95325320018438)       0.0  1305.559158
# 2   POINT (4.72056276417257 52.95324463672156)       0.0  1346.972275
# 3  POINT (4.720558059176533 52.95323607325844)       0.0  1350.531578
# 4   POINT (4.720553354182343 52.9532275097952)       0.0  1387.853613

# %%
gdf_melt.variable = (gdf_melt.variable * 100).astype(int)

# %%
gdf_melt.variable.unique()
# Out:
# array([  0,  25,  50,  75, 100, 125, 150, 175, 200, 225, 250, 275, 300,
#        325, 350, 375, 400], dtype=int64)

# %%
gdf_melt.dtypes
# Out:
# geometry     object
# variable      int32
# value       float64
# dtype: object

# %%
gdf.crs
# Out:
# {'init': 'epsg:4326', 'no_defs': True}

# %%
gdf_melt.to_file(r'D:\Projects\Pr\3915.10\Data_Viewer\gdf_volume_sand_melt_v3.shp')

# %%
#gdf.to_file(r'D:\Projects\Pr\3915.10\Data_Viewer\gdf_volume_sand.json', driver='GeoJSON')
