# %%
import hkvsobekpy as hkv

# %%
his_fp = r"C:\Users\hoek.HKV\Desktop\UPFLOWDT.HIS"

# %%
his = hkv.read_his.ReadMetadata(his_fp)

# %%
locations = his.GetLocations()
timestamps = his.GetTimestamps()
parameters = his.GetParameters()

loc = locations[-1]
param = parameters[-1]

# %%
df = his.EnkeleWaardenArray(loc, param)

# %%
df.plot()

# %%
his.hisFile.timestampInfo.offset
# Out:
# array([     12372,      55496,      98620, ..., 7938148920, 7938192044,
#        7938235168], dtype=int64)
