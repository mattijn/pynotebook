# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\hoek.HKV\Desktop\herberekeningDebieten.csv")
idx = df.groupby(['locid'])['enddate'].transform(max) == df['enddate']
df[idx]['enddate'].unique()

# %%
df.head()
# Out:
#       locid  startdate   enddate totaal_plus totaal_min            formule  \
# 0  KW100111   19700101  21000101         NaN        NaN      Debiet Vijzel
# 1  KW100121   19700101  21000101         NaN        NaN  Debiet Kantelstuw
# 2  KW100211   19700101  21000101         NaN        NaN      Debiet Vijzel
# 3  KW100311   19700101  21000101    KW100313        NaN      Debiet Vijzel
# 4  KW100411   19700101  20190501    KW100413        NaN      Debiet Vijzel
#
#    keuze formule commentaar  breedte   cc  ...  temperatuur  \
# 0            NaN        NaN      NaN  NaN  ...          NaN
# 1            1.0        NaN      2.0  1.0  ...          NaN
# 2            NaN        NaN      NaN  NaN  ...          NaN
# 3            NaN        NaN      NaN  NaN  ...          NaN
# 4            NaN        NaN      NaN  NaN  ...          NaN
#
#    timeout communicatie  vulpunt  wandruwheid  waterstand  \
# 0                   NaN   -4.000          NaN         NaN
# ...

# %%
idx = df.groupby(['locid'])['enddate'].transform(max) == df['enddate']
df[idx]['enddate'].unique()
# Out:
# array([21000101, 20190619], dtype=int64)
